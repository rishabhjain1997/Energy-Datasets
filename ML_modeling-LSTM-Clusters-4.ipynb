# %% [markdown]
# #### Importing Libraries and Dataset

# %%
import numpy as np
from statistics import mean
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import pandas as pd
import seaborn as sns
from tslearn.clustering import TimeSeriesKMeans
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, SimpleRNN 
from tensorflow.keras import regularizers
from tensorflow.keras.layers import Dense, Dropout
import tensorflow as tf
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from tensorflow import keras
import seaborn as sns
import pickle
import functools
import fastdtw
import scipy.spatial.distance as sd
#from datetime import datetime
consumption_df = pd.read_csv('Final Datasets/energy_consumption.csv')
consumption_df
# Out:
# 2022-05-30 00:14:44.172109: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-05-30 00:14:44.172142: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
#         Unnamed: 0            timestamp  energy_kWh  House Number  \
# 0                0  2012-06-01 01:00:00      1.0110             1
# 1                1  2012-06-01 02:00:00      0.4510             1
# 2                2  2012-06-01 03:00:00      0.5050             1
# 3                3  2012-06-01 04:00:00      0.4410             1
# 4                4  2012-06-01 05:00:00      0.4680             1
# ...            ...                  ...         ...           ...
# 611013      123761  2020-05-19 19:00:00      3.5802            28
# 611014      123762  2020-05-19 20:00:00      3.4398            28
# 611015      123763  2020-05-19 21:00:00      2.3049            28
# 611016      123764  2020-05-19 22:00:00      2.4921            28
# 611017      123765  2020-05-19 23:00:00      1.1817            28
#
#         electronics workbench energy  network equipment energy  \
# 0                           0.008686                  0.019316
# 1                           0.007178                  0.019338
# 2                           0.007324                  0.019336
# 3                           0.007151                  0.019339
# 4                           0.007224                  0.019338
# ...                              ...                       ...
# 611013                      0.028408                  0.038470
# 611014                      0.027762                  0.038479
# 611015                      0.022537                  0.038556
# 611016                      0.023399                  0.038544
# 611017                      0.017367                  0.038632
#
#         home office energy  RAE home office energy  \
# 0                 0.018232                0.134570
# 1                 0.013745                0.061839
# 2                 0.014177                0.068852
# 3                 0.013664                0.060540
# 4                 0.013881                0.064047
# ...                    ...                     ...
# 611013            0.069307                0.801381
# 611014            0.067384                0.770210
# 611015            0.051836                0.518247
# 611016            0.054401                0.559808
# 611017            0.036449                0.268881
#
#         RAE Mobile Phone Charger Energy
# 0                              0.000431
# 1                              0.000215
# 2                              0.000236
# 3                              0.000211
# 4                              0.000221
# ...                                 ...
# 611013                         0.002441
# 611014                         0.002348
# 611015                         0.001601
# 611016                         0.001724
# 611017                         0.000861
#
# [611018 rows x 9 columns]

# %%
if 'Unnamed: 0' in consumption_df.columns:
    consumption_df.drop('Unnamed: 0',axis=1, inplace = True)

# %%
consumption_df
# Out:
#                   timestamp  energy_kWh  House Number  \
# 0       2012-06-01 01:00:00      1.0110             1
# 1       2012-06-01 02:00:00      0.4510             1
# 2       2012-06-01 03:00:00      0.5050             1
# 3       2012-06-01 04:00:00      0.4410             1
# 4       2012-06-01 05:00:00      0.4680             1
# ...                     ...         ...           ...
# 611013  2020-05-19 19:00:00      3.5802            28
# 611014  2020-05-19 20:00:00      3.4398            28
# 611015  2020-05-19 21:00:00      2.3049            28
# 611016  2020-05-19 22:00:00      2.4921            28
# 611017  2020-05-19 23:00:00      1.1817            28
#
#         electronics workbench energy  network equipment energy  \
# 0                           0.008686                  0.019316
# 1                           0.007178                  0.019338
# 2                           0.007324                  0.019336
# 3                           0.007151                  0.019339
# 4                           0.007224                  0.019338
# ...                              ...                       ...
# 611013                      0.028408                  0.038470
# 611014                      0.027762                  0.038479
# 611015                      0.022537                  0.038556
# 611016                      0.023399                  0.038544
# 611017                      0.017367                  0.038632
#
#         home office energy  RAE home office energy  \
# 0                 0.018232                0.134570
# 1                 0.013745                0.061839
# 2                 0.014177                0.068852
# 3                 0.013664                0.060540
# 4                 0.013881                0.064047
# ...                    ...                     ...
# 611013            0.069307                0.801381
# 611014            0.067384                0.770210
# 611015            0.051836                0.518247
# 611016            0.054401                0.559808
# 611017            0.036449                0.268881
#
#         RAE Mobile Phone Charger Energy
# 0                              0.000431
# 1                              0.000215
# 2                              0.000236
# 3                              0.000211
# 4                              0.000221
# ...                                 ...
# 611013                         0.002441
# 611014                         0.002348
# 611015                         0.001601
# 611016                         0.001724
# 611017                         0.000861
#
# [611018 rows x 8 columns]

# %% [markdown]
# #### Converting Dataset to House-wise dictionary

# %%
house_wise_consumption = dict()
for house_number in consumption_df['House Number'].unique():
    house_data = consumption_df[consumption_df['House Number'] == house_number]
    house_wise_consumption[house_number] = house_data.copy()
house_wise_consumption[1]
# house_wise_consumption[14]['timestamp'].iloc[0]
# house_wise_consumption[14]['timestamp'].iloc[-1]
# house_wise_consumption[14]['House Number'].iloc[0]
# Out:
#                  timestamp  energy_kWh  House Number  \
# 0      2012-06-01 01:00:00       1.011             1
# 1      2012-06-01 02:00:00       0.451             1
# 2      2012-06-01 03:00:00       0.505             1
# 3      2012-06-01 04:00:00       0.441             1
# 4      2012-06-01 05:00:00       0.468             1
# ...                    ...         ...           ...
# 29226  2015-10-02 20:00:00       2.101             1
# 29227  2015-10-02 21:00:00       1.646             1
# 29228  2015-10-02 22:00:00       1.319             1
# 29229  2015-10-02 23:00:00       1.473             1
# 29230  2015-10-03 00:00:00       0.800             1
#
#        electronics workbench energy  network equipment energy  \
# 0                          0.008686                  0.019316
# 1                          0.007178                  0.019338
# 2                          0.007324                  0.019336
# 3                          0.007151                  0.019339
# 4                          0.007224                  0.019338
# ...                             ...                       ...
# 29226                      0.011621                  0.019273
# 29227                      0.010396                  0.019291
# 29228                      0.009516                  0.019304
# 29229                      0.009930                  0.019298
# 29230                      0.008118                  0.019324
#
#        home office energy  RAE home office energy  \
# 0                0.018232                0.134570
# 1                0.013745                0.061839
# 2                0.014177                0.068852
# 3                0.013664                0.060540
# 4                0.013881                0.064047
# ...                   ...                     ...
# 29226            0.026968                0.276137
# 29227            0.023322                0.217043
# 29228            0.020701                0.174573
# 29229            0.021935                0.194574
# 29230            0.016541                0.107166
#
#        RAE Mobile Phone Charger Energy
# 0                             0.000431
# 1                             0.000215
# 2                             0.000236
# 3                             0.000211
# 4                             0.000221
# ...                                ...
# 29226                         0.000851
# 29227                         0.000675
# 29228                         0.000549
# 29229                         0.000609
# 29230                         0.000349
#
# [29231 rows x 8 columns]

# %%
# TODO: Print the usage pattern in form of a graph
# Each cluster represents one line in the time series graph
# Plot november consumption (2017) values for each house belonging to the same cluster in a single graph
# Also plot for the whole year (annual 2017) for each house belonging to the same cluster in a single graph

# %% [markdown]
# #### Comparing Timestamps for clustering

# %%
timestamp_comparison = list()
for house in house_wise_consumption:
    first_timestamp = house_wise_consumption[house]['timestamp'].iloc[0]
    last_timestamp = house_wise_consumption[house]['timestamp'].iloc[-1]
    timestamp_comparison.append([house, first_timestamp, last_timestamp])
timestamp_comparison
timestamp_comparison_df = pd.DataFrame(timestamp_comparison, columns = ['House', 'First Timestamp', 'Last Timestamp'])
timestamp_comparison_df
# Out:
#     House      First Timestamp       Last Timestamp
# 0       1  2012-06-01 01:00:00  2015-10-03 00:00:00
# 1       2  2016-06-09 00:00:00  2019-11-20 23:00:00
# 2       3  2015-01-27 00:00:00  2018-01-29 23:00:00
# 3       4  2015-01-30 00:00:00  2018-01-29 23:00:00
# 4       5  2015-01-30 00:00:00  2018-01-29 23:00:00
# 5       6  2015-01-30 00:00:00  2018-01-29 23:00:00
# 6       7  2015-05-30 00:00:00  2018-01-29 23:00:00
# 7       8  2015-02-21 00:00:00  2018-02-20 23:00:00
# 8       9  2015-05-01 00:00:00  2018-02-21 23:00:00
# 9      10  2015-02-21 00:00:00  2018-02-20 23:00:00
# 10     11  2015-02-21 00:00:00  2018-02-20 23:00:00
# 11     12  2015-02-21 00:00:00  2018-02-20 23:00:00
# 12     13  2015-02-21 00:00:00  2018-02-20 23:00:00
# 13     14  2015-02-21 00:00:00  2018-02-20 23:00:00
# 14     15  2015-09-29 00:00:00  2018-02-20 23:00:00
# 15     16  2017-11-01 00:00:00  2019-02-18 23:00:00
# 16     17  2016-06-01 00:00:00  2017-04-29 23:00:00
# 17     18  2015-03-16 00:00:00  2018-03-15 16:00:00
# 18     19  2015-03-26 00:00:00  2018-03-25 23:00:00
# 19     20  2015-08-21 00:00:00  2018-04-20 23:00:00
# 20     21  2017-11-01 00:00:00  2018-06-04 23:00:00
# 21     22  2016-06-29 00:00:00  2018-06-05 23:00:00
# 22     23  2017-07-27 00:00:00  2020-04-05 23:00:00
# 23     24  2017-05-13 00:00:00  2020-05-12 23:00:00
# 24     25  2017-05-15 00:00:00  2020-05-14 23:00:00
# 25     26  2019-11-29 00:00:00  2020-05-20 23:00:00
# 26     27  2019-03-06 00:00:00  2020-05-20 23:00:00
# 27     28  2018-08-01 00:00:00  2020-05-19 23:00:00

# %%
# houses_with_ts = []
# sample_timestamp = '2017-11-01 00:00:00'
# for house in house_wise_consumption:
#     if sample_timestamp in house_wise_consumption[house]['timestamp'].unique():
#         houses_with_ts.append(house)
# len(houses_with_ts)
#house_wise_consumption[8][house_wise_consumption[8]['timestamp'] >= '2017-11-17'].head(60)

# %% [markdown]
# #### Creating a november consumption dictionary of dataframes

# %%
# november_consumption = dict()
# for house in house_wise_consumption:
#     house_november_consumption = house_wise_consumption[house][(house_wise_consumption[house]['timestamp'] <= '2017-11-25') & (house_wise_consumption[house]['timestamp'] >= '2017-11-01')]
#     november_consumption[house] = house_november_consumption.copy()
#     november_consumption[house].drop_duplicates(subset='timestamp', keep="last", inplace = True)
# def calculate_rows():
#     november_rows = []
#     for house in november_consumption:
#         november_rows.append([house, len(november_consumption[house])])
#     november_rows
#     november_rows_df = pd.DataFrame(november_rows, columns = ['House', 'Rows'])
#     return november_rows_df
# def calculate_incomplete_rows():
#     november_rows_df = calculate_rows()
#     november_rows_incomplete_df = november_rows_df[(november_rows_df['Rows'] > 0) & (november_rows_df['Rows'] < 576)]
#     return november_rows_incomplete_df
# def fill_na_november_consumption(complete_df, incomplete_df):
#     complete_df = complete_df.copy()
#     year_incomplete = pd.Timestamp(incomplete_df.iloc[0]['timestamp']).year
#     year_complete = pd.Timestamp(complete_df.iloc[0]['timestamp']).year
#     complete_df['timestamp'] = complete_df['timestamp'].str.replace(str(year_complete), str(year_incomplete))
#     fill_missing_values = complete_df[~complete_df.timestamp.isin(incomplete_df.timestamp)].copy()
#     #print(fill_missing_values)
#     fill_columns = ['energy_kWh', 'electronics workbench energy', 'network equipment energy', 'home office energy', 'RAE home office energy','RAE Mobile Phone Charger Energy']
#     for fill_column in fill_columns:
#         fill_missing_values[fill_column] = incomplete_df[fill_column].mean()
#     incomplete_df = pd.concat([incomplete_df, fill_missing_values])
#     incomplete_df = incomplete_df.sort_values(by=['timestamp'])
#     return incomplete_df
# def calculate_missing_november_rows():
#     november_rows_df = calculate_rows()
#     november_rows_missing_df = november_rows_df[(november_rows_df['Rows'] == 0)]
#     return november_rows_missing_df
# calculate_rows()

# %%
# for house in list(calculate_incomplete_rows()['House']):
#     november_consumption[house] = fill_na_november_consumption(november_consumption[10], november_consumption[house])

# %% [markdown]
# ##### Houses with no november-17 consumption values

# %%
# timestamp_comparison_df.set_index('House').join(calculate_missing_november_rows().set_index('House'), how='inner')

# %%
# missing_november_houses_dates = {
#     1: ['2014-11-25', '2014-11-01'],
#     17: ['2016-11-25', '2016-11-01'],
#     26: ['2019-11-25', '2019-11-01'],
#     27: ['2019-11-25', '2019-11-01'],
#     28: ['2019-11-25', '2019-11-01'],
# }

# %%
# for house in missing_november_houses_dates:
#     house_november_consumption = house_wise_consumption[house][(house_wise_consumption[house]['timestamp'] <= missing_november_houses_dates[house][0]) & (house_wise_consumption[house]['timestamp'] >= missing_november_houses_dates[house][1])]
#     #print((house, missing_november_houses_dates[house][0]))
#     november_consumption[house] = house_november_consumption.copy()
#     november_consumption[house].drop_duplicates(subset='timestamp', keep="last", inplace = True)

# %% [markdown]
# ##### Filling missing values for november consumption

# %%
# calculate_incomplete_rows()

# %%
# for house in list(calculate_incomplete_rows()['House']):
#     november_consumption[house] = fill_na_november_consumption(november_consumption[10], november_consumption[house])

# %%
#calculate_rows()november_consumption

# %% [markdown]
# #### Houses to be clustered

# %%
# ##print('Houses to be clustered: ')
# clustered_df = calculate_rows()[calculate_rows()['Rows'] ==  576]
# clustered_df

# %% [markdown]
# #### Converting to clustering matrix

# %%
# clustering_matrix = []
# for house in calculate_rows()[calculate_rows()['Rows'] ==  576]['House']:
#     clustering_matrix.append(np.array(november_consumption[house]['energy_kWh']).reshape(-1,1))
# clustering_matrix = np.array(clustering_matrix)
# clustering_matrix.shape

# %% [markdown]
# #### Time series clustering of all households except house 26

# %%
# km_sdtw = TimeSeriesKMeans(n_clusters=4, metric="softdtw", max_iter=5,
#                             max_iter_barycenter=5,
#                             metric_params={"gamma": .5},
#                             random_state=0).fit_predict(clustering_matrix)

# %%
# len(km_sdtw)

# %%
# clustered_df['Cluster'] = km_sdtw

# %%
#clustered_df = clustered_df[['House', 'Cluster']].set_index('House')
# clustered_df[clustered_df['Cluster'] == 3]

# %%
clustered_df = pd.read_csv('Tables/clustered.csv')
clustered_df
# Out:
#     House  Cluster
# 0       2        3
# 1       3        2
# 2       4        2
# 3       5        2
# 4       6        3
# 5       7        2
# 6       8        2
# 7       9        2
# 8      10        2
# 9      11        2
# 10     12        2
# 11     13        2
# 12     14        0
# 13     15        1
# 14     18        0
# 15     19        2
# 16     20        2
# 17     22        3
# 18     23        3
# 19     24        3
# 20     25        2

# %% [markdown]
# #### Used Scenarios

# %%
data = [[1, 4, 6, 'Yes'], [2, 1, 6, 'Yes'], [3, 4, 1, 'No'], [4, 1, 1, 'No']]
df = pd.DataFrame(data, columns = ['Scenarios', 'No. of subsets', 'No. of features', 'Smart devices included in modeling?']).set_index('Scenarios')
df
# Out:
#            No. of subsets  No. of features Smart devices included in modeling?
# Scenarios
# 1                       4                6                                 Yes
# 2                       1                6                                 Yes
# 3                       4                1                                  No
# 4                       1                1                                  No

# %% [markdown]
# #### Time-series LSTM-based predictive modeling

# %%
n_past = 12
n_future = 1

# %%
### Energy generation dataframe
generation_df = pd.read_csv('Final Datasets/energy_generation.csv')
generation_df
# Out:
#                  timestamp  Wind Energy  Solar Energy
# 0      2012-01-01 00:00:00     0.168265           0.0
# 1      2012-01-01 01:00:00     0.168265           0.0
# 2      2012-01-01 02:00:00     0.168265           0.0
# 3      2012-01-01 03:00:00     0.168265           0.0
# 4      2012-01-01 04:00:00     0.168265           0.0
# ...                    ...          ...           ...
# 78907  2020-12-31 19:00:00     1.710441           0.0
# 78908  2020-12-31 20:00:00     1.710441           0.0
# 78909  2020-12-31 21:00:00     1.497873           0.0
# 78910  2020-12-31 22:00:00     1.285454           0.0
# 78911  2020-12-31 23:00:00     1.286778           0.0
#
# [78912 rows x 3 columns]

# %%
class House:
    cols = ['energy_kWh', 'electronics workbench energy', 'network equipment energy',
            'home office energy', 'RAE home office energy', 'RAE Mobile Phone Charger Energy']
    def __init__(self, house):
        self.house = house
        self.consumption_df = house_wise_consumption[house].copy()[House.cols].astype(float)
        self.train_dates_df = house_wise_consumption[house]['timestamp']
        self.prepare_dataset(n_future, n_past)
    
    def __repr__(self):
        return str(self.house)
    
    def prepare_dataset(self, n_future = 1, n_past = 12):
        #Empty lists to be populated using formatted training data
        trainX = []
        trainY = []
        consumption_np = np.array(self.consumption_df)
        #Reformat input data into a shape: (n_samples x timesteps x n_features)
        #In my example, my self.consumption_df has a shape (12823, 5)
        #12823 refers to the number of data points and 5 refers to the columns (multi-variables).
        for i in range(n_past, len(consumption_np) - n_future +1):
            trainX.append(consumption_np[i - n_past:i, 0:self.consumption_df.shape[1]])
            trainY.append(consumption_np[i + n_future - 1:i + n_future, 0])

        trainX, trainY = np.array(trainX), np.array(trainY)

        #print('trainX shape == {}.'.format(trainX.shape))
        #print('trainY shape == {}.'.format(trainY.shape))
        self.trainX = trainX
        self.trainY = trainY

class Cluster: 
    def __init__(self, houses):
        self.houses = [House(house) for house in houses]
        self.trainX_list = (list(map(lambda x: x.trainX, self.houses)))
        self.trainY_list = (list(map(lambda x: x.trainY, self.houses)))
        self.train_dates_list = (list(map(lambda x: x.train_dates_df, self.houses)))
        self.consumption_df_list = (list(map(lambda x: x.consumption_df, self.houses)))
        self.prepare_dataset()
        
    
    def prepare_dataset(self):
        
        self.train_dates = np.concatenate(self.train_dates_list, axis=0)
        ## TODO - Replace concatenate with for loop or sort by time
        self.X = np.concatenate(self.trainX_list, axis=0)
        self.Y = np.concatenate(self.trainY_list, axis=0)
    
    
    def prepare_ANN_model(self):
        model = Sequential()
        #model.add(Dense(1, activation='relu', input_shape=(self.X.shape[1], self.X.shape[2])))
        model.add(Dense(128, activation='relu', input_shape=(self.X.shape[1], self.X.shape[2]), return_sequences=True))
        model.add(Dense(32, activation='relu', return_sequences=True))
        model.add(Dense(16, activation='relu', return_sequences=False))
        model.add(Dense(self.Y.shape[1]))
        model.compile(optimizer='adam', loss='mse', metrics=[tf.keras.metrics.RootMeanSquaredError(), tf.keras.metrics.MeanAbsoluteError()])
        model.summary()
        return model
    
    def prepare_RNN_model(self):
        model = Sequential()
        #model.add(SimpleRNN(1, activation='relu', input_shape=(self.X.shape[1], self.X.shape[2]), return_sequences=True))
        model.add(SimpleRNN(128, activation='relu', input_shape=(self.X.shape[1], self.X.shape[2]), return_sequences=True))
        model.add(SimpleRNN(32, activation='relu', return_sequences=True))
        model.add(SimpleRNN(16, activation='relu', return_sequences=False))
        model.add(Dense(self.Y.shape[1]))
        model.compile(optimizer='adam', loss='mse', metrics=[tf.keras.metrics.RootMeanSquaredError(), tf.keras.metrics.MeanAbsoluteError(), tf.keras.metrics.MeanAbsolutePercentageError(), tf.keras.metrics.MeanSquaredError()])
        model.summary()
        return model
    
    def prepare_LSTM_model(self):
        model = Sequential()
        #model.add(LSTM(1, activation='relu', input_shape=(self.X.shape[1], self.X.shape[2]), return_sequences=True))
        model.add(LSTM(128, activation='tanh',recurrent_activation = 'sigmoid',recurrent_dropout=0.0,unroll=False,use_bias=True, input_shape=(self.X.shape[1], self.X.shape[2]), return_sequences=True))
        model.add(LSTM(32, activation='tanh',recurrent_activation = 'sigmoid',recurrent_dropout=0.0,unroll=False,use_bias=True, return_sequences=True))
        model.add(LSTM(16, activation='tanh',recurrent_activation = 'sigmoid',recurrent_dropout=0.0,unroll=False,use_bias=True, return_sequences=False))
        model.add(Dense(self.Y.shape[1]))
        model.compile(optimizer='adam', loss='mse', metrics=[tf.keras.metrics.RootMeanSquaredError(), tf.keras.metrics.MeanAbsoluteError(), tf.keras.metrics.MeanAbsolutePercentageError(), tf.keras.metrics.MeanSquaredError()])
        model.summary()
        return model
    
    def train_model(self, model_name='LSTM'):
        if model_name == 'LSTM':
            model = self.prepare_LSTM_model()
        if model_name == 'RNN':
            model = self.prepare_RNN_model()    
        if model_name == 'ANN':
            model = self.prepare_ANN_model()    
        history = model.fit(self.X, self.Y, epochs=10, batch_size=16, validation_split=0.3, verbose=1) # Change to 30
        self.history = history
        plt.plot(history.history['loss'], label='Training loss')
        plt.plot(history.history['val_loss'], label='Testing loss')
        
        plt.legend()
        return model
    
    def predicted(self, model_name='LSTM'):
        model = self.train_model(model_name)
        predictions = list(map(lambda x: pd.Series(model.predict(x).reshape(1,-1)[0]), self.trainX_list))
        #return pd.Series(model.predict(self.X).reshape(1,-1)[0])
        self.model = model
        return dict(zip(self.houses, predictions))
    
    def results(self, model_name='LSTM'):
        predicted = self.predicted(model_name)
        house_prediction_list_df  = {}
        for house in predicted:
            house_prediction_df = house.consumption_df.iloc[n_past:].copy().reset_index(drop=True)
            house_prediction_df['timestamp'] = house.train_dates_df.iloc[n_past:].copy().reset_index(drop=True)
            house_prediction_df['energy_predicted'] = predicted[house]
            ### Anomaly Detection
            energy_stddev = house_prediction_df['energy_kWh'].std()
            house_prediction_df['Energy Consumption Error'] = house_prediction_df['energy_predicted'] - house_prediction_df['energy_kWh']
            house_prediction_df['Anomaly detected'] = house_prediction_df['Energy Consumption Error'].apply(lambda x: False if abs(x) < 1.5*energy_stddev else abs(x))
            ### Energy Deficit Calculation
            house_prediction_df['timestamp'] = pd.DatetimeIndex(house_prediction_df['timestamp'])
            generation_df['timestamp'] = pd.DatetimeIndex(generation_df['timestamp'])
            house_prediction_df = house_prediction_df.set_index('timestamp').join(generation_df.set_index('timestamp'))
            house_prediction_df['timestamp'] = house_prediction_df.index
            house_prediction_df.reset_index(drop=True, inplace=True)
            house_prediction_df['Total Generated Energy'] = house_prediction_df['Wind Energy']+ house_prediction_df['Solar Energy']
            house_prediction_df['Predicted Energy Deficit'] = house_prediction_df['Total Generated Energy'] - house_prediction_df['energy_predicted']
            house_prediction_df['Energy Deficit Flag'] = house_prediction_df['Predicted Energy Deficit'].apply(lambda x: False if x>0 else abs(x))
            house_prediction_list_df[house.house] = house_prediction_df
        return house_prediction_list_df

# %% [markdown]
# ## Model Name

# %%
model_name='HYBRID'

# %% [markdown]
# #### Scenario 1

# %%
# Train the time series model, perform predictions and answer the three research questions
zero_houses = list(clustered_df[clustered_df['Cluster'] == 0]['House'])
print(zero_houses)
zero_cluster = Cluster(zero_houses)
zero_cluster_results = zero_cluster.results(model_name)
print('Training History for Cluster 0:')
# Out:
# [14, 18]
# 2022-05-30 00:14:47.593142: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-05-30 00:14:47.593167: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-05-30 00:14:47.593185: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (rishabh-Inspiron): /proc/driver/nvidia/version does not exist
# 2022-05-30 00:14:47.593402: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 12, 128)           69120
#
#  lstm_1 (LSTM)               (None, 12, 32)            20608
#
#  lstm_2 (LSTM)               (None, 16)                3136
#
#  dense (Dense)               (None, 1)                 17
#
# =================================================================
# Total params: 92,881
# Trainable params: 92,881
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 2279/2279 [==============================] - 36s 14ms/step - loss: 0.7046 - root_mean_squared_error: 0.8394 - mean_absolute_error: 0.4978 - mean_absolute_percentage_error: 246924.3281 - mean_squared_error: 0.7046 - val_loss: 1.3749 - val_root_mean_squared_error: 1.1726 - val_mean_absolute_error: 0.6045 - val_mean_absolute_percentage_error: 285204.3438 - val_mean_squared_error: 1.3749
# Epoch 2/10
# 2279/2279 [==============================] - 34s 15ms/step - loss: 0.6307 - root_mean_squared_error: 0.7942 - mean_absolute_error: 0.4605 - mean_absolute_percentage_error: 180721.6562 - mean_squared_error: 0.6307 - val_loss: 1.3275 - val_root_mean_squared_error: 1.1522 - val_mean_absolute_error: 0.6226 - val_mean_absolute_percentage_error: 247975.8438 - val_mean_squared_error: 1.3275
# Epoch 3/10
# 2279/2279 [==============================] - 34s 15ms/step - loss: 0.6169 - root_mean_squared_error: 0.7854 - mean_absolute_error: 0.4537 - mean_absolute_percentage_error: 154919.8750 - mean_squared_error: 0.6169 - val_loss: 1.3248 - val_root_mean_squared_error: 1.1510 - val_mean_absolute_error: 0.5989 - val_mean_absolute_percentage_error: 246474.1719 - val_mean_squared_error: 1.3248
# Epoch 4/10
# 2279/2279 [==============================] - 34s 15ms/step - loss: 0.6126 - root_mean_squared_error: 0.7827 - mean_absolute_error: 0.4516 - mean_absolute_percentage_error: 139143.7656 - mean_squared_error: 0.6126 - val_loss: 1.2613 - val_root_mean_squared_error: 1.1231 - val_mean_absolute_error: 0.6060 - val_mean_absolute_percentage_error: 234061.1875 - val_mean_squared_error: 1.2613
# Epoch 5/10
# 2279/2279 [==============================] - 34s 15ms/step - loss: 0.6095 - root_mean_squared_error: 0.7807 - mean_absolute_error: 0.4483 - mean_absolute_percentage_error: 155845.4219 - mean_squared_error: 0.6095 - val_loss: 1.2620 - val_root_mean_squared_error: 1.1234 - val_mean_absolute_error: 0.5995 - val_mean_absolute_percentage_error: 253814.7500 - val_mean_squared_error: 1.2620
# Epoch 6/10
# 2279/2279 [==============================] - 34s 15ms/step - loss: 0.6064 - root_mean_squared_error: 0.7787 - mean_absolute_error: 0.4465 - mean_absolute_percentage_error: 152548.9688 - mean_squared_error: 0.6064 - val_loss: 1.2807 - val_root_mean_squared_error: 1.1317 - val_mean_absolute_error: 0.5810 - val_mean_absolute_percentage_error: 233291.6719 - val_mean_squared_error: 1.2807
# Epoch 7/10
# 2279/2279 [==============================] - 34s 15ms/step - loss: 0.6027 - root_mean_squared_error: 0.7764 - mean_absolute_error: 0.4457 - mean_absolute_percentage_error: 134819.6406 - mean_squared_error: 0.6027 - val_loss: 1.3108 - val_root_mean_squared_error: 1.1449 - val_mean_absolute_error: 0.5650 - val_mean_absolute_percentage_error: 165603.2969 - val_mean_squared_error: 1.3108
# Epoch 8/10
# 2279/2279 [==============================] - 34s 15ms/step - loss: 0.6013 - root_mean_squared_error: 0.7754 - mean_absolute_error: 0.4438 - mean_absolute_percentage_error: 145658.4531 - mean_squared_error: 0.6013 - val_loss: 1.2732 - val_root_mean_squared_error: 1.1284 - val_mean_absolute_error: 0.6335 - val_mean_absolute_percentage_error: 222595.8594 - val_mean_squared_error: 1.2732
# Epoch 9/10
# 2279/2279 [==============================] - 34s 15ms/step - loss: 0.5988 - root_mean_squared_error: 0.7738 - mean_absolute_error: 0.4425 - mean_absolute_percentage_error: 146394.1562 - mean_squared_error: 0.5988 - val_loss: 1.2903 - val_root_mean_squared_error: 1.1359 - val_mean_absolute_error: 0.5898 - val_mean_absolute_percentage_error: 210009.9062 - val_mean_squared_error: 1.2903
# Epoch 10/10
# 2279/2279 [==============================] - 34s 15ms/step - loss: 0.5952 - root_mean_squared_error: 0.7715 - mean_absolute_error: 0.4421 - mean_absolute_percentage_error: 150673.6719 - mean_squared_error: 0.5952 - val_loss: 1.2952 - val_root_mean_squared_error: 1.1381 - val_mean_absolute_error: 0.6200 - val_mean_absolute_percentage_error: 251441.2969 - val_mean_squared_error: 1.2952
# Training History for Cluster 0:

# %%
one_houses = list(clustered_df[clustered_df['Cluster'] == 1]['House'])
one_cluster = Cluster(one_houses)
one_cluster_results = one_cluster.results(model_name)
print('Training History for Cluster 1:')
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_3 (LSTM)               (None, 12, 128)           69120
#
#  lstm_4 (LSTM)               (None, 12, 32)            20608
#
#  lstm_5 (LSTM)               (None, 16)                3136
#
#  dense_1 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 92,881
# Trainable params: 92,881
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 915/915 [==============================] - 18s 16ms/step - loss: 1.3856 - root_mean_squared_error: 1.1771 - mean_absolute_error: 0.6939 - mean_absolute_percentage_error: 89.1265 - mean_squared_error: 1.3856 - val_loss: 1.5585 - val_root_mean_squared_error: 1.2484 - val_mean_absolute_error: 0.6667 - val_mean_absolute_percentage_error: 106.6072 - val_mean_squared_error: 1.5585
# Epoch 2/10
# 915/915 [==============================] - 14s 15ms/step - loss: 0.9107 - root_mean_squared_error: 0.9543 - mean_absolute_error: 0.5535 - mean_absolute_percentage_error: 70.5137 - mean_squared_error: 0.9107 - val_loss: 1.4712 - val_root_mean_squared_error: 1.2129 - val_mean_absolute_error: 0.5797 - val_mean_absolute_percentage_error: 79.1418 - val_mean_squared_error: 1.4712
# Epoch 3/10
# 915/915 [==============================] - 14s 15ms/step - loss: 0.8496 - root_mean_squared_error: 0.9217 - mean_absolute_error: 0.5292 - mean_absolute_percentage_error: 66.4342 - mean_squared_error: 0.8496 - val_loss: 1.4949 - val_root_mean_squared_error: 1.2227 - val_mean_absolute_error: 0.5736 - val_mean_absolute_percentage_error: 78.8470 - val_mean_squared_error: 1.4949
# Epoch 4/10
# 915/915 [==============================] - 14s 15ms/step - loss: 0.8396 - root_mean_squared_error: 0.9163 - mean_absolute_error: 0.5224 - mean_absolute_percentage_error: 64.8315 - mean_squared_error: 0.8396 - val_loss: 1.1083 - val_root_mean_squared_error: 1.0528 - val_mean_absolute_error: 0.5355 - val_mean_absolute_percentage_error: 81.9593 - val_mean_squared_error: 1.1083
# Epoch 5/10
# 915/915 [==============================] - 14s 15ms/step - loss: 0.8275 - root_mean_squared_error: 0.9097 - mean_absolute_error: 0.5151 - mean_absolute_percentage_error: 63.5858 - mean_squared_error: 0.8275 - val_loss: 1.1879 - val_root_mean_squared_error: 1.0899 - val_mean_absolute_error: 0.6089 - val_mean_absolute_percentage_error: 113.3698 - val_mean_squared_error: 1.1879
# Epoch 6/10
# 915/915 [==============================] - 14s 15ms/step - loss: 0.7987 - root_mean_squared_error: 0.8937 - mean_absolute_error: 0.5071 - mean_absolute_percentage_error: 62.1146 - mean_squared_error: 0.7987 - val_loss: 1.1692 - val_root_mean_squared_error: 1.0813 - val_mean_absolute_error: 0.5270 - val_mean_absolute_percentage_error: 72.6950 - val_mean_squared_error: 1.1692
# Epoch 7/10
# 915/915 [==============================] - 14s 15ms/step - loss: 0.7885 - root_mean_squared_error: 0.8879 - mean_absolute_error: 0.5027 - mean_absolute_percentage_error: 61.3730 - mean_squared_error: 0.7885 - val_loss: 1.1508 - val_root_mean_squared_error: 1.0727 - val_mean_absolute_error: 0.5242 - val_mean_absolute_percentage_error: 74.5532 - val_mean_squared_error: 1.1508
# Epoch 8/10
# 915/915 [==============================] - 14s 15ms/step - loss: 0.7677 - root_mean_squared_error: 0.8762 - mean_absolute_error: 0.4946 - mean_absolute_percentage_error: 60.8538 - mean_squared_error: 0.7677 - val_loss: 1.1832 - val_root_mean_squared_error: 1.0878 - val_mean_absolute_error: 0.5433 - val_mean_absolute_percentage_error: 81.9328 - val_mean_squared_error: 1.1832
# Epoch 9/10
# 915/915 [==============================] - 14s 15ms/step - loss: 0.7711 - root_mean_squared_error: 0.8781 - mean_absolute_error: 0.4962 - mean_absolute_percentage_error: 60.8518 - mean_squared_error: 0.7711 - val_loss: 1.1256 - val_root_mean_squared_error: 1.0609 - val_mean_absolute_error: 0.5462 - val_mean_absolute_percentage_error: 86.1391 - val_mean_squared_error: 1.1256
# Epoch 10/10
# 915/915 [==============================] - 14s 15ms/step - loss: 0.7449 - root_mean_squared_error: 0.8631 - mean_absolute_error: 0.4881 - mean_absolute_percentage_error: 59.1179 - mean_squared_error: 0.7449 - val_loss: 1.1478 - val_root_mean_squared_error: 1.0713 - val_mean_absolute_error: 0.5600 - val_mean_absolute_percentage_error: 90.0735 - val_mean_squared_error: 1.1478
# Training History for Cluster 1:

# %%
two_houses = list(clustered_df[clustered_df['Cluster'] == 2]['House'])
two_cluster = Cluster(two_houses)
two_cluster_results = two_cluster.results(model_name)
print('Training History for Cluster 2:')
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_6 (LSTM)               (None, 12, 128)           69120
#
#  lstm_7 (LSTM)               (None, 12, 32)            20608
#
#  lstm_8 (LSTM)               (None, 16)                3136
#
#  dense_2 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 92,881
# Trainable params: 92,881
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 14537/14537 [==============================] - 224s 15ms/step - loss: 0.2240 - root_mean_squared_error: 0.4733 - mean_absolute_error: 0.2793 - mean_absolute_percentage_error: 270692.0312 - mean_squared_error: 0.2240 - val_loss: 0.2755 - val_root_mean_squared_error: 0.5249 - val_mean_absolute_error: 0.3092 - val_mean_absolute_percentage_error: 74350.6094 - val_mean_squared_error: 0.2755
# Epoch 2/10
# 14537/14537 [==============================] - 221s 15ms/step - loss: 0.2156 - root_mean_squared_error: 0.4643 - mean_absolute_error: 0.2702 - mean_absolute_percentage_error: 200287.8125 - mean_squared_error: 0.2156 - val_loss: 0.2776 - val_root_mean_squared_error: 0.5268 - val_mean_absolute_error: 0.3230 - val_mean_absolute_percentage_error: 81327.8672 - val_mean_squared_error: 0.2776
# Epoch 3/10
# 14537/14537 [==============================] - 221s 15ms/step - loss: 0.2126 - root_mean_squared_error: 0.4611 - mean_absolute_error: 0.2673 - mean_absolute_percentage_error: 202176.0469 - mean_squared_error: 0.2126 - val_loss: 0.2740 - val_root_mean_squared_error: 0.5234 - val_mean_absolute_error: 0.3113 - val_mean_absolute_percentage_error: 83518.9219 - val_mean_squared_error: 0.2740
# Epoch 4/10
# 14537/14537 [==============================] - 224s 15ms/step - loss: 0.2108 - root_mean_squared_error: 0.4591 - mean_absolute_error: 0.2657 - mean_absolute_percentage_error: 169345.6719 - mean_squared_error: 0.2108 - val_loss: 0.2756 - val_root_mean_squared_error: 0.5250 - val_mean_absolute_error: 0.3199 - val_mean_absolute_percentage_error: 82562.4453 - val_mean_squared_error: 0.2756
# Epoch 5/10
# 14537/14537 [==============================] - 225s 15ms/step - loss: 0.2094 - root_mean_squared_error: 0.4576 - mean_absolute_error: 0.2645 - mean_absolute_percentage_error: 155165.8125 - mean_squared_error: 0.2094 - val_loss: 0.2747 - val_root_mean_squared_error: 0.5241 - val_mean_absolute_error: 0.3171 - val_mean_absolute_percentage_error: 79394.5859 - val_mean_squared_error: 0.2747
# Epoch 6/10
# 14537/14537 [==============================] - 225s 16ms/step - loss: 0.2081 - root_mean_squared_error: 0.4562 - mean_absolute_error: 0.2634 - mean_absolute_percentage_error: 149913.4062 - mean_squared_error: 0.2081 - val_loss: 0.2838 - val_root_mean_squared_error: 0.5327 - val_mean_absolute_error: 0.3138 - val_mean_absolute_percentage_error: 70747.1562 - val_mean_squared_error: 0.2838
# Epoch 7/10
# 14537/14537 [==============================] - 226s 16ms/step - loss: 0.2074 - root_mean_squared_error: 0.4554 - mean_absolute_error: 0.2626 - mean_absolute_percentage_error: 142205.0156 - mean_squared_error: 0.2074 - val_loss: 0.2749 - val_root_mean_squared_error: 0.5243 - val_mean_absolute_error: 0.3149 - val_mean_absolute_percentage_error: 75535.2656 - val_mean_squared_error: 0.2749
# Epoch 8/10
# 14537/14537 [==============================] - 226s 16ms/step - loss: 0.2064 - root_mean_squared_error: 0.4543 - mean_absolute_error: 0.2619 - mean_absolute_percentage_error: 156717.8438 - mean_squared_error: 0.2064 - val_loss: 0.2763 - val_root_mean_squared_error: 0.5256 - val_mean_absolute_error: 0.3111 - val_mean_absolute_percentage_error: 76467.2656 - val_mean_squared_error: 0.2763
# Epoch 9/10
# 14537/14537 [==============================] - 226s 16ms/step - loss: 0.2056 - root_mean_squared_error: 0.4534 - mean_absolute_error: 0.2612 - mean_absolute_percentage_error: 160487.2188 - mean_squared_error: 0.2056 - val_loss: 0.2743 - val_root_mean_squared_error: 0.5237 - val_mean_absolute_error: 0.3222 - val_mean_absolute_percentage_error: 77563.8281 - val_mean_squared_error: 0.2743
# Epoch 10/10
# 14537/14537 [==============================] - 227s 16ms/step - loss: 0.2048 - root_mean_squared_error: 0.4525 - mean_absolute_error: 0.2605 - mean_absolute_percentage_error: 143899.5156 - mean_squared_error: 0.2048 - val_loss: 0.2775 - val_root_mean_squared_error: 0.5268 - val_mean_absolute_error: 0.3132 - val_mean_absolute_percentage_error: 72421.7734 - val_mean_squared_error: 0.2775
# Training History for Cluster 2:

# %%
three_houses = list(clustered_df[clustered_df['Cluster'] == 3]['House'])
three_cluster = Cluster(three_houses)
three_cluster_results = three_cluster.results(model_name)
print('Training History for Cluster 3:')
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_9 (LSTM)               (None, 12, 128)           69120
#
#  lstm_10 (LSTM)              (None, 12, 32)            20608
#
#  lstm_11 (LSTM)              (None, 16)                3136
#
#  dense_3 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 92,881
# Trainable params: 92,881
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 5366/5366 [==============================] - 87s 16ms/step - loss: 0.1167 - root_mean_squared_error: 0.3417 - mean_absolute_error: 0.1798 - mean_absolute_percentage_error: 49591.3945 - mean_squared_error: 0.1167 - val_loss: 0.2133 - val_root_mean_squared_error: 0.4618 - val_mean_absolute_error: 0.2591 - val_mean_absolute_percentage_error: 60955.0977 - val_mean_squared_error: 0.2133
# Epoch 2/10
# 5366/5366 [==============================] - 83s 15ms/step - loss: 0.1124 - root_mean_squared_error: 0.3353 - mean_absolute_error: 0.1736 - mean_absolute_percentage_error: 38929.4180 - mean_squared_error: 0.1124 - val_loss: 0.2194 - val_root_mean_squared_error: 0.4684 - val_mean_absolute_error: 0.2445 - val_mean_absolute_percentage_error: 45217.5898 - val_mean_squared_error: 0.2194
# Epoch 3/10
# 5366/5366 [==============================] - 83s 15ms/step - loss: 0.1113 - root_mean_squared_error: 0.3336 - mean_absolute_error: 0.1719 - mean_absolute_percentage_error: 44966.2969 - mean_squared_error: 0.1113 - val_loss: 0.2149 - val_root_mean_squared_error: 0.4636 - val_mean_absolute_error: 0.2455 - val_mean_absolute_percentage_error: 45724.7383 - val_mean_squared_error: 0.2149
# Epoch 4/10
# 5366/5366 [==============================] - 84s 16ms/step - loss: 0.1102 - root_mean_squared_error: 0.3319 - mean_absolute_error: 0.1704 - mean_absolute_percentage_error: 51825.5078 - mean_squared_error: 0.1102 - val_loss: 0.2121 - val_root_mean_squared_error: 0.4605 - val_mean_absolute_error: 0.2500 - val_mean_absolute_percentage_error: 59961.2734 - val_mean_squared_error: 0.2121
# Epoch 5/10
# 5366/5366 [==============================] - 82s 15ms/step - loss: 0.1089 - root_mean_squared_error: 0.3300 - mean_absolute_error: 0.1691 - mean_absolute_percentage_error: 47568.9414 - mean_squared_error: 0.1089 - val_loss: 0.2163 - val_root_mean_squared_error: 0.4651 - val_mean_absolute_error: 0.2423 - val_mean_absolute_percentage_error: 45672.1992 - val_mean_squared_error: 0.2163
# Epoch 6/10
# 5366/5366 [==============================] - 82s 15ms/step - loss: 0.1078 - root_mean_squared_error: 0.3283 - mean_absolute_error: 0.1669 - mean_absolute_percentage_error: 44632.6562 - mean_squared_error: 0.1078 - val_loss: 0.2154 - val_root_mean_squared_error: 0.4641 - val_mean_absolute_error: 0.2471 - val_mean_absolute_percentage_error: 54528.9023 - val_mean_squared_error: 0.2154
# Epoch 7/10
# 5366/5366 [==============================] - 83s 15ms/step - loss: 0.1070 - root_mean_squared_error: 0.3271 - mean_absolute_error: 0.1656 - mean_absolute_percentage_error: 45971.0039 - mean_squared_error: 0.1070 - val_loss: 0.2211 - val_root_mean_squared_error: 0.4702 - val_mean_absolute_error: 0.2424 - val_mean_absolute_percentage_error: 47068.8828 - val_mean_squared_error: 0.2211
# Epoch 8/10
# 5366/5366 [==============================] - 83s 16ms/step - loss: 0.1059 - root_mean_squared_error: 0.3254 - mean_absolute_error: 0.1643 - mean_absolute_percentage_error: 43411.2695 - mean_squared_error: 0.1059 - val_loss: 0.2150 - val_root_mean_squared_error: 0.4637 - val_mean_absolute_error: 0.2440 - val_mean_absolute_percentage_error: 38228.4414 - val_mean_squared_error: 0.2150
# Epoch 9/10
# 5366/5366 [==============================] - 83s 15ms/step - loss: 0.1052 - root_mean_squared_error: 0.3244 - mean_absolute_error: 0.1636 - mean_absolute_percentage_error: 46709.5820 - mean_squared_error: 0.1052 - val_loss: 0.2176 - val_root_mean_squared_error: 0.4665 - val_mean_absolute_error: 0.2436 - val_mean_absolute_percentage_error: 38278.7383 - val_mean_squared_error: 0.2176
# Epoch 10/10
# 5366/5366 [==============================] - 83s 15ms/step - loss: 0.1045 - root_mean_squared_error: 0.3233 - mean_absolute_error: 0.1627 - mean_absolute_percentage_error: 44772.1016 - mean_squared_error: 0.1045 - val_loss: 0.2169 - val_root_mean_squared_error: 0.4657 - val_mean_absolute_error: 0.2545 - val_mean_absolute_percentage_error: 38146.9219 - val_mean_squared_error: 0.2169
# Training History for Cluster 3:

# %%
# four_houses = list(clustered_df[clustered_df['Cluster'] == 4]['House'])
# four_cluster = Cluster(four_houses)
# four_cluster_results = four_cluster.results(model_name)
# print('Training History for Cluster 4:')

# %%
## Save Scenario 1 models
zero_cluster.model.save(f'Models/Scenario1/{model_name}/zero_cluster')
one_cluster.model.save(f'Models/Scenario1/{model_name}/one_cluster')
two_cluster.model.save(f'Models/Scenario1/{model_name}/two_cluster')
three_cluster.model.save(f'Models/Scenario1/{model_name}/three_cluster')
# four_cluster.model.save(f'Models/Scenario1/{model_name}/four_cluster')

## Pickling cluster and cluster results
zero_cluster_file = open(f"Models/Scenario1/Objects/{model_name}/zero_cluster.pickle", "wb")
pickle.dump(zero_cluster, zero_cluster_file)
zero_cluster_file.close()

one_cluster_file = open(f"Models/Scenario1/Objects/{model_name}/one_cluster.pickle", "wb")
pickle.dump(one_cluster, one_cluster_file)
one_cluster_file.close()

two_cluster_file = open(f"Models/Scenario1/Objects/{model_name}/two_cluster.pickle", "wb")
pickle.dump(two_cluster, two_cluster_file)
two_cluster_file.close()

three_cluster_file = open(f"Models/Scenario1/Objects/{model_name}/three_cluster.pickle", "wb")
pickle.dump(three_cluster, three_cluster_file)
three_cluster_file.close()

# four_cluster_file = open(f"Models/Scenario1/Objects/{model_name}/four_cluster.pickle", "wb")
# pickle.dump(four_cluster, four_cluster_file)
# four_cluster_file.close()

zero_cluster_results_file = open(f"Models/Scenario1/Objects/{model_name}/zero_cluster_results.pickle", "wb")
pickle.dump(zero_cluster_results, zero_cluster_results_file)
zero_cluster_results_file.close()

one_cluster_results_file = open(f"Models/Scenario1/Objects/{model_name}/one_cluster_results.pickle", "wb")
pickle.dump(one_cluster_results, one_cluster_results_file)
one_cluster_results_file.close()

two_cluster_results_file = open(f"Models/Scenario1/Objects/{model_name}/two_cluster_results.pickle", "wb")
pickle.dump(two_cluster_results, two_cluster_results_file)
two_cluster_results_file.close()

three_cluster_results_file = open(f"Models/Scenario1/Objects/{model_name}/three_cluster_results.pickle", "wb")
pickle.dump(three_cluster_results, three_cluster_results_file)
three_cluster_results_file.close()

# four_cluster_results_file = open(f"Models/Scenario1/Objects/{model_name}/four_cluster_results.pickle", "wb")
# pickle.dump(four_cluster_results, four_cluster_results_file)
# four_cluster_results_file.close()
# Out:
# 2022-05-30 01:15:38.151304: W tensorflow/python/util/util.cc:368] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_2_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Models/Scenario1/LSTM/zero_cluster/assets
# INFO:tensorflow:Assets written to: Models/Scenario1/LSTM/zero_cluster/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7efc639560d0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7efc634b8550> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7efc63902c40> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:Found untraced functions such as lstm_cell_3_layer_call_fn, lstm_cell_3_layer_call_and_return_conditional_losses, lstm_cell_4_layer_call_fn, lstm_cell_4_layer_call_and_return_conditional_losses, lstm_cell_5_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Models/Scenario1/LSTM/one_cluster/assets
# INFO:tensorflow:Assets written to: Models/Scenario1/LSTM/one_cluster/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7efc63e37430> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7efc63e3f3d0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7efc63a40c70> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:Found untraced functions such as lstm_cell_6_layer_call_fn, lstm_cell_6_layer_call_and_return_conditional_losses, lstm_cell_7_layer_call_fn, lstm_cell_7_layer_call_and_return_conditional_losses, lstm_cell_8_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Models/Scenario1/LSTM/two_cluster/assets
# INFO:tensorflow:Assets written to: Models/Scenario1/LSTM/two_cluster/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7efc21fc2250> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7efc21fc9490> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7efc21f166d0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:Found untraced functions such as lstm_cell_9_layer_call_fn, lstm_cell_9_layer_call_and_return_conditional_losses, lstm_cell_10_layer_call_fn, lstm_cell_10_layer_call_and_return_conditional_losses, lstm_cell_11_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Models/Scenario1/LSTM/three_cluster/assets
# INFO:tensorflow:Assets written to: Models/Scenario1/LSTM/three_cluster/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7efc235bf550> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7efc22d31310> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7efc2359ea90> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_2_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ram://d29190a1-4adf-412e-b54a-43ba725b79f4/assets
# INFO:tensorflow:Assets written to: ram://d29190a1-4adf-412e-b54a-43ba725b79f4/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7efc639560d0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7efc634b8550> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7efc63902c40> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:Found untraced functions such as lstm_cell_3_layer_call_fn, lstm_cell_3_layer_call_and_return_conditional_losses, lstm_cell_4_layer_call_fn, lstm_cell_4_layer_call_and_return_conditional_losses, lstm_cell_5_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ram://592130ef-8892-4a1b-920c-5bbeb1dd774c/assets
# INFO:tensorflow:Assets written to: ram://592130ef-8892-4a1b-920c-5bbeb1dd774c/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7efc63e37430> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7efc63e3f3d0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7efc63a40c70> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:Found untraced functions such as lstm_cell_6_layer_call_fn, lstm_cell_6_layer_call_and_return_conditional_losses, lstm_cell_7_layer_call_fn, lstm_cell_7_layer_call_and_return_conditional_losses, lstm_cell_8_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ram://57876538-0049-41e1-b8f1-2f329f1c7a54/assets
# INFO:tensorflow:Assets written to: ram://57876538-0049-41e1-b8f1-2f329f1c7a54/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7efc21fc2250> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7efc21fc9490> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7efc21f166d0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:Found untraced functions such as lstm_cell_9_layer_call_fn, lstm_cell_9_layer_call_and_return_conditional_losses, lstm_cell_10_layer_call_fn, lstm_cell_10_layer_call_and_return_conditional_losses, lstm_cell_11_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ram://c45bfa56-c51a-42f2-bf99-85d80d332efb/assets
# INFO:tensorflow:Assets written to: ram://c45bfa56-c51a-42f2-bf99-85d80d332efb/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7efc235bf550> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7efc22d31310> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7efc2359ea90> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.

# %% [markdown]
# #### Scenario 2

# %%
all_houses = list(clustered_df['House'])
all_cluster = Cluster(all_houses)
all_cluster_results = all_cluster.results(model_name)
print('Training History without clustering:')
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_12 (LSTM)              (None, 12, 128)           69120
#
#  lstm_13 (LSTM)              (None, 12, 32)            20608
#
#  lstm_14 (LSTM)              (None, 16)                3136
#
#  dense_4 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 92,881
# Trainable params: 92,881
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 23095/23095 [==============================] - 293s 13ms/step - loss: 0.3152 - root_mean_squared_error: 0.5614 - mean_absolute_error: 0.3022 - mean_absolute_percentage_error: 211857.1719 - mean_squared_error: 0.3152 - val_loss: 0.3391 - val_root_mean_squared_error: 0.5823 - val_mean_absolute_error: 0.3150 - val_mean_absolute_percentage_error: 49545.2031 - val_mean_squared_error: 0.3391
# Epoch 2/10
# 23095/23095 [==============================] - 289s 12ms/step - loss: 0.2979 - root_mean_squared_error: 0.5458 - mean_absolute_error: 0.2914 - mean_absolute_percentage_error: 165778.4688 - mean_squared_error: 0.2979 - val_loss: 0.3445 - val_root_mean_squared_error: 0.5869 - val_mean_absolute_error: 0.3042 - val_mean_absolute_percentage_error: 51993.0977 - val_mean_squared_error: 0.3445
# Epoch 3/10
# 23095/23095 [==============================] - 291s 13ms/step - loss: 0.2931 - root_mean_squared_error: 0.5414 - mean_absolute_error: 0.2893 - mean_absolute_percentage_error: 161017.8438 - mean_squared_error: 0.2931 - val_loss: 0.3412 - val_root_mean_squared_error: 0.5842 - val_mean_absolute_error: 0.3219 - val_mean_absolute_percentage_error: 68676.5703 - val_mean_squared_error: 0.3412
# Epoch 4/10
# 23095/23095 [==============================] - 290s 13ms/step - loss: 0.2915 - root_mean_squared_error: 0.5399 - mean_absolute_error: 0.2881 - mean_absolute_percentage_error: 187363.7188 - mean_squared_error: 0.2915 - val_loss: 0.3450 - val_root_mean_squared_error: 0.5874 - val_mean_absolute_error: 0.3265 - val_mean_absolute_percentage_error: 60522.7656 - val_mean_squared_error: 0.3450
# Epoch 5/10
# 23095/23095 [==============================] - 291s 13ms/step - loss: 0.2878 - root_mean_squared_error: 0.5365 - mean_absolute_error: 0.2868 - mean_absolute_percentage_error: 180166.5156 - mean_squared_error: 0.2878 - val_loss: 0.3405 - val_root_mean_squared_error: 0.5835 - val_mean_absolute_error: 0.3178 - val_mean_absolute_percentage_error: 71616.3516 - val_mean_squared_error: 0.3405
# Epoch 6/10
# 23095/23095 [==============================] - 291s 13ms/step - loss: 0.2861 - root_mean_squared_error: 0.5349 - mean_absolute_error: 0.2858 - mean_absolute_percentage_error: 167055.0625 - mean_squared_error: 0.2861 - val_loss: 0.3394 - val_root_mean_squared_error: 0.5826 - val_mean_absolute_error: 0.3083 - val_mean_absolute_percentage_error: 61618.6055 - val_mean_squared_error: 0.3394
# Epoch 7/10
# 23095/23095 [==============================] - 292s 13ms/step - loss: 0.2867 - root_mean_squared_error: 0.5355 - mean_absolute_error: 0.2855 - mean_absolute_percentage_error: 133394.7344 - mean_squared_error: 0.2867 - val_loss: 0.3456 - val_root_mean_squared_error: 0.5879 - val_mean_absolute_error: 0.3320 - val_mean_absolute_percentage_error: 64387.6523 - val_mean_squared_error: 0.3456
# Epoch 8/10
# 23095/23095 [==============================] - 292s 13ms/step - loss: 0.2836 - root_mean_squared_error: 0.5325 - mean_absolute_error: 0.2844 - mean_absolute_percentage_error: 118089.4688 - mean_squared_error: 0.2836 - val_loss: 0.3416 - val_root_mean_squared_error: 0.5845 - val_mean_absolute_error: 0.3061 - val_mean_absolute_percentage_error: 50507.1875 - val_mean_squared_error: 0.3416
# Epoch 9/10
# 23095/23095 [==============================] - 294s 13ms/step - loss: 0.2827 - root_mean_squared_error: 0.5317 - mean_absolute_error: 0.2843 - mean_absolute_percentage_error: 128923.1172 - mean_squared_error: 0.2827 - val_loss: 0.3406 - val_root_mean_squared_error: 0.5837 - val_mean_absolute_error: 0.3023 - val_mean_absolute_percentage_error: 45542.3242 - val_mean_squared_error: 0.3406
# Epoch 10/10
# 23095/23095 [==============================] - 293s 13ms/step - loss: 0.2813 - root_mean_squared_error: 0.5304 - mean_absolute_error: 0.2837 - mean_absolute_percentage_error: 114709.6172 - mean_squared_error: 0.2813 - val_loss: 0.3406 - val_root_mean_squared_error: 0.5836 - val_mean_absolute_error: 0.3074 - val_mean_absolute_percentage_error: 55945.7227 - val_mean_squared_error: 0.3406
# Training History without clustering:

# %%
### Save Scenario 2 models
all_cluster.model.save(f'Models/Scenario2/{model_name}/all_cluster')

## Pickling Scenario 2 cluster and cluster result files
all_cluster_file = open(f"Models/Scenario2/Objects/{model_name}/all_cluster.pickle", "wb+")
pickle.dump(all_cluster, all_cluster_file)
all_cluster_file.close()

all_cluster_results_file = open(f"Models/Scenario2/Objects/{model_name}/all_cluster_results.pickle", "wb+")
pickle.dump(all_cluster_results, all_cluster_results_file)
all_cluster_results_file.close()
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_12_layer_call_fn, lstm_cell_12_layer_call_and_return_conditional_losses, lstm_cell_13_layer_call_fn, lstm_cell_13_layer_call_and_return_conditional_losses, lstm_cell_14_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Models/Scenario2/LSTM/all_cluster/assets
# INFO:tensorflow:Assets written to: Models/Scenario2/LSTM/all_cluster/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7efbeba90be0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7efbe8fe39d0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7efbe92fb760> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:Found untraced functions such as lstm_cell_12_layer_call_fn, lstm_cell_12_layer_call_and_return_conditional_losses, lstm_cell_13_layer_call_fn, lstm_cell_13_layer_call_and_return_conditional_losses, lstm_cell_14_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ram://2d5c12bc-a24a-49a5-9565-62f5375266db/assets
# INFO:tensorflow:Assets written to: ram://2d5c12bc-a24a-49a5-9565-62f5375266db/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7efbeba90be0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7efbe8fe39d0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7efbe92fb760> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.

# %% [markdown]
# #### Predictions Graph functions

# %%
def x_axis_label_format(label):
    """
    Convert time label to the format of pandas line plot
    """
    label = pd.Timestamp(label)
    month = label.month_name()[:3]
    #if month == 'Jan':
    month += f'\n{label.year}'
    return month

def graph_predictions(cluster_specific_results, all_results):
    first_house = list(cluster_specific_results.keys())[0]
    df1 = cluster_specific_results[first_house][['timestamp','energy_predicted', 'energy_kWh']]
    df1['timestamp'] = pd.to_datetime(df1['timestamp'])
    df1 = df1.set_index('timestamp')
    df1['energy_predicted_without_clustering']= np.array(all_results[first_house][['energy_predicted']])
    df1.rename({'energy_predicted':'energy_predicted_with_clustering', 'energy_kWh':'real_energy'},axis = 1, inplace = True)
    ax = df1[::300].plot.line(figsize=(20,10))
    #ax.set_xticklabels(map(x_axis_label_format, df1[::int(len(df1)/8)+1].index))
    #import matplotlib.dates as mdates
    #myFmt = mdates.DateFormatter('%Y-%m')
    #ax.xaxis.set_major_formatter(myFmt)
    ax.set_title(f'Predictions for house {first_house}')

# %% [markdown]
# #### Predictions for Scenario 1 and Scenario 2

# %%
graph_predictions(zero_cluster_results, all_cluster_results)
#df1 = zero_cluster_results[1][['timestamp','energy_predicted', 'energy_kWh']].set_index('timestamp')
#df1['energy_predicted_without_clustering']= np.array(all_cluster_results[1][['energy_predicted']])
# Out:
# /tmp/ipykernel_95546/442122963.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['timestamp'] = pd.to_datetime(df1['timestamp'])

# %%
graph_predictions(one_cluster_results, all_cluster_results)
# Out:
# /tmp/ipykernel_95546/442122963.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['timestamp'] = pd.to_datetime(df1['timestamp'])

# %%
graph_predictions(two_cluster_results, all_cluster_results)
# Out:
# /tmp/ipykernel_95546/442122963.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['timestamp'] = pd.to_datetime(df1['timestamp'])

# %%
graph_predictions(three_cluster_results, all_cluster_results)
# Out:
# /tmp/ipykernel_95546/442122963.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['timestamp'] = pd.to_datetime(df1['timestamp'])

# %%
# graph_predictions(four_cluster_results, all_cluster_results)

# %% [markdown]
# ### Function to create tables

# %%
def create_metrics(scenario_results, val=False):
    # tf.keras.metrics.RootMeanSquaredError(), tf.keras.metrics.MeanAbsoluteError(), tf.keras.metrics.MeanAbsolutePercentageError(), tf.keras.metrics.MeanSquaredError()
    if val == False:
        rmse = 'root_mean_squared_error'
        mae = 'mean_absolute_error'
        mape = 'mean_absolute_percentage_error'
        mse = 'mean_squared_error'
    else:
        rmse = 'val_root_mean_squared_error'
        mae = 'val_mean_absolute_error'
        mape = 'val_mean_absolute_percentage_error'
        mse = 'val_mean_squared_error'
        
    scenario_rmse = list(map(lambda x: x.history.history[rmse],scenario_results))
    scenario_mae = list(map(lambda x: x.history.history[mae],scenario_results))
    scenario_mape = list(map(lambda x: x.history.history[mape],scenario_results))
    scenario_mse = list(map(lambda x: x.history.history[mse],scenario_results))
    scenario_rmse = np.array(scenario_rmse).reshape(-1,)
    scenario_mae = np.array(scenario_mae).reshape(-1,)
    scenario_mape = np.array(scenario_mape).reshape(-1,)
    scenario_mse = np.array(scenario_mse).reshape(-1,)
    return [np.min(scenario_rmse),np.max(scenario_rmse),np.mean(scenario_rmse),np.min(scenario_mae),np.max(scenario_mae),np.mean(scenario_mae)
           ,np.min(scenario_mape),np.max(scenario_mape),np.mean(scenario_mape)
           ,np.min(scenario_mse),np.max(scenario_mse),np.mean(scenario_mse)]

# %% [markdown]
# #### Scenario 1 and Scenario 2 Metric Tables

# %%
scenario_1_results = [zero_cluster, one_cluster, two_cluster, three_cluster]
scenario_1_metrics = create_metrics(scenario_1_results)
scenario_1_validation_metrics = create_metrics(scenario_1_results, val= True)
scenario_1_metrics
# Out:
# [0.3233027756214142,
#  1.1771085262298584,
#  0.6256133466959,
#  0.1626913696527481,
#  0.6939239501953125,
#  0.3544860649853945,
#  59.11787796020508,
#  270692.03125,
#  95439.43218364715,
#  0.10452468693256378,
#  1.3855844736099243,
#  0.4514258451759815]

# %%
scenario_1_validation_metrics
# Out:
# [0.4604945778846741,
#  1.2483984231948853,
#  0.8127250917255878,
#  0.24231520295143127,
#  0.6666779518127441,
#  0.43286203071475027,
#  72.69501495361328,
#  285204.34375,
#  89975.25376853943,
#  0.2120552659034729,
#  1.5584986209869385,
#  0.7631087709218264]

# %%
scenario_2_results = [all_cluster]
scenario_2_metrics = create_metrics(scenario_2_results)
scenario_2_validation_metrics = create_metrics(scenario_2_results, val= True)
scenario_2_metrics
# Out:
# [0.5304052829742432,
#  0.5614131093025208,
#  0.5389983952045441,
#  0.2837202548980713,
#  0.30217668414115906,
#  0.28814370930194855,
#  114709.6171875,
#  211857.171875,
#  156835.571875,
#  0.28132978081703186,
#  0.31518468260765076,
#  0.2905953288078308]

# %%
scenario_2_validation_metrics
# Out:
# [0.5823274850845337,
#  0.5878520607948303,
#  0.584641969203949,
#  0.302326500415802,
#  0.33198991417884827,
#  0.31414896845817564,
#  45542.32421875,
#  71616.3515625,
#  58035.548046875,
#  0.3391053080558777,
#  0.34557002782821655,
#  0.3418098419904709]

# %% [markdown]
# #### Scenario 3 and 4

# %%
### Removing smart device features
House.cols = ['energy_kWh']
#House.cols

# %%
scenario_3_zero_cluster = Cluster(zero_houses)
scenario_3_zero_cluster_results = scenario_3_zero_cluster.results(model_name)
print('Training History for Cluster 0:')
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_15 (LSTM)              (None, 12, 128)           66560
#
#  lstm_16 (LSTM)              (None, 12, 32)            20608
#
#  lstm_17 (LSTM)              (None, 16)                3136
#
#  dense_5 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 90,321
# Trainable params: 90,321
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 2279/2279 [==============================] - 39s 16ms/step - loss: 0.6985 - root_mean_squared_error: 0.8358 - mean_absolute_error: 0.4946 - mean_absolute_percentage_error: 191686.7500 - mean_squared_error: 0.6985 - val_loss: 1.3663 - val_root_mean_squared_error: 1.1689 - val_mean_absolute_error: 0.5945 - val_mean_absolute_percentage_error: 275665.6562 - val_mean_squared_error: 1.3663
# Epoch 2/10
# 2279/2279 [==============================] - 35s 15ms/step - loss: 0.6292 - root_mean_squared_error: 0.7933 - mean_absolute_error: 0.4602 - mean_absolute_percentage_error: 172205.0000 - mean_squared_error: 0.6292 - val_loss: 1.3130 - val_root_mean_squared_error: 1.1459 - val_mean_absolute_error: 0.5976 - val_mean_absolute_percentage_error: 269264.9688 - val_mean_squared_error: 1.3130
# Epoch 3/10
# 2279/2279 [==============================] - 35s 15ms/step - loss: 0.6188 - root_mean_squared_error: 0.7866 - mean_absolute_error: 0.4538 - mean_absolute_percentage_error: 170661.0312 - mean_squared_error: 0.6188 - val_loss: 1.2859 - val_root_mean_squared_error: 1.1340 - val_mean_absolute_error: 0.5909 - val_mean_absolute_percentage_error: 250871.0781 - val_mean_squared_error: 1.2859
# Epoch 4/10
# 2279/2279 [==============================] - 35s 16ms/step - loss: 0.6114 - root_mean_squared_error: 0.7819 - mean_absolute_error: 0.4509 - mean_absolute_percentage_error: 154988.1719 - mean_squared_error: 0.6114 - val_loss: 1.3766 - val_root_mean_squared_error: 1.1733 - val_mean_absolute_error: 0.5802 - val_mean_absolute_percentage_error: 244030.9531 - val_mean_squared_error: 1.3766
# Epoch 5/10
# 2279/2279 [==============================] - 35s 15ms/step - loss: 0.6094 - root_mean_squared_error: 0.7806 - mean_absolute_error: 0.4491 - mean_absolute_percentage_error: 166471.8281 - mean_squared_error: 0.6094 - val_loss: 1.2871 - val_root_mean_squared_error: 1.1345 - val_mean_absolute_error: 0.6327 - val_mean_absolute_percentage_error: 200259.4219 - val_mean_squared_error: 1.2871
# Epoch 6/10
# 2279/2279 [==============================] - 35s 15ms/step - loss: 0.6058 - root_mean_squared_error: 0.7784 - mean_absolute_error: 0.4475 - mean_absolute_percentage_error: 165267.0000 - mean_squared_error: 0.6058 - val_loss: 1.2887 - val_root_mean_squared_error: 1.1352 - val_mean_absolute_error: 0.6000 - val_mean_absolute_percentage_error: 248178.6562 - val_mean_squared_error: 1.2887
# Epoch 7/10
# 2279/2279 [==============================] - 35s 15ms/step - loss: 0.6028 - root_mean_squared_error: 0.7764 - mean_absolute_error: 0.4456 - mean_absolute_percentage_error: 154565.0781 - mean_squared_error: 0.6028 - val_loss: 1.2778 - val_root_mean_squared_error: 1.1304 - val_mean_absolute_error: 0.5693 - val_mean_absolute_percentage_error: 196985.2656 - val_mean_squared_error: 1.2778
# Epoch 8/10
# 2279/2279 [==============================] - 35s 15ms/step - loss: 0.6014 - root_mean_squared_error: 0.7755 - mean_absolute_error: 0.4454 - mean_absolute_percentage_error: 165185.6562 - mean_squared_error: 0.6014 - val_loss: 1.3064 - val_root_mean_squared_error: 1.1430 - val_mean_absolute_error: 0.5822 - val_mean_absolute_percentage_error: 230255.8281 - val_mean_squared_error: 1.3064
# Epoch 9/10
# 2279/2279 [==============================] - 35s 15ms/step - loss: 0.5961 - root_mean_squared_error: 0.7721 - mean_absolute_error: 0.4423 - mean_absolute_percentage_error: 157743.8438 - mean_squared_error: 0.5961 - val_loss: 1.2836 - val_root_mean_squared_error: 1.1329 - val_mean_absolute_error: 0.5966 - val_mean_absolute_percentage_error: 231395.0312 - val_mean_squared_error: 1.2836
# Epoch 10/10
# 2279/2279 [==============================] - 35s 15ms/step - loss: 0.5933 - root_mean_squared_error: 0.7702 - mean_absolute_error: 0.4417 - mean_absolute_percentage_error: 161443.1875 - mean_squared_error: 0.5933 - val_loss: 1.2976 - val_root_mean_squared_error: 1.1391 - val_mean_absolute_error: 0.6363 - val_mean_absolute_percentage_error: 253432.4844 - val_mean_squared_error: 1.2976
# Training History for Cluster 0:

# %%
scenario_3_one_cluster = Cluster(one_houses)
scenario_3_one_cluster_results = scenario_3_one_cluster.results(model_name)
print('Training History for Cluster 1:')
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_18 (LSTM)              (None, 12, 128)           66560
#
#  lstm_19 (LSTM)              (None, 12, 32)            20608
#
#  lstm_20 (LSTM)              (None, 16)                3136
#
#  dense_6 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 90,321
# Trainable params: 90,321
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 915/915 [==============================] - 19s 17ms/step - loss: 1.3953 - root_mean_squared_error: 1.1812 - mean_absolute_error: 0.6969 - mean_absolute_percentage_error: 89.9642 - mean_squared_error: 1.3953 - val_loss: 1.5242 - val_root_mean_squared_error: 1.2346 - val_mean_absolute_error: 0.6427 - val_mean_absolute_percentage_error: 101.1317 - val_mean_squared_error: 1.5242
# Epoch 2/10
# 915/915 [==============================] - 14s 15ms/step - loss: 0.9479 - root_mean_squared_error: 0.9736 - mean_absolute_error: 0.5679 - mean_absolute_percentage_error: 73.0044 - mean_squared_error: 0.9479 - val_loss: 1.3617 - val_root_mean_squared_error: 1.1669 - val_mean_absolute_error: 0.6256 - val_mean_absolute_percentage_error: 107.3017 - val_mean_squared_error: 1.3617
# Epoch 3/10
# 915/915 [==============================] - 14s 15ms/step - loss: 0.8669 - root_mean_squared_error: 0.9311 - mean_absolute_error: 0.5359 - mean_absolute_percentage_error: 68.0961 - mean_squared_error: 0.8669 - val_loss: 1.2065 - val_root_mean_squared_error: 1.0984 - val_mean_absolute_error: 0.5732 - val_mean_absolute_percentage_error: 94.5028 - val_mean_squared_error: 1.2065
# Epoch 4/10
# 915/915 [==============================] - 14s 15ms/step - loss: 0.8352 - root_mean_squared_error: 0.9139 - mean_absolute_error: 0.5205 - mean_absolute_percentage_error: 65.2045 - mean_squared_error: 0.8352 - val_loss: 1.2060 - val_root_mean_squared_error: 1.0982 - val_mean_absolute_error: 0.5602 - val_mean_absolute_percentage_error: 87.6765 - val_mean_squared_error: 1.2060
# Epoch 5/10
# 915/915 [==============================] - 14s 16ms/step - loss: 0.8081 - root_mean_squared_error: 0.8989 - mean_absolute_error: 0.5090 - mean_absolute_percentage_error: 62.3614 - mean_squared_error: 0.8081 - val_loss: 1.4471 - val_root_mean_squared_error: 1.2030 - val_mean_absolute_error: 0.5897 - val_mean_absolute_percentage_error: 86.2624 - val_mean_squared_error: 1.4471
# Epoch 6/10
# 915/915 [==============================] - 14s 15ms/step - loss: 0.8046 - root_mean_squared_error: 0.8970 - mean_absolute_error: 0.5044 - mean_absolute_percentage_error: 62.1060 - mean_squared_error: 0.8046 - val_loss: 1.1612 - val_root_mean_squared_error: 1.0776 - val_mean_absolute_error: 0.5694 - val_mean_absolute_percentage_error: 94.9603 - val_mean_squared_error: 1.1612
# Epoch 7/10
# 915/915 [==============================] - 14s 16ms/step - loss: 0.7820 - root_mean_squared_error: 0.8843 - mean_absolute_error: 0.4977 - mean_absolute_percentage_error: 60.3985 - mean_squared_error: 0.7820 - val_loss: 1.2190 - val_root_mean_squared_error: 1.1041 - val_mean_absolute_error: 0.5061 - val_mean_absolute_percentage_error: 63.9344 - val_mean_squared_error: 1.2190
# Epoch 8/10
# 915/915 [==============================] - 14s 16ms/step - loss: 0.7691 - root_mean_squared_error: 0.8770 - mean_absolute_error: 0.4940 - mean_absolute_percentage_error: 60.2629 - mean_squared_error: 0.7691 - val_loss: 1.1819 - val_root_mean_squared_error: 1.0871 - val_mean_absolute_error: 0.5370 - val_mean_absolute_percentage_error: 80.2060 - val_mean_squared_error: 1.1819
# Epoch 9/10
# 915/915 [==============================] - 14s 16ms/step - loss: 0.7696 - root_mean_squared_error: 0.8773 - mean_absolute_error: 0.4940 - mean_absolute_percentage_error: 59.8218 - mean_squared_error: 0.7696 - val_loss: 1.3332 - val_root_mean_squared_error: 1.1546 - val_mean_absolute_error: 0.5261 - val_mean_absolute_percentage_error: 67.3786 - val_mean_squared_error: 1.3332
# Epoch 10/10
# 915/915 [==============================] - 15s 16ms/step - loss: 0.7611 - root_mean_squared_error: 0.8724 - mean_absolute_error: 0.4882 - mean_absolute_percentage_error: 58.2079 - mean_squared_error: 0.7611 - val_loss: 1.1048 - val_root_mean_squared_error: 1.0511 - val_mean_absolute_error: 0.5164 - val_mean_absolute_percentage_error: 73.3371 - val_mean_squared_error: 1.1048
# Training History for Cluster 1:

# %%
scenario_3_two_cluster = Cluster(two_houses)
scenario_3_two_cluster_results = scenario_3_two_cluster.results(model_name)
print('Training History for Cluster 2:')
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_21 (LSTM)              (None, 12, 128)           66560
#
#  lstm_22 (LSTM)              (None, 12, 32)            20608
#
#  lstm_23 (LSTM)              (None, 16)                3136
#
#  dense_7 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 90,321
# Trainable params: 90,321
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 14537/14537 [==============================] - 225s 15ms/step - loss: 0.2231 - root_mean_squared_error: 0.4723 - mean_absolute_error: 0.2783 - mean_absolute_percentage_error: 245120.4375 - mean_squared_error: 0.2231 - val_loss: 0.2709 - val_root_mean_squared_error: 0.5205 - val_mean_absolute_error: 0.3182 - val_mean_absolute_percentage_error: 77146.3281 - val_mean_squared_error: 0.2709
# Epoch 2/10
# 14537/14537 [==============================] - 222s 15ms/step - loss: 0.2158 - root_mean_squared_error: 0.4645 - mean_absolute_error: 0.2707 - mean_absolute_percentage_error: 208688.3438 - mean_squared_error: 0.2158 - val_loss: 0.2704 - val_root_mean_squared_error: 0.5200 - val_mean_absolute_error: 0.3196 - val_mean_absolute_percentage_error: 75239.1250 - val_mean_squared_error: 0.2704
# Epoch 3/10
# 14537/14537 [==============================] - 223s 15ms/step - loss: 0.2126 - root_mean_squared_error: 0.4611 - mean_absolute_error: 0.2675 - mean_absolute_percentage_error: 191519.4062 - mean_squared_error: 0.2126 - val_loss: 0.2738 - val_root_mean_squared_error: 0.5233 - val_mean_absolute_error: 0.3229 - val_mean_absolute_percentage_error: 76526.1719 - val_mean_squared_error: 0.2738
# Epoch 4/10
# 14537/14537 [==============================] - 223s 15ms/step - loss: 0.2108 - root_mean_squared_error: 0.4592 - mean_absolute_error: 0.2656 - mean_absolute_percentage_error: 189800.7188 - mean_squared_error: 0.2108 - val_loss: 0.2769 - val_root_mean_squared_error: 0.5262 - val_mean_absolute_error: 0.3220 - val_mean_absolute_percentage_error: 78085.0391 - val_mean_squared_error: 0.2769
# Epoch 5/10
# 14537/14537 [==============================] - 224s 15ms/step - loss: 0.2096 - root_mean_squared_error: 0.4578 - mean_absolute_error: 0.2644 - mean_absolute_percentage_error: 181771.1875 - mean_squared_error: 0.2096 - val_loss: 0.2755 - val_root_mean_squared_error: 0.5249 - val_mean_absolute_error: 0.3220 - val_mean_absolute_percentage_error: 83171.5703 - val_mean_squared_error: 0.2755
# Epoch 6/10
# 14537/14537 [==============================] - 225s 15ms/step - loss: 0.2086 - root_mean_squared_error: 0.4567 - mean_absolute_error: 0.2636 - mean_absolute_percentage_error: 167898.7344 - mean_squared_error: 0.2086 - val_loss: 0.2766 - val_root_mean_squared_error: 0.5259 - val_mean_absolute_error: 0.3217 - val_mean_absolute_percentage_error: 79084.7031 - val_mean_squared_error: 0.2766
# Epoch 7/10
# 14537/14537 [==============================] - 223s 15ms/step - loss: 0.2078 - root_mean_squared_error: 0.4559 - mean_absolute_error: 0.2629 - mean_absolute_percentage_error: 150247.0156 - mean_squared_error: 0.2078 - val_loss: 0.2741 - val_root_mean_squared_error: 0.5235 - val_mean_absolute_error: 0.3279 - val_mean_absolute_percentage_error: 81421.6875 - val_mean_squared_error: 0.2741
# Epoch 8/10
# 14537/14537 [==============================] - 224s 15ms/step - loss: 0.2070 - root_mean_squared_error: 0.4550 - mean_absolute_error: 0.2622 - mean_absolute_percentage_error: 153354.7969 - mean_squared_error: 0.2070 - val_loss: 0.2743 - val_root_mean_squared_error: 0.5238 - val_mean_absolute_error: 0.3168 - val_mean_absolute_percentage_error: 80249.0391 - val_mean_squared_error: 0.2743
# Epoch 9/10
# 14537/14537 [==============================] - 226s 16ms/step - loss: 0.2063 - root_mean_squared_error: 0.4542 - mean_absolute_error: 0.2616 - mean_absolute_percentage_error: 143565.2812 - mean_squared_error: 0.2063 - val_loss: 0.2719 - val_root_mean_squared_error: 0.5215 - val_mean_absolute_error: 0.3158 - val_mean_absolute_percentage_error: 78205.8438 - val_mean_squared_error: 0.2719
# Epoch 10/10
# 14537/14537 [==============================] - 225s 15ms/step - loss: 0.2057 - root_mean_squared_error: 0.4536 - mean_absolute_error: 0.2611 - mean_absolute_percentage_error: 143154.5312 - mean_squared_error: 0.2057 - val_loss: 0.2808 - val_root_mean_squared_error: 0.5299 - val_mean_absolute_error: 0.3182 - val_mean_absolute_percentage_error: 73132.3750 - val_mean_squared_error: 0.2808
# Training History for Cluster 2:

# %%
scenario_3_three_cluster = Cluster(three_houses)
scenario_3_three_cluster_results = scenario_3_three_cluster.results(model_name)
print('Training History for Cluster 3:')
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_24 (LSTM)              (None, 12, 128)           66560
#
#  lstm_25 (LSTM)              (None, 12, 32)            20608
#
#  lstm_26 (LSTM)              (None, 16)                3136
#
#  dense_8 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 90,321
# Trainable params: 90,321
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 5366/5366 [==============================] - 88s 16ms/step - loss: 0.1172 - root_mean_squared_error: 0.3423 - mean_absolute_error: 0.1802 - mean_absolute_percentage_error: 49917.9375 - mean_squared_error: 0.1172 - val_loss: 0.2125 - val_root_mean_squared_error: 0.4610 - val_mean_absolute_error: 0.2446 - val_mean_absolute_percentage_error: 39882.6016 - val_mean_squared_error: 0.2125
# Epoch 2/10
# 5366/5366 [==============================] - 81s 15ms/step - loss: 0.1125 - root_mean_squared_error: 0.3354 - mean_absolute_error: 0.1733 - mean_absolute_percentage_error: 37872.0430 - mean_squared_error: 0.1125 - val_loss: 0.2164 - val_root_mean_squared_error: 0.4651 - val_mean_absolute_error: 0.2444 - val_mean_absolute_percentage_error: 34385.8164 - val_mean_squared_error: 0.2164
# Epoch 3/10
# 5366/5366 [==============================] - 82s 15ms/step - loss: 0.1117 - root_mean_squared_error: 0.3342 - mean_absolute_error: 0.1724 - mean_absolute_percentage_error: 37946.4297 - mean_squared_error: 0.1117 - val_loss: 0.2202 - val_root_mean_squared_error: 0.4693 - val_mean_absolute_error: 0.2397 - val_mean_absolute_percentage_error: 42636.9961 - val_mean_squared_error: 0.2202
# Epoch 4/10
# 5366/5366 [==============================] - 83s 15ms/step - loss: 0.1107 - root_mean_squared_error: 0.3328 - mean_absolute_error: 0.1712 - mean_absolute_percentage_error: 41637.1680 - mean_squared_error: 0.1107 - val_loss: 0.2127 - val_root_mean_squared_error: 0.4612 - val_mean_absolute_error: 0.2514 - val_mean_absolute_percentage_error: 50467.6719 - val_mean_squared_error: 0.2127
# Epoch 5/10
# 5366/5366 [==============================] - 82s 15ms/step - loss: 0.1098 - root_mean_squared_error: 0.3314 - mean_absolute_error: 0.1700 - mean_absolute_percentage_error: 45478.8828 - mean_squared_error: 0.1098 - val_loss: 0.2156 - val_root_mean_squared_error: 0.4643 - val_mean_absolute_error: 0.2410 - val_mean_absolute_percentage_error: 45034.7148 - val_mean_squared_error: 0.2156
# Epoch 6/10
# 5366/5366 [==============================] - 83s 15ms/step - loss: 0.1090 - root_mean_squared_error: 0.3302 - mean_absolute_error: 0.1688 - mean_absolute_percentage_error: 44039.1445 - mean_squared_error: 0.1090 - val_loss: 0.2123 - val_root_mean_squared_error: 0.4608 - val_mean_absolute_error: 0.2473 - val_mean_absolute_percentage_error: 47602.3984 - val_mean_squared_error: 0.2123
# Epoch 7/10
# 5366/5366 [==============================] - 82s 15ms/step - loss: 0.1083 - root_mean_squared_error: 0.3291 - mean_absolute_error: 0.1677 - mean_absolute_percentage_error: 42176.7188 - mean_squared_error: 0.1083 - val_loss: 0.2134 - val_root_mean_squared_error: 0.4619 - val_mean_absolute_error: 0.2454 - val_mean_absolute_percentage_error: 41025.7227 - val_mean_squared_error: 0.2134
# Epoch 8/10
# 5366/5366 [==============================] - 83s 15ms/step - loss: 0.1073 - root_mean_squared_error: 0.3275 - mean_absolute_error: 0.1662 - mean_absolute_percentage_error: 42929.4922 - mean_squared_error: 0.1073 - val_loss: 0.2162 - val_root_mean_squared_error: 0.4650 - val_mean_absolute_error: 0.2411 - val_mean_absolute_percentage_error: 51144.5273 - val_mean_squared_error: 0.2162
# Epoch 9/10
# 5366/5366 [==============================] - 83s 15ms/step - loss: 0.1061 - root_mean_squared_error: 0.3258 - mean_absolute_error: 0.1650 - mean_absolute_percentage_error: 44151.5430 - mean_squared_error: 0.1061 - val_loss: 0.2132 - val_root_mean_squared_error: 0.4617 - val_mean_absolute_error: 0.2445 - val_mean_absolute_percentage_error: 40553.8828 - val_mean_squared_error: 0.2132
# Epoch 10/10
# 5366/5366 [==============================] - 82s 15ms/step - loss: 0.1056 - root_mean_squared_error: 0.3249 - mean_absolute_error: 0.1642 - mean_absolute_percentage_error: 41585.4297 - mean_squared_error: 0.1056 - val_loss: 0.2138 - val_root_mean_squared_error: 0.4624 - val_mean_absolute_error: 0.2455 - val_mean_absolute_percentage_error: 43771.7461 - val_mean_squared_error: 0.2138
# Training History for Cluster 3:

# %%
# scenario_3_four_cluster = Cluster(four_houses)
# scenario_3_four_cluster_results = scenario_3_four_cluster.results(model_name)
# print('Training History for Cluster 4:')

# %%
## Save Scenario 3 models
scenario_3_zero_cluster.model.save(f'Models/Scenario3/{model_name}/zero_cluster')
scenario_3_one_cluster.model.save(f'Models/Scenario3/{model_name}/one_cluster')
scenario_3_two_cluster.model.save(f'Models/Scenario3/{model_name}/two_cluster')
scenario_3_three_cluster.model.save(f'Models/Scenario3/{model_name}/three_cluster')
# scenario_3_four_cluster.model.save(f'Models/Scenario3/{model_name}/four_cluster')

# Pickling objects

scenario_3_zero_cluster_file = open(f"Models/Scenario3/Objects/{model_name}/zero_cluster.pickle", "wb")
pickle.dump(scenario_3_zero_cluster, scenario_3_zero_cluster_file)
scenario_3_zero_cluster_file.close()

scenario_3_one_cluster_file = open(f"Models/Scenario3/Objects/{model_name}/one_cluster.pickle", "wb")
pickle.dump(scenario_3_one_cluster, scenario_3_one_cluster_file)
scenario_3_one_cluster_file.close()

scenario_3_two_cluster_file = open(f"Models/Scenario3/Objects/{model_name}/two_cluster.pickle", "wb")
pickle.dump(scenario_3_two_cluster, scenario_3_two_cluster_file)
scenario_3_two_cluster_file.close()

scenario_3_three_cluster_file = open(f"Models/Scenario3/Objects/{model_name}/three_cluster.pickle", "wb")
pickle.dump(scenario_3_three_cluster, scenario_3_three_cluster_file)
scenario_3_three_cluster_file.close()

# scenario_3_four_cluster_file = open(f"Models/Scenario3/Objects/{model_name}/four_cluster.pickle", "wb")
# pickle.dump(scenario_3_four_cluster, scenario_3_four_cluster_file)
# scenario_3_four_cluster_file.close()

scenario_3_zero_cluster_results_file = open(f"Models/Scenario3/Objects/{model_name}/zero_cluster_results.pickle", "wb")
pickle.dump(scenario_3_zero_cluster_results, scenario_3_zero_cluster_results_file)
scenario_3_zero_cluster_results_file.close()

scenario_3_one_cluster_results_file = open(f"Models/Scenario3/Objects/{model_name}/one_cluster_results.pickle", "wb")
pickle.dump(scenario_3_one_cluster_results, scenario_3_one_cluster_results_file)
scenario_3_one_cluster_results_file.close()

scenario_3_two_cluster_results_file = open(f"Models/Scenario3/Objects/{model_name}/two_cluster_results.pickle", "wb")
pickle.dump(scenario_3_two_cluster_results, scenario_3_two_cluster_results_file)
scenario_3_two_cluster_results_file.close()

scenario_3_three_cluster_results_file = open(f"Models/Scenario3/Objects/{model_name}/three_cluster_results.pickle", "wb")
pickle.dump(scenario_3_three_cluster_results, scenario_3_three_cluster_results_file)
scenario_3_three_cluster_results_file.close()

# scenario_3_four_cluster_results_file = open(f"Models/Scenario3/Objects/{model_name}/four_cluster_results.pickle", "wb")
# pickle.dump(scenario_3_four_cluster_results, scenario_3_four_cluster_results_file)
# scenario_3_four_cluster_results_file.close()
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_15_layer_call_fn, lstm_cell_15_layer_call_and_return_conditional_losses, lstm_cell_16_layer_call_fn, lstm_cell_16_layer_call_and_return_conditional_losses, lstm_cell_17_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Models/Scenario3/LSTM/zero_cluster/assets
# INFO:tensorflow:Assets written to: Models/Scenario3/LSTM/zero_cluster/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7efbeab4d970> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7efbec2f5a30> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7efbfc2f89d0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:Found untraced functions such as lstm_cell_18_layer_call_fn, lstm_cell_18_layer_call_and_return_conditional_losses, lstm_cell_19_layer_call_fn, lstm_cell_19_layer_call_and_return_conditional_losses, lstm_cell_20_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Models/Scenario3/LSTM/one_cluster/assets
# INFO:tensorflow:Assets written to: Models/Scenario3/LSTM/one_cluster/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7efbfc2c0af0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7efbff1b94c0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7efbff43a3a0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:Found untraced functions such as lstm_cell_21_layer_call_fn, lstm_cell_21_layer_call_and_return_conditional_losses, lstm_cell_22_layer_call_fn, lstm_cell_22_layer_call_and_return_conditional_losses, lstm_cell_23_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Models/Scenario3/LSTM/two_cluster/assets
# INFO:tensorflow:Assets written to: Models/Scenario3/LSTM/two_cluster/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7efbe7ba89d0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7efbe7baddc0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7efbe7aee1c0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:Found untraced functions such as lstm_cell_24_layer_call_fn, lstm_cell_24_layer_call_and_return_conditional_losses, lstm_cell_25_layer_call_fn, lstm_cell_25_layer_call_and_return_conditional_losses, lstm_cell_26_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Models/Scenario3/LSTM/three_cluster/assets
# INFO:tensorflow:Assets written to: Models/Scenario3/LSTM/three_cluster/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7efbe53de4f0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7efbe535c910> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7efbe5315610> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:Found untraced functions such as lstm_cell_15_layer_call_fn, lstm_cell_15_layer_call_and_return_conditional_losses, lstm_cell_16_layer_call_fn, lstm_cell_16_layer_call_and_return_conditional_losses, lstm_cell_17_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ram://30784994-101c-4a68-aa35-f6a28d700e5e/assets
# INFO:tensorflow:Assets written to: ram://30784994-101c-4a68-aa35-f6a28d700e5e/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7efbeab4d970> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7efbec2f5a30> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7efbfc2f89d0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:Found untraced functions such as lstm_cell_18_layer_call_fn, lstm_cell_18_layer_call_and_return_conditional_losses, lstm_cell_19_layer_call_fn, lstm_cell_19_layer_call_and_return_conditional_losses, lstm_cell_20_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ram://caeb4c25-039c-4616-ae12-300a8912e686/assets
# INFO:tensorflow:Assets written to: ram://caeb4c25-039c-4616-ae12-300a8912e686/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7efbfc2c0af0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7efbff1b94c0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7efbff43a3a0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:Found untraced functions such as lstm_cell_21_layer_call_fn, lstm_cell_21_layer_call_and_return_conditional_losses, lstm_cell_22_layer_call_fn, lstm_cell_22_layer_call_and_return_conditional_losses, lstm_cell_23_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ram://8aedd017-2946-4a07-b470-3e3cf5acc500/assets
# INFO:tensorflow:Assets written to: ram://8aedd017-2946-4a07-b470-3e3cf5acc500/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7efbe7ba89d0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7efbe7baddc0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7efbe7aee1c0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:Found untraced functions such as lstm_cell_24_layer_call_fn, lstm_cell_24_layer_call_and_return_conditional_losses, lstm_cell_25_layer_call_fn, lstm_cell_25_layer_call_and_return_conditional_losses, lstm_cell_26_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ram://effa3999-8061-4f11-9bc9-78585981c1aa/assets
# INFO:tensorflow:Assets written to: ram://effa3999-8061-4f11-9bc9-78585981c1aa/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7efbe53de4f0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7efbe535c910> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7efbe5315610> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.

# %% [markdown]
# #### Scenario 4

# %%
scenario_4_all_cluster = Cluster(all_houses)
scenario_4_all_cluster_results = scenario_4_all_cluster.results(model_name)
print('Training History without clustering:')
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_27 (LSTM)              (None, 12, 128)           66560
#
#  lstm_28 (LSTM)              (None, 12, 32)            20608
#
#  lstm_29 (LSTM)              (None, 16)                3136
#
#  dense_9 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 90,321
# Trainable params: 90,321
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 23095/23095 [==============================] - 292s 12ms/step - loss: 0.3143 - root_mean_squared_error: 0.5606 - mean_absolute_error: 0.3016 - mean_absolute_percentage_error: 202860.2969 - mean_squared_error: 0.3143 - val_loss: 0.3480 - val_root_mean_squared_error: 0.5900 - val_mean_absolute_error: 0.3215 - val_mean_absolute_percentage_error: 64846.1836 - val_mean_squared_error: 0.3480
# Epoch 2/10
# 23095/23095 [==============================] - 288s 12ms/step - loss: 0.2978 - root_mean_squared_error: 0.5457 - mean_absolute_error: 0.2918 - mean_absolute_percentage_error: 173751.5938 - mean_squared_error: 0.2978 - val_loss: 0.3407 - val_root_mean_squared_error: 0.5837 - val_mean_absolute_error: 0.3092 - val_mean_absolute_percentage_error: 54132.7578 - val_mean_squared_error: 0.3407
# Epoch 3/10
# 23095/23095 [==============================] - 290s 13ms/step - loss: 0.2953 - root_mean_squared_error: 0.5434 - mean_absolute_error: 0.2909 - mean_absolute_percentage_error: 167481.1875 - mean_squared_error: 0.2953 - val_loss: 0.3443 - val_root_mean_squared_error: 0.5868 - val_mean_absolute_error: 0.3081 - val_mean_absolute_percentage_error: 55557.2852 - val_mean_squared_error: 0.3443
# Epoch 4/10
# 23095/23095 [==============================] - 290s 13ms/step - loss: 0.2924 - root_mean_squared_error: 0.5407 - mean_absolute_error: 0.2893 - mean_absolute_percentage_error: 135823.7188 - mean_squared_error: 0.2924 - val_loss: 0.3404 - val_root_mean_squared_error: 0.5835 - val_mean_absolute_error: 0.3127 - val_mean_absolute_percentage_error: 44582.8594 - val_mean_squared_error: 0.3404
# Epoch 5/10
# 23095/23095 [==============================] - 291s 13ms/step - loss: 0.2894 - root_mean_squared_error: 0.5380 - mean_absolute_error: 0.2879 - mean_absolute_percentage_error: 128514.6641 - mean_squared_error: 0.2894 - val_loss: 0.3447 - val_root_mean_squared_error: 0.5871 - val_mean_absolute_error: 0.3092 - val_mean_absolute_percentage_error: 49459.9922 - val_mean_squared_error: 0.3447
# Epoch 6/10
# 23095/23095 [==============================] - 291s 13ms/step - loss: 0.2880 - root_mean_squared_error: 0.5367 - mean_absolute_error: 0.2870 - mean_absolute_percentage_error: 119417.2656 - mean_squared_error: 0.2880 - val_loss: 0.3407 - val_root_mean_squared_error: 0.5837 - val_mean_absolute_error: 0.3157 - val_mean_absolute_percentage_error: 58937.6719 - val_mean_squared_error: 0.3407
# Epoch 7/10
# 23095/23095 [==============================] - 292s 13ms/step - loss: 0.2865 - root_mean_squared_error: 0.5352 - mean_absolute_error: 0.2861 - mean_absolute_percentage_error: 136194.8125 - mean_squared_error: 0.2865 - val_loss: 0.3383 - val_root_mean_squared_error: 0.5816 - val_mean_absolute_error: 0.3124 - val_mean_absolute_percentage_error: 44058.6914 - val_mean_squared_error: 0.3383
# Epoch 8/10
# 23095/23095 [==============================] - 292s 13ms/step - loss: 0.2853 - root_mean_squared_error: 0.5342 - mean_absolute_error: 0.2855 - mean_absolute_percentage_error: 118373.1016 - mean_squared_error: 0.2853 - val_loss: 0.3518 - val_root_mean_squared_error: 0.5931 - val_mean_absolute_error: 0.3144 - val_mean_absolute_percentage_error: 49397.2344 - val_mean_squared_error: 0.3518
# Epoch 9/10
# 23095/23095 [==============================] - 294s 13ms/step - loss: 0.2833 - root_mean_squared_error: 0.5322 - mean_absolute_error: 0.2846 - mean_absolute_percentage_error: 124087.8750 - mean_squared_error: 0.2833 - val_loss: 0.3395 - val_root_mean_squared_error: 0.5827 - val_mean_absolute_error: 0.3108 - val_mean_absolute_percentage_error: 51330.0977 - val_mean_squared_error: 0.3395
# Epoch 10/10
# 23095/23095 [==============================] - 294s 13ms/step - loss: 0.2821 - root_mean_squared_error: 0.5311 - mean_absolute_error: 0.2840 - mean_absolute_percentage_error: 109189.3125 - mean_squared_error: 0.2821 - val_loss: 0.3483 - val_root_mean_squared_error: 0.5902 - val_mean_absolute_error: 0.3135 - val_mean_absolute_percentage_error: 52618.9414 - val_mean_squared_error: 0.3483
# Training History without clustering:

# %%
### Save Scenario 4 models
scenario_4_all_cluster.model.save(f'Models/Scenario4/{model_name}/all_cluster')

## Pickling Scenario 4 cluster and cluster result files
scenario_4_all_cluster_file = open(f"Models/Scenario4/{model_name}/all_cluster.pickle", "wb")
pickle.dump(scenario_4_all_cluster, scenario_4_all_cluster_file)
scenario_4_all_cluster_file.close()

scenario_4_all_cluster_results_file = open(f"Models/Scenario4/{model_name}/all_cluster_results.pickle", "wb")
pickle.dump(scenario_4_all_cluster_results, scenario_4_all_cluster_results_file)
scenario_4_all_cluster_results_file.close()
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_27_layer_call_fn, lstm_cell_27_layer_call_and_return_conditional_losses, lstm_cell_28_layer_call_fn, lstm_cell_28_layer_call_and_return_conditional_losses, lstm_cell_29_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Models/Scenario4/LSTM/all_cluster/assets
# INFO:tensorflow:Assets written to: Models/Scenario4/LSTM/all_cluster/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7efbc48b7790> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7efbc5eb01c0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7efbc6efb9a0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:Found untraced functions such as lstm_cell_27_layer_call_fn, lstm_cell_27_layer_call_and_return_conditional_losses, lstm_cell_28_layer_call_fn, lstm_cell_28_layer_call_and_return_conditional_losses, lstm_cell_29_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ram://eb5e0817-d8eb-465b-b734-ccfd85ec77f2/assets
# INFO:tensorflow:Assets written to: ram://eb5e0817-d8eb-465b-b734-ccfd85ec77f2/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7efbc48b7790> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7efbc5eb01c0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7efbc6efb9a0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.

# %% [markdown]
# #### Predictions for Scenario 3 and Scenario 4

# %%
graph_predictions(scenario_3_zero_cluster_results, scenario_4_all_cluster_results)
# Out:
# /tmp/ipykernel_95546/442122963.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['timestamp'] = pd.to_datetime(df1['timestamp'])

# %%
graph_predictions(scenario_3_one_cluster_results, scenario_4_all_cluster_results)
# Out:
# /tmp/ipykernel_95546/442122963.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['timestamp'] = pd.to_datetime(df1['timestamp'])

# %%
graph_predictions(scenario_3_two_cluster_results, scenario_4_all_cluster_results)
# Out:
# /tmp/ipykernel_95546/442122963.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['timestamp'] = pd.to_datetime(df1['timestamp'])

# %%
graph_predictions(scenario_3_three_cluster_results, scenario_4_all_cluster_results)
# Out:
# /tmp/ipykernel_95546/442122963.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['timestamp'] = pd.to_datetime(df1['timestamp'])

# %%
# graph_predictions(scenario_3_four_cluster_results, scenario_4_all_cluster_results)

# %% [markdown]
# #### Scenario 3 and Scenario 4 Metric Tables

# %%
scenario_3_results = [scenario_3_zero_cluster, scenario_3_one_cluster, scenario_3_two_cluster, scenario_3_three_cluster]
scenario_3_metrics = create_metrics(scenario_3_results )
scenario_3_validation_metrics = create_metrics(scenario_3_results, val= True)
scenario_3_metrics
# Out:
# [0.32490700483322144,
#  1.18123197555542,
#  0.6265311896800995,
#  0.1642041653394699,
#  0.6968522071838379,
#  0.3549102272838354,
#  58.20793151855469,
#  245120.4375,
#  96593.30541973114,
#  0.10556456446647644,
#  1.3953090906143188,
#  0.45280148908495904]

# %%
scenario_3_validation_metrics
# Out:
# [0.4607914090156555,
#  1.2346041202545166,
#  0.8146206915378571,
#  0.2396681010723114,
#  0.6427144408226013,
#  0.43191081695258615,
#  63.93438720703125,
#  275665.65625,
#  90499.09990310669,
#  0.2123287320137024,
#  1.5242472887039185,
#  0.7679990772157907]

# %%
scenario_4_results = [scenario_4_all_cluster]
scenario_4_metrics = create_metrics(scenario_4_results )
scenario_4_validation_metrics = create_metrics(scenario_4_results, val= True)
scenario_4_metrics
# Out:
# [0.5311077237129211,
#  0.5605947375297546,
#  0.5397806406021118,
#  0.2839617133140564,
#  0.3016289174556732,
#  0.2888694882392883,
#  109189.3125,
#  202860.296875,
#  141569.3828125,
#  0.2820754051208496,
#  0.31426647305488586,
#  0.2914311796426773]

# %%
scenario_4_validation_metrics
# Out:
# [0.581632673740387,
#  0.5931180715560913,
#  0.5862270891666412,
#  0.3080645799636841,
#  0.32150304317474365,
#  0.31274290978908537,
#  44058.69140625,
#  64846.18359375,
#  52492.171484375,
#  0.3382965624332428,
#  0.35178902745246887,
#  0.3436754375696182]

# %%
print('Training metrics:')
df = pd.DataFrame([scenario_1_metrics, scenario_2_metrics, scenario_3_metrics, scenario_4_metrics],index=[1,2,3,4], columns = ['Min RMSE', 'Max RMSE', 'Mean RMSE','Min MAE', 'Max MAE', 'Mean MAE',
                                                                                                                              'Min MAPE', 'Max MAPE', 'Mean MAPE',
                                                                                                                              'Min MSE', 'Max MSE', 'Mean MSE'])
df['Scenario'] = np.array([1,2,3,4])
df.set_index('Scenario').round(decimals=2).to_csv(f'Tables/{model_name}_training_metrics.csv')
df
# Out:
# Training metrics:
#    Min RMSE  Max RMSE  Mean RMSE   Min MAE   Max MAE  Mean MAE       Min MAPE  \
# 1  0.323303  1.177109   0.625613  0.162691  0.693924  0.354486      59.117878
# 2  0.530405  0.561413   0.538998  0.283720  0.302177  0.288144  114709.617188
# 3  0.324907  1.181232   0.626531  0.164204  0.696852  0.354910      58.207932
# 4  0.531108  0.560595   0.539781  0.283962  0.301629  0.288869  109189.312500
#
#         Max MAPE      Mean MAPE   Min MSE   Max MSE  Mean MSE  Scenario
# 1  270692.031250   95439.432184  0.104525  1.385584  0.451426         1
# 2  211857.171875  156835.571875  0.281330  0.315185  0.290595         2
# 3  245120.437500   96593.305420  0.105565  1.395309  0.452801         3
# 4  202860.296875  141569.382812  0.282075  0.314266  0.291431         4

# %%
print('Validation metrics:')
df = pd.DataFrame([scenario_1_validation_metrics, scenario_2_validation_metrics,
                   scenario_3_validation_metrics, scenario_4_validation_metrics],index=[1,2,3,4], columns = ['Min RMSE', 'Max RMSE', 'Mean RMSE','Min MAE', 'Max MAE', 'Mean MAE',
                                                                                                                              'Min MAPE', 'Max MAPE', 'Mean MAPE',
                                                                                                                              'Min MSE', 'Max MSE', 'Mean MSE'])
df['Scenario'] = np.array([1,2,3,4])
df.set_index('Scenario').round(decimals=2).to_csv(f'Tables/{model_name}_validation_metrics.csv')
df
# Out:
# Validation metrics:
#    Min RMSE  Max RMSE  Mean RMSE   Min MAE   Max MAE  Mean MAE      Min MAPE  \
# 1  0.460495  1.248398   0.812725  0.242315  0.666678  0.432862     72.695015
# 2  0.582327  0.587852   0.584642  0.302327  0.331990  0.314149  45542.324219
# 3  0.460791  1.234604   0.814621  0.239668  0.642714  0.431911     63.934387
# 4  0.581633  0.593118   0.586227  0.308065  0.321503  0.312743  44058.691406
#
#         Max MAPE     Mean MAPE   Min MSE   Max MSE  Mean MSE  Scenario
# 1  285204.343750  89975.253769  0.212055  1.558499  0.763109         1
# 2   71616.351562  58035.548047  0.339105  0.345570  0.341810         2
# 3  275665.656250  90499.099903  0.212329  1.524247  0.767999         3
# 4   64846.183594  52492.171484  0.338297  0.351789  0.343675         4

# %% [markdown]
# ### Anomaly Distribution

# %%
def create_anomaly_df(result_df, scenario_name, monthly_agg = True, only2017=False):    
    #print(type(result_df))
    anomaly_df = result_df[['timestamp', 'Anomaly detected']]
    if only2017:
        anomaly_df = anomaly_df[(anomaly_df['timestamp'] <= '2017-12-31') & (anomaly_df['timestamp'] >= '2017-01-01')]
    anomaly_df.set_index('timestamp', inplace = True)
    if monthly_agg:
        anomaly_df['Anomaly detected'] = anomaly_df['Anomaly detected'].apply(lambda x: 0 if x is False else 1)
        anomaly_df = anomaly_df.resample("M").agg('sum')
    else: 
        anomaly_df['Anomaly detected'] = anomaly_df['Anomaly detected'].apply(lambda x: 0 if x is False else x)
    anomaly_df = anomaly_df.rename(columns={'Anomaly detected': scenario_name})
    return anomaly_df

def create_anomalies_graph( title = None,only2017=False, **kwargs):
    anomaly_dfs = []
    for scenario_name, result_df in kwargs.items():
        anomaly_df = create_anomaly_df(result_df, scenario_name, only2017=only2017)
        anomaly_dfs.append(anomaly_df)
    anomaly_df = functools.reduce(lambda left, right: left.join(right), anomaly_dfs)
    ax = anomaly_df.plot.line(figsize=(20,10))
    ax.set_xlabel(f'Time')
    ax.set_ylabel(f'Frequency')
    ax.set_title(title)
    #return anomaly_dfs

# %%
def dtw_distance(series1, series2):
    return fastdtw.fastdtw(series1,series2)[0]

def create_distance_df(title, **kwargs):
    print(title)
    anomaly_dfs = []
    for scenario_name, result_df in kwargs.items():
        anomaly_df = np.array(create_anomaly_df(result_df, scenario_name, monthly_agg=False)).reshape(1,-1)
        anomaly_dfs.append(anomaly_df)
    anomaly_distributions = np.array(anomaly_dfs).reshape(len(kwargs),-1)
    distance_matrix = sd.squareform(sd.pdist(anomaly_distributions, dtw_distance))
    return(pd.DataFrame(distance_matrix, columns = kwargs.keys(), index = kwargs.keys()))
    #return anomaly_dfs

# %%
create_anomalies_graph( 'Anomaly Frequency Distribution for House 14: Cluster 0', Scenario1 = zero_cluster_results[14], Scenario2 = all_cluster_results[14],
                       Scenario3 = scenario_3_zero_cluster_results[14], Scenario4 = scenario_4_all_cluster_results[14])
# Out:
# /tmp/ipykernel_95546/1074003093.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anomaly_df['Anomaly detected'] = anomaly_df['Anomaly detected'].apply(lambda x: 0 if x is False else 1)

# %%
create_distance_df('Similarity between anomaly distributions for House 14: Cluster 0', Scenario1 = zero_cluster_results[14], Scenario2 = all_cluster_results[14],
                       Scenario3 = scenario_3_zero_cluster_results[14], Scenario4 = scenario_4_all_cluster_results[14]).round(decimals=2).to_csv('Tables/anomaly_cluster0.csv')
# Out:
# Similarity between anomaly distributions for House 14: Cluster 0
# /tmp/ipykernel_95546/1074003093.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anomaly_df['Anomaly detected'] = anomaly_df['Anomaly detected'].apply(lambda x: 0 if x is False else x)

# %%
create_anomalies_graph( 'Anomaly Frequency Distribution for House 15: Cluster 1', Scenario1 = one_cluster_results[15], Scenario2 = all_cluster_results[15],
                       Scenario3 = scenario_3_one_cluster_results[15], Scenario4 = scenario_4_all_cluster_results[15])
# Out:
# /tmp/ipykernel_95546/1074003093.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anomaly_df['Anomaly detected'] = anomaly_df['Anomaly detected'].apply(lambda x: 0 if x is False else 1)

# %%
create_distance_df( 'Similarity between anomaly distributions for House15: Cluster 1', Scenario1 = one_cluster_results[15], Scenario2 = all_cluster_results[15],
                       Scenario3 = scenario_3_one_cluster_results[15], Scenario4 = scenario_4_all_cluster_results[15]).round(decimals=2).to_csv('Tables/anomaly_cluster1.csv')
# Out:
# Similarity between anomaly distributions for House15: Cluster 1
# /tmp/ipykernel_95546/1074003093.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anomaly_df['Anomaly detected'] = anomaly_df['Anomaly detected'].apply(lambda x: 0 if x is False else x)

# %%
create_anomalies_graph( 'Anomaly Frequency Distribution for House 3: Cluster 2', Scenario1 = two_cluster_results[3], Scenario2 = all_cluster_results[3],
                       Scenario3 = scenario_3_two_cluster_results[3], Scenario4 = scenario_4_all_cluster_results[3])
# Out:
# /tmp/ipykernel_95546/1074003093.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anomaly_df['Anomaly detected'] = anomaly_df['Anomaly detected'].apply(lambda x: 0 if x is False else 1)

# %%
create_distance_df( 'Similarity between anomaly distributions for House 3: Cluster 2', Scenario1 = two_cluster_results[3], Scenario2 = all_cluster_results[3],
                       Scenario3 = scenario_3_two_cluster_results[3], Scenario4 = scenario_4_all_cluster_results[3]).round(decimals=2).to_csv('Tables/anomaly_cluster2.csv')
# Out:
# Similarity between anomaly distributions for House 3: Cluster 2
# /tmp/ipykernel_95546/1074003093.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anomaly_df['Anomaly detected'] = anomaly_df['Anomaly detected'].apply(lambda x: 0 if x is False else x)

# %%
create_anomalies_graph( 'Anomaly Frequency Distribution for House 2: Cluster 3', Scenario1 = three_cluster_results[2], Scenario2 = all_cluster_results[2],
                       Scenario3 = scenario_3_three_cluster_results[2], Scenario4 = scenario_4_all_cluster_results[2])
# Out:
# /tmp/ipykernel_95546/1074003093.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anomaly_df['Anomaly detected'] = anomaly_df['Anomaly detected'].apply(lambda x: 0 if x is False else 1)

# %%
create_distance_df( 'Similarity between anomaly distributions for House 2: Cluster 3', Scenario1 = three_cluster_results[2], Scenario2 = all_cluster_results[2],
                       Scenario3 = scenario_3_three_cluster_results[2], Scenario4 = scenario_4_all_cluster_results[2]).round(decimals=2).to_csv('Tables/anomaly_cluster3.csv')
# Out:
# Similarity between anomaly distributions for House 2: Cluster 3
# /tmp/ipykernel_95546/1074003093.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anomaly_df['Anomaly detected'] = anomaly_df['Anomaly detected'].apply(lambda x: 0 if x is False else x)

# %%
# create_anomalies_graph( 'Anomaly Frequency Distribution for House 5: Cluster 4', Scenario1 = four_cluster_results[5], Scenario2 = all_cluster_results[5],
#                        Scenario3 = scenario_3_four_cluster_results[5], Scenario4 = scenario_4_all_cluster_results[5])

# %%
# create_distance_df( 'Similarity between anomaly distributions for House 5: Cluster 4', Scenario1 = four_cluster_results[5], Scenario2 = all_cluster_results[5],
#                        Scenario3 = scenario_3_four_cluster_results[5], Scenario4 = scenario_4_all_cluster_results[5]).round(decimals=2).to_csv('Tables/anomaly_cluster3.csv')

# %% [markdown]
# ##### 2017 Graphs

# %%
create_anomalies_graph( 'Anomaly Frequency Distribution for House 14: Cluster 0',only2017=True, Scenario1 = zero_cluster_results[14], Scenario2 = all_cluster_results[14],
                       Scenario3 = scenario_3_zero_cluster_results[14], Scenario4 = scenario_4_all_cluster_results[14])

# %%
create_anomalies_graph( 'Anomaly Frequency Distribution for House 15: Cluster 1',only2017=True, Scenario1 = one_cluster_results[15], Scenario2 = all_cluster_results[15],
                       Scenario3 = scenario_3_one_cluster_results[15], Scenario4 = scenario_4_all_cluster_results[15])

# %%
create_anomalies_graph( 'Anomaly Frequency Distribution for House 3: Cluster 2',only2017=True,Scenario1 = two_cluster_results[3], Scenario2 = all_cluster_results[3],
                       Scenario3 = scenario_3_two_cluster_results[3], Scenario4 = scenario_4_all_cluster_results[3])

# %%
create_anomalies_graph( 'Anomaly Frequency Distribution for House 2: Cluster 3',only2017=True, Scenario1 = three_cluster_results[2], Scenario2 = all_cluster_results[2],
                       Scenario3 = scenario_3_three_cluster_results[2], Scenario4 = scenario_4_all_cluster_results[2])

# %%
# create_anomalies_graph( 'Anomaly Frequency Distribution for House 5: Cluster 4',only2017=True, Scenario1 = four_cluster_results[5], Scenario2 = all_cluster_results[5],
#                        Scenario3 = scenario_3_four_cluster_results[5], Scenario4 = scenario_4_all_cluster_results[5])

# %% [markdown]
# #### Energy Deficit Calculation

# %%
def create_deficit_df(result_df, scenario_name, monthly_agg = True, only2017=False):    
    #print(type(result_df))
    energy_df = result_df[['timestamp', 'Energy Deficit Flag']]
    if only2017:
        energy_df = energy_df[(energy_df['timestamp'] <= '2017-12-31') & (energy_df['timestamp'] >= '2017-01-01')]
    energy_df.set_index('timestamp', inplace = True)
    if monthly_agg:
        energy_df['Energy Deficit Flag'] = energy_df['Energy Deficit Flag'].apply(lambda x: 0 if x is False else 1)
        energy_df = energy_df.resample("W").agg('sum')
    else: 
        energy_df['Energy Deficit Flag'] = energy_df['Energy Deficit Flag'].apply(lambda x: 0 if x is False else x)
    energy_df = energy_df.rename(columns={'Energy Deficit Flag': scenario_name})
    
    
    return energy_df

def create_energy_deficit_graph( title = None,only2017=False, **kwargs):
    energy_dfs = []
    for scenario_name, result_df in kwargs.items():
        energy_df = create_deficit_df(result_df, scenario_name, only2017=only2017)
        energy_dfs.append(energy_df)
    energy_df = functools.reduce(lambda left, right: left.join(right), energy_dfs)
    ax = energy_df.plot.line(figsize=(20,10))
    ax.set_xlabel(f'Time')
    ax.set_ylabel(f'Frequency')
    ax.set_title(title)

# %%
def create_deficit_distance_df(title, **kwargs):
    print(title)
    energy_dfs = []
    for scenario_name, result_df in kwargs.items():
        energy_df = np.array(create_deficit_df(result_df, scenario_name, monthly_agg=False)).reshape(1,-1)
        energy_dfs.append(energy_df)
    energy_distributions = np.array(energy_dfs).reshape(len(kwargs),-1)
    distance_matrix = sd.squareform(sd.pdist(energy_distributions, dtw_distance))
    return(pd.DataFrame(distance_matrix, columns = kwargs.keys(), index = kwargs.keys()))

# %%
create_energy_deficit_graph( 'Energy Deficit Frequency Distribution for House 14: Cluster 0', Scenario1 = zero_cluster_results[14], Scenario2 = all_cluster_results[14],
                       Scenario3 = scenario_3_zero_cluster_results[14], Scenario4 = scenario_4_all_cluster_results[14])
# Out:
# /tmp/ipykernel_95546/120340542.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   energy_df['Energy Deficit Flag'] = energy_df['Energy Deficit Flag'].apply(lambda x: 0 if x is False else 1)

# %%
create_deficit_distance_df('Similarity between energy deficit distributions for House 14: Cluster 0', Scenario1 = zero_cluster_results[14], Scenario2 = all_cluster_results[14],
                       Scenario3 = scenario_3_zero_cluster_results[14], Scenario4 = scenario_4_all_cluster_results[14])
# Out:
# Similarity between energy deficit distributions for House 14: Cluster 0
# /tmp/ipykernel_95546/120340542.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   energy_df['Energy Deficit Flag'] = energy_df['Energy Deficit Flag'].apply(lambda x: 0 if x is False else x)
#               Scenario1     Scenario2     Scenario3     Scenario4
# Scenario1      0.000000  13458.744707   3351.943220  13915.917434
# Scenario2  13458.744707      0.000000  14237.610889   1508.500302
# Scenario3   3351.943220  14237.610889      0.000000  15205.780930
# Scenario4  13915.917434   1508.500302  15205.780930      0.000000

# %%
create_energy_deficit_graph( 'Energy Deficit Frequency Distribution for House 15: Cluster 1', Scenario1 = one_cluster_results[15], Scenario2 = all_cluster_results[15],
                       Scenario3 = scenario_3_one_cluster_results[15], Scenario4 = scenario_4_all_cluster_results[15])
# Out:
# /tmp/ipykernel_95546/120340542.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   energy_df['Energy Deficit Flag'] = energy_df['Energy Deficit Flag'].apply(lambda x: 0 if x is False else 1)

# %%
create_deficit_distance_df( 'Similarity between energy deficit distributions for House15: Cluster 1', Scenario1 = one_cluster_results[15], 
                    Scenario2 = all_cluster_results[15],
                       Scenario3 = scenario_3_one_cluster_results[15], Scenario4 = scenario_4_all_cluster_results[15])
# Out:
# Similarity between energy deficit distributions for House15: Cluster 1
# /tmp/ipykernel_95546/120340542.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   energy_df['Energy Deficit Flag'] = energy_df['Energy Deficit Flag'].apply(lambda x: 0 if x is False else x)
#              Scenario1    Scenario2    Scenario3    Scenario4
# Scenario1     0.000000  3025.537334  3488.993010  3258.748722
# Scenario2  3025.537334     0.000000  4575.465545  1706.600454
# Scenario3  3488.993010  4575.465545     0.000000  4266.962669
# Scenario4  3258.748722  1706.600454  4266.962669     0.000000

# %%
create_energy_deficit_graph( 'Energy Deficit Frequency Distribution for House 3: Cluster 2', Scenario1 = two_cluster_results[3], Scenario2 = all_cluster_results[3],
                       Scenario3 = scenario_3_two_cluster_results[3], Scenario4 = scenario_4_all_cluster_results[3])
# Out:
# /tmp/ipykernel_95546/120340542.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   energy_df['Energy Deficit Flag'] = energy_df['Energy Deficit Flag'].apply(lambda x: 0 if x is False else 1)

# %%
create_deficit_distance_df( 'Similarity between energy deficit distributions for House 3: Cluster 2', Scenario1 = two_cluster_results[3], Scenario2 = all_cluster_results[3],
                       Scenario3 = scenario_3_two_cluster_results[3], Scenario4 = scenario_4_all_cluster_results[3])
# Out:
# Similarity between energy deficit distributions for House 3: Cluster 2
# /tmp/ipykernel_95546/120340542.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   energy_df['Energy Deficit Flag'] = energy_df['Energy Deficit Flag'].apply(lambda x: 0 if x is False else x)
#              Scenario1    Scenario2    Scenario3    Scenario4
# Scenario1     0.000000  1711.213333  1429.533205  1827.493890
# Scenario2  1711.213333     0.000000  1954.688370  1075.921187
# Scenario3  1429.533205  1954.688370     0.000000  2021.977515
# Scenario4  1827.493890  1075.921187  2021.977515     0.000000

# %%
create_energy_deficit_graph( 'Energy Deficit Frequency Distribution for House 2: Cluster 3', Scenario1 = three_cluster_results[2], Scenario2 = all_cluster_results[2],
                       Scenario3 = scenario_3_three_cluster_results[2], Scenario4 = scenario_4_all_cluster_results[2])
# Out:
# /tmp/ipykernel_95546/120340542.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   energy_df['Energy Deficit Flag'] = energy_df['Energy Deficit Flag'].apply(lambda x: 0 if x is False else 1)

# %%
create_deficit_distance_df( 'Similarity between energy deficit distributions for House 2: Cluster 3', Scenario1 = three_cluster_results[2], Scenario2 = all_cluster_results[2],
                       Scenario3 = scenario_3_three_cluster_results[2], Scenario4 = scenario_4_all_cluster_results[2])
# Out:
# Similarity between energy deficit distributions for House 2: Cluster 3
# /tmp/ipykernel_95546/120340542.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   energy_df['Energy Deficit Flag'] = energy_df['Energy Deficit Flag'].apply(lambda x: 0 if x is False else x)
#             Scenario1   Scenario2    Scenario3    Scenario4
# Scenario1    0.000000  499.237425   621.478523   507.850244
# Scenario2  499.237425    0.000000   442.053090   374.798126
# Scenario3  621.478523  442.053090     0.000000  1016.755078
# Scenario4  507.850244  374.798126  1016.755078     0.000000

# %%
create_energy_deficit_graph( 'Energy Deficit Frequency Distribution for House 5: Cluster 4', Scenario1 = four_cluster_results[5], Scenario2 = all_cluster_results[5],
                       Scenario3 = scenario_3_four_cluster_results[5], Scenario4 = scenario_4_all_cluster_results[5])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_95546/198854930.py in <module>
# ----> 1 create_energy_deficit_graph( 'Energy Deficit Frequency Distribution for House 5: Cluster 4', Scenario1 = four_cluster_results[5], Scenario2 = all_cluster_results[5],
#       2                        Scenario3 = scenario_3_four_cluster_results[5], Scenario4 = scenario_4_all_cluster_results[5])
#
# NameError: name 'four_cluster_results' is not defined

# %%
# create_deficit_distance_df( 'Similarity between energy deficit distributions for House 5: Cluster 4', Scenario1 = four_cluster_results[5], Scenario2 = all_cluster_results[5],
#                        Scenario3 = scenario_3_four_cluster_results[5], Scenario4 = scenario_4_all_cluster_results[5])

# %% [markdown]
# #### 2017 deficit graphs

# %%
create_energy_deficit_graph( 'Energy Deficit Frequency Distribution for House 14: Cluster 0',only2017=True, Scenario1 = zero_cluster_results[14], Scenario2 = all_cluster_results[14],
                       Scenario3 = scenario_3_zero_cluster_results[14], Scenario4 = scenario_4_all_cluster_results[14])

# %%
create_energy_deficit_graph( 'Energy Deficit Frequency Distribution for House 15: Cluster 1',only2017=True, Scenario1 = one_cluster_results[15], Scenario2 = all_cluster_results[15],
                       Scenario3 = scenario_3_one_cluster_results[15], Scenario4 = scenario_4_all_cluster_results[15])

# %%
create_energy_deficit_graph( 'Energy Deficit Frequency Distribution for House 3: Cluster 2',only2017=True, Scenario1 = two_cluster_results[3], Scenario2 = all_cluster_results[3],
                       Scenario3 = scenario_3_two_cluster_results[3], Scenario4 = scenario_4_all_cluster_results[3])

# %%
create_energy_deficit_graph( 'Energy Deficit Frequency Distribution for House 2: Cluster 3',only2017=True, Scenario1 = three_cluster_results[2], Scenario2 = all_cluster_results[2],
                       Scenario3 = scenario_3_three_cluster_results[2], Scenario4 = scenario_4_all_cluster_results[2])

# %%
# create_energy_deficit_graph( 'Energy Deficit Frequency Distribution for House 5: Cluster 4',only2017=True, Scenario1 = four_cluster_results[5], Scenario2 = all_cluster_results[5],
#                        Scenario3 = scenario_3_four_cluster_results[5], Scenario4 = scenario_4_all_cluster_results[5])

# %%
scenario_4_all_cluster_results_file = open(f"Models/Scenario4/Objects/{model_name}/all_cluster_results.pickle", "wb")
pickle.dump(scenario_4_all_cluster_results, scenario_4_all_cluster_results_file)
scenario_4_all_cluster_results_file.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_95546/3127663111.py in <module>
# ----> 1 scenario_4_all_cluster_results_file = open(f"Models/Scenario4/Objects/{model_name}/all_cluster_results.pickle", "wb")
#       2 pickle.dump(scenario_4_all_cluster_results, scenario_4_all_cluster_results_file)
#       3 scenario_4_all_cluster_results_file.close()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Models/Scenario4/Objects/LSTM/all_cluster_results.pickle'
