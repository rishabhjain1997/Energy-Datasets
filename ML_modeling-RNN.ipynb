# %% [markdown]
# #### Importing Libraries and Dataset

# %%
import numpy as np
from statistics import mean
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import pandas as pd
import seaborn as sns
from tslearn.clustering import TimeSeriesKMeans
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, SimpleRNN 
from tensorflow.keras import regularizers
from tensorflow.keras.layers import Dense, Dropout
import tensorflow as tf
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from tensorflow import keras
import seaborn as sns
import pickle
import functools
import fastdtw
import scipy.spatial.distance as sd
#from datetime import datetime
consumption_df = pd.read_csv('Final Datasets/energy_consumption.csv')
consumption_df
# Out:
# 2022-04-27 17:09:19.031834: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-04-27 17:09:19.031862: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
#         Unnamed: 0            timestamp  energy_kWh  House Number  \
# 0                0  2012-06-01 01:00:00      1.0110             1
# 1                1  2012-06-01 02:00:00      0.4510             1
# 2                2  2012-06-01 03:00:00      0.5050             1
# 3                3  2012-06-01 04:00:00      0.4410             1
# 4                4  2012-06-01 05:00:00      0.4680             1
# ...            ...                  ...         ...           ...
# 611013      123761  2020-05-19 19:00:00      3.5802            28
# 611014      123762  2020-05-19 20:00:00      3.4398            28
# 611015      123763  2020-05-19 21:00:00      2.3049            28
# 611016      123764  2020-05-19 22:00:00      2.4921            28
# 611017      123765  2020-05-19 23:00:00      1.1817            28
#
#         electronics workbench energy  network equipment energy  \
# 0                           0.008686                  0.019316
# 1                           0.007178                  0.019338
# 2                           0.007324                  0.019336
# 3                           0.007151                  0.019339
# 4                           0.007224                  0.019338
# ...                              ...                       ...
# 611013                      0.028408                  0.038470
# 611014                      0.027762                  0.038479
# 611015                      0.022537                  0.038556
# 611016                      0.023399                  0.038544
# 611017                      0.017367                  0.038632
#
#         home office energy  RAE home office energy  \
# 0                 0.018232                0.134570
# 1                 0.013745                0.061839
# 2                 0.014177                0.068852
# 3                 0.013664                0.060540
# 4                 0.013881                0.064047
# ...                    ...                     ...
# 611013            0.069307                0.801381
# 611014            0.067384                0.770210
# 611015            0.051836                0.518247
# 611016            0.054401                0.559808
# 611017            0.036449                0.268881
#
#         RAE Mobile Phone Charger Energy
# 0                              0.000431
# 1                              0.000215
# 2                              0.000236
# 3                              0.000211
# 4                              0.000221
# ...                                 ...
# 611013                         0.002441
# 611014                         0.002348
# 611015                         0.001601
# 611016                         0.001724
# 611017                         0.000861
#
# [611018 rows x 9 columns]

# %%
if 'Unnamed: 0' in consumption_df.columns:
    consumption_df.drop('Unnamed: 0',axis=1, inplace = True)

# %%
consumption_df
# Out:
#                   timestamp  energy_kWh  House Number  \
# 0       2012-06-01 01:00:00      1.0110             1
# 1       2012-06-01 02:00:00      0.4510             1
# 2       2012-06-01 03:00:00      0.5050             1
# 3       2012-06-01 04:00:00      0.4410             1
# 4       2012-06-01 05:00:00      0.4680             1
# ...                     ...         ...           ...
# 611013  2020-05-19 19:00:00      3.5802            28
# 611014  2020-05-19 20:00:00      3.4398            28
# 611015  2020-05-19 21:00:00      2.3049            28
# 611016  2020-05-19 22:00:00      2.4921            28
# 611017  2020-05-19 23:00:00      1.1817            28
#
#         electronics workbench energy  network equipment energy  \
# 0                           0.008686                  0.019316
# 1                           0.007178                  0.019338
# 2                           0.007324                  0.019336
# 3                           0.007151                  0.019339
# 4                           0.007224                  0.019338
# ...                              ...                       ...
# 611013                      0.028408                  0.038470
# 611014                      0.027762                  0.038479
# 611015                      0.022537                  0.038556
# 611016                      0.023399                  0.038544
# 611017                      0.017367                  0.038632
#
#         home office energy  RAE home office energy  \
# 0                 0.018232                0.134570
# 1                 0.013745                0.061839
# 2                 0.014177                0.068852
# 3                 0.013664                0.060540
# 4                 0.013881                0.064047
# ...                    ...                     ...
# 611013            0.069307                0.801381
# 611014            0.067384                0.770210
# 611015            0.051836                0.518247
# 611016            0.054401                0.559808
# 611017            0.036449                0.268881
#
#         RAE Mobile Phone Charger Energy
# 0                              0.000431
# 1                              0.000215
# 2                              0.000236
# 3                              0.000211
# 4                              0.000221
# ...                                 ...
# 611013                         0.002441
# 611014                         0.002348
# 611015                         0.001601
# 611016                         0.001724
# 611017                         0.000861
#
# [611018 rows x 8 columns]

# %% [markdown]
# #### Converting Dataset to House-wise dictionary

# %%
house_wise_consumption = dict()
for house_number in consumption_df['House Number'].unique():
    house_data = consumption_df[consumption_df['House Number'] == house_number]
    house_wise_consumption[house_number] = house_data.copy()
house_wise_consumption[1]
# house_wise_consumption[14]['timestamp'].iloc[0]
# house_wise_consumption[14]['timestamp'].iloc[-1]
# house_wise_consumption[14]['House Number'].iloc[0]
# Out:
#                  timestamp  energy_kWh  House Number  \
# 0      2012-06-01 01:00:00       1.011             1
# 1      2012-06-01 02:00:00       0.451             1
# 2      2012-06-01 03:00:00       0.505             1
# 3      2012-06-01 04:00:00       0.441             1
# 4      2012-06-01 05:00:00       0.468             1
# ...                    ...         ...           ...
# 29226  2015-10-02 20:00:00       2.101             1
# 29227  2015-10-02 21:00:00       1.646             1
# 29228  2015-10-02 22:00:00       1.319             1
# 29229  2015-10-02 23:00:00       1.473             1
# 29230  2015-10-03 00:00:00       0.800             1
#
#        electronics workbench energy  network equipment energy  \
# 0                          0.008686                  0.019316
# 1                          0.007178                  0.019338
# 2                          0.007324                  0.019336
# 3                          0.007151                  0.019339
# 4                          0.007224                  0.019338
# ...                             ...                       ...
# 29226                      0.011621                  0.019273
# 29227                      0.010396                  0.019291
# 29228                      0.009516                  0.019304
# 29229                      0.009930                  0.019298
# 29230                      0.008118                  0.019324
#
#        home office energy  RAE home office energy  \
# 0                0.018232                0.134570
# 1                0.013745                0.061839
# 2                0.014177                0.068852
# 3                0.013664                0.060540
# 4                0.013881                0.064047
# ...                   ...                     ...
# 29226            0.026968                0.276137
# 29227            0.023322                0.217043
# 29228            0.020701                0.174573
# 29229            0.021935                0.194574
# 29230            0.016541                0.107166
#
#        RAE Mobile Phone Charger Energy
# 0                             0.000431
# 1                             0.000215
# 2                             0.000236
# 3                             0.000211
# 4                             0.000221
# ...                                ...
# 29226                         0.000851
# 29227                         0.000675
# 29228                         0.000549
# 29229                         0.000609
# 29230                         0.000349
#
# [29231 rows x 8 columns]

# %%
# TODO: Print the usage pattern in form of a graph
# Each cluster represents one line in the time series graph
# Plot december consumption (2017) values for each house belonging to the same cluster in a single graph
# Also plot for the whole year (annual 2017) for each house belonging to the same cluster in a single graph

# %% [markdown]
# #### Comparing Timestamps for clustering

# %%
timestamp_comparison = list()
for house in house_wise_consumption:
    first_timestamp = house_wise_consumption[house]['timestamp'].iloc[0]
    last_timestamp = house_wise_consumption[house]['timestamp'].iloc[-1]
    timestamp_comparison.append([house, first_timestamp, last_timestamp])
timestamp_comparison
timestamp_comparison_df = pd.DataFrame(timestamp_comparison, columns = ['House', 'First Timestamp', 'Last Timestamp'])
timestamp_comparison_df
# Out:
#     House      First Timestamp       Last Timestamp
# 0       1  2012-06-01 01:00:00  2015-10-03 00:00:00
# 1       2  2016-06-09 00:00:00  2019-11-20 23:00:00
# 2       3  2015-01-27 00:00:00  2018-01-29 23:00:00
# 3       4  2015-01-30 00:00:00  2018-01-29 23:00:00
# 4       5  2015-01-30 00:00:00  2018-01-29 23:00:00
# 5       6  2015-01-30 00:00:00  2018-01-29 23:00:00
# 6       7  2015-05-30 00:00:00  2018-01-29 23:00:00
# 7       8  2015-02-21 00:00:00  2018-02-20 23:00:00
# 8       9  2015-05-01 00:00:00  2018-02-21 23:00:00
# 9      10  2015-02-21 00:00:00  2018-02-20 23:00:00
# 10     11  2015-02-21 00:00:00  2018-02-20 23:00:00
# 11     12  2015-02-21 00:00:00  2018-02-20 23:00:00
# 12     13  2015-02-21 00:00:00  2018-02-20 23:00:00
# 13     14  2015-02-21 00:00:00  2018-02-20 23:00:00
# 14     15  2015-09-29 00:00:00  2018-02-20 23:00:00
# 15     16  2017-11-01 00:00:00  2019-02-18 23:00:00
# 16     17  2016-06-01 00:00:00  2017-04-29 23:00:00
# 17     18  2015-03-16 00:00:00  2018-03-15 16:00:00
# 18     19  2015-03-26 00:00:00  2018-03-25 23:00:00
# 19     20  2015-08-21 00:00:00  2018-04-20 23:00:00
# 20     21  2017-11-01 00:00:00  2018-06-04 23:00:00
# 21     22  2016-06-29 00:00:00  2018-06-05 23:00:00
# 22     23  2017-07-27 00:00:00  2020-04-05 23:00:00
# 23     24  2017-05-13 00:00:00  2020-05-12 23:00:00
# 24     25  2017-05-15 00:00:00  2020-05-14 23:00:00
# 25     26  2019-11-29 00:00:00  2020-05-20 23:00:00
# 26     27  2019-03-06 00:00:00  2020-05-20 23:00:00
# 27     28  2018-08-01 00:00:00  2020-05-19 23:00:00

# %%
# houses_with_ts = []
# sample_timestamp = '2017-11-01 00:00:00'
# for house in house_wise_consumption:
#     if sample_timestamp in house_wise_consumption[house]['timestamp'].unique():
#         houses_with_ts.append(house)
# len(houses_with_ts)
#house_wise_consumption[8][house_wise_consumption[8]['timestamp'] >= '2017-11-17'].head(60)

# %% [markdown]
# #### Creating a December consumption dictionary of dataframes

# %%
december_consumption = dict()
for house in house_wise_consumption:
    house_december_consumption = house_wise_consumption[house][(house_wise_consumption[house]['timestamp'] <= '2017-11-25') & (house_wise_consumption[house]['timestamp'] >= '2017-11-01')]
    december_consumption[house] = house_december_consumption.copy()
    december_consumption[house].drop_duplicates(subset='timestamp', keep="last", inplace = True)
def calculate_rows():
    december_rows = []
    for house in december_consumption:
        december_rows.append([house, len(december_consumption[house])])
    december_rows
    december_rows_df = pd.DataFrame(december_rows, columns = ['House', 'Rows'])
    return december_rows_df
def calculate_incomplete_rows():
    december_rows_df = calculate_rows()
    december_rows_incomplete_df = december_rows_df[(december_rows_df['Rows'] > 0) & (december_rows_df['Rows'] < 576)]
    return december_rows_incomplete_df
def fill_na_december_consumption(complete_df, incomplete_df):
    complete_df = complete_df.copy()
    year_incomplete = pd.Timestamp(incomplete_df.iloc[0]['timestamp']).year
    year_complete = pd.Timestamp(complete_df.iloc[0]['timestamp']).year
    complete_df['timestamp'] = complete_df['timestamp'].str.replace(str(year_complete), str(year_incomplete))
    fill_missing_values = complete_df[~complete_df.timestamp.isin(incomplete_df.timestamp)].copy()
    #print(fill_missing_values)
    fill_columns = ['energy_kWh', 'electronics workbench energy', 'network equipment energy', 'home office energy', 'RAE home office energy','RAE Mobile Phone Charger Energy']
    for fill_column in fill_columns:
        fill_missing_values[fill_column] = incomplete_df[fill_column].mean()
    incomplete_df = pd.concat([incomplete_df, fill_missing_values])
    incomplete_df = incomplete_df.sort_values(by=['timestamp'])
    return incomplete_df
def calculate_missing_december_rows():
    december_rows_df = calculate_rows()
    december_rows_missing_df = december_rows_df[(december_rows_df['Rows'] == 0)]
    return december_rows_missing_df
calculate_rows()
# Out:
#     House  Rows
# 0       1     0
# 1       2   576
# 2       3   576
# 3       4   576
# 4       5   576
# 5       6   576
# 6       7   576
# 7       8   448
# 8       9   576
# 9      10   576
# 10     11   568
# 11     12   528
# 12     13   576
# 13     14   575
# 14     15   576
# 15     16   456
# 16     17     0
# 17     18   528
# 18     19   576
# 19     20   575
# 20     21   576
# 21     22   528
# 22     23   576
# 23     24   576
# 24     25   576
# 25     26     0
# 26     27     0
# 27     28     0

# %%
for house in list(calculate_incomplete_rows()['House']):
    december_consumption[house] = fill_na_december_consumption(december_consumption[10], december_consumption[house])

# %% [markdown]
# ##### Houses with no December-17 consumption values

# %%
timestamp_comparison_df.set_index('House').join(calculate_missing_december_rows().set_index('House'), how='inner')
# Out:
#            First Timestamp       Last Timestamp  Rows
# House
# 1      2012-06-01 01:00:00  2015-10-03 00:00:00     0
# 17     2016-06-01 00:00:00  2017-04-29 23:00:00     0
# 26     2019-11-29 00:00:00  2020-05-20 23:00:00     0
# 27     2019-03-06 00:00:00  2020-05-20 23:00:00     0
# 28     2018-08-01 00:00:00  2020-05-19 23:00:00     0

# %%
missing_december_houses_dates = {
    1: ['2014-11-25', '2014-11-01'],
    17: ['2016-11-25', '2016-11-01'],
    26: ['2019-11-25', '2019-11-01'],
    27: ['2019-11-25', '2019-11-01'],
    28: ['2019-11-25', '2019-11-01'],
}

# %%
for house in missing_december_houses_dates:
    house_december_consumption = house_wise_consumption[house][(house_wise_consumption[house]['timestamp'] <= missing_december_houses_dates[house][0]) & (house_wise_consumption[house]['timestamp'] >= missing_december_houses_dates[house][1])]
    #print((house, missing_december_houses_dates[house][0]))
    december_consumption[house] = house_december_consumption.copy()
    december_consumption[house].drop_duplicates(subset='timestamp', keep="last", inplace = True)

# %% [markdown]
# ##### Filling missing values for December consumption

# %%
calculate_incomplete_rows()
# Out:
#     House  Rows
# 16     17   574
# 26     27   571
# 27     28   572

# %%
for house in list(calculate_incomplete_rows()['House']):
    december_consumption[house] = fill_na_december_consumption(december_consumption[10], december_consumption[house])

# %%
#calculate_rows()december_consumption

# %% [markdown]
# #### Houses to be clustered

# %%
##print('Houses to be clustered: ')
clustered_df = calculate_rows()[calculate_rows()['Rows'] ==  576]
clustered_df
# Out:
#     House  Rows
# 0       1   576
# 1       2   576
# 2       3   576
# 3       4   576
# 4       5   576
# 5       6   576
# 6       7   576
# 7       8   576
# 8       9   576
# 9      10   576
# 10     11   576
# 11     12   576
# 12     13   576
# 13     14   576
# 14     15   576
# 15     16   576
# 16     17   576
# 17     18   576
# 18     19   576
# 19     20   576
# 20     21   576
# 21     22   576
# 22     23   576
# 23     24   576
# 24     25   576
# 26     27   576
# 27     28   576

# %% [markdown]
# #### Converting to clustering matrix

# %%
clustering_matrix = []
for house in calculate_rows()[calculate_rows()['Rows'] ==  576]['House']:
    clustering_matrix.append(np.array(december_consumption[house]['energy_kWh']).reshape(-1,1))
clustering_matrix = np.array(clustering_matrix)
clustering_matrix.shape
# Out:
# (27, 576, 1)

# %% [markdown]
# #### Time series clustering of all households except house 26

# %%
# km_sdtw = TimeSeriesKMeans(n_clusters=4, metric="softdtw", max_iter=5,
#                             max_iter_barycenter=5,
#                             metric_params={"gamma": .5},
#                             random_state=0).fit_predict(clustering_matrix)

# %%
# len(km_sdtw)

# %%
# clustered_df['Cluster'] = km_sdtw

# %%
#clustered_df = clustered_df[['House', 'Cluster']].set_index('House')
# clustered_df[clustered_df['Cluster'] == 3]

# %%
clustered_df = pd.read_csv('Tables/clustered.csv')
clustered_df
# Out:
#     House  Cluster
# 0       1        0
# 1       2        2
# 2       3        3
# 3       4        0
# 4       5        3
# 5       6        2
# 6       7        2
# 7       8        2
# 8       9        2
# 9      10        2
# 10     11        2
# 11     12        2
# 12     13        0
# 13     14        0
# 14     15        1
# 15     16        2
# 16     17        2
# 17     18        0
# 18     19        0
# 19     20        2
# 20     21        2
# 21     22        2
# 22     23        2
# 23     24        2
# 24     25        2
# 25     27        3
# 26     28        0

# %% [markdown]
# #### Used Scenarios

# %%
data = [[1, 4, 6, 'Yes'], [2, 1, 6, 'Yes'], [3, 4, 1, 'No'], [4, 1, 1, 'No']]
df = pd.DataFrame(data, columns = ['Scenarios', 'No. of subsets', 'No. of features', 'Smart devices included in modeling?']).set_index('Scenarios')
df
# Out:
#            No. of subsets  No. of features Smart devices included in modeling?
# Scenarios
# 1                       4                6                                 Yes
# 2                       1                6                                 Yes
# 3                       4                1                                  No
# 4                       1                1                                  No

# %% [markdown]
# #### Time-series LSTM-based predictive modeling

# %%
n_past = 12
n_future = 1

# %%
### Energy generation dataframe
generation_df = pd.read_csv('Final Datasets/energy_generation.csv')
generation_df
# Out:
#                  timestamp  Wind Energy  Solar Energy
# 0      2012-01-01 00:00:00     0.168265           0.0
# 1      2012-01-01 01:00:00     0.168265           0.0
# 2      2012-01-01 02:00:00     0.168265           0.0
# 3      2012-01-01 03:00:00     0.168265           0.0
# 4      2012-01-01 04:00:00     0.168265           0.0
# ...                    ...          ...           ...
# 78907  2020-12-31 19:00:00     1.710441           0.0
# 78908  2020-12-31 20:00:00     1.710441           0.0
# 78909  2020-12-31 21:00:00     1.497873           0.0
# 78910  2020-12-31 22:00:00     1.285454           0.0
# 78911  2020-12-31 23:00:00     1.286778           0.0
#
# [78912 rows x 3 columns]

# %%
class House:
    cols = ['energy_kWh', 'electronics workbench energy', 'network equipment energy',
            'home office energy', 'RAE home office energy', 'RAE Mobile Phone Charger Energy']
    def __init__(self, house):
        self.house = house
        self.consumption_df = house_wise_consumption[house].copy()[House.cols].astype(float)
        self.train_dates_df = house_wise_consumption[house]['timestamp']
        self.prepare_dataset(n_future, n_past)
    
    def __repr__(self):
        return str(self.house)
    
    def prepare_dataset(self, n_future = 1, n_past = 12):
        #Empty lists to be populated using formatted training data
        trainX = []
        trainY = []
        consumption_np = np.array(self.consumption_df)
        #Reformat input data into a shape: (n_samples x timesteps x n_features)
        #In my example, my self.consumption_df has a shape (12823, 5)
        #12823 refers to the number of data points and 5 refers to the columns (multi-variables).
        for i in range(n_past, len(consumption_np) - n_future +1):
            trainX.append(consumption_np[i - n_past:i, 0:self.consumption_df.shape[1]])
            trainY.append(consumption_np[i + n_future - 1:i + n_future, 0])

        trainX, trainY = np.array(trainX), np.array(trainY)

        #print('trainX shape == {}.'.format(trainX.shape))
        #print('trainY shape == {}.'.format(trainY.shape))
        self.trainX = trainX
        self.trainY = trainY

class Cluster: 
    def __init__(self, houses):
        self.houses = [House(house) for house in houses]
        self.trainX_list = (list(map(lambda x: x.trainX, self.houses)))
        self.trainY_list = (list(map(lambda x: x.trainY, self.houses)))
        self.train_dates_list = (list(map(lambda x: x.train_dates_df, self.houses)))
        self.consumption_df_list = (list(map(lambda x: x.consumption_df, self.houses)))
        self.prepare_dataset()
        
    
    def prepare_dataset(self):
        
        self.train_dates = np.concatenate(self.train_dates_list, axis=0)
        ## TODO - Replace concatenate with for loop or sort by time
        self.X = np.concatenate(self.trainX_list, axis=0)
        self.Y = np.concatenate(self.trainY_list, axis=0)
    
    
    def prepare_ANN_model(self):
        model = Sequential()
        #model.add(Dense(1, activation='relu', input_shape=(self.X.shape[1], self.X.shape[2])))
        model.add(Dense(128, activation='relu', input_shape=(self.X.shape[1], self.X.shape[2]), return_sequences=True))
        model.add(Dense(32, activation='relu', return_sequences=True))
        model.add(Dense(16, activation='relu', return_sequences=False))
        model.add(Dense(self.Y.shape[1]))
        model.compile(optimizer='adam', loss='mse', metrics=[tf.keras.metrics.RootMeanSquaredError(), tf.keras.metrics.MeanAbsoluteError()])
        model.summary()
        return model
    
    def prepare_RNN_model(self):
        model = Sequential()
        #model.add(SimpleRNN(1, activation='relu', input_shape=(self.X.shape[1], self.X.shape[2]), return_sequences=True))
        model.add(SimpleRNN(128, activation='tanh', input_shape=(self.X.shape[1], self.X.shape[2]), return_sequences=True))
        model.add(SimpleRNN(32, activation='tanh', return_sequences=True))
        model.add(SimpleRNN(16, activation='tanh', return_sequences=False))
        model.add(Dense(self.Y.shape[1]))
        model.compile(optimizer='adam', loss='mse', metrics=[tf.keras.metrics.RootMeanSquaredError(), tf.keras.metrics.MeanAbsoluteError(), tf.keras.metrics.MeanAbsolutePercentageError(), tf.keras.metrics.MeanSquaredError()])
        model.summary()
        return model
    
    def prepare_LSTM_model(self):
        model = Sequential()
        #model.add(LSTM(1, activation='relu', input_shape=(self.X.shape[1], self.X.shape[2]), return_sequences=True))
        model.add(LSTM(128, activation='relu', input_shape=(self.X.shape[1], self.X.shape[2]), return_sequences=True))
        model.add(LSTM(32, activation='relu', return_sequences=True))
        model.add(LSTM(16, activation='relu', return_sequences=False))
        model.add(Dense(self.Y.shape[1]))
        model.compile(optimizer='adam', loss='mse', metrics=[tf.keras.metrics.RootMeanSquaredError(), tf.keras.metrics.MeanAbsoluteError()])
        model.summary()
        return model
    
    def train_model(self, model_name='LSTM'):
        if model_name == 'LSTM':
            model = self.prepare_LSTM_model()
        if model_name == 'RNN':
            model = self.prepare_RNN_model()    
        if model_name == 'ANN':
            model = self.prepare_ANN_model()    
        history = model.fit(self.X, self.Y, epochs=10, batch_size=16, validation_split=0.3, verbose=1) # Change to 30
        self.history = history
        plt.plot(history.history['loss'], label='Training loss')
        plt.plot(history.history['val_loss'], label='Testing loss')
        
        plt.legend()
        return model
    
    def predicted(self, model_name='LSTM'):
        model = self.train_model(model_name)
        predictions = list(map(lambda x: pd.Series(model.predict(x).reshape(1,-1)[0]), self.trainX_list))
        #return pd.Series(model.predict(self.X).reshape(1,-1)[0])
        self.model = model
        return dict(zip(self.houses, predictions))
    
    def results(self, model_name='LSTM'):
        predicted = self.predicted(model_name)
        house_prediction_list_df  = {}
        for house in predicted:
            house_prediction_df = house.consumption_df.iloc[n_past:].copy().reset_index(drop=True)
            house_prediction_df['timestamp'] = house.train_dates_df.iloc[n_past:].copy().reset_index(drop=True)
            house_prediction_df['energy_predicted'] = predicted[house]
            ### Anomaly Detection
            energy_stddev = house_prediction_df['energy_kWh'].std()
            house_prediction_df['Energy Consumption Error'] = house_prediction_df['energy_predicted'] - house_prediction_df['energy_kWh']
            house_prediction_df['Anomaly detected'] = house_prediction_df['Energy Consumption Error'].apply(lambda x: False if abs(x) < 1.5*energy_stddev else abs(x))
            ### Energy Deficit Calculation
            house_prediction_df['timestamp'] = pd.DatetimeIndex(house_prediction_df['timestamp'])
            generation_df['timestamp'] = pd.DatetimeIndex(generation_df['timestamp'])
            house_prediction_df = house_prediction_df.set_index('timestamp').join(generation_df.set_index('timestamp'))
            house_prediction_df['timestamp'] = house_prediction_df.index
            house_prediction_df.reset_index(drop=True, inplace=True)
            house_prediction_df['Total Generated Energy'] = house_prediction_df['Wind Energy']+ house_prediction_df['Solar Energy']
            house_prediction_df['Predicted Energy Deficit'] = house_prediction_df['Total Generated Energy'] - house_prediction_df['energy_predicted']
            house_prediction_df['Energy Deficit Flag'] = house_prediction_df['Predicted Energy Deficit'].apply(lambda x: False if x>0 else abs(x))
            house_prediction_list_df[house.house] = house_prediction_df
        return house_prediction_list_df

# %% [markdown]
# ## Model Name

# %%
model_name='RNN'

# %% [markdown]
# #### Scenario 1

# %%
# Train the time series model, perform predictions and answer the three research questions
zero_houses = list(clustered_df[clustered_df['Cluster'] == 0]['House'])
print(zero_houses)
zero_cluster = Cluster(zero_houses)
zero_cluster_results = zero_cluster.results(model_name)
print('Training History for Cluster 0:')
# Out:
# [1, 4, 13, 14, 18, 19, 28]
# 2022-04-27 17:09:22.938697: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-04-27 17:09:22.938741: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-04-27 17:09:22.938761: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (rishabh-Inspiron): /proc/driver/nvidia/version does not exist
# 2022-04-27 17:09:22.938931: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 12, 128)           17280
#
#  simple_rnn_1 (SimpleRNN)    (None, 12, 32)            5152
#
#  simple_rnn_2 (SimpleRNN)    (None, 16)                784
#
#  dense (Dense)               (None, 1)                 17
#
# =================================================================
# Total params: 23,233
# Trainable params: 23,233
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 7681/7681 [==============================] - 70s 9ms/step - loss: 0.4768 - root_mean_squared_error: 0.6905 - mean_absolute_error: 0.4232 - mean_absolute_percentage_error: 282237.4688 - mean_squared_error: 0.4768 - val_loss: 0.6095 - val_root_mean_squared_error: 0.7807 - val_mean_absolute_error: 0.4598 - val_mean_absolute_percentage_error: 155060.3906 - val_mean_squared_error: 0.6095
# Epoch 2/10
# 7681/7681 [==============================] - 62s 8ms/step - loss: 0.4649 - root_mean_squared_error: 0.6818 - mean_absolute_error: 0.4146 - mean_absolute_percentage_error: 311648.7188 - mean_squared_error: 0.4649 - val_loss: 0.6165 - val_root_mean_squared_error: 0.7852 - val_mean_absolute_error: 0.4785 - val_mean_absolute_percentage_error: 165366.9531 - val_mean_squared_error: 0.6165
# Epoch 3/10
# 7681/7681 [==============================] - 60s 8ms/step - loss: 0.4610 - root_mean_squared_error: 0.6790 - mean_absolute_error: 0.4116 - mean_absolute_percentage_error: 334517.1562 - mean_squared_error: 0.4610 - val_loss: 0.7051 - val_root_mean_squared_error: 0.8397 - val_mean_absolute_error: 0.4683 - val_mean_absolute_percentage_error: 128732.9922 - val_mean_squared_error: 0.7051
# Epoch 4/10
# 7681/7681 [==============================] - 77s 10ms/step - loss: 0.4666 - root_mean_squared_error: 0.6830 - mean_absolute_error: 0.4171 - mean_absolute_percentage_error: 322851.2500 - mean_squared_error: 0.4666 - val_loss: 0.6341 - val_root_mean_squared_error: 0.7963 - val_mean_absolute_error: 0.4811 - val_mean_absolute_percentage_error: 170615.7500 - val_mean_squared_error: 0.6341
# Epoch 5/10
# 7681/7681 [==============================] - 79s 10ms/step - loss: 0.4832 - root_mean_squared_error: 0.6951 - mean_absolute_error: 0.4241 - mean_absolute_percentage_error: 315798.1562 - mean_squared_error: 0.4832 - val_loss: 0.6648 - val_root_mean_squared_error: 0.8154 - val_mean_absolute_error: 0.4787 - val_mean_absolute_percentage_error: 184811.4688 - val_mean_squared_error: 0.6648
# Epoch 6/10
# 7681/7681 [==============================] - 76s 10ms/step - loss: 0.4693 - root_mean_squared_error: 0.6850 - mean_absolute_error: 0.4184 - mean_absolute_percentage_error: 322275.6562 - mean_squared_error: 0.4693 - val_loss: 0.6460 - val_root_mean_squared_error: 0.8038 - val_mean_absolute_error: 0.4858 - val_mean_absolute_percentage_error: 214093.9844 - val_mean_squared_error: 0.6460
# Epoch 7/10
# 7681/7681 [==============================] - 89s 12ms/step - loss: 0.4685 - root_mean_squared_error: 0.6844 - mean_absolute_error: 0.4176 - mean_absolute_percentage_error: 336672.2812 - mean_squared_error: 0.4685 - val_loss: 0.6533 - val_root_mean_squared_error: 0.8083 - val_mean_absolute_error: 0.4674 - val_mean_absolute_percentage_error: 173449.0781 - val_mean_squared_error: 0.6533
# Epoch 8/10
# 7681/7681 [==============================] - 91s 12ms/step - loss: 0.4698 - root_mean_squared_error: 0.6854 - mean_absolute_error: 0.4190 - mean_absolute_percentage_error: 364705.5625 - mean_squared_error: 0.4698 - val_loss: 0.6884 - val_root_mean_squared_error: 0.8297 - val_mean_absolute_error: 0.5053 - val_mean_absolute_percentage_error: 169279.2344 - val_mean_squared_error: 0.6884
# Epoch 9/10
# 7681/7681 [==============================] - 89s 12ms/step - loss: 0.4671 - root_mean_squared_error: 0.6835 - mean_absolute_error: 0.4190 - mean_absolute_percentage_error: 346599.0625 - mean_squared_error: 0.4671 - val_loss: 0.7233 - val_root_mean_squared_error: 0.8505 - val_mean_absolute_error: 0.4925 - val_mean_absolute_percentage_error: 118399.8203 - val_mean_squared_error: 0.7233
# Epoch 10/10
# 7681/7681 [==============================] - 86s 11ms/step - loss: 0.4647 - root_mean_squared_error: 0.6817 - mean_absolute_error: 0.4175 - mean_absolute_percentage_error: 337927.2812 - mean_squared_error: 0.4647 - val_loss: 0.6874 - val_root_mean_squared_error: 0.8291 - val_mean_absolute_error: 0.4792 - val_mean_absolute_percentage_error: 134252.4844 - val_mean_squared_error: 0.6874
# Training History for Cluster 0:

# %%
one_houses = list(clustered_df[clustered_df['Cluster'] == 1]['House'])
one_cluster = Cluster(one_houses)
one_cluster_results = one_cluster.results(model_name)
print('Training History for Cluster 1:')
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_3 (SimpleRNN)    (None, 12, 128)           17280
#
#  simple_rnn_4 (SimpleRNN)    (None, 12, 32)            5152
#
#  simple_rnn_5 (SimpleRNN)    (None, 16)                784
#
#  dense_1 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 23,233
# Trainable params: 23,233
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 915/915 [==============================] - 9s 8ms/step - loss: 1.1358 - root_mean_squared_error: 1.0657 - mean_absolute_error: 0.6183 - mean_absolute_percentage_error: 74.2602 - mean_squared_error: 1.1358 - val_loss: 1.3705 - val_root_mean_squared_error: 1.1707 - val_mean_absolute_error: 0.5612 - val_mean_absolute_percentage_error: 72.4819 - val_mean_squared_error: 1.3705
# Epoch 2/10
# 915/915 [==============================] - 7s 8ms/step - loss: 0.9896 - root_mean_squared_error: 0.9948 - mean_absolute_error: 0.5736 - mean_absolute_percentage_error: 71.1257 - mean_squared_error: 0.9896 - val_loss: 1.5853 - val_root_mean_squared_error: 1.2591 - val_mean_absolute_error: 0.5790 - val_mean_absolute_percentage_error: 64.1649 - val_mean_squared_error: 1.5853
# Epoch 3/10
# 915/915 [==============================] - 7s 8ms/step - loss: 0.9804 - root_mean_squared_error: 0.9902 - mean_absolute_error: 0.5648 - mean_absolute_percentage_error: 68.9703 - mean_squared_error: 0.9804 - val_loss: 1.4409 - val_root_mean_squared_error: 1.2004 - val_mean_absolute_error: 0.5239 - val_mean_absolute_percentage_error: 52.8779 - val_mean_squared_error: 1.4409
# Epoch 4/10
# 915/915 [==============================] - 7s 8ms/step - loss: 0.9012 - root_mean_squared_error: 0.9493 - mean_absolute_error: 0.5522 - mean_absolute_percentage_error: 70.4214 - mean_squared_error: 0.9012 - val_loss: 1.7120 - val_root_mean_squared_error: 1.3084 - val_mean_absolute_error: 0.6051 - val_mean_absolute_percentage_error: 83.8980 - val_mean_squared_error: 1.7120
# Epoch 5/10
# 915/915 [==============================] - 7s 8ms/step - loss: 0.9171 - root_mean_squared_error: 0.9576 - mean_absolute_error: 0.5519 - mean_absolute_percentage_error: 68.4852 - mean_squared_error: 0.9171 - val_loss: 1.3790 - val_root_mean_squared_error: 1.1743 - val_mean_absolute_error: 0.5836 - val_mean_absolute_percentage_error: 87.4437 - val_mean_squared_error: 1.3790
# Epoch 6/10
# 915/915 [==============================] - 7s 8ms/step - loss: 0.8664 - root_mean_squared_error: 0.9308 - mean_absolute_error: 0.5381 - mean_absolute_percentage_error: 66.2890 - mean_squared_error: 0.8664 - val_loss: 1.3206 - val_root_mean_squared_error: 1.1492 - val_mean_absolute_error: 0.5587 - val_mean_absolute_percentage_error: 76.8883 - val_mean_squared_error: 1.3206
# Epoch 7/10
# 915/915 [==============================] - 7s 8ms/step - loss: 0.8585 - root_mean_squared_error: 0.9265 - mean_absolute_error: 0.5304 - mean_absolute_percentage_error: 64.8995 - mean_squared_error: 0.8585 - val_loss: 1.3905 - val_root_mean_squared_error: 1.1792 - val_mean_absolute_error: 0.6431 - val_mean_absolute_percentage_error: 115.4077 - val_mean_squared_error: 1.3905
# Epoch 8/10
# 915/915 [==============================] - 7s 8ms/step - loss: 0.9075 - root_mean_squared_error: 0.9527 - mean_absolute_error: 0.5411 - mean_absolute_percentage_error: 67.7106 - mean_squared_error: 0.9075 - val_loss: 1.2234 - val_root_mean_squared_error: 1.1061 - val_mean_absolute_error: 0.5842 - val_mean_absolute_percentage_error: 92.3863 - val_mean_squared_error: 1.2234
# Epoch 9/10
# 915/915 [==============================] - 7s 8ms/step - loss: 0.8872 - root_mean_squared_error: 0.9419 - mean_absolute_error: 0.5363 - mean_absolute_percentage_error: 65.9267 - mean_squared_error: 0.8872 - val_loss: 1.3111 - val_root_mean_squared_error: 1.1450 - val_mean_absolute_error: 0.5823 - val_mean_absolute_percentage_error: 89.7596 - val_mean_squared_error: 1.3111
# Epoch 10/10
# 915/915 [==============================] - 7s 8ms/step - loss: 0.8691 - root_mean_squared_error: 0.9322 - mean_absolute_error: 0.5336 - mean_absolute_percentage_error: 65.1077 - mean_squared_error: 0.8691 - val_loss: 1.4191 - val_root_mean_squared_error: 1.1912 - val_mean_absolute_error: 0.5905 - val_mean_absolute_percentage_error: 88.5316 - val_mean_squared_error: 1.4191
# Training History for Cluster 1:

# %%
two_houses = list(clustered_df[clustered_df['Cluster'] == 2]['House'])
two_cluster = Cluster(two_houses)
two_cluster_results = two_cluster.results(model_name)
print('Training History for Cluster 2:')
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_6 (SimpleRNN)    (None, 12, 128)           17280
#
#  simple_rnn_7 (SimpleRNN)    (None, 12, 32)            5152
#
#  simple_rnn_8 (SimpleRNN)    (None, 16)                784
#
#  dense_2 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 23,233
# Trainable params: 23,233
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 15196/15196 [==============================] - 121s 8ms/step - loss: 0.1526 - root_mean_squared_error: 0.3907 - mean_absolute_error: 0.2224 - mean_absolute_percentage_error: 297718.9688 - mean_squared_error: 0.1526 - val_loss: 0.2199 - val_root_mean_squared_error: 0.4690 - val_mean_absolute_error: 0.3030 - val_mean_absolute_percentage_error: 46682.1719 - val_mean_squared_error: 0.2199
# Epoch 2/10
# 15196/15196 [==============================] - 121s 8ms/step - loss: 0.1487 - root_mean_squared_error: 0.3856 - mean_absolute_error: 0.2159 - mean_absolute_percentage_error: 255008.1562 - mean_squared_error: 0.1487 - val_loss: 0.2094 - val_root_mean_squared_error: 0.4576 - val_mean_absolute_error: 0.2716 - val_mean_absolute_percentage_error: 36334.8281 - val_mean_squared_error: 0.2094
# Epoch 3/10
# 15196/15196 [==============================] - 121s 8ms/step - loss: 0.1538 - root_mean_squared_error: 0.3922 - mean_absolute_error: 0.2242 - mean_absolute_percentage_error: 440581.4688 - mean_squared_error: 0.1538 - val_loss: 0.2150 - val_root_mean_squared_error: 0.4637 - val_mean_absolute_error: 0.2789 - val_mean_absolute_percentage_error: 39861.9102 - val_mean_squared_error: 0.2150
# Epoch 4/10
# 15196/15196 [==============================] - 121s 8ms/step - loss: 0.1546 - root_mean_squared_error: 0.3932 - mean_absolute_error: 0.2262 - mean_absolute_percentage_error: 492476.7500 - mean_squared_error: 0.1546 - val_loss: 0.2187 - val_root_mean_squared_error: 0.4677 - val_mean_absolute_error: 0.2501 - val_mean_absolute_percentage_error: 33819.6602 - val_mean_squared_error: 0.2187
# Epoch 5/10
# 15196/15196 [==============================] - 121s 8ms/step - loss: 0.1534 - root_mean_squared_error: 0.3917 - mean_absolute_error: 0.2244 - mean_absolute_percentage_error: 377160.4062 - mean_squared_error: 0.1534 - val_loss: 0.2199 - val_root_mean_squared_error: 0.4690 - val_mean_absolute_error: 0.2585 - val_mean_absolute_percentage_error: 29029.6875 - val_mean_squared_error: 0.2199
# Epoch 6/10
# 15196/15196 [==============================] - 122s 8ms/step - loss: 0.1547 - root_mean_squared_error: 0.3933 - mean_absolute_error: 0.2252 - mean_absolute_percentage_error: 527012.3125 - mean_squared_error: 0.1547 - val_loss: 0.2240 - val_root_mean_squared_error: 0.4733 - val_mean_absolute_error: 0.2642 - val_mean_absolute_percentage_error: 36822.5664 - val_mean_squared_error: 0.2240
# Epoch 7/10
# 15196/15196 [==============================] - 121s 8ms/step - loss: 0.1534 - root_mean_squared_error: 0.3916 - mean_absolute_error: 0.2238 - mean_absolute_percentage_error: 383886.8438 - mean_squared_error: 0.1534 - val_loss: 0.2154 - val_root_mean_squared_error: 0.4641 - val_mean_absolute_error: 0.2467 - val_mean_absolute_percentage_error: 20554.0488 - val_mean_squared_error: 0.2154
# Epoch 8/10
# 15196/15196 [==============================] - 122s 8ms/step - loss: 0.1529 - root_mean_squared_error: 0.3910 - mean_absolute_error: 0.2233 - mean_absolute_percentage_error: 314603.2812 - mean_squared_error: 0.1529 - val_loss: 0.2302 - val_root_mean_squared_error: 0.4798 - val_mean_absolute_error: 0.3316 - val_mean_absolute_percentage_error: 47682.7109 - val_mean_squared_error: 0.2302
# Epoch 9/10
# 15196/15196 [==============================] - 122s 8ms/step - loss: 0.1531 - root_mean_squared_error: 0.3912 - mean_absolute_error: 0.2240 - mean_absolute_percentage_error: 311114.5312 - mean_squared_error: 0.1531 - val_loss: 0.2144 - val_root_mean_squared_error: 0.4631 - val_mean_absolute_error: 0.2904 - val_mean_absolute_percentage_error: 40038.5859 - val_mean_squared_error: 0.2144
# Epoch 10/10
# 15196/15196 [==============================] - 122s 8ms/step - loss: 0.1528 - root_mean_squared_error: 0.3908 - mean_absolute_error: 0.2232 - mean_absolute_percentage_error: 428130.7812 - mean_squared_error: 0.1528 - val_loss: 0.2209 - val_root_mean_squared_error: 0.4700 - val_mean_absolute_error: 0.2898 - val_mean_absolute_percentage_error: 40956.4688 - val_mean_squared_error: 0.2209
# Training History for Cluster 2:

# %%
three_houses = list(clustered_df[clustered_df['Cluster'] == 3]['House'])
three_cluster = Cluster(three_houses)
three_cluster_results = three_cluster.results(model_name)
print('Training History for Cluster 3:')
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_9 (SimpleRNN)    (None, 12, 128)           17280
#
#  simple_rnn_10 (SimpleRNN)   (None, 12, 32)            5152
#
#  simple_rnn_11 (SimpleRNN)   (None, 16)                784
#
#  dense_3 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 23,233
# Trainable params: 23,233
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 2746/2746 [==============================] - 24s 8ms/step - loss: 0.3816 - root_mean_squared_error: 0.6177 - mean_absolute_error: 0.4006 - mean_absolute_percentage_error: 238626.1094 - mean_squared_error: 0.3816 - val_loss: 0.4363 - val_root_mean_squared_error: 0.6605 - val_mean_absolute_error: 0.4449 - val_mean_absolute_percentage_error: 53680.4297 - val_mean_squared_error: 0.4363
# Epoch 2/10
# 2746/2746 [==============================] - 21s 8ms/step - loss: 0.3655 - root_mean_squared_error: 0.6045 - mean_absolute_error: 0.3854 - mean_absolute_percentage_error: 189581.9531 - mean_squared_error: 0.3655 - val_loss: 0.4125 - val_root_mean_squared_error: 0.6423 - val_mean_absolute_error: 0.4256 - val_mean_absolute_percentage_error: 52048.3984 - val_mean_squared_error: 0.4125
# Epoch 3/10
# 2746/2746 [==============================] - 21s 8ms/step - loss: 0.3739 - root_mean_squared_error: 0.6115 - mean_absolute_error: 0.3912 - mean_absolute_percentage_error: 258829.9375 - mean_squared_error: 0.3739 - val_loss: 0.4427 - val_root_mean_squared_error: 0.6653 - val_mean_absolute_error: 0.4474 - val_mean_absolute_percentage_error: 70758.2578 - val_mean_squared_error: 0.4427
# Epoch 4/10
# 2746/2746 [==============================] - 22s 8ms/step - loss: 0.3684 - root_mean_squared_error: 0.6070 - mean_absolute_error: 0.3885 - mean_absolute_percentage_error: 231328.3594 - mean_squared_error: 0.3684 - val_loss: 0.3994 - val_root_mean_squared_error: 0.6319 - val_mean_absolute_error: 0.3771 - val_mean_absolute_percentage_error: 56015.3125 - val_mean_squared_error: 0.3994
# Epoch 5/10
# 2746/2746 [==============================] - 22s 8ms/step - loss: 0.3624 - root_mean_squared_error: 0.6020 - mean_absolute_error: 0.3840 - mean_absolute_percentage_error: 260839.0156 - mean_squared_error: 0.3624 - val_loss: 0.4607 - val_root_mean_squared_error: 0.6788 - val_mean_absolute_error: 0.4303 - val_mean_absolute_percentage_error: 70162.3359 - val_mean_squared_error: 0.4607
# Epoch 6/10
# 2746/2746 [==============================] - 22s 8ms/step - loss: 0.3590 - root_mean_squared_error: 0.5991 - mean_absolute_error: 0.3801 - mean_absolute_percentage_error: 240559.4688 - mean_squared_error: 0.3590 - val_loss: 0.5208 - val_root_mean_squared_error: 0.7216 - val_mean_absolute_error: 0.4680 - val_mean_absolute_percentage_error: 77489.7734 - val_mean_squared_error: 0.5208
# Epoch 7/10
# 2746/2746 [==============================] - 22s 8ms/step - loss: 0.3526 - root_mean_squared_error: 0.5938 - mean_absolute_error: 0.3751 - mean_absolute_percentage_error: 229674.2031 - mean_squared_error: 0.3526 - val_loss: 0.4530 - val_root_mean_squared_error: 0.6731 - val_mean_absolute_error: 0.4374 - val_mean_absolute_percentage_error: 69698.2656 - val_mean_squared_error: 0.4530
# Epoch 8/10
# 2746/2746 [==============================] - 22s 8ms/step - loss: 0.3512 - root_mean_squared_error: 0.5926 - mean_absolute_error: 0.3747 - mean_absolute_percentage_error: 239574.7500 - mean_squared_error: 0.3512 - val_loss: 0.4694 - val_root_mean_squared_error: 0.6851 - val_mean_absolute_error: 0.4129 - val_mean_absolute_percentage_error: 62706.0820 - val_mean_squared_error: 0.4694
# Epoch 9/10
# 2746/2746 [==============================] - 22s 8ms/step - loss: 0.3491 - root_mean_squared_error: 0.5908 - mean_absolute_error: 0.3727 - mean_absolute_percentage_error: 218739.2812 - mean_squared_error: 0.3491 - val_loss: 0.4556 - val_root_mean_squared_error: 0.6750 - val_mean_absolute_error: 0.4080 - val_mean_absolute_percentage_error: 57980.4180 - val_mean_squared_error: 0.4556
# Epoch 10/10
# 2746/2746 [==============================] - 22s 8ms/step - loss: 0.3465 - root_mean_squared_error: 0.5886 - mean_absolute_error: 0.3690 - mean_absolute_percentage_error: 217790.6406 - mean_squared_error: 0.3465 - val_loss: 0.4328 - val_root_mean_squared_error: 0.6579 - val_mean_absolute_error: 0.4183 - val_mean_absolute_percentage_error: 85746.9766 - val_mean_squared_error: 0.4328
# Training History for Cluster 3:

# %%
## Save Scenario 1 models
zero_cluster.model.save(f'Models/Scenario1/{model_name}/zero_cluster')
one_cluster.model.save(f'Models/Scenario1/{model_name}/one_cluster')
two_cluster.model.save(f'Models/Scenario1/{model_name}/two_cluster')
three_cluster.model.save(f'Models/Scenario1/{model_name}/three_cluster')

## Pickling cluster and cluster results
zero_cluster_file = open(f"Models/Scenario1/Objects/{model_name}/zero_cluster.pickle", "wb")
pickle.dump(zero_cluster, zero_cluster_file)
zero_cluster_file.close()

one_cluster_file = open(f"Models/Scenario1/Objects/{model_name}/one_cluster.pickle", "wb")
pickle.dump(one_cluster, one_cluster_file)
one_cluster_file.close()

two_cluster_file = open(f"Models/Scenario1/Objects/{model_name}/two_cluster.pickle", "wb")
pickle.dump(two_cluster, two_cluster_file)
two_cluster_file.close()

three_cluster_file = open(f"Models/Scenario1/Objects/{model_name}/three_cluster.pickle", "wb")
pickle.dump(three_cluster, three_cluster_file)
three_cluster_file.close()

zero_cluster_results_file = open(f"Models/Scenario1/Objects/{model_name}/zero_cluster_results.pickle", "wb")
pickle.dump(zero_cluster_results, zero_cluster_results_file)
zero_cluster_results_file.close()

one_cluster_results_file = open(f"Models/Scenario1/Objects/{model_name}/one_cluster_results.pickle", "wb")
pickle.dump(one_cluster_results, one_cluster_results_file)
one_cluster_results_file.close()

two_cluster_results_file = open(f"Models/Scenario1/Objects/{model_name}/two_cluster_results.pickle", "wb")
pickle.dump(two_cluster_results, two_cluster_results_file)
two_cluster_results_file.close()

three_cluster_results_file = open(f"Models/Scenario1/Objects/{model_name}/three_cluster_results.pickle", "wb")
pickle.dump(three_cluster_results, three_cluster_results_file)
three_cluster_results_file.close()
# Out:
# 2022-04-27 17:48:21.160288: W tensorflow/python/util/util.cc:368] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# INFO:tensorflow:Assets written to: Models/Scenario1/RNN/zero_cluster/assets
# INFO:tensorflow:Assets written to: Models/Scenario1/RNN/one_cluster/assets
# INFO:tensorflow:Assets written to: Models/Scenario1/RNN/two_cluster/assets
# INFO:tensorflow:Assets written to: Models/Scenario1/RNN/three_cluster/assets
# INFO:tensorflow:Assets written to: ram://31e27aa3-9f6b-4ee6-b382-e91bdf5256c5/assets
# INFO:tensorflow:Assets written to: ram://9e7981f1-38a0-44da-8fff-109b06da436d/assets
# INFO:tensorflow:Assets written to: ram://7f4cede8-f54b-49c6-b3fb-24b393a6cb15/assets
# INFO:tensorflow:Assets written to: ram://943ee7db-6fe9-46eb-bd63-439c8fcb48ba/assets

# %% [markdown]
# #### Scenario 2

# %%
all_houses = list(clustered_df['House'])
all_cluster = Cluster(all_houses)
all_cluster_results = all_cluster.results(model_name)
print('Training History without clustering:')
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_12 (SimpleRNN)   (None, 12, 128)           17280
#
#  simple_rnn_13 (SimpleRNN)   (None, 12, 32)            5152
#
#  simple_rnn_14 (SimpleRNN)   (None, 16)                784
#
#  dense_4 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 23,233
# Trainable params: 23,233
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 26536/26536 [==============================] - 211s 8ms/step - loss: 0.3619 - root_mean_squared_error: 0.6016 - mean_absolute_error: 0.3416 - mean_absolute_percentage_error: 321802.2812 - mean_squared_error: 0.3619 - val_loss: 0.3891 - val_root_mean_squared_error: 0.6238 - val_mean_absolute_error: 0.3412 - val_mean_absolute_percentage_error: 70543.7969 - val_mean_squared_error: 0.3891
# Epoch 2/10
# 26536/26536 [==============================] - 211s 8ms/step - loss: 0.3568 - root_mean_squared_error: 0.5973 - mean_absolute_error: 0.3363 - mean_absolute_percentage_error: 311505.8125 - mean_squared_error: 0.3568 - val_loss: 0.3460 - val_root_mean_squared_error: 0.5882 - val_mean_absolute_error: 0.3527 - val_mean_absolute_percentage_error: 103791.3828 - val_mean_squared_error: 0.3460
# Epoch 3/10
# 26536/26536 [==============================] - 230s 9ms/step - loss: 0.3535 - root_mean_squared_error: 0.5945 - mean_absolute_error: 0.3328 - mean_absolute_percentage_error: 363426.8438 - mean_squared_error: 0.3535 - val_loss: 0.3716 - val_root_mean_squared_error: 0.6096 - val_mean_absolute_error: 0.4182 - val_mean_absolute_percentage_error: 125861.8594 - val_mean_squared_error: 0.3716
# Epoch 4/10
# 26536/26536 [==============================] - 229s 9ms/step - loss: 0.3435 - root_mean_squared_error: 0.5861 - mean_absolute_error: 0.3258 - mean_absolute_percentage_error: 379564.7500 - mean_squared_error: 0.3435 - val_loss: 0.3328 - val_root_mean_squared_error: 0.5768 - val_mean_absolute_error: 0.3383 - val_mean_absolute_percentage_error: 112832.0469 - val_mean_squared_error: 0.3328
# Epoch 5/10
# 26536/26536 [==============================] - 241s 9ms/step - loss: 0.3448 - root_mean_squared_error: 0.5872 - mean_absolute_error: 0.3264 - mean_absolute_percentage_error: 364872.5312 - mean_squared_error: 0.3448 - val_loss: 0.3458 - val_root_mean_squared_error: 0.5881 - val_mean_absolute_error: 0.3378 - val_mean_absolute_percentage_error: 93978.7734 - val_mean_squared_error: 0.3458
# Epoch 6/10
# 26536/26536 [==============================] - 214s 8ms/step - loss: 0.3491 - root_mean_squared_error: 0.5909 - mean_absolute_error: 0.3304 - mean_absolute_percentage_error: 408792.9062 - mean_squared_error: 0.3491 - val_loss: 0.3606 - val_root_mean_squared_error: 0.6005 - val_mean_absolute_error: 0.3779 - val_mean_absolute_percentage_error: 126209.0703 - val_mean_squared_error: 0.3606
# Epoch 7/10
# 26536/26536 [==============================] - 220s 8ms/step - loss: 0.3444 - root_mean_squared_error: 0.5869 - mean_absolute_error: 0.3281 - mean_absolute_percentage_error: 410205.4688 - mean_squared_error: 0.3444 - val_loss: 0.3493 - val_root_mean_squared_error: 0.5910 - val_mean_absolute_error: 0.3241 - val_mean_absolute_percentage_error: 95973.8750 - val_mean_squared_error: 0.3493
# Epoch 8/10
# 26536/26536 [==============================] - 204s 8ms/step - loss: 0.3455 - root_mean_squared_error: 0.5878 - mean_absolute_error: 0.3283 - mean_absolute_percentage_error: 468011.0312 - mean_squared_error: 0.3455 - val_loss: 0.3392 - val_root_mean_squared_error: 0.5824 - val_mean_absolute_error: 0.3543 - val_mean_absolute_percentage_error: 126737.4219 - val_mean_squared_error: 0.3392
# Epoch 9/10
# 26536/26536 [==============================] - 202s 8ms/step - loss: 0.3417 - root_mean_squared_error: 0.5846 - mean_absolute_error: 0.3251 - mean_absolute_percentage_error: 413519.9375 - mean_squared_error: 0.3417 - val_loss: 0.3507 - val_root_mean_squared_error: 0.5922 - val_mean_absolute_error: 0.3581 - val_mean_absolute_percentage_error: 114872.1484 - val_mean_squared_error: 0.3507
# Epoch 10/10
# 26536/26536 [==============================] - 204s 8ms/step - loss: 0.3395 - root_mean_squared_error: 0.5826 - mean_absolute_error: 0.3232 - mean_absolute_percentage_error: 426312.3125 - mean_squared_error: 0.3395 - val_loss: 0.3443 - val_root_mean_squared_error: 0.5867 - val_mean_absolute_error: 0.3302 - val_mean_absolute_percentage_error: 115706.1172 - val_mean_squared_error: 0.3443
# Training History without clustering:

# %%
### Save Scenario 2 models
all_cluster.model.save(f'Models/Scenario2/{model_name}/all_cluster')

## Pickling Scenario 2 cluster and cluster result files
all_cluster_file = open(f"Models/Scenario2/Objects/{model_name}/all_cluster.pickle", "wb+")
pickle.dump(all_cluster, all_cluster_file)
all_cluster_file.close()

all_cluster_results_file = open(f"Models/Scenario2/Objects/{model_name}/all_cluster_results.pickle", "wb+")
pickle.dump(all_cluster_results, all_cluster_results_file)
all_cluster_results_file.close()
# Out:
# INFO:tensorflow:Assets written to: Models/Scenario2/RNN/all_cluster/assets
# INFO:tensorflow:Assets written to: ram://d57024fa-e370-40f4-bc17-6d2e6cd6dc46/assets

# %% [markdown]
# #### Predictions Graph functions

# %%
def x_axis_label_format(label):
    """
    Convert time label to the format of pandas line plot
    """
    label = pd.Timestamp(label)
    month = label.month_name()[:3]
    #if month == 'Jan':
    month += f'\n{label.year}'
    return month

def graph_predictions(cluster_specific_results, all_results):
    first_house = list(cluster_specific_results.keys())[0]
    df1 = cluster_specific_results[first_house][['timestamp','energy_predicted', 'energy_kWh']]
    df1['timestamp'] = pd.to_datetime(df1['timestamp'])
    df1 = df1.set_index('timestamp')
    df1['energy_predicted_without_clustering']= np.array(all_results[first_house][['energy_predicted']])
    df1.rename({'energy_predicted':'energy_predicted_with_clustering', 'energy_kWh':'real_energy'},axis = 1, inplace = True)
    ax = df1[::300].plot.line(figsize=(20,10))
    #ax.set_xticklabels(map(x_axis_label_format, df1[::int(len(df1)/8)+1].index))
    #import matplotlib.dates as mdates
    #myFmt = mdates.DateFormatter('%Y-%m')
    #ax.xaxis.set_major_formatter(myFmt)
    ax.set_title(f'Predictions for house {first_house}')

# %% [markdown]
# #### Predictions for Scenario 1 and Scenario 2

# %%
graph_predictions(zero_cluster_results, all_cluster_results)
#df1 = zero_cluster_results[1][['timestamp','energy_predicted', 'energy_kWh']].set_index('timestamp')
#df1['energy_predicted_without_clustering']= np.array(all_cluster_results[1][['energy_predicted']])
# Out:
# /tmp/ipykernel_44732/442122963.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['timestamp'] = pd.to_datetime(df1['timestamp'])

# %%
graph_predictions(one_cluster_results, all_cluster_results)
# Out:
# /tmp/ipykernel_44732/442122963.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['timestamp'] = pd.to_datetime(df1['timestamp'])

# %%
graph_predictions(two_cluster_results, all_cluster_results)
# Out:
# /tmp/ipykernel_44732/442122963.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['timestamp'] = pd.to_datetime(df1['timestamp'])

# %%
graph_predictions(three_cluster_results, all_cluster_results)
# Out:
# /tmp/ipykernel_44732/442122963.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['timestamp'] = pd.to_datetime(df1['timestamp'])

# %% [markdown]
# ### Function to create tables

# %%
def create_metrics(scenario_results, val=False):
    # tf.keras.metrics.RootMeanSquaredError(), tf.keras.metrics.MeanAbsoluteError(), tf.keras.metrics.MeanAbsolutePercentageError(), tf.keras.metrics.MeanSquaredError()
    if val == False:
        rmse = 'root_mean_squared_error'
        mae = 'mean_absolute_error'
        mape = 'mean_absolute_percentage_error'
        mse = 'mean_squared_error'
    else:
        rmse = 'val_root_mean_squared_error'
        mae = 'val_mean_absolute_error'
        mape = 'val_mean_absolute_percentage_error'
        mse = 'val_mean_squared_error'
        
    scenario_rmse = list(map(lambda x: x.history.history[rmse],scenario_results))
    scenario_mae = list(map(lambda x: x.history.history[mae],scenario_results))
    scenario_mape = list(map(lambda x: x.history.history[mape],scenario_results))
    scenario_mse = list(map(lambda x: x.history.history[mse],scenario_results))
    scenario_rmse = np.array(scenario_rmse).reshape(-1,)
    scenario_mae = np.array(scenario_mae).reshape(-1,)
    scenario_mape = np.array(scenario_mape).reshape(-1,)
    scenario_mse = np.array(scenario_mse).reshape(-1,)
    return [np.min(scenario_rmse),np.max(scenario_rmse),np.mean(scenario_rmse),np.min(scenario_mae),np.max(scenario_mae),np.mean(scenario_mae)
           ,np.min(scenario_mape),np.max(scenario_mape),np.mean(scenario_mape)
           ,np.min(scenario_mse),np.max(scenario_mse),np.mean(scenario_mse)]

# %% [markdown]
# #### Scenario 1 and Scenario 2 Metric Tables

# %%
scenario_1_results = [zero_cluster, one_cluster, two_cluster, three_cluster]
scenario_1_metrics = create_metrics(scenario_1_results)
scenario_1_validation_metrics = create_metrics(scenario_1_results, val= True)
scenario_1_metrics
# Out:
# [0.3856377899646759,
#  1.0657414197921753,
#  0.6602602876722813,
#  0.21593734622001648,
#  0.6182777881622314,
#  0.39440674558281896,
#  64.89947509765625,
#  527012.3125,
#  235728.8252189636,
#  0.1487165093421936,
#  1.1358046531677246,
#  0.47861493192613125]

# %%
scenario_2_results = [all_cluster]
scenario_2_metrics = create_metrics(scenario_2_results)
scenario_2_validation_metrics = create_metrics(scenario_2_results, val= True)
scenario_2_metrics
# Out:
# [0.5826451778411865,
#  0.6015791893005371,
#  0.589944040775299,
#  0.32320544123649597,
#  0.3415800929069519,
#  0.3297921985387802,
#  311505.8125,
#  468011.03125,
#  386801.3875,
#  0.3394754230976105,
#  0.3618974983692169,
#  0.3480669617652893]

# %% [markdown]
# #### Scenario 3 and 4

# %%
### Removing smart device features
House.cols = ['energy_kWh']
#House.cols

# %%
scenario_3_zero_cluster = Cluster(zero_houses)
scenario_3_zero_cluster_results = scenario_3_zero_cluster.results(model_name)
print('Training History for Cluster 0:')
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_15 (SimpleRNN)   (None, 12, 128)           16640
#
#  simple_rnn_16 (SimpleRNN)   (None, 12, 32)            5152
#
#  simple_rnn_17 (SimpleRNN)   (None, 16)                784
#
#  dense_5 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 22,593
# Trainable params: 22,593
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 7681/7681 [==============================] - 61s 8ms/step - loss: 0.4806 - root_mean_squared_error: 0.6933 - mean_absolute_error: 0.4260 - mean_absolute_percentage_error: 313132.5312 - mean_squared_error: 0.4806 - val_loss: 0.7261 - val_root_mean_squared_error: 0.8521 - val_mean_absolute_error: 0.4881 - val_mean_absolute_percentage_error: 128109.8125 - val_mean_squared_error: 0.7261
# Epoch 2/10
# 7681/7681 [==============================] - 60s 8ms/step - loss: 0.4716 - root_mean_squared_error: 0.6868 - mean_absolute_error: 0.4217 - mean_absolute_percentage_error: 327512.2500 - mean_squared_error: 0.4716 - val_loss: 0.6421 - val_root_mean_squared_error: 0.8013 - val_mean_absolute_error: 0.4522 - val_mean_absolute_percentage_error: 139322.9062 - val_mean_squared_error: 0.6421
# Epoch 3/10
# 7681/7681 [==============================] - 59s 8ms/step - loss: 0.4641 - root_mean_squared_error: 0.6813 - mean_absolute_error: 0.4164 - mean_absolute_percentage_error: 332400.7188 - mean_squared_error: 0.4641 - val_loss: 0.6820 - val_root_mean_squared_error: 0.8258 - val_mean_absolute_error: 0.4678 - val_mean_absolute_percentage_error: 148969.0312 - val_mean_squared_error: 0.6820
# Epoch 4/10
# 7681/7681 [==============================] - 59s 8ms/step - loss: 0.4667 - root_mean_squared_error: 0.6831 - mean_absolute_error: 0.4173 - mean_absolute_percentage_error: 348251.5000 - mean_squared_error: 0.4667 - val_loss: 0.6364 - val_root_mean_squared_error: 0.7978 - val_mean_absolute_error: 0.5190 - val_mean_absolute_percentage_error: 230003.6719 - val_mean_squared_error: 0.6364
# Epoch 5/10
# 7681/7681 [==============================] - 60s 8ms/step - loss: 0.4678 - root_mean_squared_error: 0.6840 - mean_absolute_error: 0.4183 - mean_absolute_percentage_error: 350845.3750 - mean_squared_error: 0.4678 - val_loss: 0.7553 - val_root_mean_squared_error: 0.8691 - val_mean_absolute_error: 0.4970 - val_mean_absolute_percentage_error: 156813.8438 - val_mean_squared_error: 0.7553
# Epoch 6/10
# 7681/7681 [==============================] - 60s 8ms/step - loss: 0.4671 - root_mean_squared_error: 0.6834 - mean_absolute_error: 0.4173 - mean_absolute_percentage_error: 354219.2812 - mean_squared_error: 0.4671 - val_loss: 0.6267 - val_root_mean_squared_error: 0.7916 - val_mean_absolute_error: 0.4788 - val_mean_absolute_percentage_error: 196565.0938 - val_mean_squared_error: 0.6267
# Epoch 7/10
# 7681/7681 [==============================] - 60s 8ms/step - loss: 0.4646 - root_mean_squared_error: 0.6816 - mean_absolute_error: 0.4166 - mean_absolute_percentage_error: 356466.4688 - mean_squared_error: 0.4646 - val_loss: 0.6146 - val_root_mean_squared_error: 0.7840 - val_mean_absolute_error: 0.4544 - val_mean_absolute_percentage_error: 155801.9688 - val_mean_squared_error: 0.6146
# Epoch 8/10
# 7681/7681 [==============================] - 60s 8ms/step - loss: 0.4655 - root_mean_squared_error: 0.6822 - mean_absolute_error: 0.4153 - mean_absolute_percentage_error: 338319.0312 - mean_squared_error: 0.4655 - val_loss: 0.6226 - val_root_mean_squared_error: 0.7891 - val_mean_absolute_error: 0.4646 - val_mean_absolute_percentage_error: 160729.7344 - val_mean_squared_error: 0.6226
# Epoch 9/10
# 7681/7681 [==============================] - 60s 8ms/step - loss: 0.4627 - root_mean_squared_error: 0.6802 - mean_absolute_error: 0.4152 - mean_absolute_percentage_error: 341401.0625 - mean_squared_error: 0.4627 - val_loss: 0.6221 - val_root_mean_squared_error: 0.7887 - val_mean_absolute_error: 0.4545 - val_mean_absolute_percentage_error: 150964.6719 - val_mean_squared_error: 0.6221
# Epoch 10/10
# 7681/7681 [==============================] - 60s 8ms/step - loss: 0.4640 - root_mean_squared_error: 0.6812 - mean_absolute_error: 0.4157 - mean_absolute_percentage_error: 321356.5625 - mean_squared_error: 0.4640 - val_loss: 0.6684 - val_root_mean_squared_error: 0.8176 - val_mean_absolute_error: 0.4811 - val_mean_absolute_percentage_error: 168895.3438 - val_mean_squared_error: 0.6684
# Training History for Cluster 0:

# %%
scenario_3_one_cluster = Cluster(one_houses)
scenario_3_one_cluster_results = scenario_3_one_cluster.results(model_name)
print('Training History for Cluster 1:')
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_18 (SimpleRNN)   (None, 12, 128)           16640
#
#  simple_rnn_19 (SimpleRNN)   (None, 12, 32)            5152
#
#  simple_rnn_20 (SimpleRNN)   (None, 16)                784
#
#  dense_6 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 22,593
# Trainable params: 22,593
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 915/915 [==============================] - 8s 8ms/step - loss: 1.1269 - root_mean_squared_error: 1.0616 - mean_absolute_error: 0.6112 - mean_absolute_percentage_error: 73.7347 - mean_squared_error: 1.1269 - val_loss: 1.4043 - val_root_mean_squared_error: 1.1850 - val_mean_absolute_error: 0.6747 - val_mean_absolute_percentage_error: 116.1354 - val_mean_squared_error: 1.4043
# Epoch 2/10
# 915/915 [==============================] - 7s 8ms/step - loss: 0.9219 - root_mean_squared_error: 0.9601 - mean_absolute_error: 0.5535 - mean_absolute_percentage_error: 68.4398 - mean_squared_error: 0.9219 - val_loss: 1.2413 - val_root_mean_squared_error: 1.1141 - val_mean_absolute_error: 0.6161 - val_mean_absolute_percentage_error: 110.5104 - val_mean_squared_error: 1.2413
# Epoch 3/10
# 915/915 [==============================] - 7s 8ms/step - loss: 1.0216 - root_mean_squared_error: 1.0108 - mean_absolute_error: 0.5792 - mean_absolute_percentage_error: 72.7649 - mean_squared_error: 1.0216 - val_loss: 1.5032 - val_root_mean_squared_error: 1.2260 - val_mean_absolute_error: 0.5651 - val_mean_absolute_percentage_error: 73.2140 - val_mean_squared_error: 1.5032
# Epoch 4/10
# 915/915 [==============================] - 7s 8ms/step - loss: 1.0359 - root_mean_squared_error: 1.0178 - mean_absolute_error: 0.5928 - mean_absolute_percentage_error: 74.4549 - mean_squared_error: 1.0359 - val_loss: 1.5512 - val_root_mean_squared_error: 1.2455 - val_mean_absolute_error: 0.7253 - val_mean_absolute_percentage_error: 138.6403 - val_mean_squared_error: 1.5512
# Epoch 5/10
# 915/915 [==============================] - 7s 8ms/step - loss: 0.9545 - root_mean_squared_error: 0.9770 - mean_absolute_error: 0.5631 - mean_absolute_percentage_error: 70.8164 - mean_squared_error: 0.9545 - val_loss: 1.4541 - val_root_mean_squared_error: 1.2059 - val_mean_absolute_error: 0.6333 - val_mean_absolute_percentage_error: 104.9936 - val_mean_squared_error: 1.4541
# Epoch 6/10
# 915/915 [==============================] - 7s 8ms/step - loss: 0.9970 - root_mean_squared_error: 0.9985 - mean_absolute_error: 0.5622 - mean_absolute_percentage_error: 69.4167 - mean_squared_error: 0.9970 - val_loss: 1.5729 - val_root_mean_squared_error: 1.2541 - val_mean_absolute_error: 0.6249 - val_mean_absolute_percentage_error: 101.3679 - val_mean_squared_error: 1.5729
# Epoch 7/10
# 915/915 [==============================] - 7s 8ms/step - loss: 0.9402 - root_mean_squared_error: 0.9697 - mean_absolute_error: 0.5512 - mean_absolute_percentage_error: 68.9099 - mean_squared_error: 0.9402 - val_loss: 1.3833 - val_root_mean_squared_error: 1.1761 - val_mean_absolute_error: 0.5477 - val_mean_absolute_percentage_error: 74.1832 - val_mean_squared_error: 1.3833
# Epoch 8/10
# 915/915 [==============================] - 7s 8ms/step - loss: 0.9003 - root_mean_squared_error: 0.9489 - mean_absolute_error: 0.5337 - mean_absolute_percentage_error: 65.2593 - mean_squared_error: 0.9003 - val_loss: 1.3631 - val_root_mean_squared_error: 1.1675 - val_mean_absolute_error: 0.6501 - val_mean_absolute_percentage_error: 122.4453 - val_mean_squared_error: 1.3631
# Epoch 9/10
# 915/915 [==============================] - 7s 8ms/step - loss: 0.8703 - root_mean_squared_error: 0.9329 - mean_absolute_error: 0.5283 - mean_absolute_percentage_error: 64.8069 - mean_squared_error: 0.8703 - val_loss: 1.3957 - val_root_mean_squared_error: 1.1814 - val_mean_absolute_error: 0.6672 - val_mean_absolute_percentage_error: 130.2599 - val_mean_squared_error: 1.3957
# Epoch 10/10
# 915/915 [==============================] - 7s 8ms/step - loss: 0.8570 - root_mean_squared_error: 0.9257 - mean_absolute_error: 0.5256 - mean_absolute_percentage_error: 64.0607 - mean_squared_error: 0.8570 - val_loss: 1.1817 - val_root_mean_squared_error: 1.0870 - val_mean_absolute_error: 0.6162 - val_mean_absolute_percentage_error: 113.5457 - val_mean_squared_error: 1.1817
# Training History for Cluster 1:

# %%
scenario_3_two_cluster = Cluster(two_houses)
scenario_3_two_cluster_results = scenario_3_two_cluster.results(model_name)
print('Training History for Cluster 2:')
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_21 (SimpleRNN)   (None, 12, 128)           16640
#
#  simple_rnn_22 (SimpleRNN)   (None, 12, 32)            5152
#
#  simple_rnn_23 (SimpleRNN)   (None, 16)                784
#
#  dense_7 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 22,593
# Trainable params: 22,593
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 15196/15196 [==============================] - 121s 8ms/step - loss: 0.1518 - root_mean_squared_error: 0.3896 - mean_absolute_error: 0.2205 - mean_absolute_percentage_error: 277755.1250 - mean_squared_error: 0.1518 - val_loss: 0.2116 - val_root_mean_squared_error: 0.4600 - val_mean_absolute_error: 0.2854 - val_mean_absolute_percentage_error: 39019.2227 - val_mean_squared_error: 0.2116
# Epoch 2/10
# 15196/15196 [==============================] - 119s 8ms/step - loss: 0.1477 - root_mean_squared_error: 0.3843 - mean_absolute_error: 0.2147 - mean_absolute_percentage_error: 231898.5469 - mean_squared_error: 0.1477 - val_loss: 0.2240 - val_root_mean_squared_error: 0.4733 - val_mean_absolute_error: 0.2543 - val_mean_absolute_percentage_error: 14376.6533 - val_mean_squared_error: 0.2240
# Epoch 3/10
# 15196/15196 [==============================] - 118s 8ms/step - loss: 0.1469 - root_mean_squared_error: 0.3833 - mean_absolute_error: 0.2135 - mean_absolute_percentage_error: 205008.8906 - mean_squared_error: 0.1469 - val_loss: 0.2079 - val_root_mean_squared_error: 0.4559 - val_mean_absolute_error: 0.2493 - val_mean_absolute_percentage_error: 18993.8633 - val_mean_squared_error: 0.2079
# Epoch 4/10
# 15196/15196 [==============================] - 117s 8ms/step - loss: 0.1465 - root_mean_squared_error: 0.3827 - mean_absolute_error: 0.2128 - mean_absolute_percentage_error: 204722.0625 - mean_squared_error: 0.1465 - val_loss: 0.2090 - val_root_mean_squared_error: 0.4571 - val_mean_absolute_error: 0.2622 - val_mean_absolute_percentage_error: 29581.4863 - val_mean_squared_error: 0.2090
# Epoch 5/10
# 15196/15196 [==============================] - 118s 8ms/step - loss: 0.1459 - root_mean_squared_error: 0.3820 - mean_absolute_error: 0.2125 - mean_absolute_percentage_error: 214462.2656 - mean_squared_error: 0.1459 - val_loss: 0.2078 - val_root_mean_squared_error: 0.4558 - val_mean_absolute_error: 0.2612 - val_mean_absolute_percentage_error: 23301.1914 - val_mean_squared_error: 0.2078
# Epoch 6/10
# 15196/15196 [==============================] - 118s 8ms/step - loss: 0.1522 - root_mean_squared_error: 0.3901 - mean_absolute_error: 0.2214 - mean_absolute_percentage_error: 297758.3438 - mean_squared_error: 0.1522 - val_loss: 0.2292 - val_root_mean_squared_error: 0.4787 - val_mean_absolute_error: 0.2651 - val_mean_absolute_percentage_error: 29829.8750 - val_mean_squared_error: 0.2292
# Epoch 7/10
# 15196/15196 [==============================] - 117s 8ms/step - loss: 0.1555 - root_mean_squared_error: 0.3943 - mean_absolute_error: 0.2267 - mean_absolute_percentage_error: 350613.5625 - mean_squared_error: 0.1555 - val_loss: 0.2125 - val_root_mean_squared_error: 0.4610 - val_mean_absolute_error: 0.2754 - val_mean_absolute_percentage_error: 31968.8711 - val_mean_squared_error: 0.2125
# Epoch 8/10
# 15196/15196 [==============================] - 118s 8ms/step - loss: 0.1550 - root_mean_squared_error: 0.3937 - mean_absolute_error: 0.2267 - mean_absolute_percentage_error: 333429.8438 - mean_squared_error: 0.1550 - val_loss: 0.2334 - val_root_mean_squared_error: 0.4831 - val_mean_absolute_error: 0.2704 - val_mean_absolute_percentage_error: 27620.3652 - val_mean_squared_error: 0.2334
# Epoch 9/10
# 15196/15196 [==============================] - 119s 8ms/step - loss: 0.1534 - root_mean_squared_error: 0.3916 - mean_absolute_error: 0.2248 - mean_absolute_percentage_error: 298162.7500 - mean_squared_error: 0.1534 - val_loss: 0.2151 - val_root_mean_squared_error: 0.4638 - val_mean_absolute_error: 0.2522 - val_mean_absolute_percentage_error: 29919.8301 - val_mean_squared_error: 0.2151
# Epoch 10/10
# 15196/15196 [==============================] - 119s 8ms/step - loss: 0.1522 - root_mean_squared_error: 0.3901 - mean_absolute_error: 0.2232 - mean_absolute_percentage_error: 311863.5938 - mean_squared_error: 0.1522 - val_loss: 0.2132 - val_root_mean_squared_error: 0.4618 - val_mean_absolute_error: 0.2830 - val_mean_absolute_percentage_error: 36368.1289 - val_mean_squared_error: 0.2132
# Training History for Cluster 2:

# %%
scenario_3_three_cluster = Cluster(three_houses)
scenario_3_three_cluster_results = scenario_3_three_cluster.results(model_name)
print('Training History for Cluster 3:')
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_24 (SimpleRNN)   (None, 12, 128)           16640
#
#  simple_rnn_25 (SimpleRNN)   (None, 12, 32)            5152
#
#  simple_rnn_26 (SimpleRNN)   (None, 16)                784
#
#  dense_8 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 22,593
# Trainable params: 22,593
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 2746/2746 [==============================] - 23s 8ms/step - loss: 0.3829 - root_mean_squared_error: 0.6188 - mean_absolute_error: 0.4021 - mean_absolute_percentage_error: 245405.2031 - mean_squared_error: 0.3829 - val_loss: 0.4625 - val_root_mean_squared_error: 0.6801 - val_mean_absolute_error: 0.4185 - val_mean_absolute_percentage_error: 48560.6953 - val_mean_squared_error: 0.4625
# Epoch 2/10
# 2746/2746 [==============================] - 21s 8ms/step - loss: 0.3673 - root_mean_squared_error: 0.6061 - mean_absolute_error: 0.3873 - mean_absolute_percentage_error: 258965.1562 - mean_squared_error: 0.3673 - val_loss: 0.4767 - val_root_mean_squared_error: 0.6905 - val_mean_absolute_error: 0.4054 - val_mean_absolute_percentage_error: 56579.9766 - val_mean_squared_error: 0.4767
# Epoch 3/10
# 2746/2746 [==============================] - 22s 8ms/step - loss: 0.3634 - root_mean_squared_error: 0.6028 - mean_absolute_error: 0.3844 - mean_absolute_percentage_error: 251229.4531 - mean_squared_error: 0.3634 - val_loss: 0.4981 - val_root_mean_squared_error: 0.7058 - val_mean_absolute_error: 0.4989 - val_mean_absolute_percentage_error: 85827.6250 - val_mean_squared_error: 0.4981
# Epoch 4/10
# 2746/2746 [==============================] - 22s 8ms/step - loss: 0.3556 - root_mean_squared_error: 0.5963 - mean_absolute_error: 0.3773 - mean_absolute_percentage_error: 228985.2344 - mean_squared_error: 0.3556 - val_loss: 0.4910 - val_root_mean_squared_error: 0.7007 - val_mean_absolute_error: 0.4593 - val_mean_absolute_percentage_error: 80449.9609 - val_mean_squared_error: 0.4910
# Epoch 5/10
# 2746/2746 [==============================] - 22s 8ms/step - loss: 0.3537 - root_mean_squared_error: 0.5947 - mean_absolute_error: 0.3760 - mean_absolute_percentage_error: 255210.4219 - mean_squared_error: 0.3537 - val_loss: 0.4428 - val_root_mean_squared_error: 0.6654 - val_mean_absolute_error: 0.4233 - val_mean_absolute_percentage_error: 78085.6875 - val_mean_squared_error: 0.4428
# Epoch 6/10
# 2746/2746 [==============================] - 22s 8ms/step - loss: 0.3530 - root_mean_squared_error: 0.5942 - mean_absolute_error: 0.3749 - mean_absolute_percentage_error: 314090.0625 - mean_squared_error: 0.3530 - val_loss: 0.4838 - val_root_mean_squared_error: 0.6956 - val_mean_absolute_error: 0.4670 - val_mean_absolute_percentage_error: 82820.0469 - val_mean_squared_error: 0.4838
# Epoch 7/10
# 2746/2746 [==============================] - 22s 8ms/step - loss: 0.3442 - root_mean_squared_error: 0.5867 - mean_absolute_error: 0.3669 - mean_absolute_percentage_error: 267742.7188 - mean_squared_error: 0.3442 - val_loss: 0.4587 - val_root_mean_squared_error: 0.6773 - val_mean_absolute_error: 0.4439 - val_mean_absolute_percentage_error: 44186.1328 - val_mean_squared_error: 0.4587
# Epoch 8/10
# 2746/2746 [==============================] - 22s 8ms/step - loss: 0.3472 - root_mean_squared_error: 0.5892 - mean_absolute_error: 0.3696 - mean_absolute_percentage_error: 296436.2812 - mean_squared_error: 0.3472 - val_loss: 0.4802 - val_root_mean_squared_error: 0.6930 - val_mean_absolute_error: 0.4713 - val_mean_absolute_percentage_error: 94186.4141 - val_mean_squared_error: 0.4802
# Epoch 9/10
# 2746/2746 [==============================] - 22s 8ms/step - loss: 0.3490 - root_mean_squared_error: 0.5907 - mean_absolute_error: 0.3731 - mean_absolute_percentage_error: 225092.0156 - mean_squared_error: 0.3490 - val_loss: 0.4472 - val_root_mean_squared_error: 0.6687 - val_mean_absolute_error: 0.4342 - val_mean_absolute_percentage_error: 80931.8984 - val_mean_squared_error: 0.4472
# Epoch 10/10
# 2746/2746 [==============================] - 22s 8ms/step - loss: 0.3463 - root_mean_squared_error: 0.5884 - mean_absolute_error: 0.3684 - mean_absolute_percentage_error: 212941.9375 - mean_squared_error: 0.3463 - val_loss: 0.4288 - val_root_mean_squared_error: 0.6549 - val_mean_absolute_error: 0.3999 - val_mean_absolute_percentage_error: 55109.2305 - val_mean_squared_error: 0.4288
# Training History for Cluster 3:

# %%
## Save Scenario 3 models
scenario_3_zero_cluster.model.save(f'Models/Scenario3/{model_name}/zero_cluster')
scenario_3_one_cluster.model.save(f'Models/Scenario3/{model_name}/one_cluster')
scenario_3_two_cluster.model.save(f'Models/Scenario3/{model_name}/two_cluster')
scenario_3_three_cluster.model.save(f'Models/Scenario3/{model_name}/three_cluster')

# Pickling objects

scenario_3_zero_cluster_file = open(f"Models/Scenario3/Objects/{model_name}/zero_cluster.pickle", "wb")
pickle.dump(scenario_3_zero_cluster, scenario_3_zero_cluster_file)
scenario_3_zero_cluster_file.close()

scenario_3_one_cluster_file = open(f"Models/Scenario3/Objects/{model_name}/one_cluster.pickle", "wb")
pickle.dump(scenario_3_one_cluster, scenario_3_one_cluster_file)
scenario_3_one_cluster_file.close()

scenario_3_two_cluster_file = open(f"Models/Scenario3/Objects/{model_name}/two_cluster.pickle", "wb")
pickle.dump(scenario_3_two_cluster, scenario_3_two_cluster_file)
scenario_3_two_cluster_file.close()

scenario_3_three_cluster_file = open(f"Models/Scenario3/Objects/{model_name}/three_cluster.pickle", "wb")
pickle.dump(scenario_3_three_cluster, scenario_3_three_cluster_file)
scenario_3_three_cluster_file.close()

scenario_3_zero_cluster_results_file = open(f"Models/Scenario3/Objects/{model_name}/zero_cluster_results.pickle", "wb")
pickle.dump(scenario_3_zero_cluster_results, scenario_3_zero_cluster_results_file)
scenario_3_zero_cluster_results_file.close()

scenario_3_one_cluster_results_file = open(f"Models/Scenario3/Objects/{model_name}/one_cluster_results.pickle", "wb")
pickle.dump(scenario_3_one_cluster_results, scenario_3_one_cluster_results_file)
scenario_3_one_cluster_results_file.close()

scenario_3_two_cluster_results_file = open(f"Models/Scenario3/Objects/{model_name}/two_cluster_results.pickle", "wb")
pickle.dump(scenario_3_two_cluster_results, scenario_3_two_cluster_results_file)
scenario_3_two_cluster_results_file.close()

scenario_3_three_cluster_results_file = open(f"Models/Scenario3/Objects/{model_name}/three_cluster_results.pickle", "wb")
pickle.dump(scenario_3_three_cluster_results, scenario_3_three_cluster_results_file)
scenario_3_three_cluster_results_file.close()
# Out:
# INFO:tensorflow:Assets written to: Models/Scenario3/RNN/zero_cluster/assets
# INFO:tensorflow:Assets written to: Models/Scenario3/RNN/one_cluster/assets
# INFO:tensorflow:Assets written to: Models/Scenario3/RNN/two_cluster/assets
# INFO:tensorflow:Assets written to: Models/Scenario3/RNN/three_cluster/assets
# INFO:tensorflow:Assets written to: ram://966e1354-8ef1-4852-a1a8-9bb5c494c260/assets
# INFO:tensorflow:Assets written to: ram://69b0f24e-99aa-432a-9dd8-186a75c2e7f3/assets
# INFO:tensorflow:Assets written to: ram://9468ed98-3d1e-4675-a646-c613943af929/assets
# INFO:tensorflow:Assets written to: ram://9311fa2e-b02d-4f47-b0a2-6dbae53ae74c/assets

# %% [markdown]
# #### Scenario 4

# %%
scenario_4_all_cluster = Cluster(all_houses)
scenario_4_all_cluster_results = scenario_4_all_cluster.results(model_name)
print('Training History without clustering:')
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_27 (SimpleRNN)   (None, 12, 128)           16640
#
#  simple_rnn_28 (SimpleRNN)   (None, 12, 32)            5152
#
#  simple_rnn_29 (SimpleRNN)   (None, 16)                784
#
#  dense_9 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 22,593
# Trainable params: 22,593
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 26536/26536 [==============================] - 208s 8ms/step - loss: 0.3522 - root_mean_squared_error: 0.5934 - mean_absolute_error: 0.3345 - mean_absolute_percentage_error: 414040.9375 - mean_squared_error: 0.3522 - val_loss: 0.3373 - val_root_mean_squared_error: 0.5807 - val_mean_absolute_error: 0.3351 - val_mean_absolute_percentage_error: 95515.3203 - val_mean_squared_error: 0.3373
# Epoch 2/10
# 26536/26536 [==============================] - 211s 8ms/step - loss: 0.3537 - root_mean_squared_error: 0.5948 - mean_absolute_error: 0.3318 - mean_absolute_percentage_error: 475183.0000 - mean_squared_error: 0.3537 - val_loss: 0.3896 - val_root_mean_squared_error: 0.6242 - val_mean_absolute_error: 0.3653 - val_mean_absolute_percentage_error: 104644.7891 - val_mean_squared_error: 0.3896
# Epoch 3/10
# 26536/26536 [==============================] - 212s 8ms/step - loss: 0.3467 - root_mean_squared_error: 0.5888 - mean_absolute_error: 0.3265 - mean_absolute_percentage_error: 442766.9062 - mean_squared_error: 0.3467 - val_loss: 0.3517 - val_root_mean_squared_error: 0.5931 - val_mean_absolute_error: 0.3370 - val_mean_absolute_percentage_error: 106627.5547 - val_mean_squared_error: 0.3517
# Epoch 4/10
# 26536/26536 [==============================] - 210s 8ms/step - loss: 0.3411 - root_mean_squared_error: 0.5840 - mean_absolute_error: 0.3233 - mean_absolute_percentage_error: 409848.1562 - mean_squared_error: 0.3411 - val_loss: 0.3381 - val_root_mean_squared_error: 0.5814 - val_mean_absolute_error: 0.3381 - val_mean_absolute_percentage_error: 92923.0781 - val_mean_squared_error: 0.3381
# Epoch 5/10
# 26536/26536 [==============================] - 210s 8ms/step - loss: 0.3397 - root_mean_squared_error: 0.5828 - mean_absolute_error: 0.3216 - mean_absolute_percentage_error: 424973.0625 - mean_squared_error: 0.3397 - val_loss: 0.3321 - val_root_mean_squared_error: 0.5763 - val_mean_absolute_error: 0.3160 - val_mean_absolute_percentage_error: 58532.3281 - val_mean_squared_error: 0.3321
# Epoch 6/10
# 26536/26536 [==============================] - 211s 8ms/step - loss: 0.3402 - root_mean_squared_error: 0.5833 - mean_absolute_error: 0.3219 - mean_absolute_percentage_error: 406023.1250 - mean_squared_error: 0.3402 - val_loss: 0.3443 - val_root_mean_squared_error: 0.5868 - val_mean_absolute_error: 0.3465 - val_mean_absolute_percentage_error: 98663.5000 - val_mean_squared_error: 0.3443
# Epoch 7/10
# 26536/26536 [==============================] - 211s 8ms/step - loss: 0.3405 - root_mean_squared_error: 0.5835 - mean_absolute_error: 0.3223 - mean_absolute_percentage_error: 420931.9375 - mean_squared_error: 0.3405 - val_loss: 0.3446 - val_root_mean_squared_error: 0.5870 - val_mean_absolute_error: 0.3436 - val_mean_absolute_percentage_error: 96951.2812 - val_mean_squared_error: 0.3446
# Epoch 8/10
# 26536/26536 [==============================] - 211s 8ms/step - loss: 0.3400 - root_mean_squared_error: 0.5831 - mean_absolute_error: 0.3225 - mean_absolute_percentage_error: 445450.4062 - mean_squared_error: 0.3400 - val_loss: 0.3521 - val_root_mean_squared_error: 0.5934 - val_mean_absolute_error: 0.3182 - val_mean_absolute_percentage_error: 69012.5156 - val_mean_squared_error: 0.3521
# Epoch 9/10
# 26536/26536 [==============================] - 211s 8ms/step - loss: 0.3395 - root_mean_squared_error: 0.5827 - mean_absolute_error: 0.3225 - mean_absolute_percentage_error: 453252.3750 - mean_squared_error: 0.3395 - val_loss: 0.3416 - val_root_mean_squared_error: 0.5844 - val_mean_absolute_error: 0.3364 - val_mean_absolute_percentage_error: 104122.3984 - val_mean_squared_error: 0.3416
# Epoch 10/10
# 26536/26536 [==============================] - 212s 8ms/step - loss: 0.3413 - root_mean_squared_error: 0.5842 - mean_absolute_error: 0.3233 - mean_absolute_percentage_error: 457142.9062 - mean_squared_error: 0.3413 - val_loss: 0.3485 - val_root_mean_squared_error: 0.5904 - val_mean_absolute_error: 0.3290 - val_mean_absolute_percentage_error: 83067.3594 - val_mean_squared_error: 0.3485
# Training History without clustering:

# %%
### Save Scenario 4 models
scenario_4_all_cluster.model.save(f'Models/Scenario4/{model_name}/all_cluster')

## Pickling Scenario 4 cluster and cluster result files
scenario_4_all_cluster_file = open(f"Models/Scenario4/Objects/{model_name}/all_cluster.pickle", "wb")
pickle.dump(scenario_4_all_cluster, scenario_4_all_cluster_file)
scenario_4_all_cluster_file.close()

scenario_4_all_cluster_results_file = open(f"Models/Scenario4/Objects/{model_name}/all_cluster_results.pickle", "wb")
pickle.dump(scenario_4_all_cluster_results, scenario_4_all_cluster_results_file)
scenario_4_all_cluster_results_file.close()
# Out:
# INFO:tensorflow:Assets written to: Models/Scenario4/RNN/all_cluster/assets
# INFO:tensorflow:Assets written to: ram://cc38bba3-4cd7-418c-8a9a-c8f5be967c31/assets

# %% [markdown]
# #### Predictions for Scenario 3 and Scenario 4

# %%
graph_predictions(scenario_3_zero_cluster_results, scenario_4_all_cluster_results)
# Out:
# /tmp/ipykernel_44732/442122963.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['timestamp'] = pd.to_datetime(df1['timestamp'])

# %%
graph_predictions(scenario_3_one_cluster_results, scenario_4_all_cluster_results)
# Out:
# /tmp/ipykernel_44732/442122963.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['timestamp'] = pd.to_datetime(df1['timestamp'])

# %%
graph_predictions(scenario_3_two_cluster_results, scenario_4_all_cluster_results)
# Out:
# /tmp/ipykernel_44732/442122963.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['timestamp'] = pd.to_datetime(df1['timestamp'])

# %%
graph_predictions(scenario_3_three_cluster_results, scenario_4_all_cluster_results)
# Out:
# /tmp/ipykernel_44732/442122963.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['timestamp'] = pd.to_datetime(df1['timestamp'])

# %% [markdown]
# #### Scenario 3 and Scenario 4 Metric Tables

# %%
scenario_3_results = [scenario_3_zero_cluster, scenario_3_one_cluster, scenario_3_two_cluster, scenario_3_three_cluster]
scenario_3_metrics = create_metrics(scenario_3_results )
scenario_3_validation_metrics = create_metrics(scenario_3_results, val= True)
scenario_3_metrics
# Out:
# [0.38196420669555664,
#  1.0615628957748413,
#  0.6622403606772422,
#  0.2124786525964737,
#  0.611237645149231,
#  0.3939357105642557,
#  64.06070709228516,
#  356466.46875,
#  216659.27285060883,
#  0.14589665830135345,
#  1.1269158124923706,
#  0.48424508683383466]

# %%
scenario_4_results = [scenario_4_all_cluster]
scenario_4_metrics = create_metrics(scenario_4_results )
scenario_4_validation_metrics = create_metrics(scenario_4_results, val= True)
scenario_4_metrics
# Out:
# [0.5826871395111084,
#  0.594763994216919,
#  0.5860539138317108,
#  0.32162943482398987,
#  0.33454200625419617,
#  0.32502720952034,
#  406023.125,
#  475183.0,
#  434961.28125,
#  0.3395242989063263,
#  0.35374417901039124,
#  0.34347822368144987]

# %%
print('Training metrics:')
df = pd.DataFrame([scenario_1_metrics, scenario_2_metrics, scenario_3_metrics, scenario_4_metrics],index=[1,2,3,4], columns = ['Min RMSE', 'Max RMSE', 'Mean RMSE','Min MAE', 'Max MAE', 'Mean MAE',
                                                                                                                              'Min MAPE', 'Max MAPE', 'Mean MAPE',
                                                                                                                              'Min MSE', 'Max MSE', 'Mean MSE'])
df['Scenario'] = np.array([1,2,3,4])
df.set_index('Scenario').round(decimals=2).to_csv('Tables/training_metrics.csv')
# Out:
# Training metrics:

# %%
print('Validation metrics:')
df = pd.DataFrame([scenario_1_validation_metrics, scenario_2_validation_metrics,
                   scenario_3_validation_metrics, scenario_4_validation_metrics],index=[1,2,3,4], columns = ['Min RMSE', 'Max RMSE', 'Mean RMSE','Min MAE', 'Max MAE', 'Mean MAE',
                                                                                                                              'Min MAPE', 'Max MAPE', 'Mean MAPE',
                                                                                                                              'Min MSE', 'Max MSE', 'Mean MSE'])
df['Scenario'] = np.array([1,2,3,4])
df.set_index('Scenario').round(decimals=2).to_csv('Tables/validation_metrics.csv')
# Out:
# Validation metrics:

# %% [markdown]
# ### Anomaly Distribution

# %%
def create_anomaly_df(result_df, scenario_name, monthly_agg = True):    
    #print(type(result_df))
    anomaly_df = result_df[['timestamp', 'Anomaly detected']]
    anomaly_df.set_index('timestamp', inplace = True)
    if monthly_agg:
        anomaly_df['Anomaly detected'] = anomaly_df['Anomaly detected'].apply(lambda x: 0 if x is False else 1)
        anomaly_df = anomaly_df.resample("M").agg('sum')
    else: 
        anomaly_df['Anomaly detected'] = anomaly_df['Anomaly detected'].apply(lambda x: 0 if x is False else x)
    anomaly_df = anomaly_df.rename(columns={'Anomaly detected': scenario_name})
    return anomaly_df

def create_anomalies_graph( title = None, **kwargs):
    anomaly_dfs = []
    for scenario_name, result_df in kwargs.items():
        anomaly_df = create_anomaly_df(result_df, scenario_name)
        anomaly_dfs.append(anomaly_df)
    anomaly_df = functools.reduce(lambda left, right: left.join(right), anomaly_dfs)
    ax = anomaly_df.plot.line(figsize=(20,10))
    ax.set_xlabel(f'Time')
    ax.set_ylabel(f'Frequency')
    ax.set_title(title)
    #return anomaly_dfs

# %%
def dtw_distance(series1, series2):
    return fastdtw.fastdtw(series1,series2)[0]

def create_distance_df(title, **kwargs):
    print(title)
    anomaly_dfs = []
    for scenario_name, result_df in kwargs.items():
        anomaly_df = np.array(create_anomaly_df(result_df, scenario_name, monthly_agg=False)).reshape(1,-1)
        anomaly_dfs.append(anomaly_df)
    anomaly_distributions = np.array(anomaly_dfs).reshape(len(kwargs),-1)
    distance_matrix = sd.squareform(sd.pdist(anomaly_distributions, dtw_distance))
    return(pd.DataFrame(distance_matrix, columns = kwargs.keys(), index = kwargs.keys()))
    #return anomaly_dfs

# %%
create_anomalies_graph( 'Anomaly Frequency Distribution for House 1: Cluster 0', Scenario1 = zero_cluster_results[1], Scenario2 = all_cluster_results[1],
                       Scenario3 = scenario_3_zero_cluster_results[1], Scenario4 = scenario_4_all_cluster_results[1])
# Out:
# /tmp/ipykernel_44732/3162963936.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anomaly_df['Anomaly detected'] = anomaly_df['Anomaly detected'].apply(lambda x: 0 if x is False else 1)

# %%
create_distance_df('Similarity between anomaly distributions for House1: Cluster 0', Scenario1 = zero_cluster_results[1], Scenario2 = all_cluster_results[1],
                       Scenario3 = scenario_3_zero_cluster_results[1], Scenario4 = scenario_4_all_cluster_results[1]).round(decimals=2).to_csv('Tables/anomaly_cluster0.csv')
# Out:
# Similarity between anomaly distributions for House1: Cluster 0
# /tmp/ipykernel_44732/3162963936.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anomaly_df['Anomaly detected'] = anomaly_df['Anomaly detected'].apply(lambda x: 0 if x is False else x)

# %%
create_anomalies_graph( 'Anomaly Frequency Distribution for House 15: Cluster 1', Scenario1 = one_cluster_results[15], Scenario2 = all_cluster_results[15],
                       Scenario3 = scenario_3_one_cluster_results[15], Scenario4 = scenario_4_all_cluster_results[15])
# Out:
# /tmp/ipykernel_44732/3162963936.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anomaly_df['Anomaly detected'] = anomaly_df['Anomaly detected'].apply(lambda x: 0 if x is False else 1)

# %%
create_distance_df( 'Similarity between anomaly distributions for House15: Cluster 1', Scenario1 = one_cluster_results[15], Scenario2 = all_cluster_results[15],
                       Scenario3 = scenario_3_one_cluster_results[15], Scenario4 = scenario_4_all_cluster_results[15]).round(decimals=2).to_csv('Tables/anomaly_cluster1.csv')
# Out:
# Similarity between anomaly distributions for House15: Cluster 1
# /tmp/ipykernel_44732/3162963936.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anomaly_df['Anomaly detected'] = anomaly_df['Anomaly detected'].apply(lambda x: 0 if x is False else x)

# %%
create_anomalies_graph( 'Anomaly Frequency Distribution for House 2: Cluster 2', Scenario1 = two_cluster_results[2], Scenario2 = all_cluster_results[2],
                       Scenario3 = scenario_3_two_cluster_results[2], Scenario4 = scenario_4_all_cluster_results[2])
# Out:
# /tmp/ipykernel_44732/3162963936.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anomaly_df['Anomaly detected'] = anomaly_df['Anomaly detected'].apply(lambda x: 0 if x is False else 1)

# %%
create_distance_df( 'Similarity between anomaly distributions for House 2: Cluster 2', Scenario1 = two_cluster_results[2], Scenario2 = all_cluster_results[2],
                       Scenario3 = scenario_3_two_cluster_results[2], Scenario4 = scenario_4_all_cluster_results[2]).round(decimals=2).to_csv('Tables/anomaly_cluster2.csv')
# Out:
# Similarity between anomaly distributions for House 2: Cluster 2
# /tmp/ipykernel_44732/3162963936.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anomaly_df['Anomaly detected'] = anomaly_df['Anomaly detected'].apply(lambda x: 0 if x is False else x)

# %%
create_anomalies_graph( 'Anomaly Frequency Distribution for House 3: Cluster 3', Scenario1 = three_cluster_results[3], Scenario2 = all_cluster_results[3],
                       Scenario3 = scenario_3_three_cluster_results[3], Scenario4 = scenario_4_all_cluster_results[3])
# Out:
# /tmp/ipykernel_44732/3162963936.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anomaly_df['Anomaly detected'] = anomaly_df['Anomaly detected'].apply(lambda x: 0 if x is False else 1)

# %%
create_distance_df( 'Similarity between anomaly distributions for House 3: Cluster 3', Scenario1 = three_cluster_results[3], Scenario2 = all_cluster_results[3],
                       Scenario3 = scenario_3_three_cluster_results[3], Scenario4 = scenario_4_all_cluster_results[3]).round(decimals=2).to_csv('Tables/anomaly_cluster3.csv')
# Out:
# Similarity between anomaly distributions for House 3: Cluster 3
# /tmp/ipykernel_44732/3162963936.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anomaly_df['Anomaly detected'] = anomaly_df['Anomaly detected'].apply(lambda x: 0 if x is False else x)

# %% [markdown]
# #### Energy Deficit Calculation

# %%
def create_deficit_df(result_df, scenario_name, monthly_agg = True):    
    #print(type(result_df))
    energy_df = result_df[['timestamp', 'Energy Deficit Flag']]
    energy_df.set_index('timestamp', inplace = True)
    if monthly_agg:
        energy_df['Energy Deficit Flag'] = energy_df['Energy Deficit Flag'].apply(lambda x: 0 if x is False else 1)
        energy_df = energy_df.resample("W").agg('sum')
    else: 
        energy_df['Energy Deficit Flag'] = energy_df['Energy Deficit Flag'].apply(lambda x: 0 if x is False else x)
    energy_df = energy_df.rename(columns={'Energy Deficit Flag': scenario_name})
    return energy_df

def create_energy_deficit_graph( title = None, **kwargs):
    energy_dfs = []
    for scenario_name, result_df in kwargs.items():
        energy_df = create_deficit_df(result_df, scenario_name)
        
        energy_dfs.append(energy_df)
    energy_df = functools.reduce(lambda left, right: left.join(right), energy_dfs)
    ax = energy_df.plot.line(figsize=(20,10))
    ax.set_xlabel(f'Time')
    ax.set_ylabel(f'Frequency')
    ax.set_title(title)

# %%
def create_deficit_distance_df(title, **kwargs):
    print(title)
    energy_dfs = []
    for scenario_name, result_df in kwargs.items():
        energy_df = np.array(create_deficit_df(result_df, scenario_name, monthly_agg=False)).reshape(1,-1)
        print(energy_df)
        energy_dfs.append(energy_df)
    energy_distributions = np.array(energy_dfs).reshape(len(kwargs),-1)
    distance_matrix = sd.squareform(sd.pdist(energy_distributions, dtw_distance))
    return(pd.DataFrame(distance_matrix, columns = kwargs.keys(), index = kwargs.keys()))

# %%
create_energy_deficit_graph( 'Energy Deficit Frequency Distribution for House 1: Cluster 0', Scenario1 = zero_cluster_results[1], Scenario2 = all_cluster_results[1],
                       Scenario3 = scenario_3_zero_cluster_results[1], Scenario4 = scenario_4_all_cluster_results[1])
# Out:
# /tmp/ipykernel_44732/2530998586.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   energy_df['Energy Deficit Flag'] = energy_df['Energy Deficit Flag'].apply(lambda x: 0 if x is False else 1)

# %%
create_deficit_distance_df('Similarity between energy deficit distributions for House1: Cluster 0', Scenario1 = zero_cluster_results[1], Scenario2 = all_cluster_results[1],
                       Scenario3 = scenario_3_zero_cluster_results[1], Scenario4 = scenario_4_all_cluster_results[1])
# Out:
# Similarity between energy deficit distributions for House1: Cluster 0
# [[0.         0.         0.         ... 1.07574122 0.9295558  1.07968879]]
# [[0.         0.         0.         ... 1.11176091 0.91402057 1.00071276]]
# [[0.         0.         0.         ... 1.34583943 0.94775977 1.34186447]]
# [[0.         0.         0.         ... 1.03005736 0.9594343  1.05202473]]
# /tmp/ipykernel_44732/2530998586.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   energy_df['Energy Deficit Flag'] = energy_df['Energy Deficit Flag'].apply(lambda x: 0 if x is False else x)
#              Scenario1     Scenario2     Scenario3    Scenario4
# Scenario1     0.000000   8160.609596   2620.970896  6033.892936
# Scenario2  8160.609596      0.000000  10653.944122  2631.299365
# Scenario3  2620.970896  10653.944122      0.000000  9964.160209
# Scenario4  6033.892936   2631.299365   9964.160209     0.000000

# %%
create_energy_deficit_graph( 'Energy Deficit Frequency Distribution for House 15: Cluster 1', Scenario1 = one_cluster_results[15], Scenario2 = all_cluster_results[15],
                       Scenario3 = scenario_3_one_cluster_results[15], Scenario4 = scenario_4_all_cluster_results[15])
# Out:
# /tmp/ipykernel_44732/2530998586.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   energy_df['Energy Deficit Flag'] = energy_df['Energy Deficit Flag'].apply(lambda x: 0 if x is False else 1)

# %%
create_deficit_distance_df( 'Similarity between energy deficit distributions for House15: Cluster 1', Scenario1 = one_cluster_results[15], 
                    Scenario2 = all_cluster_results[15],
                       Scenario3 = scenario_3_one_cluster_results[15], Scenario4 = scenario_4_all_cluster_results[15])
# Out:
# Similarity between energy deficit distributions for House15: Cluster 1
# [[0.         1.13164541 2.96987006 ... 1.91291784 2.90632048 3.00565628]]
# [[0.         0.         0.06850871 ... 1.88381289 2.78495254 2.88377647]]
# [[0.         0.03228297 2.48128149 ... 2.32227276 3.14486327 3.40875296]]
# [[0.         0.         0.         ... 1.90360831 2.41121426 2.60025314]]
# /tmp/ipykernel_44732/2530998586.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   energy_df['Energy Deficit Flag'] = energy_df['Energy Deficit Flag'].apply(lambda x: 0 if x is False else x)
#               Scenario1     Scenario2     Scenario3     Scenario4
# Scenario1      0.000000   9282.811230   4855.600942  10408.093120
# Scenario2   9282.811230      0.000000  11298.762315   3792.383169
# Scenario3   4855.600942  11298.762315      0.000000  12549.807385
# Scenario4  10408.093120   3792.383169  12549.807385      0.000000

# %%
create_energy_deficit_graph( 'Energy Deficit Frequency Distribution for House 2: Cluster 2', Scenario1 = two_cluster_results[2], Scenario2 = all_cluster_results[2],
                       Scenario3 = scenario_3_two_cluster_results[2], Scenario4 = scenario_4_all_cluster_results[2])
# Out:
# /tmp/ipykernel_44732/2530998586.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   energy_df['Energy Deficit Flag'] = energy_df['Energy Deficit Flag'].apply(lambda x: 0 if x is False else 1)

# %%
create_deficit_distance_df( 'Similarity between energy deficit distributions for House 2: Cluster 2', Scenario1 = two_cluster_results[2], Scenario2 = all_cluster_results[2],
                       Scenario3 = scenario_3_two_cluster_results[2], Scenario4 = scenario_4_all_cluster_results[2])
# Out:
# Similarity between energy deficit distributions for House 2: Cluster 2
# [[0.         0.         0.         ... 0.         0.02936856 0.        ]]
# [[0.         0.         0.         ... 0.         0.08661322 0.        ]]
# [[0.        0.        0.        ... 0.        0.2431113 0.       ]]
# [[0.        0.        0.        ... 0.        0.1541305 0.       ]]
# /tmp/ipykernel_44732/2530998586.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   energy_df['Energy Deficit Flag'] = energy_df['Energy Deficit Flag'].apply(lambda x: 0 if x is False else x)
#              Scenario1    Scenario2    Scenario3    Scenario4
# Scenario1     0.000000  2126.432719   489.512640  1670.324518
# Scenario2  2126.432719     0.000000  2209.224944   693.191680
# Scenario3   489.512640  2209.224944     0.000000  2403.517926
# Scenario4  1670.324518   693.191680  2403.517926     0.000000

# %%
create_energy_deficit_graph( 'Energy Deficit Frequency Distribution for House 3: Cluster 3', Scenario1 = three_cluster_results[3], Scenario2 = all_cluster_results[3],
                       Scenario3 = scenario_3_three_cluster_results[3], Scenario4 = scenario_4_all_cluster_results[3])
# Out:
# /tmp/ipykernel_44732/2530998586.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   energy_df['Energy Deficit Flag'] = energy_df['Energy Deficit Flag'].apply(lambda x: 0 if x is False else 1)

# %%
create_deficit_distance_df( 'Similarity between energy deficit distributions for House 3: Cluster 3', Scenario1 = three_cluster_results[3], Scenario2 = all_cluster_results[3],
                       Scenario3 = scenario_3_three_cluster_results[3], Scenario4 = scenario_4_all_cluster_results[3])
# Out:
# Similarity between energy deficit distributions for House 3: Cluster 3
# [[0.79245453 0.39897968 0.51233917 ... 0.         0.         0.        ]]
# [[1.11347728 0.50370087 0.47823065 ... 0.         0.         0.        ]]
# [[0.82648795 0.45623495 0.42976218 ... 0.         0.         0.        ]]
# [[1.24441605 0.46538617 0.46226984 ... 0.         0.         0.        ]]
# /tmp/ipykernel_44732/2530998586.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   energy_df['Energy Deficit Flag'] = energy_df['Energy Deficit Flag'].apply(lambda x: 0 if x is False else x)
#              Scenario1    Scenario2    Scenario3    Scenario4
# Scenario1     0.000000  2582.372491  3276.700993  3289.980628
# Scenario2  2582.372491     0.000000  5803.308998  1983.191891
# Scenario3  3276.700993  5803.308998     0.000000  3606.767471
# Scenario4  3289.980628  1983.191891  3606.767471     0.000000

# %%
print(tf. __version__)
# Out:
# 2.7.0

# %%
print('Hello')
# Out:
# Hello
