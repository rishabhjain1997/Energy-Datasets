# %% [markdown]
# #### Importing Libraries and Dataset

# %%
import numpy as np
from statistics import mean
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import pandas as pd
import seaborn as sns
from tslearn.clustering import TimeSeriesKMeans
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, SimpleRNN 
from tensorflow.keras import regularizers
from tensorflow.keras.layers import Dense, Dropout
import tensorflow as tf
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from tensorflow import keras
import seaborn as sns
import pickle
import functools
import fastdtw
import scipy.spatial.distance as sd
#from datetime import datetime
consumption_df = pd.read_csv('Final Datasets/energy_consumption.csv')
consumption_df
# Out:
# 2022-03-30 13:51:05.028486: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-03-30 13:51:05.028524: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
#         Unnamed: 0            timestamp  energy_kWh  House Number  \
# 0                0  2012-06-01 01:00:00      1.0110             1
# 1                1  2012-06-01 02:00:00      0.4510             1
# 2                2  2012-06-01 03:00:00      0.5050             1
# 3                3  2012-06-01 04:00:00      0.4410             1
# 4                4  2012-06-01 05:00:00      0.4680             1
# ...            ...                  ...         ...           ...
# 611013      123761  2020-05-19 19:00:00      3.5802            28
# 611014      123762  2020-05-19 20:00:00      3.4398            28
# 611015      123763  2020-05-19 21:00:00      2.3049            28
# 611016      123764  2020-05-19 22:00:00      2.4921            28
# 611017      123765  2020-05-19 23:00:00      1.1817            28
#
#         electronics workbench energy  network equipment energy  \
# 0                           0.008686                  0.019316
# 1                           0.007178                  0.019338
# 2                           0.007324                  0.019336
# 3                           0.007151                  0.019339
# 4                           0.007224                  0.019338
# ...                              ...                       ...
# 611013                      0.028408                  0.038470
# 611014                      0.027762                  0.038479
# 611015                      0.022537                  0.038556
# 611016                      0.023399                  0.038544
# 611017                      0.017367                  0.038632
#
#         home office energy  RAE home office energy  \
# 0                 0.018232                0.134570
# 1                 0.013745                0.061839
# 2                 0.014177                0.068852
# 3                 0.013664                0.060540
# 4                 0.013881                0.064047
# ...                    ...                     ...
# 611013            0.069307                0.801381
# 611014            0.067384                0.770210
# 611015            0.051836                0.518247
# 611016            0.054401                0.559808
# 611017            0.036449                0.268881
#
#         RAE Mobile Phone Charger Energy
# 0                              0.000431
# 1                              0.000215
# 2                              0.000236
# 3                              0.000211
# 4                              0.000221
# ...                                 ...
# 611013                         0.002441
# 611014                         0.002348
# 611015                         0.001601
# 611016                         0.001724
# 611017                         0.000861
#
# [611018 rows x 9 columns]

# %%
if 'Unnamed: 0' in consumption_df.columns:
    consumption_df.drop('Unnamed: 0',axis=1, inplace = True)

# %%
consumption_df
# Out:
#                   timestamp  energy_kWh  House Number  \
# 0       2012-06-01 01:00:00      1.0110             1
# 1       2012-06-01 02:00:00      0.4510             1
# 2       2012-06-01 03:00:00      0.5050             1
# 3       2012-06-01 04:00:00      0.4410             1
# 4       2012-06-01 05:00:00      0.4680             1
# ...                     ...         ...           ...
# 611013  2020-05-19 19:00:00      3.5802            28
# 611014  2020-05-19 20:00:00      3.4398            28
# 611015  2020-05-19 21:00:00      2.3049            28
# 611016  2020-05-19 22:00:00      2.4921            28
# 611017  2020-05-19 23:00:00      1.1817            28
#
#         electronics workbench energy  network equipment energy  \
# 0                           0.008686                  0.019316
# 1                           0.007178                  0.019338
# 2                           0.007324                  0.019336
# 3                           0.007151                  0.019339
# 4                           0.007224                  0.019338
# ...                              ...                       ...
# 611013                      0.028408                  0.038470
# 611014                      0.027762                  0.038479
# 611015                      0.022537                  0.038556
# 611016                      0.023399                  0.038544
# 611017                      0.017367                  0.038632
#
#         home office energy  RAE home office energy  \
# 0                 0.018232                0.134570
# 1                 0.013745                0.061839
# 2                 0.014177                0.068852
# 3                 0.013664                0.060540
# 4                 0.013881                0.064047
# ...                    ...                     ...
# 611013            0.069307                0.801381
# 611014            0.067384                0.770210
# 611015            0.051836                0.518247
# 611016            0.054401                0.559808
# 611017            0.036449                0.268881
#
#         RAE Mobile Phone Charger Energy
# 0                              0.000431
# 1                              0.000215
# 2                              0.000236
# 3                              0.000211
# 4                              0.000221
# ...                                 ...
# 611013                         0.002441
# 611014                         0.002348
# 611015                         0.001601
# 611016                         0.001724
# 611017                         0.000861
#
# [611018 rows x 8 columns]

# %% [markdown]
# #### Converting Dataset to House-wise dictionary

# %%
house_wise_consumption = dict()
for house_number in consumption_df['House Number'].unique():
    house_data = consumption_df[consumption_df['House Number'] == house_number]
    house_wise_consumption[house_number] = house_data.copy()
house_wise_consumption[1]
# house_wise_consumption[14]['timestamp'].iloc[0]
# house_wise_consumption[14]['timestamp'].iloc[-1]
# house_wise_consumption[14]['House Number'].iloc[0]
# Out:
#                  timestamp  energy_kWh  House Number  \
# 0      2012-06-01 01:00:00       1.011             1
# 1      2012-06-01 02:00:00       0.451             1
# 2      2012-06-01 03:00:00       0.505             1
# 3      2012-06-01 04:00:00       0.441             1
# 4      2012-06-01 05:00:00       0.468             1
# ...                    ...         ...           ...
# 29226  2015-10-02 20:00:00       2.101             1
# 29227  2015-10-02 21:00:00       1.646             1
# 29228  2015-10-02 22:00:00       1.319             1
# 29229  2015-10-02 23:00:00       1.473             1
# 29230  2015-10-03 00:00:00       0.800             1
#
#        electronics workbench energy  network equipment energy  \
# 0                          0.008686                  0.019316
# 1                          0.007178                  0.019338
# 2                          0.007324                  0.019336
# 3                          0.007151                  0.019339
# 4                          0.007224                  0.019338
# ...                             ...                       ...
# 29226                      0.011621                  0.019273
# 29227                      0.010396                  0.019291
# 29228                      0.009516                  0.019304
# 29229                      0.009930                  0.019298
# 29230                      0.008118                  0.019324
#
#        home office energy  RAE home office energy  \
# 0                0.018232                0.134570
# 1                0.013745                0.061839
# 2                0.014177                0.068852
# 3                0.013664                0.060540
# 4                0.013881                0.064047
# ...                   ...                     ...
# 29226            0.026968                0.276137
# 29227            0.023322                0.217043
# 29228            0.020701                0.174573
# 29229            0.021935                0.194574
# 29230            0.016541                0.107166
#
#        RAE Mobile Phone Charger Energy
# 0                             0.000431
# 1                             0.000215
# 2                             0.000236
# 3                             0.000211
# 4                             0.000221
# ...                                ...
# 29226                         0.000851
# 29227                         0.000675
# 29228                         0.000549
# 29229                         0.000609
# 29230                         0.000349
#
# [29231 rows x 8 columns]

# %%
# TODO: Print the usage pattern in form of a graph
# Each cluster represents one line in the time series graph
# Plot december consumption (2017) values for each house belonging to the same cluster in a single graph
# Also plot for the whole year (annual 2017) for each house belonging to the same cluster in a single graph

# %% [markdown]
# #### Comparing Timestamps for clustering

# %%
timestamp_comparison = list()
for house in house_wise_consumption:
    first_timestamp = house_wise_consumption[house]['timestamp'].iloc[0]
    last_timestamp = house_wise_consumption[house]['timestamp'].iloc[-1]
    timestamp_comparison.append([house, first_timestamp, last_timestamp])
timestamp_comparison
timestamp_comparison_df = pd.DataFrame(timestamp_comparison, columns = ['House', 'First Timestamp', 'Last Timestamp'])
timestamp_comparison_df
# Out:
#     House      First Timestamp       Last Timestamp
# 0       1  2012-06-01 01:00:00  2015-10-03 00:00:00
# 1       2  2016-06-09 00:00:00  2019-11-20 23:00:00
# 2       3  2015-01-27 00:00:00  2018-01-29 23:00:00
# 3       4  2015-01-30 00:00:00  2018-01-29 23:00:00
# 4       5  2015-01-30 00:00:00  2018-01-29 23:00:00
# 5       6  2015-01-30 00:00:00  2018-01-29 23:00:00
# 6       7  2015-05-30 00:00:00  2018-01-29 23:00:00
# 7       8  2015-02-21 00:00:00  2018-02-20 23:00:00
# 8       9  2015-05-01 00:00:00  2018-02-21 23:00:00
# 9      10  2015-02-21 00:00:00  2018-02-20 23:00:00
# 10     11  2015-02-21 00:00:00  2018-02-20 23:00:00
# 11     12  2015-02-21 00:00:00  2018-02-20 23:00:00
# 12     13  2015-02-21 00:00:00  2018-02-20 23:00:00
# 13     14  2015-02-21 00:00:00  2018-02-20 23:00:00
# 14     15  2015-09-29 00:00:00  2018-02-20 23:00:00
# 15     16  2017-11-01 00:00:00  2019-02-18 23:00:00
# 16     17  2016-06-01 00:00:00  2017-04-29 23:00:00
# 17     18  2015-03-16 00:00:00  2018-03-15 16:00:00
# 18     19  2015-03-26 00:00:00  2018-03-25 23:00:00
# 19     20  2015-08-21 00:00:00  2018-04-20 23:00:00
# 20     21  2017-11-01 00:00:00  2018-06-04 23:00:00
# 21     22  2016-06-29 00:00:00  2018-06-05 23:00:00
# 22     23  2017-07-27 00:00:00  2020-04-05 23:00:00
# 23     24  2017-05-13 00:00:00  2020-05-12 23:00:00
# 24     25  2017-05-15 00:00:00  2020-05-14 23:00:00
# 25     26  2019-11-29 00:00:00  2020-05-20 23:00:00
# 26     27  2019-03-06 00:00:00  2020-05-20 23:00:00
# 27     28  2018-08-01 00:00:00  2020-05-19 23:00:00

# %%
# houses_with_ts = []
# sample_timestamp = '2017-11-01 00:00:00'
# for house in house_wise_consumption:
#     if sample_timestamp in house_wise_consumption[house]['timestamp'].unique():
#         houses_with_ts.append(house)
# len(houses_with_ts)
#house_wise_consumption[8][house_wise_consumption[8]['timestamp'] >= '2017-11-17'].head(60)

# %% [markdown]
# #### Creating a December consumption dictionary of dataframes

# %%
december_consumption = dict()
for house in house_wise_consumption:
    house_december_consumption = house_wise_consumption[house][(house_wise_consumption[house]['timestamp'] <= '2017-11-25') & (house_wise_consumption[house]['timestamp'] >= '2017-11-01')]
    december_consumption[house] = house_december_consumption.copy()
    december_consumption[house].drop_duplicates(subset='timestamp', keep="last", inplace = True)
def calculate_rows():
    december_rows = []
    for house in december_consumption:
        december_rows.append([house, len(december_consumption[house])])
    december_rows
    december_rows_df = pd.DataFrame(december_rows, columns = ['House', 'Rows'])
    return december_rows_df
def calculate_incomplete_rows():
    december_rows_df = calculate_rows()
    december_rows_incomplete_df = december_rows_df[(december_rows_df['Rows'] > 0) & (december_rows_df['Rows'] < 576)]
    return december_rows_incomplete_df
def fill_na_december_consumption(complete_df, incomplete_df):
    complete_df = complete_df.copy()
    year_incomplete = pd.Timestamp(incomplete_df.iloc[0]['timestamp']).year
    year_complete = pd.Timestamp(complete_df.iloc[0]['timestamp']).year
    complete_df['timestamp'] = complete_df['timestamp'].str.replace(str(year_complete), str(year_incomplete))
    fill_missing_values = complete_df[~complete_df.timestamp.isin(incomplete_df.timestamp)].copy()
    #print(fill_missing_values)
    fill_columns = ['energy_kWh', 'electronics workbench energy', 'network equipment energy', 'home office energy', 'RAE home office energy','RAE Mobile Phone Charger Energy']
    for fill_column in fill_columns:
        fill_missing_values[fill_column] = incomplete_df[fill_column].mean()
    incomplete_df = pd.concat([incomplete_df, fill_missing_values])
    incomplete_df = incomplete_df.sort_values(by=['timestamp'])
    return incomplete_df
def calculate_missing_december_rows():
    december_rows_df = calculate_rows()
    december_rows_missing_df = december_rows_df[(december_rows_df['Rows'] == 0)]
    return december_rows_missing_df
calculate_rows()
# Out:
#     House  Rows
# 0       1     0
# 1       2   576
# 2       3   576
# 3       4   576
# 4       5   576
# 5       6   576
# 6       7   576
# 7       8   448
# 8       9   576
# 9      10   576
# 10     11   568
# 11     12   528
# 12     13   576
# 13     14   575
# 14     15   576
# 15     16   456
# 16     17     0
# 17     18   528
# 18     19   576
# 19     20   575
# 20     21   576
# 21     22   528
# 22     23   576
# 23     24   576
# 24     25   576
# 25     26     0
# 26     27     0
# 27     28     0

# %%
for house in list(calculate_incomplete_rows()['House']):
    december_consumption[house] = fill_na_december_consumption(december_consumption[10], december_consumption[house])

# %% [markdown]
# ##### Houses with no December-17 consumption values

# %%
timestamp_comparison_df.set_index('House').join(calculate_missing_december_rows().set_index('House'), how='inner')
# Out:
#            First Timestamp       Last Timestamp  Rows
# House
# 1      2012-06-01 01:00:00  2015-10-03 00:00:00     0
# 17     2016-06-01 00:00:00  2017-04-29 23:00:00     0
# 26     2019-11-29 00:00:00  2020-05-20 23:00:00     0
# 27     2019-03-06 00:00:00  2020-05-20 23:00:00     0
# 28     2018-08-01 00:00:00  2020-05-19 23:00:00     0

# %%
missing_december_houses_dates = {
    1: ['2014-11-25', '2014-11-01'],
    17: ['2016-11-25', '2016-11-01'],
    26: ['2019-11-25', '2019-11-01'],
    27: ['2019-11-25', '2019-11-01'],
    28: ['2019-11-25', '2019-11-01'],
}

# %%
for house in missing_december_houses_dates:
    house_december_consumption = house_wise_consumption[house][(house_wise_consumption[house]['timestamp'] <= missing_december_houses_dates[house][0]) & (house_wise_consumption[house]['timestamp'] >= missing_december_houses_dates[house][1])]
    #print((house, missing_december_houses_dates[house][0]))
    december_consumption[house] = house_december_consumption.copy()
    december_consumption[house].drop_duplicates(subset='timestamp', keep="last", inplace = True)

# %% [markdown]
# ##### Filling missing values for December consumption

# %%
calculate_incomplete_rows()
# Out:
#     House  Rows
# 16     17   574
# 26     27   571
# 27     28   572

# %%
for house in list(calculate_incomplete_rows()['House']):
    december_consumption[house] = fill_na_december_consumption(december_consumption[10], december_consumption[house])

# %%
#calculate_rows()december_consumption

# %% [markdown]
# #### Houses to be clustered

# %%
##print('Houses to be clustered: ')
clustered_df = calculate_rows()[calculate_rows()['Rows'] ==  576]
clustered_df
# Out:
#     House  Rows
# 0       1   576
# 1       2   576
# 2       3   576
# 3       4   576
# 4       5   576
# 5       6   576
# 6       7   576
# 7       8   576
# 8       9   576
# 9      10   576
# 10     11   576
# 11     12   576
# 12     13   576
# 13     14   576
# 14     15   576
# 15     16   576
# 16     17   576
# 17     18   576
# 18     19   576
# 19     20   576
# 20     21   576
# 21     22   576
# 22     23   576
# 23     24   576
# 24     25   576
# 26     27   576
# 27     28   576

# %% [markdown]
# #### Converting to clustering matrix

# %%
clustering_matrix = []
for house in calculate_rows()[calculate_rows()['Rows'] ==  576]['House']:
    clustering_matrix.append(np.array(december_consumption[house]['energy_kWh']).reshape(-1,1))
clustering_matrix = np.array(clustering_matrix)
clustering_matrix.shape
# Out:
# (27, 576, 1)

# %% [markdown]
# #### Time series clustering of all households except house 26

# %%
# km_sdtw = TimeSeriesKMeans(n_clusters=4, metric="softdtw", max_iter=5,
#                             max_iter_barycenter=5,
#                             metric_params={"gamma": .5},
#                             random_state=0).fit_predict(clustering_matrix)

# %%
# len(km_sdtw)

# %%
# clustered_df['Cluster'] = km_sdtw

# %%
#clustered_df = clustered_df[['House', 'Cluster']].set_index('House')
# clustered_df[clustered_df['Cluster'] == 3]

# %%
clustered_df = pd.read_csv('Tables/clustered.csv')
clustered_df
# Out:
#     House  Cluster
# 0       1        0
# 1       2        2
# 2       3        3
# 3       4        0
# 4       5        3
# 5       6        2
# 6       7        2
# 7       8        2
# 8       9        2
# 9      10        2
# 10     11        2
# 11     12        2
# 12     13        0
# 13     14        0
# 14     15        1
# 15     16        2
# 16     17        2
# 17     18        0
# 18     19        0
# 19     20        2
# 20     21        2
# 21     22        2
# 22     23        2
# 23     24        2
# 24     25        2
# 25     27        3
# 26     28        0

# %% [markdown]
# #### Used Scenarios

# %%
data = [[1, 4, 6, 'Yes'], [2, 1, 6, 'Yes'], [3, 4, 1, 'No'], [4, 1, 1, 'No']]
df = pd.DataFrame(data, columns = ['Scenarios', 'No. of subsets', 'No. of features', 'Smart devices included in modeling?']).set_index('Scenarios')
df
# Out:
#            No. of subsets  No. of features Smart devices included in modeling?
# Scenarios
# 1                       4                6                                 Yes
# 2                       1                6                                 Yes
# 3                       4                1                                  No
# 4                       1                1                                  No

# %% [markdown]
# #### Time-series LSTM-based predictive modeling

# %%
n_past = 14
n_future = 1

# %%
### Energy generation dataframe
generation_df = pd.read_csv('Final Datasets/energy_generation.csv')
generation_df
# Out:
#                  timestamp  Wind Energy  Solar Energy
# 0      2012-01-01 00:00:00     0.168265           0.0
# 1      2012-01-01 01:00:00     0.168265           0.0
# 2      2012-01-01 02:00:00     0.168265           0.0
# 3      2012-01-01 03:00:00     0.168265           0.0
# 4      2012-01-01 04:00:00     0.168265           0.0
# ...                    ...          ...           ...
# 78907  2020-12-31 19:00:00     1.710441           0.0
# 78908  2020-12-31 20:00:00     1.710441           0.0
# 78909  2020-12-31 21:00:00     1.497873           0.0
# 78910  2020-12-31 22:00:00     1.285454           0.0
# 78911  2020-12-31 23:00:00     1.286778           0.0
#
# [78912 rows x 3 columns]

# %%
class House:
    cols = ['energy_kWh', 'electronics workbench energy', 'network equipment energy',
            'home office energy', 'RAE home office energy', 'RAE Mobile Phone Charger Energy']
    def __init__(self, house):
        self.house = house
        self.consumption_df = house_wise_consumption[house].copy()[House.cols].astype(float)
        self.train_dates_df = house_wise_consumption[house]['timestamp']
        self.prepare_dataset(n_future, n_past)
    
    def __repr__(self):
        return str(self.house)
    
    def prepare_dataset(self, n_future = 1, n_past = 14):
        #Empty lists to be populated using formatted training data
        trainX = []
        trainY = []
        consumption_np = np.array(self.consumption_df)
        #Reformat input data into a shape: (n_samples x timesteps x n_features)
        #In my example, my self.consumption_df has a shape (12823, 5)
        #12823 refers to the number of data points and 5 refers to the columns (multi-variables).
        for i in range(n_past, len(consumption_np) - n_future +1):
            trainX.append(consumption_np[i - n_past:i, 0:self.consumption_df.shape[1]])
            trainY.append(consumption_np[i + n_future - 1:i + n_future, 0])

        trainX, trainY = np.array(trainX), np.array(trainY)

        #print('trainX shape == {}.'.format(trainX.shape))
        #print('trainY shape == {}.'.format(trainY.shape))
        self.trainX = trainX
        self.trainY = trainY

class Cluster: 
    def __init__(self, houses):
        self.houses = [House(house) for house in houses]
        self.trainX_list = (list(map(lambda x: x.trainX, self.houses)))
        self.trainY_list = (list(map(lambda x: x.trainY, self.houses)))
        self.train_dates_list = (list(map(lambda x: x.train_dates_df, self.houses)))
        self.consumption_df_list = (list(map(lambda x: x.consumption_df, self.houses)))
        self.prepare_dataset()
        
    
    def prepare_dataset(self):
        
        self.train_dates = np.concatenate(self.train_dates_list, axis=0)
        ## TODO - Replace concatenate with for loop or sort by time
        self.X = np.concatenate(self.trainX_list, axis=0)
        self.Y = np.concatenate(self.trainY_list, axis=0)
    
    
    def prepare_ANN_model(self):
        model = Sequential()
        #model.add(Dense(1, activation='relu', input_shape=(self.X.shape[1], self.X.shape[2])))
        model.add(Dense(128, activation='relu', input_shape=(self.X.shape[1], self.X.shape[2]), return_sequences=True))
        model.add(Dense(32, activation='relu', return_sequences=True))
        model.add(Dense(16, activation='relu', return_sequences=False))
        model.add(Dense(self.Y.shape[1]))
        model.compile(optimizer='adam', loss='mse', metrics=[tf.keras.metrics.RootMeanSquaredError(), tf.keras.metrics.MeanAbsoluteError()])
        model.summary()
        return model
    
    def prepare_RNN_model(self):
        model = Sequential()
        #model.add(SimpleRNN(1, activation='relu', input_shape=(self.X.shape[1], self.X.shape[2]), return_sequences=True))
        model.add(SimpleRNN(128, activation='relu', input_shape=(self.X.shape[1], self.X.shape[2]), return_sequences=True))
        model.add(SimpleRNN(32, activation='relu', return_sequences=True))
        model.add(SimpleRNN(16, activation='relu', return_sequences=False))
        model.add(Dense(self.Y.shape[1]))
        model.compile(optimizer='adam', loss='mse', metrics=[tf.keras.metrics.RootMeanSquaredError(), tf.keras.metrics.MeanAbsoluteError()])
        model.summary()
        return model
    
    def prepare_LSTM_model(self):
        model = Sequential()
        #model.add(LSTM(1, activation='relu', input_shape=(self.X.shape[1], self.X.shape[2]), return_sequences=True))
        model.add(LSTM(128, activation='relu', input_shape=(self.X.shape[1], self.X.shape[2]), return_sequences=True))
        model.add(LSTM(32, activation='relu', return_sequences=True))
        model.add(LSTM(16, activation='relu', return_sequences=False))
        model.add(Dense(self.Y.shape[1]))
        model.compile(optimizer='adam', loss='mse', metrics=[tf.keras.metrics.RootMeanSquaredError(), tf.keras.metrics.MeanAbsoluteError()])
        model.summary()
        return model
    
    def train_model(self, model_name='LSTM'):
        if model_name == 'LSTM':
            model = self.prepare_LSTM_model()
        if model_name == 'RNN':
            model = self.prepare_RNN_model()    
        if model_name == 'ANN':
            model = self.prepare_ANN_model()    
        history = model.fit(self.X, self.Y, epochs=30, batch_size=16, validation_split=0.3, verbose=1) # Change to 30
        self.history = history
        plt.plot(history.history['loss'], label='Training loss')
        plt.plot(history.history['val_loss'], label='Testing loss')
        
        plt.legend()
        return model
    
    def predicted(self, model_name='LSTM'):
        model = self.train_model(model_name)
        predictions = list(map(lambda x: pd.Series(model.predict(x).reshape(1,-1)[0]), self.trainX_list))
        #return pd.Series(model.predict(self.X).reshape(1,-1)[0])
        self.model = model
        return dict(zip(self.houses, predictions))
    
    def results(self, model_name='LSTM'):
        predicted = self.predicted(model_name)
        house_prediction_list_df  = {}
        for house in predicted:
            house_prediction_df = house.consumption_df.iloc[n_past:].copy().reset_index(drop=True)
            house_prediction_df['timestamp'] = house.train_dates_df.iloc[n_past:].copy().reset_index(drop=True)
            house_prediction_df['energy_predicted'] = predicted[house]
            ### Anomaly Detection
            energy_stddev = house_prediction_df['energy_kWh'].std()
            house_prediction_df['Energy Consumption Error'] = house_prediction_df['energy_predicted'] - house_prediction_df['energy_kWh']
            house_prediction_df['Anomaly detected'] = house_prediction_df['Energy Consumption Error'].apply(lambda x: False if abs(x) < 1.5*energy_stddev else abs(x))
            ### Energy Deficit Calculation
            house_prediction_df['timestamp'] = pd.DatetimeIndex(house_prediction_df['timestamp'])
            generation_df['timestamp'] = pd.DatetimeIndex(generation_df['timestamp'])
            house_prediction_df = house_prediction_df.set_index('timestamp').join(generation_df.set_index('timestamp'))
            house_prediction_df['timestamp'] = house_prediction_df.index
            house_prediction_df.reset_index(drop=True, inplace=True)
            house_prediction_df['Total Generated Energy'] = house_prediction_df['Wind Energy']+ house_prediction_df['Solar Energy']
            house_prediction_df['Predicted Energy Deficit'] = house_prediction_df['Total Generated Energy'] - house_prediction_df['energy_predicted']
            house_prediction_df['Energy Deficit Flag'] = house_prediction_df['Predicted Energy Deficit'].apply(lambda x: False if x>0 else abs(x))
            house_prediction_list_df[house.house] = house_prediction_df
        return house_prediction_list_df

# %% [markdown]
# ## Model Name

# %%
model_name='RNN'

# %% [markdown]
# #### Scenario 1

# %%
# Train the time series model, perform predictions and answer the three research questions
zero_houses = list(clustered_df[clustered_df['Cluster'] == 0]['House'])
print(zero_houses)
zero_cluster = Cluster(zero_houses)
zero_cluster_results = zero_cluster.results(model_name)
print('Training History for Cluster 0:')
# Out:
# [1, 4, 13, 14, 18, 19, 28]
# 2022-03-30 13:51:09.478144: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-03-30 13:51:09.478169: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-03-30 13:51:09.478187: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (rishabh-Inspiron): /proc/driver/nvidia/version does not exist
# 2022-03-30 13:51:09.478495: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-03-30 13:51:09.649035: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 41286672 exceeds 10% of free system memory.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 14, 128)           17280
#
#  simple_rnn_1 (SimpleRNN)    (None, 14, 32)            5152
#
#  simple_rnn_2 (SimpleRNN)    (None, 16)                784
#
#  dense (Dense)               (None, 1)                 17
#
# =================================================================
# Total params: 23,233
# Trainable params: 23,233
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 7676/7680 [============================>.] - ETA: 0s - loss: 0.4663 - root_mean_squared_error: 0.6829 - mean_absolute_error: 0.4127
# 2022-03-30 13:52:03.452628: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 17694432 exceeds 10% of free system memory.
# 7680/7680 [==============================] - 61s 8ms/step - loss: 0.4664 - root_mean_squared_error: 0.6829 - mean_absolute_error: 0.4127 - val_loss: 0.5995 - val_root_mean_squared_error: 0.7743 - val_mean_absolute_error: 0.4579
# Epoch 2/30
# 7680/7680 [==============================] - 63s 8ms/step - loss: 0.4515 - root_mean_squared_error: 0.6719 - mean_absolute_error: 0.4025 - val_loss: 0.6001 - val_root_mean_squared_error: 0.7746 - val_mean_absolute_error: 0.4414
# Epoch 3/30
# 7680/7680 [==============================] - 62s 8ms/step - loss: 0.4453 - root_mean_squared_error: 0.6673 - mean_absolute_error: 0.3982 - val_loss: 0.6285 - val_root_mean_squared_error: 0.7928 - val_mean_absolute_error: 0.4633
# Epoch 4/30
# 7680/7680 [==============================] - 63s 8ms/step - loss: 0.4413 - root_mean_squared_error: 0.6643 - mean_absolute_error: 0.3958 - val_loss: 0.6602 - val_root_mean_squared_error: 0.8125 - val_mean_absolute_error: 0.4613
# Epoch 5/30
# 7680/7680 [==============================] - 63s 8ms/step - loss: 0.4396 - root_mean_squared_error: 0.6630 - mean_absolute_error: 0.3943 - val_loss: 0.6055 - val_root_mean_squared_error: 0.7781 - val_mean_absolute_error: 0.4651
# Epoch 6/30
# 7680/7680 [==============================] - 66s 9ms/step - loss: 0.4369 - root_mean_squared_error: 0.6610 - mean_absolute_error: 0.3925 - val_loss: 0.6319 - val_root_mean_squared_error: 0.7950 - val_mean_absolute_error: 0.4555
# Epoch 7/30
# 7680/7680 [==============================] - 60s 8ms/step - loss: 0.4364 - root_mean_squared_error: 0.6606 - mean_absolute_error: 0.3924 - val_loss: 0.6248 - val_root_mean_squared_error: 0.7904 - val_mean_absolute_error: 0.4560
# Epoch 8/30
# 7680/7680 [==============================] - 61s 8ms/step - loss: 0.4343 - root_mean_squared_error: 0.6590 - mean_absolute_error: 0.3913 - val_loss: 0.6344 - val_root_mean_squared_error: 0.7965 - val_mean_absolute_error: 0.4530
# Epoch 9/30
# 7680/7680 [==============================] - 60s 8ms/step - loss: 0.4341 - root_mean_squared_error: 0.6589 - mean_absolute_error: 0.3914 - val_loss: 0.6058 - val_root_mean_squared_error: 0.7783 - val_mean_absolute_error: 0.4576
# Epoch 10/30
# 7680/7680 [==============================] - 61s 8ms/step - loss: 0.4336 - root_mean_squared_error: 0.6585 - mean_absolute_error: 0.3906 - val_loss: 0.6104 - val_root_mean_squared_error: 0.7813 - val_mean_absolute_error: 0.4427
# Epoch 11/30
# 7680/7680 [==============================] - 84s 11ms/step - loss: 0.4342 - root_mean_squared_error: 0.6589 - mean_absolute_error: 0.3914 - val_loss: 0.6185 - val_root_mean_squared_error: 0.7865 - val_mean_absolute_error: 0.4514
# Epoch 12/30
# 7680/7680 [==============================] - 85s 11ms/step - loss: 0.4305 - root_mean_squared_error: 0.6561 - mean_absolute_error: 0.3892 - val_loss: 0.6465 - val_root_mean_squared_error: 0.8041 - val_mean_absolute_error: 0.4582
# Epoch 13/30
# 7680/7680 [==============================] - 66s 9ms/step - loss: 0.4299 - root_mean_squared_error: 0.6557 - mean_absolute_error: 0.3890 - val_loss: 0.6138 - val_root_mean_squared_error: 0.7835 - val_mean_absolute_error: 0.4437
# Epoch 14/30
# 7680/7680 [==============================] - 80s 10ms/step - loss: 0.4294 - root_mean_squared_error: 0.6553 - mean_absolute_error: 0.3889 - val_loss: 0.6105 - val_root_mean_squared_error: 0.7814 - val_mean_absolute_error: 0.4489
# Epoch 15/30
# 7680/7680 [==============================] - 85s 11ms/step - loss: 0.4286 - root_mean_squared_error: 0.6547 - mean_absolute_error: 0.3887 - val_loss: 0.6149 - val_root_mean_squared_error: 0.7841 - val_mean_absolute_error: 0.4465
# Epoch 16/30
# 7680/7680 [==============================] - 77s 10ms/step - loss: 0.4276 - root_mean_squared_error: 0.6539 - mean_absolute_error: 0.3881 - val_loss: 0.6467 - val_root_mean_squared_error: 0.8042 - val_mean_absolute_error: 0.4583
# Epoch 17/30
# 7680/7680 [==============================] - 60s 8ms/step - loss: 0.4291 - root_mean_squared_error: 0.6551 - mean_absolute_error: 0.3887 - val_loss: 0.6156 - val_root_mean_squared_error: 0.7846 - val_mean_absolute_error: 0.4529
# Epoch 18/30
# 7680/7680 [==============================] - 64s 8ms/step - loss: 0.4284 - root_mean_squared_error: 0.6545 - mean_absolute_error: 0.3892 - val_loss: 0.6298 - val_root_mean_squared_error: 0.7936 - val_mean_absolute_error: 0.4446
# Epoch 19/30
# 7680/7680 [==============================] - 61s 8ms/step - loss: 0.4293 - root_mean_squared_error: 0.6552 - mean_absolute_error: 0.3887 - val_loss: 0.6277 - val_root_mean_squared_error: 0.7923 - val_mean_absolute_error: 0.4531
# Epoch 20/30
# 7680/7680 [==============================] - 66s 9ms/step - loss: 0.4279 - root_mean_squared_error: 0.6542 - mean_absolute_error: 0.3884 - val_loss: 0.5966 - val_root_mean_squared_error: 0.7724 - val_mean_absolute_error: 0.4428
# Epoch 21/30
# 7680/7680 [==============================] - 87s 11ms/step - loss: 0.4264 - root_mean_squared_error: 0.6530 - mean_absolute_error: 0.3877 - val_loss: 0.6076 - val_root_mean_squared_error: 0.7795 - val_mean_absolute_error: 0.4450
# Epoch 22/30
# 7680/7680 [==============================] - 89s 12ms/step - loss: 0.4259 - root_mean_squared_error: 0.6526 - mean_absolute_error: 0.3871 - val_loss: 0.5993 - val_root_mean_squared_error: 0.7741 - val_mean_absolute_error: 0.4555
# Epoch 23/30
# 7680/7680 [==============================] - 87s 11ms/step - loss: 0.4248 - root_mean_squared_error: 0.6517 - mean_absolute_error: 0.3868 - val_loss: 0.6276 - val_root_mean_squared_error: 0.7922 - val_mean_absolute_error: 0.4503
# Epoch 24/30
# 7680/7680 [==============================] - 64s 8ms/step - loss: 0.4257 - root_mean_squared_error: 0.6525 - mean_absolute_error: 0.3873 - val_loss: 0.6111 - val_root_mean_squared_error: 0.7817 - val_mean_absolute_error: 0.4502
# Epoch 25/30
# 7680/7680 [==============================] - 62s 8ms/step - loss: 0.4249 - root_mean_squared_error: 0.6518 - mean_absolute_error: 0.3873 - val_loss: 0.6101 - val_root_mean_squared_error: 0.7811 - val_mean_absolute_error: 0.4586
# Epoch 26/30
# 7680/7680 [==============================] - 62s 8ms/step - loss: 0.4246 - root_mean_squared_error: 0.6516 - mean_absolute_error: 0.3873 - val_loss: 0.6635 - val_root_mean_squared_error: 0.8146 - val_mean_absolute_error: 0.4679
# Epoch 27/30
# 7680/7680 [==============================] - 88s 11ms/step - loss: 0.4263 - root_mean_squared_error: 0.6530 - mean_absolute_error: 0.3874 - val_loss: 0.5964 - val_root_mean_squared_error: 0.7723 - val_mean_absolute_error: 0.4448
# Epoch 28/30
# 7680/7680 [==============================] - 89s 12ms/step - loss: 0.4254 - root_mean_squared_error: 0.6522 - mean_absolute_error: 0.3869 - val_loss: 0.6500 - val_root_mean_squared_error: 0.8062 - val_mean_absolute_error: 0.4551
# Epoch 29/30
# 7680/7680 [==============================] - 90s 12ms/step - loss: 0.4283 - root_mean_squared_error: 0.6544 - mean_absolute_error: 0.3890 - val_loss: 0.5975 - val_root_mean_squared_error: 0.7730 - val_mean_absolute_error: 0.4613
# Epoch 30/30
# 7680/7680 [==============================] - 91s 12ms/step - loss: 0.4259 - root_mean_squared_error: 0.6526 - mean_absolute_error: 0.3874 - val_loss: 0.6511 - val_root_mean_squared_error: 0.8069 - val_mean_absolute_error: 0.4636
# Training History for Cluster 0:

# %%
one_houses = list(clustered_df[clustered_df['Cluster'] == 1]['House'])
one_cluster = Cluster(one_houses)
one_cluster_results = one_cluster.results(model_name)
print('Training History for Cluster 1:')
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_3 (SimpleRNN)    (None, 14, 128)           17280
#
#  simple_rnn_4 (SimpleRNN)    (None, 14, 32)            5152
#
#  simple_rnn_5 (SimpleRNN)    (None, 16)                784
#
#  dense_1 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 23,233
# Trainable params: 23,233
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 915/915 [==============================] - 13s 12ms/step - loss: 1.1434 - root_mean_squared_error: 1.0693 - mean_absolute_error: 0.6010 - val_loss: 1.4417 - val_root_mean_squared_error: 1.2007 - val_mean_absolute_error: 0.5652
# Epoch 2/30
# 915/915 [==============================] - 10s 11ms/step - loss: 0.9157 - root_mean_squared_error: 0.9569 - mean_absolute_error: 0.5323 - val_loss: 1.3483 - val_root_mean_squared_error: 1.1612 - val_mean_absolute_error: 0.5645
# Epoch 3/30
# 915/915 [==============================] - 10s 11ms/step - loss: 0.8601 - root_mean_squared_error: 0.9274 - mean_absolute_error: 0.5232 - val_loss: 1.2718 - val_root_mean_squared_error: 1.1278 - val_mean_absolute_error: 0.5706
# Epoch 4/30
# 915/915 [==============================] - 11s 12ms/step - loss: 0.8443 - root_mean_squared_error: 0.9188 - mean_absolute_error: 0.5157 - val_loss: 1.3330 - val_root_mean_squared_error: 1.1545 - val_mean_absolute_error: 0.5725
# Epoch 5/30
# 915/915 [==============================] - 11s 11ms/step - loss: 0.8395 - root_mean_squared_error: 0.9162 - mean_absolute_error: 0.5120 - val_loss: 1.2232 - val_root_mean_squared_error: 1.1060 - val_mean_absolute_error: 0.5662
# Epoch 6/30
# 915/915 [==============================] - 10s 11ms/step - loss: 0.8075 - root_mean_squared_error: 0.8986 - mean_absolute_error: 0.5052 - val_loss: 1.3104 - val_root_mean_squared_error: 1.1447 - val_mean_absolute_error: 0.5581
# Epoch 7/30
# 915/915 [==============================] - 10s 11ms/step - loss: 0.7938 - root_mean_squared_error: 0.8909 - mean_absolute_error: 0.4987 - val_loss: 1.2741 - val_root_mean_squared_error: 1.1287 - val_mean_absolute_error: 0.5123
# Epoch 8/30
# 915/915 [==============================] - 11s 12ms/step - loss: 0.8020 - root_mean_squared_error: 0.8956 - mean_absolute_error: 0.5026 - val_loss: 1.2003 - val_root_mean_squared_error: 1.0956 - val_mean_absolute_error: 0.5199
# Epoch 9/30
# 915/915 [==============================] - 11s 11ms/step - loss: 0.7815 - root_mean_squared_error: 0.8840 - mean_absolute_error: 0.4946 - val_loss: 1.3388 - val_root_mean_squared_error: 1.1570 - val_mean_absolute_error: 0.6633
# Epoch 10/30
# 915/915 [==============================] - 11s 12ms/step - loss: 0.7760 - root_mean_squared_error: 0.8809 - mean_absolute_error: 0.4976 - val_loss: 1.1974 - val_root_mean_squared_error: 1.0943 - val_mean_absolute_error: 0.5608
# Epoch 11/30
# 915/915 [==============================] - 10s 11ms/step - loss: 0.7714 - root_mean_squared_error: 0.8783 - mean_absolute_error: 0.4931 - val_loss: 1.1734 - val_root_mean_squared_error: 1.0832 - val_mean_absolute_error: 0.5228
# Epoch 12/30
# 915/915 [==============================] - 11s 12ms/step - loss: 0.7603 - root_mean_squared_error: 0.8720 - mean_absolute_error: 0.4923 - val_loss: 1.1236 - val_root_mean_squared_error: 1.0600 - val_mean_absolute_error: 0.5744
# Epoch 13/30
# 915/915 [==============================] - 10s 11ms/step - loss: 0.7586 - root_mean_squared_error: 0.8710 - mean_absolute_error: 0.4946 - val_loss: 1.2190 - val_root_mean_squared_error: 1.1041 - val_mean_absolute_error: 0.5832
# Epoch 14/30
# 915/915 [==============================] - 11s 12ms/step - loss: 0.7435 - root_mean_squared_error: 0.8623 - mean_absolute_error: 0.4897 - val_loss: 1.1696 - val_root_mean_squared_error: 1.0815 - val_mean_absolute_error: 0.5572
# Epoch 15/30
# 915/915 [==============================] - 11s 12ms/step - loss: 0.7408 - root_mean_squared_error: 0.8607 - mean_absolute_error: 0.4839 - val_loss: 1.1540 - val_root_mean_squared_error: 1.0742 - val_mean_absolute_error: 0.5157
# Epoch 16/30
# 915/915 [==============================] - 11s 12ms/step - loss: 0.7297 - root_mean_squared_error: 0.8542 - mean_absolute_error: 0.4840 - val_loss: 1.2057 - val_root_mean_squared_error: 1.0980 - val_mean_absolute_error: 0.5390
# Epoch 17/30
# 915/915 [==============================] - 11s 12ms/step - loss: 0.7227 - root_mean_squared_error: 0.8501 - mean_absolute_error: 0.4791 - val_loss: 1.2108 - val_root_mean_squared_error: 1.1004 - val_mean_absolute_error: 0.5448
# Epoch 18/30
# 915/915 [==============================] - 11s 12ms/step - loss: 0.7087 - root_mean_squared_error: 0.8418 - mean_absolute_error: 0.4794 - val_loss: 1.1637 - val_root_mean_squared_error: 1.0787 - val_mean_absolute_error: 0.5274
# Epoch 19/30
# 915/915 [==============================] - 11s 12ms/step - loss: 0.7111 - root_mean_squared_error: 0.8433 - mean_absolute_error: 0.4790 - val_loss: 1.1163 - val_root_mean_squared_error: 1.0566 - val_mean_absolute_error: 0.5122
# Epoch 20/30
# 915/915 [==============================] - 11s 12ms/step - loss: 0.7122 - root_mean_squared_error: 0.8439 - mean_absolute_error: 0.4795 - val_loss: 1.2202 - val_root_mean_squared_error: 1.1046 - val_mean_absolute_error: 0.5977
# Epoch 21/30
# 915/915 [==============================] - 11s 12ms/step - loss: 0.6851 - root_mean_squared_error: 0.8277 - mean_absolute_error: 0.4746 - val_loss: 1.1189 - val_root_mean_squared_error: 1.0578 - val_mean_absolute_error: 0.4903
# Epoch 22/30
# 915/915 [==============================] - 11s 12ms/step - loss: 0.7125 - root_mean_squared_error: 0.8441 - mean_absolute_error: 0.4805 - val_loss: 1.1464 - val_root_mean_squared_error: 1.0707 - val_mean_absolute_error: 0.5370
# Epoch 23/30
# 915/915 [==============================] - 10s 11ms/step - loss: 0.7154 - root_mean_squared_error: 0.8458 - mean_absolute_error: 0.4796 - val_loss: 1.3354 - val_root_mean_squared_error: 1.1556 - val_mean_absolute_error: 0.6528
# Epoch 24/30
# 915/915 [==============================] - 11s 12ms/step - loss: 0.7065 - root_mean_squared_error: 0.8406 - mean_absolute_error: 0.4798 - val_loss: 1.1626 - val_root_mean_squared_error: 1.0782 - val_mean_absolute_error: 0.5324
# Epoch 25/30
# 915/915 [==============================] - 11s 12ms/step - loss: 0.6991 - root_mean_squared_error: 0.8361 - mean_absolute_error: 0.4720 - val_loss: 1.1942 - val_root_mean_squared_error: 1.0928 - val_mean_absolute_error: 0.5421
# Epoch 26/30
# 915/915 [==============================] - 11s 12ms/step - loss: 0.6857 - root_mean_squared_error: 0.8281 - mean_absolute_error: 0.4754 - val_loss: 1.1706 - val_root_mean_squared_error: 1.0819 - val_mean_absolute_error: 0.5373
# Epoch 27/30
# 915/915 [==============================] - 11s 12ms/step - loss: 0.6928 - root_mean_squared_error: 0.8324 - mean_absolute_error: 0.4751 - val_loss: 1.1285 - val_root_mean_squared_error: 1.0623 - val_mean_absolute_error: 0.5388
# Epoch 28/30
# 915/915 [==============================] - 11s 12ms/step - loss: 0.6764 - root_mean_squared_error: 0.8225 - mean_absolute_error: 0.4695 - val_loss: 1.1237 - val_root_mean_squared_error: 1.0601 - val_mean_absolute_error: 0.5354
# Epoch 29/30
# 915/915 [==============================] - 11s 12ms/step - loss: 0.6724 - root_mean_squared_error: 0.8200 - mean_absolute_error: 0.4714 - val_loss: 1.1721 - val_root_mean_squared_error: 1.0826 - val_mean_absolute_error: 0.5417
# Epoch 30/30
# 915/915 [==============================] - 11s 12ms/step - loss: 0.6878 - root_mean_squared_error: 0.8294 - mean_absolute_error: 0.4746 - val_loss: 1.1066 - val_root_mean_squared_error: 1.0519 - val_mean_absolute_error: 0.5207
# Training History for Cluster 1:

# %%
two_houses = list(clustered_df[clustered_df['Cluster'] == 2]['House'])
two_cluster = Cluster(two_houses)
two_cluster_results = two_cluster.results(model_name)
print('Training History for Cluster 2:')
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_6 (SimpleRNN)    (None, 14, 128)           17280
#
#  simple_rnn_7 (SimpleRNN)    (None, 14, 32)            5152
#
#  simple_rnn_8 (SimpleRNN)    (None, 16)                784
#
#  dense_2 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 23,233
# Trainable params: 23,233
# Non-trainable params: 0
# _________________________________________________________________
# 2022-03-30 14:32:57.253981: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 81682272 exceeds 10% of free system memory.
# Epoch 1/30
# 15189/15194 [============================>.] - ETA: 0s - loss: 0.1484 - root_mean_squared_error: 0.3852 - mean_absolute_error: 0.2149
# 2022-03-30 14:35:17.993335: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 35007168 exceeds 10% of free system memory.
# 15194/15194 [==============================] - 156s 10ms/step - loss: 0.1484 - root_mean_squared_error: 0.3852 - mean_absolute_error: 0.2149 - val_loss: 0.2072 - val_root_mean_squared_error: 0.4552 - val_mean_absolute_error: 0.2474
# Epoch 2/30
# 15194/15194 [==============================] - 168s 11ms/step - loss: 0.1460 - root_mean_squared_error: 0.3821 - mean_absolute_error: 0.2112 - val_loss: 0.2073 - val_root_mean_squared_error: 0.4553 - val_mean_absolute_error: 0.2678
# Epoch 3/30
# 15194/15194 [==============================] - 140s 9ms/step - loss: 0.1454 - root_mean_squared_error: 0.3813 - mean_absolute_error: 0.2103 - val_loss: 0.2100 - val_root_mean_squared_error: 0.4583 - val_mean_absolute_error: 0.2503
# Epoch 4/30
# 15194/15194 [==============================] - 122s 8ms/step - loss: 0.1448 - root_mean_squared_error: 0.3805 - mean_absolute_error: 0.2097 - val_loss: 0.2118 - val_root_mean_squared_error: 0.4602 - val_mean_absolute_error: 0.2601
# Epoch 5/30
# 15194/15194 [==============================] - 146s 10ms/step - loss: 0.1445 - root_mean_squared_error: 0.3802 - mean_absolute_error: 0.2093 - val_loss: 0.2059 - val_root_mean_squared_error: 0.4537 - val_mean_absolute_error: 0.2582
# Epoch 6/30
# 15194/15194 [==============================] - 132s 9ms/step - loss: 0.1441 - root_mean_squared_error: 0.3796 - mean_absolute_error: 0.2088 - val_loss: 0.2110 - val_root_mean_squared_error: 0.4594 - val_mean_absolute_error: 0.2434
# Epoch 7/30
# 15194/15194 [==============================] - 122s 8ms/step - loss: 0.1441 - root_mean_squared_error: 0.3795 - mean_absolute_error: 0.2086 - val_loss: 0.2068 - val_root_mean_squared_error: 0.4547 - val_mean_absolute_error: 0.2520
# Epoch 8/30
# 15194/15194 [==============================] - 131s 9ms/step - loss: 0.1440 - root_mean_squared_error: 0.3794 - mean_absolute_error: 0.2084 - val_loss: 0.2061 - val_root_mean_squared_error: 0.4539 - val_mean_absolute_error: 0.2590
# Epoch 9/30
# 15194/15194 [==============================] - 178s 12ms/step - loss: 0.1439 - root_mean_squared_error: 0.3793 - mean_absolute_error: 0.2083 - val_loss: 0.2083 - val_root_mean_squared_error: 0.4564 - val_mean_absolute_error: 0.2519
# Epoch 10/30
# 15194/15194 [==============================] - 175s 12ms/step - loss: 0.1438 - root_mean_squared_error: 0.3792 - mean_absolute_error: 0.2083 - val_loss: 0.2103 - val_root_mean_squared_error: 0.4585 - val_mean_absolute_error: 0.2595
# Epoch 11/30
# 15194/15194 [==============================] - 166s 11ms/step - loss: 0.1436 - root_mean_squared_error: 0.3789 - mean_absolute_error: 0.2081 - val_loss: 0.2070 - val_root_mean_squared_error: 0.4550 - val_mean_absolute_error: 0.2514
# Epoch 12/30
# 15194/15194 [==============================] - 177s 12ms/step - loss: 0.1436 - root_mean_squared_error: 0.3790 - mean_absolute_error: 0.2080 - val_loss: 0.2067 - val_root_mean_squared_error: 0.4547 - val_mean_absolute_error: 0.2529
# Epoch 13/30
# 15194/15194 [==============================] - 155s 10ms/step - loss: 0.1434 - root_mean_squared_error: 0.3787 - mean_absolute_error: 0.2080 - val_loss: 0.2050 - val_root_mean_squared_error: 0.4527 - val_mean_absolute_error: 0.2484
# Epoch 14/30
# 15194/15194 [==============================] - 185s 12ms/step - loss: 0.1435 - root_mean_squared_error: 0.3788 - mean_absolute_error: 0.2080 - val_loss: 0.2065 - val_root_mean_squared_error: 0.4544 - val_mean_absolute_error: 0.2604
# Epoch 15/30
# 15194/15194 [==============================] - 139s 9ms/step - loss: 0.1434 - root_mean_squared_error: 0.3787 - mean_absolute_error: 0.2077 - val_loss: 0.2061 - val_root_mean_squared_error: 0.4539 - val_mean_absolute_error: 0.2540
# Epoch 16/30
# 15194/15194 [==============================] - 194s 13ms/step - loss: 0.1433 - root_mean_squared_error: 0.3786 - mean_absolute_error: 0.2078 - val_loss: 0.2074 - val_root_mean_squared_error: 0.4554 - val_mean_absolute_error: 0.2492
# Epoch 17/30
# 15194/15194 [==============================] - 191s 13ms/step - loss: 0.1433 - root_mean_squared_error: 0.3785 - mean_absolute_error: 0.2078 - val_loss: 0.2081 - val_root_mean_squared_error: 0.4562 - val_mean_absolute_error: 0.2600
# Epoch 18/30
# 15194/15194 [==============================] - 189s 12ms/step - loss: 0.1432 - root_mean_squared_error: 0.3784 - mean_absolute_error: 0.2079 - val_loss: 0.2058 - val_root_mean_squared_error: 0.4537 - val_mean_absolute_error: 0.2488
# Epoch 19/30
# 15194/15194 [==============================] - 193s 13ms/step - loss: 0.1431 - root_mean_squared_error: 0.3783 - mean_absolute_error: 0.2077 - val_loss: 0.2087 - val_root_mean_squared_error: 0.4569 - val_mean_absolute_error: 0.2534
# Epoch 20/30
# 15194/15194 [==============================] - 152s 10ms/step - loss: 0.1434 - root_mean_squared_error: 0.3787 - mean_absolute_error: 0.2079 - val_loss: 0.2066 - val_root_mean_squared_error: 0.4546 - val_mean_absolute_error: 0.2451
# Epoch 21/30
# 15194/15194 [==============================] - 126s 8ms/step - loss: 0.1433 - root_mean_squared_error: 0.3786 - mean_absolute_error: 0.2077 - val_loss: 0.2081 - val_root_mean_squared_error: 0.4562 - val_mean_absolute_error: 0.2493
# Epoch 22/30
# 15194/15194 [==============================] - 124s 8ms/step - loss: 0.1432 - root_mean_squared_error: 0.3784 - mean_absolute_error: 0.2074 - val_loss: 0.2049 - val_root_mean_squared_error: 0.4526 - val_mean_absolute_error: 0.2508
# Epoch 23/30
# 15194/15194 [==============================] - 125s 8ms/step - loss: 0.1432 - root_mean_squared_error: 0.3784 - mean_absolute_error: 0.2077 - val_loss: 0.2078 - val_root_mean_squared_error: 0.4559 - val_mean_absolute_error: 0.2534
# Epoch 24/30
# 15194/15194 [==============================] - 126s 8ms/step - loss: 0.1431 - root_mean_squared_error: 0.3783 - mean_absolute_error: 0.2075 - val_loss: 0.2092 - val_root_mean_squared_error: 0.4573 - val_mean_absolute_error: 0.2491
# Epoch 25/30
# 15194/15194 [==============================] - 126s 8ms/step - loss: 0.1429 - root_mean_squared_error: 0.3780 - mean_absolute_error: 0.2073 - val_loss: 0.2063 - val_root_mean_squared_error: 0.4542 - val_mean_absolute_error: 0.2471
# Epoch 26/30
# 15194/15194 [==============================] - 128s 8ms/step - loss: 0.1429 - root_mean_squared_error: 0.3780 - mean_absolute_error: 0.2073 - val_loss: 0.2083 - val_root_mean_squared_error: 0.4564 - val_mean_absolute_error: 0.2458
# Epoch 27/30
# 15194/15194 [==============================] - 153s 10ms/step - loss: 0.1430 - root_mean_squared_error: 0.3782 - mean_absolute_error: 0.2075 - val_loss: 0.2060 - val_root_mean_squared_error: 0.4539 - val_mean_absolute_error: 0.2587
# Epoch 28/30
# 15194/15194 [==============================] - 168s 11ms/step - loss: 0.1430 - root_mean_squared_error: 0.3781 - mean_absolute_error: 0.2075 - val_loss: 0.2071 - val_root_mean_squared_error: 0.4551 - val_mean_absolute_error: 0.2455
# Epoch 29/30
# 15194/15194 [==============================] - 135s 9ms/step - loss: 0.1429 - root_mean_squared_error: 0.3780 - mean_absolute_error: 0.2074 - val_loss: 0.2079 - val_root_mean_squared_error: 0.4560 - val_mean_absolute_error: 0.2508
# Epoch 30/30
# 15194/15194 [==============================] - 144s 9ms/step - loss: 0.1429 - root_mean_squared_error: 0.3780 - mean_absolute_error: 0.2075 - val_loss: 0.2083 - val_root_mean_squared_error: 0.4564 - val_mean_absolute_error: 0.2465
# Training History for Cluster 2:

# %%
three_houses = list(clustered_df[clustered_df['Cluster'] == 3]['House'])
three_cluster = Cluster(three_houses)
three_cluster_results = three_cluster.results(model_name)
print('Training History for Cluster 3:')
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_9 (SimpleRNN)    (None, 14, 128)           17280
#
#  simple_rnn_10 (SimpleRNN)   (None, 14, 32)            5152
#
#  simple_rnn_11 (SimpleRNN)   (None, 16)                784
#
#  dense_3 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 23,233
# Trainable params: 23,233
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 2745/2745 [==============================] - 26s 9ms/step - loss: 0.3680 - root_mean_squared_error: 0.6066 - mean_absolute_error: 0.3848 - val_loss: 0.4125 - val_root_mean_squared_error: 0.6423 - val_mean_absolute_error: 0.3899
# Epoch 2/30
# 2745/2745 [==============================] - 24s 9ms/step - loss: 0.3478 - root_mean_squared_error: 0.5897 - mean_absolute_error: 0.3700 - val_loss: 0.4157 - val_root_mean_squared_error: 0.6447 - val_mean_absolute_error: 0.4163
# Epoch 3/30
# 2745/2745 [==============================] - 24s 9ms/step - loss: 0.3363 - root_mean_squared_error: 0.5799 - mean_absolute_error: 0.3598 - val_loss: 0.4254 - val_root_mean_squared_error: 0.6522 - val_mean_absolute_error: 0.3973
# Epoch 4/30
# 2745/2745 [==============================] - 23s 8ms/step - loss: 0.3310 - root_mean_squared_error: 0.5754 - mean_absolute_error: 0.3550 - val_loss: 0.4148 - val_root_mean_squared_error: 0.6440 - val_mean_absolute_error: 0.3773
# Epoch 5/30
# 2745/2745 [==============================] - 23s 9ms/step - loss: 0.3284 - root_mean_squared_error: 0.5731 - mean_absolute_error: 0.3526 - val_loss: 0.4027 - val_root_mean_squared_error: 0.6346 - val_mean_absolute_error: 0.3917
# Epoch 6/30
# 2745/2745 [==============================] - 23s 8ms/step - loss: 0.3256 - root_mean_squared_error: 0.5706 - mean_absolute_error: 0.3501 - val_loss: 0.3953 - val_root_mean_squared_error: 0.6287 - val_mean_absolute_error: 0.4059
# Epoch 7/30
# 2745/2745 [==============================] - 23s 8ms/step - loss: 0.3227 - root_mean_squared_error: 0.5681 - mean_absolute_error: 0.3488 - val_loss: 0.4046 - val_root_mean_squared_error: 0.6361 - val_mean_absolute_error: 0.3938
# Epoch 8/30
# 2745/2745 [==============================] - 23s 8ms/step - loss: 0.3204 - root_mean_squared_error: 0.5660 - mean_absolute_error: 0.3455 - val_loss: 0.3939 - val_root_mean_squared_error: 0.6276 - val_mean_absolute_error: 0.4125
# Epoch 9/30
# 2745/2745 [==============================] - 23s 8ms/step - loss: 0.3207 - root_mean_squared_error: 0.5663 - mean_absolute_error: 0.3456 - val_loss: 0.4112 - val_root_mean_squared_error: 0.6412 - val_mean_absolute_error: 0.3915
# Epoch 10/30
# 2745/2745 [==============================] - 25s 9ms/step - loss: 0.3198 - root_mean_squared_error: 0.5655 - mean_absolute_error: 0.3458 - val_loss: 0.3863 - val_root_mean_squared_error: 0.6216 - val_mean_absolute_error: 0.3943
# Epoch 11/30
# 2745/2745 [==============================] - 24s 9ms/step - loss: 0.3183 - root_mean_squared_error: 0.5642 - mean_absolute_error: 0.3442 - val_loss: 0.3779 - val_root_mean_squared_error: 0.6147 - val_mean_absolute_error: 0.3908
# Epoch 12/30
# 2745/2745 [==============================] - 24s 9ms/step - loss: 0.3170 - root_mean_squared_error: 0.5630 - mean_absolute_error: 0.3438 - val_loss: 0.3924 - val_root_mean_squared_error: 0.6264 - val_mean_absolute_error: 0.3824
# Epoch 13/30
# 2745/2745 [==============================] - 24s 9ms/step - loss: 0.3163 - root_mean_squared_error: 0.5624 - mean_absolute_error: 0.3423 - val_loss: 0.3758 - val_root_mean_squared_error: 0.6130 - val_mean_absolute_error: 0.3719
# Epoch 14/30
# 2745/2745 [==============================] - 24s 9ms/step - loss: 0.3148 - root_mean_squared_error: 0.5611 - mean_absolute_error: 0.3418 - val_loss: 0.3995 - val_root_mean_squared_error: 0.6321 - val_mean_absolute_error: 0.3916
# Epoch 15/30
# 2745/2745 [==============================] - 26s 10ms/step - loss: 0.3150 - root_mean_squared_error: 0.5612 - mean_absolute_error: 0.3418 - val_loss: 0.3910 - val_root_mean_squared_error: 0.6253 - val_mean_absolute_error: 0.3691
# Epoch 16/30
# 2745/2745 [==============================] - 25s 9ms/step - loss: 0.3129 - root_mean_squared_error: 0.5593 - mean_absolute_error: 0.3404 - val_loss: 0.3935 - val_root_mean_squared_error: 0.6273 - val_mean_absolute_error: 0.3788
# Epoch 17/30
# 2745/2745 [==============================] - 32s 12ms/step - loss: 0.3139 - root_mean_squared_error: 0.5603 - mean_absolute_error: 0.3421 - val_loss: 0.3815 - val_root_mean_squared_error: 0.6177 - val_mean_absolute_error: 0.3644
# Epoch 18/30
# 2745/2745 [==============================] - 34s 12ms/step - loss: 0.3121 - root_mean_squared_error: 0.5587 - mean_absolute_error: 0.3406 - val_loss: 0.3921 - val_root_mean_squared_error: 0.6262 - val_mean_absolute_error: 0.3815
# Epoch 19/30
# 2745/2745 [==============================] - 24s 9ms/step - loss: 0.3136 - root_mean_squared_error: 0.5600 - mean_absolute_error: 0.3408 - val_loss: 0.4114 - val_root_mean_squared_error: 0.6414 - val_mean_absolute_error: 0.3883
# Epoch 20/30
# 2745/2745 [==============================] - 23s 9ms/step - loss: 0.3097 - root_mean_squared_error: 0.5565 - mean_absolute_error: 0.3390 - val_loss: 0.4039 - val_root_mean_squared_error: 0.6356 - val_mean_absolute_error: 0.3881
# Epoch 21/30
# 2745/2745 [==============================] - 23s 8ms/step - loss: 0.3101 - root_mean_squared_error: 0.5569 - mean_absolute_error: 0.3384 - val_loss: 0.3862 - val_root_mean_squared_error: 0.6214 - val_mean_absolute_error: 0.3797
# Epoch 22/30
# 2745/2745 [==============================] - 23s 8ms/step - loss: 0.3110 - root_mean_squared_error: 0.5577 - mean_absolute_error: 0.3393 - val_loss: 0.4380 - val_root_mean_squared_error: 0.6618 - val_mean_absolute_error: 0.3973
# Epoch 23/30
# 2745/2745 [==============================] - 23s 8ms/step - loss: 0.3099 - root_mean_squared_error: 0.5567 - mean_absolute_error: 0.3392 - val_loss: 0.3816 - val_root_mean_squared_error: 0.6178 - val_mean_absolute_error: 0.3730
# Epoch 24/30
# 2745/2745 [==============================] - 23s 8ms/step - loss: 0.3101 - root_mean_squared_error: 0.5569 - mean_absolute_error: 0.3393 - val_loss: 0.3872 - val_root_mean_squared_error: 0.6223 - val_mean_absolute_error: 0.3580
# Epoch 25/30
# 2745/2745 [==============================] - 23s 8ms/step - loss: 0.3078 - root_mean_squared_error: 0.5548 - mean_absolute_error: 0.3382 - val_loss: 0.3931 - val_root_mean_squared_error: 0.6270 - val_mean_absolute_error: 0.3730
# Epoch 26/30
# 2745/2745 [==============================] - 23s 8ms/step - loss: 0.3079 - root_mean_squared_error: 0.5549 - mean_absolute_error: 0.3370 - val_loss: 0.3938 - val_root_mean_squared_error: 0.6275 - val_mean_absolute_error: 0.3864
# Epoch 27/30
# 2745/2745 [==============================] - 24s 9ms/step - loss: 0.3080 - root_mean_squared_error: 0.5550 - mean_absolute_error: 0.3380 - val_loss: 0.4016 - val_root_mean_squared_error: 0.6337 - val_mean_absolute_error: 0.3931
# Epoch 28/30
# 2745/2745 [==============================] - 23s 8ms/step - loss: 0.3069 - root_mean_squared_error: 0.5540 - mean_absolute_error: 0.3367 - val_loss: 0.3953 - val_root_mean_squared_error: 0.6287 - val_mean_absolute_error: 0.3820
# Epoch 29/30
# 2745/2745 [==============================] - 33s 12ms/step - loss: 0.3038 - root_mean_squared_error: 0.5512 - mean_absolute_error: 0.3352 - val_loss: 0.3881 - val_root_mean_squared_error: 0.6230 - val_mean_absolute_error: 0.3740
# Epoch 30/30
# 2745/2745 [==============================] - 40s 15ms/step - loss: 0.3027 - root_mean_squared_error: 0.5502 - mean_absolute_error: 0.3339 - val_loss: 0.4000 - val_root_mean_squared_error: 0.6325 - val_mean_absolute_error: 0.3948
# Training History for Cluster 3:

# %%
## Save Scenario 1 models
zero_cluster.model.save(f'Models/Scenario1/{model_name}/zero_cluster')
one_cluster.model.save(f'Models/Scenario1/{model_name}/one_cluster')
two_cluster.model.save(f'Models/Scenario1/{model_name}/two_cluster')
three_cluster.model.save(f'Models/Scenario1/{model_name}/three_cluster')

## Pickling cluster and cluster results
zero_cluster_file = open(f"Models/Scenario1/Objects/{model_name}/zero_cluster.pickle", "wb")
pickle.dump(zero_cluster, zero_cluster_file)
zero_cluster_file.close()

one_cluster_file = open(f"Models/Scenario1/Objects/{model_name}/one_cluster.pickle", "wb")
pickle.dump(one_cluster, one_cluster_file)
one_cluster_file.close()

two_cluster_file = open(f"Models/Scenario1/Objects/{model_name}/two_cluster.pickle", "wb")
pickle.dump(two_cluster, two_cluster_file)
two_cluster_file.close()

three_cluster_file = open(f"Models/Scenario1/Objects/{model_name}/three_cluster.pickle", "wb")
pickle.dump(three_cluster, three_cluster_file)
three_cluster_file.close()

zero_cluster_results_file = open(f"Models/Scenario1/Objects/{model_name}/zero_cluster_results.pickle", "wb")
pickle.dump(zero_cluster_results, zero_cluster_results_file)
zero_cluster_results_file.close()

one_cluster_results_file = open(f"Models/Scenario1/Objects/{model_name}/one_cluster_results.pickle", "wb")
pickle.dump(one_cluster_results, one_cluster_results_file)
one_cluster_results_file.close()

two_cluster_results_file = open(f"Models/Scenario1/Objects/{model_name}/two_cluster_results.pickle", "wb")
pickle.dump(two_cluster_results, two_cluster_results_file)
two_cluster_results_file.close()

three_cluster_results_file = open(f"Models/Scenario1/Objects/{model_name}/three_cluster_results.pickle", "wb")
pickle.dump(three_cluster_results, three_cluster_results_file)
three_cluster_results_file.close()
# Out:
# 2022-03-30 16:02:15.827081: W tensorflow/python/util/util.cc:368] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# INFO:tensorflow:Assets written to: Models/Scenario1/RNN/zero_cluster/assets
# INFO:tensorflow:Assets written to: Models/Scenario1/RNN/one_cluster/assets
# INFO:tensorflow:Assets written to: Models/Scenario1/RNN/two_cluster/assets
# INFO:tensorflow:Assets written to: Models/Scenario1/RNN/three_cluster/assets
# INFO:tensorflow:Assets written to: ram://79e85e37-3095-425d-b8b9-ee54f2835987/assets
# INFO:tensorflow:Assets written to: ram://f974bf52-93cb-4d13-b71f-3cf143a75999/assets
# INFO:tensorflow:Assets written to: ram://4d975ec1-e45a-44c3-9808-c08b90a7deea/assets
# INFO:tensorflow:Assets written to: ram://8b6bb0f7-0e28-4dd3-af0a-f01d0c1fc15e/assets

# %% [markdown]
# #### Scenario 2

# %%
all_houses = list(clustered_df['House'])
all_cluster = Cluster(all_houses)
all_cluster_results = all_cluster.results(model_name)
print('Training History without clustering:')
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_12 (SimpleRNN)   (None, 14, 128)           17280
#
#  simple_rnn_13 (SimpleRNN)   (None, 14, 32)            5152
#
#  simple_rnn_14 (SimpleRNN)   (None, 16)                784
#
#  dense_4 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 23,233
# Trainable params: 23,233
# Non-trainable params: 0
# _________________________________________________________________
# 2022-03-30 16:02:47.140699: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 142643088 exceeds 10% of free system memory.
# Epoch 1/30
# 26534/26534 [==============================] - 257s 10ms/step - loss: 0.3289 - root_mean_squared_error: 0.5735 - mean_absolute_error: 0.3106 - val_loss: 0.3364 - val_root_mean_squared_error: 0.5800 - val_mean_absolute_error: 0.3205
# Epoch 2/30
# 26534/26534 [==============================] - 239s 9ms/step - loss: 0.3181 - root_mean_squared_error: 0.5640 - mean_absolute_error: 0.3056 - val_loss: 0.3296 - val_root_mean_squared_error: 0.5741 - val_mean_absolute_error: 0.3176
# Epoch 3/30
# 26534/26534 [==============================] - 329s 12ms/step - loss: 0.3164 - root_mean_squared_error: 0.5625 - mean_absolute_error: 0.3052 - val_loss: 0.3422 - val_root_mean_squared_error: 0.5850 - val_mean_absolute_error: 0.3522
# Epoch 4/30
# 26534/26534 [==============================] - 286s 11ms/step - loss: 0.3154 - root_mean_squared_error: 0.5616 - mean_absolute_error: 0.3046 - val_loss: 0.3336 - val_root_mean_squared_error: 0.5776 - val_mean_absolute_error: 0.3401
# Epoch 5/30
# 26534/26534 [==============================] - 272s 10ms/step - loss: 0.3125 - root_mean_squared_error: 0.5590 - mean_absolute_error: 0.3031 - val_loss: 0.3764 - val_root_mean_squared_error: 0.6135 - val_mean_absolute_error: 0.3346
# Epoch 6/30
# 26534/26534 [==============================] - 289s 11ms/step - loss: 0.3116 - root_mean_squared_error: 0.5583 - mean_absolute_error: 0.3024 - val_loss: 0.3351 - val_root_mean_squared_error: 0.5789 - val_mean_absolute_error: 0.3204
# Epoch 7/30
# 26534/26534 [==============================] - 279s 11ms/step - loss: 0.3110 - root_mean_squared_error: 0.5577 - mean_absolute_error: 0.3026 - val_loss: 0.3323 - val_root_mean_squared_error: 0.5764 - val_mean_absolute_error: 0.3231
# Epoch 8/30
# 26534/26534 [==============================] - 289s 11ms/step - loss: 0.3100 - root_mean_squared_error: 0.5567 - mean_absolute_error: 0.3019 - val_loss: 0.3306 - val_root_mean_squared_error: 0.5750 - val_mean_absolute_error: 0.3077
# Epoch 9/30
# 26534/26534 [==============================] - 282s 11ms/step - loss: 0.3085 - root_mean_squared_error: 0.5555 - mean_absolute_error: 0.3013 - val_loss: 0.3464 - val_root_mean_squared_error: 0.5886 - val_mean_absolute_error: 0.3337
# Epoch 10/30
# 26534/26534 [==============================] - 279s 11ms/step - loss: 0.3084 - root_mean_squared_error: 0.5553 - mean_absolute_error: 0.3015 - val_loss: 0.3285 - val_root_mean_squared_error: 0.5732 - val_mean_absolute_error: 0.3243
# Epoch 11/30
# 26534/26534 [==============================] - 316s 12ms/step - loss: 0.3083 - root_mean_squared_error: 0.5553 - mean_absolute_error: 0.3010 - val_loss: 0.3357 - val_root_mean_squared_error: 0.5794 - val_mean_absolute_error: 0.3161
# Epoch 12/30
# 26534/26534 [==============================] - 323s 12ms/step - loss: 0.3080 - root_mean_squared_error: 0.5550 - mean_absolute_error: 0.3007 - val_loss: 0.3386 - val_root_mean_squared_error: 0.5819 - val_mean_absolute_error: 0.3146
# Epoch 13/30
# 26534/26534 [==============================] - 324s 12ms/step - loss: 0.3090 - root_mean_squared_error: 0.5559 - mean_absolute_error: 0.3012 - val_loss: 0.3345 - val_root_mean_squared_error: 0.5784 - val_mean_absolute_error: 0.3343
# Epoch 14/30
# 26534/26534 [==============================] - 305s 12ms/step - loss: 0.3077 - root_mean_squared_error: 0.5547 - mean_absolute_error: 0.3008 - val_loss: 0.3255 - val_root_mean_squared_error: 0.5705 - val_mean_absolute_error: 0.3160
# Epoch 15/30
# 26534/26534 [==============================] - 307s 12ms/step - loss: 0.3077 - root_mean_squared_error: 0.5547 - mean_absolute_error: 0.3009 - val_loss: 0.3273 - val_root_mean_squared_error: 0.5721 - val_mean_absolute_error: 0.3208
# Epoch 16/30
# 26534/26534 [==============================] - 249s 9ms/step - loss: 0.3094 - root_mean_squared_error: 0.5562 - mean_absolute_error: 0.3014 - val_loss: 0.3518 - val_root_mean_squared_error: 0.5931 - val_mean_absolute_error: 0.3238
# Epoch 17/30
# 26534/26534 [==============================] - 221s 8ms/step - loss: 0.3069 - root_mean_squared_error: 0.5539 - mean_absolute_error: 0.3007 - val_loss: 0.3275 - val_root_mean_squared_error: 0.5723 - val_mean_absolute_error: 0.3149
# Epoch 18/30
# 26534/26534 [==============================] - 219s 8ms/step - loss: 0.3059 - root_mean_squared_error: 0.5531 - mean_absolute_error: 0.3007 - val_loss: 0.3346 - val_root_mean_squared_error: 0.5785 - val_mean_absolute_error: 0.3225
# Epoch 19/30
# 26534/26534 [==============================] - 219s 8ms/step - loss: 0.3064 - root_mean_squared_error: 0.5536 - mean_absolute_error: 0.3009 - val_loss: 0.3373 - val_root_mean_squared_error: 0.5808 - val_mean_absolute_error: 0.3308
# Epoch 20/30
# 26534/26534 [==============================] - 228s 9ms/step - loss: 0.3067 - root_mean_squared_error: 0.5538 - mean_absolute_error: 0.3003 - val_loss: 0.3314 - val_root_mean_squared_error: 0.5757 - val_mean_absolute_error: 0.3176
# Epoch 21/30
# 26534/26534 [==============================] - 241s 9ms/step - loss: 0.3075 - root_mean_squared_error: 0.5545 - mean_absolute_error: 0.3018 - val_loss: 0.3344 - val_root_mean_squared_error: 0.5782 - val_mean_absolute_error: 0.3324
# Epoch 22/30
# 26534/26534 [==============================] - 227s 9ms/step - loss: 0.3060 - root_mean_squared_error: 0.5532 - mean_absolute_error: 0.3019 - val_loss: 0.3394 - val_root_mean_squared_error: 0.5825 - val_mean_absolute_error: 0.3237
# Epoch 23/30
# 26534/26534 [==============================] - 228s 9ms/step - loss: 0.3065 - root_mean_squared_error: 0.5537 - mean_absolute_error: 0.3012 - val_loss: 0.3512 - val_root_mean_squared_error: 0.5926 - val_mean_absolute_error: 0.3211
# Epoch 24/30
# 26534/26534 [==============================] - 227s 9ms/step - loss: 0.3044 - root_mean_squared_error: 0.5518 - mean_absolute_error: 0.3003 - val_loss: 0.3469 - val_root_mean_squared_error: 0.5890 - val_mean_absolute_error: 0.3250
# Epoch 25/30
# 26534/26534 [==============================] - 229s 9ms/step - loss: 0.3039 - root_mean_squared_error: 0.5513 - mean_absolute_error: 0.3004 - val_loss: 0.3313 - val_root_mean_squared_error: 0.5756 - val_mean_absolute_error: 0.3301
# Epoch 26/30
# 26534/26534 [==============================] - 228s 9ms/step - loss: 0.3057 - root_mean_squared_error: 0.5529 - mean_absolute_error: 0.3007 - val_loss: 0.3514 - val_root_mean_squared_error: 0.5928 - val_mean_absolute_error: 0.3256
# Epoch 27/30
# 26534/26534 [==============================] - 231s 9ms/step - loss: 0.3032 - root_mean_squared_error: 0.5506 - mean_absolute_error: 0.2999 - val_loss: 0.3459 - val_root_mean_squared_error: 0.5882 - val_mean_absolute_error: 0.3120
# Epoch 28/30
# 26534/26534 [==============================] - 229s 9ms/step - loss: 0.3054 - root_mean_squared_error: 0.5526 - mean_absolute_error: 0.3006 - val_loss: 0.3334 - val_root_mean_squared_error: 0.5774 - val_mean_absolute_error: 0.3185
# Epoch 29/30
# 26534/26534 [==============================] - 237s 9ms/step - loss: 0.3035 - root_mean_squared_error: 0.5509 - mean_absolute_error: 0.2997 - val_loss: 0.3467 - val_root_mean_squared_error: 0.5888 - val_mean_absolute_error: 0.3295
# Epoch 30/30
# 26534/26534 [==============================] - 236s 9ms/step - loss: 0.3041 - root_mean_squared_error: 0.5515 - mean_absolute_error: 0.3001 - val_loss: 0.3324 - val_root_mean_squared_error: 0.5766 - val_mean_absolute_error: 0.3303
# Training History without clustering:

# %%
### Save Scenario 2 models
all_cluster.model.save(f'Models/Scenario2/{model_name}/all_cluster')

## Pickling Scenario 2 cluster and cluster result files
all_cluster_file = open(f"Models/Scenario2/Objects/{model_name}/all_cluster.pickle", "wb+")
pickle.dump(all_cluster, all_cluster_file)
all_cluster_file.close()

all_cluster_results_file = open(f"Models/Scenario2/Objects/{model_name}/all_cluster_results.pickle", "wb+")
pickle.dump(all_cluster_results, all_cluster_results_file)
all_cluster_results_file.close()
# Out:
# INFO:tensorflow:Assets written to: Models/Scenario2/RNN/all_cluster/assets
# INFO:tensorflow:Assets written to: ram://d432aa8f-5948-4a4b-a2aa-056c13ff63d7/assets

# %% [markdown]
# #### Predictions Graph functions

# %%
def x_axis_label_format(label):
    """
    Convert time label to the format of pandas line plot
    """
    label = pd.Timestamp(label)
    month = label.month_name()[:3]
    #if month == 'Jan':
    month += f'\n{label.year}'
    return month

def graph_predictions(cluster_specific_results, all_results):
    first_house = list(cluster_specific_results.keys())[0]
    df1 = cluster_specific_results[first_house][['timestamp','energy_predicted', 'energy_kWh']]
    df1['timestamp'] = pd.to_datetime(df1['timestamp'])
    df1 = df1.set_index('timestamp')
    df1['energy_predicted_without_clustering']= np.array(all_results[first_house][['energy_predicted']])
    df1.rename({'energy_predicted':'energy_predicted_with_clustering', 'energy_kWh':'real_energy'},axis = 1, inplace = True)
    ax = df1[::300].plot.line(figsize=(20,10))
    #ax.set_xticklabels(map(x_axis_label_format, df1[::int(len(df1)/8)+1].index))
    #import matplotlib.dates as mdates
    #myFmt = mdates.DateFormatter('%Y-%m')
    #ax.xaxis.set_major_formatter(myFmt)
    ax.set_title(f'Predictions for house {first_house}')

# %% [markdown]
# #### Predictions for Scenario 1 and Scenario 2

# %%
graph_predictions(zero_cluster_results, all_cluster_results)
#df1 = zero_cluster_results[1][['timestamp','energy_predicted', 'energy_kWh']].set_index('timestamp')
#df1['energy_predicted_without_clustering']= np.array(all_cluster_results[1][['energy_predicted']])
# Out:
# /tmp/ipykernel_165160/442122963.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['timestamp'] = pd.to_datetime(df1['timestamp'])

# %%
graph_predictions(one_cluster_results, all_cluster_results)
# Out:
# /tmp/ipykernel_165160/442122963.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['timestamp'] = pd.to_datetime(df1['timestamp'])

# %%
graph_predictions(two_cluster_results, all_cluster_results)
# Out:
# /tmp/ipykernel_165160/442122963.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['timestamp'] = pd.to_datetime(df1['timestamp'])

# %%
graph_predictions(three_cluster_results, all_cluster_results)
# Out:
# /tmp/ipykernel_165160/442122963.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['timestamp'] = pd.to_datetime(df1['timestamp'])

# %% [markdown]
# ### Function to create tables

# %%
def create_metrics(scenario_results, val=False):
    if val == False:
        rmse = 'root_mean_squared_error'
        mae = 'mean_absolute_error'
    else:
        rmse = 'val_root_mean_squared_error'
        mae = 'val_mean_absolute_error'
    scenario_rmse = list(map(lambda x: x.history.history[rmse],scenario_results))
    scenario_mae = list(map(lambda x: x.history.history[mae],scenario_results))
    scenario_rmse = np.array(scenario_rmse).reshape(-1,)
    scenario_mae = np.array(scenario_mae).reshape(-1,)
    return [np.min(scenario_rmse),np.max(scenario_rmse),np.mean(scenario_rmse),np.min(scenario_mae),np.max(scenario_mae),np.mean(scenario_mae)]

# %% [markdown]
# #### Scenario 1 and Scenario 2 Metric Tables

# %%
scenario_1_results = [zero_cluster, one_cluster, two_cluster, three_cluster]
scenario_1_metrics = create_metrics(scenario_1_results)
scenario_1_validation_metrics = create_metrics(scenario_1_results, val= True)
scenario_1_metrics
# Out:
# [0.3780049979686737,
#  1.0692802667617798,
#  0.6180050527056058,
#  0.20730949938297272,
#  0.6009553670883179,
#  0.3593144163489342]

# %%
scenario_2_results = [all_cluster]
scenario_2_metrics = create_metrics(scenario_2_results)
scenario_2_validation_metrics = create_metrics(scenario_2_results, val= True)
scenario_2_metrics
# Out:
# [0.5506365299224854,
#  0.5734824538230896,
#  0.5557735502719879,
#  0.29968395829200745,
#  0.31059500575065613,
#  0.3017947137355804]

# %% [markdown]
# #### Scenario 3 and 4

# %%
### Removing smart device features
House.cols = ['energy_kWh']
#House.cols

# %%
scenario_3_zero_cluster = Cluster(zero_houses)
scenario_3_zero_cluster_results = scenario_3_zero_cluster.results(model_name)
print('Training History for Cluster 0:')
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_15 (SimpleRNN)   (None, 14, 128)           16640
#
#  simple_rnn_16 (SimpleRNN)   (None, 14, 32)            5152
#
#  simple_rnn_17 (SimpleRNN)   (None, 16)                784
#
#  dense_5 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 22,593
# Trainable params: 22,593
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 7680/7680 [==============================] - 66s 8ms/step - loss: 0.4601 - root_mean_squared_error: 0.6783 - mean_absolute_error: 0.4086 - val_loss: 0.5869 - val_root_mean_squared_error: 0.7661 - val_mean_absolute_error: 0.4358
# Epoch 2/30
# 7680/7680 [==============================] - 65s 8ms/step - loss: 0.4490 - root_mean_squared_error: 0.6701 - mean_absolute_error: 0.4002 - val_loss: 0.6188 - val_root_mean_squared_error: 0.7866 - val_mean_absolute_error: 0.4650
# Epoch 3/30
# 7680/7680 [==============================] - 65s 9ms/step - loss: 0.4451 - root_mean_squared_error: 0.6672 - mean_absolute_error: 0.3977 - val_loss: 0.6260 - val_root_mean_squared_error: 0.7912 - val_mean_absolute_error: 0.4528
# Epoch 4/30
# 7680/7680 [==============================] - 64s 8ms/step - loss: 0.4422 - root_mean_squared_error: 0.6649 - mean_absolute_error: 0.3958 - val_loss: 0.6314 - val_root_mean_squared_error: 0.7946 - val_mean_absolute_error: 0.4588
# Epoch 5/30
# 7680/7680 [==============================] - 66s 9ms/step - loss: 0.4413 - root_mean_squared_error: 0.6643 - mean_absolute_error: 0.3947 - val_loss: 0.6206 - val_root_mean_squared_error: 0.7878 - val_mean_absolute_error: 0.4928
# Epoch 6/30
# 7680/7680 [==============================] - 65s 9ms/step - loss: 0.4384 - root_mean_squared_error: 0.6621 - mean_absolute_error: 0.3938 - val_loss: 0.6553 - val_root_mean_squared_error: 0.8095 - val_mean_absolute_error: 0.4610
# Epoch 7/30
# 7680/7680 [==============================] - 63s 8ms/step - loss: 0.4366 - root_mean_squared_error: 0.6608 - mean_absolute_error: 0.3928 - val_loss: 0.5985 - val_root_mean_squared_error: 0.7736 - val_mean_absolute_error: 0.4475
# Epoch 8/30
# 7680/7680 [==============================] - 65s 8ms/step - loss: 0.4359 - root_mean_squared_error: 0.6602 - mean_absolute_error: 0.3923 - val_loss: 0.6138 - val_root_mean_squared_error: 0.7834 - val_mean_absolute_error: 0.4509
# Epoch 9/30
# 7680/7680 [==============================] - 68s 9ms/step - loss: 0.4346 - root_mean_squared_error: 0.6593 - mean_absolute_error: 0.3911 - val_loss: 0.6118 - val_root_mean_squared_error: 0.7822 - val_mean_absolute_error: 0.4444
# Epoch 10/30
# 7680/7680 [==============================] - 68s 9ms/step - loss: 0.4343 - root_mean_squared_error: 0.6590 - mean_absolute_error: 0.3912 - val_loss: 0.6473 - val_root_mean_squared_error: 0.8046 - val_mean_absolute_error: 0.4518
# Epoch 11/30
# 7680/7680 [==============================] - 88s 11ms/step - loss: 0.4324 - root_mean_squared_error: 0.6576 - mean_absolute_error: 0.3909 - val_loss: 0.6132 - val_root_mean_squared_error: 0.7831 - val_mean_absolute_error: 0.4492
# Epoch 12/30
# 7680/7680 [==============================] - 66s 9ms/step - loss: 0.4323 - root_mean_squared_error: 0.6575 - mean_absolute_error: 0.3905 - val_loss: 0.6354 - val_root_mean_squared_error: 0.7971 - val_mean_absolute_error: 0.4573
# Epoch 13/30
# 7680/7680 [==============================] - 63s 8ms/step - loss: 0.4320 - root_mean_squared_error: 0.6573 - mean_absolute_error: 0.3900 - val_loss: 0.6534 - val_root_mean_squared_error: 0.8083 - val_mean_absolute_error: 0.4592
# Epoch 14/30
# 7680/7680 [==============================] - 63s 8ms/step - loss: 0.4321 - root_mean_squared_error: 0.6574 - mean_absolute_error: 0.3901 - val_loss: 0.6097 - val_root_mean_squared_error: 0.7809 - val_mean_absolute_error: 0.4487
# Epoch 15/30
# 7680/7680 [==============================] - 63s 8ms/step - loss: 0.4320 - root_mean_squared_error: 0.6572 - mean_absolute_error: 0.3902 - val_loss: 0.6261 - val_root_mean_squared_error: 0.7913 - val_mean_absolute_error: 0.4472
# Epoch 16/30
# 7680/7680 [==============================] - 68s 9ms/step - loss: 0.4314 - root_mean_squared_error: 0.6568 - mean_absolute_error: 0.3899 - val_loss: 0.6443 - val_root_mean_squared_error: 0.8027 - val_mean_absolute_error: 0.4548
# Epoch 17/30
# 7680/7680 [==============================] - 65s 8ms/step - loss: 0.4318 - root_mean_squared_error: 0.6571 - mean_absolute_error: 0.3904 - val_loss: 0.6478 - val_root_mean_squared_error: 0.8048 - val_mean_absolute_error: 0.4644
# Epoch 18/30
# 7680/7680 [==============================] - 68s 9ms/step - loss: 0.4302 - root_mean_squared_error: 0.6559 - mean_absolute_error: 0.3886 - val_loss: 0.5974 - val_root_mean_squared_error: 0.7729 - val_mean_absolute_error: 0.4519
# Epoch 19/30
# 7680/7680 [==============================] - 63s 8ms/step - loss: 0.4298 - root_mean_squared_error: 0.6556 - mean_absolute_error: 0.3884 - val_loss: 0.5992 - val_root_mean_squared_error: 0.7741 - val_mean_absolute_error: 0.4493
# Epoch 20/30
# 7680/7680 [==============================] - 63s 8ms/step - loss: 0.4295 - root_mean_squared_error: 0.6553 - mean_absolute_error: 0.3885 - val_loss: 0.6342 - val_root_mean_squared_error: 0.7964 - val_mean_absolute_error: 0.4564
# Epoch 21/30
# 7680/7680 [==============================] - 64s 8ms/step - loss: 0.4294 - root_mean_squared_error: 0.6553 - mean_absolute_error: 0.3889 - val_loss: 0.6256 - val_root_mean_squared_error: 0.7910 - val_mean_absolute_error: 0.4479
# Epoch 22/30
# 7680/7680 [==============================] - 63s 8ms/step - loss: 0.4281 - root_mean_squared_error: 0.6543 - mean_absolute_error: 0.3880 - val_loss: 0.6105 - val_root_mean_squared_error: 0.7814 - val_mean_absolute_error: 0.4447
# Epoch 23/30
# 7680/7680 [==============================] - 63s 8ms/step - loss: 0.4270 - root_mean_squared_error: 0.6534 - mean_absolute_error: 0.3886 - val_loss: 0.6226 - val_root_mean_squared_error: 0.7891 - val_mean_absolute_error: 0.4551
# Epoch 24/30
# 7680/7680 [==============================] - 63s 8ms/step - loss: 0.4289 - root_mean_squared_error: 0.6549 - mean_absolute_error: 0.3895 - val_loss: 0.6252 - val_root_mean_squared_error: 0.7907 - val_mean_absolute_error: 0.4526
# Epoch 25/30
# 7680/7680 [==============================] - 63s 8ms/step - loss: 0.4280 - root_mean_squared_error: 0.6542 - mean_absolute_error: 0.3882 - val_loss: 0.6167 - val_root_mean_squared_error: 0.7853 - val_mean_absolute_error: 0.4571
# Epoch 26/30
# 7680/7680 [==============================] - 63s 8ms/step - loss: 0.4282 - root_mean_squared_error: 0.6544 - mean_absolute_error: 0.3882 - val_loss: 0.6205 - val_root_mean_squared_error: 0.7877 - val_mean_absolute_error: 0.4592
# Epoch 27/30
# 7680/7680 [==============================] - 65s 8ms/step - loss: 0.4257 - root_mean_squared_error: 0.6525 - mean_absolute_error: 0.3879 - val_loss: 0.6519 - val_root_mean_squared_error: 0.8074 - val_mean_absolute_error: 0.4546
# Epoch 28/30
# 7680/7680 [==============================] - 63s 8ms/step - loss: 0.4267 - root_mean_squared_error: 0.6532 - mean_absolute_error: 0.3878 - val_loss: 0.6364 - val_root_mean_squared_error: 0.7978 - val_mean_absolute_error: 0.4571
# Epoch 29/30
# 7680/7680 [==============================] - 65s 8ms/step - loss: 0.4262 - root_mean_squared_error: 0.6528 - mean_absolute_error: 0.3871 - val_loss: 0.6508 - val_root_mean_squared_error: 0.8067 - val_mean_absolute_error: 0.4582
# Epoch 30/30
# 7680/7680 [==============================] - 63s 8ms/step - loss: 0.4255 - root_mean_squared_error: 0.6523 - mean_absolute_error: 0.3874 - val_loss: 0.6163 - val_root_mean_squared_error: 0.7851 - val_mean_absolute_error: 0.4486
# Training History for Cluster 0:

# %%
scenario_3_one_cluster = Cluster(one_houses)
scenario_3_one_cluster_results = scenario_3_one_cluster.results(model_name)
print('Training History for Cluster 1:')
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_18 (SimpleRNN)   (None, 14, 128)           16640
#
#  simple_rnn_19 (SimpleRNN)   (None, 14, 32)            5152
#
#  simple_rnn_20 (SimpleRNN)   (None, 16)                784
#
#  dense_6 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 22,593
# Trainable params: 22,593
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 915/915 [==============================] - 9s 9ms/step - loss: 1.0078 - root_mean_squared_error: 1.0039 - mean_absolute_error: 0.5601 - val_loss: 1.2684 - val_root_mean_squared_error: 1.1262 - val_mean_absolute_error: 0.5811
# Epoch 2/30
# 915/915 [==============================] - 8s 8ms/step - loss: 0.8671 - root_mean_squared_error: 0.9312 - mean_absolute_error: 0.5249 - val_loss: 1.4326 - val_root_mean_squared_error: 1.1969 - val_mean_absolute_error: 0.5714
# Epoch 3/30
# 915/915 [==============================] - 8s 8ms/step - loss: 0.8866 - root_mean_squared_error: 0.9416 - mean_absolute_error: 0.5202 - val_loss: 1.4035 - val_root_mean_squared_error: 1.1847 - val_mean_absolute_error: 0.6567
# Epoch 4/30
# 915/915 [==============================] - 7s 8ms/step - loss: 0.8478 - root_mean_squared_error: 0.9208 - mean_absolute_error: 0.5154 - val_loss: 1.2891 - val_root_mean_squared_error: 1.1354 - val_mean_absolute_error: 0.5524
# Epoch 5/30
# 915/915 [==============================] - 8s 8ms/step - loss: 0.8070 - root_mean_squared_error: 0.8983 - mean_absolute_error: 0.5071 - val_loss: 1.1489 - val_root_mean_squared_error: 1.0719 - val_mean_absolute_error: 0.5360
# Epoch 6/30
# 915/915 [==============================] - 8s 8ms/step - loss: 0.7973 - root_mean_squared_error: 0.8929 - mean_absolute_error: 0.5011 - val_loss: 1.1697 - val_root_mean_squared_error: 1.0815 - val_mean_absolute_error: 0.5390
# Epoch 7/30
# 915/915 [==============================] - 7s 8ms/step - loss: 0.7763 - root_mean_squared_error: 0.8811 - mean_absolute_error: 0.4994 - val_loss: 1.3288 - val_root_mean_squared_error: 1.1527 - val_mean_absolute_error: 0.5556
# Epoch 8/30
# 915/915 [==============================] - 8s 8ms/step - loss: 0.7672 - root_mean_squared_error: 0.8759 - mean_absolute_error: 0.4988 - val_loss: 1.1560 - val_root_mean_squared_error: 1.0752 - val_mean_absolute_error: 0.5340
# Epoch 9/30
# 915/915 [==============================] - 8s 8ms/step - loss: 0.7697 - root_mean_squared_error: 0.8773 - mean_absolute_error: 0.4927 - val_loss: 1.2707 - val_root_mean_squared_error: 1.1273 - val_mean_absolute_error: 0.5576
# Epoch 10/30
# 915/915 [==============================] - 8s 8ms/step - loss: 0.7308 - root_mean_squared_error: 0.8549 - mean_absolute_error: 0.4829 - val_loss: 1.1969 - val_root_mean_squared_error: 1.0940 - val_mean_absolute_error: 0.5260
# Epoch 11/30
# 915/915 [==============================] - 8s 8ms/step - loss: 0.7237 - root_mean_squared_error: 0.8507 - mean_absolute_error: 0.4802 - val_loss: 1.1415 - val_root_mean_squared_error: 1.0684 - val_mean_absolute_error: 0.5137
# Epoch 12/30
# 915/915 [==============================] - 8s 8ms/step - loss: 0.7254 - root_mean_squared_error: 0.8517 - mean_absolute_error: 0.4841 - val_loss: 1.1196 - val_root_mean_squared_error: 1.0581 - val_mean_absolute_error: 0.5192
# Epoch 13/30
# 915/915 [==============================] - 8s 8ms/step - loss: 0.7279 - root_mean_squared_error: 0.8532 - mean_absolute_error: 0.4843 - val_loss: 1.0960 - val_root_mean_squared_error: 1.0469 - val_mean_absolute_error: 0.4956
# Epoch 14/30
# 915/915 [==============================] - 8s 8ms/step - loss: 0.6996 - root_mean_squared_error: 0.8364 - mean_absolute_error: 0.4773 - val_loss: 1.2190 - val_root_mean_squared_error: 1.1041 - val_mean_absolute_error: 0.5654
# Epoch 15/30
# 915/915 [==============================] - 7s 8ms/step - loss: 0.7028 - root_mean_squared_error: 0.8384 - mean_absolute_error: 0.4805 - val_loss: 1.1236 - val_root_mean_squared_error: 1.0600 - val_mean_absolute_error: 0.5087
# Epoch 16/30
# 915/915 [==============================] - 8s 8ms/step - loss: 0.6943 - root_mean_squared_error: 0.8333 - mean_absolute_error: 0.4754 - val_loss: 1.0685 - val_root_mean_squared_error: 1.0337 - val_mean_absolute_error: 0.5103
# Epoch 17/30
# 915/915 [==============================] - 8s 8ms/step - loss: 0.7040 - root_mean_squared_error: 0.8390 - mean_absolute_error: 0.4745 - val_loss: 1.1071 - val_root_mean_squared_error: 1.0522 - val_mean_absolute_error: 0.5616
# Epoch 18/30
# 915/915 [==============================] - 8s 8ms/step - loss: 0.6925 - root_mean_squared_error: 0.8322 - mean_absolute_error: 0.4752 - val_loss: 1.1065 - val_root_mean_squared_error: 1.0519 - val_mean_absolute_error: 0.4987
# Epoch 19/30
# 915/915 [==============================] - 8s 8ms/step - loss: 0.6777 - root_mean_squared_error: 0.8232 - mean_absolute_error: 0.4697 - val_loss: 1.1141 - val_root_mean_squared_error: 1.0555 - val_mean_absolute_error: 0.5030
# Epoch 20/30
# 915/915 [==============================] - 8s 8ms/step - loss: 0.6604 - root_mean_squared_error: 0.8127 - mean_absolute_error: 0.4663 - val_loss: 1.0648 - val_root_mean_squared_error: 1.0319 - val_mean_absolute_error: 0.4860
# Epoch 21/30
# 915/915 [==============================] - 8s 8ms/step - loss: 0.6940 - root_mean_squared_error: 0.8331 - mean_absolute_error: 0.4773 - val_loss: 1.1603 - val_root_mean_squared_error: 1.0772 - val_mean_absolute_error: 0.5310
# Epoch 22/30
# 915/915 [==============================] - 8s 8ms/step - loss: 0.7000 - root_mean_squared_error: 0.8367 - mean_absolute_error: 0.4772 - val_loss: 1.1102 - val_root_mean_squared_error: 1.0537 - val_mean_absolute_error: 0.5496
# Epoch 23/30
# 915/915 [==============================] - 8s 8ms/step - loss: 0.6715 - root_mean_squared_error: 0.8195 - mean_absolute_error: 0.4709 - val_loss: 1.0848 - val_root_mean_squared_error: 1.0415 - val_mean_absolute_error: 0.5089
# Epoch 24/30
# 915/915 [==============================] - 8s 8ms/step - loss: 0.6641 - root_mean_squared_error: 0.8149 - mean_absolute_error: 0.4702 - val_loss: 1.1031 - val_root_mean_squared_error: 1.0503 - val_mean_absolute_error: 0.5409
# Epoch 25/30
# 915/915 [==============================] - 8s 8ms/step - loss: 0.6501 - root_mean_squared_error: 0.8063 - mean_absolute_error: 0.4609 - val_loss: 1.1635 - val_root_mean_squared_error: 1.0787 - val_mean_absolute_error: 0.5453
# Epoch 26/30
# 915/915 [==============================] - 8s 8ms/step - loss: 0.6518 - root_mean_squared_error: 0.8074 - mean_absolute_error: 0.4668 - val_loss: 1.1079 - val_root_mean_squared_error: 1.0526 - val_mean_absolute_error: 0.5018
# Epoch 27/30
# 915/915 [==============================] - 8s 8ms/step - loss: 0.6655 - root_mean_squared_error: 0.8158 - mean_absolute_error: 0.4705 - val_loss: 1.1531 - val_root_mean_squared_error: 1.0738 - val_mean_absolute_error: 0.5339
# Epoch 28/30
# 915/915 [==============================] - 8s 8ms/step - loss: 0.6519 - root_mean_squared_error: 0.8074 - mean_absolute_error: 0.4660 - val_loss: 1.1053 - val_root_mean_squared_error: 1.0513 - val_mean_absolute_error: 0.5276
# Epoch 29/30
# 915/915 [==============================] - 8s 8ms/step - loss: 0.6506 - root_mean_squared_error: 0.8066 - mean_absolute_error: 0.4637 - val_loss: 1.0875 - val_root_mean_squared_error: 1.0428 - val_mean_absolute_error: 0.5326
# Epoch 30/30
# 915/915 [==============================] - 8s 8ms/step - loss: 0.6520 - root_mean_squared_error: 0.8075 - mean_absolute_error: 0.4644 - val_loss: 1.1702 - val_root_mean_squared_error: 1.0818 - val_mean_absolute_error: 0.5463
# Training History for Cluster 1:

# %%
scenario_3_two_cluster = Cluster(two_houses)
scenario_3_two_cluster_results = scenario_3_two_cluster.results(model_name)
print('Training History for Cluster 2:')
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_21 (SimpleRNN)   (None, 14, 128)           16640
#
#  simple_rnn_22 (SimpleRNN)   (None, 14, 32)            5152
#
#  simple_rnn_23 (SimpleRNN)   (None, 16)                784
#
#  dense_7 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 22,593
# Trainable params: 22,593
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 15194/15194 [==============================] - 127s 8ms/step - loss: 0.1483 - root_mean_squared_error: 0.3851 - mean_absolute_error: 0.2146 - val_loss: 0.2102 - val_root_mean_squared_error: 0.4584 - val_mean_absolute_error: 0.2538
# Epoch 2/30
# 15194/15194 [==============================] - 126s 8ms/step - loss: 0.1457 - root_mean_squared_error: 0.3816 - mean_absolute_error: 0.2108 - val_loss: 0.2095 - val_root_mean_squared_error: 0.4577 - val_mean_absolute_error: 0.2565
# Epoch 3/30
# 15194/15194 [==============================] - 131s 9ms/step - loss: 0.1452 - root_mean_squared_error: 0.3810 - mean_absolute_error: 0.2101 - val_loss: 0.2092 - val_root_mean_squared_error: 0.4574 - val_mean_absolute_error: 0.2655
# Epoch 4/30
# 15194/15194 [==============================] - 128s 8ms/step - loss: 0.1444 - root_mean_squared_error: 0.3800 - mean_absolute_error: 0.2094 - val_loss: 0.2070 - val_root_mean_squared_error: 0.4550 - val_mean_absolute_error: 0.2462
# Epoch 5/30
# 15194/15194 [==============================] - 128s 8ms/step - loss: 0.1444 - root_mean_squared_error: 0.3800 - mean_absolute_error: 0.2090 - val_loss: 0.2056 - val_root_mean_squared_error: 0.4535 - val_mean_absolute_error: 0.2545
# Epoch 6/30
# 15194/15194 [==============================] - 126s 8ms/step - loss: 0.1441 - root_mean_squared_error: 0.3796 - mean_absolute_error: 0.2090 - val_loss: 0.2075 - val_root_mean_squared_error: 0.4556 - val_mean_absolute_error: 0.2479
# Epoch 7/30
# 15194/15194 [==============================] - 124s 8ms/step - loss: 0.1439 - root_mean_squared_error: 0.3794 - mean_absolute_error: 0.2086 - val_loss: 0.2063 - val_root_mean_squared_error: 0.4542 - val_mean_absolute_error: 0.2510
# Epoch 8/30
# 15194/15194 [==============================] - 127s 8ms/step - loss: 0.1437 - root_mean_squared_error: 0.3791 - mean_absolute_error: 0.2085 - val_loss: 0.2072 - val_root_mean_squared_error: 0.4552 - val_mean_absolute_error: 0.2606
# Epoch 9/30
# 15194/15194 [==============================] - 125s 8ms/step - loss: 0.1437 - root_mean_squared_error: 0.3790 - mean_absolute_error: 0.2085 - val_loss: 0.2055 - val_root_mean_squared_error: 0.4533 - val_mean_absolute_error: 0.2503
# Epoch 10/30
# 15194/15194 [==============================] - 126s 8ms/step - loss: 0.1435 - root_mean_squared_error: 0.3789 - mean_absolute_error: 0.2084 - val_loss: 0.2070 - val_root_mean_squared_error: 0.4550 - val_mean_absolute_error: 0.2453
# Epoch 11/30
# 15194/15194 [==============================] - 127s 8ms/step - loss: 0.1434 - root_mean_squared_error: 0.3786 - mean_absolute_error: 0.2083 - val_loss: 0.2058 - val_root_mean_squared_error: 0.4537 - val_mean_absolute_error: 0.2528
# Epoch 12/30
# 15194/15194 [==============================] - 125s 8ms/step - loss: 0.1434 - root_mean_squared_error: 0.3787 - mean_absolute_error: 0.2083 - val_loss: 0.2050 - val_root_mean_squared_error: 0.4527 - val_mean_absolute_error: 0.2503
# Epoch 13/30
# 15194/15194 [==============================] - 123s 8ms/step - loss: 0.1432 - root_mean_squared_error: 0.3784 - mean_absolute_error: 0.2081 - val_loss: 0.2058 - val_root_mean_squared_error: 0.4536 - val_mean_absolute_error: 0.2583
# Epoch 14/30
# 15194/15194 [==============================] - 123s 8ms/step - loss: 0.1432 - root_mean_squared_error: 0.3784 - mean_absolute_error: 0.2079 - val_loss: 0.2063 - val_root_mean_squared_error: 0.4542 - val_mean_absolute_error: 0.2544
# Epoch 15/30
# 15194/15194 [==============================] - 124s 8ms/step - loss: 0.1430 - root_mean_squared_error: 0.3781 - mean_absolute_error: 0.2079 - val_loss: 0.2068 - val_root_mean_squared_error: 0.4548 - val_mean_absolute_error: 0.2564
# Epoch 16/30
# 15194/15194 [==============================] - 124s 8ms/step - loss: 0.1432 - root_mean_squared_error: 0.3784 - mean_absolute_error: 0.2080 - val_loss: 0.2096 - val_root_mean_squared_error: 0.4578 - val_mean_absolute_error: 0.2609
# Epoch 17/30
# 15194/15194 [==============================] - 123s 8ms/step - loss: 0.1431 - root_mean_squared_error: 0.3783 - mean_absolute_error: 0.2078 - val_loss: 0.2070 - val_root_mean_squared_error: 0.4550 - val_mean_absolute_error: 0.2546
# Epoch 18/30
# 15194/15194 [==============================] - 126s 8ms/step - loss: 0.1429 - root_mean_squared_error: 0.3780 - mean_absolute_error: 0.2077 - val_loss: 0.2053 - val_root_mean_squared_error: 0.4531 - val_mean_absolute_error: 0.2531
# Epoch 19/30
# 15194/15194 [==============================] - 124s 8ms/step - loss: 0.1430 - root_mean_squared_error: 0.3781 - mean_absolute_error: 0.2077 - val_loss: 0.2093 - val_root_mean_squared_error: 0.4575 - val_mean_absolute_error: 0.2597
# Epoch 20/30
# 15194/15194 [==============================] - 125s 8ms/step - loss: 0.1428 - root_mean_squared_error: 0.3779 - mean_absolute_error: 0.2076 - val_loss: 0.2070 - val_root_mean_squared_error: 0.4549 - val_mean_absolute_error: 0.2511
# Epoch 21/30
# 15194/15194 [==============================] - 125s 8ms/step - loss: 0.1429 - root_mean_squared_error: 0.3780 - mean_absolute_error: 0.2076 - val_loss: 0.2077 - val_root_mean_squared_error: 0.4558 - val_mean_absolute_error: 0.2499
# Epoch 22/30
# 15194/15194 [==============================] - 126s 8ms/step - loss: 0.1426 - root_mean_squared_error: 0.3776 - mean_absolute_error: 0.2074 - val_loss: 0.2067 - val_root_mean_squared_error: 0.4547 - val_mean_absolute_error: 0.2424
# Epoch 23/30
# 15194/15194 [==============================] - 125s 8ms/step - loss: 0.1427 - root_mean_squared_error: 0.3777 - mean_absolute_error: 0.2074 - val_loss: 0.2074 - val_root_mean_squared_error: 0.4554 - val_mean_absolute_error: 0.2503
# Epoch 24/30
# 15194/15194 [==============================] - 125s 8ms/step - loss: 0.1428 - root_mean_squared_error: 0.3779 - mean_absolute_error: 0.2075 - val_loss: 0.2073 - val_root_mean_squared_error: 0.4553 - val_mean_absolute_error: 0.2636
# Epoch 25/30
# 15194/15194 [==============================] - 126s 8ms/step - loss: 0.1427 - root_mean_squared_error: 0.3778 - mean_absolute_error: 0.2076 - val_loss: 0.2069 - val_root_mean_squared_error: 0.4549 - val_mean_absolute_error: 0.2508
# Epoch 26/30
# 15194/15194 [==============================] - 126s 8ms/step - loss: 0.1427 - root_mean_squared_error: 0.3778 - mean_absolute_error: 0.2076 - val_loss: 0.2068 - val_root_mean_squared_error: 0.4548 - val_mean_absolute_error: 0.2503
# Epoch 27/30
# 15194/15194 [==============================] - 124s 8ms/step - loss: 0.1427 - root_mean_squared_error: 0.3777 - mean_absolute_error: 0.2075 - val_loss: 0.2067 - val_root_mean_squared_error: 0.4546 - val_mean_absolute_error: 0.2612
# Epoch 28/30
# 15194/15194 [==============================] - 126s 8ms/step - loss: 0.1428 - root_mean_squared_error: 0.3779 - mean_absolute_error: 0.2076 - val_loss: 0.2054 - val_root_mean_squared_error: 0.4533 - val_mean_absolute_error: 0.2556
# Epoch 29/30
# 15194/15194 [==============================] - 126s 8ms/step - loss: 0.1426 - root_mean_squared_error: 0.3777 - mean_absolute_error: 0.2075 - val_loss: 0.2095 - val_root_mean_squared_error: 0.4577 - val_mean_absolute_error: 0.2474
# Epoch 30/30
# 15194/15194 [==============================] - 126s 8ms/step - loss: 0.1427 - root_mean_squared_error: 0.3777 - mean_absolute_error: 0.2073 - val_loss: 0.2059 - val_root_mean_squared_error: 0.4537 - val_mean_absolute_error: 0.2586
# Training History for Cluster 2:

# %%
scenario_3_three_cluster = Cluster(three_houses)
scenario_3_three_cluster_results = scenario_3_three_cluster.results(model_name)
print('Training History for Cluster 3:')
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_24 (SimpleRNN)   (None, 14, 128)           16640
#
#  simple_rnn_25 (SimpleRNN)   (None, 14, 32)            5152
#
#  simple_rnn_26 (SimpleRNN)   (None, 16)                784
#
#  dense_8 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 22,593
# Trainable params: 22,593
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 2745/2745 [==============================] - 24s 8ms/step - loss: 0.3763 - root_mean_squared_error: 0.6135 - mean_absolute_error: 0.3898 - val_loss: 0.3907 - val_root_mean_squared_error: 0.6251 - val_mean_absolute_error: 0.4167
# Epoch 2/30
# 2745/2745 [==============================] - 22s 8ms/step - loss: 0.3535 - root_mean_squared_error: 0.5945 - mean_absolute_error: 0.3749 - val_loss: 0.4159 - val_root_mean_squared_error: 0.6449 - val_mean_absolute_error: 0.4083
# Epoch 3/30
# 2745/2745 [==============================] - 22s 8ms/step - loss: 0.3457 - root_mean_squared_error: 0.5880 - mean_absolute_error: 0.3684 - val_loss: 0.3941 - val_root_mean_squared_error: 0.6278 - val_mean_absolute_error: 0.3906
# Epoch 4/30
# 2745/2745 [==============================] - 22s 8ms/step - loss: 0.3399 - root_mean_squared_error: 0.5831 - mean_absolute_error: 0.3625 - val_loss: 0.3971 - val_root_mean_squared_error: 0.6302 - val_mean_absolute_error: 0.3751
# Epoch 5/30
# 2745/2745 [==============================] - 22s 8ms/step - loss: 0.3356 - root_mean_squared_error: 0.5793 - mean_absolute_error: 0.3597 - val_loss: 0.3910 - val_root_mean_squared_error: 0.6253 - val_mean_absolute_error: 0.3980
# Epoch 6/30
# 2745/2745 [==============================] - 22s 8ms/step - loss: 0.3324 - root_mean_squared_error: 0.5765 - mean_absolute_error: 0.3564 - val_loss: 0.4268 - val_root_mean_squared_error: 0.6533 - val_mean_absolute_error: 0.4005
# Epoch 7/30
# 2745/2745 [==============================] - 22s 8ms/step - loss: 0.3293 - root_mean_squared_error: 0.5739 - mean_absolute_error: 0.3538 - val_loss: 0.3879 - val_root_mean_squared_error: 0.6228 - val_mean_absolute_error: 0.3805
# Epoch 8/30
# 2745/2745 [==============================] - 23s 8ms/step - loss: 0.3270 - root_mean_squared_error: 0.5718 - mean_absolute_error: 0.3514 - val_loss: 0.4164 - val_root_mean_squared_error: 0.6453 - val_mean_absolute_error: 0.3879
# Epoch 9/30
# 2745/2745 [==============================] - 22s 8ms/step - loss: 0.3245 - root_mean_squared_error: 0.5697 - mean_absolute_error: 0.3499 - val_loss: 0.3872 - val_root_mean_squared_error: 0.6223 - val_mean_absolute_error: 0.3883
# Epoch 10/30
# 2745/2745 [==============================] - 22s 8ms/step - loss: 0.3216 - root_mean_squared_error: 0.5671 - mean_absolute_error: 0.3472 - val_loss: 0.3901 - val_root_mean_squared_error: 0.6246 - val_mean_absolute_error: 0.3827
# Epoch 11/30
# 2745/2745 [==============================] - 22s 8ms/step - loss: 0.3217 - root_mean_squared_error: 0.5671 - mean_absolute_error: 0.3477 - val_loss: 0.3983 - val_root_mean_squared_error: 0.6311 - val_mean_absolute_error: 0.3844
# Epoch 12/30
# 2745/2745 [==============================] - 22s 8ms/step - loss: 0.3203 - root_mean_squared_error: 0.5660 - mean_absolute_error: 0.3471 - val_loss: 0.3855 - val_root_mean_squared_error: 0.6209 - val_mean_absolute_error: 0.3752
# Epoch 13/30
# 2745/2745 [==============================] - 23s 8ms/step - loss: 0.3196 - root_mean_squared_error: 0.5653 - mean_absolute_error: 0.3461 - val_loss: 0.3895 - val_root_mean_squared_error: 0.6241 - val_mean_absolute_error: 0.3766
# Epoch 14/30
# 2745/2745 [==============================] - 22s 8ms/step - loss: 0.3180 - root_mean_squared_error: 0.5639 - mean_absolute_error: 0.3452 - val_loss: 0.4083 - val_root_mean_squared_error: 0.6389 - val_mean_absolute_error: 0.4000
# Epoch 15/30
# 2745/2745 [==============================] - 22s 8ms/step - loss: 0.3146 - root_mean_squared_error: 0.5609 - mean_absolute_error: 0.3433 - val_loss: 0.4014 - val_root_mean_squared_error: 0.6335 - val_mean_absolute_error: 0.3884
# Epoch 16/30
# 2745/2745 [==============================] - 22s 8ms/step - loss: 0.3160 - root_mean_squared_error: 0.5621 - mean_absolute_error: 0.3435 - val_loss: 0.3899 - val_root_mean_squared_error: 0.6244 - val_mean_absolute_error: 0.4027
# Epoch 17/30
# 2745/2745 [==============================] - 22s 8ms/step - loss: 0.3146 - root_mean_squared_error: 0.5609 - mean_absolute_error: 0.3434 - val_loss: 0.3940 - val_root_mean_squared_error: 0.6277 - val_mean_absolute_error: 0.3678
# Epoch 18/30
# 2745/2745 [==============================] - 22s 8ms/step - loss: 0.3124 - root_mean_squared_error: 0.5589 - mean_absolute_error: 0.3408 - val_loss: 0.3907 - val_root_mean_squared_error: 0.6250 - val_mean_absolute_error: 0.3740
# Epoch 19/30
# 2745/2745 [==============================] - 22s 8ms/step - loss: 0.3131 - root_mean_squared_error: 0.5595 - mean_absolute_error: 0.3415 - val_loss: 0.3924 - val_root_mean_squared_error: 0.6264 - val_mean_absolute_error: 0.3713
# Epoch 20/30
# 2745/2745 [==============================] - 22s 8ms/step - loss: 0.3145 - root_mean_squared_error: 0.5608 - mean_absolute_error: 0.3425 - val_loss: 0.3953 - val_root_mean_squared_error: 0.6287 - val_mean_absolute_error: 0.3865
# Epoch 21/30
# 2745/2745 [==============================] - 22s 8ms/step - loss: 0.3113 - root_mean_squared_error: 0.5579 - mean_absolute_error: 0.3406 - val_loss: 0.3859 - val_root_mean_squared_error: 0.6212 - val_mean_absolute_error: 0.3719
# Epoch 22/30
# 2745/2745 [==============================] - 22s 8ms/step - loss: 0.3101 - root_mean_squared_error: 0.5569 - mean_absolute_error: 0.3401 - val_loss: 0.4088 - val_root_mean_squared_error: 0.6394 - val_mean_absolute_error: 0.3825
# Epoch 23/30
# 2745/2745 [==============================] - 22s 8ms/step - loss: 0.3093 - root_mean_squared_error: 0.5561 - mean_absolute_error: 0.3392 - val_loss: 0.4000 - val_root_mean_squared_error: 0.6325 - val_mean_absolute_error: 0.3830
# Epoch 24/30
# 2745/2745 [==============================] - 22s 8ms/step - loss: 0.3110 - root_mean_squared_error: 0.5577 - mean_absolute_error: 0.3404 - val_loss: 0.3991 - val_root_mean_squared_error: 0.6318 - val_mean_absolute_error: 0.3891
# Epoch 25/30
# 2745/2745 [==============================] - 22s 8ms/step - loss: 0.3096 - root_mean_squared_error: 0.5564 - mean_absolute_error: 0.3399 - val_loss: 0.3991 - val_root_mean_squared_error: 0.6317 - val_mean_absolute_error: 0.3873
# Epoch 26/30
# 2745/2745 [==============================] - 22s 8ms/step - loss: 0.3061 - root_mean_squared_error: 0.5533 - mean_absolute_error: 0.3376 - val_loss: 0.4169 - val_root_mean_squared_error: 0.6457 - val_mean_absolute_error: 0.3836
# Epoch 27/30
# 2745/2745 [==============================] - 22s 8ms/step - loss: 0.3074 - root_mean_squared_error: 0.5544 - mean_absolute_error: 0.3388 - val_loss: 0.4024 - val_root_mean_squared_error: 0.6343 - val_mean_absolute_error: 0.3679
# Epoch 28/30
# 2745/2745 [==============================] - 22s 8ms/step - loss: 0.3077 - root_mean_squared_error: 0.5547 - mean_absolute_error: 0.3387 - val_loss: 0.4147 - val_root_mean_squared_error: 0.6440 - val_mean_absolute_error: 0.3673
# Epoch 29/30
# 2745/2745 [==============================] - 23s 8ms/step - loss: 0.3067 - root_mean_squared_error: 0.5538 - mean_absolute_error: 0.3381 - val_loss: 0.3944 - val_root_mean_squared_error: 0.6280 - val_mean_absolute_error: 0.3821
# Epoch 30/30
# 2745/2745 [==============================] - 22s 8ms/step - loss: 0.3056 - root_mean_squared_error: 0.5528 - mean_absolute_error: 0.3381 - val_loss: 0.3991 - val_root_mean_squared_error: 0.6317 - val_mean_absolute_error: 0.3756
# Training History for Cluster 3:

# %%
## Save Scenario 3 models
scenario_3_zero_cluster.model.save(f'Models/Scenario3/{model_name}/zero_cluster')
scenario_3_one_cluster.model.save(f'Models/Scenario3/{model_name}/one_cluster')
scenario_3_two_cluster.model.save(f'Models/Scenario3/{model_name}/two_cluster')
scenario_3_three_cluster.model.save(f'Models/Scenario3/{model_name}/three_cluster')

# Pickling objects

scenario_3_zero_cluster_file = open(f"Models/Scenario3/Objects/{model_name}/zero_cluster.pickle", "wb")
pickle.dump(scenario_3_zero_cluster, scenario_3_zero_cluster_file)
scenario_3_zero_cluster_file.close()

scenario_3_one_cluster_file = open(f"Models/Scenario3/Objects/{model_name}/one_cluster.pickle", "wb")
pickle.dump(scenario_3_one_cluster, scenario_3_one_cluster_file)
scenario_3_one_cluster_file.close()

scenario_3_two_cluster_file = open(f"Models/Scenario3/Objects/{model_name}/two_cluster.pickle", "wb")
pickle.dump(scenario_3_two_cluster, scenario_3_two_cluster_file)
scenario_3_two_cluster_file.close()

scenario_3_three_cluster_file = open(f"Models/Scenario3/Objects/{model_name}/three_cluster.pickle", "wb")
pickle.dump(scenario_3_three_cluster, scenario_3_three_cluster_file)
scenario_3_three_cluster_file.close()

scenario_3_zero_cluster_results_file = open(f"Models/Scenario3/Objects/{model_name}/zero_cluster_results.pickle", "wb")
pickle.dump(scenario_3_zero_cluster_results, scenario_3_zero_cluster_results_file)
scenario_3_zero_cluster_results_file.close()

scenario_3_one_cluster_results_file = open(f"Models/Scenario3/Objects/{model_name}/one_cluster_results.pickle", "wb")
pickle.dump(scenario_3_one_cluster_results, scenario_3_one_cluster_results_file)
scenario_3_one_cluster_results_file.close()

scenario_3_two_cluster_results_file = open(f"Models/Scenario3/Objects/{model_name}/two_cluster_results.pickle", "wb")
pickle.dump(scenario_3_two_cluster_results, scenario_3_two_cluster_results_file)
scenario_3_two_cluster_results_file.close()

scenario_3_three_cluster_results_file = open(f"Models/Scenario3/Objects/{model_name}/three_cluster_results.pickle", "wb")
pickle.dump(scenario_3_three_cluster_results, scenario_3_three_cluster_results_file)
scenario_3_three_cluster_results_file.close()
# Out:
# INFO:tensorflow:Assets written to: Models/Scenario3/RNN/zero_cluster/assets
# INFO:tensorflow:Assets written to: Models/Scenario3/RNN/one_cluster/assets
# INFO:tensorflow:Assets written to: Models/Scenario3/RNN/two_cluster/assets
# INFO:tensorflow:Assets written to: Models/Scenario3/RNN/three_cluster/assets
# INFO:tensorflow:Assets written to: ram://cb287e21-ef80-425c-a7d2-e0d4bd070158/assets
# INFO:tensorflow:Assets written to: ram://9164c524-db92-4b31-acf7-e408b4af74ab/assets
# INFO:tensorflow:Assets written to: ram://3a29117f-d9c4-45d1-92db-6921e7e9f05b/assets
# INFO:tensorflow:Assets written to: ram://61b5e290-0c76-4465-b779-3544e782b3e7/assets

# %% [markdown]
# #### Scenario 4

# %%
scenario_4_all_cluster = Cluster(all_houses)
scenario_4_all_cluster_results = scenario_4_all_cluster.results(model_name)
print('Training History without clustering:')
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_27 (SimpleRNN)   (None, 14, 128)           16640
#
#  simple_rnn_28 (SimpleRNN)   (None, 14, 32)            5152
#
#  simple_rnn_29 (SimpleRNN)   (None, 16)                784
#
#  dense_9 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 22,593
# Trainable params: 22,593
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 26534/26534 [==============================] - 216s 8ms/step - loss: 0.3272 - root_mean_squared_error: 0.5720 - mean_absolute_error: 0.3110 - val_loss: 0.3323 - val_root_mean_squared_error: 0.5765 - val_mean_absolute_error: 0.3166
# Epoch 2/30
# 26534/26534 [==============================] - 216s 8ms/step - loss: 0.3180 - root_mean_squared_error: 0.5639 - mean_absolute_error: 0.3054 - val_loss: 0.3553 - val_root_mean_squared_error: 0.5961 - val_mean_absolute_error: 0.3271
# Epoch 3/30
# 26534/26534 [==============================] - 216s 8ms/step - loss: 0.3149 - root_mean_squared_error: 0.5611 - mean_absolute_error: 0.3039 - val_loss: 0.3244 - val_root_mean_squared_error: 0.5696 - val_mean_absolute_error: 0.3281
# Epoch 4/30
# 26534/26534 [==============================] - 217s 8ms/step - loss: 0.3128 - root_mean_squared_error: 0.5593 - mean_absolute_error: 0.3030 - val_loss: 0.3328 - val_root_mean_squared_error: 0.5769 - val_mean_absolute_error: 0.3341
# Epoch 5/30
# 26534/26534 [==============================] - 215s 8ms/step - loss: 0.3106 - root_mean_squared_error: 0.5573 - mean_absolute_error: 0.3019 - val_loss: 0.3307 - val_root_mean_squared_error: 0.5750 - val_mean_absolute_error: 0.3242
# Epoch 6/30
# 26534/26534 [==============================] - 215s 8ms/step - loss: 0.3098 - root_mean_squared_error: 0.5566 - mean_absolute_error: 0.3021 - val_loss: 0.3432 - val_root_mean_squared_error: 0.5858 - val_mean_absolute_error: 0.3243
# Epoch 7/30
# 26534/26534 [==============================] - 218s 8ms/step - loss: 0.3099 - root_mean_squared_error: 0.5567 - mean_absolute_error: 0.3014 - val_loss: 0.3276 - val_root_mean_squared_error: 0.5723 - val_mean_absolute_error: 0.3091
# Epoch 8/30
# 26534/26534 [==============================] - 219s 8ms/step - loss: 0.3078 - root_mean_squared_error: 0.5548 - mean_absolute_error: 0.3011 - val_loss: 0.3456 - val_root_mean_squared_error: 0.5879 - val_mean_absolute_error: 0.3234
# Epoch 9/30
# 26534/26534 [==============================] - 221s 8ms/step - loss: 0.3064 - root_mean_squared_error: 0.5535 - mean_absolute_error: 0.3003 - val_loss: 0.3531 - val_root_mean_squared_error: 0.5942 - val_mean_absolute_error: 0.3151
# Epoch 10/30
# 26534/26534 [==============================] - 217s 8ms/step - loss: 0.3066 - root_mean_squared_error: 0.5537 - mean_absolute_error: 0.3002 - val_loss: 0.3718 - val_root_mean_squared_error: 0.6098 - val_mean_absolute_error: 0.3207
# Epoch 11/30
# 26534/26534 [==============================] - 219s 8ms/step - loss: 0.3082 - root_mean_squared_error: 0.5551 - mean_absolute_error: 0.3013 - val_loss: 0.3529 - val_root_mean_squared_error: 0.5941 - val_mean_absolute_error: 0.3286
# Epoch 12/30
# 26534/26534 [==============================] - 219s 8ms/step - loss: 0.3082 - root_mean_squared_error: 0.5552 - mean_absolute_error: 0.3007 - val_loss: 0.3298 - val_root_mean_squared_error: 0.5743 - val_mean_absolute_error: 0.3150
# Epoch 13/30
# 26534/26534 [==============================] - 219s 8ms/step - loss: 0.3047 - root_mean_squared_error: 0.5520 - mean_absolute_error: 0.2997 - val_loss: 0.3325 - val_root_mean_squared_error: 0.5767 - val_mean_absolute_error: 0.3168
# Epoch 14/30
# 26534/26534 [==============================] - 220s 8ms/step - loss: 0.3068 - root_mean_squared_error: 0.5539 - mean_absolute_error: 0.3006 - val_loss: 0.3351 - val_root_mean_squared_error: 0.5789 - val_mean_absolute_error: 0.3379
# Epoch 15/30
# 26534/26534 [==============================] - 220s 8ms/step - loss: 0.3047 - root_mean_squared_error: 0.5520 - mean_absolute_error: 0.2997 - val_loss: 0.3350 - val_root_mean_squared_error: 0.5788 - val_mean_absolute_error: 0.3195
# Epoch 16/30
# 26534/26534 [==============================] - 221s 8ms/step - loss: 0.3043 - root_mean_squared_error: 0.5516 - mean_absolute_error: 0.2995 - val_loss: 0.3387 - val_root_mean_squared_error: 0.5820 - val_mean_absolute_error: 0.3197
# Epoch 17/30
# 26534/26534 [==============================] - 222s 8ms/step - loss: 0.3052 - root_mean_squared_error: 0.5524 - mean_absolute_error: 0.2999 - val_loss: 0.3319 - val_root_mean_squared_error: 0.5761 - val_mean_absolute_error: 0.3258
# Epoch 18/30
# 26534/26534 [==============================] - 226s 9ms/step - loss: 0.3048 - root_mean_squared_error: 0.5521 - mean_absolute_error: 0.2999 - val_loss: 0.3373 - val_root_mean_squared_error: 0.5808 - val_mean_absolute_error: 0.3192
# Epoch 19/30
# 26534/26534 [==============================] - 230s 9ms/step - loss: 0.3036 - root_mean_squared_error: 0.5510 - mean_absolute_error: 0.2995 - val_loss: 0.3426 - val_root_mean_squared_error: 0.5853 - val_mean_absolute_error: 0.3213
# Epoch 20/30
# 26534/26534 [==============================] - 231s 9ms/step - loss: 0.3049 - root_mean_squared_error: 0.5522 - mean_absolute_error: 0.2996 - val_loss: 0.3454 - val_root_mean_squared_error: 0.5877 - val_mean_absolute_error: 0.3380
# Epoch 21/30
# 26534/26534 [==============================] - 228s 9ms/step - loss: 0.3048 - root_mean_squared_error: 0.5521 - mean_absolute_error: 0.3000 - val_loss: 0.3480 - val_root_mean_squared_error: 0.5899 - val_mean_absolute_error: 0.3156
# Epoch 22/30
# 26534/26534 [==============================] - 229s 9ms/step - loss: 0.3043 - root_mean_squared_error: 0.5516 - mean_absolute_error: 0.2997 - val_loss: 0.3505 - val_root_mean_squared_error: 0.5920 - val_mean_absolute_error: 0.3444
# Epoch 23/30
# 26534/26534 [==============================] - 233s 9ms/step - loss: 0.3034 - root_mean_squared_error: 0.5508 - mean_absolute_error: 0.2989 - val_loss: 0.3438 - val_root_mean_squared_error: 0.5863 - val_mean_absolute_error: 0.3164
# Epoch 24/30
# 26534/26534 [==============================] - 230s 9ms/step - loss: 0.3055 - root_mean_squared_error: 0.5527 - mean_absolute_error: 0.2995 - val_loss: 0.3369 - val_root_mean_squared_error: 0.5804 - val_mean_absolute_error: 0.3297
# Epoch 25/30
# 26534/26534 [==============================] - 236s 9ms/step - loss: 0.3036 - root_mean_squared_error: 0.5510 - mean_absolute_error: 0.2991 - val_loss: 0.3449 - val_root_mean_squared_error: 0.5873 - val_mean_absolute_error: 0.3327
# Epoch 26/30
# 26534/26534 [==============================] - 231s 9ms/step - loss: 0.3049 - root_mean_squared_error: 0.5522 - mean_absolute_error: 0.2994 - val_loss: 0.3312 - val_root_mean_squared_error: 0.5755 - val_mean_absolute_error: 0.3224
# Epoch 27/30
# 26534/26534 [==============================] - 233s 9ms/step - loss: 0.3038 - root_mean_squared_error: 0.5512 - mean_absolute_error: 0.2991 - val_loss: 0.3341 - val_root_mean_squared_error: 0.5780 - val_mean_absolute_error: 0.3223
# Epoch 28/30
# 26534/26534 [==============================] - 231s 9ms/step - loss: 0.3059 - root_mean_squared_error: 0.5530 - mean_absolute_error: 0.2997 - val_loss: 0.3384 - val_root_mean_squared_error: 0.5817 - val_mean_absolute_error: 0.3150
# Epoch 29/30
# 26534/26534 [==============================] - 227s 9ms/step - loss: 0.3043 - root_mean_squared_error: 0.5516 - mean_absolute_error: 0.2995 - val_loss: 0.3337 - val_root_mean_squared_error: 0.5777 - val_mean_absolute_error: 0.3164
# Epoch 30/30
# 26534/26534 [==============================] - 230s 9ms/step - loss: 0.3044 - root_mean_squared_error: 0.5518 - mean_absolute_error: 0.2994 - val_loss: 0.3387 - val_root_mean_squared_error: 0.5820 - val_mean_absolute_error: 0.3206
# Training History without clustering:

# %%
### Save Scenario 4 models
scenario_4_all_cluster.model.save(f'Models/Scenario4/{model_name}/all_cluster')

## Pickling Scenario 4 cluster and cluster result files
scenario_4_all_cluster_file = open(f"Models/Scenario4/Objects/{model_name}/all_cluster.pickle", "wb")
pickle.dump(scenario_4_all_cluster, scenario_4_all_cluster_file)
scenario_4_all_cluster_file.close()

scenario_4_all_cluster_results_file = open(f"Models/Scenario4/Objects/{model_name}/all_cluster_results.pickle", "wb")
pickle.dump(scenario_4_all_cluster_results, scenario_4_all_cluster_results_file)
scenario_4_all_cluster_results_file.close()
# Out:
# INFO:tensorflow:Assets written to: Models/Scenario4/RNN/all_cluster/assets
# INFO:tensorflow:Assets written to: ram://798a2475-5cf0-4854-8377-40f2fea12b4e/assets

# %% [markdown]
# #### Predictions for Scenario 3 and Scenario 4

# %%
graph_predictions(scenario_3_zero_cluster_results, scenario_4_all_cluster_results)
# Out:
# /tmp/ipykernel_165160/442122963.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['timestamp'] = pd.to_datetime(df1['timestamp'])

# %%
graph_predictions(scenario_3_one_cluster_results, scenario_4_all_cluster_results)
# Out:
# /tmp/ipykernel_165160/442122963.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['timestamp'] = pd.to_datetime(df1['timestamp'])

# %%
graph_predictions(scenario_3_two_cluster_results, scenario_4_all_cluster_results)
# Out:
# /tmp/ipykernel_165160/442122963.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['timestamp'] = pd.to_datetime(df1['timestamp'])

# %%
graph_predictions(scenario_3_three_cluster_results, scenario_4_all_cluster_results)
# Out:
# /tmp/ipykernel_165160/442122963.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['timestamp'] = pd.to_datetime(df1['timestamp'])

# %% [markdown]
# #### Scenario 3 and Scenario 4 Metric Tables

# %%
scenario_3_results = [scenario_3_zero_cluster, scenario_3_one_cluster, scenario_3_two_cluster, scenario_3_three_cluster]
scenario_3_metrics = create_metrics(scenario_3_results )
scenario_3_validation_metrics = create_metrics(scenario_3_results, val= True)
scenario_3_metrics
# Out:
# [0.3775913715362549,
#  1.0039081573486328,
#  0.6143027263383071,
#  0.20734894275665283,
#  0.5601377487182617,
#  0.3582742609083652]

# %%
scenario_4_results = [scenario_4_all_cluster]
scenario_4_metrics = create_metrics(scenario_4_results )
scenario_4_validation_metrics = create_metrics(scenario_4_results, val= True)
scenario_4_metrics
# Out:
# [0.5508353114128113,
#  0.5719912648200989,
#  0.5544800420602163,
#  0.2989273965358734,
#  0.31098392605781555,
#  0.300832066933314]

# %%
print('Training metrics:')
df = pd.DataFrame([scenario_1_metrics, scenario_2_metrics, scenario_3_metrics, scenario_4_metrics],index=[1,2,3,4], columns = ['Min RMSE', 'Max RMSE', 'Mean RMSE','Min MAE', 'Max MAE', 'Mean MAE'])
df['Scenario'] = np.array([1,2,3,4])
df.set_index('Scenario').round(decimals=2).to_csv('Tables/training_metrics.csv')
# Out:
# Training metrics:

# %%
print('Validation metrics:')
df = pd.DataFrame([scenario_1_validation_metrics, scenario_2_validation_metrics,
                   scenario_3_validation_metrics, scenario_4_validation_metrics],index=[1,2,3,4], columns = ['Min RMSE', 'Max RMSE', 'Mean RMSE','Min MAE', 'Max MAE', 'Mean MAE'])
df['Scenario'] = np.array([1,2,3,4])
df.set_index('Scenario').round(decimals=2).to_csv('Tables/validation_metrics.csv')
# Out:
# Validation metrics:

# %% [markdown]
# ### Anomaly Distribution

# %%
def create_anomaly_df(result_df, scenario_name, monthly_agg = True):    
    #print(type(result_df))
    anomaly_df = result_df[['timestamp', 'Anomaly detected']]
    anomaly_df.set_index('timestamp', inplace = True)
    if monthly_agg:
        anomaly_df['Anomaly detected'] = anomaly_df['Anomaly detected'].apply(lambda x: 0 if x is False else 1)
        anomaly_df = anomaly_df.resample("M").agg('sum')
    else: 
        anomaly_df['Anomaly detected'] = anomaly_df['Anomaly detected'].apply(lambda x: 0 if x is False else x)
    anomaly_df = anomaly_df.rename(columns={'Anomaly detected': scenario_name})
    return anomaly_df

def create_anomalies_graph( title = None, **kwargs):
    anomaly_dfs = []
    for scenario_name, result_df in kwargs.items():
        anomaly_df = create_anomaly_df(result_df, scenario_name)
        anomaly_dfs.append(anomaly_df)
    anomaly_df = functools.reduce(lambda left, right: left.join(right), anomaly_dfs)
    ax = anomaly_df.plot.line(figsize=(20,10))
    ax.set_xlabel(f'Time')
    ax.set_ylabel(f'Frequency')
    ax.set_title(title)
    #return anomaly_dfs

# %%
def dtw_distance(series1, series2):
    return fastdtw.fastdtw(series1,series2)[0]

def create_distance_df(title, **kwargs):
    print(title)
    anomaly_dfs = []
    for scenario_name, result_df in kwargs.items():
        anomaly_df = np.array(create_anomaly_df(result_df, scenario_name, monthly_agg=False)).reshape(1,-1)
        anomaly_dfs.append(anomaly_df)
    anomaly_distributions = np.array(anomaly_dfs).reshape(len(kwargs),-1)
    distance_matrix = sd.squareform(sd.pdist(anomaly_distributions, dtw_distance))
    return(pd.DataFrame(distance_matrix, columns = kwargs.keys(), index = kwargs.keys()))
    #return anomaly_dfs

# %%
create_anomalies_graph( 'Anomaly Frequency Distribution for House 1: Cluster 0', Scenario1 = zero_cluster_results[1], Scenario2 = all_cluster_results[1],
                       Scenario3 = scenario_3_zero_cluster_results[1], Scenario4 = scenario_4_all_cluster_results[1])
# Out:
# /tmp/ipykernel_165160/3162963936.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anomaly_df['Anomaly detected'] = anomaly_df['Anomaly detected'].apply(lambda x: 0 if x is False else 1)

# %%
create_distance_df('Similarity between anomaly distributions for House1: Cluster 0', Scenario1 = zero_cluster_results[1], Scenario2 = all_cluster_results[1],
                       Scenario3 = scenario_3_zero_cluster_results[1], Scenario4 = scenario_4_all_cluster_results[1]).round(decimals=2).to_csv('Tables/anomaly_cluster0.csv')
# Out:
# Similarity between anomaly distributions for House1: Cluster 0
# /tmp/ipykernel_165160/3162963936.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anomaly_df['Anomaly detected'] = anomaly_df['Anomaly detected'].apply(lambda x: 0 if x is False else x)

# %%
create_anomalies_graph( 'Anomaly Frequency Distribution for House 15: Cluster 1', Scenario1 = one_cluster_results[15], Scenario2 = all_cluster_results[15],
                       Scenario3 = scenario_3_one_cluster_results[15], Scenario4 = scenario_4_all_cluster_results[15])
# Out:
# /tmp/ipykernel_165160/3162963936.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anomaly_df['Anomaly detected'] = anomaly_df['Anomaly detected'].apply(lambda x: 0 if x is False else 1)

# %%
create_distance_df( 'Similarity between anomaly distributions for House15: Cluster 1', Scenario1 = one_cluster_results[15], Scenario2 = all_cluster_results[15],
                       Scenario3 = scenario_3_one_cluster_results[15], Scenario4 = scenario_4_all_cluster_results[15]).round(decimals=2).to_csv('Tables/anomaly_cluster1.csv')
# Out:
# Similarity between anomaly distributions for House15: Cluster 1
# /tmp/ipykernel_165160/3162963936.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anomaly_df['Anomaly detected'] = anomaly_df['Anomaly detected'].apply(lambda x: 0 if x is False else x)

# %%
create_anomalies_graph( 'Anomaly Frequency Distribution for House 2: Cluster 2', Scenario1 = two_cluster_results[2], Scenario2 = all_cluster_results[2],
                       Scenario3 = scenario_3_two_cluster_results[2], Scenario4 = scenario_4_all_cluster_results[2])
# Out:
# /tmp/ipykernel_165160/3162963936.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anomaly_df['Anomaly detected'] = anomaly_df['Anomaly detected'].apply(lambda x: 0 if x is False else 1)

# %%
create_distance_df( 'Similarity between anomaly distributions for House 2: Cluster 2', Scenario1 = two_cluster_results[2], Scenario2 = all_cluster_results[2],
                       Scenario3 = scenario_3_two_cluster_results[2], Scenario4 = scenario_4_all_cluster_results[2]).round(decimals=2).to_csv('Tables/anomaly_cluster2.csv')
# Out:
# Similarity between anomaly distributions for House 2: Cluster 2
# /tmp/ipykernel_165160/3162963936.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anomaly_df['Anomaly detected'] = anomaly_df['Anomaly detected'].apply(lambda x: 0 if x is False else x)

# %%
create_anomalies_graph( 'Anomaly Frequency Distribution for House 3: Cluster 3', Scenario1 = three_cluster_results[3], Scenario2 = all_cluster_results[3],
                       Scenario3 = scenario_3_three_cluster_results[3], Scenario4 = scenario_4_all_cluster_results[3])
# Out:
# /tmp/ipykernel_165160/3162963936.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anomaly_df['Anomaly detected'] = anomaly_df['Anomaly detected'].apply(lambda x: 0 if x is False else 1)

# %%
create_distance_df( 'Similarity between anomaly distributions for House 3: Cluster 3', Scenario1 = three_cluster_results[3], Scenario2 = all_cluster_results[3],
                       Scenario3 = scenario_3_three_cluster_results[3], Scenario4 = scenario_4_all_cluster_results[3]).round(decimals=2).to_csv('Tables/anomaly_cluster3.csv')
# Out:
# Similarity between anomaly distributions for House 3: Cluster 3
# /tmp/ipykernel_165160/3162963936.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anomaly_df['Anomaly detected'] = anomaly_df['Anomaly detected'].apply(lambda x: 0 if x is False else x)

# %% [markdown]
# #### Energy Deficit Calculation

# %%
def create_deficit_df(result_df, scenario_name, monthly_agg = True):    
    #print(type(result_df))
    energy_df = result_df[['timestamp', 'Energy Deficit Flag']]
    energy_df.set_index('timestamp', inplace = True)
    if monthly_agg:
        energy_df['Energy Deficit Flag'] = energy_df['Energy Deficit Flag'].apply(lambda x: 0 if x is False else 1)
        energy_df = energy_df.resample("W").agg('sum')
    else: 
        energy_df['Energy Deficit Flag'] = energy_df['Energy Deficit Flag'].apply(lambda x: 0 if x is False else x)
    energy_df = energy_df.rename(columns={'Energy Deficit Flag': scenario_name})
    return energy_df

def create_energy_deficit_graph( title = None, **kwargs):
    energy_dfs = []
    for scenario_name, result_df in kwargs.items():
        energy_df = create_deficit_df(result_df, scenario_name)
        energy_dfs.append(energy_df)
    energy_df = functools.reduce(lambda left, right: left.join(right), energy_dfs)
    ax = energy_df.plot.line(figsize=(20,10))
    ax.set_xlabel(f'Time')
    ax.set_ylabel(f'Frequency')
    ax.set_title(title)

# %%
def create_deficit_distance_df(title, **kwargs):
    print(title)
    energy_dfs = []
    for scenario_name, result_df in kwargs.items():
        energy_df = np.array(create_deficit_df(result_df, scenario_name, monthly_agg=False)).reshape(1,-1)
        energy_dfs.append(energy_df)
    energy_distributions = np.array(energy_dfs).reshape(len(kwargs),-1)
    distance_matrix = sd.squareform(sd.pdist(energy_distributions, dtw_distance))
    return(pd.DataFrame(distance_matrix, columns = kwargs.keys(), index = kwargs.keys()))

# %%
create_energy_deficit_graph( 'Energy Deficit Frequency Distribution for House 1: Cluster 0', Scenario1 = zero_cluster_results[1], Scenario2 = all_cluster_results[1],
                       Scenario3 = scenario_3_zero_cluster_results[1], Scenario4 = scenario_4_all_cluster_results[1])
# Out:
# /tmp/ipykernel_165160/2779099769.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   energy_df['Energy Deficit Flag'] = energy_df['Energy Deficit Flag'].apply(lambda x: 0 if x is False else 1)

# %%
create_deficit_distance_df('Similarity between energy deficit distributions for House1: Cluster 0', Scenario1 = zero_cluster_results[1], Scenario2 = all_cluster_results[1],
                       Scenario3 = scenario_3_zero_cluster_results[1], Scenario4 = scenario_4_all_cluster_results[1])
# Out:
# Similarity between energy deficit distributions for House1: Cluster 0
# /tmp/ipykernel_165160/2779099769.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   energy_df['Energy Deficit Flag'] = energy_df['Energy Deficit Flag'].apply(lambda x: 0 if x is False else x)
#              Scenario1    Scenario2    Scenario3    Scenario4
# Scenario1     0.000000  2993.429172  2617.010877  2577.804706
# Scenario2  2993.429172     0.000000  3478.867399  2298.533574
# Scenario3  2617.010877  3478.867399     0.000000  2504.105382
# Scenario4  2577.804706  2298.533574  2504.105382     0.000000

# %%
create_energy_deficit_graph( 'Energy Deficit Frequency Distribution for House 15: Cluster 1', Scenario1 = one_cluster_results[15], Scenario2 = all_cluster_results[15],
                       Scenario3 = scenario_3_one_cluster_results[15], Scenario4 = scenario_4_all_cluster_results[15])
# Out:
# /tmp/ipykernel_165160/2779099769.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   energy_df['Energy Deficit Flag'] = energy_df['Energy Deficit Flag'].apply(lambda x: 0 if x is False else 1)

# %%
create_deficit_distance_df( 'Similarity between energy deficit distributions for House15: Cluster 1', Scenario1 = one_cluster_results[15], 
                    Scenario2 = all_cluster_results[15],
                       Scenario3 = scenario_3_one_cluster_results[15], Scenario4 = scenario_4_all_cluster_results[15])
# Out:
# Similarity between energy deficit distributions for House15: Cluster 1
# /tmp/ipykernel_165160/2779099769.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   energy_df['Energy Deficit Flag'] = energy_df['Energy Deficit Flag'].apply(lambda x: 0 if x is False else x)
#              Scenario1    Scenario2    Scenario3    Scenario4
# Scenario1     0.000000  5851.593658  2855.214660  3181.573215
# Scenario2  5851.593658     0.000000  3522.846022  4262.180575
# Scenario3  2855.214660  3522.846022     0.000000  3546.214974
# Scenario4  3181.573215  4262.180575  3546.214974     0.000000

# %%
create_energy_deficit_graph( 'Energy Deficit Frequency Distribution for House 2: Cluster 2', Scenario1 = two_cluster_results[2], Scenario2 = all_cluster_results[2],
                       Scenario3 = scenario_3_two_cluster_results[2], Scenario4 = scenario_4_all_cluster_results[2])
# Out:
# /tmp/ipykernel_165160/2779099769.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   energy_df['Energy Deficit Flag'] = energy_df['Energy Deficit Flag'].apply(lambda x: 0 if x is False else 1)

# %%
create_deficit_distance_df( 'Similarity between energy deficit distributions for House 2: Cluster 2', Scenario1 = two_cluster_results[2], Scenario2 = all_cluster_results[2],
                       Scenario3 = scenario_3_two_cluster_results[2], Scenario4 = scenario_4_all_cluster_results[2])
# Out:
# Similarity between energy deficit distributions for House 2: Cluster 2
# /tmp/ipykernel_165160/2779099769.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   energy_df['Energy Deficit Flag'] = energy_df['Energy Deficit Flag'].apply(lambda x: 0 if x is False else x)
#              Scenario1    Scenario2    Scenario3   Scenario4
# Scenario1     0.000000  2342.764027   443.190102  542.222495
# Scenario2  2342.764027     0.000000  1287.628886  896.874391
# Scenario3   443.190102  1287.628886     0.000000  537.741390
# Scenario4   542.222495   896.874391   537.741390    0.000000

# %%
create_energy_deficit_graph( 'Energy Deficit Frequency Distribution for House 3: Cluster 3', Scenario1 = three_cluster_results[3], Scenario2 = all_cluster_results[3],
                       Scenario3 = scenario_3_three_cluster_results[3], Scenario4 = scenario_4_all_cluster_results[3])
# Out:
# /tmp/ipykernel_165160/2779099769.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   energy_df['Energy Deficit Flag'] = energy_df['Energy Deficit Flag'].apply(lambda x: 0 if x is False else 1)

# %%
create_deficit_distance_df( 'Similarity between energy deficit distributions for House 3: Cluster 3', Scenario1 = three_cluster_results[3], Scenario2 = all_cluster_results[3],
                       Scenario3 = scenario_3_three_cluster_results[3], Scenario4 = scenario_4_all_cluster_results[3])
# Out:
# Similarity between energy deficit distributions for House 3: Cluster 3
# /tmp/ipykernel_165160/2779099769.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   energy_df['Energy Deficit Flag'] = energy_df['Energy Deficit Flag'].apply(lambda x: 0 if x is False else x)
#              Scenario1    Scenario2    Scenario3    Scenario4
# Scenario1     0.000000  2971.424279  2786.937867  3066.849629
# Scenario2  2971.424279     0.000000  3076.241744  1295.387197
# Scenario3  2786.937867  3076.241744     0.000000  3253.365347
# Scenario4  3066.849629  1295.387197  3253.365347     0.000000

# %%
print(tf. __version__)
# Out:
# 2.7.0

# %%
print('Hello')
# Out:
# Hello
