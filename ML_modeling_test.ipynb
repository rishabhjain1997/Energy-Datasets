# %% [markdown]
# #### Importing Libraries and Dataset

# %%
import numpy as np
from statistics import mean
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import pandas as pd
import seaborn as sns
from tslearn.clustering import TimeSeriesKMeans
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM
from tensorflow.keras import regularizers
from tensorflow.keras.layers import Dense, Dropout
import tensorflow as tf
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from tensorflow import keras
import seaborn as sns
import pickle
import functools
import fastdtw
import scipy.spatial.distance as sd
#from datetime import datetime
consumption_df = pd.read_csv('Final Datasets/energy_consumption.csv')
consumption_df
# Out:
#         Unnamed: 0            timestamp  energy_kWh  House Number  \
# 0                0  2012-06-01 01:00:00       1.011             1
# 1                1  2012-06-01 02:00:00       0.451             1
# 2                2  2012-06-01 03:00:00       0.505             1
# 3                3  2012-06-01 04:00:00       0.441             1
# 4                4  2012-06-01 05:00:00       0.468             1
# ...            ...                  ...         ...           ...
# 611013      123761  2020-05-19 19:00:00       3.060            28
# 611014      123762  2020-05-19 20:00:00       2.940            28
# 611015      123763  2020-05-19 21:00:00       1.970            28
# 611016      123764  2020-05-19 22:00:00       2.130            28
# 611017      123765  2020-05-19 23:00:00       1.010            28
#
#         electronics workbench energy  network equipment energy  \
# 0                           0.008686                  0.019316
# 1                           0.007178                  0.019338
# 2                           0.007324                  0.019336
# 3                           0.007151                  0.019339
# 4                           0.007224                  0.019338
# ...                              ...                       ...
# 611013                      0.014204                  0.019235
# 611014                      0.013881                  0.019240
# 611015                      0.011269                  0.019278
# 611016                      0.011700                  0.019272
# 611017                      0.008683                  0.019316
#
#         home office energy  RAE home office energy  \
# 0                 0.018232                0.134570
# 1                 0.013745                0.061839
# 2                 0.014177                0.068852
# 3                 0.013664                0.060540
# 4                 0.013881                0.064047
# ...                    ...                     ...
# 611013            0.034654                0.400690
# 611014            0.033692                0.385105
# 611015            0.025918                0.259123
# 611016            0.027200                0.279904
# 611017            0.018224                0.134440
#
#         RAE Mobile Phone Charger Energy
# 0                              0.000431
# 1                              0.000215
# 2                              0.000236
# 3                              0.000211
# 4                              0.000221
# ...                                 ...
# 611013                         0.001220
# 611014                         0.001174
# 611015                         0.000800
# 611016                         0.000862
# 611017                         0.000430
#
# [611018 rows x 9 columns]

# %%
if 'Unnamed: 0' in consumption_df.columns:
    consumption_df.drop('Unnamed: 0',axis=1, inplace = True)

# %%
consumption_df
# Out:
#                   timestamp  energy_kWh  House Number  \
# 0       2012-06-01 01:00:00       1.011             1
# 1       2012-06-01 02:00:00       0.451             1
# 2       2012-06-01 03:00:00       0.505             1
# 3       2012-06-01 04:00:00       0.441             1
# 4       2012-06-01 05:00:00       0.468             1
# ...                     ...         ...           ...
# 611013  2020-05-19 19:00:00       3.060            28
# 611014  2020-05-19 20:00:00       2.940            28
# 611015  2020-05-19 21:00:00       1.970            28
# 611016  2020-05-19 22:00:00       2.130            28
# 611017  2020-05-19 23:00:00       1.010            28
#
#         electronics workbench energy  network equipment energy  \
# 0                           0.008686                  0.019316
# 1                           0.007178                  0.019338
# 2                           0.007324                  0.019336
# 3                           0.007151                  0.019339
# 4                           0.007224                  0.019338
# ...                              ...                       ...
# 611013                      0.014204                  0.019235
# 611014                      0.013881                  0.019240
# 611015                      0.011269                  0.019278
# 611016                      0.011700                  0.019272
# 611017                      0.008683                  0.019316
#
#         home office energy  RAE home office energy  \
# 0                 0.018232                0.134570
# 1                 0.013745                0.061839
# 2                 0.014177                0.068852
# 3                 0.013664                0.060540
# 4                 0.013881                0.064047
# ...                    ...                     ...
# 611013            0.034654                0.400690
# 611014            0.033692                0.385105
# 611015            0.025918                0.259123
# 611016            0.027200                0.279904
# 611017            0.018224                0.134440
#
#         RAE Mobile Phone Charger Energy
# 0                              0.000431
# 1                              0.000215
# 2                              0.000236
# 3                              0.000211
# 4                              0.000221
# ...                                 ...
# 611013                         0.001220
# 611014                         0.001174
# 611015                         0.000800
# 611016                         0.000862
# 611017                         0.000430
#
# [611018 rows x 8 columns]

# %% [markdown]
# #### Converting Dataset to House-wise dictionary

# %%
house_wise_consumption = dict()
for house_number in consumption_df['House Number'].unique():
    house_data = consumption_df[consumption_df['House Number'] == house_number]
    house_wise_consumption[house_number] = house_data.copy()
house_wise_consumption[1]
# house_wise_consumption[14]['timestamp'].iloc[0]
# house_wise_consumption[14]['timestamp'].iloc[-1]
# house_wise_consumption[14]['House Number'].iloc[0]
# Out:
#                  timestamp  energy_kWh  House Number  \
# 0      2012-06-01 01:00:00       1.011             1
# 1      2012-06-01 02:00:00       0.451             1
# 2      2012-06-01 03:00:00       0.505             1
# 3      2012-06-01 04:00:00       0.441             1
# 4      2012-06-01 05:00:00       0.468             1
# ...                    ...         ...           ...
# 29226  2015-10-02 20:00:00       2.101             1
# 29227  2015-10-02 21:00:00       1.646             1
# 29228  2015-10-02 22:00:00       1.319             1
# 29229  2015-10-02 23:00:00       1.473             1
# 29230  2015-10-03 00:00:00       0.800             1
#
#        electronics workbench energy  network equipment energy  \
# 0                          0.008686                  0.019316
# 1                          0.007178                  0.019338
# 2                          0.007324                  0.019336
# 3                          0.007151                  0.019339
# 4                          0.007224                  0.019338
# ...                             ...                       ...
# 29226                      0.011621                  0.019273
# 29227                      0.010396                  0.019291
# 29228                      0.009516                  0.019304
# 29229                      0.009930                  0.019298
# 29230                      0.008118                  0.019324
#
#        home office energy  RAE home office energy  \
# 0                0.018232                0.134570
# 1                0.013745                0.061839
# 2                0.014177                0.068852
# 3                0.013664                0.060540
# 4                0.013881                0.064047
# ...                   ...                     ...
# 29226            0.026968                0.276137
# 29227            0.023322                0.217043
# 29228            0.020701                0.174573
# 29229            0.021935                0.194574
# 29230            0.016541                0.107166
#
#        RAE Mobile Phone Charger Energy
# 0                             0.000431
# 1                             0.000215
# 2                             0.000236
# 3                             0.000211
# 4                             0.000221
# ...                                ...
# 29226                         0.000851
# 29227                         0.000675
# 29228                         0.000549
# 29229                         0.000609
# 29230                         0.000349
#
# [29231 rows x 8 columns]

# %% [markdown]
# #### Comparing Timestamps for clustering

# %%
timestamp_comparison = list()
for house in house_wise_consumption:
    first_timestamp = house_wise_consumption[house]['timestamp'].iloc[0]
    last_timestamp = house_wise_consumption[house]['timestamp'].iloc[-1]
    timestamp_comparison.append([house, first_timestamp, last_timestamp])
timestamp_comparison
timestamp_comparison_df = pd.DataFrame(timestamp_comparison, columns = ['House', 'First Timestamp', 'Last Timestamp'])
timestamp_comparison_df
# Out:
#     House      First Timestamp       Last Timestamp
# 0       1  2012-06-01 01:00:00  2015-10-03 00:00:00
# 1       2  2016-06-09 00:00:00  2019-11-20 23:00:00
# 2       3  2015-01-27 00:00:00  2018-01-29 23:00:00
# 3       4  2015-01-30 00:00:00  2018-01-29 23:00:00
# 4       5  2015-01-30 00:00:00  2018-01-29 23:00:00
# 5       6  2015-01-30 00:00:00  2018-01-29 23:00:00
# 6       7  2015-05-30 00:00:00  2018-01-29 23:00:00
# 7       8  2015-02-21 00:00:00  2018-02-20 23:00:00
# 8       9  2015-05-01 00:00:00  2018-02-21 23:00:00
# 9      10  2015-02-21 00:00:00  2018-02-20 23:00:00
# 10     11  2015-02-21 00:00:00  2018-02-20 23:00:00
# 11     12  2015-02-21 00:00:00  2018-02-20 23:00:00
# 12     13  2015-02-21 00:00:00  2018-02-20 23:00:00
# 13     14  2015-02-21 00:00:00  2018-02-20 23:00:00
# 14     15  2015-09-29 00:00:00  2018-02-20 23:00:00
# 15     16  2017-11-01 00:00:00  2019-02-18 23:00:00
# 16     17  2016-06-01 00:00:00  2017-04-29 23:00:00
# 17     18  2015-03-16 00:00:00  2018-03-15 16:00:00
# 18     19  2015-03-26 00:00:00  2018-03-25 23:00:00
# 19     20  2015-08-21 00:00:00  2018-04-20 23:00:00
# 20     21  2017-11-01 00:00:00  2018-06-04 23:00:00
# 21     22  2016-06-29 00:00:00  2018-06-05 23:00:00
# 22     23  2017-07-27 00:00:00  2020-04-05 23:00:00
# 23     24  2017-05-13 00:00:00  2020-05-12 23:00:00
# 24     25  2017-05-15 00:00:00  2020-05-14 23:00:00
# 25     26  2019-11-29 00:00:00  2020-05-20 23:00:00
# 26     27  2019-03-06 00:00:00  2020-05-20 23:00:00
# 27     28  2018-08-01 00:00:00  2020-05-19 23:00:00

# %%
# houses_with_ts = []
# sample_timestamp = '2017-11-01 00:00:00'
# for house in house_wise_consumption:
#     if sample_timestamp in house_wise_consumption[house]['timestamp'].unique():
#         houses_with_ts.append(house)
# len(houses_with_ts)
#house_wise_consumption[8][house_wise_consumption[8]['timestamp'] >= '2017-11-17'].head(60)

# %% [markdown]
# #### Creating a December consumption dictionary of dataframes

# %%
december_consumption = dict()
for house in house_wise_consumption:
    house_december_consumption = house_wise_consumption[house][(house_wise_consumption[house]['timestamp'] <= '2017-11-25') & (house_wise_consumption[house]['timestamp'] >= '2017-11-01')]
    december_consumption[house] = house_december_consumption.copy()
    december_consumption[house].drop_duplicates(subset='timestamp', keep="last", inplace = True)
def calculate_rows():
    december_rows = []
    for house in december_consumption:
        december_rows.append([house, len(december_consumption[house])])
    december_rows
    december_rows_df = pd.DataFrame(december_rows, columns = ['House', 'Rows'])
    return december_rows_df
def calculate_incomplete_rows():
    december_rows_df = calculate_rows()
    december_rows_incomplete_df = december_rows_df[(december_rows_df['Rows'] > 0) & (december_rows_df['Rows'] < 576)]
    return december_rows_incomplete_df
def fill_na_december_consumption(complete_df, incomplete_df):
    complete_df = complete_df.copy()
    year_incomplete = pd.Timestamp(incomplete_df.iloc[0]['timestamp']).year
    year_complete = pd.Timestamp(complete_df.iloc[0]['timestamp']).year
    complete_df['timestamp'] = complete_df['timestamp'].str.replace(str(year_complete), str(year_incomplete))
    fill_missing_values = complete_df[~complete_df.timestamp.isin(incomplete_df.timestamp)].copy()
    #print(fill_missing_values)
    fill_columns = ['energy_kWh', 'electronics workbench energy', 'network equipment energy', 'home office energy', 'RAE home office energy','RAE Mobile Phone Charger Energy']
    for fill_column in fill_columns:
        fill_missing_values[fill_column] = incomplete_df[fill_column].mean()
    incomplete_df = pd.concat([incomplete_df, fill_missing_values])
    incomplete_df = incomplete_df.sort_values(by=['timestamp'])
    return incomplete_df
def calculate_missing_december_rows():
    december_rows_df = calculate_rows()
    december_rows_missing_df = december_rows_df[(december_rows_df['Rows'] == 0)]
    return december_rows_missing_df
calculate_rows()
# Out:
#     House  Rows
# 0       1     0
# 1       2   576
# 2       3   576
# 3       4   576
# 4       5   576
# 5       6   576
# 6       7   576
# 7       8   448
# 8       9   576
# 9      10   576
# 10     11   568
# 11     12   528
# 12     13   576
# 13     14   575
# 14     15   576
# 15     16   456
# 16     17     0
# 17     18   528
# 18     19   576
# 19     20   575
# 20     21   576
# 21     22   528
# 22     23   576
# 23     24   576
# 24     25   576
# 25     26     0
# 26     27     0
# 27     28     0

# %%
for house in list(calculate_incomplete_rows()['House']):
    december_consumption[house] = fill_na_december_consumption(december_consumption[10], december_consumption[house])

# %% [markdown]
# ##### Houses with no December-17 consumption values

# %%
timestamp_comparison_df.set_index('House').join(calculate_missing_december_rows().set_index('House'), how='inner')
# Out:
#            First Timestamp       Last Timestamp  Rows
# House
# 1      2012-06-01 01:00:00  2015-10-03 00:00:00     0
# 17     2016-06-01 00:00:00  2017-04-29 23:00:00     0
# 26     2019-11-29 00:00:00  2020-05-20 23:00:00     0
# 27     2019-03-06 00:00:00  2020-05-20 23:00:00     0
# 28     2018-08-01 00:00:00  2020-05-19 23:00:00     0

# %%
missing_december_houses_dates = {
    1: ['2014-11-25', '2014-11-01'],
    17: ['2016-11-25', '2016-11-01'],
    26: ['2019-11-25', '2019-11-01'],
    27: ['2019-11-25', '2019-11-01'],
    28: ['2019-11-25', '2019-11-01'],
}

# %%
for house in missing_december_houses_dates:
    house_december_consumption = house_wise_consumption[house][(house_wise_consumption[house]['timestamp'] <= missing_december_houses_dates[house][0]) & (house_wise_consumption[house]['timestamp'] >= missing_december_houses_dates[house][1])]
    #print((house, missing_december_houses_dates[house][0]))
    december_consumption[house] = house_december_consumption.copy()
    december_consumption[house].drop_duplicates(subset='timestamp', keep="last", inplace = True)

# %% [markdown]
# ##### Filling missing values for December consumption

# %%
calculate_incomplete_rows()
# Out:
#     House  Rows
# 16     17   574
# 26     27   571
# 27     28   572

# %%
for house in list(calculate_incomplete_rows()['House']):
    december_consumption[house] = fill_na_december_consumption(december_consumption[10], december_consumption[house])

# %%
#calculate_rows()

# %% [markdown]
# #### Houses to be clustered

# %%
##print('Houses to be clustered: ')
clustered_df = calculate_rows()[calculate_rows()['Rows'] ==  576]
#clustered_df

# %% [markdown]
# #### Converting to clustering matrix

# %%
clustering_matrix = []
for house in calculate_rows()[calculate_rows()['Rows'] ==  576]['House']:
    clustering_matrix.append(np.array(december_consumption[house]['energy_kWh']).reshape(-1,1))
clustering_matrix = np.array(clustering_matrix)
clustering_matrix.shape
# Out:
# (27, 576, 1)

# %% [markdown]
# #### Time series clustering of all households except house 26

# %%
km_sdtw = TimeSeriesKMeans(n_clusters=4, metric="softdtw", max_iter=5,
                            max_iter_barycenter=5,
                            metric_params={"gamma": .5},
                            random_state=0).fit_predict(clustering_matrix)

# %%
len(km_sdtw)
# Out:
# 27

# %%
clustered_df['Cluster'] = km_sdtw

# %%
#clustered_df

# %% [markdown]
# #### Used Scenarios

# %%
data = [[1, 4, 6, 'Yes'], [2, 1, 6, 'Yes'], [3, 4, 1, 'No'], [4, 1, 1, 'No']]
df = pd.DataFrame(data, columns = ['Scenarios', 'No. of subsets', 'No. of features', 'Smart devices included in modeling?']).set_index('Scenarios')
df
# Out:
#            No. of subsets  No. of features Smart devices included in modeling?
# Scenarios
# 1                       4                6                                 Yes
# 2                       1                6                                 Yes
# 3                       4                1                                  No
# 4                       1                1                                  No

# %% [markdown]
# #### Time-series LSTM-based predictive modeling

# %%
n_past = 14
n_future = 1

# %%
### Energy generation dataframe
generation_df = pd.read_csv('Final Datasets/energy_generation.csv')
generation_df
# Out:
#                  timestamp  Wind Energy  Solar Energy
# 0      2012-01-01 00:00:00     0.196361           0.0
# 1      2012-01-01 01:00:00     0.196361           0.0
# 2      2012-01-01 02:00:00     0.196361           0.0
# 3      2012-01-01 03:00:00     0.196361           0.0
# 4      2012-01-01 04:00:00     0.196361           0.0
# ...                    ...          ...           ...
# 78907  2020-12-31 19:00:00     1.996050           0.0
# 78908  2020-12-31 20:00:00     1.996050           0.0
# 78909  2020-12-31 21:00:00     1.747987           0.0
# 78910  2020-12-31 22:00:00     1.500100           0.0
# 78911  2020-12-31 23:00:00     1.501644           0.0
#
# [78912 rows x 3 columns]

# %%
class House:
    cols = ['energy_kWh', 'electronics workbench energy', 'network equipment energy',
            'home office energy', 'RAE home office energy', 'RAE Mobile Phone Charger Energy']
    def __init__(self, house):
        self.house = house
        self.consumption_df = house_wise_consumption[house].copy()[House.cols].astype(float)
        self.train_dates_df = house_wise_consumption[house]['timestamp']
        self.prepare_dataset(n_future, n_past)
    
    def __repr__(self):
        return str(self.house)
    
    def prepare_dataset(self, n_future = 1, n_past = 14):
        #Empty lists to be populated using formatted training data
        trainX = []
        trainY = []
        consumption_np = np.array(self.consumption_df)
        #Reformat input data into a shape: (n_samples x timesteps x n_features)
        #In my example, my self.consumption_df has a shape (12823, 5)
        #12823 refers to the number of data points and 5 refers to the columns (multi-variables).
        for i in range(n_past, len(consumption_np) - n_future +1):
            trainX.append(consumption_np[i - n_past:i, 0:self.consumption_df.shape[1]])
            trainY.append(consumption_np[i + n_future - 1:i + n_future, 0])

        trainX, trainY = np.array(trainX), np.array(trainY)

        #print('trainX shape == {}.'.format(trainX.shape))
        #print('trainY shape == {}.'.format(trainY.shape))
        self.trainX = trainX
        self.trainY = trainY

class Cluster: 
    def __init__(self, houses):
        self.houses = [House(house) for house in houses]
        self.trainX_list = (list(map(lambda x: x.trainX, self.houses)))
        self.trainY_list = (list(map(lambda x: x.trainY, self.houses)))
        self.train_dates_list = (list(map(lambda x: x.train_dates_df, self.houses)))
        self.consumption_df_list = (list(map(lambda x: x.consumption_df, self.houses)))
        self.prepare_dataset()
        
    
    def prepare_dataset(self):
        
        self.train_dates = np.concatenate(self.train_dates_list, axis=0)
        ## TODO - Replace concatenate with for loop or sort by time
        self.X = np.concatenate(self.trainX_list, axis=0)
        self.Y = np.concatenate(self.trainY_list, axis=0)
    
    def prepare_model(self):
        model = Sequential()
        model.add(LSTM(128, activation='relu', input_shape=(self.X.shape[1], self.X.shape[2]), return_sequences=True))
        model.add(LSTM(32, activation='relu', return_sequences=True))
        model.add(LSTM(16, activation='relu', return_sequences=False))
        model.add(Dense(self.Y.shape[1]))
        model.compile(optimizer='adam', loss='mse', metrics=[tf.keras.metrics.RootMeanSquaredError(), tf.keras.metrics.MeanAbsoluteError()])
        model.summary()
        return model
    
    def train_model(self):
        model = self.prepare_model()
        history = model.fit(self.X, self.Y, epochs=30, batch_size=16, validation_split=0.3, verbose=1)
        self.history = history
        plt.plot(history.history['loss'], label='Training loss')
        plt.plot(history.history['val_loss'], label='Testing loss')
        
        plt.legend()
        return model
    
    def predicted(self):
        model = self.train_model()
        predictions = list(map(lambda x: pd.Series(model.predict(x).reshape(1,-1)[0]), self.trainX_list))
        #return pd.Series(model.predict(self.X).reshape(1,-1)[0])
        self.model = model
        return dict(zip(self.houses, predictions))
    
    def results(self):
        predicted = self.predicted()
        house_prediction_list_df  = {}
        for house in predicted:
            house_prediction_df = house.consumption_df.iloc[n_past:].copy().reset_index(drop=True)
            house_prediction_df['timestamp'] = house.train_dates_df.iloc[n_past:].copy().reset_index(drop=True)
            house_prediction_df['energy_predicted'] = predicted[house]
            ### Anomaly Detection
            energy_stddev = house_prediction_df['energy_kWh'].std()
            house_prediction_df['Energy Consumption Error'] = house_prediction_df['energy_predicted'] - house_prediction_df['energy_kWh']
            house_prediction_df['Anomaly detected'] = house_prediction_df['Energy Consumption Error'].apply(lambda x: False if abs(x) < 1.5*energy_stddev else abs(x))
            ### Energy Deficit Calculation
            house_prediction_df['timestamp'] = pd.DatetimeIndex(house_prediction_df['timestamp'])
            house_prediction_df = house_prediction_df.set_index('timestamp').join(generation_df.set_index('timestamp'))
            house_prediction_df['timestamp'] = house_prediction_df.index
            house_prediction_df.reset_index(drop=True, inplace=True)
            house_prediction_df['Total Generated Energy'] = house_prediction_df['Wind Energy']+ house_prediction_df['Solar Energy']
            house_prediction_df['Predicted Energy Deficit'] = house_prediction_df['Total Generated Energy'] - house_prediction_df['energy_predicted']
            house_prediction_df['Energy Deficit Flag'] = house_prediction_df['Predicted Energy Deficit'].apply(lambda x: False if x>0 else abs(x))
            house_prediction_list_df[house.house] = house_prediction_df
        return house_prediction_list_df

# %% [markdown]
# #### Scenario 1

# %%
zero_houses = list(clustered_df[clustered_df['Cluster'] == 0]['House'])
zero_cluster = Cluster(zero_houses)
zero_cluster_results = zero_cluster.results()
print('Training History for Cluster 0:')
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 14, 128)           69120
#
#  lstm_1 (LSTM)               (None, 14, 32)            20608
#
#  lstm_2 (LSTM)               (None, 16)                3136
#
#  dense (Dense)               (None, 1)                 17
#
# =================================================================
# Total params: 92,881
# Trainable params: 92,881
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 7680/7680 [==============================] - 137s 18ms/step - loss: 0.4794 - root_mean_squared_error: 0.6924 - mean_absolute_error: 0.4252 - val_loss: 0.6096 - val_root_mean_squared_error: 0.7808 - val_mean_absolute_error: 0.4918
# Epoch 2/30
# 7680/7680 [==============================] - 135s 18ms/step - loss: 0.4502 - root_mean_squared_error: 0.6710 - mean_absolute_error: 0.4024 - val_loss: 0.6562 - val_root_mean_squared_error: 0.8100 - val_mean_absolute_error: 0.4599
# Epoch 3/30
# 7680/7680 [==============================] - 135s 18ms/step - loss: 0.4441 - root_mean_squared_error: 0.6664 - mean_absolute_error: 0.3977 - val_loss: 0.6170 - val_root_mean_squared_error: 0.7855 - val_mean_absolute_error: 0.4457
# Epoch 4/30
# 7680/7680 [==============================] - 149s 19ms/step - loss: 0.4377 - root_mean_squared_error: 0.6616 - mean_absolute_error: 0.3943 - val_loss: 0.6066 - val_root_mean_squared_error: 0.7789 - val_mean_absolute_error: 0.4591
# Epoch 5/30
# 7680/7680 [==============================] - 149s 19ms/step - loss: 0.4332 - root_mean_squared_error: 0.6582 - mean_absolute_error: 0.3908 - val_loss: 0.6392 - val_root_mean_squared_error: 0.7995 - val_mean_absolute_error: 0.4442
# Epoch 6/30
# 7680/7680 [==============================] - 151s 20ms/step - loss: 0.4307 - root_mean_squared_error: 0.6562 - mean_absolute_error: 0.3901 - val_loss: 0.6102 - val_root_mean_squared_error: 0.7812 - val_mean_absolute_error: 0.4471
# Epoch 7/30
# 7680/7680 [==============================] - 152s 20ms/step - loss: 0.4286 - root_mean_squared_error: 0.6547 - mean_absolute_error: 0.3880 - val_loss: 0.6086 - val_root_mean_squared_error: 0.7801 - val_mean_absolute_error: 0.4432
# Epoch 8/30
# 7680/7680 [==============================] - 151s 20ms/step - loss: 0.4275 - root_mean_squared_error: 0.6538 - mean_absolute_error: 0.3870 - val_loss: 0.6123 - val_root_mean_squared_error: 0.7825 - val_mean_absolute_error: 0.4445
# Epoch 9/30
# 7680/7680 [==============================] - 152s 20ms/step - loss: 0.4255 - root_mean_squared_error: 0.6523 - mean_absolute_error: 0.3860 - val_loss: 0.6126 - val_root_mean_squared_error: 0.7827 - val_mean_absolute_error: 0.4453
# Epoch 10/30
# 7680/7680 [==============================] - 134s 17ms/step - loss: 0.4235 - root_mean_squared_error: 0.6508 - mean_absolute_error: 0.3853 - val_loss: 0.6069 - val_root_mean_squared_error: 0.7790 - val_mean_absolute_error: 0.4488
# Epoch 11/30
# 7680/7680 [==============================] - 119s 15ms/step - loss: 0.4207 - root_mean_squared_error: 0.6486 - mean_absolute_error: 0.3840 - val_loss: 0.6373 - val_root_mean_squared_error: 0.7983 - val_mean_absolute_error: 0.4612
# Epoch 12/30
# 7680/7680 [==============================] - 118s 15ms/step - loss: 0.4204 - root_mean_squared_error: 0.6484 - mean_absolute_error: 0.3838 - val_loss: 0.6119 - val_root_mean_squared_error: 0.7822 - val_mean_absolute_error: 0.4471
# Epoch 13/30
# 7680/7680 [==============================] - 119s 15ms/step - loss: 0.4192 - root_mean_squared_error: 0.6474 - mean_absolute_error: 0.3835 - val_loss: 0.6286 - val_root_mean_squared_error: 0.7928 - val_mean_absolute_error: 0.4553
# Epoch 14/30
# 7680/7680 [==============================] - 119s 15ms/step - loss: 0.4171 - root_mean_squared_error: 0.6458 - mean_absolute_error: 0.3826 - val_loss: 0.6425 - val_root_mean_squared_error: 0.8016 - val_mean_absolute_error: 0.4525
# Epoch 15/30
# 7680/7680 [==============================] - 119s 15ms/step - loss: 0.4172 - root_mean_squared_error: 0.6459 - mean_absolute_error: 0.3825 - val_loss: 0.6179 - val_root_mean_squared_error: 0.7860 - val_mean_absolute_error: 0.4440
# Epoch 16/30
# 7680/7680 [==============================] - 119s 15ms/step - loss: 0.4153 - root_mean_squared_error: 0.6444 - mean_absolute_error: 0.3816 - val_loss: 0.6222 - val_root_mean_squared_error: 0.7888 - val_mean_absolute_error: 0.4446
# Epoch 17/30
# 7680/7680 [==============================] - 119s 15ms/step - loss: 0.4135 - root_mean_squared_error: 0.6431 - mean_absolute_error: 0.3811 - val_loss: 0.6404 - val_root_mean_squared_error: 0.8002 - val_mean_absolute_error: 0.4540
# Epoch 18/30
# 7680/7680 [==============================] - 119s 15ms/step - loss: 0.4120 - root_mean_squared_error: 0.6419 - mean_absolute_error: 0.3809 - val_loss: 0.6418 - val_root_mean_squared_error: 0.8011 - val_mean_absolute_error: 0.4527
# Epoch 19/30
# 7680/7680 [==============================] - 119s 15ms/step - loss: 0.4110 - root_mean_squared_error: 0.6411 - mean_absolute_error: 0.3797 - val_loss: 0.6304 - val_root_mean_squared_error: 0.7940 - val_mean_absolute_error: 0.4577
# Epoch 20/30
# 7680/7680 [==============================] - 119s 15ms/step - loss: 0.4091 - root_mean_squared_error: 0.6396 - mean_absolute_error: 0.3797 - val_loss: 0.6504 - val_root_mean_squared_error: 0.8065 - val_mean_absolute_error: 0.4523
# Epoch 21/30
# 7680/7680 [==============================] - 119s 15ms/step - loss: 0.4076 - root_mean_squared_error: 0.6384 - mean_absolute_error: 0.3794 - val_loss: 0.6382 - val_root_mean_squared_error: 0.7989 - val_mean_absolute_error: 0.4627
# Epoch 22/30
# 7680/7680 [==============================] - 119s 15ms/step - loss: 0.4070 - root_mean_squared_error: 0.6379 - mean_absolute_error: 0.3788 - val_loss: 0.6428 - val_root_mean_squared_error: 0.8017 - val_mean_absolute_error: 0.4601
# Epoch 23/30
# 7680/7680 [==============================] - 119s 15ms/step - loss: 0.4080 - root_mean_squared_error: 0.6387 - mean_absolute_error: 0.3791 - val_loss: 0.6561 - val_root_mean_squared_error: 0.8100 - val_mean_absolute_error: 0.4541
# Epoch 24/30
# 7680/7680 [==============================] - 119s 15ms/step - loss: 0.4044 - root_mean_squared_error: 0.6359 - mean_absolute_error: 0.3784 - val_loss: 0.6431 - val_root_mean_squared_error: 0.8019 - val_mean_absolute_error: 0.4593
# Epoch 25/30
# 7680/7680 [==============================] - 119s 15ms/step - loss: 0.4026 - root_mean_squared_error: 0.6345 - mean_absolute_error: 0.3775 - val_loss: 0.6332 - val_root_mean_squared_error: 0.7957 - val_mean_absolute_error: 0.4576
# Epoch 26/30
# 7680/7680 [==============================] - 118s 15ms/step - loss: 0.4031 - root_mean_squared_error: 0.6349 - mean_absolute_error: 0.3774 - val_loss: 0.6253 - val_root_mean_squared_error: 0.7908 - val_mean_absolute_error: 0.4536
# Epoch 27/30
# 7680/7680 [==============================] - 118s 15ms/step - loss: 0.4007 - root_mean_squared_error: 0.6330 - mean_absolute_error: 0.3772 - val_loss: 0.6542 - val_root_mean_squared_error: 0.8088 - val_mean_absolute_error: 0.4486
# Epoch 28/30
# 7680/7680 [==============================] - 118s 15ms/step - loss: 0.3996 - root_mean_squared_error: 0.6322 - mean_absolute_error: 0.3769 - val_loss: 0.6559 - val_root_mean_squared_error: 0.8099 - val_mean_absolute_error: 0.4579
# Epoch 29/30
# 7680/7680 [==============================] - 118s 15ms/step - loss: 0.3975 - root_mean_squared_error: 0.6305 - mean_absolute_error: 0.3759 - val_loss: 0.6870 - val_root_mean_squared_error: 0.8289 - val_mean_absolute_error: 0.4605
# Epoch 30/30
# 7680/7680 [==============================] - 118s 15ms/step - loss: 0.3962 - root_mean_squared_error: 0.6295 - mean_absolute_error: 0.3758 - val_loss: 0.6450 - val_root_mean_squared_error: 0.8031 - val_mean_absolute_error: 0.4531
# Training History for Cluster 0:

# %%
one_houses = list(clustered_df[clustered_df['Cluster'] == 1]['House'])
one_cluster = Cluster(one_houses)
one_cluster_results = one_cluster.results()
print('Training History for Cluster 1:')
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_3 (LSTM)               (None, 14, 128)           69120
#
#  lstm_4 (LSTM)               (None, 14, 32)            20608
#
#  lstm_5 (LSTM)               (None, 16)                3136
#
#  dense_1 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 92,881
# Trainable params: 92,881
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 915/915 [==============================] - 16s 16ms/step - loss: 1.5322 - root_mean_squared_error: 1.2378 - mean_absolute_error: 0.7344 - val_loss: 1.5333 - val_root_mean_squared_error: 1.2383 - val_mean_absolute_error: 0.5720
# Epoch 2/30
# 915/915 [==============================] - 14s 15ms/step - loss: 0.9748 - root_mean_squared_error: 0.9873 - mean_absolute_error: 0.5580 - val_loss: 1.6658 - val_root_mean_squared_error: 1.2907 - val_mean_absolute_error: 0.5420
# Epoch 3/30
# 915/915 [==============================] - 14s 16ms/step - loss: 0.9153 - root_mean_squared_error: 0.9567 - mean_absolute_error: 0.5418 - val_loss: 1.3061 - val_root_mean_squared_error: 1.1428 - val_mean_absolute_error: 0.5610
# Epoch 4/30
# 915/915 [==============================] - 14s 15ms/step - loss: 0.9002 - root_mean_squared_error: 0.9488 - mean_absolute_error: 0.5384 - val_loss: 1.2746 - val_root_mean_squared_error: 1.1290 - val_mean_absolute_error: 0.6482
# Epoch 5/30
# 915/915 [==============================] - 14s 15ms/step - loss: 0.8703 - root_mean_squared_error: 0.9329 - mean_absolute_error: 0.5322 - val_loss: 1.1614 - val_root_mean_squared_error: 1.0777 - val_mean_absolute_error: 0.5432
# Epoch 6/30
# 915/915 [==============================] - 14s 15ms/step - loss: 0.8475 - root_mean_squared_error: 0.9206 - mean_absolute_error: 0.5248 - val_loss: 1.1830 - val_root_mean_squared_error: 1.0877 - val_mean_absolute_error: 0.5663
# Epoch 7/30
# 915/915 [==============================] - 14s 15ms/step - loss: 0.8376 - root_mean_squared_error: 0.9152 - mean_absolute_error: 0.5243 - val_loss: 1.1726 - val_root_mean_squared_error: 1.0829 - val_mean_absolute_error: 0.5813
# Epoch 8/30
# 915/915 [==============================] - 14s 15ms/step - loss: 0.8031 - root_mean_squared_error: 0.8961 - mean_absolute_error: 0.5126 - val_loss: 1.1304 - val_root_mean_squared_error: 1.0632 - val_mean_absolute_error: 0.5147
# Epoch 9/30
# 915/915 [==============================] - 14s 15ms/step - loss: 0.8256 - root_mean_squared_error: 0.9086 - mean_absolute_error: 0.5134 - val_loss: 1.1783 - val_root_mean_squared_error: 1.0855 - val_mean_absolute_error: 0.5283
# Epoch 10/30
# 915/915 [==============================] - 14s 15ms/step - loss: 0.7979 - root_mean_squared_error: 0.8932 - mean_absolute_error: 0.5048 - val_loss: 1.1996 - val_root_mean_squared_error: 1.0953 - val_mean_absolute_error: 0.5153
# Epoch 11/30
# 915/915 [==============================] - 14s 15ms/step - loss: 0.8224 - root_mean_squared_error: 0.9069 - mean_absolute_error: 0.5097 - val_loss: 1.1985 - val_root_mean_squared_error: 1.0947 - val_mean_absolute_error: 0.6016
# Epoch 12/30
# 915/915 [==============================] - 14s 15ms/step - loss: 0.7727 - root_mean_squared_error: 0.8790 - mean_absolute_error: 0.4995 - val_loss: 1.1044 - val_root_mean_squared_error: 1.0509 - val_mean_absolute_error: 0.5509
# Epoch 13/30
# 915/915 [==============================] - 14s 15ms/step - loss: 0.7572 - root_mean_squared_error: 0.8702 - mean_absolute_error: 0.4948 - val_loss: 1.1269 - val_root_mean_squared_error: 1.0616 - val_mean_absolute_error: 0.5405
# Epoch 14/30
# 915/915 [==============================] - 14s 15ms/step - loss: 0.7547 - root_mean_squared_error: 0.8688 - mean_absolute_error: 0.4916 - val_loss: 1.0832 - val_root_mean_squared_error: 1.0408 - val_mean_absolute_error: 0.5497
# Epoch 15/30
# 915/915 [==============================] - 14s 15ms/step - loss: 0.7557 - root_mean_squared_error: 0.8693 - mean_absolute_error: 0.4917 - val_loss: 1.1284 - val_root_mean_squared_error: 1.0622 - val_mean_absolute_error: 0.4877
# Epoch 16/30
# 915/915 [==============================] - 14s 15ms/step - loss: 0.7462 - root_mean_squared_error: 0.8638 - mean_absolute_error: 0.4910 - val_loss: 1.1112 - val_root_mean_squared_error: 1.0541 - val_mean_absolute_error: 0.5643
# Epoch 17/30
# 915/915 [==============================] - 14s 15ms/step - loss: 0.7459 - root_mean_squared_error: 0.8637 - mean_absolute_error: 0.4880 - val_loss: 1.1677 - val_root_mean_squared_error: 1.0806 - val_mean_absolute_error: 0.5132
# Epoch 18/30
# 915/915 [==============================] - 14s 15ms/step - loss: 0.7308 - root_mean_squared_error: 0.8549 - mean_absolute_error: 0.4850 - val_loss: 1.2028 - val_root_mean_squared_error: 1.0967 - val_mean_absolute_error: 0.5793
# Epoch 19/30
# 915/915 [==============================] - 14s 15ms/step - loss: 0.7397 - root_mean_squared_error: 0.8600 - mean_absolute_error: 0.4871 - val_loss: 1.2265 - val_root_mean_squared_error: 1.1075 - val_mean_absolute_error: 0.5470
# Epoch 20/30
# 915/915 [==============================] - 14s 15ms/step - loss: 0.7280 - root_mean_squared_error: 0.8532 - mean_absolute_error: 0.4856 - val_loss: 1.1045 - val_root_mean_squared_error: 1.0510 - val_mean_absolute_error: 0.4995
# Epoch 21/30
# 915/915 [==============================] - 14s 15ms/step - loss: 0.7061 - root_mean_squared_error: 0.8403 - mean_absolute_error: 0.4762 - val_loss: 1.3092 - val_root_mean_squared_error: 1.1442 - val_mean_absolute_error: 0.5859
# Epoch 22/30
# 915/915 [==============================] - 14s 15ms/step - loss: 0.7188 - root_mean_squared_error: 0.8478 - mean_absolute_error: 0.4844 - val_loss: 1.1107 - val_root_mean_squared_error: 1.0539 - val_mean_absolute_error: 0.5151
# Epoch 23/30
# 915/915 [==============================] - 14s 15ms/step - loss: 0.7092 - root_mean_squared_error: 0.8422 - mean_absolute_error: 0.4750 - val_loss: 1.1396 - val_root_mean_squared_error: 1.0675 - val_mean_absolute_error: 0.5290
# Epoch 24/30
# 915/915 [==============================] - 14s 15ms/step - loss: 0.7012 - root_mean_squared_error: 0.8374 - mean_absolute_error: 0.4772 - val_loss: 1.1146 - val_root_mean_squared_error: 1.0557 - val_mean_absolute_error: 0.5171
# Epoch 25/30
# 915/915 [==============================] - 14s 15ms/step - loss: 0.7782 - root_mean_squared_error: 0.8821 - mean_absolute_error: 0.4791 - val_loss: 4.8359 - val_root_mean_squared_error: 2.1991 - val_mean_absolute_error: 0.5960
# Epoch 26/30
# 915/915 [==============================] - 14s 15ms/step - loss: 0.7263 - root_mean_squared_error: 0.8522 - mean_absolute_error: 0.4737 - val_loss: 1.1195 - val_root_mean_squared_error: 1.0581 - val_mean_absolute_error: 0.5231
# Epoch 27/30
# 915/915 [==============================] - 14s 15ms/step - loss: 0.6865 - root_mean_squared_error: 0.8286 - mean_absolute_error: 0.4683 - val_loss: 1.0953 - val_root_mean_squared_error: 1.0466 - val_mean_absolute_error: 0.5237
# Epoch 28/30
# 915/915 [==============================] - 14s 15ms/step - loss: 0.6963 - root_mean_squared_error: 0.8345 - mean_absolute_error: 0.4726 - val_loss: 1.1034 - val_root_mean_squared_error: 1.0504 - val_mean_absolute_error: 0.5289
# Epoch 29/30
# 915/915 [==============================] - 14s 15ms/step - loss: 0.6799 - root_mean_squared_error: 0.8246 - mean_absolute_error: 0.4681 - val_loss: 1.1634 - val_root_mean_squared_error: 1.0786 - val_mean_absolute_error: 0.5123
# Epoch 30/30
# 915/915 [==============================] - 14s 15ms/step - loss: 0.6792 - root_mean_squared_error: 0.8242 - mean_absolute_error: 0.4688 - val_loss: 1.1250 - val_root_mean_squared_error: 1.0606 - val_mean_absolute_error: 0.4872
# Training History for Cluster 1:

# %%
two_houses = list(clustered_df[clustered_df['Cluster'] == 2]['House'])
two_cluster = Cluster(two_houses)
two_cluster_results = two_cluster.results()
print('Training History for Cluster 2:')
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_6 (LSTM)               (None, 14, 128)           69120
#
#  lstm_7 (LSTM)               (None, 14, 32)            20608
#
#  lstm_8 (LSTM)               (None, 16)                3136
#
#  dense_2 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 92,881
# Trainable params: 92,881
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 15194/15194 [==============================] - 237s 15ms/step - loss: 0.1512 - root_mean_squared_error: 0.3888 - mean_absolute_error: 0.2194 - val_loss: 0.2008 - val_root_mean_squared_error: 0.4481 - val_mean_absolute_error: 0.2550
# Epoch 2/30
# 15194/15194 [==============================] - 235s 15ms/step - loss: 0.1453 - root_mean_squared_error: 0.3811 - mean_absolute_error: 0.2109 - val_loss: 0.2043 - val_root_mean_squared_error: 0.4520 - val_mean_absolute_error: 0.2536
# Epoch 3/30
# 15194/15194 [==============================] - 236s 16ms/step - loss: 0.1440 - root_mean_squared_error: 0.3794 - mean_absolute_error: 0.2091 - val_loss: 0.2033 - val_root_mean_squared_error: 0.4509 - val_mean_absolute_error: 0.2414
# Epoch 4/30
# 15194/15194 [==============================] - 253s 17ms/step - loss: 0.1427 - root_mean_squared_error: 0.3778 - mean_absolute_error: 0.2079 - val_loss: 0.2032 - val_root_mean_squared_error: 0.4508 - val_mean_absolute_error: 0.2435
# Epoch 5/30
# 15194/15194 [==============================] - 235s 15ms/step - loss: 0.1420 - root_mean_squared_error: 0.3769 - mean_absolute_error: 0.2070 - val_loss: 0.2030 - val_root_mean_squared_error: 0.4505 - val_mean_absolute_error: 0.2517
# Epoch 6/30
# 15194/15194 [==============================] - 235s 15ms/step - loss: 0.1416 - root_mean_squared_error: 0.3762 - mean_absolute_error: 0.2067 - val_loss: 0.2021 - val_root_mean_squared_error: 0.4496 - val_mean_absolute_error: 0.2510
# Epoch 7/30
# 15194/15194 [==============================] - 235s 15ms/step - loss: 0.1411 - root_mean_squared_error: 0.3756 - mean_absolute_error: 0.2064 - val_loss: 0.2029 - val_root_mean_squared_error: 0.4505 - val_mean_absolute_error: 0.2512
# Epoch 8/30
# 15194/15194 [==============================] - 235s 15ms/step - loss: 0.1408 - root_mean_squared_error: 0.3752 - mean_absolute_error: 0.2057 - val_loss: 0.2043 - val_root_mean_squared_error: 0.4520 - val_mean_absolute_error: 0.2469
# Epoch 9/30
# 15194/15194 [==============================] - 236s 16ms/step - loss: 0.1403 - root_mean_squared_error: 0.3746 - mean_absolute_error: 0.2055 - val_loss: 0.2033 - val_root_mean_squared_error: 0.4509 - val_mean_absolute_error: 0.2458
# Epoch 10/30
# 15194/15194 [==============================] - 236s 16ms/step - loss: 0.1400 - root_mean_squared_error: 0.3742 - mean_absolute_error: 0.2050 - val_loss: 0.2041 - val_root_mean_squared_error: 0.4518 - val_mean_absolute_error: 0.2434
# Epoch 11/30
# 15194/15194 [==============================] - 236s 16ms/step - loss: 0.1396 - root_mean_squared_error: 0.3736 - mean_absolute_error: 0.2048 - val_loss: 0.2041 - val_root_mean_squared_error: 0.4518 - val_mean_absolute_error: 0.2577
# Epoch 12/30
# 15194/15194 [==============================] - 235s 15ms/step - loss: 0.1393 - root_mean_squared_error: 0.3733 - mean_absolute_error: 0.2047 - val_loss: 0.2027 - val_root_mean_squared_error: 0.4502 - val_mean_absolute_error: 0.2522
# Epoch 13/30
# 15194/15194 [==============================] - 236s 16ms/step - loss: 0.1389 - root_mean_squared_error: 0.3727 - mean_absolute_error: 0.2044 - val_loss: 0.2048 - val_root_mean_squared_error: 0.4525 - val_mean_absolute_error: 0.2526
# Epoch 14/30
# 15194/15194 [==============================] - 236s 16ms/step - loss: 0.1388 - root_mean_squared_error: 0.3725 - mean_absolute_error: 0.2042 - val_loss: 0.2019 - val_root_mean_squared_error: 0.4493 - val_mean_absolute_error: 0.2511
# Epoch 15/30
# 15194/15194 [==============================] - 236s 16ms/step - loss: 0.1384 - root_mean_squared_error: 0.3720 - mean_absolute_error: 0.2039 - val_loss: 0.2056 - val_root_mean_squared_error: 0.4534 - val_mean_absolute_error: 0.2506
# Epoch 16/30
# 15194/15194 [==============================] - 236s 16ms/step - loss: 0.1381 - root_mean_squared_error: 0.3716 - mean_absolute_error: 0.2038 - val_loss: 0.2061 - val_root_mean_squared_error: 0.4540 - val_mean_absolute_error: 0.2424
# Epoch 17/30
# 15194/15194 [==============================] - 236s 16ms/step - loss: 0.1377 - root_mean_squared_error: 0.3710 - mean_absolute_error: 0.2035 - val_loss: 0.2056 - val_root_mean_squared_error: 0.4535 - val_mean_absolute_error: 0.2453
# Epoch 18/30
# 15194/15194 [==============================] - 236s 16ms/step - loss: 0.1374 - root_mean_squared_error: 0.3707 - mean_absolute_error: 0.2032 - val_loss: 0.2052 - val_root_mean_squared_error: 0.4530 - val_mean_absolute_error: 0.2541
# Epoch 19/30
# 15194/15194 [==============================] - 236s 16ms/step - loss: 0.1373 - root_mean_squared_error: 0.3706 - mean_absolute_error: 0.2031 - val_loss: 0.2070 - val_root_mean_squared_error: 0.4549 - val_mean_absolute_error: 0.2542
# Epoch 20/30
# 15194/15194 [==============================] - 236s 16ms/step - loss: 0.1369 - root_mean_squared_error: 0.3700 - mean_absolute_error: 0.2029 - val_loss: 0.2042 - val_root_mean_squared_error: 0.4518 - val_mean_absolute_error: 0.2524
# Epoch 21/30
# 15194/15194 [==============================] - 236s 16ms/step - loss: 0.1365 - root_mean_squared_error: 0.3694 - mean_absolute_error: 0.2028 - val_loss: 0.2068 - val_root_mean_squared_error: 0.4547 - val_mean_absolute_error: 0.2459
# Epoch 22/30
# 15194/15194 [==============================] - 236s 16ms/step - loss: 0.1369 - root_mean_squared_error: 0.3701 - mean_absolute_error: 0.2029 - val_loss: 0.2828 - val_root_mean_squared_error: 0.5318 - val_mean_absolute_error: 0.2525
# Epoch 23/30
# 15194/15194 [==============================] - 236s 16ms/step - loss: 0.1401 - root_mean_squared_error: 0.3742 - mean_absolute_error: 0.2029 - val_loss: 0.4734 - val_root_mean_squared_error: 0.6880 - val_mean_absolute_error: 0.2498
# Epoch 24/30
# 15194/15194 [==============================] - 236s 16ms/step - loss: 0.1361 - root_mean_squared_error: 0.3689 - mean_absolute_error: 0.2023 - val_loss: 0.2066 - val_root_mean_squared_error: 0.4545 - val_mean_absolute_error: 0.2481
# Epoch 25/30
# 15194/15194 [==============================] - 236s 16ms/step - loss: 0.1356 - root_mean_squared_error: 0.3682 - mean_absolute_error: 0.2021 - val_loss: 0.2076 - val_root_mean_squared_error: 0.4556 - val_mean_absolute_error: 0.2520
# Epoch 26/30
# 15194/15194 [==============================] - 236s 16ms/step - loss: 0.1354 - root_mean_squared_error: 0.3679 - mean_absolute_error: 0.2020 - val_loss: 0.2104 - val_root_mean_squared_error: 0.4587 - val_mean_absolute_error: 0.2523
# Epoch 27/30
# 15194/15194 [==============================] - 237s 16ms/step - loss: 22.1389 - root_mean_squared_error: 4.7052 - mean_absolute_error: 0.3203 - val_loss: 20.8565 - val_root_mean_squared_error: 4.5669 - val_mean_absolute_error: 0.5285
# Epoch 28/30
# 15194/15194 [==============================] - 237s 16ms/step - loss: 0.9048 - root_mean_squared_error: 0.9512 - mean_absolute_error: 0.2887 - val_loss: 2.0415 - val_root_mean_squared_error: 1.4288 - val_mean_absolute_error: 0.2661
# Epoch 29/30
# 15194/15194 [==============================] - 237s 16ms/step - loss: 1.1590 - root_mean_squared_error: 1.0766 - mean_absolute_error: 0.2742 - val_loss: 4.8554 - val_root_mean_squared_error: 2.2035 - val_mean_absolute_error: 0.4406
# Epoch 30/30
# 15194/15194 [==============================] - 238s 16ms/step - loss: 1.7991 - root_mean_squared_error: 1.3413 - mean_absolute_error: 0.3487 - val_loss: 0.3688 - val_root_mean_squared_error: 0.6073 - val_mean_absolute_error: 0.4246
# Training History for Cluster 2:

# %%
three_houses = list(clustered_df[clustered_df['Cluster'] == 3]['House'])
three_cluster = Cluster(three_houses)
three_cluster_results = three_cluster.results()
print('Training History for Cluster 3:')
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_9 (LSTM)               (None, 14, 128)           69120
#
#  lstm_10 (LSTM)              (None, 14, 32)            20608
#
#  lstm_11 (LSTM)              (None, 16)                3136
#
#  dense_3 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 92,881
# Trainable params: 92,881
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 2745/2745 [==============================] - 45s 16ms/step - loss: 0.4211 - root_mean_squared_error: 0.6490 - mean_absolute_error: 0.4314 - val_loss: 0.4283 - val_root_mean_squared_error: 0.6544 - val_mean_absolute_error: 0.4068
# Epoch 2/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.3620 - root_mean_squared_error: 0.6016 - mean_absolute_error: 0.3832 - val_loss: 0.3870 - val_root_mean_squared_error: 0.6221 - val_mean_absolute_error: 0.3983
# Epoch 3/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.3526 - root_mean_squared_error: 0.5938 - mean_absolute_error: 0.3755 - val_loss: 0.4059 - val_root_mean_squared_error: 0.6371 - val_mean_absolute_error: 0.3533
# Epoch 4/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.3448 - root_mean_squared_error: 0.5872 - mean_absolute_error: 0.3676 - val_loss: 0.3936 - val_root_mean_squared_error: 0.6274 - val_mean_absolute_error: 0.3587
# Epoch 5/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.3381 - root_mean_squared_error: 0.5814 - mean_absolute_error: 0.3614 - val_loss: 0.3977 - val_root_mean_squared_error: 0.6306 - val_mean_absolute_error: 0.3828
# Epoch 6/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.3326 - root_mean_squared_error: 0.5767 - mean_absolute_error: 0.3572 - val_loss: 0.3862 - val_root_mean_squared_error: 0.6215 - val_mean_absolute_error: 0.3777
# Epoch 7/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.3290 - root_mean_squared_error: 0.5736 - mean_absolute_error: 0.3544 - val_loss: 0.3870 - val_root_mean_squared_error: 0.6221 - val_mean_absolute_error: 0.3639
# Epoch 8/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.3251 - root_mean_squared_error: 0.5702 - mean_absolute_error: 0.3505 - val_loss: 0.3727 - val_root_mean_squared_error: 0.6105 - val_mean_absolute_error: 0.3614
# Epoch 9/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.3231 - root_mean_squared_error: 0.5684 - mean_absolute_error: 0.3499 - val_loss: 0.4076 - val_root_mean_squared_error: 0.6384 - val_mean_absolute_error: 0.4138
# Epoch 10/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.3211 - root_mean_squared_error: 0.5667 - mean_absolute_error: 0.3474 - val_loss: 0.3928 - val_root_mean_squared_error: 0.6267 - val_mean_absolute_error: 0.3787
# Epoch 11/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.3187 - root_mean_squared_error: 0.5645 - mean_absolute_error: 0.3460 - val_loss: 0.3906 - val_root_mean_squared_error: 0.6250 - val_mean_absolute_error: 0.3913
# Epoch 12/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.3171 - root_mean_squared_error: 0.5631 - mean_absolute_error: 0.3455 - val_loss: 0.3674 - val_root_mean_squared_error: 0.6062 - val_mean_absolute_error: 0.3778
# Epoch 13/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.3152 - root_mean_squared_error: 0.5614 - mean_absolute_error: 0.3441 - val_loss: 0.3727 - val_root_mean_squared_error: 0.6105 - val_mean_absolute_error: 0.3730
# Epoch 14/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.3141 - root_mean_squared_error: 0.5605 - mean_absolute_error: 0.3418 - val_loss: 0.3886 - val_root_mean_squared_error: 0.6234 - val_mean_absolute_error: 0.3769
# Epoch 15/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.3116 - root_mean_squared_error: 0.5582 - mean_absolute_error: 0.3399 - val_loss: 0.3993 - val_root_mean_squared_error: 0.6319 - val_mean_absolute_error: 0.3951
# Epoch 16/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.3098 - root_mean_squared_error: 0.5566 - mean_absolute_error: 0.3394 - val_loss: 0.3840 - val_root_mean_squared_error: 0.6197 - val_mean_absolute_error: 0.3706
# Epoch 17/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.3095 - root_mean_squared_error: 0.5563 - mean_absolute_error: 0.3391 - val_loss: 0.3859 - val_root_mean_squared_error: 0.6212 - val_mean_absolute_error: 0.3669
# Epoch 18/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.3074 - root_mean_squared_error: 0.5544 - mean_absolute_error: 0.3378 - val_loss: 0.3938 - val_root_mean_squared_error: 0.6276 - val_mean_absolute_error: 0.3738
# Epoch 19/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.3058 - root_mean_squared_error: 0.5530 - mean_absolute_error: 0.3363 - val_loss: 0.4051 - val_root_mean_squared_error: 0.6364 - val_mean_absolute_error: 0.3785
# Epoch 20/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.3045 - root_mean_squared_error: 0.5518 - mean_absolute_error: 0.3354 - val_loss: 0.4168 - val_root_mean_squared_error: 0.6456 - val_mean_absolute_error: 0.3954
# Epoch 21/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.3013 - root_mean_squared_error: 0.5489 - mean_absolute_error: 0.3341 - val_loss: 0.4084 - val_root_mean_squared_error: 0.6391 - val_mean_absolute_error: 0.3894
# Epoch 22/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.3006 - root_mean_squared_error: 0.5482 - mean_absolute_error: 0.3332 - val_loss: 0.4037 - val_root_mean_squared_error: 0.6354 - val_mean_absolute_error: 0.3906
# Epoch 23/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.2989 - root_mean_squared_error: 0.5467 - mean_absolute_error: 0.3329 - val_loss: 0.4124 - val_root_mean_squared_error: 0.6422 - val_mean_absolute_error: 0.3916
# Epoch 24/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.2972 - root_mean_squared_error: 0.5452 - mean_absolute_error: 0.3312 - val_loss: 0.4098 - val_root_mean_squared_error: 0.6401 - val_mean_absolute_error: 0.4047
# Epoch 25/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.2952 - root_mean_squared_error: 0.5433 - mean_absolute_error: 0.3302 - val_loss: 0.3982 - val_root_mean_squared_error: 0.6310 - val_mean_absolute_error: 0.3978
# Epoch 26/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.2935 - root_mean_squared_error: 0.5417 - mean_absolute_error: 0.3290 - val_loss: 0.4152 - val_root_mean_squared_error: 0.6443 - val_mean_absolute_error: 0.3853
# Epoch 27/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.2909 - root_mean_squared_error: 0.5393 - mean_absolute_error: 0.3275 - val_loss: 0.4038 - val_root_mean_squared_error: 0.6354 - val_mean_absolute_error: 0.3729
# Epoch 28/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.2901 - root_mean_squared_error: 0.5386 - mean_absolute_error: 0.3279 - val_loss: 0.4195 - val_root_mean_squared_error: 0.6477 - val_mean_absolute_error: 0.3780
# Epoch 29/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.2869 - root_mean_squared_error: 0.5356 - mean_absolute_error: 0.3256 - val_loss: 0.4331 - val_root_mean_squared_error: 0.6581 - val_mean_absolute_error: 0.3921
# Epoch 30/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.2867 - root_mean_squared_error: 0.5354 - mean_absolute_error: 0.3253 - val_loss: 0.4235 - val_root_mean_squared_error: 0.6507 - val_mean_absolute_error: 0.4020
# Training History for Cluster 3:

# %%
### Save Scenario 1 models
# zero_cluster.model.save('Models/Scenario1/zero_cluster')
# one_cluster.model.save('Models/Scenario1/one_cluster')
# two_cluster.model.save('Models/Scenario1/two_cluster')
# three_cluster.model.save('Models/Scenario1/three_cluster')

### Pickling cluster and cluster results
# zero_cluster_file = open("Models/Scenario1/Objects/zero_cluster.pickle", "wb")
# pickle.dump(zero_cluster, zero_cluster_file)
# zero_cluster_file.close()

# one_cluster_file = open("Models/Scenario1/Objects/one_cluster.pickle", "wb")
# pickle.dump(one_cluster, one_cluster_file)
# one_cluster_file.close()

# two_cluster_file = open("Models/Scenario1/Objects/two_cluster.pickle", "wb")
# pickle.dump(two_cluster, two_cluster_file)
# two_cluster_file.close()

# three_cluster_file = open("Models/Scenario1/Objects/three_cluster.pickle", "wb")
# pickle.dump(three_cluster, three_cluster_file)
# three_cluster_file.close()

# zero_cluster_results_file = open("Models/Scenario1/Objects/zero_cluster_results.pickle", "wb")
# pickle.dump(zero_cluster_results, zero_cluster_results_file)
# zero_cluster_results_file.close()

# one_cluster_results_file = open("Models/Scenario1/Objects/one_cluster_results.pickle", "wb")
# pickle.dump(one_cluster_results, one_cluster_results_file)
# one_cluster_results_file.close()

# two_cluster_results_file = open("Models/Scenario1/Objects/two_cluster_results.pickle", "wb")
# pickle.dump(two_cluster_results, two_cluster_results_file)
# two_cluster_results_file.close()

# three_cluster_results_file = open("Models/Scenario1/Objects/three_cluster_results.pickle", "wb")
# pickle.dump(three_cluster_results, three_cluster_results_file)
# three_cluster_results_file.close()

# %% [markdown]
# #### Scenario 2

# %%
all_houses = list(clustered_df['House'])
all_cluster = Cluster(all_houses)
all_cluster_results = all_cluster.results()
print('Training History without clustering:')
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_12 (LSTM)              (None, 14, 128)           69120
#
#  lstm_13 (LSTM)              (None, 14, 32)            20608
#
#  lstm_14 (LSTM)              (None, 16)                3136
#
#  dense_4 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 92,881
# Trainable params: 92,881
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 26534/26534 [==============================] - 413s 16ms/step - loss: 0.3335 - root_mean_squared_error: 0.5775 - mean_absolute_error: 0.3158 - val_loss: 0.3216 - val_root_mean_squared_error: 0.5671 - val_mean_absolute_error: 0.3179
# Epoch 2/30
# 26534/26534 [==============================] - 411s 15ms/step - loss: 0.3115 - root_mean_squared_error: 0.5581 - mean_absolute_error: 0.3012 - val_loss: 0.3273 - val_root_mean_squared_error: 0.5721 - val_mean_absolute_error: 0.3157
# Epoch 3/30
# 26534/26534 [==============================] - 411s 15ms/step - loss: 0.3061 - root_mean_squared_error: 0.5532 - mean_absolute_error: 0.2988 - val_loss: 0.3561 - val_root_mean_squared_error: 0.5967 - val_mean_absolute_error: 0.3130
# Epoch 4/30
# 26534/26534 [==============================] - 411s 15ms/step - loss: 0.3048 - root_mean_squared_error: 0.5521 - mean_absolute_error: 0.2973 - val_loss: 0.3539 - val_root_mean_squared_error: 0.5949 - val_mean_absolute_error: 0.3183
# Epoch 5/30
# 26534/26534 [==============================] - 411s 15ms/step - loss: 0.3008 - root_mean_squared_error: 0.5484 - mean_absolute_error: 0.2962 - val_loss: 0.3284 - val_root_mean_squared_error: 0.5730 - val_mean_absolute_error: 0.3155
# Epoch 6/30
# 26534/26534 [==============================] - 411s 15ms/step - loss: 0.2981 - root_mean_squared_error: 0.5460 - mean_absolute_error: 0.2952 - val_loss: 0.3684 - val_root_mean_squared_error: 0.6070 - val_mean_absolute_error: 0.3162
# Epoch 7/30
# 26534/26534 [==============================] - 411s 15ms/step - loss: 0.2971 - root_mean_squared_error: 0.5451 - mean_absolute_error: 0.2950 - val_loss: 0.3586 - val_root_mean_squared_error: 0.5989 - val_mean_absolute_error: 0.3318
# Epoch 8/30
# 26534/26534 [==============================] - 411s 15ms/step - loss: 0.2948 - root_mean_squared_error: 0.5430 - mean_absolute_error: 0.2940 - val_loss: 0.3320 - val_root_mean_squared_error: 0.5762 - val_mean_absolute_error: 0.3153
# Epoch 9/30
# 26534/26534 [==============================] - 411s 15ms/step - loss: 0.2941 - root_mean_squared_error: 0.5423 - mean_absolute_error: 0.2939 - val_loss: 0.3503 - val_root_mean_squared_error: 0.5918 - val_mean_absolute_error: 0.3163
# Epoch 10/30
# 26534/26534 [==============================] - 411s 15ms/step - loss: 0.2935 - root_mean_squared_error: 0.5417 - mean_absolute_error: 0.2933 - val_loss: 0.3383 - val_root_mean_squared_error: 0.5816 - val_mean_absolute_error: 0.3172
# Epoch 11/30
# 26534/26534 [==============================] - 411s 15ms/step - loss: 0.2930 - root_mean_squared_error: 0.5413 - mean_absolute_error: 0.2931 - val_loss: 0.3474 - val_root_mean_squared_error: 0.5894 - val_mean_absolute_error: 0.3138
# Epoch 12/30
# 26534/26534 [==============================] - 411s 15ms/step - loss: 0.2917 - root_mean_squared_error: 0.5401 - mean_absolute_error: 0.2926 - val_loss: 0.3229 - val_root_mean_squared_error: 0.5683 - val_mean_absolute_error: 0.3150
# Epoch 13/30
# 26534/26534 [==============================] - 411s 15ms/step - loss: 0.3559 - root_mean_squared_error: 0.5966 - mean_absolute_error: 0.2922 - val_loss: 0.3484 - val_root_mean_squared_error: 0.5903 - val_mean_absolute_error: 0.3241
# Epoch 14/30
# 26534/26534 [==============================] - 411s 15ms/step - loss: 0.2904 - root_mean_squared_error: 0.5389 - mean_absolute_error: 0.2921 - val_loss: 0.3592 - val_root_mean_squared_error: 0.5993 - val_mean_absolute_error: 0.3176
# Epoch 15/30
# 26534/26534 [==============================] - 411s 15ms/step - loss: 0.3932 - root_mean_squared_error: 0.6271 - mean_absolute_error: 0.2920 - val_loss: 2.5058 - val_root_mean_squared_error: 1.5830 - val_mean_absolute_error: 0.3244
# Epoch 16/30
# 26534/26534 [==============================] - 412s 16ms/step - loss: 3.5893 - root_mean_squared_error: 1.8946 - mean_absolute_error: 0.3414 - val_loss: 1.3233 - val_root_mean_squared_error: 1.1504 - val_mean_absolute_error: 0.3688
# Epoch 17/30
# 26534/26534 [==============================] - 412s 16ms/step - loss: 0.7586 - root_mean_squared_error: 0.8710 - mean_absolute_error: 0.3433 - val_loss: 0.3667 - val_root_mean_squared_error: 0.6056 - val_mean_absolute_error: 0.3344
# Epoch 18/30
# 26534/26534 [==============================] - 411s 16ms/step - loss: 0.3646 - root_mean_squared_error: 0.6038 - mean_absolute_error: 0.3125 - val_loss: 0.3356 - val_root_mean_squared_error: 0.5793 - val_mean_absolute_error: 0.3140
# Epoch 19/30
# 26534/26534 [==============================] - 411s 15ms/step - loss: 0.2981 - root_mean_squared_error: 0.5459 - mean_absolute_error: 0.2966 - val_loss: 0.3597 - val_root_mean_squared_error: 0.5998 - val_mean_absolute_error: 0.3173
# Epoch 20/30
# 26534/26534 [==============================] - 412s 16ms/step - loss: 0.2915 - root_mean_squared_error: 0.5399 - mean_absolute_error: 0.2933 - val_loss: 0.3549 - val_root_mean_squared_error: 0.5957 - val_mean_absolute_error: 0.3278
# Epoch 21/30
# 26534/26534 [==============================] - 411s 16ms/step - loss: 0.3164 - root_mean_squared_error: 0.5625 - mean_absolute_error: 0.2965 - val_loss: 0.3415 - val_root_mean_squared_error: 0.5844 - val_mean_absolute_error: 0.3288
# Epoch 22/30
# 26534/26534 [==============================] - 411s 16ms/step - loss: 0.2999 - root_mean_squared_error: 0.5476 - mean_absolute_error: 0.2952 - val_loss: 0.4578 - val_root_mean_squared_error: 0.6766 - val_mean_absolute_error: 0.3223
# Epoch 23/30
# 26534/26534 [==============================] - 411s 16ms/step - loss: 0.2909 - root_mean_squared_error: 0.5394 - mean_absolute_error: 0.2926 - val_loss: 0.3399 - val_root_mean_squared_error: 0.5830 - val_mean_absolute_error: 0.3132
# Epoch 24/30
# 26534/26534 [==============================] - 411s 16ms/step - loss: 0.2885 - root_mean_squared_error: 0.5371 - mean_absolute_error: 0.2917 - val_loss: 0.3489 - val_root_mean_squared_error: 0.5907 - val_mean_absolute_error: 0.3102
# Epoch 25/30
# 26534/26534 [==============================] - 412s 16ms/step - loss: 5.0420 - root_mean_squared_error: 2.2454 - mean_absolute_error: 0.3041 - val_loss: 0.3537 - val_root_mean_squared_error: 0.5947 - val_mean_absolute_error: 0.3204
# Epoch 26/30
# 26534/26534 [==============================] - 412s 16ms/step - loss: 0.4659 - root_mean_squared_error: 0.6826 - mean_absolute_error: 0.2963 - val_loss: 0.4460 - val_root_mean_squared_error: 0.6678 - val_mean_absolute_error: 0.3204
# Epoch 27/30
# 26534/26534 [==============================] - 412s 16ms/step - loss: 0.3117 - root_mean_squared_error: 0.5583 - mean_absolute_error: 0.2955 - val_loss: 0.3343 - val_root_mean_squared_error: 0.5782 - val_mean_absolute_error: 0.3105
# Epoch 28/30
# 26534/26534 [==============================] - 412s 16ms/step - loss: 0.2907 - root_mean_squared_error: 0.5391 - mean_absolute_error: 0.2924 - val_loss: 0.3590 - val_root_mean_squared_error: 0.5992 - val_mean_absolute_error: 0.3265
# Epoch 29/30
# 26534/26534 [==============================] - 412s 16ms/step - loss: 0.2871 - root_mean_squared_error: 0.5358 - mean_absolute_error: 0.2910 - val_loss: 0.3823 - val_root_mean_squared_error: 0.6183 - val_mean_absolute_error: 0.3270
# Epoch 30/30
# 26534/26534 [==============================] - 412s 16ms/step - loss: 0.2862 - root_mean_squared_error: 0.5349 - mean_absolute_error: 0.2906 - val_loss: 0.3683 - val_root_mean_squared_error: 0.6069 - val_mean_absolute_error: 0.3169
# Training History without clustering:

# %%
# ### Save Scenario 2 models
# all_cluster.model.save('Models/Scenario2/all_cluster')

### Pickling Scenario 2 cluster and cluster result files
# all_cluster_file = open("Models/Scenario2/Objects/all_cluster.pickle", "wb")
# pickle.dump(all_cluster, all_cluster_file)
# all_cluster_file.close()

# all_cluster_results_file = open("Models/Scenario2/Objects/all_cluster_results.pickle", "wb")
# pickle.dump(all_cluster_results, all_cluster_results_file)
# all_cluster_results_file.close()

# %% [markdown]
# #### Predictions Graph functions

# %%
def x_axis_label_format(label):
    """
    Convert time label to the format of pandas line plot
    """
    label = pd.Timestamp(label)
    month = label.month_name()[:3]
    #if month == 'Jan':
    month += f'\n{label.year}'
    return month

def graph_predictions(cluster_specific_results, all_results):
    first_house = list(cluster_specific_results.keys())[0]
    df1 = cluster_specific_results[first_house][['timestamp','energy_predicted', 'energy_kWh']]
    df1['timestamp'] = pd.to_datetime(df1['timestamp'])
    df1 = df1.set_index('timestamp')
    df1['energy_predicted_without_clustering']= np.array(all_results[first_house][['energy_predicted']])
    df1.rename({'energy_predicted':'energy_predicted_with_clustering', 'energy_kWh':'real_energy'},axis = 1, inplace = True)
    ax = df1[::300].plot.line(figsize=(20,10))
    #ax.set_xticklabels(map(x_axis_label_format, df1[::int(len(df1)/8)+1].index))
    #import matplotlib.dates as mdates
    #myFmt = mdates.DateFormatter('%Y-%m')
    #ax.xaxis.set_major_formatter(myFmt)
    ax.set_title(f'Predictions for house {first_house}')

# %% [markdown]
# #### Predictions for Scenario 1 and Scenario 2

# %%
graph_predictions(zero_cluster_results, all_cluster_results)
#df1 = zero_cluster_results[1][['timestamp','energy_predicted', 'energy_kWh']].set_index('timestamp')
#df1['energy_predicted_without_clustering']= np.array(all_cluster_results[1][['energy_predicted']])
# Out:
# <ipython-input-31-9643f5cc2f5c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['timestamp'] = pd.to_datetime(df1['timestamp'])

# %%
graph_predictions(one_cluster_results, all_cluster_results)
# Out:
# <ipython-input-31-9643f5cc2f5c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['timestamp'] = pd.to_datetime(df1['timestamp'])

# %%
graph_predictions(two_cluster_results, all_cluster_results)
# Out:
# <ipython-input-31-9643f5cc2f5c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['timestamp'] = pd.to_datetime(df1['timestamp'])

# %%
graph_predictions(three_cluster_results, all_cluster_results)
# Out:
# <ipython-input-31-9643f5cc2f5c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['timestamp'] = pd.to_datetime(df1['timestamp'])

# %% [markdown]
# ### Function to create tables

# %%
def create_metrics(scenario_results, val=False):
    if val == False:
        rmse = 'root_mean_squared_error'
        mae = 'mean_absolute_error'
    else:
        rmse = 'val_root_mean_squared_error'
        mae = 'val_mean_absolute_error'
    scenario_rmse = list(map(lambda x: x.history.history[rmse],scenario_results))
    scenario_mae = list(map(lambda x: x.history.history[mae],scenario_results))
    scenario_rmse = np.array(scenario_rmse).reshape(-1,)
    scenario_mae = np.array(scenario_mae).reshape(-1,)
    return [np.min(scenario_rmse),np.max(scenario_rmse),np.mean(scenario_rmse),np.min(scenario_mae),np.max(scenario_mae),np.mean(scenario_mae)]

# %% [markdown]
# #### Scenario 1 and Scenario 2 Metric Tables

# %%
scenario_1_results = [zero_cluster, one_cluster, two_cluster, three_cluster]
scenario_1_metrics = create_metrics(scenario_1_results)
scenario_1_validation_metrics = create_metrics(scenario_1_results, val= True)
scenario_1_metrics
# Out:
# [0.3679359257221222,
#  4.705197811126709,
#  0.6731053752203783,
#  0.20195959508419037,
#  0.7344261407852173,
#  0.36370304599404335]

# %%
scenario_2_results = [all_cluster]
scenario_2_metrics = create_metrics(scenario_2_results)
scenario_2_validation_metrics = create_metrics(scenario_2_results, val= True)
scenario_2_metrics
# Out:
# [0.5349379181861877,
#  2.2454309463500977,
#  0.6696454008420308,
#  0.2906368672847748,
#  0.34334608912467957,
#  0.2991941452026367]

# %% [markdown]
# #### Scenario 3 and 4

# %%
### Removing smart device features
House.cols = ['energy_kWh']
#House.cols

# %%
scenario_3_zero_cluster = Cluster(zero_houses)
scenario_3_zero_cluster_results = scenario_3_zero_cluster.results()
print('Training History for Cluster 0:')
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_15 (LSTM)              (None, 14, 128)           66560
#
#  lstm_16 (LSTM)              (None, 14, 32)            20608
#
#  lstm_17 (LSTM)              (None, 16)                3136
#
#  dense_5 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 90,321
# Trainable params: 90,321
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 7680/7680 [==============================] - 121s 16ms/step - loss: 0.4823 - root_mean_squared_error: 0.6945 - mean_absolute_error: 0.4274 - val_loss: 0.6235 - val_root_mean_squared_error: 0.7896 - val_mean_absolute_error: 0.4539
# Epoch 2/30
# 7680/7680 [==============================] - 119s 16ms/step - loss: 0.4489 - root_mean_squared_error: 0.6700 - mean_absolute_error: 0.4025 - val_loss: 0.6375 - val_root_mean_squared_error: 0.7985 - val_mean_absolute_error: 0.4492
# Epoch 3/30
# 7680/7680 [==============================] - 119s 16ms/step - loss: 0.4422 - root_mean_squared_error: 0.6650 - mean_absolute_error: 0.3967 - val_loss: 0.6195 - val_root_mean_squared_error: 0.7871 - val_mean_absolute_error: 0.4557
# Epoch 4/30
# 7680/7680 [==============================] - 119s 16ms/step - loss: 0.4367 - root_mean_squared_error: 0.6609 - mean_absolute_error: 0.3932 - val_loss: 0.6256 - val_root_mean_squared_error: 0.7909 - val_mean_absolute_error: 0.4538
# Epoch 5/30
# 7680/7680 [==============================] - 119s 16ms/step - loss: 0.4336 - root_mean_squared_error: 0.6585 - mean_absolute_error: 0.3909 - val_loss: 0.6143 - val_root_mean_squared_error: 0.7838 - val_mean_absolute_error: 0.4417
# Epoch 6/30
# 7680/7680 [==============================] - 119s 15ms/step - loss: 0.4304 - root_mean_squared_error: 0.6560 - mean_absolute_error: 0.3889 - val_loss: 0.5988 - val_root_mean_squared_error: 0.7738 - val_mean_absolute_error: 0.4443
# Epoch 7/30
# 7680/7680 [==============================] - 119s 16ms/step - loss: 0.4274 - root_mean_squared_error: 0.6537 - mean_absolute_error: 0.3879 - val_loss: 0.6257 - val_root_mean_squared_error: 0.7910 - val_mean_absolute_error: 0.4646
# Epoch 8/30
# 7680/7680 [==============================] - 119s 16ms/step - loss: 0.4273 - root_mean_squared_error: 0.6537 - mean_absolute_error: 0.3872 - val_loss: 0.6149 - val_root_mean_squared_error: 0.7842 - val_mean_absolute_error: 0.4717
# Epoch 9/30
# 7680/7680 [==============================] - 119s 15ms/step - loss: 0.4245 - root_mean_squared_error: 0.6515 - mean_absolute_error: 0.3857 - val_loss: 0.6233 - val_root_mean_squared_error: 0.7895 - val_mean_absolute_error: 0.4508
# Epoch 10/30
# 7680/7680 [==============================] - 119s 16ms/step - loss: 0.4232 - root_mean_squared_error: 0.6505 - mean_absolute_error: 0.3853 - val_loss: 0.6337 - val_root_mean_squared_error: 0.7960 - val_mean_absolute_error: 0.4693
# Epoch 11/30
# 7680/7680 [==============================] - 119s 16ms/step - loss: 0.4222 - root_mean_squared_error: 0.6498 - mean_absolute_error: 0.3847 - val_loss: 0.6240 - val_root_mean_squared_error: 0.7899 - val_mean_absolute_error: 0.4525
# Epoch 12/30
# 7680/7680 [==============================] - 119s 16ms/step - loss: 0.4200 - root_mean_squared_error: 0.6480 - mean_absolute_error: 0.3839 - val_loss: 0.6205 - val_root_mean_squared_error: 0.7877 - val_mean_absolute_error: 0.4457
# Epoch 13/30
# 7680/7680 [==============================] - 119s 16ms/step - loss: 0.4183 - root_mean_squared_error: 0.6468 - mean_absolute_error: 0.3828 - val_loss: 0.6344 - val_root_mean_squared_error: 0.7965 - val_mean_absolute_error: 0.4503
# Epoch 14/30
# 7680/7680 [==============================] - 119s 16ms/step - loss: 0.4172 - root_mean_squared_error: 0.6459 - mean_absolute_error: 0.3828 - val_loss: 0.6633 - val_root_mean_squared_error: 0.8144 - val_mean_absolute_error: 0.4558
# Epoch 15/30
# 7680/7680 [==============================] - 119s 16ms/step - loss: 0.4163 - root_mean_squared_error: 0.6452 - mean_absolute_error: 0.3818 - val_loss: 0.6488 - val_root_mean_squared_error: 0.8055 - val_mean_absolute_error: 0.4551
# Epoch 16/30
# 7680/7680 [==============================] - 119s 15ms/step - loss: 0.4145 - root_mean_squared_error: 0.6438 - mean_absolute_error: 0.3813 - val_loss: 0.6354 - val_root_mean_squared_error: 0.7971 - val_mean_absolute_error: 0.4441
# Epoch 17/30
# 7680/7680 [==============================] - 119s 16ms/step - loss: 0.4133 - root_mean_squared_error: 0.6429 - mean_absolute_error: 0.3809 - val_loss: 0.6370 - val_root_mean_squared_error: 0.7981 - val_mean_absolute_error: 0.4512
# Epoch 18/30
# 7680/7680 [==============================] - 119s 16ms/step - loss: 0.4130 - root_mean_squared_error: 0.6427 - mean_absolute_error: 0.3803 - val_loss: 0.6486 - val_root_mean_squared_error: 0.8054 - val_mean_absolute_error: 0.4529
# Epoch 19/30
# 7680/7680 [==============================] - 119s 16ms/step - loss: 0.4116 - root_mean_squared_error: 0.6415 - mean_absolute_error: 0.3798 - val_loss: 0.6459 - val_root_mean_squared_error: 0.8037 - val_mean_absolute_error: 0.4525
# Epoch 20/30
# 7680/7680 [==============================] - 119s 16ms/step - loss: 0.4089 - root_mean_squared_error: 0.6394 - mean_absolute_error: 0.3793 - val_loss: 0.6450 - val_root_mean_squared_error: 0.8031 - val_mean_absolute_error: 0.4541
# Epoch 21/30
# 7680/7680 [==============================] - 119s 16ms/step - loss: 0.4089 - root_mean_squared_error: 0.6394 - mean_absolute_error: 0.3792 - val_loss: 0.6455 - val_root_mean_squared_error: 0.8034 - val_mean_absolute_error: 0.4494
# Epoch 22/30
# 7680/7680 [==============================] - 119s 16ms/step - loss: 0.4074 - root_mean_squared_error: 0.6383 - mean_absolute_error: 0.3786 - val_loss: 0.6249 - val_root_mean_squared_error: 0.7905 - val_mean_absolute_error: 0.4545
# Epoch 23/30
# 7680/7680 [==============================] - 119s 16ms/step - loss: 0.4075 - root_mean_squared_error: 0.6383 - mean_absolute_error: 0.3785 - val_loss: 0.6269 - val_root_mean_squared_error: 0.7918 - val_mean_absolute_error: 0.4534
# Epoch 24/30
# 7680/7680 [==============================] - 119s 16ms/step - loss: 0.4029 - root_mean_squared_error: 0.6347 - mean_absolute_error: 0.3772 - val_loss: 0.6516 - val_root_mean_squared_error: 0.8072 - val_mean_absolute_error: 0.4566
# Epoch 25/30
# 7680/7680 [==============================] - 119s 16ms/step - loss: 0.4024 - root_mean_squared_error: 0.6344 - mean_absolute_error: 0.3765 - val_loss: 0.6205 - val_root_mean_squared_error: 0.7877 - val_mean_absolute_error: 0.4561
# Epoch 26/30
# 7680/7680 [==============================] - 119s 16ms/step - loss: 0.4020 - root_mean_squared_error: 0.6341 - mean_absolute_error: 0.3773 - val_loss: 0.6421 - val_root_mean_squared_error: 0.8013 - val_mean_absolute_error: 0.4513
# Epoch 27/30
# 7680/7680 [==============================] - 119s 15ms/step - loss: 0.4008 - root_mean_squared_error: 0.6331 - mean_absolute_error: 0.3763 - val_loss: 0.6431 - val_root_mean_squared_error: 0.8019 - val_mean_absolute_error: 0.4546
# Epoch 28/30
# 7680/7680 [==============================] - 119s 16ms/step - loss: 0.4008 - root_mean_squared_error: 0.6331 - mean_absolute_error: 0.3760 - val_loss: 0.6536 - val_root_mean_squared_error: 0.8085 - val_mean_absolute_error: 0.4625
# Epoch 29/30
# 7680/7680 [==============================] - 119s 16ms/step - loss: 0.3965 - root_mean_squared_error: 0.6297 - mean_absolute_error: 0.3747 - val_loss: 0.6397 - val_root_mean_squared_error: 0.7998 - val_mean_absolute_error: 0.4547
# Epoch 30/30
# 7680/7680 [==============================] - 119s 16ms/step - loss: 0.3955 - root_mean_squared_error: 0.6289 - mean_absolute_error: 0.3748 - val_loss: 0.6619 - val_root_mean_squared_error: 0.8135 - val_mean_absolute_error: 0.4601
# Training History for Cluster 0:

# %%
scenario_3_one_cluster = Cluster(one_houses)
scenario_3_one_cluster_results = scenario_3_one_cluster.results()
print('Training History for Cluster 1:')
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_18 (LSTM)              (None, 14, 128)           66560
#
#  lstm_19 (LSTM)              (None, 14, 32)            20608
#
#  lstm_20 (LSTM)              (None, 16)                3136
#
#  dense_6 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 90,321
# Trainable params: 90,321
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 915/915 [==============================] - 17s 16ms/step - loss: 1.4794 - root_mean_squared_error: 1.2163 - mean_absolute_error: 0.7024 - val_loss: 1.6574 - val_root_mean_squared_error: 1.2874 - val_mean_absolute_error: 0.5285
# Epoch 2/30
# 915/915 [==============================] - 14s 16ms/step - loss: 0.9787 - root_mean_squared_error: 0.9893 - mean_absolute_error: 0.5667 - val_loss: 1.4840 - val_root_mean_squared_error: 1.2182 - val_mean_absolute_error: 0.6090
# Epoch 3/30
# 915/915 [==============================] - 14s 16ms/step - loss: 0.9135 - root_mean_squared_error: 0.9558 - mean_absolute_error: 0.5420 - val_loss: 1.4223 - val_root_mean_squared_error: 1.1926 - val_mean_absolute_error: 0.5132
# Epoch 4/30
# 915/915 [==============================] - 14s 16ms/step - loss: 0.8913 - root_mean_squared_error: 0.9441 - mean_absolute_error: 0.5322 - val_loss: 1.2872 - val_root_mean_squared_error: 1.1346 - val_mean_absolute_error: 0.5582
# Epoch 5/30
# 915/915 [==============================] - 14s 16ms/step - loss: 0.8582 - root_mean_squared_error: 0.9264 - mean_absolute_error: 0.5262 - val_loss: 1.1756 - val_root_mean_squared_error: 1.0842 - val_mean_absolute_error: 0.5730
# Epoch 6/30
# 915/915 [==============================] - 14s 16ms/step - loss: 0.8377 - root_mean_squared_error: 0.9152 - mean_absolute_error: 0.5186 - val_loss: 1.3030 - val_root_mean_squared_error: 1.1415 - val_mean_absolute_error: 0.5124
# Epoch 7/30
# 915/915 [==============================] - 14s 16ms/step - loss: 0.8116 - root_mean_squared_error: 0.9009 - mean_absolute_error: 0.5177 - val_loss: 1.2705 - val_root_mean_squared_error: 1.1272 - val_mean_absolute_error: 0.6676
# Epoch 8/30
# 915/915 [==============================] - 14s 16ms/step - loss: 0.8138 - root_mean_squared_error: 0.9021 - mean_absolute_error: 0.5119 - val_loss: 1.3520 - val_root_mean_squared_error: 1.1628 - val_mean_absolute_error: 0.5437
# Epoch 9/30
# 915/915 [==============================] - 14s 16ms/step - loss: 0.8130 - root_mean_squared_error: 0.9017 - mean_absolute_error: 0.5123 - val_loss: 1.4607 - val_root_mean_squared_error: 1.2086 - val_mean_absolute_error: 0.5490
# Epoch 10/30
# 915/915 [==============================] - 14s 16ms/step - loss: 0.8021 - root_mean_squared_error: 0.8956 - mean_absolute_error: 0.5095 - val_loss: 1.0985 - val_root_mean_squared_error: 1.0481 - val_mean_absolute_error: 0.5010
# Epoch 11/30
# 915/915 [==============================] - 14s 16ms/step - loss: 0.7767 - root_mean_squared_error: 0.8813 - mean_absolute_error: 0.4996 - val_loss: 1.7487 - val_root_mean_squared_error: 1.3224 - val_mean_absolute_error: 0.6087
# Epoch 12/30
# 915/915 [==============================] - 14s 16ms/step - loss: 0.7880 - root_mean_squared_error: 0.8877 - mean_absolute_error: 0.5032 - val_loss: 1.2299 - val_root_mean_squared_error: 1.1090 - val_mean_absolute_error: 0.6117
# Epoch 13/30
# 915/915 [==============================] - 14s 16ms/step - loss: 0.7532 - root_mean_squared_error: 0.8679 - mean_absolute_error: 0.4915 - val_loss: 1.0615 - val_root_mean_squared_error: 1.0303 - val_mean_absolute_error: 0.5070
# Epoch 14/30
# 915/915 [==============================] - 14s 16ms/step - loss: 0.7917 - root_mean_squared_error: 0.8898 - mean_absolute_error: 0.4994 - val_loss: 1.1495 - val_root_mean_squared_error: 1.0721 - val_mean_absolute_error: 0.5006
# Epoch 15/30
# 915/915 [==============================] - 14s 16ms/step - loss: 0.7645 - root_mean_squared_error: 0.8743 - mean_absolute_error: 0.4928 - val_loss: 1.1995 - val_root_mean_squared_error: 1.0952 - val_mean_absolute_error: 0.5495
# Epoch 16/30
# 915/915 [==============================] - 14s 16ms/step - loss: 0.7505 - root_mean_squared_error: 0.8663 - mean_absolute_error: 0.4869 - val_loss: 1.1063 - val_root_mean_squared_error: 1.0518 - val_mean_absolute_error: 0.5706
# Epoch 17/30
# 915/915 [==============================] - 14s 16ms/step - loss: 0.7463 - root_mean_squared_error: 0.8639 - mean_absolute_error: 0.4855 - val_loss: 1.1044 - val_root_mean_squared_error: 1.0509 - val_mean_absolute_error: 0.5226
# Epoch 18/30
# 915/915 [==============================] - 14s 16ms/step - loss: 0.7338 - root_mean_squared_error: 0.8566 - mean_absolute_error: 0.4837 - val_loss: 1.2853 - val_root_mean_squared_error: 1.1337 - val_mean_absolute_error: 0.5610
# Epoch 19/30
# 915/915 [==============================] - 14s 16ms/step - loss: 0.7376 - root_mean_squared_error: 0.8588 - mean_absolute_error: 0.4828 - val_loss: 1.1904 - val_root_mean_squared_error: 1.0910 - val_mean_absolute_error: 0.5494
# Epoch 20/30
# 915/915 [==============================] - 14s 16ms/step - loss: 0.7308 - root_mean_squared_error: 0.8549 - mean_absolute_error: 0.4846 - val_loss: 1.1515 - val_root_mean_squared_error: 1.0731 - val_mean_absolute_error: 0.5486
# Epoch 21/30
# 915/915 [==============================] - 14s 16ms/step - loss: 0.7120 - root_mean_squared_error: 0.8438 - mean_absolute_error: 0.4796 - val_loss: 1.1081 - val_root_mean_squared_error: 1.0527 - val_mean_absolute_error: 0.5108
# Epoch 22/30
# 915/915 [==============================] - 14s 16ms/step - loss: 0.7181 - root_mean_squared_error: 0.8474 - mean_absolute_error: 0.4799 - val_loss: 1.0640 - val_root_mean_squared_error: 1.0315 - val_mean_absolute_error: 0.5052
# Epoch 23/30
# 915/915 [==============================] - 14s 16ms/step - loss: 0.7030 - root_mean_squared_error: 0.8384 - mean_absolute_error: 0.4754 - val_loss: 1.1360 - val_root_mean_squared_error: 1.0658 - val_mean_absolute_error: 0.5337
# Epoch 24/30
# 915/915 [==============================] - 14s 16ms/step - loss: 0.7179 - root_mean_squared_error: 0.8473 - mean_absolute_error: 0.4775 - val_loss: 1.0771 - val_root_mean_squared_error: 1.0378 - val_mean_absolute_error: 0.4992
# Epoch 25/30
# 915/915 [==============================] - 14s 16ms/step - loss: 0.7064 - root_mean_squared_error: 0.8405 - mean_absolute_error: 0.4747 - val_loss: 1.0366 - val_root_mean_squared_error: 1.0181 - val_mean_absolute_error: 0.5121
# Epoch 26/30
# 915/915 [==============================] - 14s 16ms/step - loss: 0.7085 - root_mean_squared_error: 0.8417 - mean_absolute_error: 0.4743 - val_loss: 1.0648 - val_root_mean_squared_error: 1.0319 - val_mean_absolute_error: 0.4939
# Epoch 27/30
# 915/915 [==============================] - 14s 16ms/step - loss: 0.6950 - root_mean_squared_error: 0.8337 - mean_absolute_error: 0.4718 - val_loss: 1.0874 - val_root_mean_squared_error: 1.0428 - val_mean_absolute_error: 0.5023
# Epoch 28/30
# 915/915 [==============================] - 14s 16ms/step - loss: 0.6957 - root_mean_squared_error: 0.8341 - mean_absolute_error: 0.4710 - val_loss: 1.0948 - val_root_mean_squared_error: 1.0463 - val_mean_absolute_error: 0.5152
# Epoch 29/30
# 915/915 [==============================] - 14s 16ms/step - loss: 0.6917 - root_mean_squared_error: 0.8317 - mean_absolute_error: 0.4719 - val_loss: 1.0982 - val_root_mean_squared_error: 1.0480 - val_mean_absolute_error: 0.5229
# Epoch 30/30
# 915/915 [==============================] - 14s 16ms/step - loss: 0.6927 - root_mean_squared_error: 0.8323 - mean_absolute_error: 0.4708 - val_loss: 1.0523 - val_root_mean_squared_error: 1.0258 - val_mean_absolute_error: 0.5223
# Training History for Cluster 1:

# %%
scenario_3_two_cluster = Cluster(two_houses)
scenario_3_two_cluster_results = scenario_3_two_cluster.results()
print('Training History for Cluster 2:')
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_21 (LSTM)              (None, 14, 128)           66560
#
#  lstm_22 (LSTM)              (None, 14, 32)            20608
#
#  lstm_23 (LSTM)              (None, 16)                3136
#
#  dense_7 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 90,321
# Trainable params: 90,321
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 15194/15194 [==============================] - 237s 15ms/step - loss: 0.1540 - root_mean_squared_error: 0.3924 - mean_absolute_error: 0.2221 - val_loss: 0.2054 - val_root_mean_squared_error: 0.4532 - val_mean_absolute_error: 0.2415
# Epoch 2/30
# 15194/15194 [==============================] - 235s 15ms/step - loss: 0.1454 - root_mean_squared_error: 0.3814 - mean_absolute_error: 0.2114 - val_loss: 0.2025 - val_root_mean_squared_error: 0.4500 - val_mean_absolute_error: 0.2609
# Epoch 3/30
# 15194/15194 [==============================] - 235s 15ms/step - loss: 0.1444 - root_mean_squared_error: 0.3800 - mean_absolute_error: 0.2098 - val_loss: 0.2023 - val_root_mean_squared_error: 0.4498 - val_mean_absolute_error: 0.2494
# Epoch 4/30
# 15194/15194 [==============================] - 235s 15ms/step - loss: 0.1436 - root_mean_squared_error: 0.3790 - mean_absolute_error: 0.2088 - val_loss: 0.2069 - val_root_mean_squared_error: 0.4549 - val_mean_absolute_error: 0.2405
# Epoch 5/30
# 15194/15194 [==============================] - 235s 15ms/step - loss: 0.1428 - root_mean_squared_error: 0.3779 - mean_absolute_error: 0.2080 - val_loss: 0.2027 - val_root_mean_squared_error: 0.4502 - val_mean_absolute_error: 0.2507
# Epoch 6/30
# 15194/15194 [==============================] - 235s 15ms/step - loss: 0.1422 - root_mean_squared_error: 0.3770 - mean_absolute_error: 0.2072 - val_loss: 0.2047 - val_root_mean_squared_error: 0.4524 - val_mean_absolute_error: 0.2481
# Epoch 7/30
# 15194/15194 [==============================] - 235s 15ms/step - loss: 0.1415 - root_mean_squared_error: 0.3762 - mean_absolute_error: 0.2067 - val_loss: 0.2026 - val_root_mean_squared_error: 0.4501 - val_mean_absolute_error: 0.2446
# Epoch 8/30
# 15194/15194 [==============================] - 235s 15ms/step - loss: 0.1411 - root_mean_squared_error: 0.3757 - mean_absolute_error: 0.2063 - val_loss: 0.2036 - val_root_mean_squared_error: 0.4512 - val_mean_absolute_error: 0.2480
# Epoch 9/30
# 15194/15194 [==============================] - 235s 15ms/step - loss: 0.1408 - root_mean_squared_error: 0.3752 - mean_absolute_error: 0.2061 - val_loss: 0.2023 - val_root_mean_squared_error: 0.4498 - val_mean_absolute_error: 0.2597
# Epoch 10/30
# 15194/15194 [==============================] - 235s 15ms/step - loss: 0.1404 - root_mean_squared_error: 0.3747 - mean_absolute_error: 0.2058 - val_loss: 0.2025 - val_root_mean_squared_error: 0.4500 - val_mean_absolute_error: 0.2579
# Epoch 11/30
# 15194/15194 [==============================] - 235s 15ms/step - loss: 0.1403 - root_mean_squared_error: 0.3746 - mean_absolute_error: 0.2055 - val_loss: 0.2020 - val_root_mean_squared_error: 0.4495 - val_mean_absolute_error: 0.2459
# Epoch 12/30
# 15194/15194 [==============================] - 235s 15ms/step - loss: 0.1398 - root_mean_squared_error: 0.3739 - mean_absolute_error: 0.2052 - val_loss: 0.2024 - val_root_mean_squared_error: 0.4499 - val_mean_absolute_error: 0.2506
# Epoch 13/30
# 15194/15194 [==============================] - 235s 15ms/step - loss: 0.1395 - root_mean_squared_error: 0.3735 - mean_absolute_error: 0.2052 - val_loss: 0.2021 - val_root_mean_squared_error: 0.4495 - val_mean_absolute_error: 0.2481
# Epoch 14/30
# 15194/15194 [==============================] - 235s 15ms/step - loss: 0.1394 - root_mean_squared_error: 0.3733 - mean_absolute_error: 0.2048 - val_loss: 0.2022 - val_root_mean_squared_error: 0.4497 - val_mean_absolute_error: 0.2497
# Epoch 15/30
# 15194/15194 [==============================] - 235s 15ms/step - loss: 0.1390 - root_mean_squared_error: 0.3728 - mean_absolute_error: 0.2045 - val_loss: 0.2061 - val_root_mean_squared_error: 0.4539 - val_mean_absolute_error: 0.2432
# Epoch 16/30
# 15194/15194 [==============================] - 235s 15ms/step - loss: 0.1388 - root_mean_squared_error: 0.3725 - mean_absolute_error: 0.2044 - val_loss: 0.2028 - val_root_mean_squared_error: 0.4504 - val_mean_absolute_error: 0.2477
# Epoch 17/30
# 15194/15194 [==============================] - 235s 15ms/step - loss: 0.1384 - root_mean_squared_error: 0.3720 - mean_absolute_error: 0.2042 - val_loss: 0.2029 - val_root_mean_squared_error: 0.4504 - val_mean_absolute_error: 0.2463
# Epoch 18/30
# 15194/15194 [==============================] - 235s 15ms/step - loss: 0.1381 - root_mean_squared_error: 0.3716 - mean_absolute_error: 0.2039 - val_loss: 0.2049 - val_root_mean_squared_error: 0.4527 - val_mean_absolute_error: 0.2470
# Epoch 19/30
# 15194/15194 [==============================] - 235s 15ms/step - loss: 0.1378 - root_mean_squared_error: 0.3713 - mean_absolute_error: 0.2038 - val_loss: 0.2069 - val_root_mean_squared_error: 0.4549 - val_mean_absolute_error: 0.2461
# Epoch 20/30
# 15194/15194 [==============================] - 235s 15ms/step - loss: 0.1375 - root_mean_squared_error: 0.3708 - mean_absolute_error: 0.2036 - val_loss: 0.2056 - val_root_mean_squared_error: 0.4534 - val_mean_absolute_error: 0.2545
# Epoch 21/30
# 15194/15194 [==============================] - 235s 15ms/step - loss: 0.1381 - root_mean_squared_error: 0.3716 - mean_absolute_error: 0.2035 - val_loss: 0.2041 - val_root_mean_squared_error: 0.4518 - val_mean_absolute_error: 0.2498
# Epoch 22/30
# 15194/15194 [==============================] - 235s 15ms/step - loss: 0.1372 - root_mean_squared_error: 0.3704 - mean_absolute_error: 0.2035 - val_loss: 0.2037 - val_root_mean_squared_error: 0.4514 - val_mean_absolute_error: 0.2481
# Epoch 23/30
# 15194/15194 [==============================] - 235s 15ms/step - loss: 0.1369 - root_mean_squared_error: 0.3700 - mean_absolute_error: 0.2031 - val_loss: 0.2046 - val_root_mean_squared_error: 0.4523 - val_mean_absolute_error: 0.2503
# Epoch 24/30
# 15194/15194 [==============================] - 235s 15ms/step - loss: 0.1366 - root_mean_squared_error: 0.3697 - mean_absolute_error: 0.2030 - val_loss: 0.2063 - val_root_mean_squared_error: 0.4542 - val_mean_absolute_error: 0.2480
# Epoch 25/30
# 15194/15194 [==============================] - 235s 15ms/step - loss: 0.1364 - root_mean_squared_error: 0.3693 - mean_absolute_error: 0.2028 - val_loss: 0.2073 - val_root_mean_squared_error: 0.4553 - val_mean_absolute_error: 0.2461
# Epoch 26/30
# 15194/15194 [==============================] - 235s 15ms/step - loss: 0.1593 - root_mean_squared_error: 0.3991 - mean_absolute_error: 0.2048 - val_loss: 0.2084 - val_root_mean_squared_error: 0.4565 - val_mean_absolute_error: 0.2486
# Epoch 27/30
# 15194/15194 [==============================] - 235s 15ms/step - loss: 0.1414 - root_mean_squared_error: 0.3760 - mean_absolute_error: 0.2042 - val_loss: 0.2068 - val_root_mean_squared_error: 0.4547 - val_mean_absolute_error: 0.2505
# Epoch 28/30
# 15194/15194 [==============================] - 235s 15ms/step - loss: 0.1383 - root_mean_squared_error: 0.3718 - mean_absolute_error: 0.2034 - val_loss: 0.2040 - val_root_mean_squared_error: 0.4517 - val_mean_absolute_error: 0.2495
# Epoch 29/30
# 15194/15194 [==============================] - 235s 15ms/step - loss: 0.1363 - root_mean_squared_error: 0.3691 - mean_absolute_error: 0.2029 - val_loss: 0.2071 - val_root_mean_squared_error: 0.4550 - val_mean_absolute_error: 0.2468
# Epoch 30/30
# 15194/15194 [==============================] - 235s 15ms/step - loss: 0.1362 - root_mean_squared_error: 0.3691 - mean_absolute_error: 0.2028 - val_loss: 0.2064 - val_root_mean_squared_error: 0.4543 - val_mean_absolute_error: 0.2481
# Training History for Cluster 2:

# %%
scenario_3_three_cluster = Cluster(three_houses)
scenario_3_three_cluster_results = scenario_3_three_cluster.results()
print('Training History for Cluster 3:')
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_24 (LSTM)              (None, 14, 128)           66560
#
#  lstm_25 (LSTM)              (None, 14, 32)            20608
#
#  lstm_26 (LSTM)              (None, 16)                3136
#
#  dense_8 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 90,321
# Trainable params: 90,321
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 2745/2745 [==============================] - 45s 16ms/step - loss: 0.4069 - root_mean_squared_error: 0.6379 - mean_absolute_error: 0.4185 - val_loss: 0.3994 - val_root_mean_squared_error: 0.6319 - val_mean_absolute_error: 0.4249
# Epoch 2/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.3604 - root_mean_squared_error: 0.6003 - mean_absolute_error: 0.3831 - val_loss: 0.4142 - val_root_mean_squared_error: 0.6436 - val_mean_absolute_error: 0.3666
# Epoch 3/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.3522 - root_mean_squared_error: 0.5934 - mean_absolute_error: 0.3767 - val_loss: 0.4012 - val_root_mean_squared_error: 0.6334 - val_mean_absolute_error: 0.3582
# Epoch 4/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.3462 - root_mean_squared_error: 0.5884 - mean_absolute_error: 0.3716 - val_loss: 0.4121 - val_root_mean_squared_error: 0.6420 - val_mean_absolute_error: 0.3931
# Epoch 5/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.3409 - root_mean_squared_error: 0.5839 - mean_absolute_error: 0.3665 - val_loss: 0.4196 - val_root_mean_squared_error: 0.6477 - val_mean_absolute_error: 0.3598
# Epoch 6/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.3364 - root_mean_squared_error: 0.5800 - mean_absolute_error: 0.3629 - val_loss: 0.3788 - val_root_mean_squared_error: 0.6155 - val_mean_absolute_error: 0.3658
# Epoch 7/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.3319 - root_mean_squared_error: 0.5761 - mean_absolute_error: 0.3584 - val_loss: 0.3993 - val_root_mean_squared_error: 0.6319 - val_mean_absolute_error: 0.3893
# Epoch 8/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.3295 - root_mean_squared_error: 0.5740 - mean_absolute_error: 0.3554 - val_loss: 0.3859 - val_root_mean_squared_error: 0.6212 - val_mean_absolute_error: 0.3919
# Epoch 9/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.3252 - root_mean_squared_error: 0.5702 - mean_absolute_error: 0.3530 - val_loss: 0.4016 - val_root_mean_squared_error: 0.6337 - val_mean_absolute_error: 0.3979
# Epoch 10/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.3222 - root_mean_squared_error: 0.5676 - mean_absolute_error: 0.3499 - val_loss: 0.4040 - val_root_mean_squared_error: 0.6356 - val_mean_absolute_error: 0.3770
# Epoch 11/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.3195 - root_mean_squared_error: 0.5653 - mean_absolute_error: 0.3469 - val_loss: 0.3898 - val_root_mean_squared_error: 0.6244 - val_mean_absolute_error: 0.3826
# Epoch 12/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.3164 - root_mean_squared_error: 0.5625 - mean_absolute_error: 0.3446 - val_loss: 0.3997 - val_root_mean_squared_error: 0.6322 - val_mean_absolute_error: 0.3875
# Epoch 13/30
# 2745/2745 [==============================] - 43s 15ms/step - loss: 0.3152 - root_mean_squared_error: 0.5614 - mean_absolute_error: 0.3430 - val_loss: 0.4008 - val_root_mean_squared_error: 0.6331 - val_mean_absolute_error: 0.3837
# Epoch 14/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.3124 - root_mean_squared_error: 0.5589 - mean_absolute_error: 0.3421 - val_loss: 0.3842 - val_root_mean_squared_error: 0.6198 - val_mean_absolute_error: 0.3811
# Epoch 15/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.3109 - root_mean_squared_error: 0.5576 - mean_absolute_error: 0.3399 - val_loss: 0.3924 - val_root_mean_squared_error: 0.6264 - val_mean_absolute_error: 0.3982
# Epoch 16/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.3093 - root_mean_squared_error: 0.5562 - mean_absolute_error: 0.3386 - val_loss: 0.3939 - val_root_mean_squared_error: 0.6276 - val_mean_absolute_error: 0.4072
# Epoch 17/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.3073 - root_mean_squared_error: 0.5543 - mean_absolute_error: 0.3373 - val_loss: 0.3822 - val_root_mean_squared_error: 0.6182 - val_mean_absolute_error: 0.3660
# Epoch 18/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.3054 - root_mean_squared_error: 0.5526 - mean_absolute_error: 0.3358 - val_loss: 0.3905 - val_root_mean_squared_error: 0.6249 - val_mean_absolute_error: 0.3714
# Epoch 19/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.3046 - root_mean_squared_error: 0.5519 - mean_absolute_error: 0.3347 - val_loss: 0.4141 - val_root_mean_squared_error: 0.6435 - val_mean_absolute_error: 0.3843
# Epoch 20/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.3027 - root_mean_squared_error: 0.5502 - mean_absolute_error: 0.3339 - val_loss: 0.3880 - val_root_mean_squared_error: 0.6229 - val_mean_absolute_error: 0.3734
# Epoch 21/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.3006 - root_mean_squared_error: 0.5483 - mean_absolute_error: 0.3325 - val_loss: 0.3920 - val_root_mean_squared_error: 0.6261 - val_mean_absolute_error: 0.3982
# Epoch 22/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.2994 - root_mean_squared_error: 0.5472 - mean_absolute_error: 0.3319 - val_loss: 0.4068 - val_root_mean_squared_error: 0.6378 - val_mean_absolute_error: 0.3800
# Epoch 23/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.2978 - root_mean_squared_error: 0.5457 - mean_absolute_error: 0.3309 - val_loss: 0.3899 - val_root_mean_squared_error: 0.6244 - val_mean_absolute_error: 0.3777
# Epoch 24/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.2955 - root_mean_squared_error: 0.5436 - mean_absolute_error: 0.3295 - val_loss: 0.3896 - val_root_mean_squared_error: 0.6242 - val_mean_absolute_error: 0.3629
# Epoch 25/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.2949 - root_mean_squared_error: 0.5430 - mean_absolute_error: 0.3293 - val_loss: 0.4004 - val_root_mean_squared_error: 0.6328 - val_mean_absolute_error: 0.3901
# Epoch 26/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.2910 - root_mean_squared_error: 0.5394 - mean_absolute_error: 0.3276 - val_loss: 0.4251 - val_root_mean_squared_error: 0.6520 - val_mean_absolute_error: 0.3972
# Epoch 27/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.2896 - root_mean_squared_error: 0.5381 - mean_absolute_error: 0.3264 - val_loss: 0.4148 - val_root_mean_squared_error: 0.6441 - val_mean_absolute_error: 0.3857
# Epoch 28/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.2882 - root_mean_squared_error: 0.5369 - mean_absolute_error: 0.3257 - val_loss: 0.3970 - val_root_mean_squared_error: 0.6301 - val_mean_absolute_error: 0.3683
# Epoch 29/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.2860 - root_mean_squared_error: 0.5348 - mean_absolute_error: 0.3240 - val_loss: 0.4111 - val_root_mean_squared_error: 0.6412 - val_mean_absolute_error: 0.3826
# Epoch 30/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.2846 - root_mean_squared_error: 0.5335 - mean_absolute_error: 0.3233 - val_loss: 0.3936 - val_root_mean_squared_error: 0.6274 - val_mean_absolute_error: 0.3762
# Training History for Cluster 3:

# %%
### Save Scenario 3 models
# scenario_3_zero_cluster.model.save('Models/Scenario3/zero_cluster')
# scenario_3_one_cluster.model.save('Models/Scenario3/one_cluster')
# scenario_3_two_cluster.model.save('Models/Scenario3/two_cluster')
# scenario_3_three_cluster.model.save('Models/Scenario3/three_cluster')

## Pickling objects

# scenario_3_zero_cluster_file = open("Models/Scenario3/Objects/zero_cluster.pickle", "wb")
# pickle.dump(scenario_3_zero_cluster, scenario_3_zero_cluster_file)
# scenario_3_zero_cluster_file.close()

# scenario_3_one_cluster_file = open("Models/Scenario3/Objects/one_cluster.pickle", "wb")
# pickle.dump(scenario_3_one_cluster, scenario_3_one_cluster_file)
# scenario_3_one_cluster_file.close()

# scenario_3_two_cluster_file = open("Models/Scenario3/Objects/two_cluster.pickle", "wb")
# pickle.dump(scenario_3_two_cluster, scenario_3_two_cluster_file)
# scenario_3_two_cluster_file.close()

# scenario_3_three_cluster_file = open("Models/Scenario3/Objects/three_cluster.pickle", "wb")
# pickle.dump(scenario_3_three_cluster, scenario_3_three_cluster_file)
# scenario_3_three_cluster_file.close()

# scenario_3_zero_cluster_results_file = open("Models/Scenario3/Objects/zero_cluster_results.pickle", "wb")
# pickle.dump(scenario_3_zero_cluster_results, scenario_3_zero_cluster_results_file)
# scenario_3_zero_cluster_results_file.close()

# scenario_3_one_cluster_results_file = open("Models/Scenario3/Objects/one_cluster_results.pickle", "wb")
# pickle.dump(scenario_3_one_cluster_results, scenario_3_one_cluster_results_file)
# scenario_3_one_cluster_results_file.close()

# scenario_3_two_cluster_results_file = open("Models/Scenario3/Objects/two_cluster_results.pickle", "wb")
# pickle.dump(scenario_3_two_cluster_results, scenario_3_two_cluster_results_file)
# scenario_3_two_cluster_results_file.close()

# scenario_3_three_cluster_results_file = open("Models/Scenario3/Objects/three_cluster_results.pickle", "wb")
# pickle.dump(scenario_3_three_cluster_results, scenario_3_three_cluster_results_file)
# scenario_3_three_cluster_results_file.close()

# %% [markdown]
# #### Scenario 4

# %%
scenario_4_all_cluster = Cluster(all_houses)
scenario_4_all_cluster_results = scenario_4_all_cluster.results()
print('Training History without clustering:')
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_27 (LSTM)              (None, 14, 128)           66560
#
#  lstm_28 (LSTM)              (None, 14, 32)            20608
#
#  lstm_29 (LSTM)              (None, 16)                3136
#
#  dense_9 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 90,321
# Trainable params: 90,321
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 26534/26534 [==============================] - 416s 16ms/step - loss: 0.3400 - root_mean_squared_error: 0.5831 - mean_absolute_error: 0.3196 - val_loss: 0.3346 - val_root_mean_squared_error: 0.5784 - val_mean_absolute_error: 0.3351
# Epoch 2/30
# 26534/26534 [==============================] - 413s 16ms/step - loss: 0.3158 - root_mean_squared_error: 0.5620 - mean_absolute_error: 0.3039 - val_loss: 0.3323 - val_root_mean_squared_error: 0.5764 - val_mean_absolute_error: 0.3181
# Epoch 3/30
# 26534/26534 [==============================] - 413s 16ms/step - loss: 0.3088 - root_mean_squared_error: 0.5557 - mean_absolute_error: 0.3009 - val_loss: 0.3391 - val_root_mean_squared_error: 0.5823 - val_mean_absolute_error: 0.3093
# Epoch 4/30
# 26534/26534 [==============================] - 413s 16ms/step - loss: 0.3054 - root_mean_squared_error: 0.5526 - mean_absolute_error: 0.2993 - val_loss: 0.3236 - val_root_mean_squared_error: 0.5688 - val_mean_absolute_error: 0.3076
# Epoch 5/30
# 26534/26534 [==============================] - 413s 16ms/step - loss: 0.3026 - root_mean_squared_error: 0.5501 - mean_absolute_error: 0.2982 - val_loss: 0.3836 - val_root_mean_squared_error: 0.6193 - val_mean_absolute_error: 0.3197
# Epoch 6/30
# 26534/26534 [==============================] - 413s 16ms/step - loss: 0.3013 - root_mean_squared_error: 0.5489 - mean_absolute_error: 0.2972 - val_loss: 0.3707 - val_root_mean_squared_error: 0.6088 - val_mean_absolute_error: 0.3269
# Epoch 7/30
# 26534/26534 [==============================] - 413s 16ms/step - loss: 0.2994 - root_mean_squared_error: 0.5472 - mean_absolute_error: 0.2965 - val_loss: 0.3296 - val_root_mean_squared_error: 0.5742 - val_mean_absolute_error: 0.3161
# Epoch 8/30
# 26534/26534 [==============================] - 413s 16ms/step - loss: 0.2981 - root_mean_squared_error: 0.5460 - mean_absolute_error: 0.2960 - val_loss: 0.3605 - val_root_mean_squared_error: 0.6004 - val_mean_absolute_error: 0.3241
# Epoch 9/30
# 26534/26534 [==============================] - 413s 16ms/step - loss: 0.2958 - root_mean_squared_error: 0.5439 - mean_absolute_error: 0.2953 - val_loss: 0.3290 - val_root_mean_squared_error: 0.5736 - val_mean_absolute_error: 0.3238
# Epoch 10/30
# 26534/26534 [==============================] - 413s 16ms/step - loss: 0.2952 - root_mean_squared_error: 0.5433 - mean_absolute_error: 0.2948 - val_loss: 0.3508 - val_root_mean_squared_error: 0.5923 - val_mean_absolute_error: 0.3236
# Epoch 11/30
# 26534/26534 [==============================] - 413s 16ms/step - loss: 0.2952 - root_mean_squared_error: 0.5434 - mean_absolute_error: 0.2943 - val_loss: 0.3286 - val_root_mean_squared_error: 0.5732 - val_mean_absolute_error: 0.3315
# Epoch 12/30
# 26534/26534 [==============================] - 413s 16ms/step - loss: 0.2923 - root_mean_squared_error: 0.5407 - mean_absolute_error: 0.2937 - val_loss: 0.3367 - val_root_mean_squared_error: 0.5802 - val_mean_absolute_error: 0.3204
# Epoch 13/30
# 26534/26534 [==============================] - 413s 16ms/step - loss: 0.2926 - root_mean_squared_error: 0.5409 - mean_absolute_error: 0.2933 - val_loss: 0.3452 - val_root_mean_squared_error: 0.5875 - val_mean_absolute_error: 0.3135
# Epoch 14/30
# 26534/26534 [==============================] - 413s 16ms/step - loss: 0.2912 - root_mean_squared_error: 0.5396 - mean_absolute_error: 0.2929 - val_loss: 0.3240 - val_root_mean_squared_error: 0.5692 - val_mean_absolute_error: 0.3197
# Epoch 15/30
# 26534/26534 [==============================] - 413s 16ms/step - loss: 0.2899 - root_mean_squared_error: 0.5384 - mean_absolute_error: 0.2922 - val_loss: 0.3646 - val_root_mean_squared_error: 0.6038 - val_mean_absolute_error: 0.3164
# Epoch 16/30
# 26534/26534 [==============================] - 413s 16ms/step - loss: 0.2893 - root_mean_squared_error: 0.5379 - mean_absolute_error: 0.2921 - val_loss: 0.3402 - val_root_mean_squared_error: 0.5832 - val_mean_absolute_error: 0.3184
# Epoch 17/30
# 26534/26534 [==============================] - 413s 16ms/step - loss: 0.2888 - root_mean_squared_error: 0.5374 - mean_absolute_error: 0.2920 - val_loss: 0.3400 - val_root_mean_squared_error: 0.5831 - val_mean_absolute_error: 0.3092
# Epoch 18/30
# 26534/26534 [==============================] - 414s 16ms/step - loss: 0.2877 - root_mean_squared_error: 0.5363 - mean_absolute_error: 0.2912 - val_loss: 0.3477 - val_root_mean_squared_error: 0.5897 - val_mean_absolute_error: 0.3254
# Epoch 19/30
# 26534/26534 [==============================] - 414s 16ms/step - loss: 0.2873 - root_mean_squared_error: 0.5360 - mean_absolute_error: 0.2911 - val_loss: 0.3363 - val_root_mean_squared_error: 0.5799 - val_mean_absolute_error: 0.3122
# Epoch 20/30
# 26534/26534 [==============================] - 413s 16ms/step - loss: 0.2871 - root_mean_squared_error: 0.5358 - mean_absolute_error: 0.2909 - val_loss: 0.3525 - val_root_mean_squared_error: 0.5938 - val_mean_absolute_error: 0.3203
# Epoch 21/30
# 26534/26534 [==============================] - 414s 16ms/step - loss: 0.2856 - root_mean_squared_error: 0.5344 - mean_absolute_error: 0.2906 - val_loss: 0.3445 - val_root_mean_squared_error: 0.5870 - val_mean_absolute_error: 0.3210
# Epoch 22/30
# 26534/26534 [==============================] - 414s 16ms/step - loss: 0.2853 - root_mean_squared_error: 0.5341 - mean_absolute_error: 0.2903 - val_loss: 0.3312 - val_root_mean_squared_error: 0.5755 - val_mean_absolute_error: 0.3189
# Epoch 23/30
# 26534/26534 [==============================] - 498s 19ms/step - loss: 1.5510 - root_mean_squared_error: 1.2454 - mean_absolute_error: 0.2909 - val_loss: 0.3712 - val_root_mean_squared_error: 0.6092 - val_mean_absolute_error: 0.3140
# Epoch 24/30
# 26534/26534 [==============================] - 621s 23ms/step - loss: 0.2844 - root_mean_squared_error: 0.5333 - mean_absolute_error: 0.2900 - val_loss: 0.3779 - val_root_mean_squared_error: 0.6147 - val_mean_absolute_error: 0.3262
# Epoch 25/30
# 26534/26534 [==============================] - 476s 18ms/step - loss: 0.2838 - root_mean_squared_error: 0.5327 - mean_absolute_error: 0.2899 - val_loss: 0.3645 - val_root_mean_squared_error: 0.6038 - val_mean_absolute_error: 0.3192
# Epoch 26/30
# 26534/26534 [==============================] - 457s 17ms/step - loss: 0.2917 - root_mean_squared_error: 0.5401 - mean_absolute_error: 0.2897 - val_loss: 0.3449 - val_root_mean_squared_error: 0.5873 - val_mean_absolute_error: 0.3159
# Epoch 27/30
# 26534/26534 [==============================] - 421s 16ms/step - loss: 0.3528 - root_mean_squared_error: 0.5940 - mean_absolute_error: 0.2899 - val_loss: 0.3588 - val_root_mean_squared_error: 0.5990 - val_mean_absolute_error: 0.3171
# Epoch 28/30
# 26534/26534 [==============================] - 421s 16ms/step - loss: 0.5467 - root_mean_squared_error: 0.7394 - mean_absolute_error: 0.2899 - val_loss: 0.3550 - val_root_mean_squared_error: 0.5958 - val_mean_absolute_error: 0.3223
# Epoch 29/30
# 26534/26534 [==============================] - 439s 17ms/step - loss: 0.3040 - root_mean_squared_error: 0.5513 - mean_absolute_error: 0.2892 - val_loss: 0.3542 - val_root_mean_squared_error: 0.5951 - val_mean_absolute_error: 0.3249
# Epoch 30/30
# 26534/26534 [==============================] - 437s 16ms/step - loss: 0.2825 - root_mean_squared_error: 0.5315 - mean_absolute_error: 0.2895 - val_loss: 0.3530 - val_root_mean_squared_error: 0.5941 - val_mean_absolute_error: 0.3170
# Training History without clustering:

# %%
# ### Save Scenario 4 models
# scenario_4_all_cluster.model.save('Models/Scenario4/all_cluster')

### Pickling Scenario 4 cluster and cluster result files
# scenario_4_all_cluster_file = open("Models/Scenario4/Objects/all_cluster.pickle", "wb")
# pickle.dump(scenario_4_all_cluster, scenario_4_all_cluster_file)
# scenario_4_all_cluster_file.close()

# scenario_4_all_cluster_results_file = open("Models/Scenario4/Objects/all_cluster_results.pickle", "wb")
# pickle.dump(scenario_4_all_cluster_results, scenario_4_all_cluster_results_file)
# scenario_4_all_cluster_results_file.close()

# %% [markdown]
# #### Predictions for Scenario 3 and Scenario 4

# %%
graph_predictions(scenario_3_zero_cluster_results, scenario_4_all_cluster_results)
# Out:
# <ipython-input-31-9643f5cc2f5c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['timestamp'] = pd.to_datetime(df1['timestamp'])

# %%
graph_predictions(scenario_3_one_cluster_results, scenario_4_all_cluster_results)
# Out:
# <ipython-input-31-9643f5cc2f5c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['timestamp'] = pd.to_datetime(df1['timestamp'])

# %%
graph_predictions(scenario_3_two_cluster_results, scenario_4_all_cluster_results)
# Out:
# <ipython-input-31-9643f5cc2f5c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['timestamp'] = pd.to_datetime(df1['timestamp'])

# %%
graph_predictions(scenario_3_three_cluster_results, scenario_4_all_cluster_results)
# Out:
# <ipython-input-31-9643f5cc2f5c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['timestamp'] = pd.to_datetime(df1['timestamp'])

# %% [markdown]
# #### Scenario 3 and Scenario 4 Metric Tables

# %%
scenario_3_results = [scenario_3_zero_cluster, scenario_3_one_cluster, scenario_3_two_cluster, scenario_3_three_cluster]
scenario_3_metrics = create_metrics(scenario_3_results )
scenario_3_validation_metrics = create_metrics(scenario_3_results, val= True)
scenario_3_metrics
# Out:
# [0.36909234523773193,
#  1.2163209915161133,
#  0.6179086955885092,
#  0.20277628302574158,
#  0.7024189233779907,
#  0.3597872260957956]

# %%
scenario_4_results = [scenario_4_all_cluster]
scenario_4_metrics = create_metrics(scenario_4_results )
scenario_4_validation_metrics = create_metrics(scenario_4_results, val= True)
scenario_4_metrics
# Out:
# [0.5315418839454651,
#  1.2453898191452026,
#  0.5751848419507345,
#  0.28924962878227234,
#  0.31956133246421814,
#  0.2941772590080897]

# %%
print('Training metrics:')
df = pd.DataFrame([scenario_1_metrics, scenario_2_metrics, scenario_3_metrics, scenario_4_metrics],index=[1,2,3,4], columns = ['Min RMSE', 'Max RMSE', 'Mean RMSE','Min MAE', 'Max MAE', 'Mean MAE'])
df['Scenario'] = np.array([1,2,3,4])
df.set_index('Scenario')
# Out:
# Training metrics:
#           Min RMSE  Max RMSE  Mean RMSE   Min MAE   Max MAE  Mean MAE
# Scenario
# 1         0.367936  4.705198   0.673105  0.201960  0.734426  0.363703
# 2         0.534938  2.245431   0.669645  0.290637  0.343346  0.299194
# 3         0.369092  1.216321   0.617909  0.202776  0.702419  0.359787
# 4         0.531542  1.245390   0.575185  0.289250  0.319561  0.294177

# %%
print('Validation metrics:')
df = pd.DataFrame([scenario_1_validation_metrics, scenario_2_validation_metrics,
                   scenario_3_validation_metrics, scenario_4_validation_metrics],index=[1,2,3,4], columns = ['Min RMSE', 'Max RMSE', 'Mean RMSE','Min MAE', 'Max MAE', 'Mean MAE'])
df['Scenario'] = np.array([1,2,3,4])
df.set_index('Scenario')
# Out:
# Validation metrics:
#           Min RMSE  Max RMSE  Mean RMSE   Min MAE   Max MAE  Mean MAE
# Scenario
# 1         0.448147  4.566897   0.812607  0.241360  0.648222  0.413318
# 2         0.567081  1.582978   0.647333  0.310249  0.368792  0.321029
# 3         0.449479  1.322366   0.745330  0.240514  0.667575  0.406423
# 4         0.568841  0.619334   0.589334  0.307573  0.335076  0.319592

# %% [markdown]
# ### Anomaly Distribution

# %%
def create_anomaly_df(result_df, scenario_name, monthly_agg = True):    
    #print(type(result_df))
    anomaly_df = result_df[['timestamp', 'Anomaly detected']]
    anomaly_df.set_index('timestamp', inplace = True)
    if monthly_agg:
        anomaly_df['Anomaly detected'] = anomaly_df['Anomaly detected'].apply(lambda x: 0 if x is False else 1)
        anomaly_df = anomaly_df.resample("M").agg('sum')
    else: 
        anomaly_df['Anomaly detected'] = anomaly_df['Anomaly detected'].apply(lambda x: 0 if x is False else x)
    anomaly_df = anomaly_df.rename(columns={'Anomaly detected': scenario_name})
    return anomaly_df

def create_anomalies_graph( title = None, **kwargs):
    anomaly_dfs = []
    for scenario_name, result_df in kwargs.items():
        anomaly_df = create_anomaly_df(result_df, scenario_name)
        anomaly_dfs.append(anomaly_df)
    anomaly_df = functools.reduce(lambda left, right: left.join(right), anomaly_dfs)
    ax = anomaly_df.plot.line(figsize=(20,10))
    ax.set_xlabel(f'Time')
    ax.set_ylabel(f'Frequency')
    ax.set_title(title)
    #return anomaly_dfs

# %%
def dtw_distance(series1, series2):
    return fastdtw.fastdtw(series1,series2)[0]

def create_distance_df(title, **kwargs):
    print(title)
    anomaly_dfs = []
    for scenario_name, result_df in kwargs.items():
        anomaly_df = np.array(create_anomaly_df(result_df, scenario_name, monthly_agg=False)).reshape(1,-1)
        anomaly_dfs.append(anomaly_df)
    anomaly_distributions = np.array(anomaly_dfs).reshape(len(kwargs),-1)
    distance_matrix = sd.squareform(sd.pdist(anomaly_distributions, dtw_distance))
    return(pd.DataFrame(distance_matrix, columns = kwargs.keys(), index = kwargs.keys()))
    #return anomaly_dfs

# %%
create_anomalies_graph( 'Anomaly Frequency Distribution for House 1: Cluster 0', Scenario1 = zero_cluster_results[1], Scenario2 = all_cluster_results[1],
                       Scenario3 = scenario_3_zero_cluster_results[1], Scenario4 = scenario_4_all_cluster_results[1])
# Out:
# <ipython-input-203-5eaf4267c8ed>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anomaly_df['Anomaly detected'] = anomaly_df['Anomaly detected'].apply(lambda x: 0 if x is False else 1)

# %%
create_distance_df('Similarity between anomaly distributions for House1: Cluster 0', Scenario1 = zero_cluster_results[1], Scenario2 = all_cluster_results[1],
                       Scenario3 = scenario_3_zero_cluster_results[1], Scenario4 = scenario_4_all_cluster_results[1])
# Out:
# Similarity between anomaly distributions for House1: Cluster 0
# <ipython-input-203-5eaf4267c8ed>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anomaly_df['Anomaly detected'] = anomaly_df['Anomaly detected'].apply(lambda x: 0 if x is False else x)
#              Scenario1    Scenario2    Scenario3    Scenario4
# Scenario1     0.000000   761.444733  1592.995059   938.951313
# Scenario2   761.444733     0.000000  1435.246039   692.430370
# Scenario3  1592.995059  1435.246039     0.000000  1431.964637
# Scenario4   938.951313   692.430370  1431.964637     0.000000

# %%
create_anomalies_graph( 'Anomaly Frequency Distribution for House 15: Cluster 1', Scenario1 = one_cluster_results[15], Scenario2 = all_cluster_results[15],
                       Scenario3 = scenario_3_one_cluster_results[15], Scenario4 = scenario_4_all_cluster_results[15])
# Out:
# <ipython-input-135-7a0c5d9c2912>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anomaly_df['Anomaly detected'] = anomaly_df['Anomaly detected'].apply(lambda x: 0 if x is False else 1)

# %%
create_distance_df( 'Similarity between anomaly distributions for House15: Cluster 1', Scenario1 = one_cluster_results[15], Scenario2 = all_cluster_results[15],
                       Scenario3 = scenario_3_one_cluster_results[15], Scenario4 = scenario_4_all_cluster_results[15])
# Out:
# Similarity between anomaly distributions for House15: Cluster 1
# <ipython-input-203-5eaf4267c8ed>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anomaly_df['Anomaly detected'] = anomaly_df['Anomaly detected'].apply(lambda x: 0 if x is False else x)
#             Scenario1   Scenario2   Scenario3   Scenario4
# Scenario1    0.000000  597.799820  499.833598  706.447296
# Scenario2  597.799820    0.000000  726.405154  464.765907
# Scenario3  499.833598  726.405154    0.000000  931.920371
# Scenario4  706.447296  464.765907  931.920371    0.000000

# %%
create_anomalies_graph( 'Anomaly Frequency Distribution for House 2: Cluster 2', Scenario1 = two_cluster_results[2], Scenario2 = all_cluster_results[2],
                       Scenario3 = scenario_3_two_cluster_results[2], Scenario4 = scenario_4_all_cluster_results[2])
# Out:
# <ipython-input-135-7a0c5d9c2912>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anomaly_df['Anomaly detected'] = anomaly_df['Anomaly detected'].apply(lambda x: 0 if x is False else 1)

# %%
create_distance_df( 'Similarity between anomaly distributions for House 2: Cluster 2', Scenario1 = two_cluster_results[2], Scenario2 = all_cluster_results[2],
                       Scenario3 = scenario_3_two_cluster_results[2], Scenario4 = scenario_4_all_cluster_results[2])
# Out:
# Similarity between anomaly distributions for House 2: Cluster 2
# <ipython-input-203-5eaf4267c8ed>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anomaly_df['Anomaly detected'] = anomaly_df['Anomaly detected'].apply(lambda x: 0 if x is False else x)
#             Scenario1   Scenario2   Scenario3   Scenario4
# Scenario1    0.000000  776.731952  762.970812  791.063067
# Scenario2  776.731952    0.000000  507.458111  211.427134
# Scenario3  762.970812  507.458111    0.000000  185.769410
# Scenario4  791.063067  211.427134  185.769410    0.000000

# %%
create_anomalies_graph( 'Anomaly Frequency Distribution for House 3: Cluster 3', Scenario1 = three_cluster_results[3], Scenario2 = all_cluster_results[3],
                       Scenario3 = scenario_3_three_cluster_results[3], Scenario4 = scenario_4_all_cluster_results[3])
# Out:
# <ipython-input-135-7a0c5d9c2912>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anomaly_df['Anomaly detected'] = anomaly_df['Anomaly detected'].apply(lambda x: 0 if x is False else 1)

# %%
create_distance_df( 'Similarity between anomaly distributions for House 3: Cluster 3', Scenario1 = three_cluster_results[3], Scenario2 = all_cluster_results[3],
                       Scenario3 = scenario_3_three_cluster_results[3], Scenario4 = scenario_4_all_cluster_results[3])
# Out:
# Similarity between anomaly distributions for House 3: Cluster 3
# <ipython-input-203-5eaf4267c8ed>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anomaly_df['Anomaly detected'] = anomaly_df['Anomaly detected'].apply(lambda x: 0 if x is False else x)
#              Scenario1    Scenario2    Scenario3    Scenario4
# Scenario1     0.000000  2961.505633   748.554445  3036.681767
# Scenario2  2961.505633     0.000000  3243.669528   618.634470
# Scenario3   748.554445  3243.669528     0.000000  2963.691511
# Scenario4  3036.681767   618.634470  2963.691511     0.000000

# %% [markdown]
# #### Energy Deficit Calculation

# %%
def create_deficit_df(result_df, scenario_name, monthly_agg = True):    
    #print(type(result_df))
    energy_df = result_df[['timestamp', 'Energy Deficit Flag']]
    energy_df.set_index('timestamp', inplace = True)
    if monthly_agg:
        energy_df['Energy Deficit Flag'] = energy_df['Energy Deficit Flag'].apply(lambda x: 0 if x is False else 1)
        energy_df = energy_df.resample("W").agg('sum')
    else: 
        energy_df['Energy Deficit Flag'] = energy_df['Energy Deficit Flag'].apply(lambda x: 0 if x is False else x)
    energy_df = energy_df.rename(columns={'Energy Deficit Flag': scenario_name})
    return energy_df

def create_energy_deficit_graph( title = None, **kwargs):
    energy_dfs = []
    for scenario_name, result_df in kwargs.items():
        energy_df = create_deficit_df(result_df, scenario_name)
        energy_dfs.append(energy_df)
    energy_df = functools.reduce(lambda left, right: left.join(right), energy_dfs)
    ax = energy_df.plot.line(figsize=(20,10))
    ax.set_xlabel(f'Time')
    ax.set_ylabel(f'Frequency')
    ax.set_title(title)

# %%
def create_deficit_distance_df(title, **kwargs):
    print(title)
    energy_dfs = []
    for scenario_name, result_df in kwargs.items():
        energy_df = np.array(create_deficit_df(result_df, scenario_name, monthly_agg=False)).reshape(1,-1)
        energy_dfs.append(energy_df)
    energy_distributions = np.array(energy_dfs).reshape(len(kwargs),-1)
    distance_matrix = sd.squareform(sd.pdist(energy_distributions, dtw_distance))
    return(pd.DataFrame(distance_matrix, columns = kwargs.keys(), index = kwargs.keys()))

# %%
create_energy_deficit_graph( 'Energy Deficit Frequency Distribution for House 1: Cluster 0', Scenario1 = zero_cluster_results[1], Scenario2 = all_cluster_results[1],
                       Scenario3 = scenario_3_zero_cluster_results[1], Scenario4 = scenario_4_all_cluster_results[1])
# Out:
# <ipython-input-232-b37064844ec5>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   energy_df['Energy Deficit Flag'] = energy_df['Energy Deficit Flag'].apply(lambda x: 0 if x is False else 1)

# %%
create_deficit_distance_df('Similarity between energy deficit distributions for House1: Cluster 0', Scenario1 = zero_cluster_results[1], Scenario2 = all_cluster_results[1],
                       Scenario3 = scenario_3_zero_cluster_results[1], Scenario4 = scenario_4_all_cluster_results[1])
# Out:
# Similarity between energy deficit distributions for House1: Cluster 0
# <ipython-input-232-b37064844ec5>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   energy_df['Energy Deficit Flag'] = energy_df['Energy Deficit Flag'].apply(lambda x: 0 if x is False else x)
#              Scenario1    Scenario2    Scenario3    Scenario4
# Scenario1     0.000000  2729.412191  2621.717259  6352.531733
# Scenario2  2729.412191     0.000000  2817.024375  1899.450995
# Scenario3  2621.717259  2817.024375     0.000000  6610.747373
# Scenario4  6352.531733  1899.450995  6610.747373     0.000000

# %%
create_energy_deficit_graph( 'Energy Deficit Frequency Distribution for House 15: Cluster 1', Scenario1 = one_cluster_results[15], Scenario2 = all_cluster_results[15],
                       Scenario3 = scenario_3_one_cluster_results[15], Scenario4 = scenario_4_all_cluster_results[15])
# Out:
# <ipython-input-232-b37064844ec5>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   energy_df['Energy Deficit Flag'] = energy_df['Energy Deficit Flag'].apply(lambda x: 0 if x is False else 1)
