# %% [markdown]
# #### Importing Libraries and Dataset

# %%
import numpy as np
from statistics import mean
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import pandas as pd
import seaborn as sns
from tslearn.clustering import TimeSeriesKMeans
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, SimpleRNN 
from tensorflow.keras import regularizers
from tensorflow.keras.layers import Dense, Dropout
import tensorflow as tf
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from tensorflow import keras
import seaborn as sns
import pickle
import functools
import fastdtw
import scipy.spatial.distance as sd
#from datetime import datetime
consumption_df = pd.read_csv('Final Datasets/energy_consumption.csv')
consumption_df
# Out:
# 2022-03-29 09:20:32.913403: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-03-29 09:20:32.913489: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
#         Unnamed: 0            timestamp  energy_kWh  House Number  \
# 0                0  2012-06-01 01:00:00      1.0110             1
# 1                1  2012-06-01 02:00:00      0.4510             1
# 2                2  2012-06-01 03:00:00      0.5050             1
# 3                3  2012-06-01 04:00:00      0.4410             1
# 4                4  2012-06-01 05:00:00      0.4680             1
# ...            ...                  ...         ...           ...
# 611013      123761  2020-05-19 19:00:00      3.5802            28
# 611014      123762  2020-05-19 20:00:00      3.4398            28
# 611015      123763  2020-05-19 21:00:00      2.3049            28
# 611016      123764  2020-05-19 22:00:00      2.4921            28
# 611017      123765  2020-05-19 23:00:00      1.1817            28
#
#         electronics workbench energy  network equipment energy  \
# 0                           0.008686                  0.019316
# 1                           0.007178                  0.019338
# 2                           0.007324                  0.019336
# 3                           0.007151                  0.019339
# 4                           0.007224                  0.019338
# ...                              ...                       ...
# 611013                      0.028408                  0.038470
# 611014                      0.027762                  0.038479
# 611015                      0.022537                  0.038556
# 611016                      0.023399                  0.038544
# 611017                      0.017367                  0.038632
#
#         home office energy  RAE home office energy  \
# 0                 0.018232                0.134570
# 1                 0.013745                0.061839
# 2                 0.014177                0.068852
# 3                 0.013664                0.060540
# 4                 0.013881                0.064047
# ...                    ...                     ...
# 611013            0.069307                0.801381
# 611014            0.067384                0.770210
# 611015            0.051836                0.518247
# 611016            0.054401                0.559808
# 611017            0.036449                0.268881
#
#         RAE Mobile Phone Charger Energy
# 0                              0.000431
# 1                              0.000215
# 2                              0.000236
# 3                              0.000211
# 4                              0.000221
# ...                                 ...
# 611013                         0.002441
# 611014                         0.002348
# 611015                         0.001601
# 611016                         0.001724
# 611017                         0.000861
#
# [611018 rows x 9 columns]

# %%
if 'Unnamed: 0' in consumption_df.columns:
    consumption_df.drop('Unnamed: 0',axis=1, inplace = True)

# %%
consumption_df
# Out:
#                   timestamp  energy_kWh  House Number  \
# 0       2012-06-01 01:00:00      1.0110             1
# 1       2012-06-01 02:00:00      0.4510             1
# 2       2012-06-01 03:00:00      0.5050             1
# 3       2012-06-01 04:00:00      0.4410             1
# 4       2012-06-01 05:00:00      0.4680             1
# ...                     ...         ...           ...
# 611013  2020-05-19 19:00:00      3.5802            28
# 611014  2020-05-19 20:00:00      3.4398            28
# 611015  2020-05-19 21:00:00      2.3049            28
# 611016  2020-05-19 22:00:00      2.4921            28
# 611017  2020-05-19 23:00:00      1.1817            28
#
#         electronics workbench energy  network equipment energy  \
# 0                           0.008686                  0.019316
# 1                           0.007178                  0.019338
# 2                           0.007324                  0.019336
# 3                           0.007151                  0.019339
# 4                           0.007224                  0.019338
# ...                              ...                       ...
# 611013                      0.028408                  0.038470
# 611014                      0.027762                  0.038479
# 611015                      0.022537                  0.038556
# 611016                      0.023399                  0.038544
# 611017                      0.017367                  0.038632
#
#         home office energy  RAE home office energy  \
# 0                 0.018232                0.134570
# 1                 0.013745                0.061839
# 2                 0.014177                0.068852
# 3                 0.013664                0.060540
# 4                 0.013881                0.064047
# ...                    ...                     ...
# 611013            0.069307                0.801381
# 611014            0.067384                0.770210
# 611015            0.051836                0.518247
# 611016            0.054401                0.559808
# 611017            0.036449                0.268881
#
#         RAE Mobile Phone Charger Energy
# 0                              0.000431
# 1                              0.000215
# 2                              0.000236
# 3                              0.000211
# 4                              0.000221
# ...                                 ...
# 611013                         0.002441
# 611014                         0.002348
# 611015                         0.001601
# 611016                         0.001724
# 611017                         0.000861
#
# [611018 rows x 8 columns]

# %% [markdown]
# #### Converting Dataset to House-wise dictionary

# %%
house_wise_consumption = dict()
for house_number in consumption_df['House Number'].unique():
    house_data = consumption_df[consumption_df['House Number'] == house_number]
    house_wise_consumption[house_number] = house_data.copy()
house_wise_consumption[1]
# house_wise_consumption[14]['timestamp'].iloc[0]
# house_wise_consumption[14]['timestamp'].iloc[-1]
# house_wise_consumption[14]['House Number'].iloc[0]
# Out:
#                  timestamp  energy_kWh  House Number  \
# 0      2012-06-01 01:00:00       1.011             1
# 1      2012-06-01 02:00:00       0.451             1
# 2      2012-06-01 03:00:00       0.505             1
# 3      2012-06-01 04:00:00       0.441             1
# 4      2012-06-01 05:00:00       0.468             1
# ...                    ...         ...           ...
# 29226  2015-10-02 20:00:00       2.101             1
# 29227  2015-10-02 21:00:00       1.646             1
# 29228  2015-10-02 22:00:00       1.319             1
# 29229  2015-10-02 23:00:00       1.473             1
# 29230  2015-10-03 00:00:00       0.800             1
#
#        electronics workbench energy  network equipment energy  \
# 0                          0.008686                  0.019316
# 1                          0.007178                  0.019338
# 2                          0.007324                  0.019336
# 3                          0.007151                  0.019339
# 4                          0.007224                  0.019338
# ...                             ...                       ...
# 29226                      0.011621                  0.019273
# 29227                      0.010396                  0.019291
# 29228                      0.009516                  0.019304
# 29229                      0.009930                  0.019298
# 29230                      0.008118                  0.019324
#
#        home office energy  RAE home office energy  \
# 0                0.018232                0.134570
# 1                0.013745                0.061839
# 2                0.014177                0.068852
# 3                0.013664                0.060540
# 4                0.013881                0.064047
# ...                   ...                     ...
# 29226            0.026968                0.276137
# 29227            0.023322                0.217043
# 29228            0.020701                0.174573
# 29229            0.021935                0.194574
# 29230            0.016541                0.107166
#
#        RAE Mobile Phone Charger Energy
# 0                             0.000431
# 1                             0.000215
# 2                             0.000236
# 3                             0.000211
# 4                             0.000221
# ...                                ...
# 29226                         0.000851
# 29227                         0.000675
# 29228                         0.000549
# 29229                         0.000609
# 29230                         0.000349
#
# [29231 rows x 8 columns]

# %%
# TODO: Print the usage pattern in form of a graph
# Each cluster represents one line in the time series graph
# Plot december consumption (2017) values for each house belonging to the same cluster in a single graph
# Also plot for the whole year (annual 2017) for each house belonging to the same cluster in a single graph

# %% [markdown]
# #### Comparing Timestamps for clustering

# %%
timestamp_comparison = list()
for house in house_wise_consumption:
    first_timestamp = house_wise_consumption[house]['timestamp'].iloc[0]
    last_timestamp = house_wise_consumption[house]['timestamp'].iloc[-1]
    timestamp_comparison.append([house, first_timestamp, last_timestamp])
timestamp_comparison
timestamp_comparison_df = pd.DataFrame(timestamp_comparison, columns = ['House', 'First Timestamp', 'Last Timestamp'])
timestamp_comparison_df
# Out:
#     House      First Timestamp       Last Timestamp
# 0       1  2012-06-01 01:00:00  2015-10-03 00:00:00
# 1       2  2016-06-09 00:00:00  2019-11-20 23:00:00
# 2       3  2015-01-27 00:00:00  2018-01-29 23:00:00
# 3       4  2015-01-30 00:00:00  2018-01-29 23:00:00
# 4       5  2015-01-30 00:00:00  2018-01-29 23:00:00
# 5       6  2015-01-30 00:00:00  2018-01-29 23:00:00
# 6       7  2015-05-30 00:00:00  2018-01-29 23:00:00
# 7       8  2015-02-21 00:00:00  2018-02-20 23:00:00
# 8       9  2015-05-01 00:00:00  2018-02-21 23:00:00
# 9      10  2015-02-21 00:00:00  2018-02-20 23:00:00
# 10     11  2015-02-21 00:00:00  2018-02-20 23:00:00
# 11     12  2015-02-21 00:00:00  2018-02-20 23:00:00
# 12     13  2015-02-21 00:00:00  2018-02-20 23:00:00
# 13     14  2015-02-21 00:00:00  2018-02-20 23:00:00
# 14     15  2015-09-29 00:00:00  2018-02-20 23:00:00
# 15     16  2017-11-01 00:00:00  2019-02-18 23:00:00
# 16     17  2016-06-01 00:00:00  2017-04-29 23:00:00
# 17     18  2015-03-16 00:00:00  2018-03-15 16:00:00
# 18     19  2015-03-26 00:00:00  2018-03-25 23:00:00
# 19     20  2015-08-21 00:00:00  2018-04-20 23:00:00
# 20     21  2017-11-01 00:00:00  2018-06-04 23:00:00
# 21     22  2016-06-29 00:00:00  2018-06-05 23:00:00
# 22     23  2017-07-27 00:00:00  2020-04-05 23:00:00
# 23     24  2017-05-13 00:00:00  2020-05-12 23:00:00
# 24     25  2017-05-15 00:00:00  2020-05-14 23:00:00
# 25     26  2019-11-29 00:00:00  2020-05-20 23:00:00
# 26     27  2019-03-06 00:00:00  2020-05-20 23:00:00
# 27     28  2018-08-01 00:00:00  2020-05-19 23:00:00

# %%
# houses_with_ts = []
# sample_timestamp = '2017-11-01 00:00:00'
# for house in house_wise_consumption:
#     if sample_timestamp in house_wise_consumption[house]['timestamp'].unique():
#         houses_with_ts.append(house)
# len(houses_with_ts)
#house_wise_consumption[8][house_wise_consumption[8]['timestamp'] >= '2017-11-17'].head(60)

# %% [markdown]
# #### Creating a December consumption dictionary of dataframes

# %%
december_consumption = dict()
for house in house_wise_consumption:
    house_december_consumption = house_wise_consumption[house][(house_wise_consumption[house]['timestamp'] <= '2017-11-25') & (house_wise_consumption[house]['timestamp'] >= '2017-11-01')]
    december_consumption[house] = house_december_consumption.copy()
    december_consumption[house].drop_duplicates(subset='timestamp', keep="last", inplace = True)
def calculate_rows():
    december_rows = []
    for house in december_consumption:
        december_rows.append([house, len(december_consumption[house])])
    december_rows
    december_rows_df = pd.DataFrame(december_rows, columns = ['House', 'Rows'])
    return december_rows_df
def calculate_incomplete_rows():
    december_rows_df = calculate_rows()
    december_rows_incomplete_df = december_rows_df[(december_rows_df['Rows'] > 0) & (december_rows_df['Rows'] < 576)]
    return december_rows_incomplete_df
def fill_na_december_consumption(complete_df, incomplete_df):
    complete_df = complete_df.copy()
    year_incomplete = pd.Timestamp(incomplete_df.iloc[0]['timestamp']).year
    year_complete = pd.Timestamp(complete_df.iloc[0]['timestamp']).year
    complete_df['timestamp'] = complete_df['timestamp'].str.replace(str(year_complete), str(year_incomplete))
    fill_missing_values = complete_df[~complete_df.timestamp.isin(incomplete_df.timestamp)].copy()
    #print(fill_missing_values)
    fill_columns = ['energy_kWh', 'electronics workbench energy', 'network equipment energy', 'home office energy', 'RAE home office energy','RAE Mobile Phone Charger Energy']
    for fill_column in fill_columns:
        fill_missing_values[fill_column] = incomplete_df[fill_column].mean()
    incomplete_df = pd.concat([incomplete_df, fill_missing_values])
    incomplete_df = incomplete_df.sort_values(by=['timestamp'])
    return incomplete_df
def calculate_missing_december_rows():
    december_rows_df = calculate_rows()
    december_rows_missing_df = december_rows_df[(december_rows_df['Rows'] == 0)]
    return december_rows_missing_df
calculate_rows()
# Out:
#     House  Rows
# 0       1     0
# 1       2   576
# 2       3   576
# 3       4   576
# 4       5   576
# 5       6   576
# 6       7   576
# 7       8   448
# 8       9   576
# 9      10   576
# 10     11   568
# 11     12   528
# 12     13   576
# 13     14   575
# 14     15   576
# 15     16   456
# 16     17     0
# 17     18   528
# 18     19   576
# 19     20   575
# 20     21   576
# 21     22   528
# 22     23   576
# 23     24   576
# 24     25   576
# 25     26     0
# 26     27     0
# 27     28     0

# %%
for house in list(calculate_incomplete_rows()['House']):
    december_consumption[house] = fill_na_december_consumption(december_consumption[10], december_consumption[house])

# %% [markdown]
# ##### Houses with no December-17 consumption values

# %%
timestamp_comparison_df.set_index('House').join(calculate_missing_december_rows().set_index('House'), how='inner')
# Out:
#            First Timestamp       Last Timestamp  Rows
# House
# 1      2012-06-01 01:00:00  2015-10-03 00:00:00     0
# 17     2016-06-01 00:00:00  2017-04-29 23:00:00     0
# 26     2019-11-29 00:00:00  2020-05-20 23:00:00     0
# 27     2019-03-06 00:00:00  2020-05-20 23:00:00     0
# 28     2018-08-01 00:00:00  2020-05-19 23:00:00     0

# %%
missing_december_houses_dates = {
    1: ['2014-11-25', '2014-11-01'],
    17: ['2016-11-25', '2016-11-01'],
    26: ['2019-11-25', '2019-11-01'],
    27: ['2019-11-25', '2019-11-01'],
    28: ['2019-11-25', '2019-11-01'],
}

# %%
for house in missing_december_houses_dates:
    house_december_consumption = house_wise_consumption[house][(house_wise_consumption[house]['timestamp'] <= missing_december_houses_dates[house][0]) & (house_wise_consumption[house]['timestamp'] >= missing_december_houses_dates[house][1])]
    #print((house, missing_december_houses_dates[house][0]))
    december_consumption[house] = house_december_consumption.copy()
    december_consumption[house].drop_duplicates(subset='timestamp', keep="last", inplace = True)

# %% [markdown]
# ##### Filling missing values for December consumption

# %%
calculate_incomplete_rows()
# Out:
#     House  Rows
# 16     17   574
# 26     27   571
# 27     28   572

# %%
for house in list(calculate_incomplete_rows()['House']):
    december_consumption[house] = fill_na_december_consumption(december_consumption[10], december_consumption[house])

# %%
#calculate_rows()december_consumption

# %% [markdown]
# #### Houses to be clustered

# %%
##print('Houses to be clustered: ')
clustered_df = calculate_rows()[calculate_rows()['Rows'] ==  576]
clustered_df
# Out:
#     House  Rows
# 0       1   576
# 1       2   576
# 2       3   576
# 3       4   576
# 4       5   576
# 5       6   576
# 6       7   576
# 7       8   576
# 8       9   576
# 9      10   576
# 10     11   576
# 11     12   576
# 12     13   576
# 13     14   576
# 14     15   576
# 15     16   576
# 16     17   576
# 17     18   576
# 18     19   576
# 19     20   576
# 20     21   576
# 21     22   576
# 22     23   576
# 23     24   576
# 24     25   576
# 26     27   576
# 27     28   576

# %% [markdown]
# #### Converting to clustering matrix

# %%
clustering_matrix = []
for house in calculate_rows()[calculate_rows()['Rows'] ==  576]['House']:
    clustering_matrix.append(np.array(december_consumption[house]['energy_kWh']).reshape(-1,1))
clustering_matrix = np.array(clustering_matrix)
clustering_matrix.shape
# Out:
# (27, 576, 1)

# %% [markdown]
# #### Time series clustering of all households except house 26

# %%
# km_sdtw = TimeSeriesKMeans(n_clusters=4, metric="softdtw", max_iter=5,
#                             max_iter_barycenter=5,
#                             metric_params={"gamma": .5},
#                             random_state=0).fit_predict(clustering_matrix)

# %%
# len(km_sdtw)

# %%
# clustered_df['Cluster'] = km_sdtw

# %%
#clustered_df = clustered_df[['House', 'Cluster']].set_index('House')
# clustered_df[clustered_df['Cluster'] == 3]

# %%
clustered_df = pd.read_csv('Tables/clustered.csv')
clustered_df
# Out:
#     House  Cluster
# 0       1        0
# 1       2        2
# 2       3        3
# 3       4        0
# 4       5        3
# 5       6        2
# 6       7        2
# 7       8        2
# 8       9        2
# 9      10        2
# 10     11        2
# 11     12        2
# 12     13        0
# 13     14        0
# 14     15        1
# 15     16        2
# 16     17        2
# 17     18        0
# 18     19        0
# 19     20        2
# 20     21        2
# 21     22        2
# 22     23        2
# 23     24        2
# 24     25        2
# 25     27        3
# 26     28        0

# %% [markdown]
# #### Used Scenarios

# %%
data = [[1, 4, 6, 'Yes'], [2, 1, 6, 'Yes'], [3, 4, 1, 'No'], [4, 1, 1, 'No']]
df = pd.DataFrame(data, columns = ['Scenarios', 'No. of subsets', 'No. of features', 'Smart devices included in modeling?']).set_index('Scenarios')
df
# Out:
#            No. of subsets  No. of features Smart devices included in modeling?
# Scenarios
# 1                       4                6                                 Yes
# 2                       1                6                                 Yes
# 3                       4                1                                  No
# 4                       1                1                                  No

# %% [markdown]
# #### Time-series LSTM-based predictive modeling

# %%
n_past = 14
n_future = 1

# %%
### Energy generation dataframe
generation_df = pd.read_csv('Final Datasets/energy_generation.csv')
generation_df
# Out:
#                  timestamp  Wind Energy  Solar Energy
# 0      2012-01-01 00:00:00     0.168265           0.0
# 1      2012-01-01 01:00:00     0.168265           0.0
# 2      2012-01-01 02:00:00     0.168265           0.0
# 3      2012-01-01 03:00:00     0.168265           0.0
# 4      2012-01-01 04:00:00     0.168265           0.0
# ...                    ...          ...           ...
# 78907  2020-12-31 19:00:00     1.710441           0.0
# 78908  2020-12-31 20:00:00     1.710441           0.0
# 78909  2020-12-31 21:00:00     1.497873           0.0
# 78910  2020-12-31 22:00:00     1.285454           0.0
# 78911  2020-12-31 23:00:00     1.286778           0.0
#
# [78912 rows x 3 columns]

# %%
class House:
    cols = ['energy_kWh', 'electronics workbench energy', 'network equipment energy',
            'home office energy', 'RAE home office energy', 'RAE Mobile Phone Charger Energy']
    def __init__(self, house):
        self.house = house
        self.consumption_df = house_wise_consumption[house].copy()[House.cols].astype(float)
        self.train_dates_df = house_wise_consumption[house]['timestamp']
        self.prepare_dataset(n_future, n_past)
    
    def __repr__(self):
        return str(self.house)
    
    def prepare_dataset(self, n_future = 1, n_past = 14):
        #Empty lists to be populated using formatted training data
        trainX = []
        trainY = []
        consumption_np = np.array(self.consumption_df)
        #Reformat input data into a shape: (n_samples x timesteps x n_features)
        #In my example, my self.consumption_df has a shape (12823, 5)
        #12823 refers to the number of data points and 5 refers to the columns (multi-variables).
        for i in range(n_past, len(consumption_np) - n_future +1):
            trainX.append(consumption_np[i - n_past:i, 0:self.consumption_df.shape[1]])
            trainY.append(consumption_np[i + n_future - 1:i + n_future, 0])

        trainX, trainY = np.array(trainX), np.array(trainY)

        #print('trainX shape == {}.'.format(trainX.shape))
        #print('trainY shape == {}.'.format(trainY.shape))
        self.trainX = trainX
        self.trainY = trainY

class Cluster: 
    def __init__(self, houses):
        self.houses = [House(house) for house in houses]
        self.trainX_list = (list(map(lambda x: x.trainX, self.houses)))
        self.trainY_list = (list(map(lambda x: x.trainY, self.houses)))
        self.train_dates_list = (list(map(lambda x: x.train_dates_df, self.houses)))
        self.consumption_df_list = (list(map(lambda x: x.consumption_df, self.houses)))
        self.prepare_dataset()
        
    
    def prepare_dataset(self):
        
        self.train_dates = np.concatenate(self.train_dates_list, axis=0)
        ## TODO - Replace concatenate with for loop or sort by time
        self.X = np.concatenate(self.trainX_list, axis=0)
        self.Y = np.concatenate(self.trainY_list, axis=0)
    
    
    def prepare_ANN_model(self):
        model = Sequential()
        #model.add(Dense(1, activation='relu', input_shape=(self.X.shape[1], self.X.shape[2])))
        model.add(Dense(128, activation='relu', input_shape=(self.X.shape[1], self.X.shape[2]), return_sequences=True))
        model.add(Dense(32, activation='relu', return_sequences=True))
        model.add(Dense(16, activation='relu', return_sequences=False))
        model.add(Dense(self.Y.shape[1]))
        model.compile(optimizer='adam', loss='mse', metrics=[tf.keras.metrics.RootMeanSquaredError(), tf.keras.metrics.MeanAbsoluteError()])
        model.summary()
        return model
    
    def prepare_RNN_model(self):
        model = Sequential()
        #model.add(SimpleRNN(1, activation='relu', input_shape=(self.X.shape[1], self.X.shape[2]), return_sequences=True))
        model.add(SimpleRNN(128, activation='relu', input_shape=(self.X.shape[1], self.X.shape[2]), return_sequences=True))
        model.add(SimpleRNN(32, activation='relu', return_sequences=True))
        model.add(SimpleRNN(16, activation='relu', return_sequences=False))
        model.add(Dense(self.Y.shape[1]))
        model.compile(optimizer='adam', loss='mse', metrics=[tf.keras.metrics.RootMeanSquaredError(), tf.keras.metrics.MeanAbsoluteError()])
        model.summary()
        return model
    
    def prepare_LSTM_model(self):
        model = Sequential()
        #model.add(LSTM(1, activation='relu', input_shape=(self.X.shape[1], self.X.shape[2]), return_sequences=True))
        model.add(LSTM(128, activation='relu', input_shape=(self.X.shape[1], self.X.shape[2]), return_sequences=True))
        model.add(LSTM(32, activation='relu', return_sequences=True))
        model.add(LSTM(16, activation='relu', return_sequences=False))
        model.add(Dense(self.Y.shape[1]))
        model.compile(optimizer='adam', loss='mse', metrics=[tf.keras.metrics.RootMeanSquaredError(), tf.keras.metrics.MeanAbsoluteError()])
        model.summary()
        return model
    
    def train_model(self, model_name='LSTM'):
        if model_name == 'LSTM':
            model = self.prepare_LSTM_model()
        if model_name == 'RNN':
            model = self.prepare_RNN_model()    
        if model_name == 'ANN':
            model = self.prepare_ANN_model()    
        history = model.fit(self.X, self.Y, epochs=30, batch_size=16, validation_split=0.3, verbose=1) # Change to 30
        self.history = history
        plt.plot(history.history['loss'], label='Training loss')
        plt.plot(history.history['val_loss'], label='Testing loss')
        
        plt.legend()
        return model
    
    def predicted(self, model_name='LSTM'):
        model = self.train_model(model_name)
        predictions = list(map(lambda x: pd.Series(model.predict(x).reshape(1,-1)[0]), self.trainX_list))
        #return pd.Series(model.predict(self.X).reshape(1,-1)[0])
        self.model = model
        return dict(zip(self.houses, predictions))
    
    def results(self, model_name='LSTM'):
        predicted = self.predicted(model_name)
        house_prediction_list_df  = {}
        for house in predicted:
            house_prediction_df = house.consumption_df.iloc[n_past:].copy().reset_index(drop=True)
            house_prediction_df['timestamp'] = house.train_dates_df.iloc[n_past:].copy().reset_index(drop=True)
            house_prediction_df['energy_predicted'] = predicted[house]
            ### Anomaly Detection
            energy_stddev = house_prediction_df['energy_kWh'].std()
            house_prediction_df['Energy Consumption Error'] = house_prediction_df['energy_predicted'] - house_prediction_df['energy_kWh']
            house_prediction_df['Anomaly detected'] = house_prediction_df['Energy Consumption Error'].apply(lambda x: False if abs(x) < 1.5*energy_stddev else abs(x))
            ### Energy Deficit Calculation
            house_prediction_df['timestamp'] = pd.DatetimeIndex(house_prediction_df['timestamp'])
            generation_df['timestamp'] = pd.DatetimeIndex(generation_df['timestamp'])
            house_prediction_df = house_prediction_df.set_index('timestamp').join(generation_df.set_index('timestamp'))
            house_prediction_df['timestamp'] = house_prediction_df.index
            house_prediction_df.reset_index(drop=True, inplace=True)
            house_prediction_df['Total Generated Energy'] = house_prediction_df['Wind Energy']+ house_prediction_df['Solar Energy']
            house_prediction_df['Predicted Energy Deficit'] = house_prediction_df['Total Generated Energy'] - house_prediction_df['energy_predicted']
            house_prediction_df['Energy Deficit Flag'] = house_prediction_df['Predicted Energy Deficit'].apply(lambda x: False if x>0 else abs(x))
            house_prediction_list_df[house.house] = house_prediction_df
        return house_prediction_list_df

# %% [markdown]
# ## Model Name

# %%
model_name='LSTM'

# %% [markdown]
# #### Scenario 1

# %%
# Train the time series model, perform predictions and answer the three research questions
zero_houses = list(clustered_df[clustered_df['Cluster'] == 0]['House'])
print(zero_houses)
zero_cluster = Cluster(zero_houses)
zero_cluster_results = zero_cluster.results(model_name)
print('Training History for Cluster 0:')
# Out:
# [1, 4, 13, 14, 18, 19, 28]
# 2022-03-29 09:20:37.594449: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-03-29 09:20:37.594472: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-03-29 09:20:37.594487: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (rishabh-Inspiron): /proc/driver/nvidia/version does not exist
# 2022-03-29 09:20:37.594833: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 14, 128)           69120
#
#  lstm_1 (LSTM)               (None, 14, 32)            20608
#
#  lstm_2 (LSTM)               (None, 16)                3136
#
#  dense (Dense)               (None, 1)                 17
#
# =================================================================
# Total params: 92,881
# Trainable params: 92,881
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 7680/7680 [==============================] - 123s 16ms/step - loss: 0.4956 - root_mean_squared_error: 0.7040 - mean_absolute_error: 0.4325 - val_loss: 0.6155 - val_root_mean_squared_error: 0.7845 - val_mean_absolute_error: 0.4553
# Epoch 2/30
# 7680/7680 [==============================] - 149s 19ms/step - loss: 0.4498 - root_mean_squared_error: 0.6706 - mean_absolute_error: 0.4030 - val_loss: 0.6123 - val_root_mean_squared_error: 0.7825 - val_mean_absolute_error: 0.4589
# Epoch 3/30
# 7680/7680 [==============================] - 152s 20ms/step - loss: 0.4419 - root_mean_squared_error: 0.6648 - mean_absolute_error: 0.3977 - val_loss: 0.6596 - val_root_mean_squared_error: 0.8122 - val_mean_absolute_error: 0.4492
# Epoch 4/30
# 7680/7680 [==============================] - 127s 17ms/step - loss: 0.4375 - root_mean_squared_error: 0.6614 - mean_absolute_error: 0.3943 - val_loss: 0.6067 - val_root_mean_squared_error: 0.7789 - val_mean_absolute_error: 0.4495
# Epoch 5/30
# 7680/7680 [==============================] - 131s 17ms/step - loss: 0.4340 - root_mean_squared_error: 0.6588 - mean_absolute_error: 0.3921 - val_loss: 0.6188 - val_root_mean_squared_error: 0.7866 - val_mean_absolute_error: 0.4593
# Epoch 6/30
# 7680/7680 [==============================] - 126s 16ms/step - loss: 0.4310 - root_mean_squared_error: 0.6565 - mean_absolute_error: 0.3905 - val_loss: 0.6107 - val_root_mean_squared_error: 0.7815 - val_mean_absolute_error: 0.4614
# Epoch 7/30
# 7680/7680 [==============================] - 146s 19ms/step - loss: 0.4293 - root_mean_squared_error: 0.6552 - mean_absolute_error: 0.3887 - val_loss: 0.6094 - val_root_mean_squared_error: 0.7807 - val_mean_absolute_error: 0.4437
# Epoch 8/30
# 7680/7680 [==============================] - 135s 18ms/step - loss: 0.4268 - root_mean_squared_error: 0.6533 - mean_absolute_error: 0.3879 - val_loss: 0.6255 - val_root_mean_squared_error: 0.7909 - val_mean_absolute_error: 0.4472
# Epoch 9/30
# 7680/7680 [==============================] - 130s 17ms/step - loss: 0.4257 - root_mean_squared_error: 0.6525 - mean_absolute_error: 0.3867 - val_loss: 0.6360 - val_root_mean_squared_error: 0.7975 - val_mean_absolute_error: 0.4551
# Epoch 10/30
# 7680/7680 [==============================] - 127s 17ms/step - loss: 0.4237 - root_mean_squared_error: 0.6509 - mean_absolute_error: 0.3861 - val_loss: 0.6164 - val_root_mean_squared_error: 0.7851 - val_mean_absolute_error: 0.4531
# Epoch 11/30
# 7680/7680 [==============================] - 128s 17ms/step - loss: 0.4218 - root_mean_squared_error: 0.6495 - mean_absolute_error: 0.3849 - val_loss: 0.6307 - val_root_mean_squared_error: 0.7941 - val_mean_absolute_error: 0.4518
# Epoch 12/30
# 7680/7680 [==============================] - 130s 17ms/step - loss: 0.4203 - root_mean_squared_error: 0.6483 - mean_absolute_error: 0.3846 - val_loss: 0.6381 - val_root_mean_squared_error: 0.7988 - val_mean_absolute_error: 0.4496
# Epoch 13/30
# 7680/7680 [==============================] - 130s 17ms/step - loss: 0.4192 - root_mean_squared_error: 0.6475 - mean_absolute_error: 0.3840 - val_loss: 0.6477 - val_root_mean_squared_error: 0.8048 - val_mean_absolute_error: 0.4550
# Epoch 14/30
# 7680/7680 [==============================] - 130s 17ms/step - loss: 0.4180 - root_mean_squared_error: 0.6465 - mean_absolute_error: 0.3836 - val_loss: 0.6083 - val_root_mean_squared_error: 0.7799 - val_mean_absolute_error: 0.4550
# Epoch 15/30
# 7680/7680 [==============================] - 130s 17ms/step - loss: 0.4166 - root_mean_squared_error: 0.6454 - mean_absolute_error: 0.3829 - val_loss: 0.6700 - val_root_mean_squared_error: 0.8185 - val_mean_absolute_error: 0.4629
# Epoch 16/30
# 7680/7680 [==============================] - 139s 18ms/step - loss: 0.4153 - root_mean_squared_error: 0.6444 - mean_absolute_error: 0.3820 - val_loss: 0.6396 - val_root_mean_squared_error: 0.7997 - val_mean_absolute_error: 0.4603
# Epoch 17/30
# 7680/7680 [==============================] - 147s 19ms/step - loss: 0.4138 - root_mean_squared_error: 0.6432 - mean_absolute_error: 0.3819 - val_loss: 0.6322 - val_root_mean_squared_error: 0.7951 - val_mean_absolute_error: 0.4561
# Epoch 18/30
# 7680/7680 [==============================] - 151s 20ms/step - loss: 0.4120 - root_mean_squared_error: 0.6419 - mean_absolute_error: 0.3814 - val_loss: 0.6558 - val_root_mean_squared_error: 0.8098 - val_mean_absolute_error: 0.4516
# Epoch 19/30
# 7680/7680 [==============================] - 140s 18ms/step - loss: 0.4122 - root_mean_squared_error: 0.6420 - mean_absolute_error: 0.3807 - val_loss: 0.6377 - val_root_mean_squared_error: 0.7985 - val_mean_absolute_error: 0.4515
# Epoch 20/30
# 7680/7680 [==============================] - 137s 18ms/step - loss: 0.4094 - root_mean_squared_error: 0.6399 - mean_absolute_error: 0.3805 - val_loss: 0.6817 - val_root_mean_squared_error: 0.8257 - val_mean_absolute_error: 0.4576
# Epoch 21/30
# 7680/7680 [==============================] - 136s 18ms/step - loss: 0.4081 - root_mean_squared_error: 0.6388 - mean_absolute_error: 0.3799 - val_loss: 0.6592 - val_root_mean_squared_error: 0.8119 - val_mean_absolute_error: 0.4597
# Epoch 22/30
# 7680/7680 [==============================] - 132s 17ms/step - loss: 0.4072 - root_mean_squared_error: 0.6381 - mean_absolute_error: 0.3793 - val_loss: 0.6495 - val_root_mean_squared_error: 0.8059 - val_mean_absolute_error: 0.4568
# Epoch 23/30
# 7680/7680 [==============================] - 132s 17ms/step - loss: 0.4059 - root_mean_squared_error: 0.6371 - mean_absolute_error: 0.3791 - val_loss: 0.6746 - val_root_mean_squared_error: 0.8213 - val_mean_absolute_error: 0.4585
# Epoch 24/30
# 7680/7680 [==============================] - 133s 17ms/step - loss: 0.4040 - root_mean_squared_error: 0.6356 - mean_absolute_error: 0.3784 - val_loss: 0.6465 - val_root_mean_squared_error: 0.8040 - val_mean_absolute_error: 0.4552
# Epoch 25/30
# 7680/7680 [==============================] - 143s 19ms/step - loss: 0.4027 - root_mean_squared_error: 0.6345 - mean_absolute_error: 0.3780 - val_loss: 0.6995 - val_root_mean_squared_error: 0.8364 - val_mean_absolute_error: 0.4635
# Epoch 26/30
# 7680/7680 [==============================] - 138s 18ms/step - loss: 0.4367 - root_mean_squared_error: 0.6608 - mean_absolute_error: 0.3862 - val_loss: 0.6528 - val_root_mean_squared_error: 0.8080 - val_mean_absolute_error: 0.4587
# Epoch 27/30
# 7680/7680 [==============================] - 133s 17ms/step - loss: 0.4188 - root_mean_squared_error: 0.6472 - mean_absolute_error: 0.3841 - val_loss: 0.6734 - val_root_mean_squared_error: 0.8206 - val_mean_absolute_error: 0.4633
# Epoch 28/30
# 7680/7680 [==============================] - 133s 17ms/step - loss: 0.4135 - root_mean_squared_error: 0.6430 - mean_absolute_error: 0.3820 - val_loss: 0.6717 - val_root_mean_squared_error: 0.8196 - val_mean_absolute_error: 0.4699
# Epoch 29/30
# 7680/7680 [==============================] - 134s 17ms/step - loss: 0.4080 - root_mean_squared_error: 0.6388 - mean_absolute_error: 0.3802 - val_loss: 0.6583 - val_root_mean_squared_error: 0.8114 - val_mean_absolute_error: 0.4616
# Epoch 30/30
# 7680/7680 [==============================] - 134s 18ms/step - loss: 0.4056 - root_mean_squared_error: 0.6369 - mean_absolute_error: 0.3791 - val_loss: 0.6493 - val_root_mean_squared_error: 0.8058 - val_mean_absolute_error: 0.4640
# Training History for Cluster 0:

# %%
one_houses = list(clustered_df[clustered_df['Cluster'] == 1]['House'])
one_cluster = Cluster(one_houses)
one_cluster_results = one_cluster.results(model_name)
print('Training History for Cluster 1:')
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_3 (LSTM)               (None, 14, 128)           69120
#
#  lstm_4 (LSTM)               (None, 14, 32)            20608
#
#  lstm_5 (LSTM)               (None, 16)                3136
#
#  dense_1 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 92,881
# Trainable params: 92,881
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 915/915 [==============================] - 18s 17ms/step - loss: 1.4689 - root_mean_squared_error: 1.2120 - mean_absolute_error: 0.7125 - val_loss: 1.8633 - val_root_mean_squared_error: 1.3650 - val_mean_absolute_error: 0.9202
# Epoch 2/30
# 915/915 [==============================] - 15s 17ms/step - loss: 1.0059 - root_mean_squared_error: 1.0030 - mean_absolute_error: 0.5720 - val_loss: 1.5327 - val_root_mean_squared_error: 1.2380 - val_mean_absolute_error: 0.5490
# Epoch 3/30
# 915/915 [==============================] - 15s 17ms/step - loss: 0.9286 - root_mean_squared_error: 0.9637 - mean_absolute_error: 0.5486 - val_loss: 1.3449 - val_root_mean_squared_error: 1.1597 - val_mean_absolute_error: 0.5227
# Epoch 4/30
# 915/915 [==============================] - 15s 17ms/step - loss: 0.8665 - root_mean_squared_error: 0.9309 - mean_absolute_error: 0.5316 - val_loss: 1.2015 - val_root_mean_squared_error: 1.0961 - val_mean_absolute_error: 0.5567
# Epoch 5/30
# 915/915 [==============================] - 15s 17ms/step - loss: 0.8737 - root_mean_squared_error: 0.9347 - mean_absolute_error: 0.5286 - val_loss: 1.2474 - val_root_mean_squared_error: 1.1169 - val_mean_absolute_error: 0.5101
# Epoch 6/30
# 915/915 [==============================] - 16s 17ms/step - loss: 0.8410 - root_mean_squared_error: 0.9170 - mean_absolute_error: 0.5227 - val_loss: 1.2268 - val_root_mean_squared_error: 1.1076 - val_mean_absolute_error: 0.5931
# Epoch 7/30
# 915/915 [==============================] - 15s 17ms/step - loss: 0.8226 - root_mean_squared_error: 0.9070 - mean_absolute_error: 0.5207 - val_loss: 1.2218 - val_root_mean_squared_error: 1.1053 - val_mean_absolute_error: 0.5309
# Epoch 8/30
# 915/915 [==============================] - 16s 17ms/step - loss: 0.7981 - root_mean_squared_error: 0.8934 - mean_absolute_error: 0.5077 - val_loss: 1.2389 - val_root_mean_squared_error: 1.1131 - val_mean_absolute_error: 0.6131
# Epoch 9/30
# 915/915 [==============================] - 16s 17ms/step - loss: 0.7814 - root_mean_squared_error: 0.8839 - mean_absolute_error: 0.5074 - val_loss: 1.0767 - val_root_mean_squared_error: 1.0377 - val_mean_absolute_error: 0.5579
# Epoch 10/30
# 915/915 [==============================] - 15s 17ms/step - loss: 0.7856 - root_mean_squared_error: 0.8864 - mean_absolute_error: 0.5025 - val_loss: 1.4955 - val_root_mean_squared_error: 1.2229 - val_mean_absolute_error: 0.6200
# Epoch 11/30
# 915/915 [==============================] - 15s 17ms/step - loss: 0.7767 - root_mean_squared_error: 0.8813 - mean_absolute_error: 0.5011 - val_loss: 1.0966 - val_root_mean_squared_error: 1.0472 - val_mean_absolute_error: 0.5086
# Epoch 12/30
# 915/915 [==============================] - 16s 17ms/step - loss: 0.7609 - root_mean_squared_error: 0.8723 - mean_absolute_error: 0.4950 - val_loss: 1.1398 - val_root_mean_squared_error: 1.0676 - val_mean_absolute_error: 0.5478
# Epoch 13/30
# 915/915 [==============================] - 15s 17ms/step - loss: 0.7461 - root_mean_squared_error: 0.8638 - mean_absolute_error: 0.4892 - val_loss: 1.1912 - val_root_mean_squared_error: 1.0914 - val_mean_absolute_error: 0.5637
# Epoch 14/30
# 915/915 [==============================] - 15s 17ms/step - loss: 0.7521 - root_mean_squared_error: 0.8672 - mean_absolute_error: 0.4939 - val_loss: 1.0877 - val_root_mean_squared_error: 1.0429 - val_mean_absolute_error: 0.5440
# Epoch 15/30
# 915/915 [==============================] - 15s 17ms/step - loss: 0.7490 - root_mean_squared_error: 0.8655 - mean_absolute_error: 0.4899 - val_loss: 1.1486 - val_root_mean_squared_error: 1.0717 - val_mean_absolute_error: 0.5267
# Epoch 16/30
# 915/915 [==============================] - 15s 17ms/step - loss: 0.7278 - root_mean_squared_error: 0.8531 - mean_absolute_error: 0.4836 - val_loss: 1.1536 - val_root_mean_squared_error: 1.0740 - val_mean_absolute_error: 0.5104
# Epoch 17/30
# 915/915 [==============================] - 16s 17ms/step - loss: 0.7160 - root_mean_squared_error: 0.8462 - mean_absolute_error: 0.4790 - val_loss: 1.1217 - val_root_mean_squared_error: 1.0591 - val_mean_absolute_error: 0.4868
# Epoch 18/30
# 915/915 [==============================] - 15s 17ms/step - loss: 0.7229 - root_mean_squared_error: 0.8502 - mean_absolute_error: 0.4842 - val_loss: 1.0412 - val_root_mean_squared_error: 1.0204 - val_mean_absolute_error: 0.5109
# Epoch 19/30
# 915/915 [==============================] - 15s 17ms/step - loss: 0.7081 - root_mean_squared_error: 0.8415 - mean_absolute_error: 0.4771 - val_loss: 1.1398 - val_root_mean_squared_error: 1.0676 - val_mean_absolute_error: 0.5654
# Epoch 20/30
# 915/915 [==============================] - 15s 17ms/step - loss: 0.7106 - root_mean_squared_error: 0.8429 - mean_absolute_error: 0.4790 - val_loss: 1.1404 - val_root_mean_squared_error: 1.0679 - val_mean_absolute_error: 0.5318
# Epoch 21/30
# 915/915 [==============================] - 16s 18ms/step - loss: 0.6921 - root_mean_squared_error: 0.8319 - mean_absolute_error: 0.4716 - val_loss: 1.2243 - val_root_mean_squared_error: 1.1065 - val_mean_absolute_error: 0.5216
# Epoch 22/30
# 915/915 [==============================] - 15s 17ms/step - loss: 0.6996 - root_mean_squared_error: 0.8364 - mean_absolute_error: 0.4720 - val_loss: 1.0234 - val_root_mean_squared_error: 1.0116 - val_mean_absolute_error: 0.5297
# Epoch 23/30
# 915/915 [==============================] - 15s 17ms/step - loss: 0.6792 - root_mean_squared_error: 0.8241 - mean_absolute_error: 0.4680 - val_loss: 1.1915 - val_root_mean_squared_error: 1.0916 - val_mean_absolute_error: 0.5248
# Epoch 24/30
# 915/915 [==============================] - 16s 17ms/step - loss: 0.6762 - root_mean_squared_error: 0.8223 - mean_absolute_error: 0.4685 - val_loss: 1.0335 - val_root_mean_squared_error: 1.0166 - val_mean_absolute_error: 0.5000
# Epoch 25/30
# 915/915 [==============================] - 16s 17ms/step - loss: 0.6760 - root_mean_squared_error: 0.8222 - mean_absolute_error: 0.4648 - val_loss: 1.0151 - val_root_mean_squared_error: 1.0075 - val_mean_absolute_error: 0.5227
# Epoch 26/30
# 915/915 [==============================] - 16s 17ms/step - loss: 0.6743 - root_mean_squared_error: 0.8211 - mean_absolute_error: 0.4650 - val_loss: 1.0711 - val_root_mean_squared_error: 1.0350 - val_mean_absolute_error: 0.5079
# Epoch 27/30
# 915/915 [==============================] - 16s 17ms/step - loss: 0.6636 - root_mean_squared_error: 0.8146 - mean_absolute_error: 0.4633 - val_loss: 1.0727 - val_root_mean_squared_error: 1.0357 - val_mean_absolute_error: 0.5089
# Epoch 28/30
# 915/915 [==============================] - 16s 17ms/step - loss: 0.6570 - root_mean_squared_error: 0.8105 - mean_absolute_error: 0.4585 - val_loss: 1.2172 - val_root_mean_squared_error: 1.1033 - val_mean_absolute_error: 0.5835
# Epoch 29/30
# 915/915 [==============================] - 16s 17ms/step - loss: 0.6647 - root_mean_squared_error: 0.8153 - mean_absolute_error: 0.4649 - val_loss: 1.0825 - val_root_mean_squared_error: 1.0404 - val_mean_absolute_error: 0.5030
# Epoch 30/30
# 915/915 [==============================] - 16s 17ms/step - loss: 0.6695 - root_mean_squared_error: 0.8182 - mean_absolute_error: 0.4630 - val_loss: 1.1554 - val_root_mean_squared_error: 1.0749 - val_mean_absolute_error: 0.5405
# Training History for Cluster 1:

# %%
two_houses = list(clustered_df[clustered_df['Cluster'] == 2]['House'])
two_cluster = Cluster(two_houses)
two_cluster_results = two_cluster.results(model_name)
print('Training History for Cluster 2:')
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_6 (LSTM)               (None, 14, 128)           69120
#
#  lstm_7 (LSTM)               (None, 14, 32)            20608
#
#  lstm_8 (LSTM)               (None, 16)                3136
#
#  dense_2 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 92,881
# Trainable params: 92,881
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 15194/15194 [==============================] - 257s 17ms/step - loss: 0.1526 - root_mean_squared_error: 0.3906 - mean_absolute_error: 0.2208 - val_loss: 0.2081 - val_root_mean_squared_error: 0.4562 - val_mean_absolute_error: 0.2614
# Epoch 2/30
# 15194/15194 [==============================] - 260s 17ms/step - loss: 0.1449 - root_mean_squared_error: 0.3806 - mean_absolute_error: 0.2102 - val_loss: 0.2094 - val_root_mean_squared_error: 0.4576 - val_mean_absolute_error: 0.2497
# Epoch 3/30
# 15194/15194 [==============================] - 289s 19ms/step - loss: 0.1437 - root_mean_squared_error: 0.3791 - mean_absolute_error: 0.2086 - val_loss: 0.2048 - val_root_mean_squared_error: 0.4526 - val_mean_absolute_error: 0.2564
# Epoch 4/30
# 15194/15194 [==============================] - 279s 18ms/step - loss: 0.1426 - root_mean_squared_error: 0.3777 - mean_absolute_error: 0.2076 - val_loss: 0.2085 - val_root_mean_squared_error: 0.4566 - val_mean_absolute_error: 0.2641
# Epoch 5/30
# 15194/15194 [==============================] - 276s 18ms/step - loss: 0.1422 - root_mean_squared_error: 0.3772 - mean_absolute_error: 0.2071 - val_loss: 0.2072 - val_root_mean_squared_error: 0.4552 - val_mean_absolute_error: 0.2548
# Epoch 6/30
# 15194/15194 [==============================] - 273s 18ms/step - loss: 0.1417 - root_mean_squared_error: 0.3764 - mean_absolute_error: 0.2065 - val_loss: 0.2050 - val_root_mean_squared_error: 0.4528 - val_mean_absolute_error: 0.2524
# Epoch 7/30
# 15194/15194 [==============================] - 277s 18ms/step - loss: 0.1414 - root_mean_squared_error: 0.3760 - mean_absolute_error: 0.2063 - val_loss: 0.2071 - val_root_mean_squared_error: 0.4551 - val_mean_absolute_error: 0.2544
# Epoch 8/30
# 15194/15194 [==============================] - 252s 17ms/step - loss: 0.1408 - root_mean_squared_error: 0.3752 - mean_absolute_error: 0.2058 - val_loss: 0.2130 - val_root_mean_squared_error: 0.4615 - val_mean_absolute_error: 0.2479
# Epoch 9/30
# 15194/15194 [==============================] - 249s 16ms/step - loss: 0.1406 - root_mean_squared_error: 0.3749 - mean_absolute_error: 0.2057 - val_loss: 0.2052 - val_root_mean_squared_error: 0.4530 - val_mean_absolute_error: 0.2537
# Epoch 10/30
# 15194/15194 [==============================] - 250s 16ms/step - loss: 0.1403 - root_mean_squared_error: 0.3745 - mean_absolute_error: 0.2055 - val_loss: 0.2083 - val_root_mean_squared_error: 0.4564 - val_mean_absolute_error: 0.2516
# Epoch 11/30
# 15194/15194 [==============================] - 249s 16ms/step - loss: 0.1398 - root_mean_squared_error: 0.3739 - mean_absolute_error: 0.2050 - val_loss: 0.2054 - val_root_mean_squared_error: 0.4532 - val_mean_absolute_error: 0.2516
# Epoch 12/30
# 15194/15194 [==============================] - 250s 16ms/step - loss: 0.1395 - root_mean_squared_error: 0.3736 - mean_absolute_error: 0.2048 - val_loss: 0.2066 - val_root_mean_squared_error: 0.4545 - val_mean_absolute_error: 0.2489
# Epoch 13/30
# 15194/15194 [==============================] - 251s 17ms/step - loss: 0.1394 - root_mean_squared_error: 0.3734 - mean_absolute_error: 0.2045 - val_loss: 0.2064 - val_root_mean_squared_error: 0.4543 - val_mean_absolute_error: 0.2482
# Epoch 14/30
# 15194/15194 [==============================] - 251s 17ms/step - loss: 0.1389 - root_mean_squared_error: 0.3727 - mean_absolute_error: 0.2044 - val_loss: 0.2059 - val_root_mean_squared_error: 0.4537 - val_mean_absolute_error: 0.2514
# Epoch 15/30
# 15194/15194 [==============================] - 251s 17ms/step - loss: 0.1385 - root_mean_squared_error: 0.3721 - mean_absolute_error: 0.2041 - val_loss: 0.2079 - val_root_mean_squared_error: 0.4559 - val_mean_absolute_error: 0.2480
# Epoch 16/30
# 15194/15194 [==============================] - 254s 17ms/step - loss: 0.1382 - root_mean_squared_error: 0.3718 - mean_absolute_error: 0.2038 - val_loss: 0.2065 - val_root_mean_squared_error: 0.4544 - val_mean_absolute_error: 0.2512
# Epoch 17/30
# 15194/15194 [==============================] - 252s 17ms/step - loss: 0.1379 - root_mean_squared_error: 0.3713 - mean_absolute_error: 0.2036 - val_loss: 0.2081 - val_root_mean_squared_error: 0.4562 - val_mean_absolute_error: 0.2532
# Epoch 18/30
# 15194/15194 [==============================] - 249s 16ms/step - loss: 0.1375 - root_mean_squared_error: 0.3708 - mean_absolute_error: 0.2033 - val_loss: 0.2103 - val_root_mean_squared_error: 0.4586 - val_mean_absolute_error: 0.2517
# Epoch 19/30
# 15194/15194 [==============================] - 260s 17ms/step - loss: 0.1373 - root_mean_squared_error: 0.3706 - mean_absolute_error: 0.2032 - val_loss: 0.2068 - val_root_mean_squared_error: 0.4547 - val_mean_absolute_error: 0.2489
# Epoch 20/30
# 15194/15194 [==============================] - 258s 17ms/step - loss: 0.1370 - root_mean_squared_error: 0.3701 - mean_absolute_error: 0.2030 - val_loss: 0.2098 - val_root_mean_squared_error: 0.4581 - val_mean_absolute_error: 0.2477
# Epoch 21/30
# 15194/15194 [==============================] - 267s 18ms/step - loss: 0.1370 - root_mean_squared_error: 0.3701 - mean_absolute_error: 0.2029 - val_loss: 0.2083 - val_root_mean_squared_error: 0.4564 - val_mean_absolute_error: 0.2454
# Epoch 22/30
# 15194/15194 [==============================] - 310s 20ms/step - loss: 0.1363 - root_mean_squared_error: 0.3692 - mean_absolute_error: 0.2024 - val_loss: 0.2102 - val_root_mean_squared_error: 0.4585 - val_mean_absolute_error: 0.2533
# Epoch 23/30
# 15194/15194 [==============================] - 256s 17ms/step - loss: 0.1361 - root_mean_squared_error: 0.3689 - mean_absolute_error: 0.2025 - val_loss: 0.2101 - val_root_mean_squared_error: 0.4584 - val_mean_absolute_error: 0.2509
# Epoch 24/30
# 15194/15194 [==============================] - 295s 19ms/step - loss: 0.1358 - root_mean_squared_error: 0.3685 - mean_absolute_error: 0.2024 - val_loss: 0.2076 - val_root_mean_squared_error: 0.4556 - val_mean_absolute_error: 0.2495
# Epoch 25/30
# 15194/15194 [==============================] - 292s 19ms/step - loss: 0.1356 - root_mean_squared_error: 0.3682 - mean_absolute_error: 0.2019 - val_loss: 0.2096 - val_root_mean_squared_error: 0.4578 - val_mean_absolute_error: 0.2545
# Epoch 26/30
# 15194/15194 [==============================] - 286s 19ms/step - loss: 0.1352 - root_mean_squared_error: 0.3677 - mean_absolute_error: 0.2020 - val_loss: 0.2086 - val_root_mean_squared_error: 0.4567 - val_mean_absolute_error: 0.2534
# Epoch 27/30
# 15194/15194 [==============================] - 284s 19ms/step - loss: 0.1348 - root_mean_squared_error: 0.3672 - mean_absolute_error: 0.2017 - val_loss: 0.2097 - val_root_mean_squared_error: 0.4580 - val_mean_absolute_error: 0.2541
# Epoch 28/30
# 15194/15194 [==============================] - 274s 18ms/step - loss: 0.1348 - root_mean_squared_error: 0.3671 - mean_absolute_error: 0.2017 - val_loss: 0.2086 - val_root_mean_squared_error: 0.4567 - val_mean_absolute_error: 0.2533
# Epoch 29/30
# 15194/15194 [==============================] - 273s 18ms/step - loss: 0.1340 - root_mean_squared_error: 0.3661 - mean_absolute_error: 0.2013 - val_loss: 0.2257 - val_root_mean_squared_error: 0.4751 - val_mean_absolute_error: 0.2485
# Epoch 30/30
# 15194/15194 [==============================] - 275s 18ms/step - loss: 0.3127 - root_mean_squared_error: 0.5592 - mean_absolute_error: 0.2068 - val_loss: 0.2296 - val_root_mean_squared_error: 0.4791 - val_mean_absolute_error: 0.2582
# Training History for Cluster 2:

# %%
three_houses = list(clustered_df[clustered_df['Cluster'] == 3]['House'])
three_cluster = Cluster(three_houses)
three_cluster_results = three_cluster.results(model_name)
print('Training History for Cluster 3:')
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_9 (LSTM)               (None, 14, 128)           69120
#
#  lstm_10 (LSTM)              (None, 14, 32)            20608
#
#  lstm_11 (LSTM)              (None, 16)                3136
#
#  dense_3 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 92,881
# Trainable params: 92,881
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 2745/2745 [==============================] - 65s 23ms/step - loss: 0.4054 - root_mean_squared_error: 0.6367 - mean_absolute_error: 0.4180 - val_loss: 0.4141 - val_root_mean_squared_error: 0.6435 - val_mean_absolute_error: 0.4194
# Epoch 2/30
# 2745/2745 [==============================] - 52s 19ms/step - loss: 0.3641 - root_mean_squared_error: 0.6034 - mean_absolute_error: 0.3836 - val_loss: 0.4065 - val_root_mean_squared_error: 0.6376 - val_mean_absolute_error: 0.3661
# Epoch 3/30
# 2745/2745 [==============================] - 48s 18ms/step - loss: 0.3547 - root_mean_squared_error: 0.5956 - mean_absolute_error: 0.3769 - val_loss: 0.4052 - val_root_mean_squared_error: 0.6366 - val_mean_absolute_error: 0.3669
# Epoch 4/30
# 2745/2745 [==============================] - 48s 17ms/step - loss: 0.3450 - root_mean_squared_error: 0.5874 - mean_absolute_error: 0.3684 - val_loss: 0.4121 - val_root_mean_squared_error: 0.6419 - val_mean_absolute_error: 0.4314
# Epoch 5/30
# 2745/2745 [==============================] - 48s 17ms/step - loss: 0.3371 - root_mean_squared_error: 0.5806 - mean_absolute_error: 0.3612 - val_loss: 0.4243 - val_root_mean_squared_error: 0.6514 - val_mean_absolute_error: 0.4038
# Epoch 6/30
# 2745/2745 [==============================] - 47s 17ms/step - loss: 0.3319 - root_mean_squared_error: 0.5761 - mean_absolute_error: 0.3573 - val_loss: 0.3915 - val_root_mean_squared_error: 0.6257 - val_mean_absolute_error: 0.3655
# Epoch 7/30
# 2745/2745 [==============================] - 48s 18ms/step - loss: 0.3287 - root_mean_squared_error: 0.5733 - mean_absolute_error: 0.3547 - val_loss: 0.3752 - val_root_mean_squared_error: 0.6125 - val_mean_absolute_error: 0.3763
# Epoch 8/30
# 2745/2745 [==============================] - 49s 18ms/step - loss: 0.3255 - root_mean_squared_error: 0.5705 - mean_absolute_error: 0.3518 - val_loss: 0.3769 - val_root_mean_squared_error: 0.6139 - val_mean_absolute_error: 0.3656
# Epoch 9/30
# 2745/2745 [==============================] - 48s 18ms/step - loss: 0.3223 - root_mean_squared_error: 0.5677 - mean_absolute_error: 0.3504 - val_loss: 0.4123 - val_root_mean_squared_error: 0.6421 - val_mean_absolute_error: 0.4119
# Epoch 10/30
# 2745/2745 [==============================] - 48s 18ms/step - loss: 0.3202 - root_mean_squared_error: 0.5659 - mean_absolute_error: 0.3481 - val_loss: 0.3942 - val_root_mean_squared_error: 0.6278 - val_mean_absolute_error: 0.3789
# Epoch 11/30
# 2745/2745 [==============================] - 48s 17ms/step - loss: 0.3175 - root_mean_squared_error: 0.5635 - mean_absolute_error: 0.3459 - val_loss: 0.3833 - val_root_mean_squared_error: 0.6191 - val_mean_absolute_error: 0.3997
# Epoch 12/30
# 2745/2745 [==============================] - 49s 18ms/step - loss: 0.3155 - root_mean_squared_error: 0.5617 - mean_absolute_error: 0.3435 - val_loss: 0.4255 - val_root_mean_squared_error: 0.6523 - val_mean_absolute_error: 0.3920
# Epoch 13/30
# 2745/2745 [==============================] - 48s 18ms/step - loss: 0.3133 - root_mean_squared_error: 0.5598 - mean_absolute_error: 0.3422 - val_loss: 0.3916 - val_root_mean_squared_error: 0.6258 - val_mean_absolute_error: 0.3740
# Epoch 14/30
# 2745/2745 [==============================] - 48s 18ms/step - loss: 0.3112 - root_mean_squared_error: 0.5579 - mean_absolute_error: 0.3400 - val_loss: 0.4150 - val_root_mean_squared_error: 0.6442 - val_mean_absolute_error: 0.4228
# Epoch 15/30
# 2745/2745 [==============================] - 54s 20ms/step - loss: 0.3094 - root_mean_squared_error: 0.5562 - mean_absolute_error: 0.3388 - val_loss: 0.4063 - val_root_mean_squared_error: 0.6375 - val_mean_absolute_error: 0.3780
# Epoch 16/30
# 2745/2745 [==============================] - 53s 19ms/step - loss: 0.3076 - root_mean_squared_error: 0.5546 - mean_absolute_error: 0.3377 - val_loss: 0.3860 - val_root_mean_squared_error: 0.6213 - val_mean_absolute_error: 0.3722
# Epoch 17/30
# 2745/2745 [==============================] - 53s 19ms/step - loss: 0.3061 - root_mean_squared_error: 0.5533 - mean_absolute_error: 0.3369 - val_loss: 0.3979 - val_root_mean_squared_error: 0.6308 - val_mean_absolute_error: 0.3842
# Epoch 18/30
# 2745/2745 [==============================] - 46s 17ms/step - loss: 0.3040 - root_mean_squared_error: 0.5513 - mean_absolute_error: 0.3357 - val_loss: 0.3968 - val_root_mean_squared_error: 0.6299 - val_mean_absolute_error: 0.3798
# Epoch 19/30
# 2745/2745 [==============================] - 47s 17ms/step - loss: 0.3021 - root_mean_squared_error: 0.5497 - mean_absolute_error: 0.3341 - val_loss: 0.4061 - val_root_mean_squared_error: 0.6373 - val_mean_absolute_error: 0.3885
# Epoch 20/30
# 2745/2745 [==============================] - 53s 19ms/step - loss: 0.3007 - root_mean_squared_error: 0.5483 - mean_absolute_error: 0.3334 - val_loss: 0.4219 - val_root_mean_squared_error: 0.6495 - val_mean_absolute_error: 0.4193
# Epoch 21/30
# 2745/2745 [==============================] - 56s 20ms/step - loss: 0.2984 - root_mean_squared_error: 0.5462 - mean_absolute_error: 0.3315 - val_loss: 0.4085 - val_root_mean_squared_error: 0.6391 - val_mean_absolute_error: 0.3747
# Epoch 22/30
# 2745/2745 [==============================] - 56s 20ms/step - loss: 0.2967 - root_mean_squared_error: 0.5447 - mean_absolute_error: 0.3310 - val_loss: 0.4058 - val_root_mean_squared_error: 0.6370 - val_mean_absolute_error: 0.3688
# Epoch 23/30
# 2745/2745 [==============================] - 49s 18ms/step - loss: 0.2955 - root_mean_squared_error: 0.5436 - mean_absolute_error: 0.3304 - val_loss: 0.4105 - val_root_mean_squared_error: 0.6407 - val_mean_absolute_error: 0.3749
# Epoch 24/30
# 2745/2745 [==============================] - 50s 18ms/step - loss: 0.2922 - root_mean_squared_error: 0.5405 - mean_absolute_error: 0.3281 - val_loss: 0.4068 - val_root_mean_squared_error: 0.6378 - val_mean_absolute_error: 0.3830
# Epoch 25/30
# 2745/2745 [==============================] - 80s 29ms/step - loss: 0.2910 - root_mean_squared_error: 0.5394 - mean_absolute_error: 0.3275 - val_loss: 0.4393 - val_root_mean_squared_error: 0.6628 - val_mean_absolute_error: 0.3925
# Epoch 26/30
# 2745/2745 [==============================] - 57s 21ms/step - loss: 0.2886 - root_mean_squared_error: 0.5372 - mean_absolute_error: 0.3262 - val_loss: 0.4202 - val_root_mean_squared_error: 0.6482 - val_mean_absolute_error: 0.3938
# Epoch 27/30
# 2745/2745 [==============================] - 57s 21ms/step - loss: 0.2873 - root_mean_squared_error: 0.5360 - mean_absolute_error: 0.3264 - val_loss: 0.4272 - val_root_mean_squared_error: 0.6536 - val_mean_absolute_error: 0.3740
# Epoch 28/30
# 2745/2745 [==============================] - 52s 19ms/step - loss: 0.2847 - root_mean_squared_error: 0.5336 - mean_absolute_error: 0.3242 - val_loss: 0.4250 - val_root_mean_squared_error: 0.6520 - val_mean_absolute_error: 0.3861
# Epoch 29/30
# 2745/2745 [==============================] - 51s 19ms/step - loss: 0.2840 - root_mean_squared_error: 0.5329 - mean_absolute_error: 0.3240 - val_loss: 0.4325 - val_root_mean_squared_error: 0.6576 - val_mean_absolute_error: 0.4044
# Epoch 30/30
# 2745/2745 [==============================] - 50s 18ms/step - loss: 0.2806 - root_mean_squared_error: 0.5297 - mean_absolute_error: 0.3219 - val_loss: 0.4561 - val_root_mean_squared_error: 0.6753 - val_mean_absolute_error: 0.3994
# Training History for Cluster 3:

# %%
## Save Scenario 1 models
zero_cluster.model.save(f'Models/Scenario1/{model_name}/zero_cluster')
one_cluster.model.save(f'Models/Scenario1/{model_name}/one_cluster')
two_cluster.model.save(f'Models/Scenario1/{model_name}/two_cluster')
three_cluster.model.save(f'Models/Scenario1/{model_name}/three_cluster')

## Pickling cluster and cluster results
zero_cluster_file = open(f"Models/Scenario1/Objects/{model_name}/zero_cluster.pickle", "wb")
pickle.dump(zero_cluster, zero_cluster_file)
zero_cluster_file.close()

one_cluster_file = open(f"Models/Scenario1/Objects/{model_name}/one_cluster.pickle", "wb")
pickle.dump(one_cluster, one_cluster_file)
one_cluster_file.close()

two_cluster_file = open(f"Models/Scenario1/Objects/{model_name}/two_cluster.pickle", "wb")
pickle.dump(two_cluster, two_cluster_file)
two_cluster_file.close()

three_cluster_file = open(f"Models/Scenario1/Objects/{model_name}/three_cluster.pickle", "wb")
pickle.dump(three_cluster, three_cluster_file)
three_cluster_file.close()

zero_cluster_results_file = open(f"Models/Scenario1/Objects/{model_name}/zero_cluster_results.pickle", "wb")
pickle.dump(zero_cluster_results, zero_cluster_results_file)
zero_cluster_results_file.close()

one_cluster_results_file = open(f"Models/Scenario1/Objects/{model_name}/one_cluster_results.pickle", "wb")
pickle.dump(one_cluster_results, one_cluster_results_file)
one_cluster_results_file.close()

two_cluster_results_file = open(f"Models/Scenario1/Objects/{model_name}/two_cluster_results.pickle", "wb")
pickle.dump(two_cluster_results, two_cluster_results_file)
two_cluster_results_file.close()

three_cluster_results_file = open(f"Models/Scenario1/Objects/{model_name}/three_cluster_results.pickle", "wb")
pickle.dump(three_cluster_results, three_cluster_results_file)
three_cluster_results_file.close()
# Out:
# 2022-03-29 13:17:19.503916: W tensorflow/python/util/util.cc:368] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# INFO:tensorflow:Assets written to: Models/Scenario1/LSTM/zero_cluster/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f6020919280> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f60205d5970> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f6020564a30> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# INFO:tensorflow:Assets written to: Models/Scenario1/LSTM/one_cluster/assets
# INFO:tensorflow:Assets written to: Models/Scenario1/LSTM/one_cluster/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f600d550a90> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f600d576400> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f600d4ceaf0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# INFO:tensorflow:Assets written to: Models/Scenario1/LSTM/two_cluster/assets
# INFO:tensorflow:Assets written to: Models/Scenario1/LSTM/two_cluster/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f600dc6ad60> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f600dc74130> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f600dcb35e0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# INFO:tensorflow:Assets written to: Models/Scenario1/LSTM/three_cluster/assets
# INFO:tensorflow:Assets written to: Models/Scenario1/LSTM/three_cluster/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f600c37ec10> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f600c3d85e0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f600c231670> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# INFO:tensorflow:Assets written to: ram://36a3c7b9-c902-4a15-8770-23d9dfd539c8/assets
# INFO:tensorflow:Assets written to: ram://36a3c7b9-c902-4a15-8770-23d9dfd539c8/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f6020919280> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f60205d5970> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f6020564a30> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# INFO:tensorflow:Assets written to: ram://78bc1fa1-1afc-4e4a-8d10-5e759c61fe9f/assets
# INFO:tensorflow:Assets written to: ram://78bc1fa1-1afc-4e4a-8d10-5e759c61fe9f/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f600d550a90> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f600d576400> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f600d4ceaf0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# INFO:tensorflow:Assets written to: ram://c8d254d4-31a5-4991-a76e-c1d97516ab28/assets
# INFO:tensorflow:Assets written to: ram://c8d254d4-31a5-4991-a76e-c1d97516ab28/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f600dc6ad60> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f600dc74130> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f600dcb35e0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# INFO:tensorflow:Assets written to: ram://d3fb2345-e7dc-41cb-83b4-8750baa48273/assets
# INFO:tensorflow:Assets written to: ram://d3fb2345-e7dc-41cb-83b4-8750baa48273/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f600c37ec10> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f600c3d85e0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f600c231670> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.

# %% [markdown]
# #### Scenario 2

# %%
all_houses = list(clustered_df['House'])
all_cluster = Cluster(all_houses)
all_cluster_results = all_cluster.results(model_name)
print('Training History without clustering:')
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_12 (LSTM)              (None, 14, 128)           69120
#
#  lstm_13 (LSTM)              (None, 14, 32)            20608
#
#  lstm_14 (LSTM)              (None, 16)                3136
#
#  dense_4 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 92,881
# Trainable params: 92,881
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 26534/26534 [==============================] - 734s 27ms/step - loss: 0.3347 - root_mean_squared_error: 0.5785 - mean_absolute_error: 0.3179 - val_loss: 0.4000 - val_root_mean_squared_error: 0.6324 - val_mean_absolute_error: 0.3210
# Epoch 2/30
# 26534/26534 [==============================] - 612s 23ms/step - loss: 0.3128 - root_mean_squared_error: 0.5593 - mean_absolute_error: 0.3027 - val_loss: 0.3343 - val_root_mean_squared_error: 0.5781 - val_mean_absolute_error: 0.3217
# Epoch 3/30
# 26534/26534 [==============================] - 626s 24ms/step - loss: 0.3084 - root_mean_squared_error: 0.5554 - mean_absolute_error: 0.3001 - val_loss: 0.3289 - val_root_mean_squared_error: 0.5735 - val_mean_absolute_error: 0.3277
# Epoch 4/30
# 26534/26534 [==============================] - 563s 21ms/step - loss: 0.3050 - root_mean_squared_error: 0.5522 - mean_absolute_error: 0.2988 - val_loss: 0.3772 - val_root_mean_squared_error: 0.6142 - val_mean_absolute_error: 0.3347
# Epoch 5/30
# 26534/26534 [==============================] - 468s 18ms/step - loss: 0.3020 - root_mean_squared_error: 0.5496 - mean_absolute_error: 0.2978 - val_loss: 0.3348 - val_root_mean_squared_error: 0.5786 - val_mean_absolute_error: 0.3177
# Epoch 6/30
# 26534/26534 [==============================] - 658s 25ms/step - loss: 0.2992 - root_mean_squared_error: 0.5470 - mean_absolute_error: 0.2967 - val_loss: 0.3428 - val_root_mean_squared_error: 0.5855 - val_mean_absolute_error: 0.3189
# Epoch 7/30
# 26534/26534 [==============================] - 1539s 58ms/step - loss: 0.2976 - root_mean_squared_error: 0.5456 - mean_absolute_error: 0.2960 - val_loss: 0.3578 - val_root_mean_squared_error: 0.5982 - val_mean_absolute_error: 0.3182
# Epoch 8/30
# 26534/26534 [==============================] - 643s 24ms/step - loss: 0.2962 - root_mean_squared_error: 0.5443 - mean_absolute_error: 0.2953 - val_loss: 0.3730 - val_root_mean_squared_error: 0.6107 - val_mean_absolute_error: 0.3196
# Epoch 9/30
# 26534/26534 [==============================] - 511s 19ms/step - loss: 0.2958 - root_mean_squared_error: 0.5438 - mean_absolute_error: 0.2948 - val_loss: 0.3718 - val_root_mean_squared_error: 0.6097 - val_mean_absolute_error: 0.3266
# Epoch 10/30
# 26534/26534 [==============================] - 606s 23ms/step - loss: 0.3043 - root_mean_squared_error: 0.5517 - mean_absolute_error: 0.2946 - val_loss: 0.3558 - val_root_mean_squared_error: 0.5965 - val_mean_absolute_error: 0.3260
# Epoch 11/30
# 26534/26534 [==============================] - 774s 29ms/step - loss: 0.2946 - root_mean_squared_error: 0.5428 - mean_absolute_error: 0.2940 - val_loss: 0.3415 - val_root_mean_squared_error: 0.5844 - val_mean_absolute_error: 0.3186
# Epoch 12/30
# 26534/26534 [==============================] - 721s 27ms/step - loss: 0.2929 - root_mean_squared_error: 0.5412 - mean_absolute_error: 0.2938 - val_loss: 0.3538 - val_root_mean_squared_error: 0.5948 - val_mean_absolute_error: 0.3180
# Epoch 13/30
# 26534/26534 [==============================] - 610s 23ms/step - loss: 0.2933 - root_mean_squared_error: 0.5415 - mean_absolute_error: 0.2932 - val_loss: 0.3713 - val_root_mean_squared_error: 0.6093 - val_mean_absolute_error: 0.3347
# Epoch 14/30
# 26534/26534 [==============================] - 506s 19ms/step - loss: 0.2934 - root_mean_squared_error: 0.5417 - mean_absolute_error: 0.2932 - val_loss: 0.3553 - val_root_mean_squared_error: 0.5961 - val_mean_absolute_error: 0.3150
# Epoch 15/30
# 26534/26534 [==============================] - 605s 23ms/step - loss: 0.2906 - root_mean_squared_error: 0.5390 - mean_absolute_error: 0.2925 - val_loss: 0.3435 - val_root_mean_squared_error: 0.5861 - val_mean_absolute_error: 0.3170
# Epoch 16/30
# 26534/26534 [==============================] - 466s 18ms/step - loss: 0.2915 - root_mean_squared_error: 0.5399 - mean_absolute_error: 0.2925 - val_loss: 0.3455 - val_root_mean_squared_error: 0.5878 - val_mean_absolute_error: 0.3310
# Epoch 17/30
# 26534/26534 [==============================] - 470s 18ms/step - loss: 2.0201 - root_mean_squared_error: 1.4213 - mean_absolute_error: 0.2947 - val_loss: 0.3759 - val_root_mean_squared_error: 0.6131 - val_mean_absolute_error: 0.3162
# Epoch 18/30
# 26534/26534 [==============================] - 472s 18ms/step - loss: 5.1466 - root_mean_squared_error: 2.2686 - mean_absolute_error: 0.3166 - val_loss: 0.3464 - val_root_mean_squared_error: 0.5885 - val_mean_absolute_error: 0.3209
# Epoch 19/30
# 26534/26534 [==============================] - 477s 18ms/step - loss: 0.2918 - root_mean_squared_error: 0.5402 - mean_absolute_error: 0.2930 - val_loss: 0.3266 - val_root_mean_squared_error: 0.5715 - val_mean_absolute_error: 0.3136
# Epoch 20/30
# 26534/26534 [==============================] - 479s 18ms/step - loss: 0.2897 - root_mean_squared_error: 0.5382 - mean_absolute_error: 0.2921 - val_loss: 0.3838 - val_root_mean_squared_error: 0.6195 - val_mean_absolute_error: 0.3355
# Epoch 21/30
# 26534/26534 [==============================] - 478s 18ms/step - loss: 0.2881 - root_mean_squared_error: 0.5368 - mean_absolute_error: 0.2915 - val_loss: 0.3444 - val_root_mean_squared_error: 0.5869 - val_mean_absolute_error: 0.3276
# Epoch 22/30
# 26534/26534 [==============================] - 482s 18ms/step - loss: 0.2876 - root_mean_squared_error: 0.5363 - mean_absolute_error: 0.2913 - val_loss: 0.3628 - val_root_mean_squared_error: 0.6023 - val_mean_absolute_error: 0.3241
# Epoch 23/30
# 26534/26534 [==============================] - 482s 18ms/step - loss: 0.2872 - root_mean_squared_error: 0.5359 - mean_absolute_error: 0.2911 - val_loss: 0.3405 - val_root_mean_squared_error: 0.5835 - val_mean_absolute_error: 0.3211
# Epoch 24/30
# 26534/26534 [==============================] - 481s 18ms/step - loss: 0.2865 - root_mean_squared_error: 0.5353 - mean_absolute_error: 0.2908 - val_loss: 0.3528 - val_root_mean_squared_error: 0.5939 - val_mean_absolute_error: 0.3167
# Epoch 25/30
# 26534/26534 [==============================] - 485s 18ms/step - loss: 0.2961 - root_mean_squared_error: 0.5441 - mean_absolute_error: 0.2913 - val_loss: 0.3559 - val_root_mean_squared_error: 0.5966 - val_mean_absolute_error: 0.3237
# Epoch 26/30
# 26534/26534 [==============================] - 488s 18ms/step - loss: 8.2621 - root_mean_squared_error: 2.8744 - mean_absolute_error: 0.2985 - val_loss: 0.3480 - val_root_mean_squared_error: 0.5899 - val_mean_absolute_error: 0.3211
# Epoch 27/30
# 26534/26534 [==============================] - 488s 18ms/step - loss: 0.3486 - root_mean_squared_error: 0.5904 - mean_absolute_error: 0.2925 - val_loss: 0.3438 - val_root_mean_squared_error: 0.5863 - val_mean_absolute_error: 0.3300
# Epoch 28/30
# 26534/26534 [==============================] - 529s 20ms/step - loss: 0.3040 - root_mean_squared_error: 0.5514 - mean_absolute_error: 0.2911 - val_loss: 0.3577 - val_root_mean_squared_error: 0.5980 - val_mean_absolute_error: 0.3233
# Epoch 29/30
# 26534/26534 [==============================] - 540s 20ms/step - loss: 1.0996 - root_mean_squared_error: 1.0486 - mean_absolute_error: 0.2949 - val_loss: 0.3744 - val_root_mean_squared_error: 0.6119 - val_mean_absolute_error: 0.3263
# Epoch 30/30
# 26534/26534 [==============================] - 609s 23ms/step - loss: 0.2954 - root_mean_squared_error: 0.5435 - mean_absolute_error: 0.2909 - val_loss: 0.3525 - val_root_mean_squared_error: 0.5937 - val_mean_absolute_error: 0.3381
# Training History without clustering:

# %%
### Save Scenario 2 models
all_cluster.model.save(f'Models/Scenario2/{model_name}/all_cluster')

## Pickling Scenario 2 cluster and cluster result files
all_cluster_file = open(f"Models/Scenario2/Objects/{model_name}/all_cluster.pickle", "wb+")
pickle.dump(all_cluster, all_cluster_file)
all_cluster_file.close()

all_cluster_results_file = open(f"Models/Scenario2/Objects/{model_name}/all_cluster_results.pickle", "wb+")
pickle.dump(all_cluster_results, all_cluster_results_file)
all_cluster_results_file.close()
# Out:
# INFO:tensorflow:Assets written to: Models/Scenario2/LSTM/all_cluster/assets
# INFO:tensorflow:Assets written to: Models/Scenario2/LSTM/all_cluster/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f5fca510070> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f5fea6f7a90> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f5fcbd4a700> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# INFO:tensorflow:Assets written to: ram://f2104cf6-f629-42e6-81eb-ad089c3c6714/assets
# INFO:tensorflow:Assets written to: ram://f2104cf6-f629-42e6-81eb-ad089c3c6714/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f5fca510070> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f5fea6f7a90> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f5fcbd4a700> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.

# %% [markdown]
# #### Predictions Graph functions

# %%
def x_axis_label_format(label):
    """
    Convert time label to the format of pandas line plot
    """
    label = pd.Timestamp(label)
    month = label.month_name()[:3]
    #if month == 'Jan':
    month += f'\n{label.year}'
    return month

def graph_predictions(cluster_specific_results, all_results):
    first_house = list(cluster_specific_results.keys())[0]
    df1 = cluster_specific_results[first_house][['timestamp','energy_predicted', 'energy_kWh']]
    df1['timestamp'] = pd.to_datetime(df1['timestamp'])
    df1 = df1.set_index('timestamp')
    df1['energy_predicted_without_clustering']= np.array(all_results[first_house][['energy_predicted']])
    df1.rename({'energy_predicted':'energy_predicted_with_clustering', 'energy_kWh':'real_energy'},axis = 1, inplace = True)
    ax = df1[::300].plot.line(figsize=(20,10))
    #ax.set_xticklabels(map(x_axis_label_format, df1[::int(len(df1)/8)+1].index))
    #import matplotlib.dates as mdates
    #myFmt = mdates.DateFormatter('%Y-%m')
    #ax.xaxis.set_major_formatter(myFmt)
    ax.set_title(f'Predictions for house {first_house}')

# %% [markdown]
# #### Predictions for Scenario 1 and Scenario 2

# %%
graph_predictions(zero_cluster_results, all_cluster_results)
#df1 = zero_cluster_results[1][['timestamp','energy_predicted', 'energy_kWh']].set_index('timestamp')
#df1['energy_predicted_without_clustering']= np.array(all_cluster_results[1][['energy_predicted']])
# Out:
# /tmp/ipykernel_119344/442122963.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['timestamp'] = pd.to_datetime(df1['timestamp'])

# %%
graph_predictions(one_cluster_results, all_cluster_results)
# Out:
# /tmp/ipykernel_119344/442122963.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['timestamp'] = pd.to_datetime(df1['timestamp'])

# %%
graph_predictions(two_cluster_results, all_cluster_results)
# Out:
# /tmp/ipykernel_119344/442122963.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['timestamp'] = pd.to_datetime(df1['timestamp'])

# %%
graph_predictions(three_cluster_results, all_cluster_results)
# Out:
# /tmp/ipykernel_119344/442122963.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['timestamp'] = pd.to_datetime(df1['timestamp'])

# %% [markdown]
# ### Function to create tables

# %%
def create_metrics(scenario_results, val=False):
    if val == False:
        rmse = 'root_mean_squared_error'
        mae = 'mean_absolute_error'
    else:
        rmse = 'val_root_mean_squared_error'
        mae = 'val_mean_absolute_error'
    scenario_rmse = list(map(lambda x: x.history.history[rmse],scenario_results))
    scenario_mae = list(map(lambda x: x.history.history[mae],scenario_results))
    scenario_rmse = np.array(scenario_rmse).reshape(-1,)
    scenario_mae = np.array(scenario_mae).reshape(-1,)
    return [np.min(scenario_rmse),np.max(scenario_rmse),np.mean(scenario_rmse),np.min(scenario_mae),np.max(scenario_mae),np.mean(scenario_mae)]

# %% [markdown]
# #### Scenario 1 and Scenario 2 Metric Tables

# %%
scenario_1_results = [zero_cluster, one_cluster, two_cluster, three_cluster]
scenario_1_metrics = create_metrics(scenario_1_results)
scenario_1_validation_metrics = create_metrics(scenario_1_results, val= True)
scenario_1_metrics
# Out:
# [0.3660842180252075,
#  1.2119908332824707,
#  0.6166011494894822,
#  0.20133846998214722,
#  0.7125244736671448,
#  0.35880887880921364]

# %%
scenario_2_results = [all_cluster]
scenario_2_metrics = create_metrics(scenario_2_results)
scenario_2_validation_metrics = create_metrics(scenario_2_results, val= True)
scenario_2_metrics
# Out:
# [0.5352774262428284,
#  2.874387264251709,
#  0.7279474596182506,
#  0.2907836139202118,
#  0.31786519289016724,
#  0.29581207036972046]

# %% [markdown]
# #### Scenario 3 and 4

# %%
### Removing smart device features
House.cols = ['energy_kWh']
#House.cols

# %%
scenario_3_zero_cluster = Cluster(zero_houses)
scenario_3_zero_cluster_results = scenario_3_zero_cluster.results(model_name)
print('Training History for Cluster 0:')
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_15 (LSTM)              (None, 14, 128)           66560
#
#  lstm_16 (LSTM)              (None, 14, 32)            20608
#
#  lstm_17 (LSTM)              (None, 16)                3136
#
#  dense_5 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 90,321
# Trainable params: 90,321
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 7680/7680 [==============================] - 140s 18ms/step - loss: 0.5004 - root_mean_squared_error: 0.7074 - mean_absolute_error: 0.4381 - val_loss: 0.6764 - val_root_mean_squared_error: 0.8224 - val_mean_absolute_error: 0.4635
# Epoch 2/30
# 7680/7680 [==============================] - 129s 17ms/step - loss: 0.4505 - root_mean_squared_error: 0.6712 - mean_absolute_error: 0.4035 - val_loss: 0.6223 - val_root_mean_squared_error: 0.7889 - val_mean_absolute_error: 0.4713
# Epoch 3/30
# 7680/7680 [==============================] - 130s 17ms/step - loss: 0.4429 - root_mean_squared_error: 0.6655 - mean_absolute_error: 0.3970 - val_loss: 0.6234 - val_root_mean_squared_error: 0.7896 - val_mean_absolute_error: 0.4596
# Epoch 4/30
# 7680/7680 [==============================] - 135s 18ms/step - loss: 0.4383 - root_mean_squared_error: 0.6620 - mean_absolute_error: 0.3943 - val_loss: 0.6312 - val_root_mean_squared_error: 0.7945 - val_mean_absolute_error: 0.4443
# Epoch 5/30
# 7680/7680 [==============================] - 133s 17ms/step - loss: 0.4337 - root_mean_squared_error: 0.6586 - mean_absolute_error: 0.3914 - val_loss: 0.6224 - val_root_mean_squared_error: 0.7889 - val_mean_absolute_error: 0.4634
# Epoch 6/30
# 7680/7680 [==============================] - 136s 18ms/step - loss: 0.4304 - root_mean_squared_error: 0.6561 - mean_absolute_error: 0.3899 - val_loss: 0.6359 - val_root_mean_squared_error: 0.7974 - val_mean_absolute_error: 0.4576
# Epoch 7/30
# 7680/7680 [==============================] - 135s 18ms/step - loss: 0.4285 - root_mean_squared_error: 0.6546 - mean_absolute_error: 0.3888 - val_loss: 0.6558 - val_root_mean_squared_error: 0.8098 - val_mean_absolute_error: 0.4584
# Epoch 8/30
# 7680/7680 [==============================] - 135s 18ms/step - loss: 0.4269 - root_mean_squared_error: 0.6533 - mean_absolute_error: 0.3873 - val_loss: 0.6294 - val_root_mean_squared_error: 0.7933 - val_mean_absolute_error: 0.4492
# Epoch 9/30
# 7680/7680 [==============================] - 130s 17ms/step - loss: 0.4237 - root_mean_squared_error: 0.6510 - mean_absolute_error: 0.3862 - val_loss: 0.6582 - val_root_mean_squared_error: 0.8113 - val_mean_absolute_error: 0.4516
# Epoch 10/30
# 7680/7680 [==============================] - 135s 18ms/step - loss: 0.4227 - root_mean_squared_error: 0.6502 - mean_absolute_error: 0.3858 - val_loss: 0.6334 - val_root_mean_squared_error: 0.7959 - val_mean_absolute_error: 0.4658
# Epoch 11/30
# 7680/7680 [==============================] - 146s 19ms/step - loss: 0.4207 - root_mean_squared_error: 0.6486 - mean_absolute_error: 0.3846 - val_loss: 0.6115 - val_root_mean_squared_error: 0.7820 - val_mean_absolute_error: 0.4522
# Epoch 12/30
# 7680/7680 [==============================] - 147s 19ms/step - loss: 0.4189 - root_mean_squared_error: 0.6472 - mean_absolute_error: 0.3842 - val_loss: 0.6273 - val_root_mean_squared_error: 0.7920 - val_mean_absolute_error: 0.4477
# Epoch 13/30
# 7680/7680 [==============================] - 134s 17ms/step - loss: 0.4188 - root_mean_squared_error: 0.6472 - mean_absolute_error: 0.3836 - val_loss: 0.6166 - val_root_mean_squared_error: 0.7852 - val_mean_absolute_error: 0.4552
# Epoch 14/30
# 7680/7680 [==============================] - 130s 17ms/step - loss: 0.4161 - root_mean_squared_error: 0.6450 - mean_absolute_error: 0.3831 - val_loss: 0.6535 - val_root_mean_squared_error: 0.8084 - val_mean_absolute_error: 0.4561
# Epoch 15/30
# 7680/7680 [==============================] - 130s 17ms/step - loss: 0.4153 - root_mean_squared_error: 0.6444 - mean_absolute_error: 0.3826 - val_loss: 0.6654 - val_root_mean_squared_error: 0.8157 - val_mean_absolute_error: 0.4563
# Epoch 16/30
# 7680/7680 [==============================] - 129s 17ms/step - loss: 0.4134 - root_mean_squared_error: 0.6430 - mean_absolute_error: 0.3817 - val_loss: 0.6307 - val_root_mean_squared_error: 0.7942 - val_mean_absolute_error: 0.4674
# Epoch 17/30
# 7680/7680 [==============================] - 128s 17ms/step - loss: 0.4117 - root_mean_squared_error: 0.6417 - mean_absolute_error: 0.3815 - val_loss: 0.6514 - val_root_mean_squared_error: 0.8071 - val_mean_absolute_error: 0.4641
# Epoch 18/30
# 7680/7680 [==============================] - 130s 17ms/step - loss: 0.4104 - root_mean_squared_error: 0.6406 - mean_absolute_error: 0.3807 - val_loss: 0.6442 - val_root_mean_squared_error: 0.8026 - val_mean_absolute_error: 0.4602
# Epoch 19/30
# 7680/7680 [==============================] - 128s 17ms/step - loss: 0.4092 - root_mean_squared_error: 0.6397 - mean_absolute_error: 0.3805 - val_loss: 0.6497 - val_root_mean_squared_error: 0.8060 - val_mean_absolute_error: 0.4574
# Epoch 20/30
# 7680/7680 [==============================] - 130s 17ms/step - loss: 0.4073 - root_mean_squared_error: 0.6382 - mean_absolute_error: 0.3795 - val_loss: 0.6463 - val_root_mean_squared_error: 0.8039 - val_mean_absolute_error: 0.4749
# Epoch 21/30
# 7680/7680 [==============================] - 128s 17ms/step - loss: 0.4064 - root_mean_squared_error: 0.6375 - mean_absolute_error: 0.3794 - val_loss: 0.6318 - val_root_mean_squared_error: 0.7949 - val_mean_absolute_error: 0.4550
# Epoch 22/30
# 7680/7680 [==============================] - 128s 17ms/step - loss: 0.4050 - root_mean_squared_error: 0.6364 - mean_absolute_error: 0.3787 - val_loss: 0.6527 - val_root_mean_squared_error: 0.8079 - val_mean_absolute_error: 0.4585
# Epoch 23/30
# 7680/7680 [==============================] - 130s 17ms/step - loss: 0.4042 - root_mean_squared_error: 0.6358 - mean_absolute_error: 0.3784 - val_loss: 0.6749 - val_root_mean_squared_error: 0.8215 - val_mean_absolute_error: 0.4631
# Epoch 24/30
# 7680/7680 [==============================] - 133s 17ms/step - loss: 0.4018 - root_mean_squared_error: 0.6338 - mean_absolute_error: 0.3776 - val_loss: 0.6601 - val_root_mean_squared_error: 0.8125 - val_mean_absolute_error: 0.4723
# Epoch 25/30
# 7680/7680 [==============================] - 138s 18ms/step - loss: 0.4010 - root_mean_squared_error: 0.6333 - mean_absolute_error: 0.3777 - val_loss: 0.6762 - val_root_mean_squared_error: 0.8223 - val_mean_absolute_error: 0.4725
# Epoch 26/30
# 7680/7680 [==============================] - 143s 19ms/step - loss: 0.3992 - root_mean_squared_error: 0.6318 - mean_absolute_error: 0.3768 - val_loss: 0.6647 - val_root_mean_squared_error: 0.8153 - val_mean_absolute_error: 0.4558
# Epoch 27/30
# 7680/7680 [==============================] - 156s 20ms/step - loss: 0.3987 - root_mean_squared_error: 0.6314 - mean_absolute_error: 0.3768 - val_loss: 0.6871 - val_root_mean_squared_error: 0.8289 - val_mean_absolute_error: 0.4671
# Epoch 28/30
# 7680/7680 [==============================] - 126s 16ms/step - loss: 0.3978 - root_mean_squared_error: 0.6307 - mean_absolute_error: 0.3763 - val_loss: 0.6560 - val_root_mean_squared_error: 0.8099 - val_mean_absolute_error: 0.4640
# Epoch 29/30
# 7680/7680 [==============================] - 125s 16ms/step - loss: 0.3957 - root_mean_squared_error: 0.6290 - mean_absolute_error: 0.3757 - val_loss: 0.6680 - val_root_mean_squared_error: 0.8173 - val_mean_absolute_error: 0.4730
# Epoch 30/30
# 7680/7680 [==============================] - 125s 16ms/step - loss: 0.3938 - root_mean_squared_error: 0.6276 - mean_absolute_error: 0.3757 - val_loss: 0.6577 - val_root_mean_squared_error: 0.8110 - val_mean_absolute_error: 0.4644
# Training History for Cluster 0:

# %%
scenario_3_one_cluster = Cluster(one_houses)
scenario_3_one_cluster_results = scenario_3_one_cluster.results(model_name)
print('Training History for Cluster 1:')
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_18 (LSTM)              (None, 14, 128)           66560
#
#  lstm_19 (LSTM)              (None, 14, 32)            20608
#
#  lstm_20 (LSTM)              (None, 16)                3136
#
#  dense_6 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 90,321
# Trainable params: 90,321
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 915/915 [==============================] - 17s 16ms/step - loss: 1.5684 - root_mean_squared_error: 1.2524 - mean_absolute_error: 0.7521 - val_loss: 1.6506 - val_root_mean_squared_error: 1.2848 - val_mean_absolute_error: 0.7030
# Epoch 2/30
# 915/915 [==============================] - 14s 16ms/step - loss: 0.9877 - root_mean_squared_error: 0.9938 - mean_absolute_error: 0.5685 - val_loss: 1.3959 - val_root_mean_squared_error: 1.1815 - val_mean_absolute_error: 0.6014
# Epoch 3/30
# 915/915 [==============================] - 15s 16ms/step - loss: 0.9096 - root_mean_squared_error: 0.9537 - mean_absolute_error: 0.5376 - val_loss: 1.3183 - val_root_mean_squared_error: 1.1482 - val_mean_absolute_error: 0.5530
# Epoch 4/30
# 915/915 [==============================] - 14s 16ms/step - loss: 0.8680 - root_mean_squared_error: 0.9316 - mean_absolute_error: 0.5241 - val_loss: 1.3022 - val_root_mean_squared_error: 1.1411 - val_mean_absolute_error: 0.5405
# Epoch 5/30
# 915/915 [==============================] - 14s 16ms/step - loss: 0.8350 - root_mean_squared_error: 0.9138 - mean_absolute_error: 0.5178 - val_loss: 1.2311 - val_root_mean_squared_error: 1.1096 - val_mean_absolute_error: 0.6651
# Epoch 6/30
# 915/915 [==============================] - 14s 16ms/step - loss: 0.8241 - root_mean_squared_error: 0.9078 - mean_absolute_error: 0.5128 - val_loss: 1.1788 - val_root_mean_squared_error: 1.0857 - val_mean_absolute_error: 0.5469
# Epoch 7/30
# 915/915 [==============================] - 14s 16ms/step - loss: 0.8167 - root_mean_squared_error: 0.9037 - mean_absolute_error: 0.5089 - val_loss: 1.1150 - val_root_mean_squared_error: 1.0559 - val_mean_absolute_error: 0.5528
# Epoch 8/30
# 915/915 [==============================] - 15s 16ms/step - loss: 0.7924 - root_mean_squared_error: 0.8902 - mean_absolute_error: 0.5033 - val_loss: 1.1546 - val_root_mean_squared_error: 1.0745 - val_mean_absolute_error: 0.6070
# Epoch 9/30
# 915/915 [==============================] - 14s 16ms/step - loss: 0.8041 - root_mean_squared_error: 0.8967 - mean_absolute_error: 0.5040 - val_loss: 1.3094 - val_root_mean_squared_error: 1.1443 - val_mean_absolute_error: 0.5551
# Epoch 10/30
# 915/915 [==============================] - 15s 16ms/step - loss: 0.7801 - root_mean_squared_error: 0.8832 - mean_absolute_error: 0.4952 - val_loss: 1.1101 - val_root_mean_squared_error: 1.0536 - val_mean_absolute_error: 0.5118
# Epoch 11/30
# 915/915 [==============================] - 14s 16ms/step - loss: 0.7773 - root_mean_squared_error: 0.8817 - mean_absolute_error: 0.4955 - val_loss: 1.3111 - val_root_mean_squared_error: 1.1450 - val_mean_absolute_error: 0.6502
# Epoch 12/30
# 915/915 [==============================] - 15s 16ms/step - loss: 0.7695 - root_mean_squared_error: 0.8772 - mean_absolute_error: 0.4919 - val_loss: 1.2169 - val_root_mean_squared_error: 1.1031 - val_mean_absolute_error: 0.5760
# Epoch 13/30
# 915/915 [==============================] - 15s 16ms/step - loss: 0.7543 - root_mean_squared_error: 0.8685 - mean_absolute_error: 0.4891 - val_loss: 1.1096 - val_root_mean_squared_error: 1.0534 - val_mean_absolute_error: 0.5568
# Epoch 14/30
# 915/915 [==============================] - 15s 16ms/step - loss: 0.7552 - root_mean_squared_error: 0.8690 - mean_absolute_error: 0.4886 - val_loss: 1.0773 - val_root_mean_squared_error: 1.0379 - val_mean_absolute_error: 0.5030
# Epoch 15/30
# 915/915 [==============================] - 14s 16ms/step - loss: 0.7436 - root_mean_squared_error: 0.8623 - mean_absolute_error: 0.4849 - val_loss: 1.1288 - val_root_mean_squared_error: 1.0625 - val_mean_absolute_error: 0.5115
# Epoch 16/30
# 915/915 [==============================] - 15s 16ms/step - loss: 0.7420 - root_mean_squared_error: 0.8614 - mean_absolute_error: 0.4850 - val_loss: 1.0827 - val_root_mean_squared_error: 1.0405 - val_mean_absolute_error: 0.5041
# Epoch 17/30
# 915/915 [==============================] - 15s 16ms/step - loss: 0.7334 - root_mean_squared_error: 0.8564 - mean_absolute_error: 0.4835 - val_loss: 1.1046 - val_root_mean_squared_error: 1.0510 - val_mean_absolute_error: 0.5014
# Epoch 18/30
# 915/915 [==============================] - 15s 16ms/step - loss: 0.7226 - root_mean_squared_error: 0.8501 - mean_absolute_error: 0.4794 - val_loss: 1.1326 - val_root_mean_squared_error: 1.0642 - val_mean_absolute_error: 0.5468
# Epoch 19/30
# 915/915 [==============================] - 15s 16ms/step - loss: 0.7355 - root_mean_squared_error: 0.8576 - mean_absolute_error: 0.4808 - val_loss: 1.2074 - val_root_mean_squared_error: 1.0988 - val_mean_absolute_error: 0.5047
# Epoch 20/30
# 915/915 [==============================] - 14s 16ms/step - loss: 0.7018 - root_mean_squared_error: 0.8378 - mean_absolute_error: 0.4743 - val_loss: 1.0785 - val_root_mean_squared_error: 1.0385 - val_mean_absolute_error: 0.5545
# Epoch 21/30
# 915/915 [==============================] - 15s 16ms/step - loss: 0.7202 - root_mean_squared_error: 0.8486 - mean_absolute_error: 0.4788 - val_loss: 1.0550 - val_root_mean_squared_error: 1.0271 - val_mean_absolute_error: 0.5231
# Epoch 22/30
# 915/915 [==============================] - 14s 16ms/step - loss: 0.7073 - root_mean_squared_error: 0.8410 - mean_absolute_error: 0.4721 - val_loss: 1.0866 - val_root_mean_squared_error: 1.0424 - val_mean_absolute_error: 0.5501
# Epoch 23/30
# 915/915 [==============================] - 15s 16ms/step - loss: 0.7075 - root_mean_squared_error: 0.8412 - mean_absolute_error: 0.4752 - val_loss: 1.0875 - val_root_mean_squared_error: 1.0428 - val_mean_absolute_error: 0.5223
# Epoch 24/30
# 915/915 [==============================] - 15s 16ms/step - loss: 0.6878 - root_mean_squared_error: 0.8294 - mean_absolute_error: 0.4704 - val_loss: 1.1271 - val_root_mean_squared_error: 1.0616 - val_mean_absolute_error: 0.5245
# Epoch 25/30
# 915/915 [==============================] - 15s 16ms/step - loss: 0.6950 - root_mean_squared_error: 0.8337 - mean_absolute_error: 0.4704 - val_loss: 1.1903 - val_root_mean_squared_error: 1.0910 - val_mean_absolute_error: 0.5436
# Epoch 26/30
# 915/915 [==============================] - 15s 16ms/step - loss: 0.6841 - root_mean_squared_error: 0.8271 - mean_absolute_error: 0.4696 - val_loss: 1.0451 - val_root_mean_squared_error: 1.0223 - val_mean_absolute_error: 0.5410
# Epoch 27/30
# 915/915 [==============================] - 14s 16ms/step - loss: 0.6723 - root_mean_squared_error: 0.8199 - mean_absolute_error: 0.4664 - val_loss: 1.2788 - val_root_mean_squared_error: 1.1308 - val_mean_absolute_error: 0.5346
# Epoch 28/30
# 915/915 [==============================] - 14s 16ms/step - loss: 0.6755 - root_mean_squared_error: 0.8219 - mean_absolute_error: 0.4651 - val_loss: 1.0850 - val_root_mean_squared_error: 1.0417 - val_mean_absolute_error: 0.4832
# Epoch 29/30
# 915/915 [==============================] - 14s 16ms/step - loss: 0.6663 - root_mean_squared_error: 0.8163 - mean_absolute_error: 0.4619 - val_loss: 1.1216 - val_root_mean_squared_error: 1.0591 - val_mean_absolute_error: 0.5203
# Epoch 30/30
# 915/915 [==============================] - 14s 16ms/step - loss: 0.6668 - root_mean_squared_error: 0.8166 - mean_absolute_error: 0.4634 - val_loss: 1.1084 - val_root_mean_squared_error: 1.0528 - val_mean_absolute_error: 0.5046
# Training History for Cluster 1:

# %%
scenario_3_two_cluster = Cluster(two_houses)
scenario_3_two_cluster_results = scenario_3_two_cluster.results(model_name)
print('Training History for Cluster 2:')
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_21 (LSTM)              (None, 14, 128)           66560
#
#  lstm_22 (LSTM)              (None, 14, 32)            20608
#
#  lstm_23 (LSTM)              (None, 16)                3136
#
#  dense_7 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 90,321
# Trainable params: 90,321
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 15194/15194 [==============================] - 242s 16ms/step - loss: 0.1528 - root_mean_squared_error: 0.3909 - mean_absolute_error: 0.2214 - val_loss: 0.2061 - val_root_mean_squared_error: 0.4540 - val_mean_absolute_error: 0.2422
# Epoch 2/30
# 15194/15194 [==============================] - 240s 16ms/step - loss: 0.1456 - root_mean_squared_error: 0.3816 - mean_absolute_error: 0.2113 - val_loss: 0.2041 - val_root_mean_squared_error: 0.4517 - val_mean_absolute_error: 0.2461
# Epoch 3/30
# 15194/15194 [==============================] - 242s 16ms/step - loss: 0.1445 - root_mean_squared_error: 0.3801 - mean_absolute_error: 0.2099 - val_loss: 0.2063 - val_root_mean_squared_error: 0.4542 - val_mean_absolute_error: 0.2457
# Epoch 4/30
# 15194/15194 [==============================] - 240s 16ms/step - loss: 0.1435 - root_mean_squared_error: 0.3789 - mean_absolute_error: 0.2089 - val_loss: 0.2041 - val_root_mean_squared_error: 0.4518 - val_mean_absolute_error: 0.2478
# Epoch 5/30
# 15194/15194 [==============================] - 242s 16ms/step - loss: 0.1428 - root_mean_squared_error: 0.3779 - mean_absolute_error: 0.2080 - val_loss: 0.2071 - val_root_mean_squared_error: 0.4551 - val_mean_absolute_error: 0.2569
# Epoch 6/30
# 15194/15194 [==============================] - 243s 16ms/step - loss: 0.1423 - root_mean_squared_error: 0.3772 - mean_absolute_error: 0.2075 - val_loss: 0.2062 - val_root_mean_squared_error: 0.4541 - val_mean_absolute_error: 0.2465
# Epoch 7/30
# 15194/15194 [==============================] - 244s 16ms/step - loss: 0.1418 - root_mean_squared_error: 0.3766 - mean_absolute_error: 0.2069 - val_loss: 0.2068 - val_root_mean_squared_error: 0.4548 - val_mean_absolute_error: 0.2456
# Epoch 8/30
# 15194/15194 [==============================] - 243s 16ms/step - loss: 0.1415 - root_mean_squared_error: 0.3762 - mean_absolute_error: 0.2066 - val_loss: 0.2036 - val_root_mean_squared_error: 0.4513 - val_mean_absolute_error: 0.2539
# Epoch 9/30
# 15194/15194 [==============================] - 246s 16ms/step - loss: 0.1410 - root_mean_squared_error: 0.3755 - mean_absolute_error: 0.2062 - val_loss: 0.2060 - val_root_mean_squared_error: 0.4539 - val_mean_absolute_error: 0.2500
# Epoch 10/30
# 15194/15194 [==============================] - 245s 16ms/step - loss: 0.1407 - root_mean_squared_error: 0.3751 - mean_absolute_error: 0.2059 - val_loss: 0.2126 - val_root_mean_squared_error: 0.4610 - val_mean_absolute_error: 0.2605
# Epoch 11/30
# 15194/15194 [==============================] - 246s 16ms/step - loss: 0.1404 - root_mean_squared_error: 0.3747 - mean_absolute_error: 0.2057 - val_loss: 0.2066 - val_root_mean_squared_error: 0.4545 - val_mean_absolute_error: 0.2493
# Epoch 12/30
# 15194/15194 [==============================] - 248s 16ms/step - loss: 0.1400 - root_mean_squared_error: 0.3741 - mean_absolute_error: 0.2053 - val_loss: 0.2059 - val_root_mean_squared_error: 0.4537 - val_mean_absolute_error: 0.2502
# Epoch 13/30
# 15194/15194 [==============================] - 246s 16ms/step - loss: 0.1396 - root_mean_squared_error: 0.3737 - mean_absolute_error: 0.2051 - val_loss: 0.2061 - val_root_mean_squared_error: 0.4540 - val_mean_absolute_error: 0.2556
# Epoch 14/30
# 15194/15194 [==============================] - 247s 16ms/step - loss: 0.1394 - root_mean_squared_error: 0.3733 - mean_absolute_error: 0.2050 - val_loss: 0.2053 - val_root_mean_squared_error: 0.4531 - val_mean_absolute_error: 0.2463
# Epoch 15/30
# 15194/15194 [==============================] - 247s 16ms/step - loss: 0.1391 - root_mean_squared_error: 0.3729 - mean_absolute_error: 0.2048 - val_loss: 0.2087 - val_root_mean_squared_error: 0.4568 - val_mean_absolute_error: 0.2502
# Epoch 16/30
# 15194/15194 [==============================] - 248s 16ms/step - loss: 0.1389 - root_mean_squared_error: 0.3726 - mean_absolute_error: 0.2045 - val_loss: 0.2069 - val_root_mean_squared_error: 0.4549 - val_mean_absolute_error: 0.2615
# Epoch 17/30
# 15194/15194 [==============================] - 248s 16ms/step - loss: 0.1384 - root_mean_squared_error: 0.3720 - mean_absolute_error: 0.2041 - val_loss: 0.2088 - val_root_mean_squared_error: 0.4569 - val_mean_absolute_error: 0.2548
# Epoch 18/30
# 15194/15194 [==============================] - 249s 16ms/step - loss: 0.1382 - root_mean_squared_error: 0.3718 - mean_absolute_error: 0.2043 - val_loss: 0.2072 - val_root_mean_squared_error: 0.4552 - val_mean_absolute_error: 0.2547
# Epoch 19/30
# 15194/15194 [==============================] - 248s 16ms/step - loss: 0.1379 - root_mean_squared_error: 0.3714 - mean_absolute_error: 0.2039 - val_loss: 0.2071 - val_root_mean_squared_error: 0.4551 - val_mean_absolute_error: 0.2501
# Epoch 20/30
# 15194/15194 [==============================] - 250s 16ms/step - loss: 0.1377 - root_mean_squared_error: 0.3710 - mean_absolute_error: 0.2036 - val_loss: 0.2075 - val_root_mean_squared_error: 0.4555 - val_mean_absolute_error: 0.2464
# Epoch 21/30
# 15194/15194 [==============================] - 251s 16ms/step - loss: 1.0008 - root_mean_squared_error: 1.0004 - mean_absolute_error: 0.2084 - val_loss: 33.0328 - val_root_mean_squared_error: 5.7474 - val_mean_absolute_error: 0.2762
# Epoch 22/30
# 15194/15194 [==============================] - 250s 16ms/step - loss: 0.4628 - root_mean_squared_error: 0.6803 - mean_absolute_error: 0.2128 - val_loss: 0.2466 - val_root_mean_squared_error: 0.4966 - val_mean_absolute_error: 0.2662
# Epoch 23/30
# 15194/15194 [==============================] - 251s 16ms/step - loss: 0.4606 - root_mean_squared_error: 0.6787 - mean_absolute_error: 0.2365 - val_loss: 0.4043 - val_root_mean_squared_error: 0.6358 - val_mean_absolute_error: 0.3054
# Epoch 24/30
# 15194/15194 [==============================] - 252s 17ms/step - loss: 0.1685 - root_mean_squared_error: 0.4105 - mean_absolute_error: 0.2291 - val_loss: 0.2277 - val_root_mean_squared_error: 0.4772 - val_mean_absolute_error: 0.2754
# Epoch 25/30
# 15194/15194 [==============================] - 252s 17ms/step - loss: 0.1898 - root_mean_squared_error: 0.4356 - mean_absolute_error: 0.2176 - val_loss: 0.2151 - val_root_mean_squared_error: 0.4637 - val_mean_absolute_error: 0.2594
# Epoch 26/30
# 15194/15194 [==============================] - 251s 17ms/step - loss: 0.1448 - root_mean_squared_error: 0.3805 - mean_absolute_error: 0.2084 - val_loss: 0.2073 - val_root_mean_squared_error: 0.4553 - val_mean_absolute_error: 0.2629
# Epoch 27/30
# 15194/15194 [==============================] - 252s 17ms/step - loss: 0.1403 - root_mean_squared_error: 0.3745 - mean_absolute_error: 0.2059 - val_loss: 0.2059 - val_root_mean_squared_error: 0.4538 - val_mean_absolute_error: 0.2519
# Epoch 28/30
# 15194/15194 [==============================] - 251s 16ms/step - loss: 0.1387 - root_mean_squared_error: 0.3725 - mean_absolute_error: 0.2044 - val_loss: 0.2084 - val_root_mean_squared_error: 0.4565 - val_mean_absolute_error: 0.2563
# Epoch 29/30
# 15194/15194 [==============================] - 251s 17ms/step - loss: 0.1380 - root_mean_squared_error: 0.3715 - mean_absolute_error: 0.2040 - val_loss: 0.2075 - val_root_mean_squared_error: 0.4556 - val_mean_absolute_error: 0.2489
# Epoch 30/30
# 15194/15194 [==============================] - 251s 17ms/step - loss: 0.1374 - root_mean_squared_error: 0.3707 - mean_absolute_error: 0.2034 - val_loss: 0.2077 - val_root_mean_squared_error: 0.4558 - val_mean_absolute_error: 0.2524
# Training History for Cluster 2:

# %%
scenario_3_three_cluster = Cluster(three_houses)
scenario_3_three_cluster_results = scenario_3_three_cluster.results(model_name)
print('Training History for Cluster 3:')
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_24 (LSTM)              (None, 14, 128)           66560
#
#  lstm_25 (LSTM)              (None, 14, 32)            20608
#
#  lstm_26 (LSTM)              (None, 16)                3136
#
#  dense_8 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 90,321
# Trainable params: 90,321
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 2745/2745 [==============================] - 46s 16ms/step - loss: 0.4079 - root_mean_squared_error: 0.6387 - mean_absolute_error: 0.4210 - val_loss: 0.5017 - val_root_mean_squared_error: 0.7083 - val_mean_absolute_error: 0.4490
# Epoch 2/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.3643 - root_mean_squared_error: 0.6036 - mean_absolute_error: 0.3853 - val_loss: 0.4038 - val_root_mean_squared_error: 0.6354 - val_mean_absolute_error: 0.3818
# Epoch 3/30
# 2745/2745 [==============================] - 44s 16ms/step - loss: 0.3562 - root_mean_squared_error: 0.5969 - mean_absolute_error: 0.3799 - val_loss: 0.4067 - val_root_mean_squared_error: 0.6378 - val_mean_absolute_error: 0.3596
# Epoch 4/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.3473 - root_mean_squared_error: 0.5893 - mean_absolute_error: 0.3718 - val_loss: 0.3915 - val_root_mean_squared_error: 0.6257 - val_mean_absolute_error: 0.4105
# Epoch 5/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.3398 - root_mean_squared_error: 0.5830 - mean_absolute_error: 0.3657 - val_loss: 0.3669 - val_root_mean_squared_error: 0.6057 - val_mean_absolute_error: 0.3596
# Epoch 6/30
# 2745/2745 [==============================] - 44s 16ms/step - loss: 0.3354 - root_mean_squared_error: 0.5792 - mean_absolute_error: 0.3612 - val_loss: 0.4386 - val_root_mean_squared_error: 0.6623 - val_mean_absolute_error: 0.3904
# Epoch 7/30
# 2745/2745 [==============================] - 44s 16ms/step - loss: 0.3312 - root_mean_squared_error: 0.5755 - mean_absolute_error: 0.3580 - val_loss: 0.3902 - val_root_mean_squared_error: 0.6247 - val_mean_absolute_error: 0.3624
# Epoch 8/30
# 2745/2745 [==============================] - 44s 16ms/step - loss: 0.3283 - root_mean_squared_error: 0.5730 - mean_absolute_error: 0.3549 - val_loss: 0.3913 - val_root_mean_squared_error: 0.6255 - val_mean_absolute_error: 0.3705
# Epoch 9/30
# 2745/2745 [==============================] - 44s 16ms/step - loss: 0.3266 - root_mean_squared_error: 0.5715 - mean_absolute_error: 0.3536 - val_loss: 0.4097 - val_root_mean_squared_error: 0.6401 - val_mean_absolute_error: 0.3827
# Epoch 10/30
# 2745/2745 [==============================] - 44s 16ms/step - loss: 0.3243 - root_mean_squared_error: 0.5695 - mean_absolute_error: 0.3515 - val_loss: 0.4192 - val_root_mean_squared_error: 0.6474 - val_mean_absolute_error: 0.3844
# Epoch 11/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.3218 - root_mean_squared_error: 0.5673 - mean_absolute_error: 0.3495 - val_loss: 0.4142 - val_root_mean_squared_error: 0.6436 - val_mean_absolute_error: 0.3817
# Epoch 12/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.3201 - root_mean_squared_error: 0.5658 - mean_absolute_error: 0.3477 - val_loss: 0.3861 - val_root_mean_squared_error: 0.6214 - val_mean_absolute_error: 0.3775
# Epoch 13/30
# 2745/2745 [==============================] - 44s 16ms/step - loss: 0.3176 - root_mean_squared_error: 0.5636 - mean_absolute_error: 0.3465 - val_loss: 0.4005 - val_root_mean_squared_error: 0.6328 - val_mean_absolute_error: 0.3793
# Epoch 14/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.3160 - root_mean_squared_error: 0.5621 - mean_absolute_error: 0.3444 - val_loss: 0.3801 - val_root_mean_squared_error: 0.6165 - val_mean_absolute_error: 0.3646
# Epoch 15/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.3139 - root_mean_squared_error: 0.5603 - mean_absolute_error: 0.3428 - val_loss: 0.3978 - val_root_mean_squared_error: 0.6307 - val_mean_absolute_error: 0.3817
# Epoch 16/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.3131 - root_mean_squared_error: 0.5596 - mean_absolute_error: 0.3419 - val_loss: 0.4067 - val_root_mean_squared_error: 0.6378 - val_mean_absolute_error: 0.3674
# Epoch 17/30
# 2745/2745 [==============================] - 44s 16ms/step - loss: 0.3110 - root_mean_squared_error: 0.5577 - mean_absolute_error: 0.3404 - val_loss: 0.3843 - val_root_mean_squared_error: 0.6200 - val_mean_absolute_error: 0.3657
# Epoch 18/30
# 2745/2745 [==============================] - 44s 16ms/step - loss: 0.3088 - root_mean_squared_error: 0.5557 - mean_absolute_error: 0.3381 - val_loss: 0.4086 - val_root_mean_squared_error: 0.6392 - val_mean_absolute_error: 0.3915
# Epoch 19/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.3072 - root_mean_squared_error: 0.5543 - mean_absolute_error: 0.3390 - val_loss: 0.4033 - val_root_mean_squared_error: 0.6351 - val_mean_absolute_error: 0.3979
# Epoch 20/30
# 2745/2745 [==============================] - 44s 16ms/step - loss: 0.3053 - root_mean_squared_error: 0.5526 - mean_absolute_error: 0.3366 - val_loss: 0.4005 - val_root_mean_squared_error: 0.6329 - val_mean_absolute_error: 0.3872
# Epoch 21/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.3039 - root_mean_squared_error: 0.5512 - mean_absolute_error: 0.3356 - val_loss: 0.4177 - val_root_mean_squared_error: 0.6463 - val_mean_absolute_error: 0.3754
# Epoch 22/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.3024 - root_mean_squared_error: 0.5499 - mean_absolute_error: 0.3344 - val_loss: 0.3948 - val_root_mean_squared_error: 0.6284 - val_mean_absolute_error: 0.3824
# Epoch 23/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.3008 - root_mean_squared_error: 0.5484 - mean_absolute_error: 0.3332 - val_loss: 0.4030 - val_root_mean_squared_error: 0.6348 - val_mean_absolute_error: 0.3800
# Epoch 24/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.2980 - root_mean_squared_error: 0.5459 - mean_absolute_error: 0.3316 - val_loss: 0.4218 - val_root_mean_squared_error: 0.6494 - val_mean_absolute_error: 0.3910
# Epoch 25/30
# 2745/2745 [==============================] - 44s 16ms/step - loss: 0.2970 - root_mean_squared_error: 0.5450 - mean_absolute_error: 0.3302 - val_loss: 0.4206 - val_root_mean_squared_error: 0.6485 - val_mean_absolute_error: 0.3860
# Epoch 26/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.2960 - root_mean_squared_error: 0.5440 - mean_absolute_error: 0.3303 - val_loss: 0.4188 - val_root_mean_squared_error: 0.6472 - val_mean_absolute_error: 0.4038
# Epoch 27/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.2944 - root_mean_squared_error: 0.5426 - mean_absolute_error: 0.3301 - val_loss: 0.4021 - val_root_mean_squared_error: 0.6341 - val_mean_absolute_error: 0.3795
# Epoch 28/30
# 2745/2745 [==============================] - 44s 16ms/step - loss: 0.2925 - root_mean_squared_error: 0.5408 - mean_absolute_error: 0.3284 - val_loss: 0.4010 - val_root_mean_squared_error: 0.6332 - val_mean_absolute_error: 0.3941
# Epoch 29/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.2909 - root_mean_squared_error: 0.5394 - mean_absolute_error: 0.3284 - val_loss: 0.4231 - val_root_mean_squared_error: 0.6504 - val_mean_absolute_error: 0.3834
# Epoch 30/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.2886 - root_mean_squared_error: 0.5372 - mean_absolute_error: 0.3260 - val_loss: 0.4134 - val_root_mean_squared_error: 0.6429 - val_mean_absolute_error: 0.3785
# Training History for Cluster 3:

# %%
## Save Scenario 3 models
scenario_3_zero_cluster.model.save(f'Models/Scenario3/{model_name}/zero_cluster')
scenario_3_one_cluster.model.save(f'Models/Scenario3/{model_name}/one_cluster')
scenario_3_two_cluster.model.save(f'Models/Scenario3/{model_name}/two_cluster')
scenario_3_three_cluster.model.save(f'Models/Scenario3/{model_name}/three_cluster')

# Pickling objects

scenario_3_zero_cluster_file = open(f"Models/Scenario3/Objects/{model_name}/zero_cluster.pickle", "wb")
pickle.dump(scenario_3_zero_cluster, scenario_3_zero_cluster_file)
scenario_3_zero_cluster_file.close()

scenario_3_one_cluster_file = open(f"Models/Scenario3/Objects/{model_name}/one_cluster.pickle", "wb")
pickle.dump(scenario_3_one_cluster, scenario_3_one_cluster_file)
scenario_3_one_cluster_file.close()

scenario_3_two_cluster_file = open(f"Models/Scenario3/Objects/{model_name}/two_cluster.pickle", "wb")
pickle.dump(scenario_3_two_cluster, scenario_3_two_cluster_file)
scenario_3_two_cluster_file.close()

scenario_3_three_cluster_file = open(f"Models/Scenario3/Objects/{model_name}/three_cluster.pickle", "wb")
pickle.dump(scenario_3_three_cluster, scenario_3_three_cluster_file)
scenario_3_three_cluster_file.close()

scenario_3_zero_cluster_results_file = open(f"Models/Scenario3/Objects/{model_name}/zero_cluster_results.pickle", "wb")
pickle.dump(scenario_3_zero_cluster_results, scenario_3_zero_cluster_results_file)
scenario_3_zero_cluster_results_file.close()

scenario_3_one_cluster_results_file = open(f"Models/Scenario3/Objects/{model_name}/one_cluster_results.pickle", "wb")
pickle.dump(scenario_3_one_cluster_results, scenario_3_one_cluster_results_file)
scenario_3_one_cluster_results_file.close()

scenario_3_two_cluster_results_file = open(f"Models/Scenario3/Objects/{model_name}/two_cluster_results.pickle", "wb")
pickle.dump(scenario_3_two_cluster_results, scenario_3_two_cluster_results_file)
scenario_3_two_cluster_results_file.close()

scenario_3_three_cluster_results_file = open(f"Models/Scenario3/Objects/{model_name}/three_cluster_results.pickle", "wb")
pickle.dump(scenario_3_three_cluster_results, scenario_3_three_cluster_results_file)
scenario_3_three_cluster_results_file.close()
# Out:
# INFO:tensorflow:Assets written to: Models/Scenario3/LSTM/zero_cluster/assets
# INFO:tensorflow:Assets written to: Models/Scenario3/LSTM/zero_cluster/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f5fcba49340> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f600d58a070> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f5fb136da30> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# INFO:tensorflow:Assets written to: Models/Scenario3/LSTM/one_cluster/assets
# INFO:tensorflow:Assets written to: Models/Scenario3/LSTM/one_cluster/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f600cebfcd0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f600cf62700> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f600cebdd90> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# INFO:tensorflow:Assets written to: Models/Scenario3/LSTM/two_cluster/assets
# INFO:tensorflow:Assets written to: Models/Scenario3/LSTM/two_cluster/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f6014071ac0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f5fea0800a0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f5fca53d5b0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# INFO:tensorflow:Assets written to: Models/Scenario3/LSTM/three_cluster/assets
# INFO:tensorflow:Assets written to: Models/Scenario3/LSTM/three_cluster/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f5f974b9c40> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f5f97507280> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f5f97466d30> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# INFO:tensorflow:Assets written to: ram://4a5a6950-f2ac-47f2-940a-42d823f5787b/assets
# INFO:tensorflow:Assets written to: ram://4a5a6950-f2ac-47f2-940a-42d823f5787b/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f5fcba49340> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f600d58a070> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f5fb136da30> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# INFO:tensorflow:Assets written to: ram://8b2f0f1d-febc-4451-96a1-89af3f0bbf89/assets
# INFO:tensorflow:Assets written to: ram://8b2f0f1d-febc-4451-96a1-89af3f0bbf89/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f600cebfcd0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f600cf62700> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f600cebdd90> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# INFO:tensorflow:Assets written to: ram://a476d65b-5775-4df6-8b9c-927e0569a3e3/assets
# INFO:tensorflow:Assets written to: ram://a476d65b-5775-4df6-8b9c-927e0569a3e3/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f6014071ac0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f5fea0800a0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f5fca53d5b0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# INFO:tensorflow:Assets written to: ram://b1842180-f0b1-4477-9504-a8c73a7b7b25/assets
# INFO:tensorflow:Assets written to: ram://b1842180-f0b1-4477-9504-a8c73a7b7b25/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f5f974b9c40> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f5f97507280> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f5f97466d30> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.

# %% [markdown]
# #### Scenario 4

# %%
scenario_4_all_cluster = Cluster(all_houses)
scenario_4_all_cluster_results = scenario_4_all_cluster.results(model_name)
print('Training History without clustering:')
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_27 (LSTM)              (None, 14, 128)           66560
#
#  lstm_28 (LSTM)              (None, 14, 32)            20608
#
#  lstm_29 (LSTM)              (None, 16)                3136
#
#  dense_9 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 90,321
# Trainable params: 90,321
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 26534/26534 [==============================] - 423s 16ms/step - loss: 0.3354 - root_mean_squared_error: 0.5792 - mean_absolute_error: 0.3185 - val_loss: 0.3415 - val_root_mean_squared_error: 0.5844 - val_mean_absolute_error: 0.3412
# Epoch 2/30
# 26534/26534 [==============================] - 421s 16ms/step - loss: 0.3126 - root_mean_squared_error: 0.5591 - mean_absolute_error: 0.3023 - val_loss: 0.3665 - val_root_mean_squared_error: 0.6054 - val_mean_absolute_error: 0.3147
# Epoch 3/30
# 26534/26534 [==============================] - 422s 16ms/step - loss: 0.3064 - root_mean_squared_error: 0.5535 - mean_absolute_error: 0.2997 - val_loss: 0.3372 - val_root_mean_squared_error: 0.5807 - val_mean_absolute_error: 0.3282
# Epoch 4/30
# 26534/26534 [==============================] - 422s 16ms/step - loss: 0.3036 - root_mean_squared_error: 0.5510 - mean_absolute_error: 0.2982 - val_loss: 0.3378 - val_root_mean_squared_error: 0.5812 - val_mean_absolute_error: 0.3121
# Epoch 5/30
# 26534/26534 [==============================] - 422s 16ms/step - loss: 0.3015 - root_mean_squared_error: 0.5491 - mean_absolute_error: 0.2969 - val_loss: 0.3364 - val_root_mean_squared_error: 0.5800 - val_mean_absolute_error: 0.3224
# Epoch 6/30
# 26534/26534 [==============================] - 424s 16ms/step - loss: 0.3002 - root_mean_squared_error: 0.5479 - mean_absolute_error: 0.2963 - val_loss: 0.3382 - val_root_mean_squared_error: 0.5816 - val_mean_absolute_error: 0.3248
# Epoch 7/30
# 26534/26534 [==============================] - 425s 16ms/step - loss: 0.2983 - root_mean_squared_error: 0.5461 - mean_absolute_error: 0.2958 - val_loss: 0.3547 - val_root_mean_squared_error: 0.5955 - val_mean_absolute_error: 0.3232
# Epoch 8/30
# 26534/26534 [==============================] - 425s 16ms/step - loss: 0.2975 - root_mean_squared_error: 0.5454 - mean_absolute_error: 0.2952 - val_loss: 0.3598 - val_root_mean_squared_error: 0.5998 - val_mean_absolute_error: 0.3229
# Epoch 9/30
# 26534/26534 [==============================] - 426s 16ms/step - loss: 0.2961 - root_mean_squared_error: 0.5441 - mean_absolute_error: 0.2950 - val_loss: 0.3495 - val_root_mean_squared_error: 0.5912 - val_mean_absolute_error: 0.3144
# Epoch 10/30
# 26534/26534 [==============================] - 427s 16ms/step - loss: 0.2954 - root_mean_squared_error: 0.5435 - mean_absolute_error: 0.2943 - val_loss: 0.3709 - val_root_mean_squared_error: 0.6090 - val_mean_absolute_error: 0.3203
# Epoch 11/30
# 26534/26534 [==============================] - 428s 16ms/step - loss: 0.2940 - root_mean_squared_error: 0.5422 - mean_absolute_error: 0.2938 - val_loss: 0.3503 - val_root_mean_squared_error: 0.5919 - val_mean_absolute_error: 0.3311
# Epoch 12/30
# 26534/26534 [==============================] - 429s 16ms/step - loss: 0.2935 - root_mean_squared_error: 0.5418 - mean_absolute_error: 0.2936 - val_loss: 0.3570 - val_root_mean_squared_error: 0.5975 - val_mean_absolute_error: 0.3211
# Epoch 13/30
# 26534/26534 [==============================] - 429s 16ms/step - loss: 0.2913 - root_mean_squared_error: 0.5397 - mean_absolute_error: 0.2930 - val_loss: 0.3367 - val_root_mean_squared_error: 0.5802 - val_mean_absolute_error: 0.3165
# Epoch 14/30
# 26534/26534 [==============================] - 431s 16ms/step - loss: 0.2912 - root_mean_squared_error: 0.5396 - mean_absolute_error: 0.2924 - val_loss: 0.3361 - val_root_mean_squared_error: 0.5797 - val_mean_absolute_error: 0.3088
# Epoch 15/30
# 26534/26534 [==============================] - 431s 16ms/step - loss: 0.2915 - root_mean_squared_error: 0.5399 - mean_absolute_error: 0.2924 - val_loss: 0.3440 - val_root_mean_squared_error: 0.5865 - val_mean_absolute_error: 0.3275
# Epoch 16/30
# 26534/26534 [==============================] - 432s 16ms/step - loss: 0.2938 - root_mean_squared_error: 0.5420 - mean_absolute_error: 0.2921 - val_loss: 0.3700 - val_root_mean_squared_error: 0.6083 - val_mean_absolute_error: 0.3333
# Epoch 17/30
# 26534/26534 [==============================] - 432s 16ms/step - loss: 0.2894 - root_mean_squared_error: 0.5380 - mean_absolute_error: 0.2915 - val_loss: 0.3514 - val_root_mean_squared_error: 0.5928 - val_mean_absolute_error: 0.3200
# Epoch 18/30
# 26534/26534 [==============================] - 434s 16ms/step - loss: 0.2946 - root_mean_squared_error: 0.5428 - mean_absolute_error: 0.2918 - val_loss: 0.3404 - val_root_mean_squared_error: 0.5834 - val_mean_absolute_error: 0.3143
# Epoch 19/30
# 26534/26534 [==============================] - 434s 16ms/step - loss: 0.2882 - root_mean_squared_error: 0.5368 - mean_absolute_error: 0.2911 - val_loss: 0.3446 - val_root_mean_squared_error: 0.5870 - val_mean_absolute_error: 0.3233
# Epoch 20/30
# 26534/26534 [==============================] - 435s 16ms/step - loss: 0.2872 - root_mean_squared_error: 0.5359 - mean_absolute_error: 0.2912 - val_loss: 0.3412 - val_root_mean_squared_error: 0.5841 - val_mean_absolute_error: 0.3332
# Epoch 21/30
# 26534/26534 [==============================] - 435s 16ms/step - loss: 0.2884 - root_mean_squared_error: 0.5370 - mean_absolute_error: 0.2908 - val_loss: 0.3454 - val_root_mean_squared_error: 0.5877 - val_mean_absolute_error: 0.3187
# Epoch 22/30
# 26534/26534 [==============================] - 438s 16ms/step - loss: 0.5134 - root_mean_squared_error: 0.7165 - mean_absolute_error: 0.3026 - val_loss: 0.3933 - val_root_mean_squared_error: 0.6272 - val_mean_absolute_error: 0.3384
# Epoch 23/30
# 26534/26534 [==============================] - 440s 17ms/step - loss: 0.5364 - root_mean_squared_error: 0.7324 - mean_absolute_error: 0.3517 - val_loss: 0.6701 - val_root_mean_squared_error: 0.8186 - val_mean_absolute_error: 0.3968
# Epoch 24/30
# 26534/26534 [==============================] - 443s 17ms/step - loss: 4.7393 - root_mean_squared_error: 2.1770 - mean_absolute_error: 0.5010 - val_loss: 0.6536 - val_root_mean_squared_error: 0.8085 - val_mean_absolute_error: 0.4915
# Epoch 25/30
# 26534/26534 [==============================] - 443s 17ms/step - loss: 2.2789 - root_mean_squared_error: 1.5096 - mean_absolute_error: 0.4710 - val_loss: 9.8600 - val_root_mean_squared_error: 3.1401 - val_mean_absolute_error: 0.5453
# Epoch 26/30
# 26534/26534 [==============================] - 445s 17ms/step - loss: 4.7127 - root_mean_squared_error: 2.1709 - mean_absolute_error: 0.4634 - val_loss: 2.7299 - val_root_mean_squared_error: 1.6522 - val_mean_absolute_error: 0.5278
# Epoch 27/30
# 26534/26534 [==============================] - 445s 17ms/step - loss: 6.9123 - root_mean_squared_error: 2.6291 - mean_absolute_error: 0.5212 - val_loss: 0.6782 - val_root_mean_squared_error: 0.8236 - val_mean_absolute_error: 0.5162
# Epoch 28/30
# 26534/26534 [==============================] - 447s 17ms/step - loss: 5.1167 - root_mean_squared_error: 2.2620 - mean_absolute_error: 0.5025 - val_loss: 0.6693 - val_root_mean_squared_error: 0.8181 - val_mean_absolute_error: 0.4884
# Epoch 29/30
# 26534/26534 [==============================] - 448s 17ms/step - loss: 0.6102 - root_mean_squared_error: 0.7812 - mean_absolute_error: 0.4955 - val_loss: 0.6768 - val_root_mean_squared_error: 0.8227 - val_mean_absolute_error: 0.4941
# Epoch 30/30
# 26534/26534 [==============================] - 449s 17ms/step - loss: 0.6068 - root_mean_squared_error: 0.7790 - mean_absolute_error: 0.4935 - val_loss: 0.5662 - val_root_mean_squared_error: 0.7524 - val_mean_absolute_error: 0.4563
# Training History without clustering:

# %%
### Save Scenario 4 models
scenario_4_all_cluster.model.save(f'Models/Scenario4/{model_name}/all_cluster')

## Pickling Scenario 4 cluster and cluster result files
scenario_4_all_cluster_file = open(f"Models/Scenario4/{model_name}/all_cluster.pickle", "wb")
pickle.dump(scenario_4_all_cluster, scenario_4_all_cluster_file)
scenario_4_all_cluster_file.close()

scenario_4_all_cluster_results_file = open(f"Models/Scenario4/{model_name}/all_cluster_results.pickle", "wb")
pickle.dump(scenario_4_all_cluster_results, scenario_4_all_cluster_results_file)
scenario_4_all_cluster_results_file.close()
# Out:
# INFO:tensorflow:Assets written to: Models/Scenario4/LSTM/all_cluster/assets
# INFO:tensorflow:Assets written to: Models/Scenario4/LSTM/all_cluster/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f5f7a6028b0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f5f78faf7f0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f5f7a8ccee0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# INFO:tensorflow:Assets written to: ram://6ee52d97-8230-4bd9-826f-da7528aac42e/assets
# INFO:tensorflow:Assets written to: ram://6ee52d97-8230-4bd9-826f-da7528aac42e/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f5f7a6028b0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f5f78faf7f0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f5f7a8ccee0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.

# %% [markdown]
# #### Predictions for Scenario 3 and Scenario 4

# %%
graph_predictions(scenario_3_zero_cluster_results, scenario_4_all_cluster_results)
# Out:
# /tmp/ipykernel_119344/442122963.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['timestamp'] = pd.to_datetime(df1['timestamp'])

# %%
graph_predictions(scenario_3_one_cluster_results, scenario_4_all_cluster_results)
# Out:
# /tmp/ipykernel_119344/442122963.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['timestamp'] = pd.to_datetime(df1['timestamp'])

# %%
graph_predictions(scenario_3_two_cluster_results, scenario_4_all_cluster_results)
# Out:
# /tmp/ipykernel_119344/442122963.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['timestamp'] = pd.to_datetime(df1['timestamp'])

# %%
graph_predictions(scenario_3_three_cluster_results, scenario_4_all_cluster_results)
# Out:
# /tmp/ipykernel_119344/442122963.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['timestamp'] = pd.to_datetime(df1['timestamp'])

# %% [markdown]
# #### Scenario 3 and Scenario 4 Metric Tables

# %%
scenario_3_results = [scenario_3_zero_cluster, scenario_3_one_cluster, scenario_3_two_cluster, scenario_3_three_cluster]
scenario_3_metrics = create_metrics(scenario_3_results )
scenario_3_validation_metrics = create_metrics(scenario_3_results, val= True)
scenario_3_metrics
# Out:
# [0.3706747889518738,
#  1.25237238407135,
#  0.6279423837860425,
#  0.20341117680072784,
#  0.7520983219146729,
#  0.36028993998964626]

# %%
scenario_4_results = [scenario_4_all_cluster]
scenario_4_metrics = create_metrics(scenario_4_results )
scenario_4_validation_metrics = create_metrics(scenario_4_results, val= True)
scenario_4_metrics
# Out:
# [0.5359355807304382,
#  2.6291229724884033,
#  0.8404126505057017,
#  0.2908397614955902,
#  0.5211940407752991,
#  0.34360813200473783]

# %%
print('Training metrics:')
df = pd.DataFrame([scenario_1_metrics, scenario_2_metrics, scenario_3_metrics, scenario_4_metrics],index=[1,2,3,4], columns = ['Min RMSE', 'Max RMSE', 'Mean RMSE','Min MAE', 'Max MAE', 'Mean MAE'])
df['Scenario'] = np.array([1,2,3,4])
df.set_index('Scenario').round(decimals=2).to_csv('Tables/training_metrics.csv')
# Out:
# Training metrics:

# %%
print('Validation metrics:')
df = pd.DataFrame([scenario_1_validation_metrics, scenario_2_validation_metrics,
                   scenario_3_validation_metrics, scenario_4_validation_metrics],index=[1,2,3,4], columns = ['Min RMSE', 'Max RMSE', 'Mean RMSE','Min MAE', 'Max MAE', 'Mean MAE'])
df['Scenario'] = np.array([1,2,3,4])
df.set_index('Scenario').round(decimals=2).to_csv('Tables/validation_metrics.csv')
# Out:
# Validation metrics:

# %% [markdown]
# ### Anomaly Distribution

# %%
def create_anomaly_df(result_df, scenario_name, monthly_agg = True):    
    #print(type(result_df))
    anomaly_df = result_df[['timestamp', 'Anomaly detected']]
    anomaly_df.set_index('timestamp', inplace = True)
    if monthly_agg:
        anomaly_df['Anomaly detected'] = anomaly_df['Anomaly detected'].apply(lambda x: 0 if x is False else 1)
        anomaly_df = anomaly_df.resample("M").agg('sum')
    else: 
        anomaly_df['Anomaly detected'] = anomaly_df['Anomaly detected'].apply(lambda x: 0 if x is False else x)
    anomaly_df = anomaly_df.rename(columns={'Anomaly detected': scenario_name})
    return anomaly_df

def create_anomalies_graph( title = None, **kwargs):
    anomaly_dfs = []
    for scenario_name, result_df in kwargs.items():
        anomaly_df = create_anomaly_df(result_df, scenario_name)
        anomaly_dfs.append(anomaly_df)
    anomaly_df = functools.reduce(lambda left, right: left.join(right), anomaly_dfs)
    ax = anomaly_df.plot.line(figsize=(20,10))
    ax.set_xlabel(f'Time')
    ax.set_ylabel(f'Frequency')
    ax.set_title(title)
    #return anomaly_dfs

# %%
def dtw_distance(series1, series2):
    return fastdtw.fastdtw(series1,series2)[0]

def create_distance_df(title, **kwargs):
    print(title)
    anomaly_dfs = []
    for scenario_name, result_df in kwargs.items():
        anomaly_df = np.array(create_anomaly_df(result_df, scenario_name, monthly_agg=False)).reshape(1,-1)
        anomaly_dfs.append(anomaly_df)
    anomaly_distributions = np.array(anomaly_dfs).reshape(len(kwargs),-1)
    distance_matrix = sd.squareform(sd.pdist(anomaly_distributions, dtw_distance))
    return(pd.DataFrame(distance_matrix, columns = kwargs.keys(), index = kwargs.keys()))
    #return anomaly_dfs

# %%
create_anomalies_graph( 'Anomaly Frequency Distribution for House 1: Cluster 0', Scenario1 = zero_cluster_results[1], Scenario2 = all_cluster_results[1],
                       Scenario3 = scenario_3_zero_cluster_results[1], Scenario4 = scenario_4_all_cluster_results[1])
# Out:
# /tmp/ipykernel_119344/3162963936.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anomaly_df['Anomaly detected'] = anomaly_df['Anomaly detected'].apply(lambda x: 0 if x is False else 1)

# %%
create_distance_df('Similarity between anomaly distributions for House1: Cluster 0', Scenario1 = zero_cluster_results[1], Scenario2 = all_cluster_results[1],
                       Scenario3 = scenario_3_zero_cluster_results[1], Scenario4 = scenario_4_all_cluster_results[1]).round(decimals=2).to_csv('Tables/anomaly_cluster0.csv')
# Out:
# Similarity between anomaly distributions for House1: Cluster 0
# /tmp/ipykernel_119344/3162963936.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anomaly_df['Anomaly detected'] = anomaly_df['Anomaly detected'].apply(lambda x: 0 if x is False else x)

# %%
create_anomalies_graph( 'Anomaly Frequency Distribution for House 15: Cluster 1', Scenario1 = one_cluster_results[15], Scenario2 = all_cluster_results[15],
                       Scenario3 = scenario_3_one_cluster_results[15], Scenario4 = scenario_4_all_cluster_results[15])
# Out:
# /tmp/ipykernel_119344/3162963936.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anomaly_df['Anomaly detected'] = anomaly_df['Anomaly detected'].apply(lambda x: 0 if x is False else 1)

# %%
create_distance_df( 'Similarity between anomaly distributions for House15: Cluster 1', Scenario1 = one_cluster_results[15], Scenario2 = all_cluster_results[15],
                       Scenario3 = scenario_3_one_cluster_results[15], Scenario4 = scenario_4_all_cluster_results[15]).round(decimals=2).to_csv('Tables/anomaly_cluster1.csv')
# Out:
# Similarity between anomaly distributions for House15: Cluster 1
# /tmp/ipykernel_119344/3162963936.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anomaly_df['Anomaly detected'] = anomaly_df['Anomaly detected'].apply(lambda x: 0 if x is False else x)

# %%
create_anomalies_graph( 'Anomaly Frequency Distribution for House 2: Cluster 2', Scenario1 = two_cluster_results[2], Scenario2 = all_cluster_results[2],
                       Scenario3 = scenario_3_two_cluster_results[2], Scenario4 = scenario_4_all_cluster_results[2])
# Out:
# /tmp/ipykernel_119344/3162963936.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anomaly_df['Anomaly detected'] = anomaly_df['Anomaly detected'].apply(lambda x: 0 if x is False else 1)

# %%
create_distance_df( 'Similarity between anomaly distributions for House 2: Cluster 2', Scenario1 = two_cluster_results[2], Scenario2 = all_cluster_results[2],
                       Scenario3 = scenario_3_two_cluster_results[2], Scenario4 = scenario_4_all_cluster_results[2]).round(decimals=2).to_csv('Tables/anomaly_cluster2.csv')
# Out:
# Similarity between anomaly distributions for House 2: Cluster 2
# /tmp/ipykernel_119344/3162963936.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anomaly_df['Anomaly detected'] = anomaly_df['Anomaly detected'].apply(lambda x: 0 if x is False else x)

# %%
create_anomalies_graph( 'Anomaly Frequency Distribution for House 3: Cluster 3', Scenario1 = three_cluster_results[3], Scenario2 = all_cluster_results[3],
                       Scenario3 = scenario_3_three_cluster_results[3], Scenario4 = scenario_4_all_cluster_results[3])
# Out:
# /tmp/ipykernel_119344/3162963936.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anomaly_df['Anomaly detected'] = anomaly_df['Anomaly detected'].apply(lambda x: 0 if x is False else 1)

# %%
create_distance_df( 'Similarity between anomaly distributions for House 3: Cluster 3', Scenario1 = three_cluster_results[3], Scenario2 = all_cluster_results[3],
                       Scenario3 = scenario_3_three_cluster_results[3], Scenario4 = scenario_4_all_cluster_results[3]).round(decimals=2).to_csv('Tables/anomaly_cluster3.csv')
# Out:
# Similarity between anomaly distributions for House 3: Cluster 3
# /tmp/ipykernel_119344/3162963936.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anomaly_df['Anomaly detected'] = anomaly_df['Anomaly detected'].apply(lambda x: 0 if x is False else x)

# %% [markdown]
# #### Energy Deficit Calculation

# %%
def create_deficit_df(result_df, scenario_name, monthly_agg = True):    
    #print(type(result_df))
    energy_df = result_df[['timestamp', 'Energy Deficit Flag']]
    energy_df.set_index('timestamp', inplace = True)
    if monthly_agg:
        energy_df['Energy Deficit Flag'] = energy_df['Energy Deficit Flag'].apply(lambda x: 0 if x is False else 1)
        energy_df = energy_df.resample("W").agg('sum')
    else: 
        energy_df['Energy Deficit Flag'] = energy_df['Energy Deficit Flag'].apply(lambda x: 0 if x is False else x)
    energy_df = energy_df.rename(columns={'Energy Deficit Flag': scenario_name})
    return energy_df

def create_energy_deficit_graph( title = None, **kwargs):
    energy_dfs = []
    for scenario_name, result_df in kwargs.items():
        energy_df = create_deficit_df(result_df, scenario_name)
        energy_dfs.append(energy_df)
    energy_df = functools.reduce(lambda left, right: left.join(right), energy_dfs)
    ax = energy_df.plot.line(figsize=(20,10))
    ax.set_xlabel(f'Time')
    ax.set_ylabel(f'Frequency')
    ax.set_title(title)

# %%
def create_deficit_distance_df(title, **kwargs):
    print(title)
    energy_dfs = []
    for scenario_name, result_df in kwargs.items():
        energy_df = np.array(create_deficit_df(result_df, scenario_name, monthly_agg=False)).reshape(1,-1)
        energy_dfs.append(energy_df)
    energy_distributions = np.array(energy_dfs).reshape(len(kwargs),-1)
    distance_matrix = sd.squareform(sd.pdist(energy_distributions, dtw_distance))
    return(pd.DataFrame(distance_matrix, columns = kwargs.keys(), index = kwargs.keys()))

# %%
create_energy_deficit_graph( 'Energy Deficit Frequency Distribution for House 1: Cluster 0', Scenario1 = zero_cluster_results[1], Scenario2 = all_cluster_results[1],
                       Scenario3 = scenario_3_zero_cluster_results[1], Scenario4 = scenario_4_all_cluster_results[1])
# Out:
# /tmp/ipykernel_119344/2779099769.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   energy_df['Energy Deficit Flag'] = energy_df['Energy Deficit Flag'].apply(lambda x: 0 if x is False else 1)

# %%
create_deficit_distance_df('Similarity between energy deficit distributions for House1: Cluster 0', Scenario1 = zero_cluster_results[1], Scenario2 = all_cluster_results[1],
                       Scenario3 = scenario_3_zero_cluster_results[1], Scenario4 = scenario_4_all_cluster_results[1])
# Out:
# Similarity between energy deficit distributions for House1: Cluster 0
# /tmp/ipykernel_119344/2779099769.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   energy_df['Energy Deficit Flag'] = energy_df['Energy Deficit Flag'].apply(lambda x: 0 if x is False else x)
#              Scenario1    Scenario2    Scenario3    Scenario4
# Scenario1     0.000000  2528.422636  2936.268400  9652.258650
# Scenario2  2528.422636     0.000000  2525.242190  7179.358023
# Scenario3  2936.268400  2525.242190     0.000000  8940.725172
# Scenario4  9652.258650  7179.358023  8940.725172     0.000000

# %%
create_energy_deficit_graph( 'Energy Deficit Frequency Distribution for House 15: Cluster 1', Scenario1 = one_cluster_results[15], Scenario2 = all_cluster_results[15],
                       Scenario3 = scenario_3_one_cluster_results[15], Scenario4 = scenario_4_all_cluster_results[15])
# Out:
# /tmp/ipykernel_119344/2779099769.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   energy_df['Energy Deficit Flag'] = energy_df['Energy Deficit Flag'].apply(lambda x: 0 if x is False else 1)

# %%
create_deficit_distance_df( 'Similarity between energy deficit distributions for House15: Cluster 1', Scenario1 = one_cluster_results[15], 
                    Scenario2 = all_cluster_results[15],
                       Scenario3 = scenario_3_one_cluster_results[15], Scenario4 = scenario_4_all_cluster_results[15])
# Out:
# Similarity between energy deficit distributions for House15: Cluster 1
# /tmp/ipykernel_119344/2779099769.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   energy_df['Energy Deficit Flag'] = energy_df['Energy Deficit Flag'].apply(lambda x: 0 if x is False else x)
#               Scenario1     Scenario2     Scenario3     Scenario4
# Scenario1      0.000000   4078.844882   3483.470914  13920.065242
# Scenario2   4078.844882      0.000000   3861.651905  12853.421457
# Scenario3   3483.470914   3861.651905      0.000000  13567.107453
# Scenario4  13920.065242  12853.421457  13567.107453      0.000000

# %%
create_energy_deficit_graph( 'Energy Deficit Frequency Distribution for House 2: Cluster 2', Scenario1 = two_cluster_results[2], Scenario2 = all_cluster_results[2],
                       Scenario3 = scenario_3_two_cluster_results[2], Scenario4 = scenario_4_all_cluster_results[2])
# Out:
# /tmp/ipykernel_119344/2779099769.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   energy_df['Energy Deficit Flag'] = energy_df['Energy Deficit Flag'].apply(lambda x: 0 if x is False else 1)

# %%
create_deficit_distance_df( 'Similarity between energy deficit distributions for House 2: Cluster 2', Scenario1 = two_cluster_results[2], Scenario2 = all_cluster_results[2],
                       Scenario3 = scenario_3_two_cluster_results[2], Scenario4 = scenario_4_all_cluster_results[2])
# Out:
# Similarity between energy deficit distributions for House 2: Cluster 2
# /tmp/ipykernel_119344/2779099769.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   energy_df['Energy Deficit Flag'] = energy_df['Energy Deficit Flag'].apply(lambda x: 0 if x is False else x)
#              Scenario1    Scenario2    Scenario3    Scenario4
# Scenario1     0.000000  1288.385300   455.117581  2365.851996
# Scenario2  1288.385300     0.000000  2055.705346  1755.474998
# Scenario3   455.117581  2055.705346     0.000000  2492.260201
# Scenario4  2365.851996  1755.474998  2492.260201     0.000000

# %%
create_energy_deficit_graph( 'Energy Deficit Frequency Distribution for House 3: Cluster 3', Scenario1 = three_cluster_results[3], Scenario2 = all_cluster_results[3],
                       Scenario3 = scenario_3_three_cluster_results[3], Scenario4 = scenario_4_all_cluster_results[3])
# Out:
# /tmp/ipykernel_119344/2779099769.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   energy_df['Energy Deficit Flag'] = energy_df['Energy Deficit Flag'].apply(lambda x: 0 if x is False else 1)

# %%
create_deficit_distance_df( 'Similarity between energy deficit distributions for House 3: Cluster 3', Scenario1 = three_cluster_results[3], Scenario2 = all_cluster_results[3],
                       Scenario3 = scenario_3_three_cluster_results[3], Scenario4 = scenario_4_all_cluster_results[3])
# Out:
# Similarity between energy deficit distributions for House 3: Cluster 3
# /tmp/ipykernel_119344/2779099769.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   energy_df['Energy Deficit Flag'] = energy_df['Energy Deficit Flag'].apply(lambda x: 0 if x is False else x)
#              Scenario1    Scenario2    Scenario3    Scenario4
# Scenario1     0.000000  3004.819668  3121.040687  6933.266866
# Scenario2  3004.819668     0.000000  3250.123760  5811.271396
# Scenario3  3121.040687  3250.123760     0.000000  5352.228005
# Scenario4  6933.266866  5811.271396  5352.228005     0.000000

# %%
print(tf. __version__)
# Out:
# 2.7.0

# %%
scenario_4_all_cluster_results_file = open(f"Models/Scenario4/Objects/{model_name}/all_cluster_results.pickle", "wb")
pickle.dump(scenario_4_all_cluster_results, scenario_4_all_cluster_results_file)
scenario_4_all_cluster_results_file.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_119344/3127663111.py in <module>
# ----> 1 scenario_4_all_cluster_results_file = open(f"Models/Scenario4/Objects/{model_name}/all_cluster_results.pickle", "wb")
#       2 pickle.dump(scenario_4_all_cluster_results, scenario_4_all_cluster_results_file)
#       3 scenario_4_all_cluster_results_file.close()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Models/Scenario4/Objects/LSTM/all_cluster_results.pickle'
