# %% [markdown]
# #### Importing Libraries and Dataset

# %%
import numpy as np
from statistics import mean
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import pandas as pd
import seaborn as sns
from tslearn.clustering import TimeSeriesKMeans
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, SimpleRNN 
from tensorflow.keras import regularizers
from tensorflow.keras.layers import Dense, Dropout
import tensorflow as tf
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from tensorflow import keras
import seaborn as sns
import pickle
import functools
import fastdtw
import scipy.spatial.distance as sd
#from datetime import datetime
consumption_df = pd.read_csv('Final Datasets/energy_consumption.csv')
consumption_df
# Out:
# 2022-03-06 14:32:05.338982: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-03-06 14:32:05.339009: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
#         Unnamed: 0            timestamp  energy_kWh  House Number  \
# 0                0  2012-06-01 01:00:00      1.0110             1
# 1                1  2012-06-01 02:00:00      0.4510             1
# 2                2  2012-06-01 03:00:00      0.5050             1
# 3                3  2012-06-01 04:00:00      0.4410             1
# 4                4  2012-06-01 05:00:00      0.4680             1
# ...            ...                  ...         ...           ...
# 611013      123761  2020-05-19 19:00:00      3.5802            28
# 611014      123762  2020-05-19 20:00:00      3.4398            28
# 611015      123763  2020-05-19 21:00:00      2.3049            28
# 611016      123764  2020-05-19 22:00:00      2.4921            28
# 611017      123765  2020-05-19 23:00:00      1.1817            28
#
#         electronics workbench energy  network equipment energy  \
# 0                           0.008686                  0.019316
# 1                           0.007178                  0.019338
# 2                           0.007324                  0.019336
# 3                           0.007151                  0.019339
# 4                           0.007224                  0.019338
# ...                              ...                       ...
# 611013                      0.028408                  0.038470
# 611014                      0.027762                  0.038479
# 611015                      0.022537                  0.038556
# 611016                      0.023399                  0.038544
# 611017                      0.017367                  0.038632
#
#         home office energy  RAE home office energy  \
# 0                 0.018232                0.134570
# 1                 0.013745                0.061839
# 2                 0.014177                0.068852
# 3                 0.013664                0.060540
# 4                 0.013881                0.064047
# ...                    ...                     ...
# 611013            0.069307                0.801381
# 611014            0.067384                0.770210
# 611015            0.051836                0.518247
# 611016            0.054401                0.559808
# 611017            0.036449                0.268881
#
#         RAE Mobile Phone Charger Energy
# 0                              0.000431
# 1                              0.000215
# 2                              0.000236
# 3                              0.000211
# 4                              0.000221
# ...                                 ...
# 611013                         0.002441
# 611014                         0.002348
# 611015                         0.001601
# 611016                         0.001724
# 611017                         0.000861
#
# [611018 rows x 9 columns]

# %%
if 'Unnamed: 0' in consumption_df.columns:
    consumption_df.drop('Unnamed: 0',axis=1, inplace = True)

# %%
consumption_df
# Out:
#                   timestamp  energy_kWh  House Number  \
# 0       2012-06-01 01:00:00      1.0110             1
# 1       2012-06-01 02:00:00      0.4510             1
# 2       2012-06-01 03:00:00      0.5050             1
# 3       2012-06-01 04:00:00      0.4410             1
# 4       2012-06-01 05:00:00      0.4680             1
# ...                     ...         ...           ...
# 611013  2020-05-19 19:00:00      3.5802            28
# 611014  2020-05-19 20:00:00      3.4398            28
# 611015  2020-05-19 21:00:00      2.3049            28
# 611016  2020-05-19 22:00:00      2.4921            28
# 611017  2020-05-19 23:00:00      1.1817            28
#
#         electronics workbench energy  network equipment energy  \
# 0                           0.008686                  0.019316
# 1                           0.007178                  0.019338
# 2                           0.007324                  0.019336
# 3                           0.007151                  0.019339
# 4                           0.007224                  0.019338
# ...                              ...                       ...
# 611013                      0.028408                  0.038470
# 611014                      0.027762                  0.038479
# 611015                      0.022537                  0.038556
# 611016                      0.023399                  0.038544
# 611017                      0.017367                  0.038632
#
#         home office energy  RAE home office energy  \
# 0                 0.018232                0.134570
# 1                 0.013745                0.061839
# 2                 0.014177                0.068852
# 3                 0.013664                0.060540
# 4                 0.013881                0.064047
# ...                    ...                     ...
# 611013            0.069307                0.801381
# 611014            0.067384                0.770210
# 611015            0.051836                0.518247
# 611016            0.054401                0.559808
# 611017            0.036449                0.268881
#
#         RAE Mobile Phone Charger Energy
# 0                              0.000431
# 1                              0.000215
# 2                              0.000236
# 3                              0.000211
# 4                              0.000221
# ...                                 ...
# 611013                         0.002441
# 611014                         0.002348
# 611015                         0.001601
# 611016                         0.001724
# 611017                         0.000861
#
# [611018 rows x 8 columns]

# %% [markdown]
# #### Converting Dataset to House-wise dictionary

# %%
house_wise_consumption = dict()
for house_number in consumption_df['House Number'].unique():
    house_data = consumption_df[consumption_df['House Number'] == house_number]
    house_wise_consumption[house_number] = house_data.copy()
house_wise_consumption[1]
# house_wise_consumption[14]['timestamp'].iloc[0]
# house_wise_consumption[14]['timestamp'].iloc[-1]
# house_wise_consumption[14]['House Number'].iloc[0]
# Out:
#                  timestamp  energy_kWh  House Number  \
# 0      2012-06-01 01:00:00       1.011             1
# 1      2012-06-01 02:00:00       0.451             1
# 2      2012-06-01 03:00:00       0.505             1
# 3      2012-06-01 04:00:00       0.441             1
# 4      2012-06-01 05:00:00       0.468             1
# ...                    ...         ...           ...
# 29226  2015-10-02 20:00:00       2.101             1
# 29227  2015-10-02 21:00:00       1.646             1
# 29228  2015-10-02 22:00:00       1.319             1
# 29229  2015-10-02 23:00:00       1.473             1
# 29230  2015-10-03 00:00:00       0.800             1
#
#        electronics workbench energy  network equipment energy  \
# 0                          0.008686                  0.019316
# 1                          0.007178                  0.019338
# 2                          0.007324                  0.019336
# 3                          0.007151                  0.019339
# 4                          0.007224                  0.019338
# ...                             ...                       ...
# 29226                      0.011621                  0.019273
# 29227                      0.010396                  0.019291
# 29228                      0.009516                  0.019304
# 29229                      0.009930                  0.019298
# 29230                      0.008118                  0.019324
#
#        home office energy  RAE home office energy  \
# 0                0.018232                0.134570
# 1                0.013745                0.061839
# 2                0.014177                0.068852
# 3                0.013664                0.060540
# 4                0.013881                0.064047
# ...                   ...                     ...
# 29226            0.026968                0.276137
# 29227            0.023322                0.217043
# 29228            0.020701                0.174573
# 29229            0.021935                0.194574
# 29230            0.016541                0.107166
#
#        RAE Mobile Phone Charger Energy
# 0                             0.000431
# 1                             0.000215
# 2                             0.000236
# 3                             0.000211
# 4                             0.000221
# ...                                ...
# 29226                         0.000851
# 29227                         0.000675
# 29228                         0.000549
# 29229                         0.000609
# 29230                         0.000349
#
# [29231 rows x 8 columns]

# %% [markdown]
# #### Comparing Timestamps for clustering

# %%
timestamp_comparison = list()
for house in house_wise_consumption:
    first_timestamp = house_wise_consumption[house]['timestamp'].iloc[0]
    last_timestamp = house_wise_consumption[house]['timestamp'].iloc[-1]
    timestamp_comparison.append([house, first_timestamp, last_timestamp])
timestamp_comparison
timestamp_comparison_df = pd.DataFrame(timestamp_comparison, columns = ['House', 'First Timestamp', 'Last Timestamp'])
timestamp_comparison_df
# Out:
#     House      First Timestamp       Last Timestamp
# 0       1  2012-06-01 01:00:00  2015-10-03 00:00:00
# 1       2  2016-06-09 00:00:00  2019-11-20 23:00:00
# 2       3  2015-01-27 00:00:00  2018-01-29 23:00:00
# 3       4  2015-01-30 00:00:00  2018-01-29 23:00:00
# 4       5  2015-01-30 00:00:00  2018-01-29 23:00:00
# 5       6  2015-01-30 00:00:00  2018-01-29 23:00:00
# 6       7  2015-05-30 00:00:00  2018-01-29 23:00:00
# 7       8  2015-02-21 00:00:00  2018-02-20 23:00:00
# 8       9  2015-05-01 00:00:00  2018-02-21 23:00:00
# 9      10  2015-02-21 00:00:00  2018-02-20 23:00:00
# 10     11  2015-02-21 00:00:00  2018-02-20 23:00:00
# 11     12  2015-02-21 00:00:00  2018-02-20 23:00:00
# 12     13  2015-02-21 00:00:00  2018-02-20 23:00:00
# 13     14  2015-02-21 00:00:00  2018-02-20 23:00:00
# 14     15  2015-09-29 00:00:00  2018-02-20 23:00:00
# 15     16  2017-11-01 00:00:00  2019-02-18 23:00:00
# 16     17  2016-06-01 00:00:00  2017-04-29 23:00:00
# 17     18  2015-03-16 00:00:00  2018-03-15 16:00:00
# 18     19  2015-03-26 00:00:00  2018-03-25 23:00:00
# 19     20  2015-08-21 00:00:00  2018-04-20 23:00:00
# 20     21  2017-11-01 00:00:00  2018-06-04 23:00:00
# 21     22  2016-06-29 00:00:00  2018-06-05 23:00:00
# 22     23  2017-07-27 00:00:00  2020-04-05 23:00:00
# 23     24  2017-05-13 00:00:00  2020-05-12 23:00:00
# 24     25  2017-05-15 00:00:00  2020-05-14 23:00:00
# 25     26  2019-11-29 00:00:00  2020-05-20 23:00:00
# 26     27  2019-03-06 00:00:00  2020-05-20 23:00:00
# 27     28  2018-08-01 00:00:00  2020-05-19 23:00:00

# %%
# houses_with_ts = []
# sample_timestamp = '2017-11-01 00:00:00'
# for house in house_wise_consumption:
#     if sample_timestamp in house_wise_consumption[house]['timestamp'].unique():
#         houses_with_ts.append(house)
# len(houses_with_ts)
#house_wise_consumption[8][house_wise_consumption[8]['timestamp'] >= '2017-11-17'].head(60)

# %% [markdown]
# #### Creating a December consumption dictionary of dataframes

# %%
december_consumption = dict()
for house in house_wise_consumption:
    house_december_consumption = house_wise_consumption[house][(house_wise_consumption[house]['timestamp'] <= '2017-11-25') & (house_wise_consumption[house]['timestamp'] >= '2017-11-01')]
    december_consumption[house] = house_december_consumption.copy()
    december_consumption[house].drop_duplicates(subset='timestamp', keep="last", inplace = True)
def calculate_rows():
    december_rows = []
    for house in december_consumption:
        december_rows.append([house, len(december_consumption[house])])
    december_rows
    december_rows_df = pd.DataFrame(december_rows, columns = ['House', 'Rows'])
    return december_rows_df
def calculate_incomplete_rows():
    december_rows_df = calculate_rows()
    december_rows_incomplete_df = december_rows_df[(december_rows_df['Rows'] > 0) & (december_rows_df['Rows'] < 576)]
    return december_rows_incomplete_df
def fill_na_december_consumption(complete_df, incomplete_df):
    complete_df = complete_df.copy()
    year_incomplete = pd.Timestamp(incomplete_df.iloc[0]['timestamp']).year
    year_complete = pd.Timestamp(complete_df.iloc[0]['timestamp']).year
    complete_df['timestamp'] = complete_df['timestamp'].str.replace(str(year_complete), str(year_incomplete))
    fill_missing_values = complete_df[~complete_df.timestamp.isin(incomplete_df.timestamp)].copy()
    #print(fill_missing_values)
    fill_columns = ['energy_kWh', 'electronics workbench energy', 'network equipment energy', 'home office energy', 'RAE home office energy','RAE Mobile Phone Charger Energy']
    for fill_column in fill_columns:
        fill_missing_values[fill_column] = incomplete_df[fill_column].mean()
    incomplete_df = pd.concat([incomplete_df, fill_missing_values])
    incomplete_df = incomplete_df.sort_values(by=['timestamp'])
    return incomplete_df
def calculate_missing_december_rows():
    december_rows_df = calculate_rows()
    december_rows_missing_df = december_rows_df[(december_rows_df['Rows'] == 0)]
    return december_rows_missing_df
calculate_rows()
# Out:
#     House  Rows
# 0       1     0
# 1       2   576
# 2       3   576
# 3       4   576
# 4       5   576
# 5       6   576
# 6       7   576
# 7       8   448
# 8       9   576
# 9      10   576
# 10     11   568
# 11     12   528
# 12     13   576
# 13     14   575
# 14     15   576
# 15     16   456
# 16     17     0
# 17     18   528
# 18     19   576
# 19     20   575
# 20     21   576
# 21     22   528
# 22     23   576
# 23     24   576
# 24     25   576
# 25     26     0
# 26     27     0
# 27     28     0

# %%
for house in list(calculate_incomplete_rows()['House']):
    december_consumption[house] = fill_na_december_consumption(december_consumption[10], december_consumption[house])

# %% [markdown]
# ##### Houses with no December-17 consumption values

# %%
timestamp_comparison_df.set_index('House').join(calculate_missing_december_rows().set_index('House'), how='inner')
# Out:
#            First Timestamp       Last Timestamp  Rows
# House
# 1      2012-06-01 01:00:00  2015-10-03 00:00:00     0
# 17     2016-06-01 00:00:00  2017-04-29 23:00:00     0
# 26     2019-11-29 00:00:00  2020-05-20 23:00:00     0
# 27     2019-03-06 00:00:00  2020-05-20 23:00:00     0
# 28     2018-08-01 00:00:00  2020-05-19 23:00:00     0

# %%
missing_december_houses_dates = {
    1: ['2014-11-25', '2014-11-01'],
    17: ['2016-11-25', '2016-11-01'],
    26: ['2019-11-25', '2019-11-01'],
    27: ['2019-11-25', '2019-11-01'],
    28: ['2019-11-25', '2019-11-01'],
}

# %%
for house in missing_december_houses_dates:
    house_december_consumption = house_wise_consumption[house][(house_wise_consumption[house]['timestamp'] <= missing_december_houses_dates[house][0]) & (house_wise_consumption[house]['timestamp'] >= missing_december_houses_dates[house][1])]
    #print((house, missing_december_houses_dates[house][0]))
    december_consumption[house] = house_december_consumption.copy()
    december_consumption[house].drop_duplicates(subset='timestamp', keep="last", inplace = True)

# %% [markdown]
# ##### Filling missing values for December consumption

# %%
calculate_incomplete_rows()
# Out:
#     House  Rows
# 16     17   574
# 26     27   571
# 27     28   572

# %%
for house in list(calculate_incomplete_rows()['House']):
    december_consumption[house] = fill_na_december_consumption(december_consumption[10], december_consumption[house])

# %%
#calculate_rows()

# %% [markdown]
# #### Houses to be clustered

# %%
##print('Houses to be clustered: ')
clustered_df = calculate_rows()[calculate_rows()['Rows'] ==  576]
#clustered_df

# %% [markdown]
# #### Converting to clustering matrix

# %%
clustering_matrix = []
for house in calculate_rows()[calculate_rows()['Rows'] ==  576]['House']:
    clustering_matrix.append(np.array(december_consumption[house]['energy_kWh']).reshape(-1,1))
clustering_matrix = np.array(clustering_matrix)
clustering_matrix.shape
# Out:
# (27, 576, 1)

# %% [markdown]
# #### Time series clustering of all households except house 26

# %%
km_sdtw = TimeSeriesKMeans(n_clusters=4, metric="softdtw", max_iter=5,
                            max_iter_barycenter=5,
                            metric_params={"gamma": .5},
                            random_state=0).fit_predict(clustering_matrix)

# %%
len(km_sdtw)
# Out:
# 27

# %%
clustered_df['Cluster'] = km_sdtw

# %%
#clustered_df = clustered_df[['House', 'Cluster']].set_index('House')
clustered_df[clustered_df['Cluster'] == 3]
# Out:
#     House  Rows  Cluster
# 2       3   576        3
# 4       5   576        3
# 26     27   576        3

# %% [markdown]
# #### Used Scenarios

# %%
data = [[1, 4, 6, 'Yes'], [2, 1, 6, 'Yes'], [3, 4, 1, 'No'], [4, 1, 1, 'No']]
df = pd.DataFrame(data, columns = ['Scenarios', 'No. of subsets', 'No. of features', 'Smart devices included in modeling?']).set_index('Scenarios')
df
# Out:
#            No. of subsets  No. of features Smart devices included in modeling?
# Scenarios
# 1                       4                6                                 Yes
# 2                       1                6                                 Yes
# 3                       4                1                                  No
# 4                       1                1                                  No

# %% [markdown]
# #### Time-series LSTM-based predictive modeling

# %%
n_past = 14
n_future = 1

# %%
### Energy generation dataframe
generation_df = pd.read_csv('Final Datasets/energy_generation.csv')
generation_df
# Out:
#                  timestamp  Wind Energy  Solar Energy
# 0      2012-01-01 00:00:00     0.168265           0.0
# 1      2012-01-01 01:00:00     0.168265           0.0
# 2      2012-01-01 02:00:00     0.168265           0.0
# 3      2012-01-01 03:00:00     0.168265           0.0
# 4      2012-01-01 04:00:00     0.168265           0.0
# ...                    ...          ...           ...
# 78907  2020-12-31 19:00:00     1.710441           0.0
# 78908  2020-12-31 20:00:00     1.710441           0.0
# 78909  2020-12-31 21:00:00     1.497873           0.0
# 78910  2020-12-31 22:00:00     1.285454           0.0
# 78911  2020-12-31 23:00:00     1.286778           0.0
#
# [78912 rows x 3 columns]

# %%
class House:
    cols = ['energy_kWh', 'electronics workbench energy', 'network equipment energy',
            'home office energy', 'RAE home office energy', 'RAE Mobile Phone Charger Energy']
    def __init__(self, house):
        self.house = house
        self.consumption_df = house_wise_consumption[house].copy()[House.cols].astype(float)
        self.train_dates_df = house_wise_consumption[house]['timestamp']
        self.prepare_dataset(n_future, n_past)
    
    def __repr__(self):
        return str(self.house)
    
    def prepare_dataset(self, n_future = 1, n_past = 14):
        #Empty lists to be populated using formatted training data
        trainX = []
        trainY = []
        consumption_np = np.array(self.consumption_df)
        #Reformat input data into a shape: (n_samples x timesteps x n_features)
        #In my example, my self.consumption_df has a shape (12823, 5)
        #12823 refers to the number of data points and 5 refers to the columns (multi-variables).
        for i in range(n_past, len(consumption_np) - n_future +1):
            trainX.append(consumption_np[i - n_past:i, 0:self.consumption_df.shape[1]])
            trainY.append(consumption_np[i + n_future - 1:i + n_future, 0])

        trainX, trainY = np.array(trainX), np.array(trainY)

        #print('trainX shape == {}.'.format(trainX.shape))
        #print('trainY shape == {}.'.format(trainY.shape))
        self.trainX = trainX
        self.trainY = trainY

class Cluster: 
    def __init__(self, houses):
        self.houses = [House(house) for house in houses]
        self.trainX_list = (list(map(lambda x: x.trainX, self.houses)))
        self.trainY_list = (list(map(lambda x: x.trainY, self.houses)))
        self.train_dates_list = (list(map(lambda x: x.train_dates_df, self.houses)))
        self.consumption_df_list = (list(map(lambda x: x.consumption_df, self.houses)))
        self.prepare_dataset()
        
    
    def prepare_dataset(self):
        
        self.train_dates = np.concatenate(self.train_dates_list, axis=0)
        ## TODO - Replace concatenate with for loop or sort by time
        self.X = np.concatenate(self.trainX_list, axis=0)
        self.Y = np.concatenate(self.trainY_list, axis=0)
    
    
    def prepare_ANN_model(self):
        model = Sequential()
        #model.add(Dense(1, activation='relu', input_shape=(self.X.shape[1], self.X.shape[2])))
        model.add(Dense(128, activation='relu', input_shape=(self.X.shape[1], self.X.shape[2]), return_sequences=True))
        model.add(Dense(32, activation='relu', return_sequences=True))
        model.add(Dense(16, activation='relu', return_sequences=False))
        model.add(Dense(self.Y.shape[1]))
        model.compile(optimizer='adam', loss='mse', metrics=[tf.keras.metrics.RootMeanSquaredError(), tf.keras.metrics.MeanAbsoluteError()])
        model.summary()
        return model
    
    def prepare_RNN_model(self):
        model = Sequential()
        #model.add(SimpleRNN(1, activation='relu', input_shape=(self.X.shape[1], self.X.shape[2]), return_sequences=True))
        model.add(SimpleRNN(128, activation='relu', input_shape=(self.X.shape[1], self.X.shape[2]), return_sequences=True))
        model.add(SimpleRNN(32, activation='relu', return_sequences=True))
        model.add(SimpleRNN(16, activation='relu', return_sequences=False))
        model.add(Dense(self.Y.shape[1]))
        model.compile(optimizer='adam', loss='mse', metrics=[tf.keras.metrics.RootMeanSquaredError(), tf.keras.metrics.MeanAbsoluteError()])
        model.summary()
        return model
    
    def prepare_LSTM_model(self):
        model = Sequential()
        #model.add(LSTM(1, activation='relu', input_shape=(self.X.shape[1], self.X.shape[2]), return_sequences=True))
        model.add(LSTM(128, activation='relu', input_shape=(self.X.shape[1], self.X.shape[2]), return_sequences=True))
        model.add(LSTM(32, activation='relu', return_sequences=True))
        model.add(LSTM(16, activation='relu', return_sequences=False))
        model.add(Dense(self.Y.shape[1]))
        model.compile(optimizer='adam', loss='mse', metrics=[tf.keras.metrics.RootMeanSquaredError(), tf.keras.metrics.MeanAbsoluteError()])
        model.summary()
        return model
    
    def train_model(self, model_name='LSTM'):
        if model_name == 'LSTM':
            model = self.prepare_LSTM_model()
        if model_name == 'RNN':
            model = self.prepare_RNN_model()    
        if model_name == 'ANN':
            model = self.prepare_ANN_model()    
        history = model.fit(self.X, self.Y, epochs=30, batch_size=16, validation_split=0.3, verbose=1) # Change to 30
        self.history = history
        plt.plot(history.history['loss'], label='Training loss')
        plt.plot(history.history['val_loss'], label='Testing loss')
        
        plt.legend()
        return model
    
    def predicted(self, model_name='LSTM'):
        model = self.train_model(model_name)
        predictions = list(map(lambda x: pd.Series(model.predict(x).reshape(1,-1)[0]), self.trainX_list))
        #return pd.Series(model.predict(self.X).reshape(1,-1)[0])
        self.model = model
        return dict(zip(self.houses, predictions))
    
    def results(self, model_name='LSTM'):
        predicted = self.predicted(model_name)
        house_prediction_list_df  = {}
        for house in predicted:
            house_prediction_df = house.consumption_df.iloc[n_past:].copy().reset_index(drop=True)
            house_prediction_df['timestamp'] = house.train_dates_df.iloc[n_past:].copy().reset_index(drop=True)
            house_prediction_df['energy_predicted'] = predicted[house]
            ### Anomaly Detection
            energy_stddev = house_prediction_df['energy_kWh'].std()
            house_prediction_df['Energy Consumption Error'] = house_prediction_df['energy_predicted'] - house_prediction_df['energy_kWh']
            house_prediction_df['Anomaly detected'] = house_prediction_df['Energy Consumption Error'].apply(lambda x: False if abs(x) < 1.5*energy_stddev else abs(x))
            ### Energy Deficit Calculation
            house_prediction_df['timestamp'] = pd.DatetimeIndex(house_prediction_df['timestamp'])
            generation_df['timestamp'] = pd.DatetimeIndex(generation_df['timestamp'])
            house_prediction_df = house_prediction_df.set_index('timestamp').join(generation_df.set_index('timestamp'))
            house_prediction_df['timestamp'] = house_prediction_df.index
            house_prediction_df.reset_index(drop=True, inplace=True)
            house_prediction_df['Total Generated Energy'] = house_prediction_df['Wind Energy']+ house_prediction_df['Solar Energy']
            house_prediction_df['Predicted Energy Deficit'] = house_prediction_df['Total Generated Energy'] - house_prediction_df['energy_predicted']
            house_prediction_df['Energy Deficit Flag'] = house_prediction_df['Predicted Energy Deficit'].apply(lambda x: False if x>0 else abs(x))
            house_prediction_list_df[house.house] = house_prediction_df
        return house_prediction_list_df

# %% [markdown]
# ## Model Name

# %%
model_name='RNN'

# %% [markdown]
# #### Scenario 1

# %%
zero_houses = list(clustered_df[clustered_df['Cluster'] == 0]['House'])
zero_cluster = Cluster(zero_houses)
zero_cluster_results = zero_cluster.results(model_name)
print('Training History for Cluster 0:')
# Out:
# 2022-03-06 14:32:48.787104: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-03-06 14:32:48.787136: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-03-06 14:32:48.787157: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (rishabh-Inspiron): /proc/driver/nvidia/version does not exist
# 2022-03-06 14:32:48.787330: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 14, 128)           17280
#
#  simple_rnn_1 (SimpleRNN)    (None, 14, 32)            5152
#
#  simple_rnn_2 (SimpleRNN)    (None, 16)                784
#
#  dense (Dense)               (None, 1)                 17
#
# =================================================================
# Total params: 23,233
# Trainable params: 23,233
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 7680/7680 [==============================] - 86s 11ms/step - loss: 0.4673 - root_mean_squared_error: 0.6836 - mean_absolute_error: 0.4134 - val_loss: 0.6369 - val_root_mean_squared_error: 0.7981 - val_mean_absolute_error: 0.4508
# Epoch 2/30
# 7680/7680 [==============================] - 84s 11ms/step - loss: 0.4507 - root_mean_squared_error: 0.6713 - mean_absolute_error: 0.4014 - val_loss: 0.6094 - val_root_mean_squared_error: 0.7806 - val_mean_absolute_error: 0.4453
# Epoch 3/30
# 7680/7680 [==============================] - 84s 11ms/step - loss: 0.4456 - root_mean_squared_error: 0.6675 - mean_absolute_error: 0.3982 - val_loss: 0.6438 - val_root_mean_squared_error: 0.8023 - val_mean_absolute_error: 0.4570
# Epoch 4/30
# 7680/7680 [==============================] - 86s 11ms/step - loss: 0.4419 - root_mean_squared_error: 0.6647 - mean_absolute_error: 0.3963 - val_loss: 0.6251 - val_root_mean_squared_error: 0.7906 - val_mean_absolute_error: 0.4484
# Epoch 5/30
# 7680/7680 [==============================] - 86s 11ms/step - loss: 0.4395 - root_mean_squared_error: 0.6629 - mean_absolute_error: 0.3944 - val_loss: 0.6265 - val_root_mean_squared_error: 0.7915 - val_mean_absolute_error: 0.4514
# Epoch 6/30
# 7680/7680 [==============================] - 85s 11ms/step - loss: 0.4388 - root_mean_squared_error: 0.6625 - mean_absolute_error: 0.3934 - val_loss: 0.6270 - val_root_mean_squared_error: 0.7918 - val_mean_absolute_error: 0.4553
# Epoch 7/30
# 7680/7680 [==============================] - 87s 11ms/step - loss: 0.4369 - root_mean_squared_error: 0.6610 - mean_absolute_error: 0.3926 - val_loss: 0.6001 - val_root_mean_squared_error: 0.7746 - val_mean_absolute_error: 0.4597
# Epoch 8/30
# 7680/7680 [==============================] - 86s 11ms/step - loss: 0.4356 - root_mean_squared_error: 0.6600 - mean_absolute_error: 0.3916 - val_loss: 0.6282 - val_root_mean_squared_error: 0.7926 - val_mean_absolute_error: 0.4548
# Epoch 9/30
# 7680/7680 [==============================] - 85s 11ms/step - loss: 0.4343 - root_mean_squared_error: 0.6590 - mean_absolute_error: 0.3912 - val_loss: 0.6260 - val_root_mean_squared_error: 0.7912 - val_mean_absolute_error: 0.4617
# Epoch 10/30
# 7680/7680 [==============================] - 86s 11ms/step - loss: 0.4339 - root_mean_squared_error: 0.6587 - mean_absolute_error: 0.3912 - val_loss: 0.6343 - val_root_mean_squared_error: 0.7964 - val_mean_absolute_error: 0.4543
# Epoch 11/30
# 7680/7680 [==============================] - 86s 11ms/step - loss: 0.4333 - root_mean_squared_error: 0.6583 - mean_absolute_error: 0.3911 - val_loss: 0.6550 - val_root_mean_squared_error: 0.8093 - val_mean_absolute_error: 0.4574
# Epoch 12/30
# 7680/7680 [==============================] - 84s 11ms/step - loss: 0.4324 - root_mean_squared_error: 0.6576 - mean_absolute_error: 0.3910 - val_loss: 0.6792 - val_root_mean_squared_error: 0.8241 - val_mean_absolute_error: 0.4717
# Epoch 13/30
# 7680/7680 [==============================] - 86s 11ms/step - loss: 0.4313 - root_mean_squared_error: 0.6567 - mean_absolute_error: 0.3902 - val_loss: 0.5995 - val_root_mean_squared_error: 0.7742 - val_mean_absolute_error: 0.4586
# Epoch 14/30
# 7680/7680 [==============================] - 103s 13ms/step - loss: 0.4309 - root_mean_squared_error: 0.6565 - mean_absolute_error: 0.3892 - val_loss: 0.6303 - val_root_mean_squared_error: 0.7939 - val_mean_absolute_error: 0.4492
# Epoch 15/30
# 7680/7680 [==============================] - 98s 13ms/step - loss: 0.4313 - root_mean_squared_error: 0.6567 - mean_absolute_error: 0.3897 - val_loss: 0.6394 - val_root_mean_squared_error: 0.7996 - val_mean_absolute_error: 0.4586
# Epoch 16/30
# 7680/7680 [==============================] - 95s 12ms/step - loss: 0.4299 - root_mean_squared_error: 0.6557 - mean_absolute_error: 0.3895 - val_loss: 0.6175 - val_root_mean_squared_error: 0.7858 - val_mean_absolute_error: 0.4505
# Epoch 17/30
# 7680/7680 [==============================] - 111s 15ms/step - loss: 0.4300 - root_mean_squared_error: 0.6558 - mean_absolute_error: 0.3891 - val_loss: 0.6473 - val_root_mean_squared_error: 0.8045 - val_mean_absolute_error: 0.4613
# Epoch 18/30
# 7680/7680 [==============================] - 102s 13ms/step - loss: 0.4289 - root_mean_squared_error: 0.6549 - mean_absolute_error: 0.3887 - val_loss: 0.6066 - val_root_mean_squared_error: 0.7789 - val_mean_absolute_error: 0.4453
# Epoch 19/30
# 7680/7680 [==============================] - 86s 11ms/step - loss: 0.4290 - root_mean_squared_error: 0.6550 - mean_absolute_error: 0.3889 - val_loss: 0.5957 - val_root_mean_squared_error: 0.7718 - val_mean_absolute_error: 0.4504
# Epoch 20/30
# 7680/7680 [==============================] - 81s 11ms/step - loss: 0.4282 - root_mean_squared_error: 0.6544 - mean_absolute_error: 0.3877 - val_loss: 0.6223 - val_root_mean_squared_error: 0.7889 - val_mean_absolute_error: 0.4536
# Epoch 21/30
# 7680/7680 [==============================] - 73s 10ms/step - loss: 0.4273 - root_mean_squared_error: 0.6537 - mean_absolute_error: 0.3880 - val_loss: 0.6125 - val_root_mean_squared_error: 0.7826 - val_mean_absolute_error: 0.4499
# Epoch 22/30
# 7680/7680 [==============================] - 79s 10ms/step - loss: 0.4271 - root_mean_squared_error: 0.6535 - mean_absolute_error: 0.3881 - val_loss: 0.5996 - val_root_mean_squared_error: 0.7743 - val_mean_absolute_error: 0.4514
# Epoch 23/30
# 7680/7680 [==============================] - 74s 10ms/step - loss: 0.4268 - root_mean_squared_error: 0.6533 - mean_absolute_error: 0.3879 - val_loss: 0.6187 - val_root_mean_squared_error: 0.7866 - val_mean_absolute_error: 0.4463
# Epoch 24/30
# 7680/7680 [==============================] - 82s 11ms/step - loss: 0.4270 - root_mean_squared_error: 0.6534 - mean_absolute_error: 0.3880 - val_loss: 0.6261 - val_root_mean_squared_error: 0.7912 - val_mean_absolute_error: 0.4508
# Epoch 25/30
# 7680/7680 [==============================] - 71s 9ms/step - loss: 0.4264 - root_mean_squared_error: 0.6530 - mean_absolute_error: 0.3881 - val_loss: 0.6284 - val_root_mean_squared_error: 0.7927 - val_mean_absolute_error: 0.4526
# Epoch 26/30
# 7680/7680 [==============================] - 62s 8ms/step - loss: 0.4264 - root_mean_squared_error: 0.6530 - mean_absolute_error: 0.3879 - val_loss: 0.6438 - val_root_mean_squared_error: 0.8024 - val_mean_absolute_error: 0.4622
# Epoch 27/30
# 7680/7680 [==============================] - 62s 8ms/step - loss: 0.4271 - root_mean_squared_error: 0.6535 - mean_absolute_error: 0.3883 - val_loss: 0.6458 - val_root_mean_squared_error: 0.8036 - val_mean_absolute_error: 0.4496
# Epoch 28/30
# 7680/7680 [==============================] - 62s 8ms/step - loss: 0.4253 - root_mean_squared_error: 0.6521 - mean_absolute_error: 0.3873 - val_loss: 0.6416 - val_root_mean_squared_error: 0.8010 - val_mean_absolute_error: 0.4575
# Epoch 29/30
# 7680/7680 [==============================] - 62s 8ms/step - loss: 0.4243 - root_mean_squared_error: 0.6514 - mean_absolute_error: 0.3871 - val_loss: 0.6494 - val_root_mean_squared_error: 0.8058 - val_mean_absolute_error: 0.4586
# Epoch 30/30
# 7680/7680 [==============================] - 62s 8ms/step - loss: 0.4246 - root_mean_squared_error: 0.6516 - mean_absolute_error: 0.3868 - val_loss: 0.6101 - val_root_mean_squared_error: 0.7811 - val_mean_absolute_error: 0.4509
# Training History for Cluster 0:

# %%
one_houses = list(clustered_df[clustered_df['Cluster'] == 1]['House'])
one_cluster = Cluster(one_houses)
one_cluster_results = one_cluster.results(model_name)
print('Training History for Cluster 1:')
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_3 (SimpleRNN)    (None, 14, 128)           17280
#
#  simple_rnn_4 (SimpleRNN)    (None, 14, 32)            5152
#
#  simple_rnn_5 (SimpleRNN)    (None, 16)                784
#
#  dense_1 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 23,233
# Trainable params: 23,233
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 915/915 [==============================] - 9s 8ms/step - loss: 0.9908 - root_mean_squared_error: 0.9954 - mean_absolute_error: 0.5539 - val_loss: 1.5251 - val_root_mean_squared_error: 1.2350 - val_mean_absolute_error: 0.7037
# Epoch 2/30
# 915/915 [==============================] - 7s 8ms/step - loss: 0.8850 - root_mean_squared_error: 0.9407 - mean_absolute_error: 0.5355 - val_loss: 1.2847 - val_root_mean_squared_error: 1.1335 - val_mean_absolute_error: 0.5685
# Epoch 3/30
# 915/915 [==============================] - 7s 8ms/step - loss: 0.8539 - root_mean_squared_error: 0.9241 - mean_absolute_error: 0.5227 - val_loss: 1.2479 - val_root_mean_squared_error: 1.1171 - val_mean_absolute_error: 0.5904
# Epoch 4/30
# 915/915 [==============================] - 7s 8ms/step - loss: 0.8396 - root_mean_squared_error: 0.9163 - mean_absolute_error: 0.5218 - val_loss: 1.2426 - val_root_mean_squared_error: 1.1147 - val_mean_absolute_error: 0.5909
# Epoch 5/30
# 915/915 [==============================] - 7s 8ms/step - loss: 0.8351 - root_mean_squared_error: 0.9138 - mean_absolute_error: 0.5113 - val_loss: 1.3717 - val_root_mean_squared_error: 1.1712 - val_mean_absolute_error: 0.6010
# Epoch 6/30
# 915/915 [==============================] - 7s 8ms/step - loss: 0.7975 - root_mean_squared_error: 0.8930 - mean_absolute_error: 0.5036 - val_loss: 1.2053 - val_root_mean_squared_error: 1.0979 - val_mean_absolute_error: 0.5582
# Epoch 7/30
# 915/915 [==============================] - 7s 8ms/step - loss: 0.7840 - root_mean_squared_error: 0.8854 - mean_absolute_error: 0.4991 - val_loss: 1.1275 - val_root_mean_squared_error: 1.0618 - val_mean_absolute_error: 0.5570
# Epoch 8/30
# 915/915 [==============================] - 7s 8ms/step - loss: 0.7770 - root_mean_squared_error: 0.8815 - mean_absolute_error: 0.4972 - val_loss: 1.1278 - val_root_mean_squared_error: 1.0620 - val_mean_absolute_error: 0.5279
# Epoch 9/30
# 915/915 [==============================] - 7s 8ms/step - loss: 0.7622 - root_mean_squared_error: 0.8731 - mean_absolute_error: 0.4941 - val_loss: 1.2777 - val_root_mean_squared_error: 1.1304 - val_mean_absolute_error: 0.5694
# Epoch 10/30
# 915/915 [==============================] - 7s 8ms/step - loss: 0.7727 - root_mean_squared_error: 0.8790 - mean_absolute_error: 0.4958 - val_loss: 1.1479 - val_root_mean_squared_error: 1.0714 - val_mean_absolute_error: 0.5347
# Epoch 11/30
# 915/915 [==============================] - 7s 8ms/step - loss: 0.7411 - root_mean_squared_error: 0.8609 - mean_absolute_error: 0.4904 - val_loss: 1.1215 - val_root_mean_squared_error: 1.0590 - val_mean_absolute_error: 0.5190
# Epoch 12/30
# 915/915 [==============================] - 7s 8ms/step - loss: 0.7306 - root_mean_squared_error: 0.8548 - mean_absolute_error: 0.4838 - val_loss: 1.0965 - val_root_mean_squared_error: 1.0471 - val_mean_absolute_error: 0.5669
# Epoch 13/30
# 915/915 [==============================] - 7s 8ms/step - loss: 0.7087 - root_mean_squared_error: 0.8418 - mean_absolute_error: 0.4819 - val_loss: 1.1938 - val_root_mean_squared_error: 1.0926 - val_mean_absolute_error: 0.5333
# Epoch 14/30
# 915/915 [==============================] - 7s 8ms/step - loss: 0.7280 - root_mean_squared_error: 0.8532 - mean_absolute_error: 0.4862 - val_loss: 1.2155 - val_root_mean_squared_error: 1.1025 - val_mean_absolute_error: 0.5638
# Epoch 15/30
# 915/915 [==============================] - 7s 8ms/step - loss: 0.7225 - root_mean_squared_error: 0.8500 - mean_absolute_error: 0.4803 - val_loss: 1.1137 - val_root_mean_squared_error: 1.0553 - val_mean_absolute_error: 0.5328
# Epoch 16/30
# 915/915 [==============================] - 7s 8ms/step - loss: 0.7253 - root_mean_squared_error: 0.8517 - mean_absolute_error: 0.4843 - val_loss: 1.1493 - val_root_mean_squared_error: 1.0721 - val_mean_absolute_error: 0.5659
# Epoch 17/30
# 915/915 [==============================] - 7s 8ms/step - loss: 0.7242 - root_mean_squared_error: 0.8510 - mean_absolute_error: 0.4864 - val_loss: 1.1358 - val_root_mean_squared_error: 1.0658 - val_mean_absolute_error: 0.5215
# Epoch 18/30
# 915/915 [==============================] - 7s 8ms/step - loss: 0.7064 - root_mean_squared_error: 0.8405 - mean_absolute_error: 0.4804 - val_loss: 1.1220 - val_root_mean_squared_error: 1.0592 - val_mean_absolute_error: 0.5820
# Epoch 19/30
# 915/915 [==============================] - 7s 8ms/step - loss: 0.6934 - root_mean_squared_error: 0.8327 - mean_absolute_error: 0.4740 - val_loss: 1.2540 - val_root_mean_squared_error: 1.1198 - val_mean_absolute_error: 0.5711
# Epoch 20/30
# 915/915 [==============================] - 7s 8ms/step - loss: 0.7107 - root_mean_squared_error: 0.8430 - mean_absolute_error: 0.4791 - val_loss: 1.2003 - val_root_mean_squared_error: 1.0956 - val_mean_absolute_error: 0.5640
# Epoch 21/30
# 915/915 [==============================] - 7s 8ms/step - loss: 0.7013 - root_mean_squared_error: 0.8374 - mean_absolute_error: 0.4765 - val_loss: 1.1008 - val_root_mean_squared_error: 1.0492 - val_mean_absolute_error: 0.5577
# Epoch 22/30
# 915/915 [==============================] - 7s 8ms/step - loss: 0.6677 - root_mean_squared_error: 0.8171 - mean_absolute_error: 0.4709 - val_loss: 1.0584 - val_root_mean_squared_error: 1.0288 - val_mean_absolute_error: 0.4984
# Epoch 23/30
# 915/915 [==============================] - 7s 8ms/step - loss: 0.6641 - root_mean_squared_error: 0.8149 - mean_absolute_error: 0.4668 - val_loss: 1.1220 - val_root_mean_squared_error: 1.0592 - val_mean_absolute_error: 0.5291
# Epoch 24/30
# 915/915 [==============================] - 7s 8ms/step - loss: 0.6932 - root_mean_squared_error: 0.8326 - mean_absolute_error: 0.4749 - val_loss: 1.0505 - val_root_mean_squared_error: 1.0250 - val_mean_absolute_error: 0.5188
# Epoch 25/30
# 915/915 [==============================] - 7s 8ms/step - loss: 0.6771 - root_mean_squared_error: 0.8228 - mean_absolute_error: 0.4668 - val_loss: 1.0754 - val_root_mean_squared_error: 1.0370 - val_mean_absolute_error: 0.5122
# Epoch 26/30
# 915/915 [==============================] - 7s 8ms/step - loss: 0.6772 - root_mean_squared_error: 0.8229 - mean_absolute_error: 0.4702 - val_loss: 1.1292 - val_root_mean_squared_error: 1.0626 - val_mean_absolute_error: 0.5163
# Epoch 27/30
# 915/915 [==============================] - 7s 8ms/step - loss: 0.6587 - root_mean_squared_error: 0.8116 - mean_absolute_error: 0.4673 - val_loss: 1.1063 - val_root_mean_squared_error: 1.0518 - val_mean_absolute_error: 0.5089
# Epoch 28/30
# 915/915 [==============================] - 7s 8ms/step - loss: 0.6485 - root_mean_squared_error: 0.8053 - mean_absolute_error: 0.4638 - val_loss: 1.1895 - val_root_mean_squared_error: 1.0906 - val_mean_absolute_error: 0.5638
# Epoch 29/30
# 915/915 [==============================] - 7s 8ms/step - loss: 0.6538 - root_mean_squared_error: 0.8086 - mean_absolute_error: 0.4660 - val_loss: 1.1290 - val_root_mean_squared_error: 1.0625 - val_mean_absolute_error: 0.5020
# Epoch 30/30
# 915/915 [==============================] - 7s 8ms/step - loss: 0.6971 - root_mean_squared_error: 0.8349 - mean_absolute_error: 0.4755 - val_loss: 1.0733 - val_root_mean_squared_error: 1.0360 - val_mean_absolute_error: 0.5580
# Training History for Cluster 1:

# %%
two_houses = list(clustered_df[clustered_df['Cluster'] == 2]['House'])
two_cluster = Cluster(two_houses)
two_cluster_results = two_cluster.results(model_name)
print('Training History for Cluster 2:')
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_6 (SimpleRNN)    (None, 14, 128)           17280
#
#  simple_rnn_7 (SimpleRNN)    (None, 14, 32)            5152
#
#  simple_rnn_8 (SimpleRNN)    (None, 16)                784
#
#  dense_2 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 23,233
# Trainable params: 23,233
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 15194/15194 [==============================] - 124s 8ms/step - loss: 0.1486 - root_mean_squared_error: 0.3854 - mean_absolute_error: 0.2147 - val_loss: 0.2087 - val_root_mean_squared_error: 0.4568 - val_mean_absolute_error: 0.2456
# Epoch 2/30
# 15194/15194 [==============================] - 129s 8ms/step - loss: 0.1458 - root_mean_squared_error: 0.3818 - mean_absolute_error: 0.2108 - val_loss: 0.2069 - val_root_mean_squared_error: 0.4549 - val_mean_absolute_error: 0.2482
# Epoch 3/30
# 15194/15194 [==============================] - 150s 10ms/step - loss: 0.1452 - root_mean_squared_error: 0.3810 - mean_absolute_error: 0.2102 - val_loss: 0.2092 - val_root_mean_squared_error: 0.4574 - val_mean_absolute_error: 0.2489
# Epoch 4/30
# 15194/15194 [==============================] - 125s 8ms/step - loss: 0.1447 - root_mean_squared_error: 0.3804 - mean_absolute_error: 0.2096 - val_loss: 0.2058 - val_root_mean_squared_error: 0.4537 - val_mean_absolute_error: 0.2491
# Epoch 5/30
# 15194/15194 [==============================] - 129s 9ms/step - loss: 0.1444 - root_mean_squared_error: 0.3801 - mean_absolute_error: 0.2093 - val_loss: 0.2053 - val_root_mean_squared_error: 0.4531 - val_mean_absolute_error: 0.2506
# Epoch 6/30
# 15194/15194 [==============================] - 148s 10ms/step - loss: 0.1442 - root_mean_squared_error: 0.3798 - mean_absolute_error: 0.2088 - val_loss: 0.2058 - val_root_mean_squared_error: 0.4537 - val_mean_absolute_error: 0.2546
# Epoch 7/30
# 15194/15194 [==============================] - 144s 9ms/step - loss: 0.1440 - root_mean_squared_error: 0.3795 - mean_absolute_error: 0.2088 - val_loss: 0.2051 - val_root_mean_squared_error: 0.4529 - val_mean_absolute_error: 0.2553
# Epoch 8/30
# 15194/15194 [==============================] - 152s 10ms/step - loss: 0.1440 - root_mean_squared_error: 0.3794 - mean_absolute_error: 0.2086 - val_loss: 0.2070 - val_root_mean_squared_error: 0.4550 - val_mean_absolute_error: 0.2437
# Epoch 9/30
# 15194/15194 [==============================] - 154s 10ms/step - loss: 0.1437 - root_mean_squared_error: 0.3791 - mean_absolute_error: 0.2084 - val_loss: 0.2064 - val_root_mean_squared_error: 0.4543 - val_mean_absolute_error: 0.2506
# Epoch 10/30
# 15194/15194 [==============================] - 132s 9ms/step - loss: 0.1438 - root_mean_squared_error: 0.3792 - mean_absolute_error: 0.2085 - val_loss: 0.2073 - val_root_mean_squared_error: 0.4553 - val_mean_absolute_error: 0.2458
# Epoch 11/30
# 15194/15194 [==============================] - 126s 8ms/step - loss: 0.1435 - root_mean_squared_error: 0.3787 - mean_absolute_error: 0.2080 - val_loss: 0.2053 - val_root_mean_squared_error: 0.4531 - val_mean_absolute_error: 0.2509
# Epoch 12/30
# 15194/15194 [==============================] - 126s 8ms/step - loss: 0.1435 - root_mean_squared_error: 0.3787 - mean_absolute_error: 0.2080 - val_loss: 0.2059 - val_root_mean_squared_error: 0.4538 - val_mean_absolute_error: 0.2502
# Epoch 13/30
# 15194/15194 [==============================] - 126s 8ms/step - loss: 0.1433 - root_mean_squared_error: 0.3785 - mean_absolute_error: 0.2080 - val_loss: 0.2055 - val_root_mean_squared_error: 0.4533 - val_mean_absolute_error: 0.2481
# Epoch 14/30
# 15194/15194 [==============================] - 130s 9ms/step - loss: 0.1433 - root_mean_squared_error: 0.3785 - mean_absolute_error: 0.2078 - val_loss: 0.2081 - val_root_mean_squared_error: 0.4562 - val_mean_absolute_error: 0.2465
# Epoch 15/30
# 15194/15194 [==============================] - 141s 9ms/step - loss: 0.1433 - root_mean_squared_error: 0.3785 - mean_absolute_error: 0.2077 - val_loss: 0.2057 - val_root_mean_squared_error: 0.4535 - val_mean_absolute_error: 0.2548
# Epoch 16/30
# 15194/15194 [==============================] - 149s 10ms/step - loss: 0.1432 - root_mean_squared_error: 0.3785 - mean_absolute_error: 0.2078 - val_loss: 0.2058 - val_root_mean_squared_error: 0.4536 - val_mean_absolute_error: 0.2510
# Epoch 17/30
# 15194/15194 [==============================] - 127s 8ms/step - loss: 0.1432 - root_mean_squared_error: 0.3785 - mean_absolute_error: 0.2079 - val_loss: 0.2055 - val_root_mean_squared_error: 0.4533 - val_mean_absolute_error: 0.2488
# Epoch 18/30
# 15194/15194 [==============================] - 127s 8ms/step - loss: 0.1433 - root_mean_squared_error: 0.3786 - mean_absolute_error: 0.2079 - val_loss: 0.2080 - val_root_mean_squared_error: 0.4561 - val_mean_absolute_error: 0.2541
# Epoch 19/30
# 15194/15194 [==============================] - 127s 8ms/step - loss: 0.1431 - root_mean_squared_error: 0.3783 - mean_absolute_error: 0.2076 - val_loss: 0.2074 - val_root_mean_squared_error: 0.4554 - val_mean_absolute_error: 0.2533
# Epoch 20/30
# 15194/15194 [==============================] - 127s 8ms/step - loss: 0.1433 - root_mean_squared_error: 0.3785 - mean_absolute_error: 0.2077 - val_loss: 0.2085 - val_root_mean_squared_error: 0.4567 - val_mean_absolute_error: 0.2481
# Epoch 21/30
# 15194/15194 [==============================] - 127s 8ms/step - loss: 0.1429 - root_mean_squared_error: 0.3780 - mean_absolute_error: 0.2076 - val_loss: 0.2065 - val_root_mean_squared_error: 0.4544 - val_mean_absolute_error: 0.2576
# Epoch 22/30
# 15194/15194 [==============================] - 127s 8ms/step - loss: 0.1430 - root_mean_squared_error: 0.3782 - mean_absolute_error: 0.2075 - val_loss: 0.2075 - val_root_mean_squared_error: 0.4555 - val_mean_absolute_error: 0.2594
# Epoch 23/30
# 15194/15194 [==============================] - 127s 8ms/step - loss: 0.1431 - root_mean_squared_error: 0.3783 - mean_absolute_error: 0.2078 - val_loss: 0.2078 - val_root_mean_squared_error: 0.4558 - val_mean_absolute_error: 0.2565
# Epoch 24/30
# 15194/15194 [==============================] - 127s 8ms/step - loss: 0.1433 - root_mean_squared_error: 0.3786 - mean_absolute_error: 0.2080 - val_loss: 0.2048 - val_root_mean_squared_error: 0.4526 - val_mean_absolute_error: 0.2505
# Epoch 25/30
# 15194/15194 [==============================] - 127s 8ms/step - loss: 0.1433 - root_mean_squared_error: 0.3786 - mean_absolute_error: 0.2078 - val_loss: 0.2073 - val_root_mean_squared_error: 0.4553 - val_mean_absolute_error: 0.2467
# Epoch 26/30
# 15194/15194 [==============================] - 128s 8ms/step - loss: 0.1432 - root_mean_squared_error: 0.3785 - mean_absolute_error: 0.2080 - val_loss: 0.2070 - val_root_mean_squared_error: 0.4550 - val_mean_absolute_error: 0.2536
# Epoch 27/30
# 15194/15194 [==============================] - 128s 8ms/step - loss: 0.1428 - root_mean_squared_error: 0.3779 - mean_absolute_error: 0.2076 - val_loss: 0.2078 - val_root_mean_squared_error: 0.4558 - val_mean_absolute_error: 0.2470
# Epoch 28/30
# 15194/15194 [==============================] - 128s 8ms/step - loss: 0.1429 - root_mean_squared_error: 0.3780 - mean_absolute_error: 0.2074 - val_loss: 0.2083 - val_root_mean_squared_error: 0.4564 - val_mean_absolute_error: 0.2463
# Epoch 29/30
# 15194/15194 [==============================] - 128s 8ms/step - loss: 0.1429 - root_mean_squared_error: 0.3780 - mean_absolute_error: 0.2074 - val_loss: 0.2061 - val_root_mean_squared_error: 0.4540 - val_mean_absolute_error: 0.2488
# Epoch 30/30
# 15194/15194 [==============================] - 128s 8ms/step - loss: 0.1429 - root_mean_squared_error: 0.3780 - mean_absolute_error: 0.2076 - val_loss: 0.2071 - val_root_mean_squared_error: 0.4551 - val_mean_absolute_error: 0.2508
# Training History for Cluster 2:

# %%
three_houses = list(clustered_df[clustered_df['Cluster'] == 3]['House'])
three_cluster = Cluster(three_houses)
three_cluster_results = three_cluster.results(model_name)
print('Training History for Cluster 3:')
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_9 (SimpleRNN)    (None, 14, 128)           17280
#
#  simple_rnn_10 (SimpleRNN)   (None, 14, 32)            5152
#
#  simple_rnn_11 (SimpleRNN)   (None, 16)                784
#
#  dense_3 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 23,233
# Trainable params: 23,233
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 2745/2745 [==============================] - 24s 8ms/step - loss: 0.3696 - root_mean_squared_error: 0.6080 - mean_absolute_error: 0.3841 - val_loss: 0.3996 - val_root_mean_squared_error: 0.6322 - val_mean_absolute_error: 0.3687
# Epoch 2/30
# 2745/2745 [==============================] - 22s 8ms/step - loss: 0.3490 - root_mean_squared_error: 0.5907 - mean_absolute_error: 0.3703 - val_loss: 0.4048 - val_root_mean_squared_error: 0.6362 - val_mean_absolute_error: 0.3761
# Epoch 3/30
# 2745/2745 [==============================] - 22s 8ms/step - loss: 0.3383 - root_mean_squared_error: 0.5817 - mean_absolute_error: 0.3624 - val_loss: 0.3971 - val_root_mean_squared_error: 0.6301 - val_mean_absolute_error: 0.3942
# Epoch 4/30
# 2745/2745 [==============================] - 22s 8ms/step - loss: 0.3331 - root_mean_squared_error: 0.5772 - mean_absolute_error: 0.3572 - val_loss: 0.4180 - val_root_mean_squared_error: 0.6465 - val_mean_absolute_error: 0.3896
# Epoch 5/30
# 2745/2745 [==============================] - 22s 8ms/step - loss: 0.3294 - root_mean_squared_error: 0.5739 - mean_absolute_error: 0.3528 - val_loss: 0.4121 - val_root_mean_squared_error: 0.6420 - val_mean_absolute_error: 0.4268
# Epoch 6/30
# 2745/2745 [==============================] - 23s 8ms/step - loss: 0.3265 - root_mean_squared_error: 0.5714 - mean_absolute_error: 0.3517 - val_loss: 0.4053 - val_root_mean_squared_error: 0.6366 - val_mean_absolute_error: 0.3959
# Epoch 7/30
# 2745/2745 [==============================] - 22s 8ms/step - loss: 0.3239 - root_mean_squared_error: 0.5691 - mean_absolute_error: 0.3498 - val_loss: 0.4085 - val_root_mean_squared_error: 0.6392 - val_mean_absolute_error: 0.3797
# Epoch 8/30
# 2745/2745 [==============================] - 22s 8ms/step - loss: 0.3218 - root_mean_squared_error: 0.5673 - mean_absolute_error: 0.3475 - val_loss: 0.3956 - val_root_mean_squared_error: 0.6290 - val_mean_absolute_error: 0.3723
# Epoch 9/30
# 2745/2745 [==============================] - 22s 8ms/step - loss: 0.3198 - root_mean_squared_error: 0.5655 - mean_absolute_error: 0.3464 - val_loss: 0.3854 - val_root_mean_squared_error: 0.6208 - val_mean_absolute_error: 0.3777
# Epoch 10/30
# 2745/2745 [==============================] - 23s 8ms/step - loss: 0.3182 - root_mean_squared_error: 0.5641 - mean_absolute_error: 0.3447 - val_loss: 0.4079 - val_root_mean_squared_error: 0.6387 - val_mean_absolute_error: 0.4042
# Epoch 11/30
# 2745/2745 [==============================] - 22s 8ms/step - loss: 0.3173 - root_mean_squared_error: 0.5633 - mean_absolute_error: 0.3442 - val_loss: 0.3904 - val_root_mean_squared_error: 0.6248 - val_mean_absolute_error: 0.3987
# Epoch 12/30
# 2745/2745 [==============================] - 22s 8ms/step - loss: 0.3156 - root_mean_squared_error: 0.5618 - mean_absolute_error: 0.3432 - val_loss: 0.4089 - val_root_mean_squared_error: 0.6395 - val_mean_absolute_error: 0.3896
# Epoch 13/30
# 2745/2745 [==============================] - 22s 8ms/step - loss: 0.3145 - root_mean_squared_error: 0.5608 - mean_absolute_error: 0.3422 - val_loss: 0.4105 - val_root_mean_squared_error: 0.6407 - val_mean_absolute_error: 0.3868
# Epoch 14/30
# 2745/2745 [==============================] - 22s 8ms/step - loss: 0.3144 - root_mean_squared_error: 0.5607 - mean_absolute_error: 0.3424 - val_loss: 0.3837 - val_root_mean_squared_error: 0.6195 - val_mean_absolute_error: 0.3735
# Epoch 15/30
# 2745/2745 [==============================] - 22s 8ms/step - loss: 0.3120 - root_mean_squared_error: 0.5586 - mean_absolute_error: 0.3401 - val_loss: 0.4018 - val_root_mean_squared_error: 0.6339 - val_mean_absolute_error: 0.3679
# Epoch 16/30
# 2745/2745 [==============================] - 22s 8ms/step - loss: 0.3106 - root_mean_squared_error: 0.5574 - mean_absolute_error: 0.3400 - val_loss: 0.3960 - val_root_mean_squared_error: 0.6293 - val_mean_absolute_error: 0.3945
# Epoch 17/30
# 2745/2745 [==============================] - 22s 8ms/step - loss: 0.3094 - root_mean_squared_error: 0.5563 - mean_absolute_error: 0.3393 - val_loss: 0.4083 - val_root_mean_squared_error: 0.6389 - val_mean_absolute_error: 0.3911
# Epoch 18/30
# 2745/2745 [==============================] - 22s 8ms/step - loss: 0.3096 - root_mean_squared_error: 0.5564 - mean_absolute_error: 0.3393 - val_loss: 0.3927 - val_root_mean_squared_error: 0.6267 - val_mean_absolute_error: 0.3712
# Epoch 19/30
# 2745/2745 [==============================] - 22s 8ms/step - loss: 0.3063 - root_mean_squared_error: 0.5534 - mean_absolute_error: 0.3370 - val_loss: 0.4055 - val_root_mean_squared_error: 0.6368 - val_mean_absolute_error: 0.3928
# Epoch 20/30
# 2745/2745 [==============================] - 22s 8ms/step - loss: 0.3068 - root_mean_squared_error: 0.5539 - mean_absolute_error: 0.3374 - val_loss: 0.4024 - val_root_mean_squared_error: 0.6344 - val_mean_absolute_error: 0.3846
# Epoch 21/30
# 2745/2745 [==============================] - 22s 8ms/step - loss: 0.3066 - root_mean_squared_error: 0.5537 - mean_absolute_error: 0.3381 - val_loss: 0.4106 - val_root_mean_squared_error: 0.6408 - val_mean_absolute_error: 0.4056
# Epoch 22/30
# 2745/2745 [==============================] - 22s 8ms/step - loss: 0.3050 - root_mean_squared_error: 0.5523 - mean_absolute_error: 0.3362 - val_loss: 0.4107 - val_root_mean_squared_error: 0.6409 - val_mean_absolute_error: 0.3985
# Epoch 23/30
# 2745/2745 [==============================] - 22s 8ms/step - loss: 0.3048 - root_mean_squared_error: 0.5521 - mean_absolute_error: 0.3365 - val_loss: 0.3940 - val_root_mean_squared_error: 0.6277 - val_mean_absolute_error: 0.3771
# Epoch 24/30
# 2745/2745 [==============================] - 22s 8ms/step - loss: 0.3051 - root_mean_squared_error: 0.5524 - mean_absolute_error: 0.3371 - val_loss: 0.3907 - val_root_mean_squared_error: 0.6251 - val_mean_absolute_error: 0.3791
# Epoch 25/30
# 2745/2745 [==============================] - 22s 8ms/step - loss: 0.3037 - root_mean_squared_error: 0.5511 - mean_absolute_error: 0.3357 - val_loss: 0.3831 - val_root_mean_squared_error: 0.6189 - val_mean_absolute_error: 0.3644
# Epoch 26/30
# 2745/2745 [==============================] - 22s 8ms/step - loss: 0.3027 - root_mean_squared_error: 0.5502 - mean_absolute_error: 0.3346 - val_loss: 0.4037 - val_root_mean_squared_error: 0.6354 - val_mean_absolute_error: 0.3739
# Epoch 27/30
# 2745/2745 [==============================] - 22s 8ms/step - loss: 0.3015 - root_mean_squared_error: 0.5491 - mean_absolute_error: 0.3349 - val_loss: 0.4039 - val_root_mean_squared_error: 0.6355 - val_mean_absolute_error: 0.3720
# Epoch 28/30
# 2745/2745 [==============================] - 22s 8ms/step - loss: 0.3022 - root_mean_squared_error: 0.5497 - mean_absolute_error: 0.3351 - val_loss: 0.4072 - val_root_mean_squared_error: 0.6381 - val_mean_absolute_error: 0.3877
# Epoch 29/30
# 2745/2745 [==============================] - 22s 8ms/step - loss: 0.3016 - root_mean_squared_error: 0.5492 - mean_absolute_error: 0.3348 - val_loss: 0.4059 - val_root_mean_squared_error: 0.6371 - val_mean_absolute_error: 0.3941
# Epoch 30/30
# 2745/2745 [==============================] - 22s 8ms/step - loss: 0.3028 - root_mean_squared_error: 0.5503 - mean_absolute_error: 0.3346 - val_loss: 0.4358 - val_root_mean_squared_error: 0.6602 - val_mean_absolute_error: 0.3851
# Training History for Cluster 3:

# %%
## Save Scenario 1 models
zero_cluster.model.save(f'Models/Scenario1/{model_name}/zero_cluster')
one_cluster.model.save(f'Models/Scenario1/{model_name}/one_cluster')
two_cluster.model.save(f'Models/Scenario1/{model_name}/two_cluster')
three_cluster.model.save(f'Models/Scenario1/{model_name}/three_cluster')

## Pickling cluster and cluster results
zero_cluster_file = open(f"Models/Scenario1/Objects/{model_name}/zero_cluster.pickle", "wb")
pickle.dump(zero_cluster, zero_cluster_file)
zero_cluster_file.close()

one_cluster_file = open(f"Models/Scenario1/Objects/{model_name}/one_cluster.pickle", "wb")
pickle.dump(one_cluster, one_cluster_file)
one_cluster_file.close()

two_cluster_file = open(f"Models/Scenario1/Objects/{model_name}/two_cluster.pickle", "wb")
pickle.dump(two_cluster, two_cluster_file)
two_cluster_file.close()

three_cluster_file = open(f"Models/Scenario1/Objects/{model_name}/three_cluster.pickle", "wb")
pickle.dump(three_cluster, three_cluster_file)
three_cluster_file.close()

zero_cluster_results_file = open(f"Models/Scenario1/Objects/{model_name}/zero_cluster_results.pickle", "wb")
pickle.dump(zero_cluster_results, zero_cluster_results_file)
zero_cluster_results_file.close()

one_cluster_results_file = open(f"Models/Scenario1/Objects/{model_name}/one_cluster_results.pickle", "wb")
pickle.dump(one_cluster_results, one_cluster_results_file)
one_cluster_results_file.close()

two_cluster_results_file = open(f"Models/Scenario1/Objects/{model_name}/two_cluster_results.pickle", "wb")
pickle.dump(two_cluster_results, two_cluster_results_file)
two_cluster_results_file.close()

three_cluster_results_file = open(f"Models/Scenario1/Objects/{model_name}/three_cluster_results.pickle", "wb")
pickle.dump(three_cluster_results, three_cluster_results_file)
three_cluster_results_file.close()
# Out:
# 2022-03-06 16:36:06.429069: W tensorflow/python/util/util.cc:368] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# INFO:tensorflow:Assets written to: Models/Scenario1/RNN/zero_cluster/assets
# INFO:tensorflow:Assets written to: Models/Scenario1/RNN/one_cluster/assets
# INFO:tensorflow:Assets written to: Models/Scenario1/RNN/two_cluster/assets
# INFO:tensorflow:Assets written to: Models/Scenario1/RNN/three_cluster/assets
# INFO:tensorflow:Assets written to: ram://ee1f6d09-2fb3-42b4-93e6-c06bc39ca5e1/assets
# INFO:tensorflow:Assets written to: ram://e58802f7-17ce-48e3-9ecf-c9f326f9dd26/assets
# INFO:tensorflow:Assets written to: ram://4842134e-963d-4918-b767-628150dbbaa7/assets
# INFO:tensorflow:Assets written to: ram://6663ae79-30be-44e0-ab0c-bd6fd7b62dd1/assets

# %% [markdown]
# #### Scenario 2

# %%
all_houses = list(clustered_df['House'])
all_cluster = Cluster(all_houses)
all_cluster_results = all_cluster.results(model_name)
print('Training History without clustering:')
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_12 (SimpleRNN)   (None, 14, 128)           17280
#
#  simple_rnn_13 (SimpleRNN)   (None, 14, 32)            5152
#
#  simple_rnn_14 (SimpleRNN)   (None, 16)                784
#
#  dense_4 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 23,233
# Trainable params: 23,233
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 26534/26534 [==============================] - 218s 8ms/step - loss: 0.3278 - root_mean_squared_error: 0.5725 - mean_absolute_error: 0.3100 - val_loss: 0.3303 - val_root_mean_squared_error: 0.5747 - val_mean_absolute_error: 0.3175
# Epoch 2/30
# 26534/26534 [==============================] - 217s 8ms/step - loss: 0.3171 - root_mean_squared_error: 0.5631 - mean_absolute_error: 0.3042 - val_loss: 0.3606 - val_root_mean_squared_error: 0.6005 - val_mean_absolute_error: 0.3444
# Epoch 3/30
# 26534/26534 [==============================] - 217s 8ms/step - loss: 0.3143 - root_mean_squared_error: 0.5606 - mean_absolute_error: 0.3034 - val_loss: 0.3358 - val_root_mean_squared_error: 0.5795 - val_mean_absolute_error: 0.3344
# Epoch 4/30
# 26534/26534 [==============================] - 217s 8ms/step - loss: 0.3116 - root_mean_squared_error: 0.5582 - mean_absolute_error: 0.3026 - val_loss: 0.3726 - val_root_mean_squared_error: 0.6104 - val_mean_absolute_error: 0.3234
# Epoch 5/30
# 26534/26534 [==============================] - 218s 8ms/step - loss: 0.3117 - root_mean_squared_error: 0.5583 - mean_absolute_error: 0.3023 - val_loss: 0.3551 - val_root_mean_squared_error: 0.5959 - val_mean_absolute_error: 0.3182
# Epoch 6/30
# 26534/26534 [==============================] - 219s 8ms/step - loss: 0.3082 - root_mean_squared_error: 0.5552 - mean_absolute_error: 0.3011 - val_loss: 0.3536 - val_root_mean_squared_error: 0.5946 - val_mean_absolute_error: 0.3257
# Epoch 7/30
# 26534/26534 [==============================] - 218s 8ms/step - loss: 0.3083 - root_mean_squared_error: 0.5553 - mean_absolute_error: 0.3009 - val_loss: 0.3357 - val_root_mean_squared_error: 0.5794 - val_mean_absolute_error: 0.3162
# Epoch 8/30
# 26534/26534 [==============================] - 219s 8ms/step - loss: 0.3071 - root_mean_squared_error: 0.5542 - mean_absolute_error: 0.3008 - val_loss: 0.3336 - val_root_mean_squared_error: 0.5776 - val_mean_absolute_error: 0.3195
# Epoch 9/30
# 26534/26534 [==============================] - 219s 8ms/step - loss: 0.3072 - root_mean_squared_error: 0.5542 - mean_absolute_error: 0.3008 - val_loss: 0.3505 - val_root_mean_squared_error: 0.5920 - val_mean_absolute_error: 0.3260
# Epoch 10/30
# 26534/26534 [==============================] - 219s 8ms/step - loss: 0.3058 - root_mean_squared_error: 0.5530 - mean_absolute_error: 0.3007 - val_loss: 0.3501 - val_root_mean_squared_error: 0.5917 - val_mean_absolute_error: 0.3203
# Epoch 11/30
# 26534/26534 [==============================] - 249s 9ms/step - loss: 0.3069 - root_mean_squared_error: 0.5540 - mean_absolute_error: 0.3012 - val_loss: 0.3362 - val_root_mean_squared_error: 0.5798 - val_mean_absolute_error: 0.3175
# Epoch 12/30
# 26534/26534 [==============================] - 256s 10ms/step - loss: 0.3054 - root_mean_squared_error: 0.5526 - mean_absolute_error: 0.3003 - val_loss: 0.4074 - val_root_mean_squared_error: 0.6383 - val_mean_absolute_error: 0.3216
# Epoch 13/30
# 26534/26534 [==============================] - 268s 10ms/step - loss: 0.3059 - root_mean_squared_error: 0.5531 - mean_absolute_error: 0.2999 - val_loss: 0.3482 - val_root_mean_squared_error: 0.5901 - val_mean_absolute_error: 0.3167
# Epoch 14/30
# 26534/26534 [==============================] - 239s 9ms/step - loss: 0.3056 - root_mean_squared_error: 0.5528 - mean_absolute_error: 0.2999 - val_loss: 0.3620 - val_root_mean_squared_error: 0.6017 - val_mean_absolute_error: 0.3413
# Epoch 15/30
# 26534/26534 [==============================] - 259s 10ms/step - loss: 0.3050 - root_mean_squared_error: 0.5523 - mean_absolute_error: 0.3000 - val_loss: 0.3363 - val_root_mean_squared_error: 0.5799 - val_mean_absolute_error: 0.3143
# Epoch 16/30
# 26534/26534 [==============================] - 219s 8ms/step - loss: 0.3032 - root_mean_squared_error: 0.5506 - mean_absolute_error: 0.2996 - val_loss: 0.3851 - val_root_mean_squared_error: 0.6205 - val_mean_absolute_error: 0.3242
# Epoch 17/30
# 26534/26534 [==============================] - 219s 8ms/step - loss: 0.3037 - root_mean_squared_error: 0.5511 - mean_absolute_error: 0.3001 - val_loss: 0.3402 - val_root_mean_squared_error: 0.5832 - val_mean_absolute_error: 0.3182
# Epoch 18/30
# 26534/26534 [==============================] - 219s 8ms/step - loss: 0.3027 - root_mean_squared_error: 0.5502 - mean_absolute_error: 0.2996 - val_loss: 0.3361 - val_root_mean_squared_error: 0.5797 - val_mean_absolute_error: 0.3196
# Epoch 19/30
# 26534/26534 [==============================] - 219s 8ms/step - loss: 0.3036 - root_mean_squared_error: 0.5510 - mean_absolute_error: 0.2996 - val_loss: 0.3310 - val_root_mean_squared_error: 0.5753 - val_mean_absolute_error: 0.3176
# Epoch 20/30
# 26534/26534 [==============================] - 219s 8ms/step - loss: 0.3036 - root_mean_squared_error: 0.5510 - mean_absolute_error: 0.2998 - val_loss: 0.3738 - val_root_mean_squared_error: 0.6114 - val_mean_absolute_error: 0.3362
# Epoch 21/30
# 26534/26534 [==============================] - 224s 8ms/step - loss: 0.3042 - root_mean_squared_error: 0.5515 - mean_absolute_error: 0.2998 - val_loss: 0.3365 - val_root_mean_squared_error: 0.5801 - val_mean_absolute_error: 0.3198
# Epoch 22/30
# 26534/26534 [==============================] - 251s 9ms/step - loss: 0.3024 - root_mean_squared_error: 0.5499 - mean_absolute_error: 0.2994 - val_loss: 0.3379 - val_root_mean_squared_error: 0.5813 - val_mean_absolute_error: 0.3172
# Epoch 23/30
# 25717/26534 [============================>.] - ETA: 6s - loss: 0.3028 - root_mean_squared_error: 0.5502 - mean_absolute_error: 0.2994
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_85693/3464048397.py in <module>
#       1 all_houses = list(clustered_df['House'])
#       2 all_cluster = Cluster(all_houses)
# ----> 3 all_cluster_results = all_cluster.results(model_name)
#       4 print('Training History without clustering:')
#
# /tmp/ipykernel_85693/3545516569.py in results(self, model_name)
#     104
#     105     def results(self, model_name='LSTM'):
# --> 106         predicted = self.predicted(model_name)
#     107         house_prediction_list_df  = {}
#     108         for house in predicted:
#
# /tmp/ipykernel_85693/3545516569.py in predicted(self, model_name)
#      97
#      98     def predicted(self, model_name='LSTM'):
# ---> 99         model = self.train_model(model_name)
#     100         predictions = list(map(lambda x: pd.Series(model.predict(x).reshape(1,-1)[0]), self.trainX_list))
#     101         #return pd.Series(model.predict(self.X).reshape(1,-1)[0])
#
# /tmp/ipykernel_85693/3545516569.py in train_model(self, model_name)
#      88         if model_name == 'ANN':
#      89             model = self.prepare_ANN_model()
# ---> 90         history = model.fit(self.X, self.Y, epochs=30, batch_size=16, validation_split=0.3, verbose=1) # Change to 30
#      91         self.history = history
#      92         plt.plot(history.history['loss'], label='Training loss')
#
# ~/anaconda3/lib/python3.9/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~/anaconda3/lib/python3.9/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1214                 _r=1):
#    1215               callbacks.on_train_batch_begin(step)
# -> 1216               tmp_logs = self.train_function(iterator)
#    1217               if data_handler.should_sync:
#    1218                 context.async_wait()
#
# ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     908
#     909       with OptionalXlaContext(self._jit_compile):
# --> 910         result = self._call(*args, **kwds)
#     911
#     912       new_tracing_count = self.experimental_get_tracing_count()
#
# ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     940       # In this case we have created variables on the first call, so we run the
#     941       # defunned version which is guaranteed to never create variables.
# --> 942       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     943     elif self._stateful_fn is not None:
#     944       # Release the lock early so that multiple threads can perform the call
#
# ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    3128       (graph_function,
#    3129        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 3130     return graph_function._call_flat(
#    3131         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3132
#
# ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1957         and executing_eagerly):
#    1958       # No tape is watching; skip to running the function.
# -> 1959       return self._build_call_outputs(self._inference_function.call(
#    1960           ctx, args, cancellation_manager=cancellation_manager))
#    1961     forward_backward = self._select_forward_and_backward_functions(
#
# ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     596       with _InterpolateFunctionError(self):
#     597         if cancellation_manager is None:
# --> 598           outputs = execute.execute(
#     599               str(self.signature.name),
#     600               num_outputs=self._num_outputs,
#
# ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      56   try:
#      57     ctx.ensure_initialized()
# ---> 58     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      59                                         inputs, attrs, num_outputs)
#      60   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
### Save Scenario 2 models
all_cluster.model.save(f'Models/Scenario2/{model_name}/all_cluster')

## Pickling Scenario 2 cluster and cluster result files
all_cluster_file = open(f"Models/Scenario2/Objects/{model_name}/all_cluster.pickle", "wb+")
pickle.dump(all_cluster, all_cluster_file)
all_cluster_file.close()

all_cluster_results_file = open(f"Models/Scenario2/Objects/{model_name}/all_cluster_results.pickle", "wb+")
pickle.dump(all_cluster_results, all_cluster_results_file)
all_cluster_results_file.close()

# %% [markdown]
# #### Predictions Graph functions

# %%
def x_axis_label_format(label):
    """
    Convert time label to the format of pandas line plot
    """
    label = pd.Timestamp(label)
    month = label.month_name()[:3]
    #if month == 'Jan':
    month += f'\n{label.year}'
    return month

def graph_predictions(cluster_specific_results, all_results):
    first_house = list(cluster_specific_results.keys())[0]
    df1 = cluster_specific_results[first_house][['timestamp','energy_predicted', 'energy_kWh']]
    df1['timestamp'] = pd.to_datetime(df1['timestamp'])
    df1 = df1.set_index('timestamp')
    df1['energy_predicted_without_clustering']= np.array(all_results[first_house][['energy_predicted']])
    df1.rename({'energy_predicted':'energy_predicted_with_clustering', 'energy_kWh':'real_energy'},axis = 1, inplace = True)
    ax = df1[::300].plot.line(figsize=(20,10))
    #ax.set_xticklabels(map(x_axis_label_format, df1[::int(len(df1)/8)+1].index))
    #import matplotlib.dates as mdates
    #myFmt = mdates.DateFormatter('%Y-%m')
    #ax.xaxis.set_major_formatter(myFmt)
    ax.set_title(f'Predictions for house {first_house}')

# %% [markdown]
# #### Predictions for Scenario 1 and Scenario 2

# %%
graph_predictions(zero_cluster_results, all_cluster_results)
#df1 = zero_cluster_results[1][['timestamp','energy_predicted', 'energy_kWh']].set_index('timestamp')
#df1['energy_predicted_without_clustering']= np.array(all_cluster_results[1][['energy_predicted']])

# %%
graph_predictions(one_cluster_results, all_cluster_results)

# %%
graph_predictions(two_cluster_results, all_cluster_results)

# %%
graph_predictions(three_cluster_results, all_cluster_results)

# %% [markdown]
# ### Function to create tables

# %%
def create_metrics(scenario_results, val=False):
    if val == False:
        rmse = 'root_mean_squared_error'
        mae = 'mean_absolute_error'
    else:
        rmse = 'val_root_mean_squared_error'
        mae = 'val_mean_absolute_error'
    scenario_rmse = list(map(lambda x: x.history.history[rmse],scenario_results))
    scenario_mae = list(map(lambda x: x.history.history[mae],scenario_results))
    scenario_rmse = np.array(scenario_rmse).reshape(-1,)
    scenario_mae = np.array(scenario_mae).reshape(-1,)
    return [np.min(scenario_rmse),np.max(scenario_rmse),np.mean(scenario_rmse),np.min(scenario_mae),np.max(scenario_mae),np.mean(scenario_mae)]

# %% [markdown]
# #### Scenario 1 and Scenario 2 Metric Tables

# %%
scenario_1_results = [zero_cluster, one_cluster, two_cluster, three_cluster]
scenario_1_metrics = create_metrics(scenario_1_results)
scenario_1_validation_metrics = create_metrics(scenario_1_results, val= True)
scenario_1_metrics

# %%
scenario_2_results = [all_cluster]
scenario_2_metrics = create_metrics(scenario_2_results)
scenario_2_validation_metrics = create_metrics(scenario_2_results, val= True)
scenario_2_metrics

# %% [markdown]
# #### Scenario 3 and 4

# %%
### Removing smart device features
House.cols = ['energy_kWh']
#House.cols

# %%
scenario_3_zero_cluster = Cluster(zero_houses)
scenario_3_zero_cluster_results = scenario_3_zero_cluster.results(model_name)
print('Training History for Cluster 0:')

# %%
scenario_3_one_cluster = Cluster(one_houses)
scenario_3_one_cluster_results = scenario_3_one_cluster.results(model_name)
print('Training History for Cluster 1:')

# %%
scenario_3_two_cluster = Cluster(two_houses)
scenario_3_two_cluster_results = scenario_3_two_cluster.results(model_name)
print('Training History for Cluster 2:')

# %%
scenario_3_three_cluster = Cluster(three_houses)
scenario_3_three_cluster_results = scenario_3_three_cluster.results(model_name)
print('Training History for Cluster 3:')

# %%
## Save Scenario 3 models
scenario_3_zero_cluster.model.save(f'Models/Scenario3/{model_name}/zero_cluster')
scenario_3_one_cluster.model.save(f'Models/Scenario3/{model_name}/one_cluster')
scenario_3_two_cluster.model.save(f'Models/Scenario3/{model_name}/two_cluster')
scenario_3_three_cluster.model.save(f'Models/Scenario3/{model_name}/three_cluster')

# Pickling objects

scenario_3_zero_cluster_file = open(f"Models/Scenario3/Objects/{model_name}/zero_cluster.pickle", "wb")
pickle.dump(scenario_3_zero_cluster, scenario_3_zero_cluster_file)
scenario_3_zero_cluster_file.close()

scenario_3_one_cluster_file = open(f"Models/Scenario3/Objects/{model_name}/one_cluster.pickle", "wb")
pickle.dump(scenario_3_one_cluster, scenario_3_one_cluster_file)
scenario_3_one_cluster_file.close()

scenario_3_two_cluster_file = open(f"Models/Scenario3/Objects/{model_name}/two_cluster.pickle", "wb")
pickle.dump(scenario_3_two_cluster, scenario_3_two_cluster_file)
scenario_3_two_cluster_file.close()

scenario_3_three_cluster_file = open(f"Models/Scenario3/Objects/{model_name}/three_cluster.pickle", "wb")
pickle.dump(scenario_3_three_cluster, scenario_3_three_cluster_file)
scenario_3_three_cluster_file.close()

scenario_3_zero_cluster_results_file = open(f"Models/Scenario3/Objects/{model_name}/zero_cluster_results.pickle", "wb")
pickle.dump(scenario_3_zero_cluster_results, scenario_3_zero_cluster_results_file)
scenario_3_zero_cluster_results_file.close()

scenario_3_one_cluster_results_file = open(f"Models/Scenario3/Objects/{model_name}/one_cluster_results.pickle", "wb")
pickle.dump(scenario_3_one_cluster_results, scenario_3_one_cluster_results_file)
scenario_3_one_cluster_results_file.close()

scenario_3_two_cluster_results_file = open(f"Models/Scenario3/Objects/{model_name}/two_cluster_results.pickle", "wb")
pickle.dump(scenario_3_two_cluster_results, scenario_3_two_cluster_results_file)
scenario_3_two_cluster_results_file.close()

scenario_3_three_cluster_results_file = open(f"Models/Scenario3/Objects/{model_name}/three_cluster_results.pickle", "wb")
pickle.dump(scenario_3_three_cluster_results, scenario_3_three_cluster_results_file)
scenario_3_three_cluster_results_file.close()

# %% [markdown]
# #### Scenario 4

# %%
scenario_4_all_cluster = Cluster(all_houses)
scenario_4_all_cluster_results = scenario_4_all_cluster.results(model_name)
print('Training History without clustering:')

# %%
### Save Scenario 4 models
scenario_4_all_cluster.model.save(f'Models/Scenario4/{model_name}/all_cluster')

## Pickling Scenario 4 cluster and cluster result files
scenario_4_all_cluster_file = open(f"Models/Scenario4/Objects/{model_name}/all_cluster.pickle", "wb")
pickle.dump(scenario_4_all_cluster, scenario_4_all_cluster_file)
scenario_4_all_cluster_file.close()

scenario_4_all_cluster_results_file = open(f"Models/Scenario4/Objects/{model_name}/all_cluster_results.pickle", "wb")
pickle.dump(scenario_4_all_cluster_results, scenario_4_all_cluster_results_file)
scenario_4_all_cluster_results_file.close()

# %% [markdown]
# #### Predictions for Scenario 3 and Scenario 4

# %%
graph_predictions(scenario_3_zero_cluster_results, scenario_4_all_cluster_results)

# %%
graph_predictions(scenario_3_one_cluster_results, scenario_4_all_cluster_results)

# %%
graph_predictions(scenario_3_two_cluster_results, scenario_4_all_cluster_results)

# %%
graph_predictions(scenario_3_three_cluster_results, scenario_4_all_cluster_results)

# %% [markdown]
# #### Scenario 3 and Scenario 4 Metric Tables

# %%
scenario_3_results = [scenario_3_zero_cluster, scenario_3_one_cluster, scenario_3_two_cluster, scenario_3_three_cluster]
scenario_3_metrics = create_metrics(scenario_3_results )
scenario_3_validation_metrics = create_metrics(scenario_3_results, val= True)
scenario_3_metrics

# %%
scenario_4_results = [scenario_4_all_cluster]
scenario_4_metrics = create_metrics(scenario_4_results )
scenario_4_validation_metrics = create_metrics(scenario_4_results, val= True)
scenario_4_metrics

# %%
print('Training metrics:')
df = pd.DataFrame([scenario_1_metrics, scenario_2_metrics, scenario_3_metrics, scenario_4_metrics],index=[1,2,3,4], columns = ['Min RMSE', 'Max RMSE', 'Mean RMSE','Min MAE', 'Max MAE', 'Mean MAE'])
df['Scenario'] = np.array([1,2,3,4])
df.set_index('Scenario').round(decimals=2).to_csv('Tables/training_metrics.csv')

# %%
print('Validation metrics:')
df = pd.DataFrame([scenario_1_validation_metrics, scenario_2_validation_metrics,
                   scenario_3_validation_metrics, scenario_4_validation_metrics],index=[1,2,3,4], columns = ['Min RMSE', 'Max RMSE', 'Mean RMSE','Min MAE', 'Max MAE', 'Mean MAE'])
df['Scenario'] = np.array([1,2,3,4])
df.set_index('Scenario').round(decimals=2).to_csv('Tables/validation_metrics.csv')

# %% [markdown]
# ### Anomaly Distribution

# %%
def create_anomaly_df(result_df, scenario_name, monthly_agg = True):    
    #print(type(result_df))
    anomaly_df = result_df[['timestamp', 'Anomaly detected']]
    anomaly_df.set_index('timestamp', inplace = True)
    if monthly_agg:
        anomaly_df['Anomaly detected'] = anomaly_df['Anomaly detected'].apply(lambda x: 0 if x is False else 1)
        anomaly_df = anomaly_df.resample("M").agg('sum')
    else: 
        anomaly_df['Anomaly detected'] = anomaly_df['Anomaly detected'].apply(lambda x: 0 if x is False else x)
    anomaly_df = anomaly_df.rename(columns={'Anomaly detected': scenario_name})
    return anomaly_df

def create_anomalies_graph( title = None, **kwargs):
    anomaly_dfs = []
    for scenario_name, result_df in kwargs.items():
        anomaly_df = create_anomaly_df(result_df, scenario_name)
        anomaly_dfs.append(anomaly_df)
    anomaly_df = functools.reduce(lambda left, right: left.join(right), anomaly_dfs)
    ax = anomaly_df.plot.line(figsize=(20,10))
    ax.set_xlabel(f'Time')
    ax.set_ylabel(f'Frequency')
    ax.set_title(title)
    #return anomaly_dfs

# %%
def dtw_distance(series1, series2):
    return fastdtw.fastdtw(series1,series2)[0]

def create_distance_df(title, **kwargs):
    print(title)
    anomaly_dfs = []
    for scenario_name, result_df in kwargs.items():
        anomaly_df = np.array(create_anomaly_df(result_df, scenario_name, monthly_agg=False)).reshape(1,-1)
        anomaly_dfs.append(anomaly_df)
    anomaly_distributions = np.array(anomaly_dfs).reshape(len(kwargs),-1)
    distance_matrix = sd.squareform(sd.pdist(anomaly_distributions, dtw_distance))
    return(pd.DataFrame(distance_matrix, columns = kwargs.keys(), index = kwargs.keys()))
    #return anomaly_dfs

# %%
create_anomalies_graph( 'Anomaly Frequency Distribution for House 1: Cluster 0', Scenario1 = zero_cluster_results[1], Scenario2 = all_cluster_results[1],
                       Scenario3 = scenario_3_zero_cluster_results[1], Scenario4 = scenario_4_all_cluster_results[1])

# %%
create_distance_df('Similarity between anomaly distributions for House1: Cluster 0', Scenario1 = zero_cluster_results[1], Scenario2 = all_cluster_results[1],
                       Scenario3 = scenario_3_zero_cluster_results[1], Scenario4 = scenario_4_all_cluster_results[1]).round(decimals=2).to_csv('Tables/anomaly_cluster0.csv')

# %%
create_anomalies_graph( 'Anomaly Frequency Distribution for House 15: Cluster 1', Scenario1 = one_cluster_results[15], Scenario2 = all_cluster_results[15],
                       Scenario3 = scenario_3_one_cluster_results[15], Scenario4 = scenario_4_all_cluster_results[15])

# %%
create_distance_df( 'Similarity between anomaly distributions for House15: Cluster 1', Scenario1 = one_cluster_results[15], Scenario2 = all_cluster_results[15],
                       Scenario3 = scenario_3_one_cluster_results[15], Scenario4 = scenario_4_all_cluster_results[15]).round(decimals=2).to_csv('Tables/anomaly_cluster1.csv')

# %%
create_anomalies_graph( 'Anomaly Frequency Distribution for House 2: Cluster 2', Scenario1 = two_cluster_results[2], Scenario2 = all_cluster_results[2],
                       Scenario3 = scenario_3_two_cluster_results[2], Scenario4 = scenario_4_all_cluster_results[2])

# %%
create_distance_df( 'Similarity between anomaly distributions for House 2: Cluster 2', Scenario1 = two_cluster_results[2], Scenario2 = all_cluster_results[2],
                       Scenario3 = scenario_3_two_cluster_results[2], Scenario4 = scenario_4_all_cluster_results[2]).round(decimals=2).to_csv('Tables/anomaly_cluster2.csv')

# %%
create_anomalies_graph( 'Anomaly Frequency Distribution for House 3: Cluster 3', Scenario1 = three_cluster_results[3], Scenario2 = all_cluster_results[3],
                       Scenario3 = scenario_3_three_cluster_results[3], Scenario4 = scenario_4_all_cluster_results[3])

# %%
create_distance_df( 'Similarity between anomaly distributions for House 3: Cluster 3', Scenario1 = three_cluster_results[3], Scenario2 = all_cluster_results[3],
                       Scenario3 = scenario_3_three_cluster_results[3], Scenario4 = scenario_4_all_cluster_results[3]).round(decimals=2).to_csv('Tables/anomaly_cluster3.csv')

# %% [markdown]
# #### Energy Deficit Calculation

# %%
def create_deficit_df(result_df, scenario_name, monthly_agg = True):    
    #print(type(result_df))
    energy_df = result_df[['timestamp', 'Energy Deficit Flag']]
    energy_df.set_index('timestamp', inplace = True)
    if monthly_agg:
        energy_df['Energy Deficit Flag'] = energy_df['Energy Deficit Flag'].apply(lambda x: 0 if x is False else 1)
        energy_df = energy_df.resample("W").agg('sum')
    else: 
        energy_df['Energy Deficit Flag'] = energy_df['Energy Deficit Flag'].apply(lambda x: 0 if x is False else x)
    energy_df = energy_df.rename(columns={'Energy Deficit Flag': scenario_name})
    return energy_df

def create_energy_deficit_graph( title = None, **kwargs):
    energy_dfs = []
    for scenario_name, result_df in kwargs.items():
        energy_df = create_deficit_df(result_df, scenario_name)
        energy_dfs.append(energy_df)
    energy_df = functools.reduce(lambda left, right: left.join(right), energy_dfs)
    ax = energy_df.plot.line(figsize=(20,10))
    ax.set_xlabel(f'Time')
    ax.set_ylabel(f'Frequency')
    ax.set_title(title)

# %%
def create_deficit_distance_df(title, **kwargs):
    print(title)
    energy_dfs = []
    for scenario_name, result_df in kwargs.items():
        energy_df = np.array(create_deficit_df(result_df, scenario_name, monthly_agg=False)).reshape(1,-1)
        energy_dfs.append(energy_df)
    energy_distributions = np.array(energy_dfs).reshape(len(kwargs),-1)
    distance_matrix = sd.squareform(sd.pdist(energy_distributions, dtw_distance))
    return(pd.DataFrame(distance_matrix, columns = kwargs.keys(), index = kwargs.keys()))

# %%
create_energy_deficit_graph( 'Energy Deficit Frequency Distribution for House 1: Cluster 0', Scenario1 = zero_cluster_results[1], Scenario2 = all_cluster_results[1],
                       Scenario3 = scenario_3_zero_cluster_results[1], Scenario4 = scenario_4_all_cluster_results[1])

# %%
create_deficit_distance_df('Similarity between energy deficit distributions for House1: Cluster 0', Scenario1 = zero_cluster_results[1], Scenario2 = all_cluster_results[1],
                       Scenario3 = scenario_3_zero_cluster_results[1], Scenario4 = scenario_4_all_cluster_results[1])

# %%
create_energy_deficit_graph( 'Energy Deficit Frequency Distribution for House 15: Cluster 1', Scenario1 = one_cluster_results[15], Scenario2 = all_cluster_results[15],
                       Scenario3 = scenario_3_one_cluster_results[15], Scenario4 = scenario_4_all_cluster_results[15])

# %%
create_deficit_distance_df( 'Similarity between energy deficit distributions for House15: Cluster 1', Scenario1 = one_cluster_results[15], 
                    Scenario2 = all_cluster_results[15],
                       Scenario3 = scenario_3_one_cluster_results[15], Scenario4 = scenario_4_all_cluster_results[15])

# %%
create_energy_deficit_graph( 'Energy Deficit Frequency Distribution for House 2: Cluster 2', Scenario1 = two_cluster_results[2], Scenario2 = all_cluster_results[2],
                       Scenario3 = scenario_3_two_cluster_results[2], Scenario4 = scenario_4_all_cluster_results[2])

# %%
create_deficit_distance_df( 'Similarity between energy deficit distributions for House 2: Cluster 2', Scenario1 = two_cluster_results[2], Scenario2 = all_cluster_results[2],
                       Scenario3 = scenario_3_two_cluster_results[2], Scenario4 = scenario_4_all_cluster_results[2])

# %%
create_energy_deficit_graph( 'Energy Deficit Frequency Distribution for House 3: Cluster 3', Scenario1 = three_cluster_results[3], Scenario2 = all_cluster_results[3],
                       Scenario3 = scenario_3_three_cluster_results[3], Scenario4 = scenario_4_all_cluster_results[3])

# %%
create_deficit_distance_df( 'Similarity between energy deficit distributions for House 3: Cluster 3', Scenario1 = three_cluster_results[3], Scenario2 = all_cluster_results[3],
                       Scenario3 = scenario_3_three_cluster_results[3], Scenario4 = scenario_4_all_cluster_results[3])

# %%
print(tf. __version__)
