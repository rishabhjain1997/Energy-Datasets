# %% [markdown]
# #### Importing Libraries and Dataset

# %%
import numpy as np
from statistics import mean
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import pandas as pd
import seaborn as sns
from tslearn.clustering import TimeSeriesKMeans
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM
from tensorflow.keras import regularizers
from tensorflow.keras.layers import Dense, Dropout
import tensorflow as tf
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from tensorflow import keras
import seaborn as sns
import pickle
import functools
import fastdtw
import scipy.spatial.distance as sd
#from datetime import datetime
consumption_df = pd.read_csv('Final Datasets/energy_consumption.csv')
consumption_df
# Out:
# 2022-01-18 15:16:40.943454: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-01-18 15:16:40.943483: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
#         Unnamed: 0            timestamp  energy_kWh  House Number  \
# 0                0  2012-06-01 01:00:00       1.011             1
# 1                1  2012-06-01 02:00:00       0.451             1
# 2                2  2012-06-01 03:00:00       0.505             1
# 3                3  2012-06-01 04:00:00       0.441             1
# 4                4  2012-06-01 05:00:00       0.468             1
# ...            ...                  ...         ...           ...
# 611013      123761  2020-05-19 19:00:00       3.060            28
# 611014      123762  2020-05-19 20:00:00       2.940            28
# 611015      123763  2020-05-19 21:00:00       1.970            28
# 611016      123764  2020-05-19 22:00:00       2.130            28
# 611017      123765  2020-05-19 23:00:00       1.010            28
#
#         electronics workbench energy  network equipment energy  \
# 0                           0.008686                  0.019316
# 1                           0.007178                  0.019338
# 2                           0.007324                  0.019336
# 3                           0.007151                  0.019339
# 4                           0.007224                  0.019338
# ...                              ...                       ...
# 611013                      0.014204                  0.019235
# 611014                      0.013881                  0.019240
# 611015                      0.011269                  0.019278
# 611016                      0.011700                  0.019272
# 611017                      0.008683                  0.019316
#
#         home office energy  RAE home office energy  \
# 0                 0.018232                0.134570
# 1                 0.013745                0.061839
# 2                 0.014177                0.068852
# 3                 0.013664                0.060540
# 4                 0.013881                0.064047
# ...                    ...                     ...
# 611013            0.034654                0.400690
# 611014            0.033692                0.385105
# 611015            0.025918                0.259123
# 611016            0.027200                0.279904
# 611017            0.018224                0.134440
#
#         RAE Mobile Phone Charger Energy
# 0                              0.000431
# 1                              0.000215
# 2                              0.000236
# 3                              0.000211
# 4                              0.000221
# ...                                 ...
# 611013                         0.001220
# 611014                         0.001174
# 611015                         0.000800
# 611016                         0.000862
# 611017                         0.000430
#
# [611018 rows x 9 columns]

# %%
if 'Unnamed: 0' in consumption_df.columns:
    consumption_df.drop('Unnamed: 0',axis=1, inplace = True)

# %%
consumption_df
# Out:
#                   timestamp  energy_kWh  House Number  \
# 0       2012-06-01 01:00:00       1.011             1
# 1       2012-06-01 02:00:00       0.451             1
# 2       2012-06-01 03:00:00       0.505             1
# 3       2012-06-01 04:00:00       0.441             1
# 4       2012-06-01 05:00:00       0.468             1
# ...                     ...         ...           ...
# 611013  2020-05-19 19:00:00       3.060            28
# 611014  2020-05-19 20:00:00       2.940            28
# 611015  2020-05-19 21:00:00       1.970            28
# 611016  2020-05-19 22:00:00       2.130            28
# 611017  2020-05-19 23:00:00       1.010            28
#
#         electronics workbench energy  network equipment energy  \
# 0                           0.008686                  0.019316
# 1                           0.007178                  0.019338
# 2                           0.007324                  0.019336
# 3                           0.007151                  0.019339
# 4                           0.007224                  0.019338
# ...                              ...                       ...
# 611013                      0.014204                  0.019235
# 611014                      0.013881                  0.019240
# 611015                      0.011269                  0.019278
# 611016                      0.011700                  0.019272
# 611017                      0.008683                  0.019316
#
#         home office energy  RAE home office energy  \
# 0                 0.018232                0.134570
# 1                 0.013745                0.061839
# 2                 0.014177                0.068852
# 3                 0.013664                0.060540
# 4                 0.013881                0.064047
# ...                    ...                     ...
# 611013            0.034654                0.400690
# 611014            0.033692                0.385105
# 611015            0.025918                0.259123
# 611016            0.027200                0.279904
# 611017            0.018224                0.134440
#
#         RAE Mobile Phone Charger Energy
# 0                              0.000431
# 1                              0.000215
# 2                              0.000236
# 3                              0.000211
# 4                              0.000221
# ...                                 ...
# 611013                         0.001220
# 611014                         0.001174
# 611015                         0.000800
# 611016                         0.000862
# 611017                         0.000430
#
# [611018 rows x 8 columns]

# %% [markdown]
# #### Converting Dataset to House-wise dictionary

# %%
house_wise_consumption = dict()
for house_number in consumption_df['House Number'].unique():
    house_data = consumption_df[consumption_df['House Number'] == house_number]
    house_wise_consumption[house_number] = house_data.copy()
house_wise_consumption[1]
# house_wise_consumption[14]['timestamp'].iloc[0]
# house_wise_consumption[14]['timestamp'].iloc[-1]
# house_wise_consumption[14]['House Number'].iloc[0]
# Out:
#                  timestamp  energy_kWh  House Number  \
# 0      2012-06-01 01:00:00       1.011             1
# 1      2012-06-01 02:00:00       0.451             1
# 2      2012-06-01 03:00:00       0.505             1
# 3      2012-06-01 04:00:00       0.441             1
# 4      2012-06-01 05:00:00       0.468             1
# ...                    ...         ...           ...
# 29226  2015-10-02 20:00:00       2.101             1
# 29227  2015-10-02 21:00:00       1.646             1
# 29228  2015-10-02 22:00:00       1.319             1
# 29229  2015-10-02 23:00:00       1.473             1
# 29230  2015-10-03 00:00:00       0.800             1
#
#        electronics workbench energy  network equipment energy  \
# 0                          0.008686                  0.019316
# 1                          0.007178                  0.019338
# 2                          0.007324                  0.019336
# 3                          0.007151                  0.019339
# 4                          0.007224                  0.019338
# ...                             ...                       ...
# 29226                      0.011621                  0.019273
# 29227                      0.010396                  0.019291
# 29228                      0.009516                  0.019304
# 29229                      0.009930                  0.019298
# 29230                      0.008118                  0.019324
#
#        home office energy  RAE home office energy  \
# 0                0.018232                0.134570
# 1                0.013745                0.061839
# 2                0.014177                0.068852
# 3                0.013664                0.060540
# 4                0.013881                0.064047
# ...                   ...                     ...
# 29226            0.026968                0.276137
# 29227            0.023322                0.217043
# 29228            0.020701                0.174573
# 29229            0.021935                0.194574
# 29230            0.016541                0.107166
#
#        RAE Mobile Phone Charger Energy
# 0                             0.000431
# 1                             0.000215
# 2                             0.000236
# 3                             0.000211
# 4                             0.000221
# ...                                ...
# 29226                         0.000851
# 29227                         0.000675
# 29228                         0.000549
# 29229                         0.000609
# 29230                         0.000349
#
# [29231 rows x 8 columns]

# %% [markdown]
# #### Comparing Timestamps for clustering

# %%
timestamp_comparison = list()
for house in house_wise_consumption:
    first_timestamp = house_wise_consumption[house]['timestamp'].iloc[0]
    last_timestamp = house_wise_consumption[house]['timestamp'].iloc[-1]
    timestamp_comparison.append([house, first_timestamp, last_timestamp])
timestamp_comparison
timestamp_comparison_df = pd.DataFrame(timestamp_comparison, columns = ['House', 'First Timestamp', 'Last Timestamp'])
timestamp_comparison_df
# Out:
#     House      First Timestamp       Last Timestamp
# 0       1  2012-06-01 01:00:00  2015-10-03 00:00:00
# 1       2  2016-06-09 00:00:00  2019-11-20 23:00:00
# 2       3  2015-01-27 00:00:00  2018-01-29 23:00:00
# 3       4  2015-01-30 00:00:00  2018-01-29 23:00:00
# 4       5  2015-01-30 00:00:00  2018-01-29 23:00:00
# 5       6  2015-01-30 00:00:00  2018-01-29 23:00:00
# 6       7  2015-05-30 00:00:00  2018-01-29 23:00:00
# 7       8  2015-02-21 00:00:00  2018-02-20 23:00:00
# 8       9  2015-05-01 00:00:00  2018-02-21 23:00:00
# 9      10  2015-02-21 00:00:00  2018-02-20 23:00:00
# 10     11  2015-02-21 00:00:00  2018-02-20 23:00:00
# 11     12  2015-02-21 00:00:00  2018-02-20 23:00:00
# 12     13  2015-02-21 00:00:00  2018-02-20 23:00:00
# 13     14  2015-02-21 00:00:00  2018-02-20 23:00:00
# 14     15  2015-09-29 00:00:00  2018-02-20 23:00:00
# 15     16  2017-11-01 00:00:00  2019-02-18 23:00:00
# 16     17  2016-06-01 00:00:00  2017-04-29 23:00:00
# 17     18  2015-03-16 00:00:00  2018-03-15 16:00:00
# 18     19  2015-03-26 00:00:00  2018-03-25 23:00:00
# 19     20  2015-08-21 00:00:00  2018-04-20 23:00:00
# 20     21  2017-11-01 00:00:00  2018-06-04 23:00:00
# 21     22  2016-06-29 00:00:00  2018-06-05 23:00:00
# 22     23  2017-07-27 00:00:00  2020-04-05 23:00:00
# 23     24  2017-05-13 00:00:00  2020-05-12 23:00:00
# 24     25  2017-05-15 00:00:00  2020-05-14 23:00:00
# 25     26  2019-11-29 00:00:00  2020-05-20 23:00:00
# 26     27  2019-03-06 00:00:00  2020-05-20 23:00:00
# 27     28  2018-08-01 00:00:00  2020-05-19 23:00:00

# %%
# houses_with_ts = []
# sample_timestamp = '2017-11-01 00:00:00'
# for house in house_wise_consumption:
#     if sample_timestamp in house_wise_consumption[house]['timestamp'].unique():
#         houses_with_ts.append(house)
# len(houses_with_ts)
#house_wise_consumption[8][house_wise_consumption[8]['timestamp'] >= '2017-11-17'].head(60)

# %% [markdown]
# #### Creating a December consumption dictionary of dataframes

# %%
december_consumption = dict()
for house in house_wise_consumption:
    house_december_consumption = house_wise_consumption[house][(house_wise_consumption[house]['timestamp'] <= '2017-11-25') & (house_wise_consumption[house]['timestamp'] >= '2017-11-01')]
    december_consumption[house] = house_december_consumption.copy()
    december_consumption[house].drop_duplicates(subset='timestamp', keep="last", inplace = True)
def calculate_rows():
    december_rows = []
    for house in december_consumption:
        december_rows.append([house, len(december_consumption[house])])
    december_rows
    december_rows_df = pd.DataFrame(december_rows, columns = ['House', 'Rows'])
    return december_rows_df
def calculate_incomplete_rows():
    december_rows_df = calculate_rows()
    december_rows_incomplete_df = december_rows_df[(december_rows_df['Rows'] > 0) & (december_rows_df['Rows'] < 576)]
    return december_rows_incomplete_df
def fill_na_december_consumption(complete_df, incomplete_df):
    complete_df = complete_df.copy()
    year_incomplete = pd.Timestamp(incomplete_df.iloc[0]['timestamp']).year
    year_complete = pd.Timestamp(complete_df.iloc[0]['timestamp']).year
    complete_df['timestamp'] = complete_df['timestamp'].str.replace(str(year_complete), str(year_incomplete))
    fill_missing_values = complete_df[~complete_df.timestamp.isin(incomplete_df.timestamp)].copy()
    #print(fill_missing_values)
    fill_columns = ['energy_kWh', 'electronics workbench energy', 'network equipment energy', 'home office energy', 'RAE home office energy','RAE Mobile Phone Charger Energy']
    for fill_column in fill_columns:
        fill_missing_values[fill_column] = incomplete_df[fill_column].mean()
    incomplete_df = pd.concat([incomplete_df, fill_missing_values])
    incomplete_df = incomplete_df.sort_values(by=['timestamp'])
    return incomplete_df
def calculate_missing_december_rows():
    december_rows_df = calculate_rows()
    december_rows_missing_df = december_rows_df[(december_rows_df['Rows'] == 0)]
    return december_rows_missing_df
calculate_rows()
# Out:
#     House  Rows
# 0       1     0
# 1       2   576
# 2       3   576
# 3       4   576
# 4       5   576
# 5       6   576
# 6       7   576
# 7       8   448
# 8       9   576
# 9      10   576
# 10     11   568
# 11     12   528
# 12     13   576
# 13     14   575
# 14     15   576
# 15     16   456
# 16     17     0
# 17     18   528
# 18     19   576
# 19     20   575
# 20     21   576
# 21     22   528
# 22     23   576
# 23     24   576
# 24     25   576
# 25     26     0
# 26     27     0
# 27     28     0

# %%
for house in list(calculate_incomplete_rows()['House']):
    december_consumption[house] = fill_na_december_consumption(december_consumption[10], december_consumption[house])

# %% [markdown]
# ##### Houses with no December-17 consumption values

# %%
timestamp_comparison_df.set_index('House').join(calculate_missing_december_rows().set_index('House'), how='inner')
# Out:
#            First Timestamp       Last Timestamp  Rows
# House
# 1      2012-06-01 01:00:00  2015-10-03 00:00:00     0
# 17     2016-06-01 00:00:00  2017-04-29 23:00:00     0
# 26     2019-11-29 00:00:00  2020-05-20 23:00:00     0
# 27     2019-03-06 00:00:00  2020-05-20 23:00:00     0
# 28     2018-08-01 00:00:00  2020-05-19 23:00:00     0

# %%
missing_december_houses_dates = {
    1: ['2014-11-25', '2014-11-01'],
    17: ['2016-11-25', '2016-11-01'],
    26: ['2019-11-25', '2019-11-01'],
    27: ['2019-11-25', '2019-11-01'],
    28: ['2019-11-25', '2019-11-01'],
}

# %%
for house in missing_december_houses_dates:
    house_december_consumption = house_wise_consumption[house][(house_wise_consumption[house]['timestamp'] <= missing_december_houses_dates[house][0]) & (house_wise_consumption[house]['timestamp'] >= missing_december_houses_dates[house][1])]
    #print((house, missing_december_houses_dates[house][0]))
    december_consumption[house] = house_december_consumption.copy()
    december_consumption[house].drop_duplicates(subset='timestamp', keep="last", inplace = True)

# %% [markdown]
# ##### Filling missing values for December consumption

# %%
calculate_incomplete_rows()
# Out:
#     House  Rows
# 16     17   574
# 26     27   571
# 27     28   572

# %%
for house in list(calculate_incomplete_rows()['House']):
    december_consumption[house] = fill_na_december_consumption(december_consumption[10], december_consumption[house])

# %%
#calculate_rows()

# %% [markdown]
# #### Houses to be clustered

# %%
##print('Houses to be clustered: ')
clustered_df = calculate_rows()[calculate_rows()['Rows'] ==  576]
#clustered_df

# %% [markdown]
# #### Converting to clustering matrix

# %%
clustering_matrix = []
for house in calculate_rows()[calculate_rows()['Rows'] ==  576]['House']:
    clustering_matrix.append(np.array(december_consumption[house]['energy_kWh']).reshape(-1,1))
clustering_matrix = np.array(clustering_matrix)
clustering_matrix.shape
# Out:
# (27, 576, 1)

# %% [markdown]
# #### Time series clustering of all households except house 26

# %%
km_sdtw = TimeSeriesKMeans(n_clusters=4, metric="softdtw", max_iter=5,
                            max_iter_barycenter=5,
                            metric_params={"gamma": .5},
                            random_state=0).fit_predict(clustering_matrix)

# %%
len(km_sdtw)
# Out:
# 27

# %%
clustered_df['Cluster'] = km_sdtw

# %%
#clustered_df = clustered_df[['House', 'Cluster']].set_index('House')
clustered_df[clustered_df['Cluster'] == 3]
# Out:
#     House  Rows  Cluster
# 2       3   576        3
# 4       5   576        3
# 26     27   576        3

# %% [markdown]
# #### Used Scenarios

# %%
data = [[1, 4, 6, 'Yes'], [2, 1, 6, 'Yes'], [3, 4, 1, 'No'], [4, 1, 1, 'No']]
df = pd.DataFrame(data, columns = ['Scenarios', 'No. of subsets', 'No. of features', 'Smart devices included in modeling?']).set_index('Scenarios')
df
# Out:
#            No. of subsets  No. of features Smart devices included in modeling?
# Scenarios
# 1                       4                6                                 Yes
# 2                       1                6                                 Yes
# 3                       4                1                                  No
# 4                       1                1                                  No

# %% [markdown]
# #### Time-series LSTM-based predictive modeling

# %%
n_past = 14
n_future = 1

# %%
### Energy generation dataframe
generation_df = pd.read_csv('Final Datasets/energy_generation.csv')
generation_df
# Out:
#                  timestamp  Wind Energy  Solar Energy
# 0      2012-01-01 00:00:00     0.196361           0.0
# 1      2012-01-01 01:00:00     0.196361           0.0
# 2      2012-01-01 02:00:00     0.196361           0.0
# 3      2012-01-01 03:00:00     0.196361           0.0
# 4      2012-01-01 04:00:00     0.196361           0.0
# ...                    ...          ...           ...
# 78907  2020-12-31 19:00:00     1.996050           0.0
# 78908  2020-12-31 20:00:00     1.996050           0.0
# 78909  2020-12-31 21:00:00     1.747987           0.0
# 78910  2020-12-31 22:00:00     1.500100           0.0
# 78911  2020-12-31 23:00:00     1.501644           0.0
#
# [78912 rows x 3 columns]

# %%
class House:
    cols = ['energy_kWh', 'electronics workbench energy', 'network equipment energy',
            'home office energy', 'RAE home office energy', 'RAE Mobile Phone Charger Energy']
    def __init__(self, house):
        self.house = house
        self.consumption_df = house_wise_consumption[house].copy()[House.cols].astype(float)
        self.train_dates_df = house_wise_consumption[house]['timestamp']
        self.prepare_dataset(n_future, n_past)
    
    def __repr__(self):
        return str(self.house)
    
    def prepare_dataset(self, n_future = 1, n_past = 14):
        #Empty lists to be populated using formatted training data
        trainX = []
        trainY = []
        consumption_np = np.array(self.consumption_df)
        #Reformat input data into a shape: (n_samples x timesteps x n_features)
        #In my example, my self.consumption_df has a shape (12823, 5)
        #12823 refers to the number of data points and 5 refers to the columns (multi-variables).
        for i in range(n_past, len(consumption_np) - n_future +1):
            trainX.append(consumption_np[i - n_past:i, 0:self.consumption_df.shape[1]])
            trainY.append(consumption_np[i + n_future - 1:i + n_future, 0])

        trainX, trainY = np.array(trainX), np.array(trainY)

        #print('trainX shape == {}.'.format(trainX.shape))
        #print('trainY shape == {}.'.format(trainY.shape))
        self.trainX = trainX
        self.trainY = trainY

class Cluster: 
    def __init__(self, houses):
        self.houses = [House(house) for house in houses]
        self.trainX_list = (list(map(lambda x: x.trainX, self.houses)))
        self.trainY_list = (list(map(lambda x: x.trainY, self.houses)))
        self.train_dates_list = (list(map(lambda x: x.train_dates_df, self.houses)))
        self.consumption_df_list = (list(map(lambda x: x.consumption_df, self.houses)))
        self.prepare_dataset()
        
    
    def prepare_dataset(self):
        
        self.train_dates = np.concatenate(self.train_dates_list, axis=0)
        ## TODO - Replace concatenate with for loop or sort by time
        self.X = np.concatenate(self.trainX_list, axis=0)
        self.Y = np.concatenate(self.trainY_list, axis=0)
    
    def prepare_model(self):
        model = Sequential()
        model.add(LSTM(128, activation='relu', input_shape=(self.X.shape[1], self.X.shape[2]), return_sequences=True))
        model.add(LSTM(32, activation='relu', return_sequences=True))
        model.add(LSTM(16, activation='relu', return_sequences=False))
        model.add(Dense(self.Y.shape[1]))
        model.compile(optimizer='adam', loss='mse', metrics=[tf.keras.metrics.RootMeanSquaredError(), tf.keras.metrics.MeanAbsoluteError()])
        model.summary()
        return model
    
    def train_model(self):
        model = self.prepare_model()
        history = model.fit(self.X, self.Y, epochs=30, batch_size=16, validation_split=0.3, verbose=1)
        self.history = history
        plt.plot(history.history['loss'], label='Training loss')
        plt.plot(history.history['val_loss'], label='Testing loss')
        
        plt.legend()
        return model
    
    def predicted(self):
        model = self.train_model()
        predictions = list(map(lambda x: pd.Series(model.predict(x).reshape(1,-1)[0]), self.trainX_list))
        #return pd.Series(model.predict(self.X).reshape(1,-1)[0])
        self.model = model
        return dict(zip(self.houses, predictions))
    
    def results(self):
        predicted = self.predicted()
        house_prediction_list_df  = {}
        for house in predicted:
            house_prediction_df = house.consumption_df.iloc[n_past:].copy().reset_index(drop=True)
            house_prediction_df['timestamp'] = house.train_dates_df.iloc[n_past:].copy().reset_index(drop=True)
            house_prediction_df['energy_predicted'] = predicted[house]
            ### Anomaly Detection
            energy_stddev = house_prediction_df['energy_kWh'].std()
            house_prediction_df['Energy Consumption Error'] = house_prediction_df['energy_predicted'] - house_prediction_df['energy_kWh']
            house_prediction_df['Anomaly detected'] = house_prediction_df['Energy Consumption Error'].apply(lambda x: False if abs(x) < 1.5*energy_stddev else abs(x))
            ### Energy Deficit Calculation
            house_prediction_df['timestamp'] = pd.DatetimeIndex(house_prediction_df['timestamp'])
            generation_df['timestamp'] = pd.DatetimeIndex(generation_df['timestamp'])
            house_prediction_df = house_prediction_df.set_index('timestamp').join(generation_df.set_index('timestamp'))
            house_prediction_df['timestamp'] = house_prediction_df.index
            house_prediction_df.reset_index(drop=True, inplace=True)
            house_prediction_df['Total Generated Energy'] = house_prediction_df['Wind Energy']+ house_prediction_df['Solar Energy']
            house_prediction_df['Predicted Energy Deficit'] = house_prediction_df['Total Generated Energy'] - house_prediction_df['energy_predicted']
            house_prediction_df['Energy Deficit Flag'] = house_prediction_df['Predicted Energy Deficit'].apply(lambda x: False if x>0 else abs(x))
            house_prediction_list_df[house.house] = house_prediction_df
        return house_prediction_list_df

# %% [markdown]
# #### Scenario 1

# %%
zero_houses = list(clustered_df[clustered_df['Cluster'] == 0]['House'])
zero_cluster = Cluster(zero_houses)
zero_cluster_results = zero_cluster.results()
print('Training History for Cluster 0:')
# Out:
# 2022-01-18 15:17:23.576261: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-01-18 15:17:23.576287: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-01-18 15:17:23.576307: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (rishabh-Inspiron): /proc/driver/nvidia/version does not exist
# 2022-01-18 15:17:23.576473: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 14, 128)           69120
#
#  lstm_1 (LSTM)               (None, 14, 32)            20608
#
#  lstm_2 (LSTM)               (None, 16)                3136
#
#  dense (Dense)               (None, 1)                 17
#
# =================================================================
# Total params: 92,881
# Trainable params: 92,881
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 7680/7680 [==============================] - 149s 19ms/step - loss: 0.4816 - root_mean_squared_error: 0.6940 - mean_absolute_error: 0.4272 - val_loss: 0.6135 - val_root_mean_squared_error: 0.7833 - val_mean_absolute_error: 0.4620
# Epoch 2/30
# 7680/7680 [==============================] - 134s 17ms/step - loss: 0.4484 - root_mean_squared_error: 0.6696 - mean_absolute_error: 0.4019 - val_loss: 0.6252 - val_root_mean_squared_error: 0.7907 - val_mean_absolute_error: 0.4553
# Epoch 3/30
# 7680/7680 [==============================] - 122s 16ms/step - loss: 0.4418 - root_mean_squared_error: 0.6647 - mean_absolute_error: 0.3963 - val_loss: 0.6362 - val_root_mean_squared_error: 0.7977 - val_mean_absolute_error: 0.4486
# Epoch 4/30
# 7680/7680 [==============================] - 127s 17ms/step - loss: 0.4369 - root_mean_squared_error: 0.6610 - mean_absolute_error: 0.3936 - val_loss: 0.6402 - val_root_mean_squared_error: 0.8002 - val_mean_absolute_error: 0.4601
# Epoch 5/30
# 7680/7680 [==============================] - 165s 21ms/step - loss: 0.4334 - root_mean_squared_error: 0.6583 - mean_absolute_error: 0.3911 - val_loss: 0.6338 - val_root_mean_squared_error: 0.7961 - val_mean_absolute_error: 0.4604
# Epoch 6/30
# 7680/7680 [==============================] - 141s 18ms/step - loss: 0.4310 - root_mean_squared_error: 0.6565 - mean_absolute_error: 0.3900 - val_loss: 0.6038 - val_root_mean_squared_error: 0.7771 - val_mean_absolute_error: 0.4676
# Epoch 7/30
# 7680/7680 [==============================] - 138s 18ms/step - loss: 0.4283 - root_mean_squared_error: 0.6544 - mean_absolute_error: 0.3879 - val_loss: 0.6395 - val_root_mean_squared_error: 0.7997 - val_mean_absolute_error: 0.4656
# Epoch 8/30
# 7680/7680 [==============================] - 135s 18ms/step - loss: 0.4264 - root_mean_squared_error: 0.6530 - mean_absolute_error: 0.3868 - val_loss: 0.6256 - val_root_mean_squared_error: 0.7910 - val_mean_absolute_error: 0.4426
# Epoch 9/30
# 7680/7680 [==============================] - 149s 19ms/step - loss: 0.4244 - root_mean_squared_error: 0.6514 - mean_absolute_error: 0.3851 - val_loss: 0.6378 - val_root_mean_squared_error: 0.7986 - val_mean_absolute_error: 0.4458
# Epoch 10/30
# 7680/7680 [==============================] - 147s 19ms/step - loss: 0.4212 - root_mean_squared_error: 0.6490 - mean_absolute_error: 0.3842 - val_loss: 0.6331 - val_root_mean_squared_error: 0.7957 - val_mean_absolute_error: 0.4660
# Epoch 11/30
# 7680/7680 [==============================] - 145s 19ms/step - loss: 0.4201 - root_mean_squared_error: 0.6481 - mean_absolute_error: 0.3835 - val_loss: 0.6191 - val_root_mean_squared_error: 0.7868 - val_mean_absolute_error: 0.4497
# Epoch 12/30
# 7680/7680 [==============================] - 155s 20ms/step - loss: 0.4186 - root_mean_squared_error: 0.6470 - mean_absolute_error: 0.3824 - val_loss: 0.6380 - val_root_mean_squared_error: 0.7988 - val_mean_absolute_error: 0.4603
# Epoch 13/30
# 7680/7680 [==============================] - 155s 20ms/step - loss: 0.4175 - root_mean_squared_error: 0.6461 - mean_absolute_error: 0.3822 - val_loss: 0.6480 - val_root_mean_squared_error: 0.8050 - val_mean_absolute_error: 0.4639
# Epoch 14/30
# 7680/7680 [==============================] - 148s 19ms/step - loss: 0.4152 - root_mean_squared_error: 0.6444 - mean_absolute_error: 0.3813 - val_loss: 0.6480 - val_root_mean_squared_error: 0.8050 - val_mean_absolute_error: 0.4504
# Epoch 15/30
# 7680/7680 [==============================] - 146s 19ms/step - loss: 0.4140 - root_mean_squared_error: 0.6435 - mean_absolute_error: 0.3812 - val_loss: 0.6241 - val_root_mean_squared_error: 0.7900 - val_mean_absolute_error: 0.4513
# Epoch 16/30
# 7680/7680 [==============================] - 146s 19ms/step - loss: 0.4125 - root_mean_squared_error: 0.6423 - mean_absolute_error: 0.3798 - val_loss: 0.6577 - val_root_mean_squared_error: 0.8110 - val_mean_absolute_error: 0.4652
# Epoch 17/30
# 7680/7680 [==============================] - 124s 16ms/step - loss: 0.4108 - root_mean_squared_error: 0.6409 - mean_absolute_error: 0.3797 - val_loss: 0.6517 - val_root_mean_squared_error: 0.8073 - val_mean_absolute_error: 0.4570
# Epoch 18/30
# 7680/7680 [==============================] - 123s 16ms/step - loss: 0.4100 - root_mean_squared_error: 0.6403 - mean_absolute_error: 0.3794 - val_loss: 0.6479 - val_root_mean_squared_error: 0.8049 - val_mean_absolute_error: 0.4572
# Epoch 19/30
# 7680/7680 [==============================] - 137s 18ms/step - loss: 0.4074 - root_mean_squared_error: 0.6383 - mean_absolute_error: 0.3781 - val_loss: 0.6565 - val_root_mean_squared_error: 0.8103 - val_mean_absolute_error: 0.4536
# Epoch 20/30
# 7680/7680 [==============================] - 144s 19ms/step - loss: 0.4070 - root_mean_squared_error: 0.6380 - mean_absolute_error: 0.3780 - val_loss: 0.6834 - val_root_mean_squared_error: 0.8267 - val_mean_absolute_error: 0.4782
# Epoch 21/30
# 7680/7680 [==============================] - 141s 18ms/step - loss: 0.4039 - root_mean_squared_error: 0.6355 - mean_absolute_error: 0.3777 - val_loss: 0.6565 - val_root_mean_squared_error: 0.8102 - val_mean_absolute_error: 0.4759
# Epoch 22/30
# 7680/7680 [==============================] - 134s 17ms/step - loss: 0.4026 - root_mean_squared_error: 0.6345 - mean_absolute_error: 0.3772 - val_loss: 0.7188 - val_root_mean_squared_error: 0.8478 - val_mean_absolute_error: 0.4640
# Epoch 23/30
# 7680/7680 [==============================] - 142s 18ms/step - loss: 0.4034 - root_mean_squared_error: 0.6351 - mean_absolute_error: 0.3772 - val_loss: 0.6531 - val_root_mean_squared_error: 0.8081 - val_mean_absolute_error: 0.4520
# Epoch 24/30
# 7680/7680 [==============================] - 144s 19ms/step - loss: 0.4004 - root_mean_squared_error: 0.6328 - mean_absolute_error: 0.3762 - val_loss: 0.6420 - val_root_mean_squared_error: 0.8013 - val_mean_absolute_error: 0.4625
# Epoch 25/30
# 7680/7680 [==============================] - 138s 18ms/step - loss: 0.3982 - root_mean_squared_error: 0.6311 - mean_absolute_error: 0.3759 - val_loss: 0.6449 - val_root_mean_squared_error: 0.8031 - val_mean_absolute_error: 0.4553
# Epoch 26/30
# 7680/7680 [==============================] - 138s 18ms/step - loss: 0.3967 - root_mean_squared_error: 0.6298 - mean_absolute_error: 0.3754 - val_loss: 0.6706 - val_root_mean_squared_error: 0.8189 - val_mean_absolute_error: 0.4616
# Epoch 27/30
# 7680/7680 [==============================] - 136s 18ms/step - loss: 0.3950 - root_mean_squared_error: 0.6285 - mean_absolute_error: 0.3748 - val_loss: 0.6778 - val_root_mean_squared_error: 0.8233 - val_mean_absolute_error: 0.4593
# Epoch 28/30
# 7680/7680 [==============================] - 122s 16ms/step - loss: 0.3929 - root_mean_squared_error: 0.6268 - mean_absolute_error: 0.3742 - val_loss: 0.6639 - val_root_mean_squared_error: 0.8148 - val_mean_absolute_error: 0.4579
# Epoch 29/30
# 7680/7680 [==============================] - 122s 16ms/step - loss: 0.5300 - root_mean_squared_error: 0.7280 - mean_absolute_error: 0.3908 - val_loss: 0.9046 - val_root_mean_squared_error: 0.9511 - val_mean_absolute_error: 0.4782
# Epoch 30/30
# 7680/7680 [==============================] - 122s 16ms/step - loss: 0.4923 - root_mean_squared_error: 0.7016 - mean_absolute_error: 0.3901 - val_loss: 1.0985 - val_root_mean_squared_error: 1.0481 - val_mean_absolute_error: 0.5013
# Training History for Cluster 0:

# %%
one_houses = list(clustered_df[clustered_df['Cluster'] == 1]['House'])
one_cluster = Cluster(one_houses)
one_cluster_results = one_cluster.results()
print('Training History for Cluster 1:')
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_3 (LSTM)               (None, 14, 128)           69120
#
#  lstm_4 (LSTM)               (None, 14, 32)            20608
#
#  lstm_5 (LSTM)               (None, 16)                3136
#
#  dense_1 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 92,881
# Trainable params: 92,881
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 915/915 [==============================] - 16s 15ms/step - loss: 1.5403 - root_mean_squared_error: 1.2411 - mean_absolute_error: 0.7416 - val_loss: 1.5630 - val_root_mean_squared_error: 1.2502 - val_mean_absolute_error: 0.6507
# Epoch 2/30
# 915/915 [==============================] - 14s 15ms/step - loss: 1.0000 - root_mean_squared_error: 1.0000 - mean_absolute_error: 0.5678 - val_loss: 1.4527 - val_root_mean_squared_error: 1.2053 - val_mean_absolute_error: 0.5365
# Epoch 3/30
# 915/915 [==============================] - 14s 15ms/step - loss: 0.9166 - root_mean_squared_error: 0.9574 - mean_absolute_error: 0.5398 - val_loss: 1.3529 - val_root_mean_squared_error: 1.1631 - val_mean_absolute_error: 0.5965
# Epoch 4/30
# 915/915 [==============================] - 14s 15ms/step - loss: 0.8768 - root_mean_squared_error: 0.9364 - mean_absolute_error: 0.5329 - val_loss: 1.3742 - val_root_mean_squared_error: 1.1723 - val_mean_absolute_error: 0.5952
# Epoch 5/30
# 915/915 [==============================] - 14s 15ms/step - loss: 0.8395 - root_mean_squared_error: 0.9162 - mean_absolute_error: 0.5185 - val_loss: 1.5684 - val_root_mean_squared_error: 1.2524 - val_mean_absolute_error: 0.6027
# Epoch 6/30
# 915/915 [==============================] - 14s 15ms/step - loss: 0.8359 - root_mean_squared_error: 0.9143 - mean_absolute_error: 0.5104 - val_loss: 1.2309 - val_root_mean_squared_error: 1.1095 - val_mean_absolute_error: 0.5677
# Epoch 7/30
# 915/915 [==============================] - 14s 15ms/step - loss: 0.8296 - root_mean_squared_error: 0.9108 - mean_absolute_error: 0.5088 - val_loss: 1.3062 - val_root_mean_squared_error: 1.1429 - val_mean_absolute_error: 0.6138
# Epoch 8/30
# 915/915 [==============================] - 14s 15ms/step - loss: 0.7983 - root_mean_squared_error: 0.8935 - mean_absolute_error: 0.5027 - val_loss: 1.1665 - val_root_mean_squared_error: 1.0800 - val_mean_absolute_error: 0.4959
# Epoch 9/30
# 915/915 [==============================] - 14s 15ms/step - loss: 0.8004 - root_mean_squared_error: 0.8946 - mean_absolute_error: 0.4982 - val_loss: 1.2549 - val_root_mean_squared_error: 1.1202 - val_mean_absolute_error: 0.5796
# Epoch 10/30
# 915/915 [==============================] - 14s 15ms/step - loss: 0.7899 - root_mean_squared_error: 0.8888 - mean_absolute_error: 0.4971 - val_loss: 1.2373 - val_root_mean_squared_error: 1.1123 - val_mean_absolute_error: 0.5062
# Epoch 11/30
# 915/915 [==============================] - 14s 15ms/step - loss: 0.7734 - root_mean_squared_error: 0.8794 - mean_absolute_error: 0.4958 - val_loss: 1.3807 - val_root_mean_squared_error: 1.1750 - val_mean_absolute_error: 0.5287
# Epoch 12/30
# 915/915 [==============================] - 14s 15ms/step - loss: 0.7717 - root_mean_squared_error: 0.8785 - mean_absolute_error: 0.4927 - val_loss: 1.2552 - val_root_mean_squared_error: 1.1204 - val_mean_absolute_error: 0.5334
# Epoch 13/30
# 915/915 [==============================] - 14s 15ms/step - loss: 0.7547 - root_mean_squared_error: 0.8687 - mean_absolute_error: 0.4862 - val_loss: 1.1744 - val_root_mean_squared_error: 1.0837 - val_mean_absolute_error: 0.5366
# Epoch 14/30
# 915/915 [==============================] - 14s 15ms/step - loss: 0.7597 - root_mean_squared_error: 0.8716 - mean_absolute_error: 0.4894 - val_loss: 2.1088 - val_root_mean_squared_error: 1.4522 - val_mean_absolute_error: 0.5766
# Epoch 15/30
# 915/915 [==============================] - 14s 15ms/step - loss: 0.7498 - root_mean_squared_error: 0.8659 - mean_absolute_error: 0.4897 - val_loss: 1.0791 - val_root_mean_squared_error: 1.0388 - val_mean_absolute_error: 0.4823
# Epoch 16/30
# 915/915 [==============================] - 14s 15ms/step - loss: 0.7399 - root_mean_squared_error: 0.8602 - mean_absolute_error: 0.4836 - val_loss: 1.2297 - val_root_mean_squared_error: 1.1089 - val_mean_absolute_error: 0.5019
# Epoch 17/30
# 915/915 [==============================] - 14s 15ms/step - loss: 0.7371 - root_mean_squared_error: 0.8585 - mean_absolute_error: 0.4818 - val_loss: 1.5727 - val_root_mean_squared_error: 1.2541 - val_mean_absolute_error: 0.5697
# Epoch 18/30
# 915/915 [==============================] - 14s 15ms/step - loss: 0.7481 - root_mean_squared_error: 0.8649 - mean_absolute_error: 0.4824 - val_loss: 1.0986 - val_root_mean_squared_error: 1.0481 - val_mean_absolute_error: 0.5377
# Epoch 19/30
# 915/915 [==============================] - 14s 15ms/step - loss: 0.7191 - root_mean_squared_error: 0.8480 - mean_absolute_error: 0.4755 - val_loss: 1.1623 - val_root_mean_squared_error: 1.0781 - val_mean_absolute_error: 0.5332
# Epoch 20/30
# 915/915 [==============================] - 14s 15ms/step - loss: 0.7052 - root_mean_squared_error: 0.8398 - mean_absolute_error: 0.4737 - val_loss: 1.0792 - val_root_mean_squared_error: 1.0389 - val_mean_absolute_error: 0.5553
# Epoch 21/30
# 915/915 [==============================] - 14s 15ms/step - loss: 0.7106 - root_mean_squared_error: 0.8430 - mean_absolute_error: 0.4767 - val_loss: 1.2835 - val_root_mean_squared_error: 1.1329 - val_mean_absolute_error: 0.5045
# Epoch 22/30
# 915/915 [==============================] - 14s 15ms/step - loss: 0.6958 - root_mean_squared_error: 0.8341 - mean_absolute_error: 0.4720 - val_loss: 1.1404 - val_root_mean_squared_error: 1.0679 - val_mean_absolute_error: 0.5192
# Epoch 23/30
# 915/915 [==============================] - 14s 15ms/step - loss: 0.7032 - root_mean_squared_error: 0.8386 - mean_absolute_error: 0.4714 - val_loss: 1.1204 - val_root_mean_squared_error: 1.0585 - val_mean_absolute_error: 0.5058
# Epoch 24/30
# 915/915 [==============================] - 14s 15ms/step - loss: 0.6880 - root_mean_squared_error: 0.8295 - mean_absolute_error: 0.4718 - val_loss: 1.1604 - val_root_mean_squared_error: 1.0772 - val_mean_absolute_error: 0.5374
# Epoch 25/30
# 915/915 [==============================] - 14s 15ms/step - loss: 0.6862 - root_mean_squared_error: 0.8284 - mean_absolute_error: 0.4701 - val_loss: 1.0677 - val_root_mean_squared_error: 1.0333 - val_mean_absolute_error: 0.5155
# Epoch 26/30
# 915/915 [==============================] - 14s 15ms/step - loss: 0.6856 - root_mean_squared_error: 0.8280 - mean_absolute_error: 0.4692 - val_loss: 1.4760 - val_root_mean_squared_error: 1.2149 - val_mean_absolute_error: 0.5832
# Epoch 27/30
# 915/915 [==============================] - 14s 15ms/step - loss: 0.6809 - root_mean_squared_error: 0.8251 - mean_absolute_error: 0.4679 - val_loss: 1.0574 - val_root_mean_squared_error: 1.0283 - val_mean_absolute_error: 0.5056
# Epoch 28/30
# 915/915 [==============================] - 14s 15ms/step - loss: 0.7000 - root_mean_squared_error: 0.8367 - mean_absolute_error: 0.4725 - val_loss: 1.0943 - val_root_mean_squared_error: 1.0461 - val_mean_absolute_error: 0.5072
# Epoch 29/30
# 915/915 [==============================] - 14s 15ms/step - loss: 0.6734 - root_mean_squared_error: 0.8206 - mean_absolute_error: 0.4643 - val_loss: 1.0371 - val_root_mean_squared_error: 1.0184 - val_mean_absolute_error: 0.5025
# Epoch 30/30
# 915/915 [==============================] - 14s 15ms/step - loss: 0.6600 - root_mean_squared_error: 0.8124 - mean_absolute_error: 0.4613 - val_loss: 1.0467 - val_root_mean_squared_error: 1.0231 - val_mean_absolute_error: 0.4971
# Training History for Cluster 1:

# %%
two_houses = list(clustered_df[clustered_df['Cluster'] == 2]['House'])
two_cluster = Cluster(two_houses)
two_cluster_results = two_cluster.results()
print('Training History for Cluster 2:')
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_6 (LSTM)               (None, 14, 128)           69120
#
#  lstm_7 (LSTM)               (None, 14, 32)            20608
#
#  lstm_8 (LSTM)               (None, 16)                3136
#
#  dense_2 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 92,881
# Trainable params: 92,881
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 2022-01-18 16:34:23.363605: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 81682272 exceeds 10% of free system memory.
# 15194/15194 [==============================] - 229s 15ms/step - loss: 0.1515 - root_mean_squared_error: 0.3892 - mean_absolute_error: 0.2199 - val_loss: 0.2052 - val_root_mean_squared_error: 0.4530 - val_mean_absolute_error: 0.2711
# Epoch 2/30
# 15194/15194 [==============================] - 227s 15ms/step - loss: 0.1453 - root_mean_squared_error: 0.3812 - mean_absolute_error: 0.2111 - val_loss: 0.2031 - val_root_mean_squared_error: 0.4506 - val_mean_absolute_error: 0.2495
# Epoch 3/30
# 15194/15194 [==============================] - 278s 18ms/step - loss: 0.1440 - root_mean_squared_error: 0.3795 - mean_absolute_error: 0.2090 - val_loss: 0.2096 - val_root_mean_squared_error: 0.4578 - val_mean_absolute_error: 0.2406
# Epoch 4/30
# 15194/15194 [==============================] - 340s 22ms/step - loss: 0.1430 - root_mean_squared_error: 0.3781 - mean_absolute_error: 0.2080 - val_loss: 0.2028 - val_root_mean_squared_error: 0.4504 - val_mean_absolute_error: 0.2499
# Epoch 5/30
# 15194/15194 [==============================] - 311s 20ms/step - loss: 0.1422 - root_mean_squared_error: 0.3770 - mean_absolute_error: 0.2072 - val_loss: 0.2055 - val_root_mean_squared_error: 0.4533 - val_mean_absolute_error: 0.2480
# Epoch 6/30
# 15194/15194 [==============================] - 256s 17ms/step - loss: 0.1418 - root_mean_squared_error: 0.3765 - mean_absolute_error: 0.2065 - val_loss: 0.2022 - val_root_mean_squared_error: 0.4496 - val_mean_absolute_error: 0.2473
# Epoch 7/30
# 15194/15194 [==============================] - 276s 18ms/step - loss: 0.1411 - root_mean_squared_error: 0.3756 - mean_absolute_error: 0.2060 - val_loss: 0.2019 - val_root_mean_squared_error: 0.4493 - val_mean_absolute_error: 0.2548
# Epoch 8/30
# 15194/15194 [==============================] - 282s 19ms/step - loss: 0.1406 - root_mean_squared_error: 0.3750 - mean_absolute_error: 0.2056 - val_loss: 0.2044 - val_root_mean_squared_error: 0.4521 - val_mean_absolute_error: 0.2518
# Epoch 9/30
# 15194/15194 [==============================] - 276s 18ms/step - loss: 0.1404 - root_mean_squared_error: 0.3747 - mean_absolute_error: 0.2054 - val_loss: 0.2038 - val_root_mean_squared_error: 0.4514 - val_mean_absolute_error: 0.2443
# Epoch 10/30
# 15194/15194 [==============================] - 253s 17ms/step - loss: 0.1401 - root_mean_squared_error: 0.3743 - mean_absolute_error: 0.2051 - val_loss: 0.2023 - val_root_mean_squared_error: 0.4498 - val_mean_absolute_error: 0.2520
# Epoch 11/30
# 15194/15194 [==============================] - 260s 17ms/step - loss: 0.1397 - root_mean_squared_error: 0.3737 - mean_absolute_error: 0.2048 - val_loss: 0.2044 - val_root_mean_squared_error: 0.4521 - val_mean_absolute_error: 0.2457
# Epoch 12/30
# 15194/15194 [==============================] - 348s 23ms/step - loss: 0.1393 - root_mean_squared_error: 0.3733 - mean_absolute_error: 0.2044 - val_loss: 0.2030 - val_root_mean_squared_error: 0.4506 - val_mean_absolute_error: 0.2540
# Epoch 13/30
# 15194/15194 [==============================] - 303s 20ms/step - loss: 0.1390 - root_mean_squared_error: 0.3728 - mean_absolute_error: 0.2043 - val_loss: 0.2058 - val_root_mean_squared_error: 0.4536 - val_mean_absolute_error: 0.2441
# Epoch 14/30
# 15194/15194 [==============================] - 314s 21ms/step - loss: 0.1387 - root_mean_squared_error: 0.3724 - mean_absolute_error: 0.2040 - val_loss: 0.2035 - val_root_mean_squared_error: 0.4511 - val_mean_absolute_error: 0.2519
# Epoch 15/30
# 15194/15194 [==============================] - 311s 20ms/step - loss: 0.1384 - root_mean_squared_error: 0.3720 - mean_absolute_error: 0.2038 - val_loss: 0.2051 - val_root_mean_squared_error: 0.4528 - val_mean_absolute_error: 0.2512
# Epoch 16/30
# 15194/15194 [==============================] - 334s 22ms/step - loss: 0.1380 - root_mean_squared_error: 0.3714 - mean_absolute_error: 0.2034 - val_loss: 0.2055 - val_root_mean_squared_error: 0.4533 - val_mean_absolute_error: 0.2468
# Epoch 17/30
# 15194/15194 [==============================] - 291s 19ms/step - loss: 0.1378 - root_mean_squared_error: 0.3713 - mean_absolute_error: 0.2034 - val_loss: 0.2036 - val_root_mean_squared_error: 0.4512 - val_mean_absolute_error: 0.2456
# Epoch 18/30
# 15194/15194 [==============================] - 287s 19ms/step - loss: 0.1375 - root_mean_squared_error: 0.3708 - mean_absolute_error: 0.2032 - val_loss: 0.2039 - val_root_mean_squared_error: 0.4516 - val_mean_absolute_error: 0.2499
# Epoch 19/30
# 15194/15194 [==============================] - 329s 22ms/step - loss: 0.1371 - root_mean_squared_error: 0.3703 - mean_absolute_error: 0.2030 - val_loss: 0.2060 - val_root_mean_squared_error: 0.4538 - val_mean_absolute_error: 0.2474
# Epoch 20/30
# 15194/15194 [==============================] - 319s 21ms/step - loss: 0.1365 - root_mean_squared_error: 0.3695 - mean_absolute_error: 0.2027 - val_loss: 0.2047 - val_root_mean_squared_error: 0.4524 - val_mean_absolute_error: 0.2486
# Epoch 21/30
# 15194/15194 [==============================] - 295s 19ms/step - loss: 0.1363 - root_mean_squared_error: 0.3692 - mean_absolute_error: 0.2024 - val_loss: 0.2058 - val_root_mean_squared_error: 0.4536 - val_mean_absolute_error: 0.2577
# Epoch 22/30
# 15194/15194 [==============================] - 252s 17ms/step - loss: 0.1359 - root_mean_squared_error: 0.3687 - mean_absolute_error: 0.2021 - val_loss: 0.2063 - val_root_mean_squared_error: 0.4542 - val_mean_absolute_error: 0.2477
# Epoch 23/30
# 15194/15194 [==============================] - 293s 19ms/step - loss: 0.1452 - root_mean_squared_error: 0.3810 - mean_absolute_error: 0.2063 - val_loss: 0.2081 - val_root_mean_squared_error: 0.4562 - val_mean_absolute_error: 0.2493
# Epoch 24/30
# 15194/15194 [==============================] - 297s 20ms/step - loss: 0.7112 - root_mean_squared_error: 0.8433 - mean_absolute_error: 0.2139 - val_loss: 0.2060 - val_root_mean_squared_error: 0.4538 - val_mean_absolute_error: 0.2486
# Epoch 25/30
# 15194/15194 [==============================] - 288s 19ms/step - loss: 0.1382 - root_mean_squared_error: 0.3718 - mean_absolute_error: 0.2039 - val_loss: 0.2053 - val_root_mean_squared_error: 0.4531 - val_mean_absolute_error: 0.2543
# Epoch 26/30
# 15194/15194 [==============================] - 289s 19ms/step - loss: 0.1369 - root_mean_squared_error: 0.3700 - mean_absolute_error: 0.2030 - val_loss: 0.2043 - val_root_mean_squared_error: 0.4520 - val_mean_absolute_error: 0.2477
# Epoch 27/30
# 15194/15194 [==============================] - 291s 19ms/step - loss: 0.1362 - root_mean_squared_error: 0.3691 - mean_absolute_error: 0.2024 - val_loss: 0.2052 - val_root_mean_squared_error: 0.4529 - val_mean_absolute_error: 0.2503
# Epoch 28/30
# 15194/15194 [==============================] - 290s 19ms/step - loss: 0.1355 - root_mean_squared_error: 0.3681 - mean_absolute_error: 0.2020 - val_loss: 0.2058 - val_root_mean_squared_error: 0.4537 - val_mean_absolute_error: 0.2443
# Epoch 29/30
# 15194/15194 [==============================] - 292s 19ms/step - loss: 0.1349 - root_mean_squared_error: 0.3673 - mean_absolute_error: 0.2015 - val_loss: 0.2062 - val_root_mean_squared_error: 0.4541 - val_mean_absolute_error: 0.2488
# Epoch 30/30
# 15194/15194 [==============================] - 294s 19ms/step - loss: 0.1618 - root_mean_squared_error: 0.4022 - mean_absolute_error: 0.2065 - val_loss: 0.5389 - val_root_mean_squared_error: 0.7341 - val_mean_absolute_error: 0.2657
# Training History for Cluster 2:

# %%
three_houses = list(clustered_df[clustered_df['Cluster'] == 3]['House'])
three_cluster = Cluster(three_houses)
three_cluster_results = three_cluster.results()
print('Training History for Cluster 3:')
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_9 (LSTM)               (None, 14, 128)           69120
#
#  lstm_10 (LSTM)              (None, 14, 32)            20608
#
#  lstm_11 (LSTM)              (None, 16)                3136
#
#  dense_3 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 92,881
# Trainable params: 92,881
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 2745/2745 [==============================] - 53s 18ms/step - loss: 0.4062 - root_mean_squared_error: 0.6374 - mean_absolute_error: 0.4209 - val_loss: 0.4278 - val_root_mean_squared_error: 0.6541 - val_mean_absolute_error: 0.4029
# Epoch 2/30
# 2745/2745 [==============================] - 50s 18ms/step - loss: 0.3598 - root_mean_squared_error: 0.5998 - mean_absolute_error: 0.3817 - val_loss: 0.4046 - val_root_mean_squared_error: 0.6361 - val_mean_absolute_error: 0.4001
# Epoch 3/30
# 2745/2745 [==============================] - 50s 18ms/step - loss: 0.3500 - root_mean_squared_error: 0.5916 - mean_absolute_error: 0.3734 - val_loss: 0.4028 - val_root_mean_squared_error: 0.6346 - val_mean_absolute_error: 0.4024
# Epoch 4/30
# 2745/2745 [==============================] - 51s 19ms/step - loss: 0.3409 - root_mean_squared_error: 0.5839 - mean_absolute_error: 0.3654 - val_loss: 0.3951 - val_root_mean_squared_error: 0.6286 - val_mean_absolute_error: 0.3974
# Epoch 5/30
# 2745/2745 [==============================] - 50s 18ms/step - loss: 0.3341 - root_mean_squared_error: 0.5780 - mean_absolute_error: 0.3594 - val_loss: 0.3905 - val_root_mean_squared_error: 0.6249 - val_mean_absolute_error: 0.4061
# Epoch 6/30
# 2745/2745 [==============================] - 50s 18ms/step - loss: 0.3294 - root_mean_squared_error: 0.5739 - mean_absolute_error: 0.3562 - val_loss: 0.4239 - val_root_mean_squared_error: 0.6511 - val_mean_absolute_error: 0.4076
# Epoch 7/30
# 2745/2745 [==============================] - 50s 18ms/step - loss: 0.3276 - root_mean_squared_error: 0.5724 - mean_absolute_error: 0.3537 - val_loss: 0.3819 - val_root_mean_squared_error: 0.6180 - val_mean_absolute_error: 0.3799
# Epoch 8/30
# 2745/2745 [==============================] - 50s 18ms/step - loss: 0.3253 - root_mean_squared_error: 0.5704 - mean_absolute_error: 0.3526 - val_loss: 0.4008 - val_root_mean_squared_error: 0.6331 - val_mean_absolute_error: 0.3944
# Epoch 9/30
# 2745/2745 [==============================] - 50s 18ms/step - loss: 0.3222 - root_mean_squared_error: 0.5677 - mean_absolute_error: 0.3499 - val_loss: 0.3950 - val_root_mean_squared_error: 0.6285 - val_mean_absolute_error: 0.3767
# Epoch 10/30
# 2745/2745 [==============================] - 50s 18ms/step - loss: 0.3201 - root_mean_squared_error: 0.5658 - mean_absolute_error: 0.3483 - val_loss: 0.3971 - val_root_mean_squared_error: 0.6302 - val_mean_absolute_error: 0.3761
# Epoch 11/30
# 2745/2745 [==============================] - 50s 18ms/step - loss: 0.3183 - root_mean_squared_error: 0.5642 - mean_absolute_error: 0.3468 - val_loss: 0.3982 - val_root_mean_squared_error: 0.6310 - val_mean_absolute_error: 0.3782
# Epoch 12/30
# 2745/2745 [==============================] - 50s 18ms/step - loss: 0.3153 - root_mean_squared_error: 0.5615 - mean_absolute_error: 0.3446 - val_loss: 0.4126 - val_root_mean_squared_error: 0.6423 - val_mean_absolute_error: 0.3838
# Epoch 13/30
# 2745/2745 [==============================] - 50s 18ms/step - loss: 0.3145 - root_mean_squared_error: 0.5608 - mean_absolute_error: 0.3435 - val_loss: 0.3840 - val_root_mean_squared_error: 0.6197 - val_mean_absolute_error: 0.3847
# Epoch 14/30
# 2745/2745 [==============================] - 50s 18ms/step - loss: 0.3124 - root_mean_squared_error: 0.5589 - mean_absolute_error: 0.3426 - val_loss: 0.3921 - val_root_mean_squared_error: 0.6262 - val_mean_absolute_error: 0.3729
# Epoch 15/30
# 2745/2745 [==============================] - 50s 18ms/step - loss: 0.3106 - root_mean_squared_error: 0.5573 - mean_absolute_error: 0.3414 - val_loss: 0.4046 - val_root_mean_squared_error: 0.6361 - val_mean_absolute_error: 0.3937
# Epoch 16/30
# 2745/2745 [==============================] - 50s 18ms/step - loss: 0.3089 - root_mean_squared_error: 0.5558 - mean_absolute_error: 0.3398 - val_loss: 0.4048 - val_root_mean_squared_error: 0.6363 - val_mean_absolute_error: 0.3706
# Epoch 17/30
# 2745/2745 [==============================] - 50s 18ms/step - loss: 0.3071 - root_mean_squared_error: 0.5542 - mean_absolute_error: 0.3382 - val_loss: 0.4063 - val_root_mean_squared_error: 0.6375 - val_mean_absolute_error: 0.3766
# Epoch 18/30
# 2745/2745 [==============================] - 50s 18ms/step - loss: 0.3061 - root_mean_squared_error: 0.5532 - mean_absolute_error: 0.3379 - val_loss: 0.4114 - val_root_mean_squared_error: 0.6414 - val_mean_absolute_error: 0.3721
# Epoch 19/30
# 2745/2745 [==============================] - 50s 18ms/step - loss: 0.3038 - root_mean_squared_error: 0.5512 - mean_absolute_error: 0.3361 - val_loss: 0.4030 - val_root_mean_squared_error: 0.6348 - val_mean_absolute_error: 0.3961
# Epoch 20/30
# 2745/2745 [==============================] - 50s 18ms/step - loss: 0.3007 - root_mean_squared_error: 0.5483 - mean_absolute_error: 0.3351 - val_loss: 0.4159 - val_root_mean_squared_error: 0.6449 - val_mean_absolute_error: 0.3843
# Epoch 21/30
# 2745/2745 [==============================] - 51s 19ms/step - loss: 0.2993 - root_mean_squared_error: 0.5471 - mean_absolute_error: 0.3338 - val_loss: 0.4083 - val_root_mean_squared_error: 0.6389 - val_mean_absolute_error: 0.3982
# Epoch 22/30
# 2745/2745 [==============================] - 52s 19ms/step - loss: 0.2970 - root_mean_squared_error: 0.5450 - mean_absolute_error: 0.3324 - val_loss: 0.3996 - val_root_mean_squared_error: 0.6321 - val_mean_absolute_error: 0.3878
# Epoch 23/30
# 2745/2745 [==============================] - 49s 18ms/step - loss: 0.2957 - root_mean_squared_error: 0.5438 - mean_absolute_error: 0.3315 - val_loss: 0.4032 - val_root_mean_squared_error: 0.6350 - val_mean_absolute_error: 0.3860
# Epoch 24/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.2938 - root_mean_squared_error: 0.5421 - mean_absolute_error: 0.3311 - val_loss: 0.4121 - val_root_mean_squared_error: 0.6420 - val_mean_absolute_error: 0.3874
# Epoch 25/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.2923 - root_mean_squared_error: 0.5406 - mean_absolute_error: 0.3301 - val_loss: 0.4192 - val_root_mean_squared_error: 0.6474 - val_mean_absolute_error: 0.3806
# Epoch 26/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.2897 - root_mean_squared_error: 0.5383 - mean_absolute_error: 0.3277 - val_loss: 0.3942 - val_root_mean_squared_error: 0.6279 - val_mean_absolute_error: 0.3868
# Epoch 27/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.2869 - root_mean_squared_error: 0.5356 - mean_absolute_error: 0.3261 - val_loss: 0.4043 - val_root_mean_squared_error: 0.6359 - val_mean_absolute_error: 0.3839
# Epoch 28/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.2850 - root_mean_squared_error: 0.5338 - mean_absolute_error: 0.3256 - val_loss: 0.4049 - val_root_mean_squared_error: 0.6363 - val_mean_absolute_error: 0.3946
# Epoch 29/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.2822 - root_mean_squared_error: 0.5312 - mean_absolute_error: 0.3236 - val_loss: 0.4174 - val_root_mean_squared_error: 0.6461 - val_mean_absolute_error: 0.3892
# Epoch 30/30
# 2745/2745 [==============================] - 43s 16ms/step - loss: 0.2806 - root_mean_squared_error: 0.5298 - mean_absolute_error: 0.3223 - val_loss: 0.4191 - val_root_mean_squared_error: 0.6474 - val_mean_absolute_error: 0.3948
# Training History for Cluster 3:

# %%
### Save Scenario 1 models
# zero_cluster.model.save('Models/Scenario1/zero_cluster')
# one_cluster.model.save('Models/Scenario1/one_cluster')
# two_cluster.model.save('Models/Scenario1/two_cluster')
# three_cluster.model.save('Models/Scenario1/three_cluster')

### Pickling cluster and cluster results
# zero_cluster_file = open("Models/Scenario1/Objects/zero_cluster.pickle", "wb")
# pickle.dump(zero_cluster, zero_cluster_file)
# zero_cluster_file.close()

# one_cluster_file = open("Models/Scenario1/Objects/one_cluster.pickle", "wb")
# pickle.dump(one_cluster, one_cluster_file)
# one_cluster_file.close()

# two_cluster_file = open("Models/Scenario1/Objects/two_cluster.pickle", "wb")
# pickle.dump(two_cluster, two_cluster_file)
# two_cluster_file.close()

# three_cluster_file = open("Models/Scenario1/Objects/three_cluster.pickle", "wb")
# pickle.dump(three_cluster, three_cluster_file)
# three_cluster_file.close()

# zero_cluster_results_file = open("Models/Scenario1/Objects/zero_cluster_results.pickle", "wb")
# pickle.dump(zero_cluster_results, zero_cluster_results_file)
# zero_cluster_results_file.close()

# one_cluster_results_file = open("Models/Scenario1/Objects/one_cluster_results.pickle", "wb")
# pickle.dump(one_cluster_results, one_cluster_results_file)
# one_cluster_results_file.close()

# two_cluster_results_file = open("Models/Scenario1/Objects/two_cluster_results.pickle", "wb")
# pickle.dump(two_cluster_results, two_cluster_results_file)
# two_cluster_results_file.close()

# three_cluster_results_file = open("Models/Scenario1/Objects/three_cluster_results.pickle", "wb")
# pickle.dump(three_cluster_results, three_cluster_results_file)
# three_cluster_results_file.close()

# %% [markdown]
# #### Scenario 2

# %%
all_houses = list(clustered_df['House'])
all_cluster = Cluster(all_houses)
all_cluster_results = all_cluster.results()
print('Training History without clustering:')
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_12 (LSTM)              (None, 14, 128)           69120
#
#  lstm_13 (LSTM)              (None, 14, 32)            20608
#
#  lstm_14 (LSTM)              (None, 16)                3136
#
#  dense_4 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 92,881
# Trainable params: 92,881
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 2022-01-18 19:25:05.928030: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 142643088 exceeds 10% of free system memory.
# 26534/26534 [==============================] - 416s 16ms/step - loss: 0.3337 - root_mean_squared_error: 0.5777 - mean_absolute_error: 0.3164 - val_loss: 0.3208 - val_root_mean_squared_error: 0.5664 - val_mean_absolute_error: 0.3106
# Epoch 2/30
# 26534/26534 [==============================] - 428s 16ms/step - loss: 0.3114 - root_mean_squared_error: 0.5580 - mean_absolute_error: 0.3015 - val_loss: 0.3244 - val_root_mean_squared_error: 0.5696 - val_mean_absolute_error: 0.3255
# Epoch 3/30
# 26534/26534 [==============================] - 423s 16ms/step - loss: 0.3059 - root_mean_squared_error: 0.5531 - mean_absolute_error: 0.2990 - val_loss: 0.3403 - val_root_mean_squared_error: 0.5833 - val_mean_absolute_error: 0.3126
# Epoch 4/30
# 26534/26534 [==============================] - 420s 16ms/step - loss: 0.3019 - root_mean_squared_error: 0.5495 - mean_absolute_error: 0.2973 - val_loss: 0.3569 - val_root_mean_squared_error: 0.5974 - val_mean_absolute_error: 0.3313
# Epoch 5/30
# 26534/26534 [==============================] - 466s 18ms/step - loss: 0.3003 - root_mean_squared_error: 0.5480 - mean_absolute_error: 0.2965 - val_loss: 0.3517 - val_root_mean_squared_error: 0.5931 - val_mean_absolute_error: 0.3160
# Epoch 6/30
# 26534/26534 [==============================] - 416s 16ms/step - loss: 0.2992 - root_mean_squared_error: 0.5470 - mean_absolute_error: 0.2956 - val_loss: 0.3476 - val_root_mean_squared_error: 0.5896 - val_mean_absolute_error: 0.3319
# Epoch 7/30
# 26534/26534 [==============================] - 438s 17ms/step - loss: 0.2960 - root_mean_squared_error: 0.5441 - mean_absolute_error: 0.2947 - val_loss: 0.3486 - val_root_mean_squared_error: 0.5904 - val_mean_absolute_error: 0.3189
# Epoch 8/30
# 26534/26534 [==============================] - 443s 17ms/step - loss: 0.2946 - root_mean_squared_error: 0.5427 - mean_absolute_error: 0.2942 - val_loss: 0.3444 - val_root_mean_squared_error: 0.5869 - val_mean_absolute_error: 0.3207
# Epoch 9/30
# 26534/26534 [==============================] - 448s 17ms/step - loss: 0.2943 - root_mean_squared_error: 0.5425 - mean_absolute_error: 0.2939 - val_loss: 0.3428 - val_root_mean_squared_error: 0.5855 - val_mean_absolute_error: 0.3101
# Epoch 10/30
# 26534/26534 [==============================] - 558s 21ms/step - loss: 0.2931 - root_mean_squared_error: 0.5414 - mean_absolute_error: 0.2936 - val_loss: 0.3563 - val_root_mean_squared_error: 0.5969 - val_mean_absolute_error: 0.3253
# Epoch 11/30
# 26534/26534 [==============================] - 418s 16ms/step - loss: 0.2922 - root_mean_squared_error: 0.5405 - mean_absolute_error: 0.2930 - val_loss: 0.3538 - val_root_mean_squared_error: 0.5948 - val_mean_absolute_error: 0.3423
# Epoch 12/30
# 26534/26534 [==============================] - 418s 16ms/step - loss: 0.2920 - root_mean_squared_error: 0.5404 - mean_absolute_error: 0.2924 - val_loss: 0.3509 - val_root_mean_squared_error: 0.5923 - val_mean_absolute_error: 0.3188
# Epoch 13/30
# 26534/26534 [==============================] - 420s 16ms/step - loss: 0.2908 - root_mean_squared_error: 0.5392 - mean_absolute_error: 0.2921 - val_loss: 0.3388 - val_root_mean_squared_error: 0.5821 - val_mean_absolute_error: 0.3193
# Epoch 14/30
#  6431/26534 [======>.......................] - ETA: 5:14 - loss: 0.2900 - root_mean_squared_error: 0.5385 - mean_absolute_error: 0.2900

# %%
# ### Save Scenario 2 models
# all_cluster.model.save('Models/Scenario2/all_cluster')

### Pickling Scenario 2 cluster and cluster result files
# all_cluster_file = open("Models/Scenario2/Objects/all_cluster.pickle", "wb")
# pickle.dump(all_cluster, all_cluster_file)
# all_cluster_file.close()

# all_cluster_results_file = open("Models/Scenario2/Objects/all_cluster_results.pickle", "wb")
# pickle.dump(all_cluster_results, all_cluster_results_file)
# all_cluster_results_file.close()

# %% [markdown]
# #### Predictions Graph functions

# %%
def x_axis_label_format(label):
    """
    Convert time label to the format of pandas line plot
    """
    label = pd.Timestamp(label)
    month = label.month_name()[:3]
    #if month == 'Jan':
    month += f'\n{label.year}'
    return month

def graph_predictions(cluster_specific_results, all_results):
    first_house = list(cluster_specific_results.keys())[0]
    df1 = cluster_specific_results[first_house][['timestamp','energy_predicted', 'energy_kWh']]
    df1['timestamp'] = pd.to_datetime(df1['timestamp'])
    df1 = df1.set_index('timestamp')
    df1['energy_predicted_without_clustering']= np.array(all_results[first_house][['energy_predicted']])
    df1.rename({'energy_predicted':'energy_predicted_with_clustering', 'energy_kWh':'real_energy'},axis = 1, inplace = True)
    ax = df1[::300].plot.line(figsize=(20,10))
    #ax.set_xticklabels(map(x_axis_label_format, df1[::int(len(df1)/8)+1].index))
    #import matplotlib.dates as mdates
    #myFmt = mdates.DateFormatter('%Y-%m')
    #ax.xaxis.set_major_formatter(myFmt)
    ax.set_title(f'Predictions for house {first_house}')

# %% [markdown]
# #### Predictions for Scenario 1 and Scenario 2

# %%
graph_predictions(zero_cluster_results, all_cluster_results)
#df1 = zero_cluster_results[1][['timestamp','energy_predicted', 'energy_kWh']].set_index('timestamp')
#df1['energy_predicted_without_clustering']= np.array(all_cluster_results[1][['energy_predicted']])

# %%
graph_predictions(one_cluster_results, all_cluster_results)

# %%
graph_predictions(two_cluster_results, all_cluster_results)

# %%
graph_predictions(three_cluster_results, all_cluster_results)

# %% [markdown]
# ### Function to create tables

# %%
def create_metrics(scenario_results, val=False):
    if val == False:
        rmse = 'root_mean_squared_error'
        mae = 'mean_absolute_error'
    else:
        rmse = 'val_root_mean_squared_error'
        mae = 'val_mean_absolute_error'
    scenario_rmse = list(map(lambda x: x.history.history[rmse],scenario_results))
    scenario_mae = list(map(lambda x: x.history.history[mae],scenario_results))
    scenario_rmse = np.array(scenario_rmse).reshape(-1,)
    scenario_mae = np.array(scenario_mae).reshape(-1,)
    return [np.min(scenario_rmse),np.max(scenario_rmse),np.mean(scenario_rmse),np.min(scenario_mae),np.max(scenario_mae),np.mean(scenario_mae)]

# %% [markdown]
# #### Scenario 1 and Scenario 2 Metric Tables

# %%
scenario_1_results = [zero_cluster, one_cluster, two_cluster, three_cluster]
scenario_1_metrics = create_metrics(scenario_1_results)
scenario_1_validation_metrics = create_metrics(scenario_1_results, val= True)
scenario_1_metrics

# %%
scenario_2_results = [all_cluster]
scenario_2_metrics = create_metrics(scenario_2_results)
scenario_2_validation_metrics = create_metrics(scenario_2_results, val= True)
scenario_2_metrics

# %% [markdown]
# #### Scenario 3 and 4

# %%
### Removing smart device features
House.cols = ['energy_kWh']
#House.cols

# %%
scenario_3_zero_cluster = Cluster(zero_houses)
scenario_3_zero_cluster_results = scenario_3_zero_cluster.results()
print('Training History for Cluster 0:')

# %%
scenario_3_one_cluster = Cluster(one_houses)
scenario_3_one_cluster_results = scenario_3_one_cluster.results()
print('Training History for Cluster 1:')

# %%
scenario_3_two_cluster = Cluster(two_houses)
scenario_3_two_cluster_results = scenario_3_two_cluster.results()
print('Training History for Cluster 2:')

# %%
scenario_3_three_cluster = Cluster(three_houses)
scenario_3_three_cluster_results = scenario_3_three_cluster.results()
print('Training History for Cluster 3:')

# %%
### Save Scenario 3 models
# scenario_3_zero_cluster.model.save('Models/Scenario3/zero_cluster')
# scenario_3_one_cluster.model.save('Models/Scenario3/one_cluster')
# scenario_3_two_cluster.model.save('Models/Scenario3/two_cluster')
# scenario_3_three_cluster.model.save('Models/Scenario3/three_cluster')

## Pickling objects

# scenario_3_zero_cluster_file = open("Models/Scenario3/Objects/zero_cluster.pickle", "wb")
# pickle.dump(scenario_3_zero_cluster, scenario_3_zero_cluster_file)
# scenario_3_zero_cluster_file.close()

# scenario_3_one_cluster_file = open("Models/Scenario3/Objects/one_cluster.pickle", "wb")
# pickle.dump(scenario_3_one_cluster, scenario_3_one_cluster_file)
# scenario_3_one_cluster_file.close()

# scenario_3_two_cluster_file = open("Models/Scenario3/Objects/two_cluster.pickle", "wb")
# pickle.dump(scenario_3_two_cluster, scenario_3_two_cluster_file)
# scenario_3_two_cluster_file.close()

# scenario_3_three_cluster_file = open("Models/Scenario3/Objects/three_cluster.pickle", "wb")
# pickle.dump(scenario_3_three_cluster, scenario_3_three_cluster_file)
# scenario_3_three_cluster_file.close()

# scenario_3_zero_cluster_results_file = open("Models/Scenario3/Objects/zero_cluster_results.pickle", "wb")
# pickle.dump(scenario_3_zero_cluster_results, scenario_3_zero_cluster_results_file)
# scenario_3_zero_cluster_results_file.close()

# scenario_3_one_cluster_results_file = open("Models/Scenario3/Objects/one_cluster_results.pickle", "wb")
# pickle.dump(scenario_3_one_cluster_results, scenario_3_one_cluster_results_file)
# scenario_3_one_cluster_results_file.close()

# scenario_3_two_cluster_results_file = open("Models/Scenario3/Objects/two_cluster_results.pickle", "wb")
# pickle.dump(scenario_3_two_cluster_results, scenario_3_two_cluster_results_file)
# scenario_3_two_cluster_results_file.close()

# scenario_3_three_cluster_results_file = open("Models/Scenario3/Objects/three_cluster_results.pickle", "wb")
# pickle.dump(scenario_3_three_cluster_results, scenario_3_three_cluster_results_file)
# scenario_3_three_cluster_results_file.close()

# %% [markdown]
# #### Scenario 4

# %%
scenario_4_all_cluster = Cluster(all_houses)
scenario_4_all_cluster_results = scenario_4_all_cluster.results()
print('Training History without clustering:')

# %%
# ### Save Scenario 4 models
# scenario_4_all_cluster.model.save('Models/Scenario4/all_cluster')

### Pickling Scenario 4 cluster and cluster result files
# scenario_4_all_cluster_file = open("Models/Scenario4/Objects/all_cluster.pickle", "wb")
# pickle.dump(scenario_4_all_cluster, scenario_4_all_cluster_file)
# scenario_4_all_cluster_file.close()

# scenario_4_all_cluster_results_file = open("Models/Scenario4/Objects/all_cluster_results.pickle", "wb")
# pickle.dump(scenario_4_all_cluster_results, scenario_4_all_cluster_results_file)
# scenario_4_all_cluster_results_file.close()

# %% [markdown]
# #### Predictions for Scenario 3 and Scenario 4

# %%
graph_predictions(scenario_3_zero_cluster_results, scenario_4_all_cluster_results)

# %%
graph_predictions(scenario_3_one_cluster_results, scenario_4_all_cluster_results)

# %%
graph_predictions(scenario_3_two_cluster_results, scenario_4_all_cluster_results)

# %%
graph_predictions(scenario_3_three_cluster_results, scenario_4_all_cluster_results)

# %% [markdown]
# #### Scenario 3 and Scenario 4 Metric Tables

# %%
scenario_3_results = [scenario_3_zero_cluster, scenario_3_one_cluster, scenario_3_two_cluster, scenario_3_three_cluster]
scenario_3_metrics = create_metrics(scenario_3_results )
scenario_3_validation_metrics = create_metrics(scenario_3_results, val= True)
scenario_3_metrics

# %%
scenario_4_results = [scenario_4_all_cluster]
scenario_4_metrics = create_metrics(scenario_4_results )
scenario_4_validation_metrics = create_metrics(scenario_4_results, val= True)
scenario_4_metrics

# %%
print('Training metrics:')
df = pd.DataFrame([scenario_1_metrics, scenario_2_metrics, scenario_3_metrics, scenario_4_metrics],index=[1,2,3,4], columns = ['Min RMSE', 'Max RMSE', 'Mean RMSE','Min MAE', 'Max MAE', 'Mean MAE'])
df['Scenario'] = np.array([1,2,3,4])
df.set_index('Scenario').round(decimals=2).to_csv('Tables/training_metrics.csv')

# %%
print('Validation metrics:')
df = pd.DataFrame([scenario_1_validation_metrics, scenario_2_validation_metrics,
                   scenario_3_validation_metrics, scenario_4_validation_metrics],index=[1,2,3,4], columns = ['Min RMSE', 'Max RMSE', 'Mean RMSE','Min MAE', 'Max MAE', 'Mean MAE'])
df['Scenario'] = np.array([1,2,3,4])
df.set_index('Scenario').round(decimals=2).to_csv('Tables/validation_metrics.csv')

# %% [markdown]
# ### Anomaly Distribution

# %%
def create_anomaly_df(result_df, scenario_name, monthly_agg = True):    
    #print(type(result_df))
    anomaly_df = result_df[['timestamp', 'Anomaly detected']]
    anomaly_df.set_index('timestamp', inplace = True)
    if monthly_agg:
        anomaly_df['Anomaly detected'] = anomaly_df['Anomaly detected'].apply(lambda x: 0 if x is False else 1)
        anomaly_df = anomaly_df.resample("M").agg('sum')
    else: 
        anomaly_df['Anomaly detected'] = anomaly_df['Anomaly detected'].apply(lambda x: 0 if x is False else x)
    anomaly_df = anomaly_df.rename(columns={'Anomaly detected': scenario_name})
    return anomaly_df

def create_anomalies_graph( title = None, **kwargs):
    anomaly_dfs = []
    for scenario_name, result_df in kwargs.items():
        anomaly_df = create_anomaly_df(result_df, scenario_name)
        anomaly_dfs.append(anomaly_df)
    anomaly_df = functools.reduce(lambda left, right: left.join(right), anomaly_dfs)
    ax = anomaly_df.plot.line(figsize=(20,10))
    ax.set_xlabel(f'Time')
    ax.set_ylabel(f'Frequency')
    ax.set_title(title)
    #return anomaly_dfs

# %%
def dtw_distance(series1, series2):
    return fastdtw.fastdtw(series1,series2)[0]

def create_distance_df(title, **kwargs):
    print(title)
    anomaly_dfs = []
    for scenario_name, result_df in kwargs.items():
        anomaly_df = np.array(create_anomaly_df(result_df, scenario_name, monthly_agg=False)).reshape(1,-1)
        anomaly_dfs.append(anomaly_df)
    anomaly_distributions = np.array(anomaly_dfs).reshape(len(kwargs),-1)
    distance_matrix = sd.squareform(sd.pdist(anomaly_distributions, dtw_distance))
    return(pd.DataFrame(distance_matrix, columns = kwargs.keys(), index = kwargs.keys()))
    #return anomaly_dfs

# %%
create_anomalies_graph( 'Anomaly Frequency Distribution for House 1: Cluster 0', Scenario1 = zero_cluster_results[1], Scenario2 = all_cluster_results[1],
                       Scenario3 = scenario_3_zero_cluster_results[1], Scenario4 = scenario_4_all_cluster_results[1])

# %%
create_distance_df('Similarity between anomaly distributions for House1: Cluster 0', Scenario1 = zero_cluster_results[1], Scenario2 = all_cluster_results[1],
                       Scenario3 = scenario_3_zero_cluster_results[1], Scenario4 = scenario_4_all_cluster_results[1]).round(decimals=2).to_csv('Tables/anomaly_cluster0.csv')

# %%
create_anomalies_graph( 'Anomaly Frequency Distribution for House 15: Cluster 1', Scenario1 = one_cluster_results[15], Scenario2 = all_cluster_results[15],
                       Scenario3 = scenario_3_one_cluster_results[15], Scenario4 = scenario_4_all_cluster_results[15])

# %%
create_distance_df( 'Similarity between anomaly distributions for House15: Cluster 1', Scenario1 = one_cluster_results[15], Scenario2 = all_cluster_results[15],
                       Scenario3 = scenario_3_one_cluster_results[15], Scenario4 = scenario_4_all_cluster_results[15]).round(decimals=2).to_csv('Tables/anomaly_cluster1.csv')

# %%
create_anomalies_graph( 'Anomaly Frequency Distribution for House 2: Cluster 2', Scenario1 = two_cluster_results[2], Scenario2 = all_cluster_results[2],
                       Scenario3 = scenario_3_two_cluster_results[2], Scenario4 = scenario_4_all_cluster_results[2])

# %%
create_distance_df( 'Similarity between anomaly distributions for House 2: Cluster 2', Scenario1 = two_cluster_results[2], Scenario2 = all_cluster_results[2],
                       Scenario3 = scenario_3_two_cluster_results[2], Scenario4 = scenario_4_all_cluster_results[2]).round(decimals=2).to_csv('Tables/anomaly_cluster2.csv')

# %%
create_anomalies_graph( 'Anomaly Frequency Distribution for House 3: Cluster 3', Scenario1 = three_cluster_results[3], Scenario2 = all_cluster_results[3],
                       Scenario3 = scenario_3_three_cluster_results[3], Scenario4 = scenario_4_all_cluster_results[3])

# %%
create_distance_df( 'Similarity between anomaly distributions for House 3: Cluster 3', Scenario1 = three_cluster_results[3], Scenario2 = all_cluster_results[3],
                       Scenario3 = scenario_3_three_cluster_results[3], Scenario4 = scenario_4_all_cluster_results[3]).round(decimals=2).to_csv('Tables/anomaly_cluster3.csv')

# %% [markdown]
# #### Energy Deficit Calculation

# %%
def create_deficit_df(result_df, scenario_name, monthly_agg = True):    
    #print(type(result_df))
    energy_df = result_df[['timestamp', 'Energy Deficit Flag']]
    energy_df.set_index('timestamp', inplace = True)
    if monthly_agg:
        energy_df['Energy Deficit Flag'] = energy_df['Energy Deficit Flag'].apply(lambda x: 0 if x is False else 1)
        energy_df = energy_df.resample("W").agg('sum')
    else: 
        energy_df['Energy Deficit Flag'] = energy_df['Energy Deficit Flag'].apply(lambda x: 0 if x is False else x)
    energy_df = energy_df.rename(columns={'Energy Deficit Flag': scenario_name})
    return energy_df

def create_energy_deficit_graph( title = None, **kwargs):
    energy_dfs = []
    for scenario_name, result_df in kwargs.items():
        energy_df = create_deficit_df(result_df, scenario_name)
        energy_dfs.append(energy_df)
    energy_df = functools.reduce(lambda left, right: left.join(right), energy_dfs)
    ax = energy_df.plot.line(figsize=(20,10))
    ax.set_xlabel(f'Time')
    ax.set_ylabel(f'Frequency')
    ax.set_title(title)

# %%
def create_deficit_distance_df(title, **kwargs):
    print(title)
    energy_dfs = []
    for scenario_name, result_df in kwargs.items():
        energy_df = np.array(create_deficit_df(result_df, scenario_name, monthly_agg=False)).reshape(1,-1)
        energy_dfs.append(energy_df)
    energy_distributions = np.array(energy_dfs).reshape(len(kwargs),-1)
    distance_matrix = sd.squareform(sd.pdist(energy_distributions, dtw_distance))
    return(pd.DataFrame(distance_matrix, columns = kwargs.keys(), index = kwargs.keys()))

# %%
create_energy_deficit_graph( 'Energy Deficit Frequency Distribution for House 1: Cluster 0', Scenario1 = zero_cluster_results[1], Scenario2 = all_cluster_results[1],
                       Scenario3 = scenario_3_zero_cluster_results[1], Scenario4 = scenario_4_all_cluster_results[1])

# %%
create_deficit_distance_df('Similarity between energy deficit distributions for House1: Cluster 0', Scenario1 = zero_cluster_results[1], Scenario2 = all_cluster_results[1],
                       Scenario3 = scenario_3_zero_cluster_results[1], Scenario4 = scenario_4_all_cluster_results[1])

# %%
create_energy_deficit_graph( 'Energy Deficit Frequency Distribution for House 15: Cluster 1', Scenario1 = one_cluster_results[15], Scenario2 = all_cluster_results[15],
                       Scenario3 = scenario_3_one_cluster_results[15], Scenario4 = scenario_4_all_cluster_results[15])

# %%
create_deficit_distance_df( 'Similarity between energy deficit distributions for House15: Cluster 1', Scenario1 = one_cluster_results[15], 
                    Scenario2 = all_cluster_results[15],
                       Scenario3 = scenario_3_one_cluster_results[15], Scenario4 = scenario_4_all_cluster_results[15])

# %%
create_energy_deficit_graph( 'Energy Deficit Frequency Distribution for House 2: Cluster 2', Scenario1 = two_cluster_results[2], Scenario2 = all_cluster_results[2],
                       Scenario3 = scenario_3_two_cluster_results[2], Scenario4 = scenario_4_all_cluster_results[2])

# %%
create_deficit_distance_df( 'Similarity between energy deficit distributions for House 2: Cluster 2', Scenario1 = two_cluster_results[2], Scenario2 = all_cluster_results[2],
                       Scenario3 = scenario_3_two_cluster_results[2], Scenario4 = scenario_4_all_cluster_results[2])

# %%
create_energy_deficit_graph( 'Energy Deficit Frequency Distribution for House 3: Cluster 3', Scenario1 = three_cluster_results[3], Scenario2 = all_cluster_results[3],
                       Scenario3 = scenario_3_three_cluster_results[3], Scenario4 = scenario_4_all_cluster_results[3])

# %%
create_deficit_distance_df( 'Similarity between energy deficit distributions for House 3: Cluster 3', Scenario1 = three_cluster_results[3], Scenario2 = all_cluster_results[3],
                       Scenario3 = scenario_3_three_cluster_results[3], Scenario4 = scenario_4_all_cluster_results[3])

# %%
print(tf. __version__)
